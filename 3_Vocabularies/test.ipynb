# %%
import pandas as pd
import zipfile
import json
from nltk.tokenize import MWETokenizer

# %%
file = "../2_2_Data_Acquisition_ETCSL/Output/alltexts.csv"
etcsl = pd.read_csv(file, keep_default_na=False)
etcsl = etcsl.loc[etcsl["lang"].str.contains("sux")]  # throw out non-Sumerian words

# %%
etcsl["lemma"] = etcsl.apply(lambda r: (r["cf"] + '[' + r["gw"] + ']' + r["pos"]) 
                            if r["cf"] != '' else r['form'] + '[NA]NA', axis=1)
etcsl['lemma'] = [lemma if not lemma == '[NA]NA' else '' for lemma in etcsl['lemma'] ] 
# kick out empty forms
etcsl["lemma"] = etcsl["lemma"].str.lower()

# %%
file = "../2_1_Data_Acquisition_ORACC/output/parsed.csv"
lexical = pd.read_csv(file, keep_default_na=False)
lexical = lexical.loc[lexical["lang"].str.contains("sux")]

# %%
lexical["lemma"] = lexical.apply(lambda r: (r["cf"] + '[' + r["gw"] + ']' + r["pos"]) 
                            if r["cf"] != '' else r['form'] + '[NA]NA', axis=1)
lexical['lemma'] = [lemma if not lemma == '[NA]NA' else '' for lemma in lexical['lemma'] ] 
# kick out empty forms
lexical["lemma"] = lexical["lemma"].str.lower()

# %%
lexical = lexical[~lexical["field"].isin(["sg", "pr"])] # remove lemmas that derive from the fields "sign" 
# or "pronunciation" in sign lists.

# %%
lexical = lexical.groupby([lexical['id_text'], lexical['id_line']]).agg({
        'lemma': tuple
    }).reset_index()

# %%
etcsl = etcsl.groupby([etcsl['id_text'], etcsl['id_line'], etcsl['text_name']]).agg({
        'lemma': list
    }).reset_index()

# %%
# kick out tuples that contain any lemma with "[na]na" and tuples of length lower than 2
lex_vocab = list(set(lexical["lemma"]))
lex_vocab_l = []
for tup in lex_vocab:
    add = True
    if len(tup) < 2:
        continue
    for lemma in tup:
        if "[na]na" in lemma:
            add = False
    if add:
        lex_vocab_l.append(tup)
lex_vocab_l
# Out:
# [('ŋeštin[vine]n', 'šušru[grape]n'),
#  ('a[arm]n', 'mah[great]v/i'),
#  ('sa[bundle]n', 'sig[tie]v/t'),
#  ('lu[person]n', 'izi[fire]n'),
#  ('kinkin[millstone]n', 'zu[tooth]n'),
#  ('gur[rim]n', 'balaŋdi[instrument]n'),
#  ('gu[neck]n', 'niŋgilim[rodent]n'),
#  ('dal[vessel]n', 'kugbabbar[silver]n'),
#  ('lub[bag]n', 'patirum[leather-bag]n'),
#  ('ašag[field]n', 'ŋeš[tree]n', 'ur[drag]v/t'),
#  ('e₂.eš₂[prison]n', 'nun[prince]n'),
#  ('a[water]n', 'sig[put]v/t'),
#  ('kir[lamb]n', 'ŋeš[penis]n', 'zu[know]v/t'),
#  ('ukuš[cucumber]n', 'liligi[plant]n'),
#  ('a[arm]n', 'su[sprinkle]v/t', 'kugbabbar[silver]n'),
#  ('ganum[stand]n', 'kaš[beer]n'),
#  ('il[basket]n', 'siki[hair]n'),
#  ('agin[thus]n', 'lu[person]n', 'zaʾe[you]ip'),
#  ('giŋ[ax]n', 'kugbabbar[silver]n'),
#  ('ušu[thirty]nu', 'mana[unit]n'),
#  ('gidim[fork]n', 'tur[be-small]v/i'),
#  ('aŋkiluh[broom]n', 'niŋkiluh[broom]n'),
#  ('buru[harvest]n', 'ed[ascend]v/i'),
#  ('lu[person]n', 'lu₂.im[criminal]n'),
#  ('e[house]n', 'ŋeškešda[dam]n'),
#  ('ninda[bread]n', 'abba[father]n', 'ah[dry]v/i'),
#  ('šunir[emblem]n', 'kugbabbar[silver]n'),
#  ('a[water]n', 'pu[orchard]n'),
#  ('bala[turn]v/i', 'gin[firm]v/i'),
#  ('egal[palace]n', 'mah[great]v/i'),
#  ('tu[soup]n', 'guniŋara[vetch]n'),
#  ('egir[back]n', 'niŋkalaga[strong]aj'),
#  ('da[side-board]n', 'ŋešnimbar[palm]n'),
#  ('kugsig[gold]n', 'lub[bag]n', 'šar[mix]v/t'),
#  ('kuš[skin]n', 'ŋar[place]v/t', 'bulug[needle]n'),
#  ('lu[person]n', 'kug[metal]n', 'gub[stand]v/i'),
#  ('lu[person]n', 'gi[thicket]n'),
#  ('al[hoe]n', 'ki[place]n'),
#  ('ni[fear]n', 'il[raise]v/t'),
#  ('par[canal]n', 'mada[land]n'),
#  ('lu[person]n', 'še[barley]n', 'la[hang]v/t', 'kita[lower]aj'),
#  ('uzu[flesh]n', 'sa[sinew]n', 'sal[thin]v/i'),
#  ('šu[hand]n', 'dubul[paralyze?]v/t'),
#  ('saŋ[head]n', 'gir[slip]v/i'),
#  ('ellaŋ[bead]n', 'nir[stone]n'),
#  ('bibra[vessel]n', 'zagin[lapis]n'),
#  ('šatam[official]n', 'e[house]n', 'ereš[lady]n'),
#  ('bisaŋ[basket]n', 'kud[cut]v/t'),
#  ('šagia[cup-bearer]n', 'ummud[waterskin]n'),
#  ('mea[where?]qp', 'anene[they]ip'),
#  ('munus[woman]n', 'kisalluh[sweeper]n'),
#  ('kišib[seal]n', 'kagina[stone]n'),
#  ('ma[ship]n', 'si[horn]n', 'limmu[four]nu'),
#  ('saŋ[head]n', 'usakar[moon]n'),
#  ('gag[pock]n', 'uzu[flesh]n', 'la[hang]v/t'),
#  ('gud[ox]n', 'gunu[speckled]v/i'),
#  ('manu[wood]n', 'ah[dry]v/i'),
#  ('sa[equal]v/t', 'silim[(to-be)-healthy]v/i'),
#  ('sipad[shepherd]n', 'gukkal[sheep]n'),
#  ('udu[sheep]n', 'ki.kaš.ni[meal]n'),
#  ('ašag[field]n', 'ŋeš[tree]n', 'peš[three]nu'),
#  ('gisig[fence]n', 'ašag[field]n'),
#  ('nim[fly]n', 'urbara[wolf]n'),
#  ('ŋešnud[bed]n', 'šagzu[midwife]n'),
#  ('lagab[block]n', 'ŋešnugal[alabaster]n'),
#  ('apap[pipe]n', 'hal[divide]v/t'),
#  ('saŋ[head]n', 'bala[turn]v/t'),
#  ('lu[person]n', 'tur[ill]n'),
#  ('endur[navel?]n', 'kud[cut]v/t'),
#  ('ŋešdili[string-of-beads]n', 'zagin[lapis]n'),
#  ('anše[equid]n', 'kaš[runner]n', 'kar[flee]v/i'),
#  ('uzu[flesh]n', 'i[oil]n', 'šah[pig]n'),
#  ('lu[person]n', 'anir[profession]n'),
#  ('ašag[field]n', 'šum[garlic]n', 'la[hang]v/t'),
#  ('mes[tree]n', 'šaršabid[tree]n'),
#  ('lu[person]n', 'sagaz[robber]n'),
#  ('ud[sun]n', 'imin[seven]nu'),
#  ('a[water]n', 'zid[right]v/i', 'ri[impose]v/t'),
#  ('zimbir[1]sn', 'amnanu[1]en'),
#  ('duru[wet]v/i', 'šu[hand]n'),
#  ('igi[face]n', 'abba[father]n', 'iri[city]n'),
#  ('bisaŋ[basket]n', 'šagrah[lining]n'),
#  ('lu[person]n', 'hulu[bad]v/i', 'gig[sick]v/i'),
#  ('a[water]n', 'šu[hand]n', 'eš[three]nu', 'bala[turn]v/i'),
#  ('kan[gate]n', 'gunu[speckled]v/i'),
#  ('ŋešnimbar[palm]n', 'niŋnam[anything]n', 'ak[do]v/t'),
#  ('gag[nail]n', 'mud[tube]n'),
#  ('erim[enemy]n', 'a[arm]n', 'e[leave]v/i'),
#  ('egar[wall]n', 'ma[ship]n'),
#  ('gu[voice]n', 'šega[agreement]n'),
#  ('gu[neck]n', 'gal[big]v/i'),
#  ('saŋ[head]n', 'gud.si.aš[ram]n'),
#  ('banšur[table]n', 'guhšu[altar]n'),
#  ('mu[name]n', 'dari[eternal]v/i'),
#  ('ud[sun]n', 'men[tiara]n', 'šag[heart]n', 'e[leave]v/i'),
#  ('šim[aromatics]n', 'šurmen[cypress]n'),
#  ('hašhur[apple]n', 'a[water]n', 'ŋal[be]v/i'),
#  ('kin[sickle]n', 'tur[small]v/i'),
#  ('lu[person]n', 'šu[hand]n', 'dugdugurhi[dead]v/i'),
#  ('nin[lady]n', 'nin[lady]n'),
#  ('nunbarhuša[1]dn', 'gibil[1]dn'),
#  ('dur[buttocks]n', 'kun[tail]n'),
#  ('e[house]n', 'ganum[stand]n'),
#  ('ki[place]n', 'idim[spring]n'),
#  ('ŋeš[tree]n', 'nuluha[asafoetida]n'),
#  ('lu[person]n', 'a[arm]n', 'gab[left]n'),
#  ('ig[door]n', 'kan[gate]n', 'egal[palace]n'),
#  ('eren[cedar]n', 'babbar[white]v/i'),
#  ('lu[person]n', 'ki[place]n', 'lah[dry]v/t'),
#  ('par[canal]n', 'gid[long]v/i'),
#  ('muru[mat]n', 'gid[long]v/i'),
#  ('lu[person]n', 'tug[textile]n', 'tun[lip]n', 'sur[spin]v/t'),
#  ('na[stone]n', 'limmu[four]nu', 'mana[unit]n'),
#  ('gada[flax]n', 'šusub[towel]n', 'erešdiŋir[priestess]n'),
#  ('lu[person]n', 'maʾu[barge]n'),
#  ('kagina[stone]n', 'dab[seize]v/t'),
#  ('ninda[bread]n', 'gur[thick]v/i', 'zidsig[flour]n'),
#  ('eme[tongue]n', 'kiʾengir[sumer]gn', 'uri[akkad]gn'),
#  ('da[line]n', 'gub[stand]v/i'),
#  ('zu[tooth]n', 'gaz[kill]v/t'),
#  ('gur[turn]v/i', 'gig[sick]v/i'),
#  ('siki[hair]n', 'sigigi[eyebrow]n'),
#  ('še[barley]n', 'mungazi[~agriculture]n'),
#  ('uzud[goat]n', 'maš[goat]n', 'nud[lie]v/i'),
#  ('inanak[1]dn', 'unug[1]sn'),
#  ('dur[board]n', 'anta[upper]v/t'),
#  ('kurum[ration]n', 'hal[divide]v/t'),
#  ('pa[branch]n', 'eren[cedar]n'),
#  ('ŋešnud[bed]n', 'uri[akkad]gn', 'gada[with]n'),
#  ('lu[person]n', 'nam[fate]n', 'e[leave]v/i'),
#  ('harran[route]n', 'kugsig[gold]n'),
#  ('saŋdu[beam]n', 'anta[upper]v/t'),
#  ('ma[ship]n', 'ninnu[fifty]nu', 'gur[unit]n'),
#  ('ŋešnud[bed]n',
#   'šagzu[midwife]n',
#   'siki[hair]n',
#   'garig[comb]n',
#   'ak[do]v/t'),
#  ('hilum[resin]n', 'urzinum[tree]n'),
#  ('ban[unit]n', 'banmin[vessel]n'),
#  ('ŋeš[tree]n', 'dud[mound]n', 'kug[pure]v/i'),
#  ('gudug[priest]n', 'sum[beard]n', 'la[hang]v/t'),
#  ('muš[snake]n', 'uŋiri[unmng]n', 'mu[grow]v/t'),
#  ('kiri[nose]n', 'šu[hand]n', 'ŋal[be]v/i', 'di[speak]v/t'),
#  ('guza[chair]n', 'šag[heart]n', 'hul[rejoice]v/i'),
#  ('duggan[bag]n', 'antibal[sign]n'),
#  ('luhša[functionary]n', 'kisal[courtyard]n', 'luh[clean]v/t'),
#  ('menata[since-when?]qp', 'menaše[how-long?]qp'),
#  ('dud[combat]n', 'mu[grow]v/i'),
#  ('na[stone]n', 'igi[eye]n', 'kud[fish]n'),
#  ('anše[equid]n', 'luhuŋa[hireling]n'),
#  ('zid[flour]n', 'edadi[flour]n'),
#  ('gud[ox]n', 'kun[tail]n', 'giggi[black]v/i'),
#  ('gu[neck]n', 'gul[destroy]v/t'),
#  ('lu[person]n', 'dun[profit]n'),
#  ('e[house]n', 'tur[be-small]v/i'),
#  ('ig[door]n', 'asal[poplar]n'),
#  ('gu[neck]n', 'šum[slaughter]v/t'),
#  ('eg[levee]n', 'šinig[tamarisk]n'),
#  ('gud[ox]n', 'babbar[white]v/i'),
#  ('saŋki[forehead]n', 'gig[sick]v/i'),
#  ('u[planking]n', 'ma[ship]n'),
#  ('ibtag[remainder]n', 'zulum[date]n'),
#  ('uzud[goat]n', 'maš[goat]n', 'tur[ill]n'),
#  ('niŋlam[garment]n', 'barag[spread]v/t', 'ak[do]v/t'),
#  ('er[tears]n', 'mun[salt]v/i'),
#  ('saŋdu[head]n', 'ana[upper]aj'),
#  ('kaš[beer]n', 'mah[great]v/i'),
#  ('bisaŋ[basket]n', 'im[clay]n', 'su[red]v/i'),
#  ('lu[person]n', 'šag[heart]n', 'dar[split]v/t'),
#  ('nundum[lip]n', 'dar[split]v/t'),
#  ('guru[shield]n', 'kalag[strong]v/i'),
#  ('a[water]n', 'rah[beat]v/t'),
#  ('e[house]n', 'duh[loosen]v/t'),
#  ('maš[goat]n', 'gub[~sheep]v/t'),
#  ('egir[back]n', 'sukkal[secretary]n'),
#  ('sila[street]n', 'kur[enter]v/i'),
#  ('kuš[skin]n', 'kaʾa[fox]n'),
#  ('šu[hand]n', 'munus[woman]n', 'dubsar[scribe]n'),
#  ('ma[ship]n', 'id[river]n', 'nirŋal[authoritative]aj'),
#  ('piriŋ[lion]n', 'kag[mouth]n', 'tab[double]v/t'),
#  ('aš[curse]n', 'gi[turn-return]v/i'),
#  ('kud[fish]n', 'sila[cut]n', 'gal[big]v/i'),
#  ('mansim[sieve]n', 'il[raise]v/t'),
#  ('aʾabak[sea]n', 'zig[rise]v/i'),
#  ('šag[heart]n', 'bil[burn]v/t'),
#  ('ašag[field]n', 'ribba[plant]n'),
#  ('ma[ship]n', 'sig[weak]v/i'),
#  ('azad[shelter]n', 'gaz[kill]v/t'),
#  ('ur[base]n', 'bad[wall]n'),
#  ('sila[lamb]n', 'gaba[chest]n'),
#  ('sahar[soil]n', 'du[spread]v/t'),
#  ('zah[disappear]v/i', 'gur[turn]v/i'),
#  ('lu[person]n', 'ušzaga[driveling]aj'),
#  ('a[water]n', 'tu[cvve]v/t'),
#  ('kuš[skin]n', 'ašgar[kid]n'),
#  ('kuš[skin]n', 'peš[mouse]n', 'ašag[field]n'),
#  ('im[clay]n', 'sugar[clay]n'),
#  ('har[ring]n', 'šu[hand]n', 'zabar[bronze]n'),
#  ('ubur[breast]n', 'dili[single]v/i', 'kugsig[gold]n'),
#  ('unu[upper-cheek]n', 'min[two]nu'),
#  ('gaʾar[cheese]n', 'gug[cake]n'),
#  ('ŋeštin[vine]n', 'ah[dry]v/i'),
#  ('ki.kal[bottom]n', 'gigir[chariot]n'),
#  ('gud[ox]n', 'dumu[child]n', 'ana[upper]aj'),
#  ('e[house]n', 'niŋgur[property]n'),
#  ('tu[soup]n', 'udra[soaked-emmer]n'),
#  ('madal[pole]n', 'gigir[chariot]n'),
#  ('ki[place]n', 'lu[person]n'),
#  ('lu[person]n', 'irʾusa[absent]v/i'),
#  ('na[pestle]n', 'niŋgina[truth]n'),
#  ('gi[thicket]n', 'diš[one]n', 'kuš[unit]n'),
#  ('a[water]n', 'še[barley]n', 'kur[mountain]n'),
#  ('uzu[flesh]n', 'šeŋ[cook]v/t'),
#  ('udu[sheep]n', 'diŋir[deity]n'),
#  ('sa[sinew]n', 'pana[bow]n'),
#  ('šu[hand]n', 'dag[demolish]v/t'),
#  ('nurma[pomegranate]n', 'pu[orchard]n', 'šu[hand]n', 'sub[rub]v/t'),
#  ('a[water]n', 'gu[neck]n', 'du[build]v/t'),
#  ('tul[fountain]n', 'mušen[bird]n'),
#  ('lu[person]n', 'še[barley]n', 'zar[sheaf]n', 'tab[grasp]v/t'),
#  ('hara[container]n', 'zagin[lapis]n'),
#  ('gurum[bend]v/t', 'ŋeštin[vine]n'),
#  ('šuŋar[favor]n', 'gi[turn]v/i'),
#  ('lu[person]n', 'kun[tail]n', 'eš[rope]n'),
#  ('azad[shelter]n', 'ri[impose]v/t'),
#  ('sila[unit]n', 'gazi[condiment]n'),
#  ('ašag[field]n', 'dud[mound]n', 'šinig[tamarisk]n'),
#  ('sipad[shepherd]n', 'gud[ox]n'),
#  ('tukul[weapon]n', 'gaz[kill]v/t'),
#  ('sila[lamb]n', 'enten[winter]n'),
#  ('in[abuse]n', 'dub[tremble]v/t'),
#  ('ŋešnud[bed]n', 'umbin[nail]n', 'gud[ox]n'),
#  ('e[house]n', 'izzi[wall]n'),
#  ('kugsig[gold]n', 'min[two]nu'),
#  ('uzu[flesh]n', 'šag[heart]n', 'lugal[king]n', 'tuku[acquire]v/t'),
#  ('ud[sun]n', 'hulu[bad]v/i'),
#  ('udu[sheep]n', 'gub[stand]v/i'),
#  ('e[house]n', 'bursaŋ[building]n'),
#  ('sukkal[secretary]n', 'idu[doorkeeper]n'),
#  ('dirig[exceed]v/i', 'lu[person]n'),
#  ('ig[door]n', 'dib[board]n'),
#  ('dam[spouse]n', 'dam[spouse]n'),
#  ('ub[corner]n', 'igi[eye]n'),
#  ('šibir[staff]n', 'šudu[equipped]aj'),
#  ('bun[bellows]n', 'dug[speak]v/t'),
#  ('gud[ox]n', 'bar[outside]n', 'šugi[senior]n'),
#  ('lu[person]n', 'pamušenak[wing]n'),
#  ('tir[forest]n', 'šen[pure]v/i'),
#  ('lu[person]n', 'ala[manacles]n'),
#  ('šag[heart]n', 'tahar[distend]v/i'),
#  ('inim[word]n', 'egal[palace]n'),
#  ('lu[person]n', 'saŋ[head]n', 'ŋeš[tree]n', 'rah[beat]v/t'),
#  ('garadin[bundle]n', 'kešed[bind]v/t'),
#  ('guza[chair]n', 'nita[male]n'),
#  ('kuš[skin]n', 'urki[dog]n'),
#  ('us₂.a.du[border]n', 'ašag[field]n'),
#  ('tukul[weapon]n', 'imin[1]dn'),
#  ('kuš[skin]n', 'babbar[white]v/i'),
#  ('duh[bran]n', 'ŋen[go]v/i'),
#  ('munu[malt]n', 'us[follow]v/t'),
#  ('bar[outside]n', 'zig[rise]v/i'),
#  ('lu[person]n', 'kug[metal]n', 'kalag[~silver]n', 'ak[do]v/t'),
#  ('ur[dog]n', 'sissig[green]v/i'),
#  ('kag[mouth]n', 'ŋiri[dagger]n', 'gal[big]v/i'),
#  ('ak[do]v/t', 'im[clay]n', 'bar[cvve]v/t'),
#  ('muš[snake]n', 'ŋušur[beam]n'),
#  ('ma[ship]n', 'luʾunug[1]dn'),
#  ('šum[garlic]n', 'saŋdu[head]n'),
#  ('a[water]n', 'de[pour]v/t'),
#  ('ig[door]n', 'me[battle]n'),
#  ('e[house]n', 'zana[doll]n'),
#  ('lu[person]n', 'barda[crossbar]n'),
#  ('ama[mother]n', 'ugu[skull]n'),
#  ('suhur[tuft]n', 'la[hang]v/t'),
#  ('udu[sheep]n', 'giggi[black]v/i'),
#  ('eg[levee]n', 'sadur[bottom]n'),
#  ('e[house]n', 'puzriš-dagan[1]tn'),
#  ('ŋešnimbar[palm]n', 'uhin[date]n', 'šag[heart]n', 'ud[sun]n'),
#  ('ugula[overseer]n', 'un.il₂[menial]n'),
#  ('eren[cedar]n', 'mes[blackness]n'),
#  ('te[denigrate]v/t', 'ak[do]v/t'),
#  ('a[water]n', 'naŋa[potash]n'),
#  ('tug[textile]n', 'a[water]n', 'tu[cvve]v/t'),
#  ('gi[thicket]n', 'ša[snap]v/t'),
#  ('kurum[ration]n', 'šub[fall]v/t'),
#  ('gurgur[vessel]n', 'i[oil]n', 'dug[good]v/i'),
#  ('munus[woman]n', 'larah[straits]n'),
#  ('zabar[bronze]n', 'huš[reddish]v/i'),
#  ('še[barley]n', 'lillan[grain]n'),
#  ('šu[hand]n', 'sud[distant]v/i', 'ri[distant]v/i'),
#  ('aga[rear]n', 'gi[turn]v/i'),
#  ('eme[tongue]n', 'dalhamun[storm]n'),
#  ('ki[place]n', 'kiŋ[seek]v/t'),
#  ('udu[sheep]n', 'niga[fattened]v/i', 'sag[rare]v/i'),
#  ('asura[water]n', 'gal[big]v/i'),
#  ('tukul[weapon]n', 'mah[great]v/i'),
#  ('guza[chair]n', 'šuniŋin[total]n'),
#  ('guza[chair]n', 'halub[tree]n'),
#  ('esi[tree]n', 'meluhha[1]gn'),
#  ('kaš[beer]n', 'hurum[~pot]n'),
#  ('siki[hair]n', 'bar[outside]n', 'gal[big]v/i'),
#  ('gada[flax]n', 'susbu[priest]n'),
#  ('niŋ[thing]n', 'šanabi[two-thirds]nu', 'sila[unit]n'),
#  ('ud[sun]n', 'utud[bear]v/t'),
#  ('attar[derision]n', 'la[hang]v/t'),
#  ('na[pestle]n', 'zagin[lapis]n'),
#  ('maš[interest]n', 'bala[turn]v/t'),
#  ('dub[knee]n', 'ki[place]n', 'dur[buttocks]n', 'ŋar[place]v/t'),
#  ('amar[young]n', 'šag[heart]n', 'dara[red]v/i'),
#  ('maš[goat]n', 'sum[beard]n', 'la[hang]v/t'),
#  ('tug[textile]n', 'šu[hand]n', 'ak[do]v/t'),
#  ('ki[place]n', 'uludin[form]n', 'la[hang]v/t'),
#  ('kid[mat]n', 'ma[ship]n', 'šag[heart]n', 'niŋin[encircle]v/t'),
#  ('mu[year]n', 'imma[last-year]ma'),
#  ('kag[mouth]n', 'piriŋ[lion]n'),
#  ('adkin[meat]n', 'lak262[animal]n'),
#  ('udu[sheep]n', 'zagšu[brand]n'),
#  ('lu[person]n', 'hunu[weak]v/i'),
#  ('e[house]n', 'šudul[yoke]n', 'apin[plow]n'),
#  ('niŋ[thing]n', 'u[ten]nu', 'giŋ[unit-of-weight]n'),
#  ('garan[bunch]n', 'hašhur[apple]n'),
#  ('ŋešnimbar[palm]n', 'ug[kill]v/t'),
#  ('lu[person]n', 'še[barley]n', 'kinkin[miller]n'),
#  ('kag[mouth]n', 'šerda[crime]n'),
#  ('al[hoe]n', 'zu[tooth]n', 'limmu[four]nu'),
#  ('sila[street]n', 'gu[eat]v/t'),
#  ('uzud[goat]n', 'mah[mature]v/i'),
#  ('e[house]n', 'kug[pure]v/i'),
#  ('kuš[skin]n', 'peš[mouse]n', 'šeg[animal]n'),
#  ('a[arm]n', 'sig[weak]v/i'),
#  ('gu[voice]n', 'rah[beat]v/t'),
#  ('igi[eye]n', 'lib[daze]n'),
#  ('na[stone]n', 'u[ten]nu', 'mana[unit]n'),
#  ('kuš[skin]n', 'giggi[black]v/i'),
#  ('igi[eye]n', 'kur[different]v/i'),
#  ('nindaʾidea[bread]n', 'ŋen[go]v/i'),
#  ('gud[ox]n', 'na[cvne]n', 'deg[collect]v/t'),
#  ('dug[pot]n', 'inun[ghee]n'),
#  ('namidu[status]n', 'gal[big]v/i'),
#  ('e[house]n', 'niŋ[thing]n', 'murgu[fodder]n'),
#  ('ašag[field]n', 'buru[harvest]n', 'mah[great]v/i', 'tur[be-small]v/i'),
#  ('ŋirigub[footstool]n', 'margida[cart]n'),
#  ('nindaʾidea[bread]n', 'i[oil]n', 'šah[pig]n'),
#  ('ennuŋ[imprisonment]n', 'murub[middle]n'),
#  ('alan[image]n', 'kugbabbar[silver]n'),
#  ('ašag[field]n', 'eninnu[1]tn'),
#  ('niŋ[thing]n', 'šukara[tool]n'),
#  ('par[canal]n', 'nukirik[gardener]n'),
#  ('lu[person]n', 'izi[fire]n', 'tag[touch]v/t'),
#  ('šeg[brick]n', 'izi[fire]n', 'ur[bake]v/t'),
#  ('kuš[skin]n', 'maš[goat]n', 'tur[small]v/i'),
#  ('gudug[priest]n', 'bala[turn]v/i', 'tuš[sit]v/i'),
#  ('igi[eye]n', 'kar[blow]v/t'),
#  ('a[arm]n', 'zid[right]v/i'),
#  ('munu[malt]n', 'duru[wet]v/i'),
#  ('lub[bag]n', 'sumun[vessel]n'),
#  ('umbisaŋ[scribe]n', 'mes[hero]n'),
#  ('maš[goat]n', 'gabaria[offering]n'),
#  ('usakar[moon]n', 'ig[door]n'),
#  ('gazi[condiment]n', 'guz[crush]v/i'),
#  ('kan[gate]n', 'munus[woman]n'),
#  ('im[clay]n', 'zusik[plucking]n'),
#  ('aŋla[clothing]n', 'niŋla[clothing]n'),
#  ('masab[basket]n', 'sig[tie]v/t'),
#  ('gigur[container]n', 'bisaŋ[basket]n'),
#  ('a[water]n', 'anzag[horizon]n', 'zu[know]v/i'),
#  ('šendili[ewer]n', 'kum[hot]v/i'),
#  ('kuš[skin]n', 'šegin[glue]n', 'zalag[shine]v/i'),
#  ('šum[garlic]n', 'tulu[slacken]v/t'),
#  ('apap[pipe]n', 'an[sky]n'),
#  ('im[clay]n', 'gur[thick]v/i'),
#  ('munus[woman]n', 'gabšam[peddlar]n'),
#  ('dur[board]n', 'kita[lower]aj'),
#  ('ya[five]nu', 'sila[unit]n'),
#  ('ugula[overseer]n', 'e[house]n', 'un.il₂[menial]n'),
#  ('lu[person]n', 'mašsaŋ[leader]n'),
#  ('e[house]n', 'saŋ[head]n', 'il[raise]v/t'),
#  ('udu[sheep]n', 'aslum[sheep]n', 'gukkal[sheep]n'),
#  ('ane[he]ip', 'nu[not]v/i'),
#  ('kag[mouth]n', 'urgir[dog]n'),
#  ('esir[shoe]n', 'gal[big]v/i'),
#  ('šag[heart]n', 'niŋniŋina[assembly]n'),
#  ('kugsig[gold]n', 'arali[earth]n'),
#  ('munus[woman]n', 'me[being]n'),
#  ('ugula[overseer]n', 'namninnu[group-of-50]n'),
#  ('gud[ox]n', 'ur[harness]n'),
#  ('e[house]n', 'šag[heart]n', 'huš[reddish]v/i'),
#  ('aŋšuluh[cleaning-equipment]n', 'niŋšuluh[cleaning-equipment]n'),
#  ('su[flesh]n', 'zig[rise]v/i'),
#  ('saŋšu[turban]n', 'dakirum[garment]n'),
#  ('epig[vessel]n', 'mušen[bird]n'),
#  ('im[clay]n', 'giggi[black]v/i'),
#  ('mu[tree]n', 'ya[five]nu', 'ŋeš[tree]n', 'ya[five]nu'),
#  ('suku[pole]n', 'margida[cart]n'),
#  ('ŋeštug[ear]n', 'gal[big]v/i'),
#  ('a[water]n', 'ru[cvve]v/t'),
#  ('šu[hand]n', 'dug[speak]v/t'),
#  ('lu[person]n', 'abba[father]n'),
#  ('duh[bran]n', 'sag[rare]v/i'),
#  ('bisaŋ[basket]n', 'kug[metal]n'),
#  ('kin[sickle]n', 'gal[big]v/i'),
#  ('ašag[field]n', 'esir[shoe]n', 'dub[tremble]v/t'),
#  ('saŋ[head]n', 'nu[not]v/i', 'še[barley]n', 'ba[allot]v/t'),
#  ('egir[back]n', 'eme[tongue]n', 'sal[thin]v/i'),
#  ('ŋešnud[bed]n', 'aški[rushes]n', 'du[build]v/t'),
#  ('eme[tongue]n', 'dug[good]v/i'),
#  ('uzu[flesh]n', 'ŋiri[dagger]n', 'ak[do]v/t'),
#  ('lu[person]n', 'gu[voice]n', 'di[speak]v/t'),
#  ('tug[textile]n', 'gir[slip]v/i'),
#  ('abzaza[zebu]n', 'kugsig[gold]n'),
#  ('ur[root]n', 'gi[thicket]n'),
#  ('šeg[brick]n', 'tug[textile]n'),
#  ('saŋ[head]n', 'ib[angry]v/i', 'ak[do]v/t'),
#  ('kiri[nose]n', 'haš[break]v/t'),
#  ('sudin[~chariot]n', 'margida[cart]n'),
#  ('saŋ[head]n', 'igi[eye]n', 'gunu[speckled]v/i'),
#  ('maš[interest]n', 'še[barley]n'),
#  ('išib[priest]n', 'kigal[platform]n'),
#  ('gag[nail]n', 'agar[lead]n'),
#  ('šeg[brick]n', 'gag[nail]n', 'ŋar[place]v/t'),
#  ('kuš[skin]n', 'durah[goat]n', 'mašda[gazelle]n'),
#  ('muš[snake]n', 'na[stone]n'),
#  ('še[barley]n', 'bala[turn]v/i'),
#  ('gu[neck]n', 'naŋ[drink]v/t'),
#  ('tu[soup]n', 'ur[convulsed]v/i'),
#  ('peš[fig]n', 'subir[1]gn'),
#  ('gag[nail]n', 'ŋešla[key]n'),
#  ('niŋkur[hostility]n', 'di[speak]v/t'),
#  ('ŋiri[dagger]n', 'šuʾi[barber]n'),
#  ('piš[bank]n', 'gul[destroy]v/t'),
#  ('maš[interest]n', 'kugbabbar[silver]n'),
#  ('gir[oven]n', 'ad.kid[weaver]n'),
#  ('im[clay]n', 'de[pour]v/t'),
#  ('sila[unit]n', 'gal[big]v/i'),
#  ('lu[person]n', 'hursaŋ[mountain]n'),
#  ('egizid[priestess]n', 'an[1]dn'),
#  ('usuh[tree]n', 'eren[cedar]n'),
#  ('lu[person]n', 'kaš[runner]n', 'kešed[bind]v/t'),
#  ('šu[hand]n', 'du[push]v/t'),
#  ('pešeš[~boat]n', 'ma[ship]n'),
#  ('lu[person]n', 'lil[ghost]n'),
#  ('umma[old-woman]n', 'gal[big]v/i'),
#  ('kuš[skin]n', 'e[leave]v/i'),
#  ('gud[ox]n', 'mu[year]n', 'eš[three]nu'),
#  ('zukešed[knot]n', 'kagina[stone]n'),
#  ('dub[knee]n', 'bar[outside]n', 'margida[cart]n'),
#  ('dam[spouse]n', 'banda[junior]v/i'),
#  ('lu[person]n', 'til[live]v/i'),
#  ('a[water]n', 'ri[impose]v/t'),
#  ('ud[sun]n', 'kaš[runner]n'),
#  ('a[arm]n', 'diš[one]n', 'kuš[unit]n'),
#  ('buniŋ[trough]n', 'zulum[date]n'),
#  ('niŋ[thing]n', 'ŋar[place]v/t'),
#  ('šu[hand]n', 'bar[outside]n', 'šuš[cover]v/t'),
#  ('siki[hair]n', 'šakanka[market]n'),
#  ('ur[he]ip', 'me[be]v/i'),
#  ('e[house]n', 'nun[prince]n'),
#  ('šu[hand]n', 'alim[bison]n'),
#  ('ašag[field]n', 'mada[land]n', 'mungen[1]gn'),
#  ('gag[nail]n', 'umbin[nail]n', 'gagsila[harness]n'),
#  ('ŋidru[scepter]n', 'ellaŋdu[trap]n'),
#  ('raba[clamp]n', 'šu[hand]n'),
#  ('tigidlu[instrument]n', 'sa[sinew]n', 'eš[three]nu'),
#  ('guru[shield]n', 'erin[people]n'),
#  ('tug[textile]n', 'šagha[cloth]n'),
#  ('lu[person]n', 'saŋ[head]n', 'du[hold]v/t'),
#  ('mea[where?]qp', 'imria[clan]n'),
#  ('šum[garlic]n', 'gaz[kill]v/t'),
#  ('uzu[flesh]n', 'sila[cut]n', 'dili[single]v/i'),
#  ('še[barley]n', 'gur[unit]n'),
#  ('šukešed[clothing]n', 'kešed[bind]v/t'),
#  ('e[house]n', 'ŋar[place]v/t'),
#  ('lu[person]n', 'še[barley]n', 'hum[snap]v/t'),
#  ('sa[net]n', 'hurda[reed-mat]n'),
#  ('ig[door]n', 'gunu[speckled]v/i'),
#  ('barda[crossbar]n', 'ŋešnud[bed]n'),
#  ('endu[song]n', 'dug[speak]v/t'),
#  ('ninda[bread]n', 'kud[sweet]v/i'),
#  ('saŋ[head]n', 'ur[convulsed]v/i'),
#  ('im[clay]n', 'ah[dry]v/i'),
#  ('sukkal[secretary]n', 'igi[face]n', 'sukkal[secretary]n'),
#  ('gag[nail]n', 'ma[ship]n'),
#  ('šag[heart]n', 'gu[neck]n', 'gi[turn]v/i'),
#  ('tilimda[vessel]n', 'kugbabbar[silver]n'),
#  ('dur[balk]n', 'bala[turn]v/i'),
#  ('abula[gate]n', 'lugal[king]n'),
#  ('šukud[fisherman]n', 'aʾabak[sea]n'),
#  ('saŋdu[head]n', 'kita[lower]aj'),
#  ('bad[open]v/t', 'ambar[reed-bed]n'),
#  ('dub.du₃[~vehicle]n', 'šag[heart]n'),
#  ('šaduga[yesterday?]n', 'de[pour]v/t'),
#  ('ŋeštug[ear]n', 'zamin[lyre]n'),
#  ('gudkalamak[path]n', 'ŋen[go]v/i'),
#  ('sa[net]n', 'ŋeš[tree]n'),
#  ('ir[scent]n', 'dug[good]v/i'),
#  ('guza[chair]n', 'niŋba[gift]n'),
#  ('an[1]dn', 'gal[big]v/i'),
#  ('mes[tree]n', 'halub[tree]n', 'magan[1]gn'),
#  ('šen[cauldron]n', 'burud[perforate]v/t'),
#  ('kaš[beer]n', 'kurun[beer]n', 'imin[seven]n', 'gur[unit]n'),
#  ('udun[kiln]n', 'bahar[potter]n'),
#  ('a[arm]n', 'badsi[parapet]n'),
#  ('udu[sheep]n', 'ki[place]n', 'ŋar[place]v/t'),
#  ('in[sector]n', 'bulug[needle]n'),
#  ('e[house]n', 'šagia[cup-bearer]n'),
#  ('kugbabbar[silver]n', 'gub[stand]v/i'),
#  ('e[house]n', 'šah[pig]n'),
#  ('e[house]n', 'namtar[fate]n'),
#  ('e[house]n', 'gid[long]v/i'),
#  ('šim[aromatics]n', 'burud[perforate]v/t'),
#  ('gag[nail]n', 'umbin[wheel]n', 'gigir[chariot]n'),
#  ('lu[person]n', 'šu[hand]n', 'kudkudra[disabled]n'),
#  ('lu[person]n', 'dubtuku[runner]n'),
#  ('bisaŋ[basket]n', 'dub[tablet]n'),
#  ('kuš[skin]n', 'siki[hair]n', 'mu[grow]v/t'),
#  ('zag[side]n', 'andul[shade]n', 'ŋešnud[bed]n'),
#  ('ama[mother]n', 'zu[know]v/i'),
#  ('dida[wort]n', 'hab[malodorous]v/i'),
#  ('zabar[bronze]n', 'ga[milk]n'),
#  ('inanak[1]dn', 'larsam[1]sn'),
#  ('nir[stone]n', 'igi[eye]n'),
#  ('bur[bowl]n', 'sissig[green]v/i'),
#  ('aŋarin[matrix]n', 'sig[tie]v/t'),
#  ('kag[mouth]n', 'taka[cvve]v/t'),
#  ('lu[person]n', 'kal[rare]v/i'),
#  ('še[barley]n', 'šu[hand]n', 'ak[do]v/t'),
#  ('usakar[moon]n', 'dušia[stone]n'),
#  ('kan[gate]n', 'hursaŋ[mountain]n'),
#  ('kul[handle]n', 'zamin[lyre]n'),
#  ('tila[grapevine]n', 'ŋeštin[vine]n'),
#  ('dur[donkey]n', 'gu[voice]n', 'di[speak]v/t'),
#  ('šir[song]n', 'namgala[~liturgy]n'),
#  ('ban[unit]n', 'ya[five]nu', 'sila[unit]n'),
#  ('gudalim[bovid]n', 'kugsig[gold]n'),
#  ('šudul[yoke]n', 'apin[plow]n'),
#  ('ildag[poplar]n', 'kur[mountain]n'),
#  ('saŋ[head]n', 'lul[false]v/i'),
#  ('lu[person]n', 'lib[absent]v/i'),
#  ('menzen[you]ip', 'nam[fate]n'),
#  ('na[stone]n', 'sa[half]n', 'mana[unit]n'),
#  ('izzi[wall]n', 'huluh[frightened]v/i'),
#  ('kaš[beer]n', 'šakanka[market]n'),
#  ('kuš[skin]n', 'šegin[glue]n', 'sig[put]v/t'),
#  ('eze[sheep]n', 'udu[sheep]n'),
#  ('gud[ox]n', 'sig[weak]v/i'),
#  ('inim[word]n', 'bar[outside]n'),
#  ('ab[cow]n', 'mah[great]v/i'),
#  ('kid[mat]n', 'sisig[breeze]n', 'ma[ship]n'),
#  ('gi[thicket]n', 'gun[load]n'),
#  ('kagina[stone]n', 'kalag[strong]v/i'),
#  ('šagia[cup-bearer]n', 'tur[be-small]v/i'),
#  ('tun[container]n', 'gidubak[stylus]n'),
#  ('bala[turn]v/t', 'dari[eternal]v'),
#  ('utul[tureen]n', 'šulal[defiled]aj'),
#  ('lu[person]n', 'šagtahar[colic]n'),
#  ('uŋ[people]n', 'dagan[totality]n'),
#  ('nundum[lip]n', 'dug[good]v/i'),
#  ('lu[person]n', 'sa[net]n', 'ur[drag]v/t'),
#  ('ellaŋ[bead]n', 'haštum[stone]n'),
#  ('lu[person]n', 'igi[eye]n', 'su[red]v/i'),
#  ('udu[sheep]n', 'šakanka[market]n'),
#  ('gigur[container]n', 'utul[tureen]n'),
#  ('a[water]n', 'dub[heap]v/t'),
#  ('lu[person]n', 'inu[straw]n', 'šu[hand]n', 'saga[reap]v/t'),
#  ('uzud[goat]n', 'šugi[senior]n'),
#  ('lu[person]n', 'zagin[lapis]n', 'e[leave]v/i'),
#  ('erin[people]n', 'sig[weak]v/i'),
#  ('dur[board]n', 'šeg[brick]n'),
#  ('nar[musician]n', 'halatuša[apprentice]n'),
#  ('huwawa[monster]n', 'zagin[lapis]n'),
#  ('kuš[skin]n', 'kundar[animal]n'),
#  ('niŋara[groats]n', 'šu[hand]n', 'ur[drag]v/t'),
#  ('uzu[flesh]n', 'šag[heart]n', 'šu[hand]n', 'niŋin[encircle]v/t'),
#  ('maš[goat]n', 'hursaŋ[mountain]n'),
#  ('ŋeš[tree]n', 'ŋeš[tree]n', 'la[hang]v/t'),
#  ('ma[ship]n', 'su[sink]v/t'),
#  ('ešgur[ring]n', 'zagin[lapis]n'),
#  ('lu[person]n', 'uš[spittle]n', 'zu[know]v/i'),
#  ('anta[upper]aj', 'dimgal[pole]n', 'ma[ship]n'),
#  ('gigur[container]n', 'šagrah[lining]n'),
#  ('ennuŋ[imprisonment]n', 'til[live]v/i'),
#  ('šu[hand]n', 'gin[firm]v/i'),
#  ('niŋlam[garment]n', 'munus[woman]n', 'kar[quay]n'),
#  ('nim[high]v/i', 'sig[weak]v/i'),
#  ('e[house]n', 'asikil[profession]n'),
#  ('ma[ship]n', 'šag[heart]n', 'hulu[bad]v/i'),
#  ('šag[heart]n', 'šu[hand]n'),
#  ('lu[person]n', 'kan[gate]n'),
#  ('ir[peg]n', 'ig[door]n'),
#  ('ninda[bread]n', 'zid[flour]n', 'munu[malt]n', 'sag[good]v/i'),
#  ('buru[harvest]n', 'ak[do]v/t'),
#  ('uzud[goat]n', 'ŋeš[penis]n', 'zu[know]v/t'),
#  ('kaš[beer]n', 'de[pour]v/t'),
#  ('ki.kal[bottom]n', 'niŋna[bag]n'),
#  ('zebed[heavy]v/i', 'dugud[heavy]v/i'),
#  ('i[oil]n', 'li[press]v/t'),
#  ('šakanka[market]n', 'mušen[bird]n'),
#  ('kaš[beer]n', 'kurun[beer]n', 'babbar[white]v/i'),
#  ('zara[pivot]n', 'ŋušur[harrow]n'),
#  ('muš[snake]n', 'saŋkal[foremost]aj'),
#  ('udu[sheep]n', 'dagaltuma[~wool]aj'),
#  ('e[house]n', 'kaʾusa[function]n'),
#  ('siki[hair]n', 'gaba[chest]n'),
#  ('kur[different]v/i', 'inim[word]n', 'bala[turn]v/i'),
#  ('mada[land]n', 'kiʾengir[sumer]gn'),
#  ('e[house]n', 'esad[trap]n'),
#  ('ig[door]n', 'manu[wood]n'),
#  ('saŋki[forehead]n', 'sig[weak]v/i', 'gig[sick]v/i'),
#  ('um[bird]n', 'nita[male]n'),
#  ('u[oil]n', 'zeb[good]v', 'i[oil]n', 'dug[good]v/i'),
#  ('a[arm]n', 'apin[plow]n'),
#  ('še[barley]n', 'saŋ[head]n', 'lillan[grain]n'),
#  ('muš[snake]n', 'su[red]v/i'),
#  ('bur[bowl]n', 'izaga[oil]n'),
#  ('dur[donkey]n', 'gu[voice]n', 'did[lawsuit]n'),
#  ('gaz[kill]v/t', 'kud[fish]n'),
#  ('lu[person]n', 'kar[insult]v/t'),
#  ('a[water]n', 'numun[seed]n', 'saŋ[head]n'),
#  ('šerkan[ornament]n', 'dug[speak]v/t'),
#  ('gi[thicket]n', 'te[pierce]v/t'),
#  ('ninda[bread]n', 'gug[cake]n', 'ŋen[go]v/i'),
#  ('siki[hair]n', 'mar.tu[westerner]n'),
#  ('zag[side]n', 'esir[shoe]n'),
#  ('na[stone]n', 'teš[shame]n'),
#  ('u[ewe]n', 'giggi[black]v/i'),
#  ('uzu[flesh]n', 'gubalŋešdua[hump]n'),
#  ('igi[eye]n', 'sa[net]n', 'ŋeš[tree]n'),
#  ('e[house]n', 'amaš[sheepfold]n'),
#  ('silim[(to-be)-healthy]v/i', 'tuku[acquire]v/t'),
#  ('lu[person]n', 'še[barley]n', 'saŋŋar[millstone]n', 'ak[do]v/t'),
#  ('peš[fig]n', 'kukkug[dark]v/i'),
#  ('maš[interest]n', 'maš[interest]n', 'tuku[acquire]v/t'),
#  ('šusi[finger]n', 'esir[shoe]n'),
#  ('sua[cat]n', 'si[horn]n'),
#  ('ŋešnimbar[palm]n', 'sukud[height]n'),
#  ('a[water]n', 'harra[dug?]aj'),
#  ('e[house]n', 'šurin[oven]n'),
#  ('gag[nail]n', 'muš[snake]n', 'apin[plow]n'),
#  ('ašag[field]n', 'ambar[reed-bed]n', 'enki[1]dn'),
#  ('e[house]n', 'šag[heart]n', 'ŋir[pride]v/t'),
#  ('ašag[field]n', 'kiri[orchard]n'),
#  ('am[bull]n', 'eš[three]nu'),
#  ('udu[sheep]n', 'deg[collect]v/t'),
#  ('siki[hair]n', 'hi[mix]v/t'),
#  ('en[lord]n', 'amar[young]n', 'kalam[land]n'),
#  ('amam[jar]n', 'sab[jar]n'),
#  ('na[stone]n', 'ya[five]nu', 'mana[unit]n'),
#  ('muš[snake]n', 'še[barley]n', 'gubula[~barley]n'),
#  ('še[cone]n', 'usuh[tree]n'),
#  ('bir[locust]n', 'gal[big]v/i'),
#  ('muš[space]n', 'bad[wall]n'),
#  ('sila[lamb]n', 'dili[single]v/i', 'ur[pluck]v/t'),
#  ('guʾe[textile]n', 'gunu[speckled]v/i'),
#  ('utul[tureen]n', 'algameš[stone]n'),
#  ('še[barley]n', 'še[barley]n', 'bala[turn]v/i'),
#  ('udu[sheep]n', 'gukkal[sheep]n', 'tu[~sheep]aj'),
#  ('suhur[tool]n', 'anše[equid]n'),
#  ('e[house]n', 'bur[tear]v/t'),
#  ('ŋeš[tree]n', 'daŋal[wide]v/i'),
#  ('ninda[bread]n', 'zilkum[~animal]n'),
#  ('ŋešŋiri[fetters]n', 'šudu[equipped]aj'),
#  ('tukumbi[if]cnj', 'ugu[cvne]n', 'de[pour]v/t'),
#  ('suhub[boots]n', 'eban[pair]n'),
#  ('ab[cow]n', 'ti[rib]n', 'dara[red]v/i'),
#  ('tug[textile]n', 'dig[soft]v/i'),
#  ('dim[post]n', 'marru[stormwind]n'),
#  ('šen[cauldron]n', 'zir[slip]n'),
#  ('antibal[sign]n', 'ma[ship]n'),
#  ('bar[outside]n', 'kun[tail]n'),
#  ('ennuŋ[imprisonment]n', 'sa[half]n'),
#  ('lu[person]n', 'dun[warp]v/t'),
#  ('lu[person]n', 'imtaga[sneering]n'),
#  ('ig[door]n', 'šag[heart]n', 'sig[silent]n'),
#  ('munu[malt]n', 'ud[sun]n', 'tab[double]v/t'),
#  ('egal[palace]n', 'namlugal[kingship]n'),
#  ('nar[musician]n', 'gal[big]v/i'),
#  ('lu[person]n', 'niŋaldi[request]n'),
#  ('ab[cow]n', 'ur[harness]n'),
#  ('suhub[boots]n', 'šukama[desire]n'),
#  ('ig[door]n', 'lul[false]v/i'),
#  ('lu[person]n', 'saŋ[head]n', 'sar[shave]v/t'),
#  ('udu[sheep]n', 'terzum[presentation]n'),
#  ('gi[thicket]n', 'guruš[cut]v/t'),
#  ('sis[spare]v/t', 'dug[speak]v/t'),
#  ('šuba[stone]n', 'gal[big]v/i'),
#  ('šu[hand]n', 'gurum[bend]v/i'),
#  ('idub[granary]n', 'še[barley]n'),
#  ('tug[textile]n', 'pala[garment]n'),
#  ('niŋ[thing]n', 'hi[mix]v/t'),
#  ('luŋa[damage]n', 'ŋar[place]v/t'),
#  ('zir[slip]n', 'ŋar[place]v/t'),
#  ('kug[metal]n', 'šum[give]v/t'),
#  ('gu[neck]n', 'si[horn]n', 'ki[place]n'),
#  ('a[arm]n', 'durah[goat]n'),
#  ('ma[ship]n', 'ma[ship]n', 'inanak[1]dn'),
#  ('mul[star]n', 'an[sky]n'),
#  ('lugal[king]n', 'us[follow]v/t'),
#  ('tug[textile]n', 'zulumhi[sheep]n'),
#  ('ninda[bread]n', 'gur[thick]v/i', 'lu[person]n'),
#  ('siki[hair]n', 'kad[tie]v/t'),
#  ('hilum[resin]n', 'šagkal[tree]n'),
#  ('mu[year]n', 'ana[upper]aj'),
#  ('ŋeštin[vine]n', 'kaʾa[fox]n'),
#  ('an[sky]n', 'zi[life]n', 'sukud[height]n'),
#  ('udu[sheep]n', 'ziga[expenditure]n', 'didli[several]aj'),
#  ('gu[neck]n', 'ki[place]n', 'la[hang]v/t'),
#  ('ab[window]n', 'šuš[cover]v/t'),
#  ('anše[equid]n', 'margida[cart]n'),
#  ('dilim[spoon]n', 'agar[lead]n'),
#  ('ubur[breast]n', 'maštab[twin]n'),
#  ('lu[person]n', 'dud[combat]n', 'mu[grow]v/i'),
#  ('gag[nail]n', 'umbin[nail]n', 'gigir[chariot]n'),
#  ('mun[salt]v/i', 'ah[dry]v/i'),
#  ('udu[sheep]n', 'mašanše[animals]n'),
#  ('kišighar[tree]n', 'kur[mountain]n'),
#  ('kag[mouth]n', 'sun[haughty]v/i'),
#  ('uzu[flesh]n', 'lipiš[innards]n'),
#  ('munkud[tax-collector]n', 'enkud[tax-collector]n'),
#  ('par[canal]n', 'šitan[water-channel]n'),
#  ('e[house]n', 'nir.gam.ma[arch]n'),
#  ('guza[chair]n', 'gar[knob]n', 'zabar[bronze]n', 'ŋar[place]v/t'),
#  ('niŋ[thing]n', 'til[complete]v/i'),
#  ('pa[branch]n', 'kud[cut]v/t'),
#  ('še[barley]n', 'deg[collect]v/t'),
#  ('na[stone]n', 'min[two]nu', 'mana[unit]n'),
#  ('e[house]n', 'še[barley]n'),
#  ('ziz[emmer]n', 'gunida[~grain]n'),
#  ('umbin[nail]n', 'šusi[finger]n', 'ŋiri[foot]n'),
#  ('niŋsakar[tool]n', 'burud[perforate]v/t'),
#  ('muš[snake]n', 'apin[plow]n'),
#  ('šakanka[market]n', 'še[barley]n'),
#  ('gada[flax]n', 'šagadu[belt]n', 'giggi[black]v/i'),
#  ('gana[field]n', 'il[worker]n'),
#  ('šilam[cow]n', 'gal[big]v/i'),
#  ('uzu[flesh]n', 'ŋeš[penis]n'),
#  ('agrig[steward]n', 'lugal[king]n'),
#  ('inanak[1]dn', 'zabalam[1]sn'),
#  ('ig[door]n', 'guruš[cut]v/t'),
#  ('gag[nail]n', 'ninda[seed-funnel]n', 'apin[plow]n'),
#  ('a[arm]n', 'itud[moon]n'),
#  ('udun[kiln]n', 'muhaldim[cook]n'),
#  ('nurma[pomegranate]n', 'su[red]v/i'),
#  ('gu[neck]n', 'šub[fall]v/i'),
#  ('zu[tooth]n', 'kin[grind]v/t'),
#  ('inim[word]n', 'zid[right]v/i'),
#  ('šu[hand]n', 'u[ten]nu'),
#  ('ŋušur[beam]n', 'tal[broad]v/i'),
#  ('lu[person]n', 'e[house]n', 'buluŋ[grow]v/t'),
#  ('sipad[shepherd]n', 'anše[equid]n'),
#  ('te[~boat]n', 'ma[ship]n'),
#  ('im[clay]n', 'dug[pot]n'),
#  ('dilim[spoon]n', 'tur[be-small]v/i'),
#  ('munus[woman]n', 'šu[hand]n', 'ak[do]v/t'),
#  ('pa[branch]n', 'ŋešnimbar[palm]n'),
#  ('niŋ[thing]n', 'udbita[former]aj'),
#  ('ib[hips]n', 'kud[cut]v/t'),
#  ('hulu[bad]v/i', 'gig[sick]v/i'),
#  ('eg[levee]n', 'sumun[old]v/i'),
#  ('saŋki[forehead]n', 'kešed[bind]v/t'),
#  ('saŋ[head]n', 'zid[right]v/i'),
#  ('arad[slave]n', 'de[carry]'),
#  ('dumunita[son]n', 'gaba[chest]n'),
#  ('šu[hand]n', 'dugud[heavy]v/i'),
#  ('gag[nail]n', 'saŋ[head]n', 'apin[plow]n'),
#  ('ninda[bread]n', 'sur[half]n'),
#  ('dala[thorn]n', 'ŋešnimbar[palm]n'),
#  ('nunbaruna[1]dn', 'gibil[1]dn'),
#  ('ašag[field]n', 'anta[upper]v/t'),
#  ('ba[half]n', 'giŋ[unit-of-weight]n'),
#  ('tu[soup]n', 'šag[heart]n'),
#  ('ŋešnud[bed]n',
#   'šagzu[midwife]n',
#   'siki[hair]n',
#   'uzud[goat]n',
#   'ak[do]v/t'),
#  ('kan[gate]n',
#   'kešda[roofing]n',
#   'ig[door]n',
#   'saŋkul[bolt]n',
#   'gub[stand]v/i'),
#  ('gag[nail]n', 'suku[pole]n', 'margida[cart]n'),
#  ('ki[place]n', 'tur[be-small]v/i', 'e[house]n'),
#  ('ekur[1]tn', 'gi[thicket]n'),
#  ('u[and]cnj', 'gin[firm]v/i'),
#  ('illar[weapon]n', 'a[arm]n', 'gab[left]n'),
#  ('ki[place]n', 'us[follow]v/t'),
#  ('siki[hair]n', 'hubuš[crush]v/t', 'ak[do]v/t'),
#  ('sahar[soil]n', 'katab[lid]n'),
#  ('gud[ox]n', 'a[arm]n', 'ur[harness]n', 'dili[single]v/i'),
#  ('siki[hair]n', 'guzi[garment]n'),
#  ('saŋ[head]n', 'pana[bow]n'),
#  ('saŋ[head]n', 'še[barley]n', 'ba[allot]v/t'),
#  ('zu[tooth]n', 'ŋeštin[vine]n'),
#  ('gu[neck]n', 'aʾak[unmng]n'),
#  ('mada[land]n', 'mungen[1]gn'),
#  ('dub.du₃[~vehicle]n', 'mar[shovel]n'),
#  ('ŋešnimbar[palm]n', 'ki[place]n', 'saŋ[head]n'),
#  ('kag[mouth]n', 'igi[face]n'),
#  ('lu[person]n', 'sumur[angry]v/i'),
#  ('utul[tureen]n', 'gibil[new]v/i'),
#  ('ya[five]nu', 'giŋ[unit-of-weight]n'),
#  ('e[house]n', 'sadur[bottom]n'),
#  ('kuš[skin]n', 'udu[sheep]n', 'giggi[black]v/i'),
#  ('nisig[greenery]n', 'tabba[vegetable?]n'),
#  ('šu[hand]n', 'sal[thin]v/i'),
#  ('saŋ[head]n', 'ŋušur[harrow]n'),
#  ('bala[turn]v/i', 'kur[different]v/i'),
#  ('niŋir[herald]n', 'ušbar[weaver]n'),
#  ('uzu[flesh]n', 'inti[way]n'),
#  ('lu[person]n', 'zag[side]n', 'saga[press?]v/t'),
#  ('gag[nail]n', 'zigan[rudder]n'),
#  ('bisaŋ[basket]n', 'sar[write]v/t'),
#  ('a[water]n', 'gub[bathe]v/i'),
#  ('lu[person]n', 'nud[lie]v/i'),
#  ('buniŋ[trough]n', 'gal[big]v/i'),
#  ('šu[hand]n', 'gal[big]v/i'),
#  ('buniŋ[trough]n', 'tur[small]v/i'),
#  ('kalam[land]n', 'ŋaʾe[i]ip', 'til[live]v/i'),
#  ('ane[he]ip', 'du[go]v/i'),
#  ('masar[fish-storage]n', 'lu₂.ulu₃.ga₂[fish]n'),
#  ('banšur[table]n', 'urud[copper]n'),
#  ('tug[textile]n', 'aguhum[clothing]n'),
#  ('lu[person]n', 'nam[fate]n', 'tar[cut]v/t'),
#  ('zahum[basin]n', 'kugbabbar[silver]n'),
#  ('bisaŋ[basket]n', 'igidu[gift]n'),
#  ('šusi[object]n', 'e[leave]v/i'),
#  ('eme[tongue]n', 'mar[shovel]n'),
#  ('ŋeš[tree]n', 'gunu[speckled]v/i'),
#  ('ma[ship]n', 'mari[1]sn'),
#  ('gaʾar[cheese]n', 'lu[mix]v/t'),
#  ('saŋkul[bolt]n', 'la[hang]v/t'),
#  ('niŋ[thing]n', 'min[two]nu', 'giŋ[unit]n'),
#  ('tu[soup]n', 'šu[hand]n'),
#  ('kugsig[gold]n', 'luh[clean]v/t'),
#  ('hašhur[apple]n', 'šeŋuš[barley]n'),
#  ('illar[weapon]n', 'a[arm]n', 'zid[right]v/i'),
#  ('gada[flax]n', 'nu[spin]v/t'),
#  ('ŋešdal[crossbar]n', 'ŋešnimbar[palm]n'),
#  ('ugu[skull]n', 'zir[break]v/t'),
#  ('bur[bowl]n', 'sal[thin]v/i'),
#  ('lu[person]n', 'inim[word]n'),
#  ('dub[knee]n', 'gurum[bend]v/i'),
#  ('ukuš[cucumber]n', 'imsaŋ[tuft]n'),
#  ('niŋkud[~plowshare]n', 'apin[plow]n'),
#  ('ki[place]n', 'ŋeštin[vine]n', 'du[plant]v/t'),
#  ('kišib[seal]n', 'alliga[stone]n'),
#  ('guru[shield]n', 'šag[heart]n', 'tuku[acquire]v/t'),
#  ('uzu[flesh]n', 'kiri[nose]n'),
#  ('burud[perforate]v/t', 'ninda[bull]n'),
#  ('kaš[beer]n', 'su[red]v/i'),
#  ('bisaŋ[basket]n', 'kugan[metal]n'),
#  ('ušub[brick-mold]n', 'šeg[brick]n', 'ur[bake]v/t'),
#  ('saŋa[priest]n', 'gal[big]v/i'),
#  ('ma[ship]n', 'du[spread]v/t'),
#  ('a[water]n', 'zag[side]n', 'la[stretch]v/t'),
#  ('e[house]n', 'kiri[orchard]n', 'mah[great]v/i'),
#  ('šu[hand]n', 'kar[blow]v/i'),
#  ('ama[mother]n', 'tur[child]n'),
#  ('ubur[breast]n', 'ugunu[decoration]n', 'kugbabbar[silver]n'),
#  ('egir[back]n', 'dam[spouse]n'),
#  ('ilila[lever]n', 'eban[pair]n'),
#  ('ŋešnud[bed]n', 'umbin[nail]n', 'aški[rushes]n'),
#  ('lagar[priest]n', 'abudu[livestock]n'),
#  ('sila[lamb]n', 'kiŋgia[messenger]n'),
#  ('magaz[bench]n', 'burud[perforate]v/t'),
#  ('uhin[date]n', 'zagin[lapis]n'),
#  ('nir[stone]n', 'alalum[jewelry]n'),
#  ('sulum[contempt]n', 'mar[place]v/t'),
#  ('guza[chair]n', 'namen[priesthood]n'),
#  ('kul[handle]n', 'giŋ[ax]n'),
#  ('gug[carnelian]n', 'marhali[stone]n'),
#  ('a[arm]n', 'dirig[excess]n'),
#  ('tun[container]n', 'šu[hand]n'),
#  ('ab[window]n', 'gu[neck]n', 'la[hang]v/t'),
#  ('niŋ[thing]n', 'lugal[king]n'),
#  ('a[water]n', 'ud[sun]n', 'zal[pass]v/t'),
#  ('gigur[container]n', 'še[barley]n', 'tuku[acquire]v/t'),
#  ('e[house]n', 'melim[splendor]n', 'huš[reddish]v/i'),
#  ('maškim[administrator]n', 'lugal[king]n'),
#  ('anše[equid]n', 'eden[plain]n'),
#  ('mušen[bird]n', 'an[sky]n', 'šub[fall]v/i'),
#  ('saŋ[head]n', 'itud[moon]n'),
#  ('kurgi[goose]n', 'nita[male]n'),
#  ('i[oil]n', 'eren[cedar]n'),
#  ('emerah[jug]n', 'si[horn]n'),
#  ('u[ewe]n', 'ŋeš[penis]n', 'zu[know]v/t'),
#  ('niŋ[thing]n', 'sumun[old]v/i'),
#  ('kiŋ[pointed]v/i', 'ŋeštin[vine]n'),
#  ('par[canal]n', 'bal[dig]v/t'),
#  ('lu[person]n', 'igi[eye]n', 'bala[turn]v/i'),
#  ('lu[person]n', 'šu[hand]n', 'dug[speak]v/t'),
#  ('guza[chair]n', 'gar[knob]n', 'urud[copper]n', 'ŋar[place]v/t'),
#  ('ŋizzal[ear]n', 'ak[do]v/t'),
#  ('na[stone]n', 'aš[boil]n', 'gun[load]n'),
#  ('e[house]n', 'ebgal[oval]n'),
#  ('kuš[skin]n', 'amsi[elephant]n'),
#  ('mu[year]n', 'bala[turn]v/i'),
#  ('niŋin[total]n', 'ŋuruš[male]n'),
#  ('ŋešbara[1]dn', 'gibil[1]dn'),
#  ('lu[person]n', 'gabkar[thief]n'),
#  ('šugur[ring]n', 'zagin[lapis]n'),
#  ('šag[heart]n', 'hul[rejoice]v/i'),
#  ('gana[field]n', 'pana[bow]n'),
#  ('kid[mat]n', 'margida[cart]n'),
#  ('anše[equid]n', 'ama[mother]n'),
#  ('kuš[skin]n', 'nig[dog]n'),
#  ('uluh[sapling]n', 'kiri[orchard]n'),
#  ('gur[rim]n', 'ala[drum]n'),
#  ('a[arm]n', 'daluš[sling]n'),
#  ('kuš[skin]n', 'amsi[elephant]n', 'kur[mountain]n'),
#  ('uzu[flesh]n', 'gag[nail]n', 'sala[bug-ridden]aj'),
#  ('lu[person]n', 'mud[rabid]aj'),
#  ('lu[person]n', 'eg[levee]n', 'sig[put]v/t'),
#  ('lu[person]n', 'še[barley]n', 'sipar[implement]n'),
#  ('sab[jar]n', 'tur[small]v/i'),
#  ('saŋkul[bolt]n', 'šulal[defiled]aj'),
#  ('šatam[official]n', 'eʾuzu[meat-house]n'),
#  ('da[side-board]n', 'umbin[wheel]n', 'margida[cart]n'),
#  ('dadara[tied]v/i', 'dug[speak]v/t'),
#  ('kiri[nose]n', 'hab[malodorous]v/i'),
#  ('še[barley]n', 'ah[dry]v/i'),
#  ('ašag[field]n', 'egir[back]n', 'šum[garlic]n', 'la[hang]v/t'),
#  ('ninda[bread]n', 'gur[thick]v/i', 'zid[flour]n', 'gunida[~grain]n'),
#  ('gi[thicket]n', 'šuš[cover]v/t'),
#  ('niŋ[thing]n', 'bur[grass]n'),
#  ('e[house]n', 'ensi[interpreter]n'),
#  ('sahar[soil]n', 'peš[thick]v/i'),
#  ('akuz[1]sn', 'subir[1]gn'),
#  ('peš[fig]n', 'duru[wet]v/i'),
#  ('ŋešnimbar[palm]n', 'maštab[twin]n'),
#  ('inim[word]n', 'diŋir[deity]n'),
#  ('ur[dog]n', 'gu[neck]n', 'tuku[acquire]v/t'),
#  ('eze[sheep]n', 'aŋguʾa[fattened]v', 'udu[sheep]n', 'niga[fattened]v/i'),
#  ('sahar[soil]n', 'pusaŋ[pit]n'),
#  ('gakkul[mash-tub]n', 'abba[father]n'),
#  ('udu[sheep]n', 'zuh[steal]v/t'),
#  ('ig[door]n', 'leʾum[board]n'),
#  ('šu[hand]n', 'du[hold]v/t'),
#  ('sumun[cow]n', 'kur[mountain]n'),
#  ('šu[hand]n', 'la[hang]v/t'),
#  ('nar[musician]n', 'igi[eye]n', 'suhurla[hairstyle]n'),
#  ('zabar[bronze]n', 'lilis[instrument]n'),
#  ('uhin[date]n', 'gunu[speckled]v/i'),
#  ('saŋ[head]n', 'ziŋal[living-things]n'),
#  ('gurgur[vessel]n', 'i[oil]n', 'šah[pig]n'),
#  ('suhur[tuft]n', 'gal[big]v/i'),
#  ('ninda[bread]n', 'gazi[condiment]n'),
#  ('šed[defecate]v/t', 'ŋeštug[ear]n'),
#  ('bulug[needle]n', 'harran[tool]n'),
#  ('zukešed[knot]n', 'gumur[spine]n'),
#  ('kur[mountain]n', 'hašur[1]gn'),
#  ('gur[rim]n', 'apin[plow]n'),
#  ('dubsar[scribe]n', 'ašag[field]n'),
#  ('ki[place]n', 'niŋla[clothing]n'),
#  ('bahar[potter]n', 'gal[big]v/i'),
#  ('ugu[skull]n', 'gig[sick]v/i'),
#  ('he₂.bad[trimmings]n', 'ŋešnimbar[palm]n'),
#  ('bir[locust]n', 'tur[be-small]v/i'),
#  ('ninda[bread]n', 'ŋeštin[vine]n'),
#  ('šu[hand]n', 'luh[clean]v/t'),
#  ('zulum[date]n', 'sag[rare]v/i'),
#  ('ŋešnimbar[palm]n', 'lu₂.im[criminal]n'),
#  ('eg[levee]n', 'šibir[staff]n'),
#  ('dimsa[unmng]n', 'e[leave]v/i'),
#  ('dala[thorn]n', 'te[pierce]v/t'),
#  ('bappir[~beer]n', 'sag[rare]v/i'),
#  ('menden[we]ip', 'menzen[you]ip'),
#  ('absin[furrow]n', 'kud[cut]v/t'),
#  ('sum[beard]n', 'zagin[lapis]n'),
#  ('niŋtahab[vessel]n', 'tur[small]v/i'),
#  ('a[water]n', 'gi[turn-return]v/i'),
#  ('eg[levee]n', 'bala[turn]v/i'),
#  ('saŋdur[seat]n', 'gigir[chariot]n'),
#  ('kaš[beer]n', 'kurun[beer]n', 'imin[seven]nu'),
#  ('ŋešnimbar[palm]n', 'šunim[spring]n'),
#  ('gud[ox]n', 'ibla[belt]n'),
#  ('saŋ[head]n', 'u[grass]n', 'šub[fall]v/t'),
#  ('niŋhulu[evil]n', 'gig[sick]v/i'),
#  ('siki[hair]n', 'šagsig[weft]n', 'nu[spin]v/t'),
#  ('barag[sanctum]n', 'sig[put]v/t'),
#  ('niŋziŋal[living-creature]n', 'eden[back]n'),
#  ('e[house]n', 'durankik[1]tn'),
#  ('har[ring]n', 'gu[neck]n', 'gilim[cross]v/t', 'zabar[bronze]n'),
#  ('lu[person]n', 'ennuŋ[imprisonment]n', 'e[house]n'),
#  ('siki[hair]n', 'guzi[garment]n', 'tur[be-small]v/i'),
#  ('dub[knee]n', 'sa[sinew]n', 'dar[split]v/t'),
#  ('ma[ship]n', 'idnirŋal[1]on'),
#  ('šag[heart]n', 'min[two]nu', 'di[speak]v/t', 'ak[do]v/t'),
#  ('er[tears]n', 'igi[eye]n', 'gig[sick]v/i'),
#  ('zamin[lyre]n', 'dug[good]v/i'),
#  ('pa[branch]n', 'mul[star]n'),
#  ('niŋgida[rod?]n', 'margida[cart]n'),
#  ('udu[sheep]n', 'sa[pay-for]v/t'),
#  ('lu[person]n', 'namra[booty]n'),
#  ('a[arm]n', 'ub[corner]n', 'sug[empty]v/i'),
#  ('gala[singer]n', 'dumu[child]n'),
#  ('e[house]n', 'libir[old]v/i'),
#  ('urud[copper]n', 'išme[stone]n'),
#  ('kid[mat]n', 'dida[wort]n', 'hi[mix]v/t'),
#  ('šu[hand]n', 'zuhul[pierce]v/t'),
#  ('malah[sailor]n', 'gal[big]v/i'),
#  ('zi[life]n', 'kar[flee]v/i'),
#  ('e[house]n', 'šušuma[consignment]n'),
#  ('šennur[plum]n', 'gal[big]v/i'),
#  ('e[house]n', 'sig[weak]v/i'),
#  ('im[clay]n', 'šag[heart]n', 'kalag[strong]v/i'),
#  ('šakanka[market]n', 'sag[good]v/i'),
#  ('tun[container]n', 'ŋiri[dagger]n'),
#  ('niŋ[thing]n', 'mu[grow]v/t'),
#  ('munus[woman]n', 'šuʾi[barber]n'),
#  ('saŋa[priest]n', 'nir[lordly]aj'),
#  ...]

# %%
tokenizer = MWETokenizer(lex_vocab_l)

# %%
etcsl["lemma2"] = etcsl.apply(lambda x: (tokenizer.tokenize(x["lemma"])), axis=1)
etcsl[["lemma","lemma2"]]
# Out:
#                                                    lemma  \
# 0                                      [dubsaŋ[first]aj]
# 1      [enki[1]dn, unu[dwelling]n, gal[big]v/i, ed[as...
# 2                                      [anzag[horizon]n]
# 3      [anŋi[eclipse]n, zu[know]v/t, ama[mother]n, tu...
# 4                          [gi[thicket]n, tuku[rock]v/t]
# 5      [an[na]na, kaš₄[na]na, an[na]na, kaš₄[na]na, m...
# 6      [mašmaš[sorcerer]n, erim[enemy]n, kur[differen...
# 7      [ŋiriŋena[path]n, enki[1]dn, ki[place]n, unu[d...
# 8              [šag[heart]n, pu₂[na]na, 1-kam-ma[1st]nu]
# 9                                      [dubsaŋ[first]aj]
# 10     [x[na]na, x[na]na, kaskal[way]n, 7[7]nu, me[be...
# 11                                          [lilia[1]dn]
# 12           [igi[eye]n, x[na]na, 7[7]nu, kur[enter]v/i]
# 13                 [šul[youth]v/i, a[arm]n, la[hang]v/t]
# 14     [gu[cord]n, di[na]na, sig[put]v/t, ša[na]na, g...
# 15                         [ŋiriŋena[path]n, lilia[1]dn]
# 16             [šag[heart]n, pu₂[na]na, 1-kam-ma[1st]nu]
# 17     [ŋiri[foot]n, iš[na]na, lu[person]n, inim[word...
# 18          [ŋiriŋena[path]n, lu[person]n, pad[find]v/t]
# 19                                     [ŋiriŋena[path]n]
# 20           [iribala[city]n, aš[curse]n, dug[speak]v/t]
# 21      [diŋir[deity]n, šembizida[kohl]n, dar[split]v/t]
# 22        [enlil[1]dn, dug[speak]v/t, kur[different]v/i]
# 23     [lugal[king]n, an[sky]n, kug[pure]v/i, mete[ap...
# 24             [lugal[king]n, enlil[1]dn, gub[stand]v/i]
# 25               [en[lord]n, gud[ox]n, banda[junior]v/i]
# 26           [šerzid[radiance]n, en[lord]n, gal[big]v/i]
# 27     [munus[woman]n, zid[right]v/i, mi[cvne]n, dug[...
# 28                         [en[lord]n, sulim[radiance]n]
# 29     [ursaŋ[hero]n, en[lord]n, huš[reddish]v/i, gal...
# ...                                                  ...
# 36466  [lala[plenty]n, niŋ[thing]n, e[house]n, du[bui...
# 36467  [namtur[smallness]n, x[na]na, dam[spouse]n, tu...
# 36468     [inim[word]n, niŋsisa[justice]n, de[bring]v/t]
# 36469  [idlurugu[1]dn, šag[heart]n, u[admiration]n, d...
# 36470             [lulu[man]n, diŋir[deity]n, me[be]v/i]
# 36471  [nu[not]v/i, gal[big]v/i, nu[not]v/i, tur[smal...
# 36472  [lu[person]n, igištu[foremost]aj, izi[fire]n, ...
# 36473  [lu[person]n, egir[back]n, dug[speak]v/t, mea[...
# 36474     [amaš[sheepfold]n, šeŋbar[animal]n, en[lord]n]
# 36475  [ildum[band]n, 50[50]nu, u[grass]n, lu[abundan...
# 36476      [ŋešgu[stock]n, ku[ku]v, tar[na]na, hu[na]na]
# 36477  [engar[farmer]n, gud[ox]n, addir[hire]n, sag[b...
# 36478  [niŋgur[property]n, niŋgur[property]n, lugal[k...
# 36479  [kur[enter]v/i, sisa[straighten]v/t, e[leave]v...
# 36480  [lu[person]n, aŋala[sack]n, kešed[bind]v/t, gu...
# 36481                       [šag[heart]n, dab[seize]v/t]
# 36482  [mu[name]n, še[call]v/t, ur[dog]n, inim[word]n...
# 36483  [nin[lady]n, amar[young]n, an[sky]n, pad[find]...
# 36484  [luma[1]dn, lu[person]n, niŋ[thing]n, sag[good...
# 36485           [banšur[table]n, enlil[1]dn, ŋal[be]v/i]
# 36486         [aba[who?]qp, zi[life]n, tuku[acquire]v/t]
# 36487  [iri[city]n, adlu[disabled-person]n, baza[dwar...
# 36488  [na[stone]n, kalag[strong]v/i, kizurra[edge]n,...
# 36489  [aya[father]n, hili[attractiveness]n, aya[fath...
# 36490  [ku.ga₂.nun.tir.ra[bird]n, gu[voice]n, de[pour...
# 36491  [tur.uz.za[duck?]n, gu[voice]n, de[pour]v/t, a...
# 36492         [šum[give]v/t, lu[person]n, us[follow]v/t]
# 36493  [lugal[king]n, dubsar[scribe]n, lugal[king]n, ...
# 36494  [lu[person]n, si[horn]n, sa[equal]v/t, kinkinš...
# 36495  [haš[thigh]n, gid[long]v/i, lu[person]n, ŋeši[...
#
#                                                   lemma2
# 0                                      [dubsaŋ[first]aj]
# 1      [enki[1]dn, unu[dwelling]n, gal[big]v/i, ed[as...
# 2                                      [anzag[horizon]n]
# 3      [anŋi[eclipse]n, zu[know]v/t, ama[mother]n, tu...
# 4                          [gi[thicket]n, tuku[rock]v/t]
# 5      [an[na]na, kaš₄[na]na, an[na]na, kaš₄[na]na, m...
# 6      [mašmaš[sorcerer]n, erim[enemy]n, kur[differen...
# 7      [ŋiriŋena[path]n, enki[1]dn, ki[place]n, unu[d...
# 8              [šag[heart]n, pu₂[na]na, 1-kam-ma[1st]nu]
# 9                                      [dubsaŋ[first]aj]
# 10     [x[na]na, x[na]na, kaskal[way]n, 7[7]nu, me[be...
# 11                                          [lilia[1]dn]
# 12           [igi[eye]n, x[na]na, 7[7]nu, kur[enter]v/i]
# 13                  [šul[youth]v/i, a[arm]n_la[hang]v/t]
# 14     [gu[cord]n, di[na]na, sig[put]v/t, ša[na]na, g...
# 15                         [ŋiriŋena[path]n, lilia[1]dn]
# 16             [šag[heart]n, pu₂[na]na, 1-kam-ma[1st]nu]
# 17     [ŋiri[foot]n, iš[na]na, lu[person]n_inim[word]...
# 18          [ŋiriŋena[path]n, lu[person]n, pad[find]v/t]
# 19                                     [ŋiriŋena[path]n]
# 20           [iribala[city]n, aš[curse]n, dug[speak]v/t]
# 21      [diŋir[deity]n, šembizida[kohl]n, dar[split]v/t]
# 22         [enlil[1]dn, dug[speak]v/t_kur[different]v/i]
# 23     [lugal[king]n, an[sky]n, kug[pure]v/i, mete[ap...
# 24             [lugal[king]n, enlil[1]dn, gub[stand]v/i]
# 25               [en[lord]n, gud[ox]n, banda[junior]v/i]
# 26           [šerzid[radiance]n, en[lord]n, gal[big]v/i]
# 27     [munus[woman]n_zid[right]v/i, mi[cvne]n_dug[sp...
# 28                         [en[lord]n, sulim[radiance]n]
# 29     [ursaŋ[hero]n, en[lord]n, huš[reddish]v/i, gal...
# ...                                                  ...
# 36466  [lala[plenty]n, niŋ[thing]n, e[house]n_du[buil...
# 36467  [namtur[smallness]n, x[na]na, dam[spouse]n, tu...
# 36468     [inim[word]n, niŋsisa[justice]n, de[bring]v/t]
# 36469  [idlurugu[1]dn, šag[heart]n, u[admiration]n_du...
# 36470             [lulu[man]n, diŋir[deity]n, me[be]v/i]
# 36471  [nu[not]v/i, gal[big]v/i, nu[not]v/i, tur[smal...
# 36472  [lu[person]n_igištu[foremost]aj, izi[fire]n, g...
# 36473  [lu[person]n, egir[back]n, dug[speak]v/t, mea[...
# 36474     [amaš[sheepfold]n, šeŋbar[animal]n, en[lord]n]
# 36475  [ildum[band]n, 50[50]nu, u[grass]n, lu[abundan...
# 36476      [ŋešgu[stock]n, ku[ku]v, tar[na]na, hu[na]na]
# 36477  [engar[farmer]n, gud[ox]n, addir[hire]n, sag[b...
# 36478  [niŋgur[property]n, niŋgur[property]n_lugal[ki...
# 36479  [kur[enter]v/i, sisa[straighten]v/t, e[leave]v...
# 36480  [lu[person]n, aŋala[sack]n, kešed[bind]v/t, gu...
# 36481                       [šag[heart]n, dab[seize]v/t]
# 36482  [mu[name]n_še[call]v/t, ur[dog]n, inim[word]n,...
# 36483  [nin[lady]n, amar[young]n, an[sky]n, pad[find]...
# 36484  [luma[1]dn, lu[person]n, niŋ[thing]n, sag[good...
# 36485           [banšur[table]n, enlil[1]dn, ŋal[be]v/i]
# 36486         [aba[who?]qp, zi[life]n, tuku[acquire]v/t]
# 36487  [iri[city]n, adlu[disabled-person]n, baza[dwar...
# 36488  [na[stone]n, kalag[strong]v/i, kizurra[edge]n,...
# 36489  [aya[father]n, hili[attractiveness]n, aya[fath...
# 36490  [ku.ga₂.nun.tir.ra[bird]n, gu[voice]n_de[pour]...
# 36491  [tur.uz.za[duck?]n, gu[voice]n_de[pour]v/t, am...
# 36492         [šum[give]v/t, lu[person]n, us[follow]v/t]
# 36493  [lugal[king]n, dubsar[scribe]n_lugal[king]n, d...
# 36494  [lu[person]n_si[horn]n_sa[equal]v/t, kinkinšu[...
# 36495  [haš[thigh]n, gid[long]v/i, lu[person]n, ŋeši[...
#
# [36496 rows x 2 columns]

# %%
etcsl_l = tokenizer.tokenize_sents(etcsl["lemma"])
#probably better to use an apply function to tokenize within the DF.

# %%
mwe = []
for line in etcsl_l:
    for lemma in line:
        if "_" in lemma:
            mwe.append(line)
            continue
mwe, len(mwe)
# Out:
# ([['šul[youth]v/i', 'a[arm]n_la[hang]v/t'],
#   ['ŋiri[foot]n',
#    'iš[na]na',
#    'lu[person]n_inim[word]n',
#    'zid[right]v/i',
#    'ga[na]na',
#    'ka×x[na]na',
#    'ba[na]na'],
#   ['enlil[1]dn', 'dug[speak]v/t_kur[different]v/i'],
#   ['munus[woman]n_zid[right]v/i', 'mi[cvne]n_dug[speak]v/t'],
#   ['munus[woman]n_zid[right]v/i', 'mi[cvne]n_dug[speak]v/t'],
#   ['lugal[king]n', 'inim[word]n_sag[good]v/i'],
#   ['ursaŋ[hero]n', 'ni[fear]n_gal[big]v/i', 'gur[lift]v/t'],
#   ['lugal[king]n', 'ŋeštug[ear]n_daŋal[wide]v/i'],
#   ['gud[ox]n_si[horn]n', 'ŋar[place]v/t'],
#   ['ud[sun]n_zal[pass]v/t'],
#   ['ursaŋ[hero]n',
#    'piriŋ[lion]n_huš[reddish]v/i',
#    'uru[flood]n',
#    'me[being]n',
#    'gal[big]v/i'],
#   ['sahar[soil]n', 'kag[mouth]n_du[build]v/t'],
#   ['lugal[king]n', 'mi[cvne]n_dug[speak]v/t'],
#   ['en[lord]n', 'kur[mountain]n', 'lu[person]n_til[live]v/i'],
#   ['kud[fish]n', 'e[house]n_du[build]v/t'],
#   ['saŋki[forehead]n_gid[long]v/i'],
#   ['gi[thicket]n', 'ana[what?]qp', 'gu[voice]n_de[pour]v/t'],
#   ['an[sky]n', 'gal[big]v/i', 'ki[place]n_gal[big]v/i'],
#   ['ana[what?]qp', 'a[arm]n_aŋ[measure]v/t'],
#   ['x[na]na', 'x[na]na', 'lu[person]n_lil[ghost]n'],
#   ['a[water]n_dug[good]v/i', 'ur[dog]n'],
#   ['en[lord]n', 'kur[mountain]n', 'lu[person]n_til[live]v/i'],
#   ['saŋki[forehead]n_gid[long]v/i'],
#   ['an[sky]n', 'gal[big]v/i', 'ki[place]n_gal[big]v/i'],
#   ['nam[lord]n', 'nun[prince]n', 'saŋ[head]n_il[raise]v/t'],
#   ['kud[fish]n', 'e[house]n_du[build]v/t'],
#   ['gi[thicket]n',
#    '(x)[na]na',
#    'ana[what?]qp',
#    '(x)[na]na',
#    'gu[voice]n_de[pour]v/t'],
#   ['ki[place]n_dug[good]v/i',
#    'ama[mother]n',
#    'heŋal[plenty]n',
#    'utud[bear]v/t'],
#   ['en[lord]n', 'kur[mountain]n', 'lu[person]n_til[live]v/i'],
#   ['ud[storm]n', 'ešbar[decision]n_kiŋ[seek]v/t'],
#   ['lugal[king]n', 'mi[cvne]n_dug[speak]v/t'],
#   ['en[lord]n', 'kur[mountain]n', 'lu[person]n_til[live]v/i'],
#   ['saŋki[forehead]n_gid[long]v/i'],
#   ['nam[lord]n', 'nun[prince]n', 'saŋ[head]n_il[raise]v/t', 'x[na]na'],
#   ['an[sky]n', 'gal[big]v/i', 'ki[place]n_gal[big]v/i'],
#   ['kud[fish]n', 'e[house]n_du[build]v/t'],
#   ['gibil[1]dn_gibil[1]dn'],
#   ['munus[woman]n_zid[right]v/i',
#    'me[being]n',
#    'inim[word]n_dug[speak]v/t',
#    'x[na]na'],
#   ['munus[woman]n_zid[right]v/i',
#    'me[being]n',
#    'inim[word]n_dug[speak]v/t',
#    'x[na]na'],
#   ['en[lord]n', 'me[being]n', 'sag[scatter]v/t_dug[speak]v/t'],
#   ['ušim[greenery]n_saŋ[head]n', 'il[raise]v/t'],
#   ['nin[lady]n', 'hili[attractiveness]n', 'šu[hand]n_du[push]v/t'],
#   ['x[na]na', 'ŋidru[scepter]n', 'šu[hand]n_du[push]v/t'],
#   ['dumu[child]n_lugal[king]n', 'x[na]na'],
#   ['x[na]na', 'ud[sun]n_zal[pass]v/t'],
#   ['innin[lady]n', 'an[1]dn_gal[big]v/i'],
#   ['lugal[king]n', 'mi[cvne]n_dug[speak]v/t'],
#   ['ud[sun]n', 'ul[distant]v/i', 'ud[sun]n_zal[pass]v/t'],
#   ['lugal[king]n', 'mi[cvne]n_dug[speak]v/t'],
#   ['e[house]n_sikil[pure]v/i', 'ki[place]n_sikil[pure]v/i'],
#   ['e[house]n_sikil[pure]v/i', 'ki[place]n_sikil[pure]v/i'],
#   ['kur[mountain]n',
#    'gal[big]v/i',
#    'kur[mountain]n',
#    'a[arm]n_aŋ[measure]v/t',
#    'gal[big]v/i'],
#   ['ab[cow]n', 'nun[prince]n', 'an[sky]n', 'kur[mountain]n_un[high]v/i'],
#   ['ki[place]n_sikil[pure]v/i', 'ki[place]n', 'dadag[bright]v/i'],
#   ['ki[place]n_sikil[pure]v/i', 'ki[place]n', 'dadag[bright]v/i'],
#   ['urgula[lion]n', 'saŋ[head]n_ŋeš[tree]n_rah[beat]v/t'],
#   ['kisikil[woman]n', 'a[water]n_tu[cvve]v/t', 'iri[city]n', 'sig[put]v/t'],
#   ['ninsikila[1]dn', 'aya[father]n', 'enki[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['iri[city]n',
#    'ašag[field]n_agar[meadow]n',
#    'absin[furrow]n',
#    'tuku[acquire]v/t'],
#   ['kag[mouth]n',
#    'a[water]n',
#    'ki[place]n',
#    'du[du]v',
#    'a[water]n_dug[good]v/i',
#    'ki[place]n',
#    'x[na]na',
#    'du[na]na'],
#   ['pu[well]n',
#    'a[water]n_ses[bitter]v/i',
#    'pu[well]n',
#    'a[water]n_dug[good]v/i',
#    'me[be]v/i'],
#   ['pu[well]n',
#    'a[water]n_ses[bitter]v/i',
#    'pu[well]n',
#    'a[water]n_dug[good]v/i',
#    'me[be]v/i'],
#   ['mes[tree]n_magan[1]gn', 'ŋešaʾabak[tree]n', 'sag[rare]v/i'],
#   ['ma[ship]n_gal[big]v/i', 'sa[equal]v/t'],
#   ['kur[mountain]n',
#    'elam[1]gn',
#    'siki[hair]n_igi[eye]n_saŋ[choose]v/t',
#    'gun[load]n',
#    'bala[turn]v/t'],
#   ['ŋeši[sesame]n',
#    'tug[textile]n_mah[great]v/i',
#    'tug[textile]n',
#    'sag[rare]v/i',
#    'ma[ship]n_gal[big]v/i',
#    'sa[equal]v/t'],
#   ['ŋeši[sesame]n',
#    'tug[textile]n_mah[great]v/i',
#    'tug[textile]n',
#    'sag[rare]v/i',
#    'ma[ship]n_gal[big]v/i',
#    'sa[equal]v/t'],
#   ['še[barley]n_še[barley]n', 'didila[smaller]v/i'],
#   ['kag[mouth]n',
#    'a[water]n',
#    'ki[place]n',
#    'du[du]v',
#    'a[water]n_dug[good]v/i',
#    'ki[place]n',
#    'du[du]v'],
#   ['pu[well]n',
#    'a[water]n_ses[bitter]v/i',
#    'pu[well]n',
#    'a[water]n_dug[good]v/i',
#    'me[be]v/i'],
#   ['pu[well]n',
#    'a[water]n_ses[bitter]v/i',
#    'pu[well]n',
#    'a[water]n_dug[good]v/i',
#    'me[be]v/i'],
#   ['ašag[field]n_agar[meadow]n',
#    'absin[furrow]n',
#    'še[barley]n',
#    'šum[give]v/t'],
#   ['ineš[now]ma', 'utu[1]dn', 'ud[sun]n', 'nen[this]dp', 'ur[he]ip_me[be]v/i'],
#   ['gu[voice]n_de[pour]v/t', 'ambar[reed-bed]n', 'lu[person]n_dab[seize]v/t'],
#   ['gu[voice]n_de[pour]v/t', 'ambar[reed-bed]n', 'lu[person]n_dab[seize]v/t'],
#   ['enki[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['a[water]n',
#    'šag[heart]n_šu[hand]n',
#    'teŋ[approach]v/i',
#    'a[water]n',
#    'enki[1]dn'],
#   ['ninnisig[1]dn', 'gu[neck]n_id[river]n', 'e[leave]v/i'],
#   ['sukkal[secretary]n', 'isimud[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['a[water]n',
#    'šag[heart]n_šu[hand]n',
#    'teŋ[approach]v/i',
#    'a[water]n',
#    'enki[1]dn'],
#   ['ninkurak[1]dn', 'gu[neck]n_id[river]n', 'e[leave]v/i'],
#   ['sukkal[secretary]n', 'isimud[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['a[water]n',
#    'šag[heart]n_šu[hand]n',
#    'teŋ[approach]v/i',
#    'a[water]n',
#    'enki[1]dn'],
#   ['lutur[child]n', 'buluŋ[grow]v/t', 'ul[swell]v/i_teŋ[approach]v/i'],
#   ['ninimma[1]dn', 'gu[neck]n_id[river]n', 'x[na]na'],
#   ['ninimma[1]dn', 'gu[neck]n_id[river]n', 'igi[eye]n', 'x[na]na'],
#   ['sukkal[secretary]n', 'isimud[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['a[water]n',
#    'šag[heart]n_šu[hand]n',
#    'teŋ[approach]v/i',
#    'a[water]n',
#    'enki[1]dn'],
#   ['nintur[1]dn', 'uttu[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['inim[word]n_dug[speak]v/t', 'inim[word]n', 'ŋeštug[ear]n'],
#   ['ŋeštin[vine]n_garan[bunch]n', 'de[bring]v/t'],
#   ['gu[neck]n', 'gu[neck]n_la[hang]v/t'],
#   ['ŋeštin[vine]n_garan[bunch]n', 'de[bring]v/t', 'ur[root]n', 'si[fill]v/t'],
#   ['e[house]n_dub[tremble]v/t', 'ŋal[open]v/t', 'ŋal[open]v/t'],
#   ['uttu[1]dn',
#    'šag[heart]n_hul[rejoice]v/i',
#    'e[house]n',
#    'ŋal[open]v/t',
#    'taka[abandon]v/t'],
#   ['ŋeštin[vine]n_garan[bunch]n', 'šum[give]v/t'],
#   ['uttu[1]dn',
#    'munus[woman]n',
#    'buluŋ[grow]v/t',
#    'gab[left]n',
#    'sig[put]v/t',
#    'šu[hand]n_sag[beat]v/t'],
#   ['enki[1]dn', 'uttu[1]dn', 'ul[swell]v/i_teŋ[approach]v/i'],
#   ['haš[thigh]n', 'tag[touch]v/t', 'šu[hand]n_tag[touch]v/t'],
#   ['a[water]n',
#    'šag[heart]n_šu[hand]n',
#    'teŋ[approach]v/i',
#    'a[water]n',
#    'enki[1]dn'],
#   ['uttu[1]dn',
#    'munus[woman]n_sag[good]v/i',
#    'aya[cry]n',
#    'haš[thigh]n',
#    'dug[speak]v/t',
#    'aya[cry]n',
#    'bar[outside]v/t',
#    'aya[cry]n',
#    'šab[heart]n',
#    'dug[speak]v/t'],
#   ['sukkal[secretary]n', 'isimud[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['ninhursaŋak[1]dn', 'e[house]n', 'kaš[runner]n_dug[speak]v/t'],
#   ['ugudili[scalp]n_gig[sick]v/i'],
#   ['pa[branch]n_siki[hair]n', 'gig[sick]v/i'],
#   ['šeš[brother]n',
#    'ana[what?]qp',
#    'gig[sick]v/i',
#    'kiri[nose]n_gig[sick]v/i'],
#   ['ninkasik[1]dn', 'niŋ[thing]n', 'šag[heart]n_si[fill]v/t', 'me[be]v/i'],
#   ['diŋir[deity]n',
#    'im[clay]n',
#    'ara[grind]v/t',
#    'zi[life]n',
#    'inim[word]n_ŋar[place]v/t'],
#   ['ud[sun]n',
#    'ŋeštug[ear]n_daŋal[wide]v/i',
#    'mud[create]v/t',
#    'diŋir[deity]n',
#    'šar[3600]nu',
#    'ŋal[be]v/i'],
#   ['enki[1]dn',
#    'engur[waters]n',
#    'burud[perforate]v/t',
#    'asura[water]n',
#    'ki[place]n',
#    'diŋir[deity]n',
#    'name[any]aj',
#    'šag[heart]n',
#    'u[admiration]n_dug[speak]v/t'],
#   ['kinud[bedroom]n', 'nud[lie]v/i', 'u[sleep]n_ku[place]v/t', 'zig[rise]v/t'],
#   ['x[na]na', 'nud[lie]v/i', 'u[sleep]n_ku[place]v/t'],
#   ['halankug[1]tn',
#    'niŋin[encircle]v/t',
#    'šag[heart]n_kušu[tired]v/i',
#    'haš[thigh]n',
#    'rah[beat]v/t'],
#   ['ŋeštug[ear]n',
#    'ŋizzal[ear]n',
#    'en[cvne]n_tar[cut]v/t',
#    'x[na]na',
#    'namkugzu[wisdom]n',
#    'mud[create]v/t',
#    'medim[limbs]n',
#    'niŋnam[anything]n',
#    'sig₇.en[goddess?]n',
#    'sig₇.hi[goddess?]n',
#    'e[leave]v/i'],
#   ['enki[1]dn',
#    'mud[create]v/t',
#    'medim[limbs]n',
#    'ni[self]rp',
#    'šag[heart]n_ŋeštug[ear]n',
#    'deg[collect]v/t'],
#   ['ama[mother]n', 'namma[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['sig₇.en[goddess?]n',
#    'sig₇.hi[goddess?]n',
#    'im[clay]n_kid[break]v/t',
#    'zaʾe[you]ip',
#    'medim[limbs]n',
#    'ŋal[be]v/i'],
#   ['enki[1]dn',
#    'kiŋ[work]n',
#    'niŋin[encircle]v/t',
#    'x[na]na',
#    'la[hang]v/t',
#    'šag[heart]n_hul[rejoice]v/i'],
#   ['gu[entirety]n',
#    'sig₇.en[goddess?]n',
#    'sig₇.hi[goddess?]n',
#    'nun[prince]n',
#    'namtar[fate]n',
#    'gi[reed]n',
#    'saŋ[head]n',
#    'ninda[bread]n_gu[eat]v/t'],
#   ['an[1]dn',
#    'enlil[1]dn',
#    'en[lord]n',
#    'nudimmud[1]dn',
#    'maš[goat]n_kug[pure]v/i',
#    'šeŋ[cook]v/t'],
#   ['en[lord]n',
#    'ŋeštug[ear]n_daŋal[wide]v/i',
#    'aba[who?]qp',
#    'ŋeštug[ear]n',
#    'deg[collect]v/t'],
#   ['aya[father]n',
#    'utud[bear]v/t',
#    'me[being]n',
#    'nam[fate]n',
#    'tar[cut]v/t',
#    'me[being]n',
#    'zaʾe[you]ip_me[be]v/i'],
#   ['enki[1]dn',
#    'ninmah[1]dn',
#    'kaš[beer]n',
#    'naŋ[drink]v/t',
#    'šag[heart]n',
#    'ul[swell]v/i_teŋ[approach]v/i'],
#   ['ninmah[1]dn', 'enki[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['ninmah[1]dn',
#    'im[clay]n',
#    'ugu[skull]n',
#    'abzu[water]n',
#    'šu[hand]n_teŋ[approach]v/i'],
#   ['lu[person]n',
#    'gi[1st]nu',
#    'šu[hand]n_šuš[cover]v/t',
#    'sa[equal]v/t',
#    'gurum[bend]v/t',
#    'lu[person]n',
#    'dim[create]v/t'],
#   ['enki[1]dn',
#    'lu[person]n',
#    'gi[1st]nu',
#    'šu[hand]n_šuš[cover]v/t',
#    'sa[equal]v/t',
#    'gurum[bend]v/t',
#    'igi[eye]n',
#    'du[spread]v/t'],
#   ['pešgi[4th]nu', 'lu[person]n', 'a[water]n_sur[press]v/t', 'dim[create]v/t'],
#   ['enki[1]dn',
#    'lu[person]n',
#    'a[water]n_sur[press]v/t',
#    'igi[eye]n',
#    'du[spread]v/t'],
#   ['nibru[1]sn', 'tiru[courtier]n', 'mu[name]n_še[call]v/t'],
#   ['ninmah[1]dn',
#    'im[clay]n',
#    'niŋin[encircle]v/t',
#    'šu[hand]n',
#    'ki[place]n_šub[fall]v/t',
#    'lul[false]v/i',
#    'lib[daze]n',
#    'ŋar[place]v/t',
#    'enki[1]dn',
#    'im[clay]n',
#    'šuniŋin[total]n',
#    'ki[place]n_šub[fall]v/t',
#    'lul[false]v/i',
#    'gi[turn]v/i'],
#   ['ninmah[1]dn',
#    'im[clay]n',
#    'niŋin[encircle]v/t',
#    'šu[hand]n',
#    'ki[place]n_šub[fall]v/t',
#    'lul[false]v/i',
#    'lib[daze]n',
#    'ŋar[place]v/t',
#    'enki[1]dn',
#    'im[clay]n',
#    'šuniŋin[total]n',
#    'ki[place]n_šub[fall]v/t',
#    'lul[false]v/i',
#    'gi[turn]v/i'],
#   ['en[lord]n',
#    'gal[big]v/i',
#    'enki[1]dn',
#    'ninmah[1]dn',
#    'gu[voice]n_de[pour]v/t'],
#   ['ninmah[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['gi[turn]v/i',
#    'umul[creature]n',
#    'azad[head]n',
#    'gig[sick]v/i',
#    'ki[place]n',
#    'x[x]n',
#    'gig[sick]v/i',
#    'igi[eye]n_gig[sick]v/i',
#    'gu[neck]n',
#    'gig[sick]v/i'],
#   ['enki[1]dn', 'ninmah[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['umul[creature]n',
#    'teŋ[approach]v/i',
#    'en[cvne]n_tar[cut]v/t',
#    'dug[speak]v/t',
#    'zu[know]v/t'],
#   ['ninda[bread]n_gu[eat]v/t', 'de[bring]v/t', 'šu[hand]n_gid[long]v/i'],
#   ['ninda[bread]n_gu[eat]v/t', 'de[bring]v/t', 'šu[hand]n_gid[long]v/i'],
#   ['gub[stand]v/i',
#    'tuš[sit]v/i',
#    'nud[lie]v/i',
#    'e[house]n',
#    'x[na]na',
#    'ninda[bread]n_gu[eat]v/t'],
#   ['ninmah[1]dn', 'enki[1]dn', 'inim[word]n_gi[turn]v/i'],
#   ['lu[person]n',
#    'šu[hand]n',
#    'dim[create]v/t',
#    'lu[person]n_til[live]v/i',
#    'me[be]v/i',
#    'lu[person]n_uš[die]v/i',
#    'me[be]v/i',
#    'il[raise]v/t',
#    'me[be]v/i'],
#   ['lu[person]n',
#    'šu[hand]n',
#    'dim[create]v/t',
#    'lu[person]n_til[live]v/i',
#    'me[be]v/i',
#    'lu[person]n_uš[die]v/i',
#    'me[be]v/i',
#    'il[raise]v/t',
#    'me[be]v/i'],
#   ['lu[person]n',
#    'a[water]n_sur[press]v/t',
#    'nam[fate]n',
#    'tar[cut]v/t',
#    'ninda[bread]n',
#    'šum[give]v/t'],
#   ['ninmah[1]dn', 'enki[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['ki[place]n',
#    'zaʾe[you]ip',
#    'tuš[sit]v/i',
#    'e[house]n_du[build]v/t',
#    'inim[word]n',
#    'muš[tree]n',
#    'ŋeš[tree]n_tuku[acquire]v/t'],
#   ['ki[place]n',
#    'zaʾe[you]ip',
#    'tuš[sit]v/i',
#    'e[house]n_du[build]v/t',
#    'inim[word]n',
#    'muš[tree]n',
#    'ŋeš[tree]n_tuku[acquire]v/t'],
#   ['ki[place]n',
#    'zaʾe[you]ip_til[live]v/i',
#    'iri[city]n_du[build]v/t',
#    'niŋ[thing]n',
#    'lib[daze]n',
#    'sig[put]v/t'],
#   ['ki[place]n',
#    'zaʾe[you]ip_til[live]v/i',
#    'iri[city]n_du[build]v/t',
#    'niŋ[thing]n',
#    'lib[daze]n',
#    'sig[put]v/t'],
#   ['iri[city]n',
#    'gelleŋ[forsake]v/i',
#    'e[house]n_gul[destroy]v/t',
#    'dumu[child]n_dumu[child]n',
#    'šu[hand]n',
#    'dab[seize]v/t'],
#   ['iri[city]n',
#    'gelleŋ[forsake]v/i',
#    'e[house]n_gul[destroy]v/t',
#    'dumu[child]n_dumu[child]n',
#    'šu[hand]n',
#    'dab[seize]v/t'],
#   ['ud[sun]n', 'me[i]ip', 'niŋ[thing]n', 'šu[hand]n', 'šu[hand]n_e[leave]v/i'],
#   ['inim[word]n',
#    'kag[mouth]n_e[leave]v/i',
#    'aba[who?]qp',
#    'kur[different]v/i'],
#   ['ninmah[1]dn',
#    'kiŋ[work]n',
#    'la[hang]v/t',
#    'šu[hand]n_du[push]v/t',
#    'dab[seize]v/t',
#    'aba[who?]qp',
#    'saŋ[head]n_ŋar[place]v/t'],
#   ['ninmah[1]dn',
#    'kiŋ[work]n',
#    'la[hang]v/t',
#    'šu[hand]n_du[push]v/t',
#    'dab[seize]v/t',
#    'aba[who?]qp',
#    'saŋ[head]n_ŋar[place]v/t'],
#   ['diŋir[deity]n',
#    'ŋeš[tree]n_tuku[acquire]v/t',
#    'umul[creature]n',
#    'du[build]v/t',
#    'x[na]na',
#    'e[house]n',
#    'ak[do]v/t'],
#   ['ninmah[1]dn',
#    'en[lord]n',
#    'gal[big]v/i',
#    'enki[1]dn',
#    'zag[side]n_sa[equal]v/t'],
#   ['aya[father]n', 'enki[1]dn', 'zamin[lyre]n_dug[good]v/i'],
#   ['aya[father]n',
#    'enki[1]dn',
#    'gud[ox]n_a[water]n',
#    'ri[impose]v/t',
#    'am[bull]n',
#    'gal[big]v/i',
#    'utud[bear]v/t'],
#   ['mi[cvne]n_dug[speak]v/t',
#    'kur[mountain]n',
#    'gal[big]v/i',
#    'enlil[1]dn',
#    'ki[place]n',
#    'aŋ[measure]v/t',
#    'an[1]dn',
#    'kug[pure]v/i'],
#   ['e[house]n_mah[great]v/i',
#    'abzu[water]n',
#    'sig[put]v/t',
#    'dim[post]n',
#    'gal[big]v/i',
#    'an[sky]n',
#    'ki[place]n'],
#   ['ud[sun]n',
#    'šid[count]v/t',
#    'itud[moon]n',
#    'e[house]n',
#    'kur[enter]v/i',
#    'mu[year]n',
#    'šu[hand]n_du[push]v/t'],
#   ['mu[year]n',
#    'šu[hand]n_du[push]v/t',
#    'unkin[assembly]n',
#    'ešbar[decision]n',
#    'šum[give]v/t'],
#   ['ešbar[decision]n_kiŋ[seek]v/t', 'ud[sun]n', 'si[horn]n_sa[equal]v/t'],
#   ['ešbar[decision]n_kiŋ[seek]v/t', 'ud[sun]n', 'si[horn]n_sa[equal]v/t'],
#   ['kag[mouth]n',
#    'ba[allot]v/t',
#    'niŋ[thing]n',
#    'lu[abundant]v/i',
#    'heŋal[plenty]n',
#    'ki[place]n_us[follow]v/t'],
#   ['unud[cowherd]n', 'dun[roam]v/i', 'šakir[churn]n', 'ud[sun]n_zal[pass]v/t'],
#   ['gud[ox]n', 'a[arm]n_gur[thick]v/i', 'kisal[courtyard]n', 'du[push]v/t'],
#   ['inim[word]n',
#    'kisikil[woman]n',
#    'hili[attractiveness]n',
#    'saŋ[head]n_ŋal[be]v/i'],
#   ['iri[city]n',
#    'ŋar[place]v/t',
#    'uŋ[people]n',
#    'u[admiration]n_dug[speak]v/t'],
#   ['šag[heart]n_hul[rejoice]v/i', 'silim[healthy]v/i', 'dug[speak]v/t'],
#   ['zaʾe[you]ip',
#    'kur[mountain]n',
#    'gal[big]v/i',
#    'enlil[1]dn',
#    'a[arm]n_aŋ[measure]v/t'],
#   ['dug[speak]v/t',
#    'ešbar[decision]n',
#    'ki[place]n_ŋar[place]v/t',
#    'nam[fate]n',
#    'tar[cut]v/t',
#    'galanzu[wise]aj'],
#   ['x[na]na',
#    'x[na]na',
#    'ud[sun]n',
#    'saŋ[head]n_gi[turn]v/i',
#    'itud[moon]n',
#    'e[house]n',
#    'kur[enter]v/i'],
#   ['x[na]na', 'ed[ascend]v/i', 'šid[count]v/t', 'sa[equal]v/t_dug[speak]v/t'],
#   ['x[na]na', 'x[na]na', 'šu[hand]n_du[push]v/t'],
#   ['x[na]na',
#    'e[na]na',
#    'tar[na]na',
#    'tukul[weapon]n',
#    'e[house]n_gi[turn]v/i'],
#   ['enki[1]dn',
#    'lugal[king]n',
#    'abzu[water]n',
#    'ni[fear]n_gal[big]v/i',
#    'kurku[observe?]v/t',
#    'silim[healthy]v/i',
#    'zid[right]v/i',
#    'dug[speak]v/t'],
#   ['an[sky]n', 'ki[place]n', 'pa[branch]n_e[leave]v/i_ak[do]v/t'],
#   ['pap[relation]n', 'lugal[king]n_kur[mountain]n'],
#   ['me[being]n', 'ur[pluck]v/t', 'me[being]n', 'šu[hand]n_ŋar[place]v/t'],
#   ['ud[storm]n',
#    'gal[big]v/i',
#    'ki[place]n_gal[big]v/i',
#    'e[leave]v/i',
#    'en[lord]n',
#    'gal[big]v/i',
#    'kalam[land]n'],
#   ['šešgal[relation]n',
#    'diŋir[deity]n',
#    'heŋal[plenty]n',
#    'šu[hand]n_du[push]v/t'],
#   ['an[1]dn',
#    'lugal[king]n',
#    'barag[sanctum]n',
#    'an[sky]n',
#    'did[lawsuit]n',
#    'si[horn]n_sa[equal]v/t'],
#   ['nintur[1]dn', 'mi[cvne]n_zid[right]v/i_dug[speak]v/t'],
#   ['nun[prince]n', 'gal[big]v/i', 'ni[self]rp', 'zamin[lyre]n_dug[speak]v/t'],
#   ['ešbar[decision]n_kiŋ[seek]v/t',
#    'zamin[lyre]n_dug[speak]v/t',
#    'enki[1]dn',
#    'zamin[lyre]n'],
#   ['ešbar[decision]n_kiŋ[seek]v/t',
#    'zamin[lyre]n_dug[speak]v/t',
#    'enki[1]dn',
#    'zamin[lyre]n'],
#   ['enki[1]dn',
#    'lugal[king]n',
#    'abzu[water]n',
#    'ni[fear]n_gal[big]v/i',
#    'kurku[observe?]v/t',
#    'silim[healthy]v/i',
#    'zid[right]v/i',
#    'dug[speak]v/t'],
#   ['en[lord]n', 'dug[speak]v/t_zid[right]v/i', 'saŋ[head]n', 'e[leave]v/i'],
#   ['e[house]n',
#    'eš[shrine]n',
#    'ki[place]n_sikil[pure]v/i',
#    'du[build]v/t',
#    'mu[name]n',
#    'dug[good]v/i',
#    'še[call]v/t'],
#   ['enkum[treasurer]n',
#    'nenkum[official]n',
#    'šu[hand]n_si[horn]n_sa[equal]v/t'],
#   ['šag[heart]n_hul[rejoice]v/i', 'de[bring]v/t'],
#   ['ambar[reed-bed]n_mah[great]v/i',
#    'ki[place]n',
#    'šag[heart]n',
#    'pad[find]v/t'],
#   ['gu[voice]n_rah[beat]v/t', 'ŋisal[rudder]n_šu[hand]n', 'du[push]v/t'],
#   ['gu[voice]n_rah[beat]v/t', 'ŋisal[rudder]n_šu[hand]n', 'du[push]v/t'],
#   ['enki[1]dn',
#    'ma[ship]n_durah[goat]n_abzu[water]n',
#    'a[arm]n_aŋ[measure]v/t'],
#   ['enki[1]dn',
#    'ma[ship]n_durah[goat]n_abzu[water]n',
#    'a[arm]n_aŋ[measure]v/t'],
#   ['eren[cedar]n', 'sissig[green]v/i', 'u[admiration]n_dug[speak]v/t'],
#   ['ma[ship]n_dilmun[1]gn', 'ŋeš[tree]n', 'du[build]v/t'],
#   ['ma[ship]n_magan[1]gn', 'anzag[horizon]n', 'la[hang]v/t'],
#   ['enlil[1]dn', 'lugal[king]n_kur[mountain]n', 'nibru[1]sn', 'de[bring]v/t'],
#   ['martu[1]en', 'mašanše[animals]n', 'saŋ[head]n_rig[donate]v/t'],
#   ['anunak[1]dn', 'mi[cvne]n_zid[right]v/i_dug[speak]v/t'],
#   ['an[sky]n',
#    'ki[place]n',
#    'niŋdaŋala[vastness]n',
#    'zag[side]n_sa[equal]v/t'],
#   ['eridug[1]sn',
#    'ki[place]n_kug[pure]v/i',
#    'ki[place]n_kal[rare]v/i',
#    'me[being]n',
#    'mah[great]v/i',
#    'šu[hand]n_teŋ[approach]v/i'],
#   ['eridug[1]sn',
#    'ki[place]n_kug[pure]v/i',
#    'ki[place]n_kal[rare]v/i',
#    'me[being]n',
#    'mah[great]v/i',
#    'šu[hand]n_teŋ[approach]v/i'],
#   ['eridug[1]sn',
#    'ki[place]n_kug[pure]v/i',
#    'ki[place]n_kal[rare]v/i',
#    'me[being]n',
#    'mah[great]v/i',
#    'šu[hand]n_teŋ[approach]v/i'],
#   ['aya[father]n',
#    'enki[1]dn',
#    'ki[place]n_kug[pure]v/i',
#    'ki[place]n_kal[rare]v/i',
#    'ŋiri[foot]n',
#    'gub[stand]v/i'],
#   ['aya[father]n',
#    'enki[1]dn',
#    'ki[place]n_kug[pure]v/i',
#    'ki[place]n_kal[rare]v/i',
#    'ŋiri[foot]n',
#    'gub[stand]v/i'],
#   ['kigub[station]n', 'mu[name]n_še[call]v/t'],
#   ['eš[shrine]n_mah[great]v/i', 'abzu[1]tn', 'sikil[pure]v/i'],
#   ['šag[heart]n',
#    'li[juniper]n',
#    'an[sky]n',
#    'u[grass]n_sikil[pure]v/i',
#    'e[leave]v/i'],
#   ['x[na]na',
#    'x[na]na',
#    'kug[pure]v/i',
#    'ki.en.du[watercourse]n',
#    'mah[great]v/i',
#    'x[na]na',
#    'enki[1]dn',
#    'si[horn]n_sa[equal]v/t'],
#   ['urin[standard]n_gal[big]v/i',
#    'abzu[water]n',
#    'sig[put]v/t',
#    'andul[shade]n_ak[do]v/t'],
#   ['urin[standard]n_gal[big]v/i',
#    'abzu[water]n',
#    'sig[put]v/t',
#    'andul[shade]n_ak[do]v/t'],
#   ['durah[goat]n', 'abzu[water]n', 'a[arm]n_aŋ[measure]v/t'],
#   ['mes[tree]n', 'abzu[water]n', 'šerkan[ornament]n_dug[speak]v/t'],
#   ['eridug[1]sn',
#    'ki[place]n_kug[pure]v/i',
#    'ki[place]n_kal[rare]v/i',
#    'me[being]n',
#    'mah[great]v/i',
#    'šu[hand]n_teŋ[approach]v/i'],
#   ['eridug[1]sn',
#    'ki[place]n_kug[pure]v/i',
#    'ki[place]n_kal[rare]v/i',
#    'me[being]n',
#    'mah[great]v/i',
#    'šu[hand]n_teŋ[approach]v/i'],
#   ['eridug[1]sn',
#    'ki[place]n_kug[pure]v/i',
#    'ki[place]n_kal[rare]v/i',
#    'me[being]n',
#    'mah[great]v/i',
#    'šu[hand]n_teŋ[approach]v/i'],
#   ['ursaŋ[hero]n', 'abzu[1]tn', 'saŋ[head]n_il[raise]v/t'],
#   ['lahama[being]n',
#    'engur[waters]n',
#    '50[50]nu',
#    'mi[cvne]n_zid[right]v/i_dug[speak]v/t'],
#   ['gu[voice]n_rah[beat]v/t', 'gamgam[bird]n', 'an[sky]n', 'x[na]na'],
#   ['lugal[king]n',
#    'una[wild]aj_gub[stand]v/i',
#    'aya[father]n',
#    'enki[1]dn',
#    'kalam[land]n',
#    'x[na]na'],
#   ['heŋal[plenty]n',
#    'an[sky]n',
#    'ki[place]n',
#    'pa[branch]n_e[leave]v/i_ak[do]v/t'],
#   ['šerzid[radiance]n',
#    'gur[lift]v/t',
#    'ud[sun]n',
#    'e[leave]v/i',
#    'ud[sun]n_šuš[cover]v/t',
#    'uŋ[people]n',
#    'me[being]n',
#    'šum[give]v/t'],
#   ['me[being]n', 'me[being]n', 'mah[great]v/i', 'šu[hand]n_tutu[cvve]v/t'],
#   ['umun[knowledge]n',
#    'zid[right]v/i',
#    'ki[place]n',
#    'diŋir[deity]n',
#    'utud[bear]v/t',
#    'an[sky]n',
#    'šu[hand]n_teŋ[approach]v/i'],
#   ['lugal[king]n_kur[mountain]n', 'gal[big]v/i', 'aya[father]n', 'enlil[1]dn'],
#   ['šag[heart]n', 'kiʾur[foundation]n', 'šu[hand]n_teŋ[approach]v/i'],
#   ['e[house]n_zid[right]v/i', 'šu[hand]n', 'an[sky]n', 'il[raise]v/t'],
#   ['iri[city]n',
#    'meteŋal[seemly]aj',
#    'a[water]n_tu[cvve]v/t',
#    'gud[ox]n',
#    'silim[healthy]v/i',
#    'gub[stand]v/i'],
#   ['barag[sanctum]n',
#    'namhe[abundance]n',
#    'kur[mountain]n',
#    'dub[knee]n_bad[open]v/t',
#    'hursaŋ[mountain]n',
#    'il[raise]v/t'],
#   ['tir[forest]n_hašur[tree]n',
#    'ŋissu[shade]n_daŋal[wide]v/i',
#    'ne[strength]n',
#    'nirŋal[authoritative]aj'],
#   ['tir[forest]n_hašur[tree]n',
#    'ŋissu[shade]n_daŋal[wide]v/i',
#    'ne[strength]n',
#    'nirŋal[authoritative]aj'],
#   ['me[being]n', 'šu[hand]n_du[push]v/t', 'si[horn]n_sa[equal]v/t'],
#   ['me[being]n', 'šu[hand]n_du[push]v/t', 'si[horn]n_sa[equal]v/t'],
#   ['gud[ox]n',
#    'gud[ox]n',
#    'gal[big]v/i',
#    'me[be]v/i',
#    'gud[ox]n_kur[mountain]n',
#    'me[be]v/i'],
#   ['me[being]n', 'gal[big]v/i', 'diŋir[deity]n', 'šu[hand]n_du[push]v/t'],
#   ['ha.ib[fish?]n', 'teš[unity]n_gu[eat]v/t'],
#   ['kug[metal]n', 'zagin[lapis]n', 'e[house]n_niŋgur[property]n'],
#   ['enlil[1]dn', 'lugal[king]n_kur[mountain]n', 'nibru[1]sn', 'de[bring]v/t'],
#   ['enki[1]dn',
#    'martu[1]en',
#    'mašanše[animals]n',
#    'saŋ[head]n_rig[donate]v/t'],
#   ['ki[place]n', 'igi[eye]n_ŋar[place]v/t'],
#   ['gud[ox]n', 'du[push]v/t', 'una[wild]aj_gub[stand]v/i'],
#   ['idigna[1]wn',
#    'am[bull]n',
#    'gal[big]v/i',
#    'šag[heart]n_hul[rejoice]v/i',
#    'utud[bear]v/t',
#    'x[na]na'],
#   ['še[barley]n',
#    'de[bring]v/t',
#    'še[barley]n_gunu[flax]n',
#    'me[be]v/i',
#    'uŋ[people]n',
#    'gu[eat]v/t'],
#   ['ekur[1]tn',
#    'e[house]n',
#    'enlil[1]dn',
#    'niŋ[thing]n_ŋal[be]v/i',
#    'si[fill]v/t'],
#   ['en[lord]n', 'namen[priesthood]n', 'suh[crown]n_kešed[bind]v/t'],
#   ['a[arm]n_gab[left]n', 'ki[place]n_us[follow]v/t'],
#   ['a[arm]n_gab[left]n', 'ki[place]n_us[follow]v/t'],
#   ['idigna[1]wn', 'buranun[1]wn', 'teš[unity]n_gu[eat]v/t'],
#   ['ambar[reed-bed]n',
#    'gu[voice]n_de[pour]v/t',
#    'hi.suhur[fish]n',
#    'suhur[carp]n',
#    'šum[give]v/t'],
#   ['gi[thicket]n',
#    'gu[voice]n_de[pour]v/t',
#    'gi[reed]n',
#    'sumun[old]v/i',
#    'gi[reed]n',
#    'henbur[stalk]n',
#    'šum[give]v/t'],
#   ['gu[cord]n_la[hang]v/t', 'mušen[bird]n', 'e[leave]v/i'],
#   ['ezen×kug[na]na',
#    'lu[person]n',
#    'a[arm]n_mah[great]v/i',
#    'dumu[child]n',
#    'ezem[festival]n',
#    'sur[locus]n'],
#   ['eš[shrine]n',
#    'šag[heart]n',
#    'gu[cord]n',
#    'suh[confuse]v/t',
#    'niŋ[thing]n',
#    'lu[person]n_zu[know]v/t'],
#   ['anunak[1]dn', 'diŋir[deity]n', 'gal[big]v/i', 'saŋ[head]n_ŋar[place]v/t'],
#   ['šag[heart]n',
#    'ten[extinguish]v/t',
#    'ŋar[place]v/t',
#    'egal[palace]n_hul[rejoice]v/i'],
#   ['eš[shrine]n',
#    'niŋ[thing]n_dug[good]v/i',
#    'eš[shrine]n',
#    'niŋ[thing]n',
#    'utud[bear]v/t',
#    'x[na]na'],
#   ['ekur[1]tn',
#    'e[house]n',
#    'enlil[1]dn',
#    'niŋ[thing]n_ŋal[be]v/i',
#    'si[fill]v/t'],
#   ['šeŋ[rain]v/i', 'an[sky]n', 'gu[voice]n_de[pour]v/t'],
#   ['iškur[1]dn', 'lu[person]n_ŋal[be]v/i', 'dumu[child]n', 'an[1]dn'],
#   ['apin[plow]n', 'šudul[yoke]n', 'erin[yoke]v/t', 'si[horn]n_sa[equal]v/t'],
#   ['gana[field]n', 'zid[right]v/i', 'še[barley]n_mu[grow]v/t'],
#   ['en[lord]n',
#    'gana[field]n',
#    'zid[right]v/i',
#    'gu[voice]n_de[pour]v/t',
#    'še[barley]n_gunu[flax]n',
#    'šum[give]v/t'],
#   ['en[lord]n',
#    'gana[field]n',
#    'zid[right]v/i',
#    'gu[voice]n_de[pour]v/t',
#    'še[barley]n_gunu[flax]n',
#    'šum[give]v/t'],
#   ['šeʾeštub[barley]n',
#    'še[barley]n_gunu[flax]n',
#    'še[barley]n',
#    'inimŋal[eloquent]aj',
#    'guru[store]n',
#    'dub[heap]v/t'],
#   ['nun[prince]n',
#    'gal[big]v/i',
#    'al[hoe]n_sa[sinew]n',
#    'sig[put]v/t',
#    'ušub[brick-mold]n',
#    'si[horn]n_sa[equal]v/t'],
#   ['nun[prince]n',
#    'gal[big]v/i',
#    'al[hoe]n_sa[sinew]n',
#    'sig[put]v/t',
#    'ušub[brick-mold]n',
#    'si[horn]n_sa[equal]v/t'],
#   ['al[hoe]n_zu[tooth]n',
#    'sig[put]v/t',
#    'muš[snake]n',
#    'adda[corpse]n',
#    'gu[eat]v/t',
#    'niŋ[thing]n',
#    'šu[hand]n',
#    'ŋal[be]v/i'],
#   ['ušub[brick-mold]n',
#    'ŋar[place]v/t',
#    'zar[sheaf]n',
#    'gunida[~grain]n',
#    'u[ewe]n',
#    'si[horn]n_sa[equal]v/t'],
#   ['gu[cord]n', 'ŋar[place]v/t', 'us[follow]v/t', 'si[horn]n_sa[equal]v/t'],
#   ['a[arm]n',
#    'unkin[assembly]n',
#    'e[house]n_ŋar[place]v/t',
#    'šuluh[cleansing]n',
#    'si[horn]n_sa[equal]v/t'],
#   ['a[arm]n',
#    'unkin[assembly]n',
#    'e[house]n_ŋar[place]v/t',
#    'šuluh[cleansing]n',
#    'si[horn]n_sa[equal]v/t'],
#   ['nun[prince]n',
#    'gal[big]v/i',
#    'uš[foundation]n',
#    'ki[place]n_tag[touch]v/t',
#    'šeg[brick]n',
#    'ki[place]n_us[follow]v/t'],
#   ['nun[prince]n',
#    'gal[big]v/i',
#    'uš[foundation]n',
#    'ki[place]n_tag[touch]v/t',
#    'šeg[brick]n',
#    'ki[place]n_us[follow]v/t'],
#   ['uš[foundation]n', 'ki[place]n_tag[touch]v/t', 'silig[cease]v/t'],
#   ['e[house]n_zid[right]v/i', 'du[build]v/t', 'kar[blow]v/t'],
#   ['aneden[steppe]n',
#    'sum[beard]n_zagin[lapis]n',
#    'la[hang]v/t',
#    'suh[crown]n',
#    'zagin[lapis]n',
#    'kešed[bind]v/t'],
#   ['ki[place]n_dug[good]v/i',
#    'ušim[greenery]n',
#    'kirizal[joy]n',
#    'šu[hand]n_gal[big]v/i',
#    'du[push]v/t'],
#   ['ki[place]n_dug[good]v/i',
#    'ušim[greenery]n',
#    'kirizal[joy]n',
#    'šu[hand]n_gal[big]v/i',
#    'du[push]v/t'],
#   ['piriŋ[lion]n',
#    'gal[big]v/i',
#    'aneden[steppe]n',
#    'atuku[powerful]n',
#    'gal[big]v/i',
#    'a[arm]n_mah[great]v/i',
#    'enlil[1]dn'],
#   ['tur[stall]n',
#    'du[build]v/t',
#    'šuluh[cleansing]n',
#    'si[horn]n_sa[equal]v/t'],
#   ['amaš[sheepfold]n',
#    'ŋar[place]v/t',
#    'i[oil]n',
#    'gara[cream]n',
#    'saŋ[head]n_šum[give]v/t'],
#   ['ki[place]n',
#    'ninda[bread]n_gu[eat]v/t',
#    'diŋir[deity]n',
#    'kirizal[joy]n',
#    'gi[turn]v/i'],
#   ['eden[back]n',
#    'ušim[greenery]n',
#    'du[build]v/t',
#    'heŋal[plenty]n',
#    'sa[equal]v/t_dug[speak]v/t'],
#   ['sila[street]n_daŋal[wide]v/i',
#    'kulaba[1]sn',
#    'enedi[game]n',
#    'sud[distant]v/i',
#    'dug[speak]v/t'],
#   ['ekur[1]tn',
#    'e[house]n',
#    'enlil[1]dn',
#    'niŋ[thing]n_ŋal[be]v/i',
#    'si[fill]v/t'],
#   ['in[sector]n_dub[heap]v/t', 'bulug[needle]n', 'si[fill]v/t'],
#   ['adda[father]n',
#    'irigal[underworld]n',
#    'ki[place]n',
#    'ud[sun]n',
#    'e[leave]v/i',
#    'niŋir[herald]n_gal[big]v/i',
#    'an[sky]n',
#    'kug[pure]v/i'],
#   ['sum[beard]n_zagin[lapis]n',
#    'la[hang]v/t',
#    'an[sky]n',
#    'kug[pure]v/i',
#    'anur[horizon]n',
#    'e[leave]v/i'],
#   ['mug[wool]n',
#    'dun[warp]v/t',
#    'temen[foundation]n',
#    'si[horn]n_sa[equal]v/t'],
#   ['enki[1]dn',
#    'niŋ[thing]n',
#    'nammunus[femininity]n',
#    'šu[hand]n_gal[big]v/i',
#    'du[push]v/t'],
#   ['uttu[1]dn', 'munus[woman]n_zid[right]v/i', 'niŋmeŋar[silence]n'],
#   ['enlil[1]dn', 'šu[hand]n_gin[firm]v/i'],
#   ['munus[woman]n', 'dili[single]v/i', 'ana[what?]qp_dug[speak]v/t'],
#   ['šeg[brick]n',
#    'utud[bear]v/t',
#    'kug[pure]v/i',
#    'namen[priesthood]n',
#    'šu[hand]n_teŋ[approach]v/i'],
#   ['dur[bond]n_kud[cut]v/t',
#    'imanak[stone]n',
#    'garaš[leek]n',
#    'ri[impose]v/t'],
#   ['silaŋarra[bowl]n',
#    'zagin[lapis]n_duru[wet]v/i',
#    'šu[hand]n_teŋ[approach]v/i'],
#   ['silaŋarra[bowl]n',
#    'zagin[lapis]n_duru[wet]v/i',
#    'šu[hand]n_teŋ[approach]v/i'],
#   ['ala[object]n',
#    'kug[pure]v/i',
#    'na[man]n',
#    'deg[collect]v/t',
#    'šu[hand]n_ri[impose]v/t'],
#   ['unu[adornment]n',
#    'šuba[stone]n',
#    'šu[hand]n_teŋ[approach]v/i',
#    'nugig[priestess]n_an[sky]n',
#    'me[be]v/i'],
#   ['unu[adornment]n',
#    'šuba[stone]n',
#    'šu[hand]n_teŋ[approach]v/i',
#    'nugig[priestess]n_an[sky]n',
#    'me[be]v/i'],
#   ['bulug[needle]n',
#    'kugsig[gold]n',
#    'mangara[chisel]n',
#    'kugbabbar[silver]n_šu[hand]n_teŋ[approach]v/i'],
#   ['ginindan[rod]n', 'šu[hand]n_teŋ[approach]v/i'],
#   ['eš[rope]n', 'zagin[lapis]n', 'a[arm]n_la[hang]v/t'],
#   ['me[being]n', 'gal[big]v/i', 'gu[voice]n_de[pour]v/t'],
#   ['in[sector]n_dub[heap]v/t',
#    'ki[place]n',
#    'sur[press]v/t',
#    'dubsar[scribe]n',
#    'kalam[land]n',
#    'me[be]v/i'],
#   ['kud[fish]n',
#    'niŋ[thing]n_dug[good]v/i',
#    'mušen[bird]n',
#    'niŋ[thing]n',
#    'kud[sweet]v/i'],
#   ['aya[father]n', 'enlil[1]dn', 'nibru[1]sn', 'šu[hand]n_gid[long]v/i'],
#   ['munus[woman]n', 'dili[single]v/i', 'ana[what?]qp_ak[do]v/t'],
#   ['munus[woman]n', 'gu[voice]n', 'sag[good]v/i', 'gu[voice]n_de[pour]v/t'],
#   ['balak[spindle]n', 'kirid[clasp]n', 'šu[hand]n_šum[give]v/t'],
#   ['murub[middle]n',
#    'arabu[bird]n',
#    'dug[speak]v/t',
#    'inim[word]n_hulu[bad]v/i',
#    'dug[speak]v/t'],
#   ['gu[cord]n', 'si[horn]n_sa[equal]v/t', 'suh[confuse]v/t'],
#   ['kisikil[woman]n',
#    'inanak[1]dn',
#    'gu[cord]n',
#    'suh[confuse]v/t',
#    'si[horn]n_sa[equal]v/t'],
#   ['tug[textile]n_guz[tufted]v/i',
#    'gudu[cord]n',
#    'gunu[speckled]v/i',
#    'gunu[speckled]v/i'],
#   ['inanak[1]dn',
#    'niŋ[thing]n_gul[destroy]v/t',
#    'gul[destroy]v/t',
#    'niŋ[thing]n_sig[put]v/t',
#    'sig[put]v/t'],
#   ['inanak[1]dn',
#    'niŋ[thing]n_gul[destroy]v/t',
#    'gul[destroy]v/t',
#    'niŋ[thing]n_sig[put]v/t',
#    'sig[put]v/t'],
#   ['kisikil[woman]n',
#    'inanak[1]dn',
#    'tigi[instrument]n',
#    'adab[drum]n',
#    'e[house]n_gi[turn]v/i'],
#   ['lu[person]n',
#    'u[admiration]n_dug[speak]v/t',
#    'igi[eye]n',
#    'kušu[tired]v/i'],
#   ['ineš[now]ma',
#    'šag[heart]n_gu[neck]n_gi[turn]v/i',
#    'kalam[land]n',
#    'ki[place]n',
#    'gi[turn]v/i'],
#   ['šag[heart]n_gu[neck]n_gi[turn]v/i', 'namlulu[humanity]n'],
#   ['x[na]na',
#    'x[na]na',
#    'e[na]na',
#    'x[na]na',
#    'x[na]na',
#    'niŋ[thing]n_ŋar[place]v/t'],
#   ['x[na]na', 'gu[voice]n_de[pour]v/t', 'x[na]na', 'namen[priesthood]n'],
#   ['gal[big]v/i_kugsig[gold]n', 'šu[hand]n_tag[touch]v/t', 'dug[speak]v/t'],
#   ['gal[big]v/i_kugsig[gold]n', 'šu[hand]n_tag[touch]v/t', 'dug[speak]v/t'],
#   ['eridug[1]sn', 'e[house]n', 'gu[neck]n_du[build]v/t'],
#   ['šeg[brick]n', 'inim[word]n_dug[speak]v/t', 'ad[voice]n', 'gi[turn]v/i'],
#   ['gisal[screen]n', 'gud[ox]n', 'murmara[noise]n_ša[cvve]v/t'],
#   ['e[house]n_lugal[king]n',
#    'ŋi[night]n',
#    'ar[praise]n',
#    'de[bring]v/t',
#    'dug[good]v/i',
#    'ŋar[place]v/t'],
#   ['e[house]n_ŋen[go]v/i', 'gu[voice]n_de[pour]v/t'],
#   ['e[house]n_ŋen[go]v/i', 'gu[voice]n_de[pour]v/t'],
#   ['e[house]n', 'kug[metal]n', 'zagin[lapis]n', 'ki[place]n_ŋar[place]v/t'],
#   ['nun[prince]n', 'abzu[water]n', 'mi[cvne]n_dug[speak]v/t'],
#   ['idigna[1]wn',
#    'buranun[1]wn',
#    'mah[great]v/i',
#    'ni[fear]n',
#    'šu[hand]n_teŋ[approach]v/i'],
#   ['ŋušur[beam]n',
#    'gud[ox]n_an[sky]n',
#    'suh[crown]n',
#    'kug[pure]v/i',
#    'galam[skilful]v/i',
#    'dug[speak]v/t'],
#   ['nir.gam.ma[arch]n', 'gud[ox]n_am[bull]n', 'si[horn]n', 'gur[lift]v/t'],
#   ['kan[gate]n',
#    'urmah[lion]n',
#    'lu[person]n',
#    'ni[fear]n',
#    'šu[hand]n_teŋ[approach]v/i'],
#   ['abzu[water]n', 'ki[place]n_sikil[pure]v/i', 'meteŋal[seemly]aj'],
#   ['ka×li[na]na', 'zagin[lapis]n', 'mi[cvne]n_dug[speak]v/t'],
#   ['e[house]n',
#    'enki[1]dn',
#    'lal₃.hi×aš₂[wax]n',
#    'kug[pure]v/i',
#    'gurum[inspection]n_ak[do]v/t'],
#   ['gud[ox]n', 'lugal[king]n_us[follow]v/t', 'sig[put]v/t'],
#   ['ni[self]rp',
#    'murmara[noise]n_ša[cvve]v/t',
#    'teš[unity]n',
#    'ad[voice]n',
#    'gi[turn]v/i'],
#   ['šag[heart]n',
#    'barag[sanctum]n',
#    'mah[great]v/i',
#    'ki[place]n_ŋar[place]v/t'],
#   ['abzu[water]n',
#    'ki[place]n_sikil[pure]v/i',
#    'ki[place]n',
#    'nam[fate]n',
#    'tar[cut]v/t'],
#   ['e[house]n_zag[side]n',
#    'du[build]v/t',
#    'me[being]n',
#    'galam[skilful]v/i',
#    'tum[suitable]v/i'],
#   ['eʾengura[1]tn',
#    'urun[exalted]v/i',
#    'mah[great]v/i',
#    'ki[place]n_us[follow]v/t'],
#   ['e[house]n_mah[great]v/i',
#    'enki[1]dn',
#    'ŋeštug[ear]n',
#    'kalam[land]n',
#    'šum[give]v/t'],
#   ['e[house]n_kug[pure]v/i', 'dug[good]v/i', 'ŋar[place]v/t'],
#   ['harhar[instrument]n',
#    'sabitum[instrument]n',
#    'miritum[instrument]n',
#    'e[house]n_sig[silent]n'],
#   ['šag[heart]n', 'ni[self]rp', 'ad[voice]n_ša[cvve]v/t'],
#   ['nar[musician]n', 'tigi[instrument]n', '7[7]nu', 'ad[voice]n_ša[cvve]v/t'],
#   ['hursaŋ[mountain]n_galam[skilful]v/i',
#    'kad[tie]v/t',
#    'a[water]n_dirig[float]v/i'],
#   ['hursaŋ[mountain]n_galam[skilful]v/i',
#    'kad[tie]v/t',
#    'a[water]n_dirig[float]v/i'],
#   ['ala[drum]n', 'ŋal[be]v/i', 'ki[place]n', 'sa[equal]v/t_dug[speak]v/t'],
#   ['kurkudu[container]n',
#    'kaš[beer]n_dug[good]v/i',
#    'duh[bran]n',
#    'sa[equal]v/t'],
#   ['kag[mouth]n_lal[syrup]n',
#    'zulum[date]n',
#    'niŋ[thing]n',
#    'ir[mighty]aj',
#    'ak[do]v/t'],
#   ['aya[father]n', 'enlil[1]dn', 'ninda[bread]n_gu[eat]v/t'],
#   ['nintur[1]dn', 'zag[side]n_gal[big]v/i', 'tuš[sit]v/i'],
#   ['lu[person]n_kaš[beer]n_naŋ[drink]v/t', 'kurun[beer]n', 'dug[good]v/i'],
#   ['enlil[1]dn', 'anunak[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['anunak[1]dn', 'ubšuʾunkenak[1]tn', 'si[horn]n_sa[equal]v/t'],
#   ['dumu[child]n', 'e[house]n_du[build]v/t', 'lugal[king]n', 'enki[1]dn'],
#   ['ki[place]n_dug[good]v/i', 'e[house]n_du[build]v/t'],
#   ['ki[place]n_dug[good]v/i', 'e[house]n_du[build]v/t'],
#   ['eridug[1]sn', 'ki[place]n_sikil[pure]v/i', 'lu[person]n', 'kur[enter]v/i'],
#   ['e[house]n_tigi[instrument]n',
#    '7[7]nu',
#    'si[horn]n_sa[equal]v/t',
#    'namšub[incantation]n',
#    'šum[give]v/t'],
#   ['e[house]n_tigi[instrument]n',
#    '7[7]nu',
#    'si[horn]n_sa[equal]v/t',
#    'namšub[incantation]n',
#    'šum[give]v/t'],
#   ['šir[song]n',
#    'kug[pure]v/i',
#    'teš[unity]n',
#    'e[house]n',
#    'ki[place]n_dug[good]v/i'],
#   ['pulal[1]on', 'pu[well]n', 'a[water]n_dug[good]v/i', 'me[be]v/i'],
#   ['id[river]n',
#    'kug[pure]v/i',
#    'nunus[woman]n',
#    'id[river]n',
#    'kug[pure]v/i',
#    'a[water]n_tu[cvve]v/t'],
#   ['šag[heart]n_hul[rejoice]v/i',
#    'a[water]n',
#    'hili[attractiveness]n',
#    'šag[heart]n_si[fill]v/t',
#    'taka[abandon]v/t'],
#   ['šag[heart]n_hul[rejoice]v/i',
#    'a[water]n',
#    'hili[attractiveness]n',
#    'šag[heart]n_si[fill]v/t',
#    'taka[abandon]v/t'],
#   ['id[river]n',
#    'kug[pure]v/i',
#    'munus[woman]n',
#    'id[river]n',
#    'kug[pure]v/i',
#    'a[water]n_tu[cvve]v/t'],
#   ['ama[mother]n', 'zu[know]v/t', 'šu[hand]n_sag[beat]v/t'],
#   ['adda[father]n', 'zu[know]v/t', 'šu[hand]n', 'sa[equal]v/t_dug[speak]v/t'],
#   ['enlil[1]dn', 'sukkal[secretary]n', 'nuska[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['eš[rope]n_ma[ship]n', 'tur[small]v/i', 'de[bring]v/t'],
#   ['ma[ship]n_gal[big]v/i', 'de[bring]v/t'],
#   ['enlil[1]dn', 'lu[person]n', 'abula[gate]n', 'gu[voice]n_de[pour]v/t'],
#   ['ud[sun]n', 'en[cvne]n_tar[cut]v/t'],
#   ['ninlil[1]dn', 'lu[person]n', 'abula[gate]n', 'gu[voice]n_de[pour]v/t'],
#   ['umuš[planning]n', 'tar[cut]v/t', 'inim[word]n_sig[put]v/t'],
#   ['šag[heart]n_sug[empty]v/i', 'si[fill]v/t'],
#   ['ud[sun]n', 'nin[lady]n', 'ne.še₃[~body]n', 'šu[hand]n_tag[touch]v/t'],
#   ['ud[sun]n', 'en[cvne]n_tar[cut]v/t'],
#   ['umuš[planning]n', 'tar[cut]v/t', 'inim[word]n_sig[put]v/t'],
#   ['šag[heart]n_sug[empty]v/i', 'si[fill]v/t'],
#   ['ud[sun]n', 'nin[lady]n', 'ne.še₃[~body]n', 'šu[hand]n_tag[touch]v/t'],
#   ['si.lu.igi[1]pn',
#    'lu[person]n_maʾaddir[ferryboat]n',
#    'enlil[1]dn',
#    'teŋ[approach]v/i'],
#   ['si.lu.igi[1]pn', 'lu[person]n_maʾaddir[ferryboat]n'],
#   ['ud[sun]n', 'en[cvne]n_tar[cut]v/t'],
#   ['lu[person]n_maʾaddir[ferryboat]n', 'ninlil[1]dn', 'teŋ[approach]v/i'],
#   ['lu[person]n_maʾaddir[ferryboat]n'],
#   ['enlil[1]dn', 'mulu[person]n', 'si.lu.igi[1]pn', 'inim[word]n_gi[turn]v/i'],
#   ['umuš[planning]n', 'tar[cut]v/t', 'inim[word]n_sig[put]v/t'],
#   ['šag[heart]n_sug[empty]v/i', 'si[fill]v/t'],
#   ['enlil[1]dn',
#    'lugal[king]n_kur[mountain]n',
#    'ŋaʾe[i]ip',
#    'ŋeš[penis]n',
#    'dug[speak]v/t'],
#   ['ud[sun]n', 'nin[lady]n', 'ne.še₃[~body]n', 'šu[hand]n_tag[touch]v/t'],
#   ['en[lord]n',
#    'gu[cord]n',
#    'mu[grow]v/t',
#    'en[lord]n',
#    'še[barley]n_mu[grow]v/t',
#    'zaʾe[you]ip'],
#   ['dug[speak]v/t', 'saŋ[head]n_du[build]v/t', 'šu[hand]n', 'bala[turn]v/t'],
#   ['zamin[lyre]n_dug[speak]v/t', 'ama[mother]n', 'ninlil[1]dn'],
#   ['x[na]na',
#    'zid[right]v/i',
#    'ŋar[place]v/t',
#    'u[admiration]n_dug[speak]v/t',
#    'hili[attractiveness]n',
#    'gur[lift]v/t'],
#   ['x[na]na',
#    'x[na]na',
#    'x[na]na',
#    'dumu[child]n',
#    'nun[prince]n',
#    'aba[who?]qp',
#    'ane[he]ip',
#    'an[1]dn',
#    'enlil[1]dn',
#    'zag[side]n_sa[equal]v/t'],
#   ['x[na]na',
#    'x[na]na',
#    'x[na]na',
#    'ab[cow]n_mah[great]v/i',
#    'sissig[green]v/i',
#    'u[admiration]n',
#    'gub[stand]v/i'],
#   ['ninlil[1]dn', 'mu[name]n', 'kiur[1]tn', 'pa[branch]n_e[leave]v/i'],
#   ['zag[side]n',
#    'an[sky]n',
#    'ki[place]n',
#    'kiengir[1]gn',
#    'niŋin[encircle]v/t',
#    'igi[eye]n',
#    'x[na]na',
#    'x[na]na',
#    'name[any]aj',
#    'saŋ[head]n_il[raise]v/t'],
#   ['teŋ[approach]v/i',
#    'šag[heart]n_hul[rejoice]v/i',
#    'dirig[float]v/i',
#    'inim[word]n',
#    'bala[turn]v/t'],
#   ['sud[1]dn',
#    'enlil[1]dn',
#    'a[arm]n',
#    'namtur[smallness]n',
#    'inim[word]n_gi[turn]v/i'],
#   ['inim[word]n',
#    'kag[mouth]n_e[leave]v/i',
#    'igi[eye]n',
#    'e[house]n',
#    'kur[enter]v/i'],
#   ['gu[voice]n_de[pour]v/t',
#    'uʾul[consent]n',
#    'arazu[supplication]n',
#    'nuska[1]dn',
#    'a[arm]n_aŋ[measure]v/t'],
#   ['gu[voice]n_de[pour]v/t',
#    'uʾul[consent]n',
#    'arazu[supplication]n',
#    'nuska[1]dn',
#    'a[arm]n_aŋ[measure]v/t'],
#   ['dumumunus[daughter]n',
#    'namdam[marriage]n_tuku[acquire]v/t',
#    'gin[firm]v/i',
#    'šum[give]v/t'],
#   ['ŋaŋiššua[1]tn', 'namerim[storage]n', 'saŋ[head]n_rig[donate]v/t'],
#   ['u[and]cnj',
#    'zaʾe[you]ip',
#    'zi[life]n',
#    'saŋ[head]n',
#    'giggi[black]v/i',
#    'šu[hand]n_ŋar[place]v/t'],
#   ['ud[sun]n_zal[pass]v/t', 'ul[hasten]v/i', 'inim[word]n', 'gur[turn]v/i'],
#   ['kingal[official]n',
#    'nuska[1]dn',
#    'a[arm]n_aŋ[measure]v/t',
#    'enlil[1]dn',
#    'šu[hand]n_teŋ[approach]v/i'],
#   ['kingal[official]n',
#    'nuska[1]dn',
#    'a[arm]n_aŋ[measure]v/t',
#    'enlil[1]dn',
#    'šu[hand]n_teŋ[approach]v/i'],
#   ['x[na]na',
#    'x[na]na',
#    'enlil[1]dn',
#    'x[na]na',
#    'x[na]na',
#    'x[na]na',
#    'gub[stand]v/i',
#    'en[cvne]n_tar[cut]v/t'],
#   ['tah[add]v/t',
#    'nanibgal[1]dn',
#    'sukkal[secretary]n',
#    'inim[word]n_sag[good]v/i'],
#   ['aba[who?]qp',
#    'zaʾe[you]ip',
#    'kur[mountain]n',
#    'gal[big]v/i',
#    'ud[sun]n',
#    'šag[heart]n_kušu[tired]v/i'],
#   ['kiŋ[work]n',
#    'lugal[king]n',
#    'subur[slave]n',
#    'dab[seize]v/t',
#    'me[i]ip',
#    'ana[what?]qp',
#    'adamin[contest]n_ak[do]v/t'],
#   ['mah[great]v/i',
#    'dirig[float]v/i',
#    'lu[person]n',
#    'šu[hand]n',
#    'gi[turn]v/i',
#    'aba[who?]qp',
#    'hulu[bad]v/i_gig[sick]v/i'],
#   ['x[na]na',
#    'ur[liver]n',
#    'šag[heart]n_hul[rejoice]v/i',
#    'ganam[moreover]ma',
#    'ud[ud]v',
#    'dug[speak]v/t'],
#   ['aruru[1]dn', 'erib[in-law]n', 'me[be]v/i', 'e[house]n_la[hang]v/t'],
#   ['x[na]na', 'a[arm]n_aŋ[measure]v/t'],
#   ['nanibgal[1]dn',
#    'x[na]na',
#    'gu[voice]n_de[pour]v/t',
#    'nadeg[advice]n',
#    'deg[collect]v/t'],
#   ['x[na]na',
#    'x[na]na',
#    'kiŋ[work]n_til[complete]v/i',
#    'kugzu[wise]aj',
#    'galanzu[wise]aj'],
#   ['x[na]na', 'igi[eye]n', 'du[du]v', 'kaš[beer]n_de[pour]v/t'],
#   ['dug[speak]v/t',
#    'ama[mother]n',
#    'šu[hand]n_luh[clean]v/t',
#    'zabar[bronze]n',
#    'šu[hand]n_ŋar[place]v/t'],
#   ['dug[speak]v/t',
#    'ama[mother]n',
#    'šu[hand]n_luh[clean]v/t',
#    'zabar[bronze]n',
#    'šu[hand]n_ŋar[place]v/t'],
#   ['x[na]na', 'umbin[nail]n', 'niŋba[gift]n', 'šu[hand]n_teŋ[approach]v/i'],
#   ['a[arm]n_aŋ[measure]v/t', 'x[na]na', 'x[na]na', 'gi[turn]v/i'],
#   ['aba[who?]qp',
#    'zaʾe[you]ip',
#    'kur[mountain]n',
#    'gal[big]v/i',
#    'ud[sun]n',
#    'šag[heart]n_kušu[tired]v/i'],
#   ['kiŋ[work]n',
#    'lugal[king]n',
#    'subur[slave]n',
#    'dab[seize]v/t',
#    'me[i]ip',
#    'ana[what?]qp',
#    'adamin[contest]n_ak[do]v/t'],
#   ['mah[great]v/i',
#    'dirig[float]v/i',
#    'lu[person]n',
#    'šu[hand]n',
#    'gi[turn]v/i',
#    'aba[who?]qp',
#    'hulu[bad]v/i_gig[sick]v/i'],
#   ['x[na]na',
#    'x[na]na',
#    'x[na]na',
#    'ur[liver]n',
#    'šag[heart]n_hul[rejoice]v/i',
#    'ganam[moreover]ma',
#    'ud[ud]v',
#    'dug[speak]v/t'],
#   ['aruru[1]dn', 'erib[in-law]n', 'me[be]v/i', 'e[house]n_la[hang]v/t'],
#   ['x[na]na',
#    'dug[good]v/i',
#    'enlil[1]dn',
#    'šag[heart]n_hul[rejoice]v/i',
#    'de[bring]v/t'],
#   ['x[na]na', 'saŋ[head]n_il[raise]v/t', 'kušum[cvne]n_tag[touch]v/t'],
#   ['x[na]na', 'saŋ[head]n_il[raise]v/t', 'kušum[cvne]n_tag[touch]v/t'],
#   ['x[na]na', 'hursaŋ[mountain]n', 'ŋal[be]v/i', 'šu[hand]n_tag[touch]v/t'],
#   ['am[bull]n',
#    'lulim[stag]n',
#    'amsi[elephant]n',
#    'durah[goat]n_mašda[gazelle]n',
#    'az[bear]n',
#    'šeg[animal]n',
#    'šeŋbar[animal]n'],
#   ['sua[cat]n',
#    'kaʾa[fox]n',
#    'sua[cat]n',
#    'uršub[tiger]n',
#    'udu[sheep]n_kur[mountain]n',
#    'abzaza[zebu]n',
#    'ugubi[monkey]n'],
#   ['gud[ox]n_niga[fattened]v/i',
#    'a[arm]n_gur[thick]v/i',
#    'gu[voice]n',
#    'sig[put]v/t'],
#   ['gud[ox]n_niga[fattened]v/i',
#    'a[arm]n_gur[thick]v/i',
#    'gu[voice]n',
#    'sig[put]v/t'],
#   ['u[ewe]n',
#    'sila[lamb]n_uzud[goat]n',
#    'maš[goat]n',
#    'zur[take-care-of]v/t',
#    'x[na]na',
#    'x[na]na',
#    'adamin[contest]n',
#    'ne[na]na',
#    'ane[he]ip',
#    'x[na]na'],
#   ['maš[goat]n_gal[big]v/i',
#    'sum[beard]n',
#    'la[hang]v/t',
#    'umbin[nail]n',
#    'sudsud[grind]v/t',
#    'sila[lamb]n',
#    'x[na]na',
#    'x[na]na'],
#   ['udu[sheep]n',
#    'namen[priesthood]n',
#    'si[horn]n_sa[equal]v/t',
#    'enlil[1]dn',
#    'ereš[1]sn'],
#   ['gaʾar[cheese]n_gal[big]v/i',
#    'gaʾar[cheese]n_gazi[condiment]n',
#    'gaʾar[cheese]n_tur[small]v/i',
#    'x[na]na'],
#   ['gaʾar[cheese]n_gal[big]v/i',
#    'gaʾar[cheese]n_gazi[condiment]n',
#    'gaʾar[cheese]n_tur[small]v/i',
#    'x[na]na'],
#   ['gaʾar[cheese]n_gal[big]v/i',
#    'gaʾar[cheese]n_gazi[condiment]n',
#    'gaʾar[cheese]n_tur[small]v/i',
#    'x[na]na'],
#   ['ga[milk]n_nunuzte[~dairy]n',
#    'šeŋ[cook]v/t',
#    'ga[milk]n_itirda[~dairy]n',
#    'x[na]na'],
#   ['ga[milk]n_nunuzte[~dairy]n',
#    'šeŋ[cook]v/t',
#    'ga[milk]n_itirda[~dairy]n',
#    'x[na]na'],
#   ['x[na]na',
#    'x[na]na',
#    'x[na]na',
#    'gur[thick]v/i',
#    'gal[big]v/i',
#    'si[horn]n_sa[equal]v/t',
#    'enlil[1]dn',
#    'ereš[1]sn'],
#   ['x[na]na',
#    'x[na]na',
#    'zulum[date]n',
#    'peš[fig]n',
#    'nurma[pomegranate]n_gal[big]v/i',
#    'x[na]na',
#    '(x)[na]na'],
#   ['nurma[pomegranate]n_gal[big]v/i',
#    'pu[orchard]n',
#    'šu[hand]n',
#    'sub[rub]v/t',
#    'ŋeštin[vine]n_garan[bunch]n',
#    'gal[big]v/i',
#    'iginim[land]n'],
#   ['nurma[pomegranate]n_gal[big]v/i',
#    'pu[orchard]n',
#    'šu[hand]n',
#    'sub[rub]v/t',
#    'ŋeštin[vine]n_garan[bunch]n',
#    'gal[big]v/i',
#    'iginim[land]n'],
#   ['ŋeš[tree]n_kur[mountain]n',
#    'girim[flower]n',
#    'ŋeš[tree]n',
#    'šag[heart]n',
#    'kiri[orchard]n',
#    'ŋeš[tree]n',
#    'hi[na]na',
#    'ud[na]na',
#    'x[na]na',
#    'x[na]na',
#    'enten[winter]n',
#    'gu[neck]n_peš[thick]v/i'],
#   ['ŋeš[tree]n_kur[mountain]n',
#    'girim[flower]n',
#    'ŋeš[tree]n',
#    'šag[heart]n',
#    'kiri[orchard]n',
#    'ŋeš[tree]n',
#    'hi[na]na',
#    'ud[na]na',
#    'x[na]na',
#    'x[na]na',
#    'enten[winter]n',
#    'gu[neck]n_peš[thick]v/i'],
#   ['gurun[fruit]n',
#    'kiri[orchard]n',
#    'si[horn]n_sa[equal]v/t',
#    'enlil[1]dn',
#    'ereš[1]sn'],
#   ['gun[load]n_dugud[heavy]v/i',
#    'si[horn]n_sa[equal]v/t',
#    'enlil[1]dn',
#    'ereš[1]sn'],
#   ['gun[load]n_dugud[heavy]v/i',
#    'si[horn]n_sa[equal]v/t',
#    'enlil[1]dn',
#    'ereš[1]sn'],
#   ['ušbar[in-law]n',
#    'enlil[1]dn',
#    'munus[woman]n',
#    'šu[hand]n',
#    'kar[blow]v/t',
#    'nanibgal[1]dn',
#    'mi[cvne]n_dug[speak]v/t',
#    'ušbar[in-law]n',
#    'enlil[1]dn',
#    'munus[woman]n',
#    'x[na]na',
#    'ezina[1]dn',
#    'x[na]na'],
#   ['nin[lady]n',
#    'zur[take-care-of]v/t',
#    'taka[abandon]v/t',
#    'gu[voice]n_de[pour]v/t'],
#   ['sag[good]v/i',
#    'gu[neck]n_la[hang]v/t',
#    'ki[place]n',
#    'aŋ[measure]v/t',
#    'bad[open]v/t',
#    'ne[ne]v'],
#   ['ŋiri[foot]n',
#    'us[follow]v/t',
#    'uŋ[people]n',
#    'si[horn]n_sa[equal]v/t',
#    'uŋ[people]n',
#    'ni[self]rp',
#    'ne[ne]v'],
#   ['nam[fate]n',
#    'tar[cut]v/t',
#    'ŋal[be]v/i',
#    'niŋ[thing]n',
#    'kur[different]v/i',
#    'saŋ[head]n_il[raise]v/t',
#    'emah[1]tn',
#    'ŋen[go]v/i'],
#   ['e[house]n_kinud[bedroom]n',
#    'ŋešnud[bed]n',
#    'girim[flower]n',
#    'tir[forest]n',
#    'šim[aromatics]n_eren[cedar]n',
#    'x[na]na'],
#   ['e[house]n_kinud[bedroom]n',
#    'ŋešnud[bed]n',
#    'girim[flower]n',
#    'tir[forest]n',
#    'šim[aromatics]n_eren[cedar]n',
#    'x[na]na'],
#   ['ki[place]n_ŋar[place]v/t',
#    'me[being]n',
#    'ki[place]n',
#    'til[live]v/i',
#    'sag[good]v/i',
#    'saŋ[head]n_rig[donate]v/t'],
#   ['ki[place]n_ŋar[place]v/t',
#    'me[being]n',
#    'ki[place]n',
#    'til[live]v/i',
#    'sag[good]v/i',
#    'saŋ[head]n_rig[donate]v/t'],
#   ['absin[furrow]n',
#    'kisikil[woman]n',
#    'sag[good]v/i',
#    'ni[self]rp',
#    'pa[branch]n_e[leave]v/i_ak[do]v/t'],
#   ['zagmuk[new-year]n',
#    'gu[cord]n',
#    'saŋ[head]n',
#    'gibil[new]v/i',
#    'še[barley]n_saŋ[head]n',
#    'gibil[new]v/i'],
#   ['buru[harvest]n',
#    'ezem[festival]n_gal[big]v/i',
#    'enlil[1]dn',
#    'saŋ[head]n',
#    'an[sky]n',
#    'il[raise]v/t'],
#   ['šu[hand]n_du[push]v/t', 'ensik[ruler]n', 'x[na]na'],
#   ['munus[woman]n', 'saŋ[head]n_il[raise]v/t', 'nungalene[1]dn', 'x[na]na'],
#   ['šir[song]n',
#    'kug[pure]v/i',
#    'mi[cvne]n_dug[speak]v/t',
#    '(x)[na]na',
#    'enlil[1]dn',
#    'ninlil[1]dn',
#    'x[na]na',
#    'x[na]na'],
#   ['x[na]na',
#    'uŋ[people]n',
#    'si[horn]n_sa[equal]v/t',
#    'uŋ[people]n',
#    'ni[self]rp',
#    'ne[ne]v'],
#   ['x[na]na',
#    'tar[cut]v/t',
#    'ŋal[be]v/i',
#    'saŋ[head]n_il[raise]v/t',
#    'ešmah[1]tn',
#    'x[na]na'],
#   ['ekur[1]tn',
#    'zagin[lapis]n',
#    'kur[enter]v/i',
#    'i[oil]n_saŋ[head]n',
#    'igi[eye]n',
#    'de[pour]v/t'],
#   ['e[house]n_kinud[bedroom]n',
#    'ŋešnud[bed]n',
#    'girim[flower]n',
#    'tir[forest]n_eren[cedar]n',
#    'dug[good]v/i'],
#   ['e[house]n_kinud[bedroom]n',
#    'ŋešnud[bed]n',
#    'girim[flower]n',
#    'tir[forest]n_eren[cedar]n',
#    'dug[good]v/i'],
#   ['barag[sanctum]n',
#    'namenlil[sovereignty]n',
#    'x[na]na',
#    'x[na]na',
#    'šud[prayer]n_ša[cvve]v/t'],
#   ['nintur[1]dn',
#    'nin[lady]n',
#    'utud[bear]v/t',
#    'nin[lady]n',
#    'dub[knee]n_bad[open]v/t',
#    'mu[name]n_še[call]v/t'],
#   ['nintur[1]dn',
#    'nin[lady]n',
#    'utud[bear]v/t',
#    'nin[lady]n',
#    'dub[knee]n_bad[open]v/t',
#    'mu[name]n_še[call]v/t'],
#   ['ki[place]n',
#    'ŋal[be]v/i',
#    'gi[reed]n',
#    'til[live]v/i',
#    'x[na]na',
#    'saŋ[head]n_rig[donate]v/t'],
#   ['x[na]na',
#    'kisikil[woman]n',
#    'sissig[green]v/i',
#    'ni[self]rp',
#    'pa[branch]n_e[leave]v/i_ak[do]v/t'],
#   ['x[na]na',
#    'še[barley]n_saŋ[head]n',
#    'mu[grow]v/t',
#    'gu[cord]n',
#    'saŋ[head]n',
#    'mu[grow]v/t'],
#   ['buru[harvest]n',
#    'ezem[festival]n_gal[big]v/i',
#    'enlil[1]dn',
#    'uŋ[people]n',
#    'har[na]na',
#    'sig[put]v/t',
#    'me[be]v/i'],
#   ['šu[hand]n_du[push]v/t',
#    'ensik[ruler]n',
#    'ulul[cultivation]n',
#    'šu[hand]n_gin[firm]v/i'],
#   ['šu[hand]n_du[push]v/t',
#    'ensik[ruler]n',
#    'ulul[cultivation]n',
#    'šu[hand]n_gin[firm]v/i'],
#   ['munus[woman]n',
#    'saŋ[head]n_il[raise]v/t',
#    'kur[mountain]n',
#    'zag[side]n',
#    'dib[pass]v/t',
#    'igi[eye]n',
#    'il[raise]v/t',
#    'pad[find]v/t'],
#   ['saŋ[head]n',
#    'en[cvne]n_tar[cut]v/t',
#    'x[na]na',
#    'zaʾe[you]ip',
#    'nam[fate]n',
#    'tar[cut]v/t'],
# ...
#   ['kug[pure]v/i', 'inanak[1]dn', 'šukaletuda[1]pn', 'gu[voice]n_de[pour]v/t'],
#   ['nin[lady]n', 'musar[garden]n', 'a[water]n_sig[put]v/t'],
#   ['ur[root]n', 'bala[turn]v/t', 'zu[tooth]n_gaz[kill]v/t'],
#   ['ub[corner]n_igi[eye]n', 'šu[hand]n', 'tuku[acquire]v/t'],
#   ['niŋ[thing]n_sig[put]v/t', 'zag[side]n', 'zu[know]v/t'],
#   ['iginim[land]n',
#    'igi[eye]n',
#    'il[raise]v/t',
#    'diŋir[deity]n',
#    'un[high]v/i',
#    'kur[mountain]n',
#    'ud[sun]n_šuš[cover]v/t',
#    'igi[eye]n',
#    'du[spread]v/t'],
#   ['diŋir[deity]n',
#    'dili[single]v/i',
#    'ŋen[go]v/i',
#    'igi[eye]n_ŋar[place]v/t'],
#   ['me[being]n', 'šu[hand]n_du[push]v/t', 'igi[eye]n', 'du[spread]v/t'],
#   ['ŋešandul[shade]n',
#    'asal[poplar]n_dug[good]v/i',
#    'ŋissu[shade]n_daŋal[wide]v/i'],
#   ['ŋešandul[shade]n',
#    'asal[poplar]n_dug[good]v/i',
#    'ŋissu[shade]n_daŋal[wide]v/i'],
#   ['ŋissu[shade]n', 'sig[weak]v/i', 'ud[sun]n_zal[pass]v/t'],
#   ['zag[side]n', 'sar[garden]n', 'igi[eye]n_sig[put]v/t'],
#   ['kug[pure]v/i', 'inanak[1]dn', 'šukaletuda[1]pn', 'gu[voice]n_de[pour]v/t'],
#   ['nar[musician]n_tur[small]v/i',
#    'egal[palace]n',
#    'lugal[king]n',
#    'kud[sweet]v/i'],
#   ['zidgu[flour]n_sag[rare]v/i',
#    'suhursumla[fish]n',
#    'x[na]na',
#    'x[na]na',
#    'x[na]na',
#    '(x)[na]na',
#    'tum[na]na',
#    'x[na]na',
#    'x[na]na'],
#   ['ugnim[army]n', 'igi[eye]n_sig[put]v/t'],
#   ['nar[musician]n',
#    'endu[song]n',
#    'šu[hand]n',
#    'gi[turn]v/i',
#    'sa[sinew]n_šu[hand]n',
#    'ru[ru]v'],
#   ['ninda[bread]n_gu[eat]v/t', 'uzu[flesh]n', 'x[na]na', 'gu[eat]v/t'],
#   ['šarur[1]dn',
#    'a[arm]n',
#    'namursaŋ[heroism]n',
#    'šu[hand]n_teŋ[approach]v/i'],
#   ['ŋešdal[crossbar]n', 'eanak[1]tn', 'pa[branch]n_kud[cut]v/t'],
#   ['ig[door]n_abula[gate]n',
#    'guru[grind]v/t',
#    'abula[gate]n',
#    'abula[gate]n_iškur[1]dn',
#    'x[na]na'],
#   ['ig[door]n_abula[gate]n',
#    'guru[grind]v/t',
#    'abula[gate]n',
#    'abula[gate]n_iškur[1]dn',
#    'x[na]na'],
#   ['gud[ox]n_kur[mountain]n',
#    'šum[give]v/t',
#    'tur[stall]n',
#    'lu[abundant]v/i'],
#   ['udu[sheep]n_kur[mountain]n',
#    'šum[give]v/t',
#    'amaš[sheepfold]n',
#    'lu[abundant]v/i'],
#   ['gud[ox]n_kur[mountain]n', 'ŋaʾe[i]ip', 'x[na]na'],
#   ['udu[sheep]n_kur[mountain]n', 'ŋaʾe[i]ip', 'x[na]na'],
#   ['zamin[lyre]n_dug[good]v/i'],
#   ['šeš[brother]n',
#    'ursaŋ[hero]n',
#    'šul[youth]v/i',
#    'utu[1]dn',
#    'kug[pure]v/i',
#    'inanak[1]dn',
#    'gu[voice]n_de[pour]v/t'],
#   ['x[na]na',
#    'x[na]na',
#    'inim[word]n_dug[speak]v/t',
#    'inim[word]n',
#    'ŋeštug[ear]n'],
#   ['x[na]na',
#    'x[na]na',
#    'x[na]na',
#    'x[na]na',
#    'maš[twin]n',
#    'inim[word]n_dug[speak]v/t',
#    'inim[word]n',
#    'ŋeštug[ear]n'],
#   ['ud[sun]n',
#    'x[na]na',
#    'x[na]na',
#    'x[na]na',
#    'dab[seize]v/t',
#    'gu[voice]n_de[pour]v/t',
#    'ŋeš[tree]n_tuku[acquire]v/t'],
#   ['ud[sun]n',
#    'x[na]na',
#    'x[na]na',
#    'x[na]na',
#    'dab[seize]v/t',
#    'gu[voice]n_de[pour]v/t',
#    'ŋeš[tree]n_tuku[acquire]v/t'],
#   ['x[na]na',
#    'x[na]na',
#    'bar[outside]v/t',
#    'tam[clean]v/i',
#    'a[arm]n_aŋ[measure]v/t',
#    'zaʾe[you]ip',
#    'igi[eye]n',
#    'du[spread]v/t'],
#   ['an[sky]n_sud[distant]v/i', 'x[na]na'],
#   ['a[water]n_rah[beat]v/t', 'x[na]na', 'hulu[bad]v/i_ak[do]v/t'],
#   ['a[water]n_rah[beat]v/t', 'x[na]na', 'hulu[bad]v/i_ak[do]v/t'],
#   ['kug[pure]v/i',
#    'inanak[1]dn',
#    'šukud[fisherman]n',
#    'inim[word]n_gi[turn]v/i'],
#   ['ki[place]n', 'ŋaʾe[i]ip', 'x[na]na', 'u[admiration]n_dug[speak]v/t'],
#   ['adagbir[1]dn', 'kug[pure]v/i', 'inanak[1]dn', 'inim[word]n_gi[turn]v/i'],
#   ['eanak[1]tn', 'an[sky]n', 'e[leave]v/i', 'u[admiration]n_dug[speak]v/t'],
#   ['x[na]na',
#    'x[na]na',
#    'x[na]na',
#    'utah[heaven]n',
#    'e[leave]v/i',
#    'udug[demon]n',
#    'sa[equal]v/t_dug[speak]v/t'],
#   ['x[na]na',
#    'zipaŋ[breath]n',
#    'x[na]na',
#    'x[na]na',
#    'ŋeš[tree]n_tuku[acquire]v/t'],
#   ['an[1]dn', 'inim[word]n', 'ŋeš[tree]n_tuku[acquire]v/t'],
#   ['dumu[child]n', 'ana[what?]qp_ak[do]v/t', 'ŋaʾe[i]ip', 'dirig[float]v/i'],
#   ['inanak[1]dn', 'ana[what?]qp_ak[do]v/t', 'ŋaʾe[i]ip', 'dirig[float]v/i'],
#   ['gukin[totality]n',
#    'kalam[land]n',
#    'mu[name]n',
#    'pad[find]v/t',
#    'gabari[copy]n_tuku[acquire]v/t'],
#   ['namlulu[humanity]n',
#    'uŋ[people]n_šar[3600]nu',
#    'ŋiri[foot]n',
#    'sig[put]v/t'],
#   ['ineš[now]ma', 'utu[1]dn', 'ud[sun]n', 'nen[this]dp', 'ur[he]ip_me[be]v/i'],
#   ['ud[sun]n',
#    'inanak[1]dn_eanak[1]tn',
#    'e[house]n',
#    'ki[place]n',
#    'nin[lady]n',
#    'dug[speak]v/t'],
#   ['innin[lady]n',
#    'ki[place]n',
#    'uma[triumph]n',
#    'gub[stand]v/i',
#    'šu[hand]n',
#    'sa[equal]v/t_dug[speak]v/t'],
#   ['inanak[1]dn',
#    'ki[place]n',
#    'uma[triumph]n',
#    'gub[stand]v/i',
#    'šu[hand]n',
#    'sa[equal]v/t_dug[speak]v/t'],
#   ['eanak[1]tn',
#    'an[1]dn',
#    'kar[flee]v/t',
#    'ki[place]n_dug[good]v/i',
#    'dug[speak]v/t'],
#   ['an[sky]n',
#    'gal[big]v/i',
#    'ki[place]n_gal[big]v/i',
#    'ŋeštug[ear]n',
#    'gub[stand]v/i'],
#   ['diŋir[deity]n',
#    'an[sky]n',
#    'gal[big]v/i',
#    'ki[place]n_gal[big]v/i',
#    'ŋeštug[ear]n',
#    'gub[stand]v/i'],
#   ['inanak[1]dn',
#    'an[sky]n',
#    'gal[big]v/i',
#    'ki[place]n_gal[big]v/i',
#    'ŋeštug[ear]n',
#    'gub[stand]v/i'],
#   ['nin[lady]n',
#    'an[sky]n',
#    'šub[fall]v/t',
#    'ki[place]n_šub[fall]v/t',
#    'kur[mountain]n',
#    'ed[ascend]v/i'],
#   ['inanak[1]dn',
#    'an[sky]n',
#    'šub[fall]v/t',
#    'ki[place]n_šub[fall]v/t',
#    'kur[mountain]n',
#    'ed[ascend]v/i'],
#   ['me[being]n', 'ur[pluck]v/t', 'šu[hand]n_la[hang]v/t'],
#   ['šugura[turban]n', 'men[tiara]n', 'eden[back]n', 'saŋ[head]n_ŋal[be]v/i'],
#   ['hili[attractiveness]n', 'saŋki[forehead]n', 'šu[hand]n_teŋ[approach]v/i'],
#   ['zagin[lapis]n', 'didila[smaller]v/i', 'gu[neck]n_la[hang]v/t'],
#   ['nunuz[egg]n_tab[double]v/t', 'gaba[chest]n', 'si[fill]v/t'],
#   ['šembizida[kohl]n',
#    'lu[person]n',
#    'ŋen[go]v/i',
#    'ŋen[go]v/i',
#    'igi[eye]n_ŋar[place]v/t'],
#   ['har[ring]n_kugsig[gold]n', 'šu[hand]n', 'du[spread]v/t'],
#   ['sukkal[secretary]n_ninšubur[1]dn', 'egir[back]n', 'ŋen[go]v/i'],
#   ['kug[pure]v/i', 'inanak[1]dn', 'ninšubur[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['inim[word]n_dug[speak]v/t', 'ŋizzal[ear]n_ak[do]v/t'],
#   ['inim[word]n_dug[speak]v/t', 'ŋizzal[ear]n_ak[do]v/t'],
#   ['e[house]n_diŋir[deity]n', 'niŋin[encircle]v/t'],
#   ['ŋeštug[ear]n',
#    'ki[place]n',
#    'u[admiration]n_dug[speak]v/t',
#    'hur[scratch]v/t'],
#   ['zagin[lapis]n_sag[good]v/i',
#    'za[bead]n',
#    'zadim[stone-cutter]n',
#    'sil[split]v/i'],
#   ['zagin[lapis]n_sag[good]v/i',
#    'za[bead]n',
#    'zadim[stone-cutter]n',
#    'sil[split]v/i'],
#   ['zagin[lapis]n_sag[good]v/i',
#    'za[bead]n',
#    'zadim[stone-cutter]n',
#    'sil[split]v/i'],
#   ['u[grass]n_namtil[life]n',
#    'zu[know]v/t',
#    'a[water]n',
#    'namtil[life]n',
#    'zu[know]v/t'],
#   ['sukkal[secretary]n_ninšubur[1]dn', 'egir[back]n', 'ŋen[go]v/i'],
#   ['sukkal[secretary]n_ninšubur[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['sukkal[secretary]n_ninšubur[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['ŋen[go]v/i', 'ninšubur[1]dn', 'saŋ[head]n_kešed[bind]v/t', 'ak[do]v/t'],
#   ['eneŋ[word]n', 'dug[speak]v/t', 'gu[neck]n_šub[fall]v/t'],
#   ['e[house]n', 'ŋal[open]v/t', 'idu[doorkeeper]n_e[house]n', 'ŋal[open]v/t'],
#   ['neti[1]dn', 'idu[doorkeeper]n_gal[big]v/i', 'kur[mountain]n'],
#   ['kug[pure]v/i', 'inanak[1]dn', 'inim[word]n_gi[turn]v/i'],
#   ['nin[sister]n_gal[big]v/i', 'kug[pure]v/i', 'ereškigalak[1]dn'],
#   ['kaš[beer]n',
#    'kisiga[offerings]n',
#    'gal[big]v/i',
#    'de[pour]v/t',
#    'ur[he]ip_me[be]v/i'],
#   ['neti[1]dn', 'idu[doorkeeper]n_gal[big]v/i', 'kur[mountain]n'],
#   ['nin[lady]n',
#    'ereškigalak[1]dn',
#    'dug[speak]v/t',
#    'inim[word]n_dug[speak]v/t'],
#   ['neti[1]dn', 'idu[doorkeeper]n_gal[big]v/i', 'kur[mountain]n'],
#   ['e[house]n', 'kur[enter]v/i', 'gu[voice]n_de[pour]v/t'],
#   ['me[being]n', 'ur[pluck]v/t', 'šu[hand]n_la[hang]v/t'],
#   ['šugura[turban]n', 'men[tiara]n', 'eden[back]n', 'saŋ[head]n_ŋal[be]v/i'],
#   ['hili[attractiveness]n', 'saŋki[forehead]n', 'šu[hand]n_teŋ[approach]v/i'],
#   ['zagin[lapis]n', 'didila[smaller]v/i', 'gu[neck]n_la[hang]v/t'],
#   ['nunuz[egg]n_tab[double]v/t', 'gaba[chest]n', 'si[fill]v/t'],
#   ['šembizida[kohl]n', 'lu[person]n', 'ŋen[go]v/i', 'igi[eye]n_ŋar[place]v/t'],
#   ['har[ring]n_kugsig[gold]n', 'šu[hand]n_la[hang]v/t'],
#   ['har[ring]n_kugsig[gold]n', 'šu[hand]n_la[hang]v/t'],
#   ['neti[1]dn', 'idu[doorkeeper]n_gal[big]v/i', 'gu[voice]n_de[pour]v/t'],
#   ['neti[1]dn', 'idu[doorkeeper]n_gal[big]v/i', 'gu[voice]n_de[pour]v/t'],
#   ['ŋen[go]v/i',
#    'neti[1]dn',
#    'idu[doorkeeper]n_gal[big]v/i',
#    'kur[mountain]n'],
#   ['inim[word]n_dug[speak]v/t', 'gu[neck]n_šub[fall]v/t'],
#   ['inim[word]n_dug[speak]v/t', 'gu[neck]n_šub[fall]v/t'],
#   ['egal[palace]n',
#    'ganzer[1]gn',
#    'dili[single]v/i',
#    'ig[door]n',
#    'šu[hand]n_us[follow]v/t'],
#   ['neti[1]dn', 'idu[doorkeeper]n_gal[big]v/i', 'kur[mountain]n'],
#   ['inim[word]n', 'nin[lady]n', 'saŋ[head]n_kešed[bind]v/t', 'ak[do]v/t'],
#   ['egal[palace]n',
#    'ganzer[1]gn',
#    'dili[single]v/i',
#    'ig[door]n',
#    'šu[hand]n_us[follow]v/t'],
#   ['kug[pure]v/i', 'inanak[1]dn', 'gu[voice]n_de[pour]v/t'],
#   ['sig[silent]n',
#    'inanak[1]dn',
#    'me[being]n',
#    'kur[mountain]n',
#    'šu[hand]n_du[push]v/t'],
#   ['sig[silent]n',
#    'inanak[1]dn',
#    'me[being]n',
#    'kur[mountain]n',
#    'šu[hand]n_du[push]v/t'],
#   ['nunuz[egg]n_tab[double]v/t',
#    'gaba[chest]n',
#    'lu[person]n',
#    'zir[break]v/t'],
#   ['sig[silent]n',
#    'inanak[1]dn',
#    'me[being]n',
#    'kur[mountain]n',
#    'šu[hand]n_du[push]v/t'],
#   ['sig[silent]n',
#    'inanak[1]dn',
#    'me[being]n',
#    'kur[mountain]n',
#    'šu[hand]n_du[push]v/t'],
#   ['har[ring]n_kugsig[gold]n', 'šu[hand]n', 'lu[person]n', 'zir[break]v/t'],
#   ['sig[silent]n',
#    'inanak[1]dn',
#    'me[being]n',
#    'kur[mountain]n',
#    'šu[hand]n_du[push]v/t'],
#   ['sig[silent]n',
#    'inanak[1]dn',
#    'me[being]n',
#    'kur[mountain]n',
#    'šu[hand]n_du[push]v/t'],
#   ['sig[silent]n',
#    'inanak[1]dn',
#    'me[being]n',
#    'kur[mountain]n',
#    'šu[hand]n_du[push]v/t'],
#   ['anunak[1]dn',
#    'dikud[judge]n',
#    '7[7]nu',
#    'igi[eye]n',
#    'did[lawsuit]n_kud[cut]v/t'],
#   ['inim[word]n_dug[speak]v/t',
#    'inim[word]n',
#    'lipiš[innards]n',
#    'gig[sick]v/i'],
#   ['gu[voice]n_de[pour]v/t', 'gu[voice]n', 'namtaga[sin]n'],
#   ['sukkal[secretary]n_ninšubur[1]dn'],
#   ['sukkal[secretary]n', 'inim[word]n_sag[good]v/i'],
#   ['ragaba[rider]n', 'inim[word]n_gin[firm]v/i'],
#   ['inim[word]n_dug[speak]v/t', 'gu[neck]n_šub[fall]v/t'],
#   ['inim[word]n_dug[speak]v/t', 'gu[neck]n_šub[fall]v/t'],
#   ['e[house]n_diŋir[deity]n', 'niŋin[encircle]v/t'],
#   ['ki[place]n_lu[person]n',
#    'dug[speak]v/t',
#    'hašgal[thigh]n',
#    'hur[scratch]v/t'],
#   ['zagin[lapis]n_sag[good]v/i',
#    'za[bead]n',
#    'zadim[stone-cutter]n',
#    'sil[split]v/i'],
#   ['dumu[child]n',
#    'an[sky]n',
#    'gal[big]v/i',
#    'al[hoe]n',
#    'dug[speak]v/t',
#    'ki[place]n_gal[big]v/i',
#    'al[hoe]n',
#    'dug[speak]v/t'],
#   ['inanak[1]dn',
#    'an[sky]n',
#    'gal[big]v/i',
#    'al[hoe]n',
#    'dug[speak]v/t',
#    'ki[place]n_gal[big]v/i',
#    'al[hoe]n',
#    'dug[speak]v/t'],
#   ['me[being]n',
#    'kur[mountain]n',
#    'me[being]n',
#    'al[hoe]n',
#    'dug[speak]v/t',
#    'sa[equal]v/t_dug[speak]v/t',
#    'kur[mountain]n',
#    'us[follow]v/t'],
#   ['aba[who?]qp',
#    'ki[place]n',
#    'sa[equal]v/t_dug[speak]v/t',
#    'ed[ascend]v/i',
#    'al[hoe]n',
#    'dug[speak]v/t'],
#   ['zagin[lapis]n_sag[good]v/i',
#    'za[bead]n',
#    'zadim[stone-cutter]n',
#    'sil[split]v/i'],
#   ['dumu[child]n',
#    'an[sky]n',
#    'gal[big]v/i',
#    'al[hoe]n',
#    'dug[speak]v/t',
#    'ki[place]n_gal[big]v/i',
#    'al[hoe]n',
#    'dug[speak]v/t'],
#   ['inanak[1]dn',
#    'an[sky]n',
#    'gal[big]v/i',
#    'al[hoe]n',
#    'dug[speak]v/t',
#    'ki[place]n_gal[big]v/i',
#    'al[hoe]n',
#    'dug[speak]v/t'],
#   ['me[being]n',
#    'kur[mountain]n',
#    'me[being]n',
#    'al[hoe]n',
#    'dug[speak]v/t',
#    'sa[equal]v/t_dug[speak]v/t',
#    'kur[mountain]n',
#    'us[follow]v/t'],
#   ['aba[who?]qp',
#    'ki[place]n',
#    'sa[equal]v/t_dug[speak]v/t',
#    'ed[ascend]v/i',
#    'al[hoe]n',
#    'dug[speak]v/t'],
#   ['zagin[lapis]n_sag[good]v/i',
#    'za[bead]n',
#    'zadim[stone-cutter]n',
#    'sil[split]v/i'],
#   ['dumu[child]n', 'ana[what?]qp_ak[do]v/t', 'ŋaʾe[i]ip', 'kušu[tired]v/i'],
#   ['inanak[1]dn', 'ana[what?]qp_ak[do]v/t', 'ŋaʾe[i]ip', 'kušu[tired]v/i'],
#   ['nin[lady]n',
#    'kur[mountain]n',
#    'ana[what?]qp_ak[do]v/t',
#    'ŋaʾe[i]ip',
#    'kušu[tired]v/i'],
#   ['nugig[priestess]n_an[sky]n',
#    'ana[what?]qp_ak[do]v/t',
#    'ŋaʾe[i]ip',
#    'kušu[tired]v/i'],
#   ['nugig[priestess]n_an[sky]n',
#    'ana[what?]qp_ak[do]v/t',
#    'ŋaʾe[i]ip',
#    'kušu[tired]v/i'],
#   ['kurŋara[performer]n', 'u[grass]n_namtil[life]n', 'šum[give]v/t'],
#   ['aya[father]n',
#    'enki[1]dn',
#    'galatura[performer]n',
#    'kurŋara[performer]n',
#    'gu[voice]n_de[pour]v/t'],
#   ['1[1]nu',
#    'u[grass]n_namtil[life]n',
#    '1[1]nu',
#    'a[water]n',
#    'namtil[life]n',
#    'ugu[skull]n',
#    'šub[fall]v/t'],
#   ['diŋir[deity]n', 'me[be]v/i', 'inim[word]n_dug[speak]v/t'],
#   ['a[water]n_id[river]n', 'ba[allot]v/t', 'šu[hand]n_gid[long]v/i'],
#   ['a[water]n_id[river]n', 'ba[allot]v/t', 'šu[hand]n_gid[long]v/i'],
#   ['ašag[field]n', 'še[barley]n', 'ba[allot]v/t', 'šu[hand]n_gid[long]v/i'],
#   ['niŋ[thing]n_lugal[king]n',
#    'me[be]v/i',
#    'niŋ[thing]n',
#    'nin[lady]n',
#    'me[be]v/i',
#    'šum[give]v/t',
#    'dug[speak]v/t'],
#   ['1[1]nu',
#    'u[grass]n_namtil[life]n',
#    '1[1]nu',
#    'a[water]n',
#    'namtil[life]n',
#    'ugu[skull]n',
#    'šub[fall]v/t'],
#   ['galatura[performer]n',
#    'kurŋara[performer]n',
#    'inim[word]n',
#    'enki[1]dn',
#    'saŋ[head]n_kešed[bind]v/t',
#    'ak[do]v/t'],
#   ['diŋir[deity]n', 'me[be]v/i', 'inim[word]n_dug[speak]v/t'],
#   ['id[river]n', 'a[water]n', 'ba[allot]v/t', 'šu[hand]n_gid[long]v/i'],
#   ['ašag[field]n', 'še[barley]n', 'ba[allot]v/t', 'šu[hand]n_gid[long]v/i'],
#   ['niŋ[thing]n_lugal[king]n',
#    'niŋ[thing]n',
#    'aŋ[thing]n',
#    'nin[lady]n',
#    'me[be]v/i',
#    'šum[give]v/t',
#    'dug[speak]v/t'],
#   ['1[1]nu',
#    'u[grass]n_namtil[life]n',
#    '1[1]nu',
#    'a[water]n',
#    'namtil[life]n',
#    'ugu[skull]n',
#    'šub[fall]v/t'],
#   ['ereškigalak[1]dn',
#    'galatura[performer]n',
#    'kurŋara[performer]n',
#    'gu[voice]n_de[pour]v/t'],
#   ['saŋdili[lone]aj', 'saŋ[head]n_šum[give]v/t'],
#   ['bar[outside]v/t',
#    'ragaba[rider]n',
#    'me[be]v/i',
#    'tukul[weapon]n_ur[root]n',
#    'la[hang]v/t'],
#   ['galla[policeman]n_tur[small]v/i', 'gišukur[enclosure]n'],
#   ['galla[policeman]n_gal[big]v/i',
#    'gi[reed]n',
#    'dubban[fence]n',
#    'zag[side]n',
#    'dab[seize]v/t'],
#   ['a[water]n_bala[turn]v/t', 'naŋ[drink]v/t'],
#   ['kadra[gift]n', 'niŋ[thing]n_dug[good]v/i', 'šu[hand]n_gid[long]v/i'],
#   ['kadra[gift]n', 'niŋ[thing]n_dug[good]v/i', 'šu[hand]n_gid[long]v/i'],
#   ['ur[root]n', 'dam[spouse]n', 'niŋ[thing]n_dug[good]v/i', 'sig[put]v/t'],
#   ['ur[root]n', 'lu[person]n', 'dam[spouse]n', 'šu[hand]n_teŋ[approach]v/i'],
#   ['ubur[breast]n',
#    'emeda[nursemaid]n',
#    'la[hang]v/t',
#    'dumu[child]n',
#    'šu[hand]n_teŋ[approach]v/i'],
#   ['galla[policeman]n',
#    'kug[pure]v/i',
#    'inanak[1]dn',
#    'gu[voice]n_de[pour]v/t'],
#   ['eneŋ[word]n', 'dug[speak]v/t', 'gu[neck]n_šub[fall]v/t'],
#   ['e[house]n_diŋir[deity]n', 'niŋin[encircle]v/t'],
#   ['ŋeštug[ear]n',
#    'ki[place]n',
#    'u[admiration]n_dug[speak]v/t',
#    'hur[scratch]v/t'],
#   ['galla[policeman]n',
#    'kug[pure]v/i',
#    'inanak[1]dn',
#    'gu[voice]n_de[pour]v/t'],
#   ['umbin[nail]n_kud[cut]v/t', 'guhaš[nape]n', 'la[hang]v/t'],
#   ['galla[policeman]n',
#    'kug[pure]v/i',
#    'inanak[1]dn',
#    'gu[voice]n_de[pour]v/t'],
#   ['lulal[1]dn',
#    'zag[side]n',
#    'e[leave]v/i',
#    'a[arm]n_zid[right]v/i',
#    'gab[left]n',
#    'us[follow]v/t'],
#   ['dumuzid[1]dn',
#    'tug[textile]n_mah[great]v/i',
#    'mur[dress]v/t',
#    'mah[great]v/i',
#    'dur[buttocks]n',
#    'dur[buttocks]n',
#    'ŋar[place]v/t'],
#   ['7[7]nu', 'x[na]na', 'saŋ[head]n_sag[beat]v/t'],
#   ['sipad[shepherd]n',
#    'gigid[reed]n',
#    'gidešta[loaf]n',
#    'igi[eye]n',
#    'šu[hand]n_tag[touch]v/t'],
#   ['inim[word]n_dug[speak]v/t',
#    'inim[word]n',
#    'lipiš[innards]n',
#    'gig[sick]v/i'],
#   ...],
#  10043)

# %%
s1 = [n.split() for n in s]
s1

# %%
tokenizer.tokenize_sents(s1)

# %%
etcsl_t = etcsl[["lemma", "id_text", "id_line"]]

# %%
etcsl_t = etcsl_t[10000:10100]

# %%
etcsl_t_g = etcsl_t.groupby([etcsl_t["id_text"], etcsl_t["id_line"]]).agg({"lemma": list})

# %%
etcsl_t_g["lemma"][1]

# %%
etcsl_lines = list(etcsl_t_g["lemma"])

# %%
tokenizer.tokenize_sents(etcsl_lines)

# %%
lexical
# Out:
#               id_text  id_line                                     lemma
# 0       dcclt/P000723        4                            (x-bad[na]na,)
# 1       dcclt/P000723        5                        (x-|en+ib|[na]na,)
# 2       dcclt/P000723        7                      (gada-sukkal[na]na,)
# 3       dcclt/P000723        8                           (gal-ga[na]na,)
# 4       dcclt/P000723        9                       (tug₂-gara₂[na]na,)
# 5       dcclt/P000723       12                       (gal-ŋišgal[na]na,)
# 6       dcclt/P000723       13                  (gal-|ga₂×di.me|[na]na,)
# 7       dcclt/P000723       14         (saŋŋa[na]na, |ga₂×gar.me|[na]na)
# 8       dcclt/P000723       15                  (x[na]na, |ga₂×x|[na]na)
# 9       dcclt/P000724        5                          (x-suhur[na]na,)
# 10      dcclt/P000724        6               (1(n01)[na]na, suhur[na]na)
# 11      dcclt/P000724        7                (1(n01)[na]na, ni-x[na]na)
# 12      dcclt/P000724        8           (1(n01)[na]na, pap-zubud[na]na)
# 13      dcclt/P000724        9            (1(n01)[na]na, hi-zubud[na]na)
# 14      dcclt/P000724       10         (1(n01)[na]na, gam-gam-ku₆[na]na)
# 15      dcclt/P000724       11           (1(n01)[na]na, nun-sumaš[na]na)
# 16      dcclt/P000724       12               (1(n01)[na]na, utuwa[na]na)
# 17      dcclt/P000724       13              (1(n01)[na]na, ud-ku₆[na]na)
# 18      dcclt/P000724       14               (1(n01)[na]na, suhur[na]na)
# 19      dcclt/P000724       15            (1(n01)[na]na, ab-suhur[na]na)
# 20      dcclt/P000724       16               (1(n01)[na]na, izi-x[na]na)
# 21      dcclt/P000724       17                              (x-x[na]na,)
# 22      dcclt/P000724       18                  (1(n01)[na]na, uš[na]na)
# 23      dcclt/P000724       19            (1(n01)[na]na, lak025-x[na]na)
# 24      dcclt/P000724       20             (1(n01)[na]na, ab₂-ku₆[na]na)
# 25      dcclt/P000724       21                (1(n01)[na]na, hi-x[na]na)
# 26      dcclt/P000724       24            (1(n01)[na]na, dur₂-ku₆[na]na)
# 27      dcclt/P000724       25           (1(n01)[na]na, sumaš-ku₆[na]na)
# 28      dcclt/P000724       26        (1(n01)[na]na, agargara-ku₆[na]na)
# 29      dcclt/P000724       27  (1(n01)[na]na, agargara-sila₃-ku₆[na]na)
# ...               ...      ...                                       ...
# 128436  dcclt/X999902       30                                (x[na]na,)
# 128437  dcclt/X999902       31                                (x[na]na,)
# 128438  dcclt/X999902       32                                (x[na]na,)
# 128439  dcclt/X999902       33                                (x[na]na,)
# 128440  dcclt/X999902       34                                (x[na]na,)
# 128441  dcclt/X999902       35                                (x[na]na,)
# 128442  dcclt/X999902       36                                (x[na]na,)
# 128443  dcclt/X999902       39                                (x[na]na,)
# 128444  dcclt/X999902       40                                (x[na]na,)
# 128445  dcclt/X999902       41                                (x[na]na,)
# 128446  dcclt/X999902       42                                (x[na]na,)
# 128447  dcclt/X999902       44                             (x-di[na]na,)
# 128448  dcclt/X999902       46                          (šakir[churn]n,)
# 128449  dcclt/X999902       48                              (muš[pot]n,)
# 128450  dcclt/X999902       49                 (ugur[a-pot]n, igi[eye]n)
# 128451  dcclt/X999902       50               (ugur[pot]n, bala[turn]v/t)
# 128452  dcclt/X999902       52                (dug[pot]n, alusa[sauce]n)
# 128453  dcclt/X999902       54               (dug[pot]n, sikil[pure]v/i)
# 128454  dcclt/X999902       56                    (namtar[(a-vessel)]n,)
# 128455  dcclt/X999902       57                    (namtar[(a-vessel)]n,)
# 128456  dcclt/X999902       59                    (niŋgula[greatness]n,)
# 128457  dcclt/X999902       60                           (x-gir₂[na]na,)
# 128458  dcclt/X999902       61                              (x-x[na]na,)
# 128459  dcclt/X999902       62                                (x[na]na,)
# 128460  dcclt/X999902       63                                (x[na]na,)
# 128461  dcclt/X999902       64                                (x[na]na,)
# 128462  dcclt/X999902       65                                (x[na]na,)
# 128463  dcclt/X999903        6                                (x[na]na,)
# 128464  dcclt/X999903        8                                (x[na]na,)
# 128465  dcclt/X999903       10                         (murgu[fodder]n,)
#
# [128466 rows x 3 columns]

# %%
t = ('kinkin[millstone]n', 'zu[tooth]n')
len(t)
# Out:
# 2
