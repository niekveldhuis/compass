# %%
from gensim.models import word2vec

# %%
sentences = word2vec.LineSentence('corpus/sux_tl.txt')

# %%
model = word2vec.Word2Vec(sentences, size=100, window=10, 
                              min_count=3, sg=1, alpha=0.025, iter=5, batch_words=10000, workers=1)

# %%
word_vectors = model.wv
with open("model/sux_tl.kv", "wb") as f:
    word_vectors.save(f)

# %%
model.wv["lugal"]
# Out:
# array([-0.42277387,  0.02677708, -0.12948595, -0.40145618,  0.06159069,
#        -0.01010768,  0.34222826,  0.12557411,  0.41016358, -0.39648014,
#         0.44648564,  0.13757084, -0.43717498,  0.35518134,  0.23975916,
#        -0.3797434 , -0.47232625, -0.3049542 ,  0.08290121, -0.15356171,
#         0.46428886,  0.36940178, -0.5148245 ,  0.2969187 ,  0.40283233,
#         0.14745793,  0.13319467, -0.28634748, -0.52759796,  0.24494997,
#         0.31786048, -0.30766067,  0.23845218, -0.38892758,  0.0826975 ,
#         0.08610701,  0.3307305 ,  0.3478293 , -0.42989308, -0.13650645,
#        -0.50183165,  0.04304333, -0.11311384, -0.09554435,  0.462936  ,
#        -0.15806401,  0.08818446, -0.04785216, -0.15550032,  0.09102593,
#        -0.27437204, -0.01982333,  0.15559271,  0.05975699, -0.03979497,
#        -0.27699107, -0.08440998, -0.08783837,  0.24693617,  0.3299241 ,
#        -0.24117397,  0.17646216, -0.19010991, -0.351185  , -0.26070634,
# ...

# %%
from gensim.models import KeyedVectors
kv = KeyedVectors.load("model/sux_tl.kv", mmap='r')

# %%
kv.similarity("lugal", "ereš")
# Out:
# /Users/veldhuis/anaconda3/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.4293726

# %%
model.most_similar("bar-ba-zi-ga")
# Out:
# /Users/veldhuis/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /Users/veldhuis/anaconda3/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('u₄-sakar-gu-la', 0.9134755730628967),
#  ('gu₂-gu₂-mu-e₃', 0.895728349685669),
#  ('{d}kar-ra-du', 0.8846389055252075),
#  ('nig₂-{geš}tag-ga', 0.8791233897209167),
#  ('u₄-nu₂-a', 0.8702421188354492),
#  ('geš-du₃-a', 0.8554140329360962),
#  ('geš-tag-ga-da', 0.8553940057754517),
#  ('{d}e₂-sag-kal-la', 0.8533855676651001),
#  ('{geš}gešbun₂', 0.851348876953125),
#  ('{d}pa-bil₂-sag', 0.8486034274101257)]

# %%
wild_animals = [
    "ur-mah", 
    "ur-bar-ra", 
    "az", 
    "ur", 
    "peš₂", 
    "ZUBUD", 
    "alim", 
    "maš-da₃", 
    "muš", 
    "šeg₉", 
    "šeg₉-bar", 
    "dara₄",
    "lulim", 
    "am", 
    "šah₂"]
dom_animals = [
    "udu", 
    "sila₄", 
    "u₈", 
    "kir₁₁", 
    "uz₃", 
    "maš₂", 
    "maš₂-gal", 
    "gu₄", 
    "ab₂", 
    "amar", 
    "anše", 
    "eme₅", 
    "dur₃"] 
animals = wild_animals.copy()
animals.extend(dom_animals)

# %%
close_to_animals = kv.most_similar(dom_animals, topn=50)
# Out:
# /Users/veldhuis/anaconda3/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
an = [a[0] for a in close_to_animals]

# %%
animals.extend(an)

# %%
animals
# Out:
# ['ur-mah',
#  'ur-bar-ra',
#  'az',
#  'ur',
#  'peš₂',
#  'ZUBUD',
#  'alim',
#  'maš-da₃',
#  'muš',
#  'šeg₉',
#  'šeg₉-bar',
#  'dara₄',
#  'lulim',
#  'am',
#  'šah₂',
#  'udu',
#  'sila₄',
#  'u₈',
#  'kir₁₁',
#  'uz₃',
#  'maš₂',
#  'maš₂-gal',
#  'gu₄',
#  'ab₂',
#  'amar',
#  'anše',
#  'eme₅',
#  'dur₃',
#  'dingir-ra-bi₂-ta',
#  'isin₂{si}{ki}-me',
#  'i-tu-ru-um-ta',
#  'šu-gu₄',
#  'e-la-ak-šu-qir-ta',
#  'ur₂-limmu₂',
#  'ur-{d}nin-da-ta',
#  '{d}inanna-ur-sag-ta',
#  'DI-su₃',
#  'lulim-munus',
#  'za-a-num₂-ta',
#  'šu-da-da-ta',
#  'e₂-gibil₄-ta',
#  'qa₂-qa₂-ad',
#  'ud₅',
#  'maš-gal',
#  'sila₄-x',
#  'ma₂-nesag',
#  'dingir-dan-ta',
#  'e₂-tur₃-še₃',
#  'kir₁₁-gub',
#  '{d}šara₂-ke₄-ne-ta',
#  'maš₂-x',
#  'wa-ta₂-ru-um-ta',
#  'hu-un-gu-ur₂-bi-ta',
#  'anše-edin-na-nita₂',
#  'nu-uk-ra-nu-um',
#  '{munus}aš₂-gar₃',
#  'nam-en-na-ke₄-ne-ta',
#  'lugal-KU-ta',
#  'šag₄-sur',
#  'hi-ir',
#  '{d}nin-gubalag-ta',
#  'i-din-e₂-a-ta',
#  'ma-at-i₃-li₂-ta',
# ...

# %%
x = [kv.similarity('az', word) for word in animals]
y = [kv.similarity('udu', word) for word in animals]
# Out:
# /Users/veldhuis/anaconda3/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
#Visualization parameters
# %pylab inline
matplotlib.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib
matplotlib.font_manager._rebuild()
rcParams['font.family'] = 'sans-serif'
rcParams['font.weight'] = 'bold'                  # you can omit this, it's the default
rcParams['font.size'] = '12'
rcParams['font.sans-serif'] = ['DejaVu Sans']
_, ax = plt.subplots(figsize=(20,20))
ax.scatter(x, y, alpha=1, color='b')
for i in range(len(animals)):
    ax.annotate(animals[i], (x[i], y[i]))
#ax.set_xlim(.25, 1.1)
#ax.set_ylim(.4, 1.1)
plt.plot([0, 1], [0, 1], linestyle='--');

# %%
"az" in animals
# Out:
# True

# %%
kv.similarity("udu", "az")
# Out:
# /Users/veldhuis/anaconda3/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.29903477
