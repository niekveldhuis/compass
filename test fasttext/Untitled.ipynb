# %%
import pickle
import fastText

# %%
with open("ogsl.p", "rb") as p:
    ogsl_df = pickle.load(p)

# %%
ogsl_df
# Out:
#                  hex                          name utf8    value
# 0             x12000                             A    𒀀      ʾu₄
# 1             x12000                             A    𒀀        a
# 2             x12000                             A    𒀀     aia₂
# 3             x12000                             A    𒀀     aya₂
# 4             x12000                             A    𒀀     barₓ
# 5             x12000                             A    𒀀   buniŋₓ
# 6             x12000                             A    𒀀     burₓ
# 7             x12000                             A    𒀀     dur₅
# 8             x12000                             A    𒀀    duru₅
# 9             x12000                             A    𒀀       e₄
# 10            x12000                             A    𒀀       ea
# 11            x12000                             A    𒀀    ebir₃
# 12            x12000                             A    𒀀      emₓ
# ...
