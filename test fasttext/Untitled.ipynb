# %%
import pickle
import fasttext
import pandas as pd

# %%
with open("ogsl.p", "rb") as p:
    ogsl_df = pickle.load(p)

# %%
no_utf8 = ogsl_df[ogsl_df["utf8"]==""]

# %%
s_names = list(no_utf8["name"])

# %%
s_names_2 = []
for name in s_names:
    name = name.replace("|", "")
    names = name.split(".")
    s_names_2.append(names)

# %%
temp_l = []
for entry in s_names_2: 
    hex_ = ""
    utf8 = ""
    for name in entry: 
        if name in list(ogsl_df["name"].replace("\|", "", regex=True)): 
            idx = ogsl_df.index[ogsl_df["name"].replace("\|", "", regex=True)==name][0]
            hex_ = hex_ + "." + ogsl_df.iloc[idx]["hex"]
            utf8 = utf8 + ogsl_df.iloc[idx]["utf8"]
        else: 
            hex_ = hex_ + ".None"
            utf8 = utf8 + ".None"
        l = [entry, hex_, utf8]
    temp_l.append(l)

# %%
temp_l
# Out:
# [[['PA', 'DAG', 'KISIM₅×(LU', 'MAŠ₂)'],
#   '.x1227A.x12056.None.None',
#   '𒉺𒁖.None.None'],
#  [['PA', 'DAG', 'KISIM₅×(LU', 'MAŠ₂)'],
#   '.x1227A.x12056.None.None',
#   '𒉺𒁖.None.None'],
#  [['PA', 'DAG', 'KISIM₅×(LU', 'MAŠ₂)'],
#   '.x1227A.x12056.None.None',
#   '𒉺𒁖.None.None'],
#  [['TAB', 'GAR', 'ŠE'], '.x122F0.x120FB.x122BA', '𒋰𒃻𒊺'],
#  [['MUŠ', 'DIN', 'ŠE', 'NUN&NUN', 'BALAG'],
#   '.x12232.x12077.x122BA.x1226A.x12046',
#   '𒈲𒁷𒊺𒉪𒁆'],
#  [['GI×TAK₄'], '.', ''],
#  [['AB₂', 'AN', 'ŠEŠ', 'KI'], '.x12016.x1202D.x122C0.x121A0', '𒀖𒀭𒋀𒆠'],
#  [['NINDA₂×GI', 'IDIM'], '.None.x12142', '.None𒅂'],
#  [['ME', 'AD', 'KU₃'], '.x12228.x1201C.x121AC', '𒈨𒀜𒆬'],
#  [['AB₂', 'ŠA₃', 'GI'], '.x12016.x122AE.x12100', '𒀖𒊮𒄀'],
#  [['GA₂×(A', 'EN)'], '.None.None', '.None.None'],
#  [['UR₂×GAN₂@t'], '.', ''],
#  [['URU×(MIN', 'GA)'], '.None.None', '.None.None'],
#  [['OO'], '.xA0.xA0', ''],
#  [['ZAX'], '.', ''],
#  [['IGI@g', 'IGI@g'], '.x1214A.x1214A', '𒅊𒅊'],
#  [['AB₂', 'TUG₂'], '.x12016.x12306', '𒀖𒌆'],
#  [['TAK₄', 'IM'], '.x122FA.x1214E', '𒋺𒅎'],
#  [['LUL', 'E₂', 'BALAG'], '.x1221C.x1208D.x12046', '𒈜𒂍𒁆'],
#  [['IM&IM'], '.', ''],
#  [['IM&IM'], '.', ''],
#  [['IM&IM'], '.', ''],
#  [['UR@180'], '.', ''],
#  [['ERIN₂', 'NUN', 'NA'], '.x1209F.x12263.x1223E', '𒂟𒉣𒈾'],
#  [['E₂×BAD'], '.', ''],
#  [['E₂×BAD'], '.', ''],
#  [['E₂×BAD'], '.', ''],
#  [['KASKAL&KASKAL', 'LAGAB&LAGAB'], '.None.None', '.None.None'],
#  [['KASKAL&KASKAL', 'LAGAB&LAGAB'], '.None.None', '.None.None'],
#  [['LAK212'], '.', ''],
#  [['PAP', 'NUN', 'ME', 'EZEN'], '.x1227D.x12263.x12228.x120A1', '𒉽𒉣𒈨𒂡'],
#  [['5(U)@v'], '.', ''],
#  [['SIG₄', 'ANŠE'], '.x122DE.x12032', '𒋞𒀲'],
#  [['GAD+DIŠ×A'], '.', ''],
#  [['EN', 'DAG', 'NUN', 'X'], '.x12097.x12056.x12263.X', '𒂗𒁖𒉣X'],
#  [['NUNUZ', 'KISIM₅×AŠGAB'], '.x1226D.None', '𒉭.None'],
#  [['AŠ₂', 'U&U'], '.x1203E.None', '𒀾.None'],
#  [['KA×HI×AŠ₂'], '.', ''],
#  [['EZEN×ŠE'], '.', ''],
#  [['TAB@t'], '.', ''],
#  [['TAB@t'], '.', ''],
#  [['KAP₀'], '.', ''],
#  [['KA×GU'], '.', ''],
#  [['KA×(ME', 'GAR)'], '.None.None', '.None.None'],
#  [['LAK589', 'PAD', 'SI'], '.None.x1227B.x122DB', '.None𒉻𒋛'],
#  [['IŠ', 'UD', 'KA', 'BAR'], '.x12156.x12313.x12157.x12047', '𒅖𒌓𒅗𒁇'],
#  [['UR×AL'], '.', ''],
#  [['UZ₃×BALAG'], '.', ''],
#  [['GAR', 'SAG', 'LAL', 'SAL'], '.x120FB.x12295.x121F2.x122A9', '𒃻𒊕𒇲𒊩'],
#  [['NINDA₂×BAL'], '.', ''],
#  [['GA₂×(SILA₃', 'ME)'], '.None.None', '.None.None'],
#  [['GUD×BAD'], '.', ''],
#  [['HI×(U', 'U)'], '.None.None', '.None.None'],
#  [['IM', 'SI'], '.x1214E.x122DB', '𒅎𒋛'],
#  [['EN', 'PAP', 'E', 'IGI@g', 'NUN', 'ME', 'EZEN×KASKAL'],
#   '.x12097.x1227D.x1208A.x1214A.x12263.x12228.x120AC',
#   '𒂗𒉽𒂊𒅊𒉣𒈨𒂬'],
#  [['HI×NUN', 'HI×NUN'], '.x12134.x12134', '𒄴𒄴'],
#  [['DAG', 'KISIM₅×U'], '.x12056.None', '𒁖.None'],
#  [['KA×(ŠU', 'X)'], '.None.None', '.None.None'],
#  [['GIŠ', 'TUG₂', 'PI', 'BU@t', 'NUN'],
#   '.x12111.x12306.x1227F.None.x12263',
#   '𒄑𒌆𒉿.None𒉣'],
#  [['NAM', 'EN', 'NA'], '.x12246.x12097.x1223E', '𒉆𒂗𒈾'],
#  [['KA×(KI', 'ŠU₂)'], '.None.None', '.None.None'],
#  [['AŠ₂', 'A'], '.x1203E.x12000', '𒀾𒀀'],
#  [['AŠ₂', 'A'], '.x1203E.x12000', '𒀾𒀀'],
#  [['UMUM×DUN₃@g'], '.', ''],
#  [['GE₂₂'], '.', ''],
#  [['GE₂₂'], '.', ''],
#  [['GE₂₂'], '.', ''],
#  [['GE₂₂'], '.', ''],
#  [['GE₂₂'], '.', ''],
#  [['GE₂₂'], '.', ''],
#  [['GE₂₂'], '.', ''],
#  [['GE₂₂'], '.', ''],
#  [['GE₂₂'], '.', ''],
#  [['GE₂₂'], '.', ''],
#  [['GE₂₂'], '.', ''],
#  [['GE₂₂'], '.', ''],
#  [['GE₂₂'], '.', ''],
#  [['LAGAR', 'IB'], '.x121EC.x12141', '𒇬𒅁'],
#  [['SAL', 'TUG₂', 'PAP', 'E', 'IGI@g', 'NUN', 'ME', 'EZEN×KASKAL'],
#   '.x122A9.x12306.x1227D.x1208A.x1214A.x12263.x12228.x120AC',
#   '𒊩𒌆𒉽𒂊𒅊𒉣𒈨𒂬'],
#  [['IGI', 'DUN'], '.x12146.x12084', '𒅆𒂄'],
#  [['KA×(ME', 'GAR', 'GAR', 'RA)'], '.None.x120FB.x120FB.None', '.None𒃻𒃻.None'],
#  [['LAK589', 'PAD', 'A', 'SI'], '.None.x1227B.x12000.x122DB', '.None𒉻𒀀𒋛'],
#  [['TAG×KU'], '.', ''],
#  [['TAG×KU'], '.', ''],
#  [['TAG×KU'], '.', ''],
#  [['TAG×KU'], '.', ''],
#  [['TAG×KU'], '.', ''],
#  [['E₂', 'BAR'], '.x1208D.x12047', '𒂍𒁇'],
#  [['AN', 'EN', 'NU', 'NUZ', 'NAM', 'AN', 'ŠEŠ', 'KI'],
#   '.x1202D.x12097.x12261.None.x12246.x1202D.x122C0.x121A0',
#   '𒀭𒂗𒉡.None𒉆𒀭𒋀𒆠'],
#  [['GI', 'KID', 'MAH'], '.x12100.x121A4.x12224', '𒄀𒆤𒈤'],
#  [['U', 'KIB'], '.x1230B.None', '𒌋.None'],
#  [['KWU822'], '.', ''],
#  [['DI', 'TAR'], '.x12072.x122FB', '𒁲𒋻'],
#  [['KA×(A', 'LA₂)'], '.None.None', '.None.None'],
#  [['SAG', 'LAL', 'SAL'], '.x12295.x121F2.x122A9', '𒊕𒇲𒊩'],
#  [['GAR', 'GAR'], '.x120FB.x120FB', '𒃻𒃻'],
#  [['UR₂×A'], '.', ''],
#  [['KA×X'], '.', ''],
#  [['KA×X'], '.', ''],
#  [['KA×X'], '.', ''],
#  [['4×NI'], '.', ''],
#  [['TUR&TUR', 'ZA&ZA', 'TUR&TUR', 'ZA&ZA'],
#   '.None.None.None.None',
#   '.None.None.None.None'],
#  [['TUR&TUR', 'ZA&ZA', 'TUR&TUR', 'ZA&ZA'],
#   '.None.None.None.None',
#   '.None.None.None.None'],
#  [['TUR&TUR', 'ZA&ZA', 'TUR&TUR', 'ZA&ZA'],
#   '.None.None.None.None',
#   '.None.None.None.None'],
#  [['TUR&TUR', 'ZA&ZA', 'TUR&TUR', 'ZA&ZA'],
#   '.None.None.None.None',
#   '.None.None.None.None'],
#  [['KUŠU₂', 'AN', 'MUŠ₃'], '.x121B5.x1202D.x12239', '𒆵𒀭𒈹'],
#  [['UD', 'MA₂', 'AB×(U', 'U', 'U)', 'ŠIR'],
#   '.x12313.x12223.None.x1230B.None.x122D3',
#   '𒌓𒈣.None𒌋.None𒋓'],
#  [['LU₂', 'KI'], '.x121FD.x121A0', '𒇽𒆠'],
#  [['GIŠ', 'MUŠ₃', 'SIK₂', 'LAM'], '.x12111.x12239.x122E0.x121F4', '𒄑𒈹𒋠𒇴'],
#  [['SAG@n@g'], '.', ''],
#  [['4(U)@v'], '.', ''],
#  [['TUG₂', 'PI', 'PI'], '.x12306.x1227F.x1227F', '𒌆𒉿𒉿'],
#  [['ŠU₂×(A', 'DIŠ)'], '.None.None', '.None.None'],
#  [['DIŠ@k'], '.', ''],
#  [['DIN', 'BI'], '.x12077.x12049', '𒁷𒁉'],
#  [['IGI@g', 'PAP'], '.x1214A.x1227D', '𒅊𒉽'],
#  [['ERIN₂@t'], '.', ''],
#  [['EZEN×ŠID'], '.', ''],
#  [['EŠ₂@t'], '.', ''],
#  [['EŠ₂@t'], '.', ''],
#  [['NINDA₂×(ŠE', 'A)'], '.None.None', '.None.None'],
#  [['NINDA₂×(ŠE', 'A)'], '.None.None', '.None.None'],
#  [['NINDA₂×(ŠE', 'A)'], '.None.None', '.None.None'],
#  [['LAK648×NI'], '.', ''],
#  [['GIŠ', 'UR₃'], '.x12111.None', '𒄑.None'],
#  [['KUR', 'ZA', 'KUR', 'ZI'], '.x121B3.x1235D.x121B3.x12363', '𒆳𒍝𒆳𒍣'],
#  [['4×GABA'], '.', ''],
#  [['A', 'BI'], '.x12000.x12049', '𒀀𒁉'],
#  [['MUŠ%MUŠ×MAŠ'], '.', ''],
#  [['AB₂×GAN₂'], '.', ''],
#  [['U', 'U', 'HUB₂'], '.x1230B.x1230B.x12138', '𒌋𒌋𒄸'],
#  [['N'], '.', ''],
#  [['N'], '.', ''],
#  [['N'], '.', ''],
#  [['ERIN₂', 'KAB'], '.x1209F.x1218F', '𒂟𒆏'],
#  [['KIB', 'NUN'], '.None.x12263', '.None𒉣'],
#  [['NINDA₂×ŠID'], '.', ''],
#  [['X₁'], '.', ''],
#  [['GUD×AŠ'], '.', ''],
#  [['NAGAR', 'DIŠ'], '.x12244.x12079', '𒉄𒁹'],
#  [['GAR', 'SAL', 'SAG', 'LAL'], '.x120FB.x122A9.x12295.x121F2', '𒃻𒊩𒊕𒇲'],
#  [['(LU', 'EŠ₂)&(LU', 'EŠ₂)'], '.None.None.None', '.None.None.None'],
#  [['BI', 'U₂', 'SA', 'KA', 'DU₃'],
#   '.x12049.x12311.x12293.x12157.None',
#   '𒁉𒌑𒊓𒅗.None'],
#  [['LAM×KUR', 'RU', 'DA'], '.x121F5.x12292.x12055', '𒇵𒊒𒁕'],
#  [['NINDA₂×DUB'], '.', ''],
#  [['GAD', 'KID₂', 'SI', 'A'], '.x120F0.None.x122DB.x12000', '𒃰.None𒋛𒀀'],
#  [['PIRIG', 'AB×GAL'], '.x1228A.x1200D', '𒊊𒀍'],
#  [['DIŠ@k', 'DIŠ@k', 'DIŠ@k', 'DIŠ@k'], '....', ''],
#  [['DIŠ@k', 'DIŠ@k', 'DIŠ@k', 'DIŠ@k'], '....', ''],
#  [['SAL', 'TUG₂', 'KU₃', 'SIG₁₇'], '.x122A9.x12306.x121AC.None', '𒊩𒌆𒆬.None'],
#  [['LAK589', 'SI'], '.None.x122DB', '.None𒋛'],
#  [['LAK526'], '.', ''],
#  [['TUG₂', 'PI', 'TE', 'A', 'RA'],
#   '.x12306.x1227F.x122FC.x12000.x1228F',
#   '𒌆𒉿𒋼𒀀𒊏'],
#  [['KA×(ŠU', 'EŠ₂)'], '.None.None', '.None.None'],
#  [['KI', 'SU', 'LU', 'GAR', 'KI'],
#   '.x121A0.x122E2.x121FB.x120FB.x121A0',
#   '𒆠𒋢𒇻𒃻𒆠'],
#  [['GIŠ', 'TUG₂', 'ZAL'], '.x12111.x12306.None', '𒄑𒌆.None'],
#  [['NE@s', 'GI'], '.x1224B.x12100', '𒉋𒄀'],
#  [['LAK589', 'A', 'SI'], '.None.x12000.x122DB', '.None𒀀𒋛'],
#  [['IGI', 'MAR'], '.x12146.x12225', '𒅆𒈥'],
#  [['GIŠ', 'TUG₂', 'PI', 'NU₁₁@90', 'SILA₃'],
#   '.x12111.x12306.x1227F.None.x122E1',
#   '𒄑𒌆𒉿.None𒋡'],
#  [['GIŠ', 'TUG₂', 'PI', 'NU₁₁@90', 'SILA₃'],
#   '.x12111.x12306.x1227F.None.x122E1',
#   '𒄑𒌆𒉿.None𒋡'],
#  [['GIŠ', 'TUG₂', 'PI', 'NU₁₁@90', 'SILA₃'],
#   '.x12111.x12306.x1227F.None.x122E1',
#   '𒄑𒌆𒉿.None𒋡'],
#  [['GIŠ', 'TUG₂', 'PI', 'NU₁₁@90', 'SILA₃'],
#   '.x12111.x12306.x1227F.None.x122E1',
#   '𒄑𒌆𒉿.None𒋡'],
#  [['GIŠ', 'TUG₂', 'PI', 'NU₁₁@90', 'SILA₃'],
#   '.x12111.x12306.x1227F.None.x122E1',
#   '𒄑𒌆𒉿.None𒋡'],
#  [['GIŠ', 'TUG₂', 'PI', 'NU₁₁@90', 'SILA₃'],
#   '.x12111.x12306.x1227F.None.x122E1',
#   '𒄑𒌆𒉿.None𒋡'],
#  [['GIŠ', 'TUG₂', 'PI', 'NU₁₁@90', 'SILA₃'],
#   '.x12111.x12306.x1227F.None.x122E1',
#   '𒄑𒌆𒉿.None𒋡'],
#  [['GIŠ', 'TUG₂', 'PI', 'NU₁₁@90', 'SILA₃'],
#   '.x12111.x12306.x1227F.None.x122E1',
#   '𒄑𒌆𒉿.None𒋡'],
#  [['GIŠ', 'TUG₂', 'PI', 'NU₁₁@90', 'SILA₃'],
#   '.x12111.x12306.x1227F.None.x122E1',
#   '𒄑𒌆𒉿.None𒋡'],
#  [['GIŠ', 'TUG₂', 'PI', 'NU₁₁@90', 'SILA₃'],
#   '.x12111.x12306.x1227F.None.x122E1',
#   '𒄑𒌆𒉿.None𒋡'],
#  [['GIŠ', 'TUG₂', 'PI', 'NU₁₁@90', 'SILA₃'],
#   '.x12111.x12306.x1227F.None.x122E1',
#   '𒄑𒌆𒉿.None𒋡'],
#  [['GIŠ', 'TUG₂', 'PI', 'NU₁₁@90', 'SILA₃'],
#   '.x12111.x12306.x1227F.None.x122E1',
#   '𒄑𒌆𒉿.None𒋡'],
#  [['AN', 'U'], '.x1202D.x1230B', '𒀭𒌋'],
#  [['LU₂@s×BAD'], '.', ''],
#  [['LU₂@s×BAD'], '.', ''],
#  [['BURU₅'], '.', ''],
#  [['BURU₅'], '.', ''],
#  [['BURU₅'], '.', ''],
#  [['BURU₅'], '.', ''],
#  [['PA', 'TAR'], '.x1227A.x122FB', '𒉺𒋻'],
#  [['GA₂×X'], '.', ''],
#  [['LAK589', 'SI', 'A'], '.None.x122DB.x12000', '.None𒋛𒀀'],
#  [['IGI×A'], '.', ''],
#  [['A', 'ZI&ZI', 'LAGAB'], '.x12000.None.x121B8', '𒀀.None𒆸'],
#  [['KA×KID₂'], '.', ''],
#  [['O'], '.', ''],
#  [['EGIR@g'], '.', ''],
#  [['ANŠE×ŠA₃'], '.', ''],
#  [['ŠE&ŠE', 'GAR&GAR'], '.None.None', '.None.None'],
#  [['ŠE&ŠE', 'GAR&GAR'], '.None.None', '.None.None'],
#  [['KA×GA₂'], '.', ''],
#  [['IGI', 'NAGAR', 'ŠIR'], '.x12146.x12244.x122D3', '𒅆𒉄𒋓'],
#  [['LAGAB×TIL'], '.', ''],
#  [['ŠE', 'UR₄'], '.x122BA.x12334', '𒊺𒌴'],
#  [['ŠIM×PI'], '.', ''],
#  [['ŠE', 'KAL'], '.x122BA.x12197', '𒊺𒆗'],
#  [['SAL', 'KAB'], '.x122A9.x1218F', '𒊩𒆏'],
#  [['UŠ', 'ANŠE'], '.x12351.x12032', '𒍑𒀲'],
#  [['AK×ŠITA'], '.', ''],
#  [['ŠEŠ', 'KI', 'DIM×ŠE'], '.x122C0.x121A0.x12075', '𒋀𒆠𒁵'],
#  [['ALAN&ALAN'], '.', ''],
#  [['4×IDIM'], '.', ''],
#  [['4×IDIM'], '.', ''],
#  [['4×IDIM'], '.', ''],
#  [['4×IDIM'], '.', ''],
#  [['4×IDIM'], '.', ''],
#  [['A', 'GISAL', 'PAD', 'SI', 'A'],
#   '.x12000.x12110.x1227B.x122DB.x12000',
#   '𒀀𒄐𒉻𒋛𒀀'],
#  [['GIŠ', 'TUG₂', 'PI', 'NI'], '.x12111.x12306.x1227F.x1224C', '𒄑𒌆𒉿𒉌'],
#  [['ZUBI'], '.', ''],
#  [['ZUBI'], '.', ''],
#  [['ZUBI'], '.', ''],
#  [['ZUBI'], '.', ''],
#  [['KWU543'], '.', ''],
#  [['(AŠ&AŠ@180)×U'], '.', ''],
#  [['ŠE&ŠE', 'PA&PA', 'GAR&GAR'], '.None.None.None', '.None.None.None'],
#  [['ŠE&ŠE', 'PA&PA', 'GAR&GAR'], '.None.None.None', '.None.None.None'],
#  [['KU', 'AN', 'RA'], '.x121AA.x1202D.x1228F', '𒆪𒀭𒊏'],
#  [['UR×A'], '.', ''],
#  [['GAR', 'SAL', 'LAL', 'SAG'], '.x120FB.x122A9.x121F2.x12295', '𒃻𒊩𒇲𒊕'],
#  [['ŠIR', 'LU', 'KUŠ&ŠIR', 'LU', 'KUŠ'],
#   '.x122D3.x121FB.None.x121FB.None',
#   '𒋓𒇻.None𒇻.None'],
#  [['GISAL', 'GAD', 'GAR', 'A', 'SI', 'A'],
#   '.x12110.x120F0.x120FB.x12000.x122DB.x12000',
#   '𒄐𒃰𒃻𒀀𒋛𒀀'],
#  [['EN', 'SAL', 'NUNUZ', 'ZI', 'AN', 'ŠEŠ', 'KI'],
#   '.x12097.x122A9.x1226D.x12363.x1202D.x122C0.x121A0',
#   '𒂗𒊩𒉭𒍣𒀭𒋀𒆠'],
#  [['DU', 'LAGAR@g'], '.x1207A.x121EF', '𒁺𒇯'],
#  [['LU₂×BAD', 'BAD'], '.x121FF.x12041', '𒇿𒁁'],
#  [['U₂', 'A', 'LAGAB×HAL'], '.x12311.x12000.x121C9', '𒌑𒀀𒇉'],
#  [['TA×GAR'], '.', ''],
#  [['UMUM×HA'], '.', ''],
#  [['AŠ', 'GAN₂'], '.x12038.x120F7', '𒀸𒃷'],
#  [['DIM×MAŠ'], '.', ''],
#  [['ZUM×LAGAB'], '.', ''],
#  [['BIL₄', 'MES', 'GA'], '.None.x12229.x120B5', '.None𒈩𒂵'],
#  [['SIK₂', 'SAG', 'PA', 'IB'], '.x122E0.x12295.x1227A.x12141', '𒋠𒊕𒉺𒅁'],
#  [['LAM', 'HI×DIŠ'], '.x121F4.x12131', '𒇴𒄱'],
#  [['KA×A', 'A'], '.x12158.x12000', '𒅘𒀀'],
#  [['NINDA₂×MI'], '.', ''],
#  [['KWU896'], '.', ''],
#  [['ILIMMU3'], '.', ''],
#  [['ILIMMU3'], '.', ''],
#  [['ILIMMU3'], '.', ''],
#  [['LAGAB×ŠE'], '.', ''],
#  [['MUNUS', 'U₈'], '.None.None', '.None.None'],
#  [['KA×(ME', 'ME)'], '.None.None', '.None.None'],
#  [['IŠ', 'A', 'SUD'], '.x12156.x12000.x122E4', '𒅖𒀀𒋤'],
#  [['GAL', 'MUG@g'], '.x120F2.x1222F', '𒃲𒈯'],
#  [['MA₂', 'SAL', 'DIŠ'], '.x12223.x122A9.x12079', '𒈣𒊩𒁹'],
#  [['LAGAR×SUM'], '.', ''],
#  [['LU₂×ŠU'], '.', ''],
#  [['LU₂×ŠU'], '.', ''],
#  [['UR₂×(GI', 'IDIM)'], '.None.None', '.None.None'],
#  [['DUN@g'], '.', ''],
#  [['PAD', 'GISAL', 'SI'], '.x1227B.x12110.x122DB', '𒉻𒄐𒋛'],
#  [['AŠ&AŠ@180'], '.', ''],
#  [['DIŠ@t'], '.', ''],
#  [['ZI%ZI'], '.', ''],
#  [['UR₂×KID₂', 'SU'], '.None.x122E2', '.None𒋢'],
#  [['PA', 'LAGAB×(GUD&GUD)'], '.x1227A.x121C7', '𒉺𒇇'],
#  [['2(DIŠ@t)'], '.', ''],
#  [['2(DIŠ@t)'], '.', ''],
#  [['KA×LUM'], '.', ''],
#  [['KA×LUM'], '.', ''],
#  [['DUMU', 'NE'], '.None.x12248', '.None𒉈'],
#  [['NINDA₂×NUMUN'], '.', ''],
#  [['PA', 'GISAL', 'SI', 'KAL', 'RU'],
#   '.x1227A.x12110.x122DB.x12197.x12292',
#   '𒉺𒄐𒋛𒆗𒊒'],
#  [['GAR', 'TUG₂'], '.x120FB.x12306', '𒃻𒌆'],
#  [['LAK171@s'], '.', ''],
#  [['LAK171@s'], '.', ''],
#  [['LAK171@s'], '.', ''],
#  [['LAK171@s'], '.', ''],
#  [['LAK171@s'], '.', ''],
#  [['LAK171@s'], '.', ''],
#  [['LAK171@s'], '.', ''],
#  [['LAK171@s'], '.', ''],
#  [['LAK171@s'], '.', ''],
#  [['LAK171@s'], '.', ''],
#  [['LAK171@s'], '.', ''],
#  [['LAK171@s'], '.', ''],
#  [['LAK171@s'], '.', ''],
#  [['LAK171@s'], '.', ''],
#  [['LAK171@s'], '.', ''],
#  [['LAK171@s'], '.', ''],
#  [['A', 'GISAL', 'GAD', 'GAR', 'A', 'SI'],
#   '.x12000.x12110.x120F0.x120FB.x12000.x122DB',
#   '𒀀𒄐𒃰𒃻𒀀𒋛'],
#  [['IGI', 'ZA', 'MUŠ₃@g'], '.x12146.x1235D.x1223D', '𒅆𒍝𒈽'],
#  [['LAGAB×ŠITA@t'], '.', ''],
#  [['IL₂@n'], '.', ''],
#  [['GAR', 'SAG', 'SAL', 'LAL'], '.x120FB.x12295.x122A9.x121F2', '𒃻𒊕𒊩𒇲'],
#  [['URU×(MIN', 'NI', 'GA)'], '.None.x1224C.None', '.None𒉌.None'],
#  [['URU×(MIN', 'NI', 'GA)'], '.None.x1224C.None', '.None𒉌.None'],
#  [['GI₄', 'NA', 'AB', 'TUM'], '.x12104.x1223E.x1200A.x12308', '𒄄𒈾𒀊𒌈'],
#  [['PA', 'EL', 'BU@g'], '.x1227A.x12096.None', '𒉺𒂖.None'],
#  [['EZEN×X'], '.', ''],
#  [['EZEN×X'], '.', ''],
#  [['EZEN×X'], '.', ''],
#  [['EZEN×X'], '.', ''],
#  [['REC169'], '.', ''],
#  [['ŠA₃×SAL'], '.', ''],
#  [['LAK524'], '.', ''],
#  [['LAK524'], '.', ''],
#  [['KA@180'], '.', ''],
#  [['EZEN×GUD'], '.', '']]
