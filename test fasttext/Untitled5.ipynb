# %% [markdown]
# Create file with all words (lemmas) of a single text listed in a row.

# %%
import pandas as pd
import zipfile
import json
import tqdm
import os
import sys
import pickle
import re
util_dir = os.path.abspath('../utils')
sys.path.append(util_dir)
from utils import *

# %%
directories = ['jsonzip', 'output', 'corpus']
make_dirs(directories)

# %%
projects = input('Project(s): ').lower()
# Out:
# Project(s):  epsd2/admin/lagash2

# %%
p = format_project_list(projects)
oracc_download(p)
# Out:
# Saving http://build-oracc.museum.upenn.edu/json/epsd2-admin-lagash2.zip as jsonzip/epsd2-admin-lagash2.zip.
# HBox(children=(FloatProgress(value=0.0, description='epsd2/admin/lagash2', max=3423458.0, style=ProgressStyle(…
# ['epsd2/admin/lagash2']

# %%
def parsejson(text):
    for JSONobject in text["cdl"]:
        field = ''
        if "cdl" in JSONobject: 
            parsejson(JSONobject)
        if "type" in JSONobject and JSONobject["type"] == "field-start":
            field = JSONobject["subtype"]
        if "f" in JSONobject and not field in ['sg', 'pr']: # skip the fields "sign" and "pronunciation"
                                # in lexical texts
            if JSONobject["f"]["lang"][:3] == "sux": #only Sumerian and Emesal
                word = JSONobject["f"]
                if "cf" in word:
                    if 'pos' in word:  #for some reason some words appear without pos. Provisionally treated as Noun
                        lemm = word["cf"] + '[' + word["gw"] + "]" + word["pos"]
                    else:
                        lemm = word["cf"] + '[' + word["gw"] + "]N"
                    lemm = lemm.replace(' ', '-') # remove commas and spaces from lemm
                    lemm = lemm.replace(',', '')
                else:
                    lemm = "_" # if word is unlemmatized enter a place holder
                l.append(lemm)
    return

# %%
lemm_ = []
ids_ = []
for project in p:
    file = "jsonzip/" + project.replace("/", "-") + ".zip"
    try:
        z = zipfile.ZipFile(file)       # create a Zipfile object
    except:
        print(file + " does not exist or is not a proper ZIP file")
        continue
    files = z.namelist()     # list of all the files in the ZIP
    files = [name for name in files if "corpusjson" in name and name[-5:] == '.json']                                                                                                  #that holds all the P, Q, and X numbers.
    for filename in tqdm(files, desc = project):                            #iterate over the file names
        l = []
        id_no = filename[-13:-5]
        if id_no in ids_ and not "X" in id_no: # Check if P/Q number is already in there
            continue        # a text may appear in multiple projects
        id_text = project + id_no # id_text is, for instance, blms/P414332
        ids_.append(id_text)
        try:
            text = z.read(filename).decode('utf-8')         #read and decode the json file of one particular text
            data_json = json.loads(text)                # make it into a json object (essentially a dictionary)
            #lemm_.append(f"\n{id_text}")     # new text starts on new line with text_id
            parsejson(data_json)
            lemm_.append(l)
        except:
            print(id_text + ' is not available or not complete')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='epsd2/admin/lagash2', max=551.0, style=ProgressStyle(desc…

# %%
df = pd.DataFrame({"textid":ids_, "lemm" : lemm_})

# %%
lemm_
# Out:
# [['_',
#   'tug[textile]N',
#   'bardul[garment]N',
#   'guz[tufted]V/i',
#   'sag[rare]V/i',
#   '_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   'sag[rare]V/i',
#   '_',
#   '_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   'us[follow]V/t',
#   '_',
#   'tug[textile]N',
#   'guʾe[textile]N',
#   'us[follow]V/t',
#   '_',
#   'tug[textile]N',
#   'gula[garment]N',
#   'us[follow]V/t',
#   '_',
#   'tug[textile]N',
#   'bardul[garment]N',
#   'PA[00]PN',
#   '_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   '_',
#   'tug[textile]N',
#   'bur[bowl]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'tug[textile]N',
#   'munus[woman]N',
#   '_',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   '_',
#   '_',
#   'lal[small]V/i',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   'guz[tufted]V/i',
#   'elam[highland]N',
#   'egal[palace]N',
#   'Lugal.inim.du₁₀[00]PN',
#   'šu[hand]N',
#   'teŋ[near]V/i'],
#  ['_',
#   'tug[textile]N',
#   'bardul[garment]N',
#   '_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   'us[follow]V/t',
#   'Ur.sukkal[00]PN',
#   '_',
#   'tug[textile]N',
#   'bardul[garment]N',
#   '_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   'zig[rise]V/i',
#   'sukkalmah[official]N',
#   'maškim[administrator]N',
#   'šara₂.i₃.sa₆[00]PN',
#   'mu[name]N',
#   'Ur.nin.gir₂.su[00]PN',
#   'mu[year]N',
#   'us[follow]V/t'],
#  ['_',
#   'sila[unit]N',
#   'lal[syrup]N',
#   '_',
#   '_',
#   'kud[fish]N',
#   'niŋki[herd]N',
#   '_',
#   'kud[fish]N',
#   '_',
#   '_',
#   'kud[fish]N',
#   'suhur[carp]N',
#   'sadug[offerings]N',
#   'emuhaldim[kitchen]N',
#   'itud[moon]N',
#   'Ezemdumuzid[1]MN',
#   'šara₂.i₃.sa₆[00]PN'],
#  ['_',
#   'še[barley]N',
#   'gur[unit]N',
#   'A.ga.de₃[00]SN',
#   '_',
#   'Lu₂.ba[00]PN',
#   'maškim[administrator]N',
#   'šu[hand]N'],
#  ['_',
#   'kaš[beer]N',
#   'Nam.tar.re₂[00]PN',
#   '_',
#   'Ur.zu[00]PN',
#   '_',
#   'nagar[carpenter]N',
#   '_',
#   'Nam.tar.re₂[00]PN',
#   '_',
#   'en.lil₂[00]PN',
#   '_',
#   'Ama.ki.im[00]PN',
#   '_',
#   'Ur.x[00]PN',
#   '_',
#   'Ur.ab.ba[00]PN',
#   '_',
#   'Lugal.šeš[00]PN',
#   '_',
#   '_',
#   '_',
#   'Nam.ha.ni[00]PN',
#   '_',
#   'Lu₂.banda₃[00]PN',
#   '_',
#   'Nam.ha.ni[00]PN',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'Lugal[00]PN',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'Lugal.ur.sag[00]PN',
#   '_',
#   '_',
#   'Lugal.KA[00]PN',
#   'Lugal.KA[00]PN',
#   'ur[dog]N',
#   'dabašin[object]N',
#   'Ama.ki.im[00]PN',
#   '_',
#   '_',
#   'Šu.ni[00]PN',
#   '_',
#   'u[grass]N',
#   '_',
#   '_',
#   '_',
#   'en.lil₂[00]PN',
#   '_',
#   '_',
#   '_',
#   'adda[father]N',
#   '_',
#   'lugal[king]N',
#   'An[00]PN',
#   '_',
#   '_',
#   'Ad.x[00]PN',
#   'Ur.x[00]PN',
#   '_',
#   '_',
#   '_',
#   'Lugal.x[00]PN',
#   'En.mu[00]PN',
#   'iginudu[blind]N',
#   'Lugal.nig₂.zu[00]PN',
#   'Šu.x[00]PN',
#   '_',
#   'Gissu[00]PN',
#   'Ur.utu[00]PN',
#   '_',
#   '_',
#   'adda[father]N',
#   'en.lil₂[00]PN',
#   '_',
#   '_',
#   '_',
#   'Ama.kalam.ma[00]PN',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'Ur.lu₂[00]PN',
#   'Ur[00]PN',
#   '_',
#   '_',
#   'Giri₃.ni[00]PN',
#   'Ku.bu.ri₂.na[00]PN',
#   '_',
#   '_',
#   'inanna.ur.sag[00]PN',
#   '_',
#   '_',
#   '_',
#   'I.mu.ut.er₃.ra[00]PN',
#   'Lugal.si.gar[00]PN',
#   '_',
#   '_',
#   'Ur.pa[00]PN',
#   'Šu.mah[00]PN',
#   '_',
#   '_',
#   '_',
#   'amagal[grandmother]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   'en.lil₂[00]PN',
#   '_',
#   'Ur.utu[00]PN',
#   '_',
#   'Ur.dingir[00]PN',
#   '_',
#   'adda[father]N',
#   '_',
#   'Ur[00]PN',
#   '_',
#   '_',
#   '_',
#   'zagmuk[new-year]N',
#   '_',
#   'Ama.kalam.ma[00]PN',
#   '_',
#   '_',
#   '_',
#   'Ku.bu.ri₂.na[00]PN',
#   '_',
#   'Ur.gu[00]PN',
#   '_',
#   '_',
#   '_',
#   'amagal[grandmother]N',
#   '_',
#   '_',
#   '_',
#   'Ur.dam[00]PN',
#   '_',
#   'utu[00]DN',
#   '_',
#   'Ur.gu[00]PN',
#   'nita[male]N',
#   '_',
#   'Šu.mah[00]PN',
#   '_',
#   'Sag.dingir[00]PN',
#   '_',
#   'Lugal.KA[00]PN'],
#  ['_',
#   '_',
#   '_',
#   'sila[unit]N',
#   'zid[flour]N',
#   'sadug[offerings]N',
#   'kaš[runner]N',
#   'I₃.si[00]SN'],
#  [],
#  ['_',
#   '_',
#   'sila[unit]N',
#   'inun[ghee]N',
#   '_',
#   'sila[unit]N',
#   'lal[syrup]N',
#   '_',
#   'zulum[date]N',
#   '_',
#   'gaʾar[cheese]N',
#   '_',
#   'hašhur[apple]N',
#   '_',
#   'ŋipar[tree]N',
#   '_',
#   'mudum[fruit]N',
#   '_',
#   'še[barley]N',
#   'halub[tree]N',
#   '_',
#   'šergu[string]N',
#   'X.x[00]FN',
#   '_',
#   '_',
#   'aʾan[spadix]N',
#   'zulum[date]N',
#   'Dumuzid[1]DN',
#   '_',
#   'inun[ghee]N',
#   '_',
#   'šaŋan[flask]N',
#   'i[oil]N',
#   '_',
#   'edak[container]N',
#   'zulum[date]N',
#   'dam[spouse]N',
#   'A.kiši₁₇.gal[00]PN',
#   '_',
#   'šaŋan[flask]N',
#   'i[oil]N',
#   'emedagal[nursemaid]N',
#   '_',
#   'šaŋan[flask]N',
#   'i[oil]N',
#   '_',
#   'Lu₂.utu[00]PN',
#   'maškim[administrator]N',
#   'šara₂.i₃.sa₆[00]PN'],
#  [],
#  ['_',
#   'erin[people]N',
#   'gub[stand]V/i',
#   'Ur.nin.tu[00]PN',
#   'šeš[brother]N',
#   'gal[big]V/i',
#   'kunzida[weir]N',
#   '_',
#   'Lu₂.ba.ba₆[00]PN',
#   'šeš[brother]N',
#   'gal[big]V/i',
#   'id[river]N',
#   'gub[stand]V/i',
#   'ugula[overseer]N',
#   'Lu₂.e₂.gibil[00]PN',
#   'ašag[field]N',
#   'Inim.nisaba[00]FN',
#   'ud[sun]N',
#   '_',
#   'Mineš[1]MN',
#   'itud[moon]N',
#   'Ezembaba[1]MN'],
#  ['_',
#   'Lu₂.dingir[00]PN',
#   'dumu[child]N',
#   'Ur.kisal[00]PN',
#   'mu[name]N',
#   'kiduru[land]N',
#   'gurum[inspection]N',
#   'kiri[orchard]N',
#   'ŋeš[tree]N',
#   'gal[big]V/i',
#   'ŋal[be]V/i',
#   'šu[hand]N',
#   'bar[cvve]V/t',
#   'ki[place]N',
#   'Ur.ba.gara₂[00]PN',
#   'ugula[overseer]N',
#   'itud[moon]N',
#   'Ezemdumuzid[1]MN',
#   'ud[sun]N',
#   '_',
#   '_',
#   'zal[pass]V/t'],
#  ['_',
#   '_',
#   '_',
#   '_',
#   'giŋ[unit]N',
#   'dabin[semolina]N',
#   '_',
#   'sila[unit]N',
#   'niŋara[groats]N',
#   '_',
#   'sila[unit]N',
#   'še[barley]N',
#   'tu[soup]N',
#   '_',
#   'zid[flour]N',
#   'i[oil]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'zid[flour]N',
#   'baba[porridge]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'giŋ[unit]N',
#   'še[barley]N',
#   'šuniŋin[total]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'zid[flour]N',
#   'Sig₁₅[00]PN',
#   'Lugal.igi.sa₆[00]PN',
#   'itud[moon]N',
#   'Ezembaba[1]MN',
#   '_',
#   'ud[sun]N',
#   'zal[pass]V/t'],
#  [],
#  ['_',
#   'dabin[semolina]N',
#   'ennuŋ[imprisonment]N',
#   '_',
#   'dabin[semolina]N',
#   '_',
#   'sila[unit]N',
#   'niŋara[groats]N',
#   'Sipa.da.ri₂[00]PN',
#   '_',
#   'sila[unit]N',
#   'zid[flour]N',
#   'Ad.da[00]PN',
#   '_',
#   'ŋuruš[male]N',
#   '_',
#   'sila[unit]N',
#   'zid[flour]N',
#   '_',
#   'niŋara[groats]N',
#   'emebala[translator]N',
#   '_',
#   'dabin[semolina]N',
#   '_',
#   'šah[pig]N',
#   'u[grass]N',
#   'urnim[lion]N',
#   '_',
#   'zid[flour]N',
#   'I.šar.pa₂.dan[00]PN',
#   'emebala[translator]N',
#   'Lugal.me.lam₂[00]PN',
#   'maškim[administrator]N',
#   '_',
#   'zid[flour]N',
#   'erin[people]N',
#   'ma[ship]N',
#   'inuda[chaff]N',
#   '_',
#   'zid[flour]N',
#   'Amar.su₄[00]PN',
#   '_',
#   '_',
#   'šah[pig]N',
#   'niga[fattened]V/i',
#   'Dingir.ba.ni[00]PN',
#   'šakkanak[general]N',
#   'Lugal.sukkal[00]PN',
#   'maškim[administrator]N',
#   '_',
#   'zid[flour]N',
#   'Maš[00]PN',
#   'emebala[translator]N',
#   'Nam.ha.ni[00]PN',
#   'maškim[administrator]N',
#   '_',
#   'bappir[~beer]N',
#   '_',
#   'niŋara[groats]N',
#   '_',
#   '_',
#   '_',
#   'zid[flour]N',
#   'erin[people]N',
#   '_',
#   'Da.da[00]PN'],
#  ['_',
#   'tug[textile]N',
#   'bardul[garment]N',
#   '_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   'us[follow]V/t',
#   '_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   'ušbar[weaver]N',
#   'Gu₃.de₂.a[00]PN',
#   'saŋ.niŋ₂.GA.ra[assets]N',
#   'ŋar[place]V/t',
#   'šara₂.i₃.sa₆[00]PN'],
#  ['_',
#   'sab[jar]N',
#   'inun[ghee]N',
#   '_',
#   'sila[unit]N',
#   'inun[ghee]N',
#   'Suen[00]DN',
#   'nanše.uri₃[00]PN',
#   'maškim[administrator]N'],
#  ['uš[die]V/i',
#   'AŠ[00]PN',
#   'Geme₂.ba[00]PN',
#   'itud[moon]N',
#   'Ezemdumuzid[1]MN',
#   'Nimgir.ki.ag₂[00]PN',
#   'mu[name]N',
#   'erešdiŋir[priestess]N',
#   'Iškur[1]DN',
#   'maš[goat]N',
#   'pad[find]V/t'],
#  ['_',
#   'gud[ox]N',
#   'udu[sheep]N',
#   'i[oil]N',
#   '_',
#   '_',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'lugal[king]N',
#   'Ur.li[00]PN',
#   'maškim[administrator]N',
#   '_',
#   'gud[ox]N',
#   '_',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '_',
#   'maš[interest]N',
#   'lugal[king]N',
#   '_',
#   'gud[ox]N',
#   '_',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '_',
#   'maš[goat]N',
#   'nin[lady]N',
#   '_',
#   'gud[ox]N',
#   '_',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '_',
#   'maš[goat]N',
#   'Dumu.lugal[00]FN',
#   '_',
#   'udu[sheep]N',
#   'kur[mountain]N',
#   'niga[fattened]V/i',
#   'e[house]N',
#   'Gula[1]DN',
#   '_',
#   'udunita[ram]N',
#   'e[house]N',
#   'diŋir[deity]N',
#   '_',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '_',
#   '_',
#   '_',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '_',
#   '_',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'barag[sack]N',
#   '_',
#   'Ma.ra.num₂[00]FN',
#   'maškim[administrator]N',
#   '_',
#   'gud[ox]N',
#   '_',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '_',
#   'udunita[ram]N',
#   'dumu[child]N',
#   'Zimudar[1]RN',
#   'Amar.šuba₃[00]PN',
#   'agaʾus[soldier]N',
#   'maškim[administrator]N',
#   '_',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'X.ni[00]PN',
#   '_',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '_',
#   'Ur.ki[00]PN',
#   'maškim[administrator]N',
#   '_',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'Be.li₂.du₁₀[00]PN',
#   'Šu.eš₁₈.dar[00]PN',
#   'maškim[administrator]N'],
#  ['kugsig[gold]N',
#   'Lugal.bur[00]PN',
#   'kug[metal]N',
#   'nindaba[offering]N',
#   'mu.DU[delivery]N',
#   'Lu₂.nanše[00]PN',
#   'maškim[administrator]N',
#   'Ur.utu[00]PN',
#   'ensik[ruler]N',
#   'itud[moon]N',
#   'ezem[festival]N',
#   'Burumaš[1]MN'],
#  ['_',
#   'udu[sheep]N',
#   'U.bar.ru.um[00]PN',
#   '_',
#   'sila[lamb]N',
#   'Gu₃.de₂.a[00]PN',
#   '_',
#   'udu[sheep]N',
#   '_',
#   '_',
#   'giŋ[unit]N',
#   'kug[metal]N',
#   '_',
#   '_',
#   'giŋ[unit]N',
#   'kug[metal]N',
#   '_',
#   '_',
#   'giŋ[unit]N',
#   'kug[metal]N',
#   '_',
#   '_',
#   'giŋ[unit]N',
#   'kug[metal]N',
#   '_',
#   '_',
#   'giŋ[unit]N',
#   'kug[metal]N',
#   '_',
#   'mu.DU[delivery]N'],
#  ['_',
#   'tug[textile]N',
#   'bardul[garment]N',
#   'guz[tufted]V/i',
#   'sag[rare]V/i',
#   '_',
#   'šaŋan[flask]N',
#   'i[oil]N',
#   'Ur.nin.gir₂.su[00]PN',
#   '_',
#   'pana[bow]N',
#   'saŋŋa[official]N',
#   'Nanše[1]DN',
#   'mu.DU[delivery]N'],
#  ['_',
#   'sila[unit]N',
#   'inun[ghee]N',
#   '_',
#   'sila[unit]N',
#   'gaʾar[cheese]N',
#   'tur[small]V/i',
#   'Suen[00]DN',
#   '_',
#   'sila[unit]N',
#   'inun[ghee]N',
#   'emi[household]N',
#   '_',
#   'gaʾar[cheese]N',
#   'emuhaldim[kitchen]N',
#   'Ur.dam[00]PN'],
#  ['_',
#   '_',
#   '_',
#   'zid[flour]N',
#   'gu[cord]N',
#   'gur[unit]N',
#   'lugal[king]N',
#   'ma[ship]N',
#   'Ur.nin.geš.zi.da[00]PN',
#   'ugula[overseer]N',
#   'Ur.šu.ga.lam.ma[00]PN',
#   'šabra[administrator]N',
#   'Nibru[00]SN',
#   'ŋiri[foot]N',
#   'Na.a.a[00]PN',
#   'šeš[brother]N',
#   'Lugal.sa₆.ga[00]PN',
#   'itud[moon]N',
#   'Gudrabimumu[1]MN'],
#  ['_',
#   'sila[unit]N',
#   'inun[ghee]N',
#   'dug[good]V/i',
#   'e[house]N',
#   'diŋir[deity]N',
#   'šara₂.i₃.sa₆[00]PN'],
#  ['laʾu[arrears]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'iʾab[ghee]N',
#   '_',
#   '_',
#   'gaʾar[cheese]N',
#   'gu[neck]N',
#   '_',
#   '_',
#   'gaʾar[cheese]N',
#   'Lugal.sipa[00]PN',
#   '_',
#   'dug[pot]N',
#   '_',
#   'sila[unit]N',
#   'i[oil]N',
#   '_',
#   '_',
#   'gaʾar[cheese]N',
#   'Inim.utu[00]PN',
#   '_',
#   'sila[unit]N',
#   'i[oil]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'sila[unit]N',
#   'iʾab[ghee]N',
#   '_',
#   'sila[unit]N',
#   'gaʾar[cheese]N',
#   'gur[unit]N',
#   'A.ga.de₃[00]SN',
#   '_',
#   '_',
#   'šu[hand]N',
#   'teŋ[near]V/i',
#   '_',
#   'gu[neck]N',
#   '_',
#   '_',
#   'mu[name]N',
#   'lugal[king]N',
#   'A.ga.de₃[00]SN',
#   '_'],
#  ['_',
#   '_',
#   '_',
#   '_',
#   'giŋ[unit]N',
#   'kug[metal]N',
#   'niŋsam[price]N',
#   'Ur.gu[00]PN',
#   '_',
#   'giŋ[unit]N',
#   'kug[metal]N',
#   '_',
#   'niŋara[groats]N',
#   '_',
#   'bappir[~beer]N',
#   '_',
#   'munu[malt]N',
#   '_',
#   'kuš[skin]N',
#   '_',
#   '_',
#   '_',
#   'kuš[skin]N',
#   '_',
#   '_',
#   '_',
#   'I₃.DU[00]PN',
#   'gara[cream]N',
#   'sila[unit]N',
#   'niŋ[thing]N',
#   'nammaškim[office]N',
#   '_',
#   'dumu[child]N',
#   '_',
#   'šu[hand]N',
#   'teŋ[near]V/i',
#   '_',
#   '_',
#   '_',
#   'šu[hand]N',
#   '_',
#   '_',
#   '_',
#   'maškim[administrator]N',
#   'kug[metal]N',
#   '_',
#   '_',
#   '_',
#   'kug[metal]N',
#   '_',
#   '_',
#   'mu[name]N',
#   'lugal[king]N',
#   'KA[unmng]N',
#   '_',
#   '_',
#   'Na.ba.lu₅[00]PN',
#   'sukkal[secretary]N',
#   'zir[break]V/t',
#   'šabra[administrator]N',
#   '_',
#   'zig[rise]V/i',
#   '_',
#   'Ku.li[00]PN',
#   'maškim[administrator]N',
#   '_',
#   'Lugal.gir₂.nun[00]PN',
#   'dubsar[scribe]N',
#   '_',
#   'Ku.li[00]PN',
#   'dumu[child]N',
#   '_',
#   '_',
#   'Za.u₂[00]PN',
#   'ašgab[leatherworker]N'],
#  ['_',
#   'še[barley]N',
#   'gur[unit]N',
#   'A.ga.de₃[00]SN',
#   'dam[spouse]N',
#   'Ur.en.lil₂[00]PN',
#   'itud[moon]N',
#   'Ezemlisina[1]MN',
#   'šu[hand]N'],
#  ['_',
#   'pana[bow]N',
#   'lugal[king]N',
#   'Lugal.sukkal[00]PN',
#   'du[go]V/i',
#   'nin.gir₂.su.igi.du[00]PN'],
#  ['_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   'sag[rare]V/i',
#   'siki[hair]N',
#   '_',
#   'mana[unit]N',
#   '_',
#   'giŋ[unit]N',
#   '_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   'siki[hair]N',
#   '_',
#   '_',
#   'mana[unit]N',
#   'lal[small]V/i',
#   '_',
#   'giŋ[unit]N',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   'guz[tufted]V/i',
#   'siki[hair]N',
#   '_',
#   'gu[neck]N',
#   '_',
#   'mana[unit]N',
#   'itud[moon]N',
#   'Ezemdumuzid[1]MN',
#   '_',
#   'šu[hand]N',
#   'teŋ[near]V/i'],
#  ['_',
#   '_',
#   'mana[unit]N',
#   '_',
#   'ad[bush]N',
#   '_',
#   '_',
#   '_',
#   'mana[unit]N',
#   '_',
#   '_',
#   'lal[small]V/i',
#   '_',
#   'mana[unit]N',
#   '_',
#   '_',
#   '_',
#   'mana[unit]N',
#   '_',
#   '_',
#   'šim[aromatics]N',
#   'kib[wheat]N',
#   'tur[small]V/i',
#   '_',
#   'dug[pot]N',
#   'inun[ghee]N',
#   '_',
#   '_',
#   'Da.num₂[00]PN',
#   'duh[loosen]V/t',
#   'šu[hand]N',
#   'teŋ[near]V/i'],
#  ['_',
#   'gu[neck]N',
#   'siki[hair]N',
#   '_',
#   'Ur.nin.a.zu[00]PN',
#   '_',
#   '_',
#   '_',
#   'damgar[merchant]N',
#   'šu[hand]N',
#   'teŋ[near]V/i'],
#  ['_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'sila[unit]N',
#   'še[barley]N',
#   'gur[unit]N',
#   'saŋ[head]N',
#   'ŋal[be]V/i',
#   'Lugal.iti.da[00]PN',
#   'nubanda[overseer]N',
#   'ŋal[be]V/i'],
#  ['_',
#   'magur[barge]N',
#   '_',
#   'Me.ni.šu.na[00]PN',
#   '_',
#   'Ur.ba.ba₆[00]PN',
#   '_',
#   'Ur.lugal.banda₃[00]PN',
#   '_',
#   'Ur.zikum.ma[00]PN',
#   '_',
#   'E₂.x.da[00]PN',
#   '_',
#   'Nin.bara₂.ge.si[00]PN',
#   '_',
#   '_',
#   'dumu[child]N',
#   'še[barley]N',
#   '_',
#   '_',
#   '_',
#   'gur[unit]N',
#   'kaš[beer]N',
#   'gub[stand]V/i',
#   'ugula[overseer]N',
#   'Sipa.da.ri₂[00]PN',
#   'ŋirsiga[attendant]N',
#   'ensik[ruler]N',
#   '_',
#   '_',
#   'ŋirsiga[attendant]N',
#   'e[house]N',
#   'Baba[1]DN'],
#  ['_',
#   'tug[textile]N',
#   'bardul[garment]N',
#   'libir[old]V/i',
#   'ugula[overseer]N',
#   'Al.la[00]PN',
#   'mu[name]N',
#   'lumah[priest]N',
#   'Baba[1]DN'],
#  ['_',
#   'sila[unit]N',
#   'inun[ghee]N',
#   '_',
#   'sila[unit]N',
#   'lal[syrup]N',
#   '_',
#   'sila[unit]N',
#   'zulum[date]N',
#   '_',
#   'sila[unit]N',
#   'gaʾar[cheese]N',
#   '_',
#   'sila[unit]N',
#   'hašhur[apple]N',
#   '_',
#   'sila[unit]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'ŋeštin[vine]N',
#   '_',
#   'sila[unit]N',
#   'mudum[fruit]N',
#   '_',
#   '_',
#   'šergu[string]N',
#   'peš[fig]N',
#   '_',
#   'Gu.ša[00]SN',
#   '_',
#   'maškim[administrator]N',
#   '_',
#   '_',
#   '_',
#   'ragaba[rider]N',
#   '_',
#   'sila[unit]N',
#   'lal[syrup]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'sila[unit]N',
#   'išah[lard]N',
#   '_',
#   'sila[unit]N',
#   'zulum[date]N',
#   '_',
#   'giŋ[unit]N',
#   'ŋeštin[vine]N',
#   'emuhaldim[kitchen]N',
#   'šara₂.i₃.sa₆[00]PN'],
#  ['_',
#   'gu[neck]N',
#   '_',
#   '_',
#   'la[hang]V/t',
#   'Da.da[00]PN',
#   '_',
#   'gu[neck]N',
#   '_',
#   '_',
#   'lal[small]V/i',
#   '_',
#   'mana[unit]N',
#   'Lu₂.dumu.zi[00]PN',
#   '_',
#   'gu[neck]N',
#   '_',
#   '_',
#   '_',
#   'mana[unit]N',
#   'siki[hair]N',
#   'udu[sheep]N',
#   'emi[household]N',
#   '_',
#   'A.x[00]PN',
#   'Gu₃.de₂.a[00]PN',
#   'ensik[ruler]N',
#   'mu[year]N',
#   'guza[chair]N',
#   'Nanše[1]DN',
#   'dim[create]V/t'],
#  ['_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'šanabi[two-thirds]NU',
#   '_',
#   '_',
#   'gam[crook]N',
#   'gid[length]N',
#   '_',
#   'kuš[unit]N',
#   'Gu.x[00]PN',
#   '_',
#   '_',
#   'barda[crossbar]N',
#   'asal[poplar]N',
#   '_',
#   'gid[length]N',
#   '_',
#   '_',
#   'kuš[unit]N',
#   'guniŋin[bale]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'sal[thin]V/i',
#   'gid[length]N',
#   '_',
#   '_',
#   'kuš[unit]N',
#   'guniŋin[bale]N',
#   '_',
#   '_',
#   '_',
#   'asal[poplar]N',
#   'gid[length]N',
#   '_',
#   'kuš[unit]N',
#   'guniŋin[bale]N',
#   '_',
#   '_',
#   'kuš[unit]N',
#   '_',
#   '_',
#   'hašhur[apple]N',
#   'gid[length]N',
#   '_',
#   'kuš[unit]N',
#   '_',
#   'usuh[tree]N',
#   'miriza[plank]N',
#   'gid[length]N',
#   '_',
#   'ninda[bread]N',
#   '_',
#   'kuš[unit]N',
#   '_',
#   '_',
#   'lal[small]V/i',
#   '_',
#   '_',
#   'barda[crossbar]N',
#   'hašhur[apple]N',
#   'gid[length]N',
#   'šanabi[two-thirds]NU',
#   'kuš[unit]N',
#   'mu[name]N',
#   '_',
#   '_',
#   '_'],
#  ['Ur.ištaran[00]PN',
#   'e[speak]V/t',
#   '_',
#   'unadug[letter]N',
#   '_',
#   'e[house]N',
#   'Ur.nig₂[00]PN',
#   'lu[person]N',
#   'kaš[runner]N',
#   '_',
#   'e[house]N',
#   '_',
#   'e[house]N',
#   'Lugal.ezem[00]PN',
#   'kuš[official]N',
#   '_',
#   'unadug[letter]N',
#   'bad[wall]N',
#   '_',
#   'dag[side]N',
#   '_'],
#  ['_',
#   'tug[textile]N',
#   'bardul[garment]N',
#   '_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   'us[follow]V/t',
#   '_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   'ušbar[weaver]N',
#   '_',
#   'mana[unit]N',
#   'kugbabbar[silver]N',
#   'ma[ship]N',
#   'ud[sun]N',
#   'zal[pass]V/t',
#   'šara₂.i₃.sa₆[00]PN',
#   'mu[name]N',
#   'šitaʾaba[priest]N'],
#  ['_',
#   'lal[small]V/i',
#   '_',
#   'gur[unit]N',
#   'še[barley]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'zidgu[flour]N',
#   '_',
#   'lal[small]V/i',
#   '_',
#   'gur[unit]N',
#   'zid[flour]N',
#   'X.na[00]DN',
#   'kaš[runner]N',
#   'I₃.si[00]SN'],
#  ['_',
#   'udunita[ram]N',
#   '_',
#   'u[ewe]N',
#   '_',
#   'Ku.li[00]PN',
#   'du[go]V/i',
#   '_',
#   'gud[ox]N',
#   '_',
#   '_',
#   'erešdiŋir[priestess]N',
#   'Baba[1]DN',
#   '_',
#   'erešdiŋir[priestess]N',
#   'ga₂.tum₃.du₁₀[00]DN',
#   '_',
#   'ensik[ruler]N',
#   'Nibru[00]SN',
#   '_',
#   'saŋŋa[official]N',
#   'en.lil₂[00]PN',
#   '_',
#   'ensik[ruler]N',
#   'Adab[00]SN',
#   '_',
#   'sila[unit]N',
#   'lib[fat]N',
#   '_',
#   '_',
#   'du[go]V/i',
#   '_',
#   'sila[unit]N',
#   '_',
#   'šanabi[two-thirds]NU',
#   'sila[unit]N',
#   'X.x[00]PN',
#   '_',
#   'sila[unit]N',
#   'Da.ba.an[00]SN',
#   '_',
#   'sila[unit]N',
#   'i[oil]N',
#   'udu[sheep]N',
#   'lu[person]N',
#   'marsa[shipyard]N',
#   '_',
#   'Lu₂.ma₂.gan[00]PN',
#   '_',
#   'du[go]V/i'],
#  ['_',
#   'kud[fish]N',
#   '_',
#   'en.lil₂[00]PN',
#   'Ur.ab.ba[00]PN',
#   'maškim[administrator]N',
#   '_',
#   'kud[fish]N',
#   'kunzid[fish]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   'lu[person]N',
#   'ŋiri[foot]N',
#   'Lugal.x[00]PN',
#   '_',
#   'kud[fish]N',
#   '_',
#   'en[priest]N',
#   'Nibru[00]SN',
#   'nin.gir₂.su.igi.du[00]PN'],
#  ['_',
#   'še[barley]N',
#   'gur[unit]N',
#   'A.ga.de₃[00]SN',
#   'Šu[00]PN',
#   'nar[musician]N',
#   'Ur.nigar[00]PN',
#   'ragaba[rider]N',
#   'maškim[administrator]N',
#   '_',
#   'gur[unit]N',
#   '_',
#   'Inim.inanna[00]PN',
#   'maškim[administrator]N',
#   'šu[hand]N'],
#  ['_',
#   '_',
#   'udunita[ram]N',
#   '_',
#   '_',
#   'u[ewe]N',
#   'nin.gir₂.su[00]DN',
#   'Lu₂.ba[00]PN',
#   'dumu[child]N',
#   'Ur.šu.KID[00]PN',
#   'dab[seize]V/t'],
#  ['_',
#   'lal[small]V/i',
#   '_',
#   'giŋ[ax]N',
#   'kugbabbar[silver]N',
#   'ki[place]N',
#   'šara₂.i₃.sa₆[00]PN',
#   'egal[palace]N',
#   'kur[enter]V/i'],
#  ['_',
#   '_',
#   '_',
#   'Lugal.bur[00]PN',
#   'šabraʾek[administrator]N',
#   'u[and]CNJ',
#   '_',
#   'ugula[overseer]N',
#   '_',
#   '_',
#   'lugal[king]N',
#   '_'],
#  ['_',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '_',
#   'sila[lamb]N',
#   '_',
#   '_',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '_',
#   'sila[lamb]N',
#   'Da.da[00]PN',
#   '_',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '_',
#   'sila[lamb]N',
#   'Ur.nin.gir₂.su[00]PN',
#   '_',
#   'udu[sheep]N',
#   '_',
#   'maš[goat]N',
#   '_',
#   '_',
#   'udu[sheep]N',
#   '_',
#   'sila[lamb]N',
#   'Li.lum[00]PN',
#   '_',
#   'uzud[goat]N',
#   '_',
#   'mu.DU[delivery]N'],
#  [],
#  ['_',
#   '_',
#   'sila[unit]N',
#   'dabin[semolina]N',
#   'ennuŋ[imprisonment]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'dabin[semolina]N',
#   '_',
#   'sila[unit]N',
#   'niŋara[groats]N',
#   'Sipa.da.ri₂[00]PN',
#   '_',
#   '_',
#   'sila[unit]N',
#   'dabin[semolina]N',
#   '_',
#   'sila[unit]N',
#   'niŋara[groats]N',
#   'E₂.zi[00]PN',
#   'šagia[cup-bearer]N',
#   '_',
#   'sila[unit]N',
#   'zid[flour]N',
#   'Ad.da[00]PN',
#   '_',
#   '_',
#   'ŋuruš[male]N',
#   '_',
#   'sila[unit]N',
#   'zid[flour]N',
#   '_',
#   'sila[unit]N',
#   'niŋara[groats]N',
#   'emebala[translator]N',
#   '_',
#   'sila[unit]N',
#   'išah[lard]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'zid[flour]N',
#   'Ur.kun[00]PN',
#   'Da.da[00]PN'],
#  ['_',
#   'kaš[beer]N',
#   'dug[pot]N',
#   'kugsig[gold]N',
#   '_',
#   'kaš[beer]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'kaš[beer]N',
#   '_',
#   'sila[unit]N',
#   'ninda[bread]N',
#   'Inim.du₁₁[00]PN',
#   '_',
#   'kaš[beer]N',
#   '_',
#   'ninda[bread]N',
#   '_',
#   '_'],
#  ['_',
#   'dug[pot]N',
#   'inun[ghee]N',
#   '_',
#   'sila[unit]N',
#   'i[oil]N',
#   '_',
#   'X.x[00]PN',
#   'Mu.x[00]PN'],
#  ['_', '_', 'nin.geš.zi.da[00]DN', 'šara₂.i₃.sa₆[00]PN'],
#  ['_',
#   'tug[textile]N',
#   'bardul[garment]N',
#   '_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   'ma[ship]N',
#   'ud[sun]N',
#   'zal[pass]V/t',
#   'zig[rise]V/i',
#   'mu[name]N',
#   'išib[priest]N',
#   'nin.gir₂.su[00]DN'],
#  ['_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   'us[follow]V/t',
#   'ki[place]N',
#   'lu[person]N',
#   'azlag[fuller]N',
#   '_',
#   '_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   'ušbar[weaver]N',
#   'ki[place]N',
#   'šara₂.i₃.sa₆[00]PN',
#   'Gu₃.de₂.a[00]PN'],
#  ['_',
#   '_',
#   'dabin[semolina]N',
#   'ennuŋ[imprisonment]N',
#   '_',
#   'dabin[semolina]N',
#   '_',
#   'sila[unit]N',
#   'niŋara[groats]N',
#   'Sipa.da.ri₂[00]PN',
#   '_',
#   'sila[unit]N',
#   'zid[flour]N',
#   'Ad.da[00]PN',
#   '_',
#   'lal[small]V/i',
#   '_',
#   'ŋuruš[male]N',
#   '_',
#   'sila[unit]N',
#   'zid[flour]N',
#   '_',
#   'niŋara[groats]N',
#   'emebala[translator]N',
#   '_',
#   '_',
#   'lu[person]N',
#   '_',
#   '_',
#   'šah[pig]N',
#   '_',
#   'zid[flour]N',
#   'I₃.lu.lu[00]PN',
#   '_',
#   'zid[flour]N',
#   'Ur.ur[00]PN',
#   'gudug[priest]N',
#   'Šara[1]DN',
#   '_',
#   'dabin[semolina]N',
#   '_',
#   '_',
#   'lu[person]N',
#   'Eb.la[00]SN',
#   'Erin.da[00]PN',
#   'maškim[administrator]N',
#   '_',
#   'niŋara[groats]N',
#   'Ur.iškur[00]PN',
#   '_',
#   'zid[flour]N',
#   'Du₁₁.ga[00]PN',
#   'nanše.bi₂.du₁₁[00]PN',
#   'maškim[administrator]N',
#   'Da.da[00]PN'],
#  ['_',
#   '_',
#   'ŋeš[tree]N',
#   'gal[big]V/i',
#   '_',
#   'ŋeš[tree]N',
#   'us[follow]V/t',
#   '_',
#   '_',
#   'ŋeš[tree]N',
#   'edak[container]N',
#   '_',
#   'ŋeš[tree]N',
#   'Zi.nu₂[00]PN',
#   '_',
#   'ŋeš[tree]N',
#   'emesig[plank]N',
#   '_',
#   'ŋeš[tree]N',
#   'miriza[plank]N',
#   '_',
#   '_',
#   'ŋeš[tree]N',
#   'barda[crossbar]N',
#   'ŋeš[tree]N',
#   'namgaʾeš[trade]N',
#   'Gu₂.ab.ba[00]SN',
#   'lu[person]N',
#   'Nigin₆[00]SN',
#   'šu[hand]N',
#   'teŋ[near]V/i'],
#  ['_',
#   'kud[fish]N',
#   'kunzid[fish]N',
#   '_',
#   'kud[fish]N',
#   'dar[split]V/t',
#   '_',
#   'kud[fish]N',
#   'Gu₂.ba.lu.a[00]PN',
#   '_',
#   'sila[unit]N',
#   'kud[fish]N',
#   'niŋki[herd]N',
#   '_',
#   'sila[unit]N',
#   'kud[fish]N',
#   'suhur[carp]N',
#   '_',
#   'sila[unit]N',
#   'kud[fish]N',
#   'saŋsur[fish]N',
#   '_',
#   'itud[moon]N',
#   'gid[length]N',
#   '_',
#   'gub[stand]V/i',
#   'u[grass]N',
#   'de[carry]V/t',
#   'šara₂.i₃.sa₆[00]PN'],
#  ['_',
#   'idgurum[ladle]N',
#   'iŋeš[oil]N',
#   'lu[person]N',
#   'Gu.ša[00]SN',
#   '_',
#   'lu[person]N',
#   'Ur.ab.ba[00]PN',
#   '_',
#   'guza[chair]N',
#   'šara₂.i₃.sa₆[00]PN'],
#  ['_',
#   'tug[textile]N',
#   'guz[tufted]V/i',
#   'Ma₂.gan[00]SN',
#   'ŋiri[foot]N',
#   'Ur.e₂.gal[00]PN',
#   'Ba.zi.ge[00]PN'],
#  ['_',
#   'lu[person]N',
#   'dal[fly]V/i',
#   '_',
#   'Da.da[00]PN',
#   'DIŠ[00]PN',
#   'zagmuk[new-year]N',
#   'DIŠ[00]PN',
#   'Ur.ga₂[00]PN',
#   'DIŠ[00]PN',
#   'Lugal.bad₃[00]PN',
#   'DIŠ[00]PN',
#   '_',
#   'DIŠ[00]PN',
#   'Nimgir.eš₃[00]PN',
#   'lu[person]N',
#   'dal[fly]V/i',
#   '_',
#   'Ambar[00]SN',
#   '_',
#   'Ur.eš₃[00]PN',
#   '_',
#   'niŋir[herald]N',
#   '_',
#   'lugal[king]N',
#   '_',
#   'Ur.nigar[00]PN',
#   '_',
#   'Zu.zu[00]PN',
#   '_',
#   'Ur.lu₂[00]PN',
#   '_',
#   'Ur.tur[00]PN',
#   '_',
#   '_',
#   '_',
#   'Sag.zi[00]PN',
#   '_',
#   'Lugal.anzu₂[00]PN',
#   '_',
#   '_',
#   '_',
#   'Lugal.dumu.gi₇[00]PN',
#   '_',
#   '_',
#   '_',
#   '_'],
#  ['_',
#   'sila[unit]N',
#   'inun[ghee]N',
#   '_',
#   'zulum[date]N',
#   '_',
#   'sila[unit]N',
#   'gaʾar[cheese]N',
#   'gal[big]V/i',
#   '_',
#   '_',
#   'sila[unit]N',
#   'inun[ghee]N',
#   '_',
#   'zulum[date]N',
#   '_',
#   'sila[unit]N',
#   'gaʾar[cheese]N',
#   '_',
#   'šara₂.i₃.sa₆[00]PN'],
#  ['_',
#   'ŋirlam[basket]N',
#   'zulum[date]N',
#   '_',
#   'sila[unit]N',
#   'Ur.dun[00]PN',
#   '_',
#   'Geme₂.ba[00]PN',
#   '_',
#   'Geme₂.šul.pa.e₃[00]PN',
#   '_',
#   'Nin.al.la[00]PN',
#   '_',
#   'Me.me[00]PN',
#   '_',
#   '_',
#   '_',
#   '_',
#   'E₂.zi[00]PN',
#   'šagia[cup-bearer]N',
#   '_',
#   'Lu₂.eridu[00]PN',
#   'itud[moon]N',
#   'UR[1]MN'],
#  ['_',
#   'tug[textile]N',
#   'guz[tufted]V/i',
#   'us[follow]V/t',
#   'Ma₂.gan[00]SN',
#   'ŋiri[foot]N',
#   'Lam.lam.ma[00]PN',
#   'dumu[child]N',
#   'lugal[king]N',
#   '_',
#   'tug[textile]N',
#   'guz[tufted]V/i',
#   'us[follow]V/t',
#   'Ad.da.mu[00]PN',
#   'dumu[child]N',
#   'saŋŋa[official]N',
#   'nin.gir₂.su[00]DN',
#   'Ba.zi.ge[00]PN'],
#  ['_', 'dumu[child]N', 'Ur.lugal[00]PN'],
#  ['_',
#   'giŋ[ax]N',
#   'kugbabbar[silver]N',
#   'ŋiri[foot]N',
#   'Lunanna[1]PN',
#   'guzala[official]N',
#   '_',
#   'mana[unit]N',
#   'ŋiri[foot]N',
#   'Ur.ba.gara₂[00]PN',
#   'dumu[child]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'giŋ[unit]N',
#   'kug[metal]N',
#   'kug[metal]N',
#   'agul[an-administrative-term]N',
#   'gi[reed]N',
#   '_',
#   'ŋiri[foot]N',
#   'Lunanna[1]PN',
#   'u[and]CNJ',
#   'Ur.ba.ba₆[00]PN',
#   'guzala[official]N',
#   '_',
#   'eʾuduk[sheephouse]N',
#   'gibil[new]V/i',
#   '_',
#   'Lu₂.du₁₀.ga[00]PN',
#   'dumu[child]N',
#   '_',
#   'kal[rare]V/i',
#   '_',
#   'nin.gir₂.su[00]DN',
#   'dumu[child]N',
#   '_',
#   '_',
#   '_',
#   'šuniŋin[total]N',
#   '_',
#   'mana[unit]N',
#   '_',
#   '_',
#   'giŋ[unit]N',
#   'kug[metal]N',
#   '_',
#   'ki[place]N',
#   'Da.da[00]PN',
#   'dumu[child]N',
#   'U₂.U₂[00]PN',
#   '_',
#   'dumu[child]N',
#   'Na.silim[00]PN',
#   'šu[hand]N',
#   'teŋ[near]V/i'],
#  ['_',
#   'kud[fish]N',
#   '_',
#   'Ur.ma.ma[00]PN',
#   'šu[hand]N',
#   'teŋ[near]V/i',
#   'nin.gir₂.su.igi.du[00]PN'],
#  ['ki[place]N',
#   '_',
#   'im[clay]N',
#   '_',
#   '_',
#   'Ha.x[00]PN',
#   '_',
#   'Ur.X[1]PN',
#   '_',
#   'Lugal.x[00]PN',
#   '_',
#   'Ur.X[1]PN',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'Ur.X[1]PN',
#   '_',
#   'Ur.nin.geš.zi.da[00]PN',
#   '_',
#   '_',
#   '_',
#   'Lu₂.x[00]PN',
#   'erin[people]N',
#   '_',
#   '_',
#   'Ka₅.a[00]PN',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'Al.la[00]PN',
#   'Šeš.x[00]PN',
#   '_',
#   '_',
#   'im[clay]N',
#   'taka[abandon]V/t',
#   'šu[hand]N',
#   '_',
#   '_',
#   '_',
#   'UN.IL₂[menial]N',
#   '_',
#   'dumu[child]N',
#   'A.ku.ri[00]PN',
#   '_',
#   'dumu[child]N',
#   '_',
#   '_',
#   '_',
#   'Gu₄.geš[00]PN',
#   'ki[place]N',
#   '_',
#   '_',
#   'gud[ox]N',
#   'ki[place]N',
#   'Lu₂.x[00]PN',
#   '_',
#   'gud[ox]N',
#   'ki[place]N',
#   'X.x[00]PN',
#   'ki[place]N',
#   'Lu₂.x[00]PN'],
#  ['_',
#   'u[ewe]N',
#   '_',
#   'udunita[ram]N',
#   'E₂.ki[00]PN',
#   'ugula[overseer]N',
#   'saŋŋa[official]N',
#   'nin.geš.zi.da[00]DN',
#   '_',
#   'Da.a.ti[00]PN',
#   '_',
#   'u[ewe]N',
#   '_',
#   'udunita[ram]N',
#   'Ur.gigir[00]PN',
#   'dumu[child]N',
#   '_',
#   '_',
#   'u[ewe]N',
#   '_',
#   '_',
#   'u[ewe]N',
#   'Lu₂.uru₁₁[00]PN',
#   'dumu[child]N',
#   'Erin.da[00]PN',
#   '_',
#   'u[ewe]N',
#   '_',
#   'ud[sun]N',
#   '_',
#   '_',
#   'u[ewe]N',
#   'Ur.dun[00]PN',
#   'ugula[overseer]N',
#   'saŋŋa[official]N',
#   'Šulpae[1]DN',
#   '_',
#   'udu[sheep]N',
#   '_',
#   'e[house]N',
#   '_',
#   'ugula[overseer]N',
#   '_',
#   '_',
#   'ud[sun]N',
#   '_'],
#  ['_',
#   '_',
#   '_',
#   '_',
#   'sila[unit]N',
#   'zid₂.KA[flour]N',
#   'gur[unit]N',
#   'A.ga.de₃[00]SN',
#   'Giri₃.ni[00]PN',
#   '_',
#   '_',
#   '_',
#   'lal[small]V/i',
#   '_',
#   '_',
#   '_',
#   'sila[unit]N',
#   'niŋara[groats]N',
#   'gur[unit]N',
#   'da[line]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'sila[unit]N',
#   'gur[unit]N',
#   '_',
#   'gur[unit]N',
#   'še[barley]N',
#   'dirig[exceed]V/i',
#   '_',
#   '_',
#   'gur[unit]N',
#   'Lugal.iri.da[00]PN',
#   'šu[hand]N',
#   'teŋ[near]V/i',
#   'Ur.lamma[00]PN'],
#  ['_',
#   'mana[unit]N',
#   'anna[metal]N',
#   'zabar[bronze]N',
#   'lugal[king]N',
#   '_',
#   'mana[unit]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   'mana[unit]N',
#   '_',
#   '_',
#   'giŋ[ax]N',
#   'gal[big]V/i',
#   'Erin.da[00]PN',
#   'šu[hand]N',
#   'teŋ[near]V/i'],
#  ['_',
#   '_',
#   'X.zi[00]FN',
#   '_',
#   '_',
#   '_',
#   'X.ni[00]PN',
#   '_',
#   'unu[adornment]N',
#   '_',
#   '_',
#   'šuniŋin[total]N',
#   'DIŠ[00]PN',
#   'ŋuruš[male]N',
#   'šuniŋin[total]N',
#   '_',
#   'dumunita[son]N',
#   'šuniŋin[total]N',
#   'AŠ[00]PN',
#   'dumunita[son]N',
#   'šuniŋin[total]N',
#   'AŠ[00]PN',
#   'dumunita[son]N',
#   'gaba[chest]N',
#   'šuniŋin[total]N',
#   '_',
#   'dumumunus[daughter]N',
#   'gaba[chest]N',
#   'lu[person]N',
#   'azlag[fuller]N',
#   '_',
#   'DIŠ[00]PN',
#   'Dingir.ama[00]PN',
#   '_',
#   'Nin.he₂.gal₂[00]PN',
#   'AŠ[00]PN',
#   'dumu[child]N',
#   '_',
#   'dumu[child]N',
#   '_',
#   '_',
#   '_',
#   'X[1]DN',
#   '_',
#   '_',
#   '_',
#   'Geme₂.x[00]PN',
#   'X[1]DN',
#   '_',
#   'Gu.x[00]PN',
#   '_',
#   '_',
#   '_',
#   'en[priest]N',
#   '_',
#   '_',
#   'Lušara[1]PN',
#   '_',
#   'Gu₃.de₂.a[00]PN',
#   'ensik[ruler]N'],
#  ['_',
#   'guza[chair]N',
#   '_',
#   'ŋešabak[tree]N',
#   'kugsig[gold]N',
#   'ŋar[place]V/t',
#   '_',
#   'guza[chair]N',
#   'šuniŋin[total]N',
#   'halub[tree]N',
#   'kugsig[gold]N',
#   'ŋar[place]V/t',
#   '_',
#   'lal[small]V/i',
#   '_',
#   'guza[chair]N',
#   'šuniŋin[total]N',
#   '_',
#   'lal[small]V/i',
#   '_',
#   'guza[chair]N',
#   'gid[long]V/i',
#   '_',
#   'guza[chair]N',
#   'munus[woman]N',
#   '_',
#   '_',
#   'guza[chair]N',
#   'munus[woman]N',
#   'Lugal.inim.du₁₀[00]PN',
#   'šu[hand]N',
#   'teŋ[near]V/i'],
#  ['_',
#   'pana[bow]N',
#   'Ur.li[00]PN',
#   '_',
#   'sila[unit]N',
#   'lal[syrup]N',
#   '_',
#   'zulum[date]N',
#   '_',
#   'sila[unit]N',
#   'gaʾar[cheese]N',
#   '_',
#   'sila[unit]N',
#   'hašhur[apple]N',
#   '_',
#   'sila[unit]N',
#   'ŋipar[tree]N',
#   '_',
#   'šergu[string]N',
#   'peš[fig]N',
#   'Mes.gal₂.nanna[00]PN',
#   '_',
#   'sila[unit]N',
#   'lal[syrup]N',
#   '_',
#   'sila[unit]N',
#   'zulum[date]N',
#   '_',
#   'sila[unit]N',
#   'gaʾar[cheese]N',
#   '_',
#   'sila[unit]N',
#   'hašhur[apple]N',
#   '_',
#   'sila[unit]N',
#   'ŋipar[tree]N',
#   '_',
#   'kuš[unit]N',
#   'peš[fig]N',
#   'An.ta.mu.zu[00]PN',
#   'šara₂.i₃.sa₆[00]PN'],
#  ['_',
#   'Sag.x[00]PN',
#   'ki[place]N',
#   'Ba.zi.ge[00]PN',
#   '_',
#   'saŋnita[man]N',
#   'šagdug[~animals]N',
#   'mašdarea[payment]N',
#   'ensik[ruler]N',
#   '_',
#   'kugla[silver-weigher]N',
#   'mu.DU[delivery]N',
#   'Mes.e₂[00]PN',
#   'dab[seize]V/t'],
#  ['_',
#   'šaŋan[flask]N',
#   'i[oil]N',
#   'Ur.šul.pa.e₃[00]PN',
#   '_',
#   'ŋirigub[footstool]N',
#   '_',
#   'gin[firm]V/i',
#   'šara₂.i₃.sa₆[00]PN'],
#  ['_',
#   'gaʾar[cheese]N',
#   'gur[unit]N',
#   'A.ga.de₃[00]SN',
#   'ki[place]N',
#   'egal[palace]N',
#   'E.ta.e₁₁[00]PN'],
#  ['_', 'udu[sheep]N', 'niga[fattened]V/i', 'Ninagalak[1]DN'],
#  ['_',
#   'tug[textile]N',
#   'bardul[garment]N',
#   '_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   '_',
#   'tug[textile]N',
#   'bur[bowl]N',
#   'Ur.iškur[00]PN',
#   'nar[musician]N',
#   '_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   'lu[person]N',
#   'marsa[shipyard]N',
#   'Lugal.inim.du₁₀[00]PN'],
#  ['_',
#   'kugbabbar[silver]N',
#   'Lu₂.ba.ba₆[00]PN',
#   'saŋ[head]N',
#   'niŋgur[property]N',
#   'ŋar[place]V/t',
#   'šara₂.i₃.sa₆[00]PN',
#   'mu[name]N',
#   'šitaʾaba[priest]N',
#   'maš[goat]N',
#   'pad[find]V/t'],
#  ['Tu.ra.am.i₃.li₂[00]PN', 'dumu[child]N', 'I₇.da[00]PN'],
#  ['_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'še[barley]N',
#   'gur[unit]N',
#   'saŋ[head]N',
#   'ŋal[be]V/i',
#   '_',
#   '_',
#   '_',
#   'ziz[emmer]N',
#   'gur[unit]N',
#   'mu[name]N',
#   'id[river]N',
#   'nin.gir₂.su.ušumgal[00]PN',
#   'bal[dig]V/t',
#   '_',
#   '_',
#   '_',
#   '_',
#   'še[barley]N',
#   'gur[unit]N',
#   'saŋ[head]N',
#   'ŋal[be]V/i',
#   '_',
#   '_',
#   '_',
#   '_',
#   'ziz[emmer]N',
#   'gur[unit]N',
#   '_',
#   'kib[wheat]N',
#   'gur[unit]N',
#   'mu[name]N',
#   'balaŋ[instrument]N',
#   'Ušumgal.kalam.ma[00]PN',
#   'dim[create]V/t',
#   '_',
#   '_',
#   '_',
#   '_',
#   'gur[unit]N',
#   '_',
#   'lal[small]V/i',
#   '_',
#   'ziz[emmer]N',
#   'gur[unit]N',
#   '_',
#   '_',
#   'kib[wheat]N',
#   'gur[unit]N',
#   'mu[name]N',
#   '_',
#   'du[build]V/t',
#   'še[barley]N',
#   'ŋeš[tree]N',
#   'rah[beat]V/t',
#   'mu[year]N',
#   '_',
#   'ki[place]N',
#   'šabra[administrator]N',
#   'en[priest]N',
#   '_',
#   'še[barley]N',
#   'gur[unit]N',
#   'A.ga.de₃[00]SN',
#   'ki[place]N',
#   'Lugal.gaba[00]PN',
#   '_',
#   '_',
#   '_',
#   'gu[neck]N',
#   '_',
#   '_',
#   'mana[unit]N',
#   'siki[hair]N',
#   'mu[year]N',
#   '_',
#   '_',
#   '_',
#   'gu[neck]N',
#   'lal[small]V/i',
#   '_',
#   'mana[unit]N',
#   'siki[hair]N',
#   'mu[name]N',
#   'Nunuz.za.bu[00]PN',
#   '_',
#   'lal[small]V/i',
#   '_',
#   'dug[pot]N',
#   'inun[ghee]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   'sila[unit]N',
#   'gaʾar[cheese]N'],
#  ['_',
#   '_',
#   'gur[unit]N',
#   'A.ga.de₃[00]SN',
#   'sadug[offerings]N',
#   'Enlil[1]DN',
#   '_',
#   'gur[unit]N',
#   'niŋ[thing]N',
#   'ezem[festival]N',
#   'Ur.ab.ba[00]PN',
#   'du[go]V/i',
#   'Lu₂.inanna[00]PN'],
#  ['_',
#   'gada[flax]N',
#   'sag[rare]V/i',
#   'iri[city]N',
#   '_',
#   '_',
#   'šaŋan[flask]N',
#   'i[oil]N',
#   '_',
#   '_',
#   'dar[split]V/t',
#   '_',
#   '_',
#   'Gu₃.de₂.a[00]PN',
#   'šu[hand]N',
#   'teŋ[near]V/i',
#   'Lugal.inim.du₁₀[00]PN'],
#  ['_',
#   'gada[flax]N',
#   'gudug[priest]N',
#   '_',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   'guz[tufted]V/i',
#   'lu[person]N',
#   'Za.ul[00]SN',
#   'Lu₂.dingir[00]PN',
#   'maškim[administrator]N',
#   'Gu₃.de₂.a[00]PN'],
#  ['mu[name]N',
#   'erešdiŋir[priestess]N',
#   'X[1]DN',
#   '_',
#   'mu[name]N',
#   '_',
#   'mu[name]N',
#   'šita[weapon]N',
#   '_',
#   'nin.gir₂.su[00]DN',
#   'dim[create]V/t',
#   'mu[name]N',
#   'e[house]N',
#   'Nindara[1]DN',
#   'du[build]V/t',
#   'u[and]CNJ',
#   'mu[name]N',
#   'mitum[weapon]N',
#   'saŋ[head]N',
#   'ninnu[fifty]NU',
#   'dim[create]V/t',
#   'mu[name]N',
#   'šita[weapon]N',
#   '_',
#   'nin.gir₂.su[00]DN',
#   'dim[create]V/t',
#   'mu[name]N',
#   'e[house]N',
#   'Nindara[1]DN',
#   'du[build]V/t',
#   'mu[name]N',
#   'mitum[weapon]N',
#   'saŋ[head]N',
#   'ninnu[fifty]NU',
#   'dim[create]V/t',
#   'ugula[overseer]N',
#   'Lugal.e₂.gid₂[00]PN'],
#  ['_',
#   'še[barley]N',
#   'gur[unit]N',
#   'A.ga.de₃[00]SN',
#   '_',
#   '_',
#   'gur[unit]N',
#   'Ur.mes[00]PN',
#   'ugula[overseer]N',
#   'agaʾus[soldier]N',
#   'tum[bring]V/t',
#   '_'],
#  ['_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'še[barley]N',
#   'dumu[child]N',
#   '_',
#   'saŋnita[man]N',
#   '_',
#   'Dingir.ma[00]PN',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'dumumunus[daughter]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'Na.x[00]PN',
#   'dumumunus[daughter]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'dumumunus[daughter]N',
#   '_',
#   '_',
#   '_',
#   'endu[song]N',
#   '_',
#   'Gu.u₂.gu.a[00]PN',
#   '_',
#   'Dingir.ma[00]PN',
#   '_',
#   'gu[cord]N',
#   'dumumunus[daughter]N',
#   '_'],
#  ['_',
#   'sila[unit]N',
#   'inun[ghee]N',
#   '_',
#   'sila[unit]N',
#   'lal[syrup]N',
#   '_',
#   'sila[unit]N',
#   'zulum[date]N',
#   '_',
#   'sila[unit]N',
#   'gaʾar[cheese]N',
#   '_',
#   'sila[unit]N',
#   'hašhur[apple]N',
#   '_',
#   'sila[unit]N',
#   'ŋipar[tree]N',
#   '_',
#   'sila[unit]N',
#   'ŋeštin[vine]N',
#   '_',
#   'sila[unit]N',
#   'mudum[fruit]N',
#   '_',
#   'šergu[string]N',
#   'peš[fig]N',
#   'lugal[king]N',
#   'Gu₄.ra₂[00]PN',
#   'maškim[administrator]N',
#   '_',
#   'lu[person]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'inun[ghee]N',
#   '_',
#   'sila[unit]N',
#   'lal[syrup]N',
#   '_',
#   'sila[unit]N',
#   'zulum[date]N',
#   '_',
#   'sila[unit]N',
#   'gaʾar[cheese]N',
#   '_',
#   'sila[unit]N',
#   'hašhur[apple]N',
#   '_',
#   'sila[unit]N',
#   'ŋipar[tree]N',
#   '_',
#   'sila[unit]N',
#   'ŋeštin[vine]N',
#   '_',
#   'sila[unit]N',
#   'mudum[fruit]N',
#   '_',
#   'šergu[string]N',
#   'peš[fig]N',
#   'Gu.ša[00]SN',
#   '_',
#   'ŋirigub[footstool]N',
#   '_',
#   'idgurum[ladle]N',
#   'iŋeš[oil]N',
#   '_',
#   'sila[unit]N',
#   'inun[ghee]N',
#   '_',
#   'sila[unit]N',
#   'lal[syrup]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'zulum[date]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'gaʾar[cheese]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'hašhur[apple]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'ŋipar[tree]N',
#   '_',
#   'sila[unit]N',
#   'ŋeštin[vine]N',
#   '_',
#   'sila[unit]N',
#   'mudum[fruit]N',
#   '_',
#   '_',
#   'šergu[string]N',
#   'peš[fig]N',
#   'dam[spouse]N',
#   'Gu.ša[00]SN',
#   '_',
#   'sila[unit]N',
#   'inun[ghee]N',
#   '_',
#   'sila[unit]N',
#   'lal[syrup]N',
#   '_',
#   'sila[unit]N',
#   'zulum[date]N',
#   '_',
#   'sila[unit]N',
#   'gaʾar[cheese]N',
#   '_',
#   'sila[unit]N',
#   'hašhur[apple]N',
#   '_',
#   'sila[unit]N',
#   'ŋipar[tree]N',
#   '_',
#   'sila[unit]N',
#   'ŋeštin[vine]N',
#   '_',
#   'sila[unit]N',
#   'mudum[fruit]N',
#   'dumu[child]N',
#   'Gu.ša[00]SN',
#   'Ur.li[00]PN',
#   'maškim[administrator]N',
#   '_',
#   'pana[bow]N',
#   '_',
#   'sila[unit]N',
#   'inun[ghee]N',
#   '_',
#   'sila[unit]N',
#   'lal[syrup]N',
#   '_',
#   'sila[unit]N',
#   'zulum[date]N',
#   '_',
#   'sila[unit]N',
#   'gaʾar[cheese]N',
#   '_',
#   'sila[unit]N',
#   'hašhur[apple]N',
#   '_',
#   'sila[unit]N',
#   'ŋipar[tree]N',
#   '_',
#   'sila[unit]N',
#   'ŋeštin[vine]N',
#   '_',
#   'sila[unit]N',
#   'mudum[fruit]N',
#   '_',
#   'šergu[string]N',
#   'peš[fig]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'inun[ghee]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'inun[ghee]N',
#   '_',
#   'sila[unit]N',
#   'zulum[date]N',
#   '_',
#   'giŋ[unit]N',
#   'lal[syrup]N',
#   'emuhaldim[kitchen]N',
#   'šara₂.i₃.sa₆[00]PN'],
#  ['_',
#   '_',
#   '_',
#   '_',
#   'gur[unit]N',
#   'lugal[king]N',
#   'ennuŋ[imprisonment]N',
#   'lu[person]N',
#   'dab[seize]V/t',
#   'Da.da[00]PN'],
#  ['_',
#   '_',
#   '_',
#   'lal[small]V/i',
#   '_',
#   'še[barley]N',
#   'gur[unit]N',
#   'sadug[offerings]N',
#   '_',
#   '_',
#   '_',
#   'ziz[emmer]N',
#   'gur[unit]N',
#   '_',
#   '_',
#   'kib[wheat]N',
#   'gur[unit]N',
#   'mu[name]N',
#   'Gu₃.de₂.a[00]PN',
#   'ensik[ruler]N',
#   'gu[neck]N',
#   'siki[hair]N',
#   'uzud[goat]N',
#   '_',
#   'še[barley]N',
#   'gur[unit]N',
#   '_',
#   '_',
#   'ziz[emmer]N',
#   'gur[unit]N',
#   'kiʾanaŋ[locus]N',
#   'mu[name]N',
#   'balaŋ[instrument]N',
#   'ušumgal[dragon]N',
#   'kalam[land]N',
#   'dim[create]V/t',
#   'Erin.da[00]PN',
#   'en[priest]N',
#   'šu[hand]N',
#   'teŋ[near]V/i'],
#  ['_',
#   'guza[chair]N',
#   'šuniŋin[total]N',
#   'Šeš.ab.ba[00]PN',
#   '_',
#   'guza[chair]N',
#   'gid[long]V/i',
#   'Ur.ab.ba[00]PN',
#   'ragaba[rider]N',
#   'Me.luh.ha[00]PN',
#   '_',
#   'guza[chair]N',
#   'šuniŋin[total]N',
#   '_',
#   '_',
#   'guza[chair]N',
#   'munus[woman]N',
#   '_',
#   'Lugal.inim.du₁₀[00]PN'],
#  ['_',
#   'dab[seize]V/t',
#   '_',
#   'tug[textile]N',
#   'bur[bowl]N',
#   'ensik[ruler]N',
#   '_',
#   'dab[seize]V/t',
#   'ugula[overseer]N',
#   'Lu₂.dumu.zi[00]PN',
#   '_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   'ula[garment]N',
#   'sag[rare]V/i',
#   '_',
#   'dab[seize]V/t',
#   '_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   'sag[rare]V/i',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   'guz[tufted]V/i',
#   'Erin.da[00]PN',
#   'dab[seize]V/t',
#   'ugula[overseer]N',
#   'Al.la[00]PN',
#   '_',
#   'tug[textile]N',
#   'guʾe[textile]N',
#   'sag[rare]V/i',
#   'Erin.da[00]PN',
#   'dab[seize]V/t',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   'guz[tufted]V/i',
#   '_',
#   'dab[seize]V/t',
#   '_',
#   'Ur.ga₂[00]PN',
#   'dab[seize]V/t',
#   '_',
#   'hal[basket]N',
#   'dab[seize]V/t',
#   '_',
#   'Ur.nig₂[00]PN',
#   '_',
#   '_',
#   '_',
#   'gada[flax]N',
#   'saŋ[head]N',
#   'šaggu[~linen]N',
#   'Lugal.e₂.gid₂[00]PN',
#   'dab[seize]V/t',
#   '_',
#   'lugal[king]N',
#   'AŠ[00]PN',
#   '_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   'sag[rare]V/i',
#   'Ur.ga₂[00]PN',
#   'dab[seize]V/t',
#   '_',
#   'tug[textile]N',
#   'guʾe[textile]N',
#   'sag[rare]V/i',
#   'gigir.re[00]PN',
#   'dab[seize]V/t',
#   '_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   'us[follow]V/t',
#   '_',
#   'dab[seize]V/t',
#   'ugula[overseer]N',
#   'Gu₃.de₂.a[00]PN',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   'guz[tufted]V/i',
#   'sag[rare]V/i',
#   'lugal[king]N',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   'guz[tufted]V/i',
#   'us[follow]V/t',
#   'lugal[king]N',
#   'hal[basket]N',
#   'dab[seize]V/t',
#   'ugula[overseer]N',
#   'elam[highland]N',
#   '_',
#   '_',
#   '_'],
#  ['_',
#   'idgurum[ladle]N',
#   'iŋeš[oil]N',
#   'Sipa.da.ri₂[00]PN',
#   'ugula[overseer]N',
#   '_',
#   'Nigar.ki.du₁₀[00]PN',
#   '_',
#   '_',
#   '_',
#   'suen.kal[00]PN',
#   '_',
#   'ad.KID[weaver]N'],
#  ['_',
#   'maš[goat]N',
#   '_',
#   'šeŋbar[animal]N',
#   'dumu[child]N',
#   '_',
#   'mu.DU[delivery]N'],
#  ['Ur.an.na[00]PN', 'dumu[child]N', 'ur[root]N'],
#  ['_',
#   'kud[fish]N',
#   '_',
#   'dar[split]V/t',
#   '_',
#   'kud[fish]N',
#   'niŋki[herd]N',
#   '_',
#   'kud[fish]N',
#   '_',
#   'I₃.la.la[00]PN',
#   'šara₂.i₃.sa₆[00]PN'],
#  ['_',
#   'kuš[skin]N',
#   'udunita[ram]N',
#   '_',
#   '_',
#   'kuš[skin]N',
#   'sila[lamb]N',
#   '_',
#   '_',
#   'dim[post]N',
#   '_',
#   '_',
#   'lutukul[soldier]N',
#   '_',
#   'saŋŋa[official]N',
#   'nin.gir₂.su[00]DN',
#   'mu[name]N',
#   'šitaʾaba[priest]N',
#   'maš[goat]N',
#   'pad[find]V/t'],
#  ['_',
#   'guza[chair]N',
#   '_',
#   'Ur.iškur[00]PN',
#   '_',
#   'guza[chair]N',
#   'munus[woman]N',
#   'Ur.li[00]PN',
#   'Lugal.inim.du₁₀[00]PN'],
#  ['_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   'guz[tufted]V/i',
#   'šar[~cloth]AJ',
#   '_',
#   '_',
#   'tug[textile]N',
#   'balla[headdress]N',
#   'nin[lady]N',
#   'A.mur.la.ba[00]PN',
#   '_',
#   'X.du[00]PN',
#   'Lugal.ibila[00]PN',
#   'ki[place]N',
#   'Ba.zi.ge[00]PN',
#   '_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   'sag[rare]V/i',
#   'A.mur.la.ba[00]PN',
#   '_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   'sag[rare]V/i',
#   'Ur.nig₂[00]PN',
#   '_',
#   'tug[textile]N',
#   'gula[garment]N',
#   'ula[garment]N',
#   'sag[rare]V/i',
#   '_',
#   'tug[textile]N',
#   'guʾe[textile]N',
#   'sag[rare]V/i',
#   'Ur.nin.mug[00]PN',
#   'ki[place]N',
#   'Ur.li[00]PN',
#   '_',
#   'tug[textile]N',
#   'šagadu[belt]N',
#   'us[follow]V/t',
#   '_',
#   'tug[textile]N',
#   '_',
#   '_',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   'guz[tufted]V/i',
#   'gigir.re[00]PN',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   'guz[tufted]V/i',
#   'A.mur.la.ba[00]PN',
#   '_',
#   'Ur.nin.mug[00]PN',
#   '_',
#   'Lugal.an.na.tum₂[00]PN',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   'guz[tufted]V/i',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   'guz[tufted]V/i',
#   'tur[small]V/i',
#   'Šu.utu[00]PN',
#   'ki[place]N',
#   'Am₃.ma[00]PN',
#   'lu[person]N',
#   'azlag[fuller]N',
#   'šu[hand]N',
#   'teŋ[near]V/i',
#   'itud[moon]N',
#   'šunumun[seed]N',
#   'mu[name]N',
#   'tukul[weapon]N',
#   'mitum[weapon]N',
#   'saŋ[head]N',
#   'ninnu[fifty]NU',
#   'dim[create]V/t'],
#  ['_',
#   '_',
#   'dumu[child]N',
#   'Lugal.sipa[00]PN',
#   'Lu₂.banda₃[00]PN',
#   'dab[seize]V/t',
#   '_',
#   'Ur.bil₃[00]PN',
#   'dumu[child]N',
#   '_',
#   '_',
#   'Lu₂.nanše[00]PN',
#   'dumu[child]N',
#   'Gissu[00]PN',
#   'Ur.nu[00]PN',
#   'dab[seize]V/t',
#   'šuniŋin[total]N',
#   '_',
#   'ŋuruš[male]N',
#   'Ur.nu[00]PN',
#   'mu.DU[delivery]N'],
#  ['Ur.ab.ba[00]PN',
#   'ensik[ruler]N',
#   'Lagaš[00]SN',
#   'Ba.sa₆[00]PN',
#   'bisaŋdubak[archivist]N',
#   'arad[slave]N'],
#  ['_',
#   '_',
#   'sila[unit]N',
#   'zidgu[flour]N',
#   'sadug[offerings]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'zidgu[flour]N',
#   'sag[rare]V/i',
#   '_',
#   'zidsig[flour]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'arzana[groats]N',
#   '_',
#   'sila[unit]N',
#   'niŋara[groats]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'niŋara[groats]N',
#   'imŋaŋa[emmer]N',
#   'sadug[offerings]N',
#   '_',
#   'zid[flour]N',
#   'nar[musician]N',
#   '_',
#   'zid[flour]N',
#   'ugula[overseer]N',
#   'emebala[translator]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'zidgu[flour]N',
#   'sag[rare]V/i',
#   '_',
#   '_',
#   'sila[unit]N',
#   'zid[flour]N',
#   'urnim[lion]N',
#   '_',
#   '_',
#   'sila[unit]N',
#   'zid[flour]N',
#   'Du₁₁.ga[00]PN',
#   '_',
#   '_',
#   'sila[unit]N',
#   'Lu₂.dumu.zi[00]PN',
#   '_',
#   'sila[unit]N',
#   'zid[flour]N',
#   'maššugidgid[diviner]N',
#   '_',
#   'sila[unit]N',
#   'zid[flour]N',
#   'magur[barge]N',
#   '_',
#   'zid[flour]N',
#   'ennuŋ[imprisonment]N',
#   '_',
#   'sila[unit]N',
#   'zid[flour]N',
#   'I₃.la.la[00]PN'],
#  ['_',
#   '_',
#   'saŋ[head]N',
#   'nita[male]N',
#   'mašdarea[payment]N',
#   'Sipa.iri.na[00]PN',
#   'kugla[silver-weigher]N',
#   'mu.DU[delivery]N'],
#  ['_', 'Aya[1]DN'],
#  ['_',
#   'kud[fish]N',
#   '_',
#   '_',
#   'zulum[date]N',
#   'Da.ga.za.na.ar[00]PN',
#   'Ur.utu[00]PN',
#   'maškim[administrator]N',
#   '_',
#   'kud[fish]N',
#   '_',
#   '_',
#   'zulum[date]N',
#   'inanna[00]PN',
#   'Lu₂.utu[00]PN',
#   'maškim[administrator]N',
#   '_',
#   'kud[fish]N',
#   '_',
#   'damgar[merchant]N',
#   'Ur.ba.gara₂[00]PN',
#   'maškim[administrator]N',
#   '_',
#   'Ba.sa₆[00]PN',
#   'Ur.ba.gara₂[00]PN',
#   '_',
#   'sila[unit]N',
#   'išah[lard]N',
#   '_',
#   'Da.da[00]PN'],
#  ['_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   'Gu₃.de₂.a[00]PN',
#   'saŋ[head]N',
#   'niŋgur[property]N',
#   'ŋar[place]V/t',
#   'šara₂.i₃.sa₆[00]PN',
#   'mu[name]N',
#   'e[house]N',
#   'Ba.gara₂[00]TN',
#   'du[build]V/t'],
#  [],
#  ['tug[textile]N',
#   'aktum[garment]N',
#   'guz[tufted]V/i',
#   '_',
#   'am[bull]N',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   'guz[tufted]V/i',
#   'tur[small]V/i',
#   '_',
#   'gada[flax]N',
#   'saŋ[head]N',
#   'gada[flax]N',
#   '_',
#   'bala[turn]V/t',
#   '_',
#   'gada[flax]N',
#   'saŋ[head]N',
#   'šaggu[~linen]N',
#   'ki[place]N',
#   'Lu₂.dingir[00]PN',
#   '_',
#   'zid[flour]N',
#   'gu[cord]N',
#   'gur[unit]N',
#   'A.ga.de₃[00]SN',
#   'ki[place]N',
#   'Ur.mes[00]PN',
#   '_',
#   '_',
#   'ki[place]N',
#   'Lu₂.x[00]PN',
#   '_',
#   'sa[bundle]N',
#   'šum[garlic]N',
#   'sikil[pure]V/i',
#   'ki[place]N',
#   '_',
#   'Ka.sa₆[00]PN',
#   '_',
#   '_',
#   'giŋ[unit]N',
#   'uš[foundation]N',
#   '_',
#   '_',
#   'Ha.ma.ti[00]PN',
#   'arad[slave]N',
#   'lu[person]N',
#   'Mudra₅[00]PN',
#   '_',
#   'Ur.saman₃[00]PN',
#   'arad[slave]N',
#   'nubanda[overseer]N',
#   'egal[palace]N',
#   '_',
#   'Lu₂.ba.ba₆[00]PN',
#   'arad[slave]N',
#   'Ur.en.sig.nun[00]PN',
#   '_',
#   'Šeš.kal.la[00]PN',
#   '_',
#   'Gu₂.tar.la₂[00]PN',
#   '_',
#   'mu[name]N',
#   'didli[several]AJ',
#   'zah[disappear]V/i',
#   '_',
#   '_',
#   '_',
#   'ŋal[be]V/i'],
#  ['_',
#   'šukur[lance]N',
#   '_',
#   'eme[~plow]N',
#   'ŋiri[dagger]N',
#   'Sanga[00]FN',
#   'Zabala₃[00]SN',
#   'e[house]N',
#   'Ša₃.ge.pa₃.da[00]PN',
#   'Umma[00]SN',
#   'X.x[00]PN',
#   '_',
#   '_',
#   '_',
#   'Lugal.kur[00]PN',
#   'dubsar[scribe]N',
#   'de[carry]V/t',
#   '_',
#   'mu[name]N',
#   'itud[moon]N',
#   '_',
#   '_'],
#  ['_',
#   'Ur.zikum.ma[00]PN',
#   'ugula[overseer]N',
#   'saŋŋa[official]N',
#   'nin.geš.zi.da[00]DN',
#   '_',
#   'Ur.ku₃.nun.na[00]PN',
#   'saŋŋa[official]N',
#   '_',
#   'saŋapinak[plowman]N',
#   '_',
#   '_',
#   'gudrah[drover]N',
#   'us[follow]V/t',
#   '_',
#   '_',
#   'erin[people]N',
#   '_',
#   '_',
#   'unud[cowherd]N',
#   '_',
#   'ugula[overseer]N',
#   'saŋŋa[official]N',
#   'Ninšubur[1]DN',
#   '_',
#   'Hu.hu[00]PN',
#   'kuš[official]N',
#   '_',
#   '_',
#   'sipad[shepherd]N',
#   '_',
#   'ugula[overseer]N',
#   'Hu.hu[00]PN',
#   'kuš[official]N',
#   '_',
#   'Na.x[00]PN',
#   '_',
#   '_',
#   'ugula[overseer]N',
#   'Lu₂.x[00]PN',
#   'šuniŋin[total]N',
#   '_',
#   'ŋuruš[male]N',
#   'saŋŋa[official]N',
#   'Ninšubur[1]DN',
#   'dab[seize]V/t',
#   'mu[name]N',
#   'Lu₂.gu.la[00]PN',
#   'ensik[ruler]N'],
#  ['_',
#   'zid[flour]N',
#   'Sig₁₅[00]PN',
#   'gur[unit]N',
#   'A.ga.de₃[00]SN',
#   '_',
#   'zidgu[flour]N',
#   'gur[unit]N',
#   'ki[place]N',
#   'Lugal.gaba[00]PN',
#   '_',
#   'zid[flour]N',
#   'Sig₁₅[00]PN',
#   'gur[unit]N',
#   '_',
#   'zidgu[flour]N',
#   'gur[unit]N',
#   'ki[place]N',
#   'Lu₂.nanše[00]PN',
#   'Lu₂.dumu.zi[00]PN',
#   'du[go]V/i',
#   '_',
#   'erin[people]N',
#   '_',
#   'lu[person]N',
#   'muhaldim[cook]N',
#   'didli[several]AJ',
#   'ennuŋ[imprisonment]N',
#   'e[leave]V/i',
#   'magid[boat-tower]N',
#   'itud[moon]N',
#   '_',
#   '_',
#   'ud[sun]N',
#   'zal[pass]V/t',
#   'ma[ship]N',
#   'ri[impose]V/t'],
#  ['_',
#   'mana[unit]N',
#   'siki[hair]N',
#   'Lugal.ha.ma.ti[00]PN',
#   '_',
#   'mana[unit]N',
#   'dam[spouse]N',
#   'Lu₂.dingir[00]PN',
#   '_',
#   'mana[unit]N',
#   'siki[hair]N',
#   'garig[comb]N',
#   'ak[do]V/t',
#   '_',
#   '_',
#   'mana[unit]N',
#   'siki[hair]N',
#   '_',
#   'mana[unit]N',
#   'siki[hair]N',
#   'mug[wool]N',
#   'Lu₂.nin.gir₂.su[00]PN',
#   '_',
#   'mana[unit]N',
#   'siki[hair]N',
#   'gu₂.TAR[~wool]AJ',
#   'dam[spouse]N',
#   'Šeš.šeš[00]PN',
#   '_',
#   'mana[unit]N',
#   'siki[hair]N',
#   'gu₂.TAR[~wool]AJ',
#   'ba.ba₆.na[00]PN',
#   '_',
#   '_',
#   'mana[unit]N',
#   'tug[textile]N',
#   'aktum[garment]N',
#   'us[follow]V/t',
#   'Lugal.šu.mah[00]PN',
#   'E₂.gissu[00]PN',
#   'mu[name]N',
#   'Lu₂.gu.la[00]PN',
#   'ensik[ruler]N'],
#  ['_',
#   'tug[textile]N',
#   'bardul[garment]N',
#   'Nig₂.du₇[00]PN',
#   '_',
#   'tug[textile]N',
#   'bardul[garment]N',
#   'Ur.nin.su[00]PN',
#   'sukkal[secretary]N',
#   'Ur.nig₂[00]PN',
#   'maškim[administrator]N',
#   'Ur.nigar[00]PN',
#   'mu[name]N',
#   'Nam.mah.ni[00]PN',
#   'us[follow]V/t'],
#  ['_',
#   'zidgu[flour]N',
#   'gur[unit]N',
#   'A.ga.de₃[00]SN',
#   'ugula[overseer]N',
#   'emebala[translator]N',
#   '_',
#   '_',
#   'zidgu[flour]N',
#   'Lu₂.nigin₆[00]PN',
#   '_',
#   '_',
#   'zidgu[flour]N',
#   'Inim.inanna[00]PN',
#   '_',
#   'zidgu[flour]N',
#   'gur[unit]N',
#   '_',
#   'arzana[groats]N',
#   '_',
#   'Lu₂.nanše[00]PN',
#   'en[priest]N',
#   'itud[moon]N',
#   'ezem[festival]N',
#   'Ezemšeʾilak[1]MN',
#   'mu[name]N',
#   'šita[weapon]N',
#   'saŋ[head]N',
#   'ninnu[fifty]NU',
#   'dim[create]V/t'],
#  ['_',
#   '_',
#   '_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   '_',
#   'Ur.bil₃[00]PN',
#   '_',
#   '_',
#   'uš[die]V/i',
#   'Ur.tur[00]PN',
#   'dumu[child]N',
#   'Si.du₃[00]PN',
#   '_',
#   'uš[die]V/i',
#   '_',
#   'malah[sailor]N',
#   '_',
# ...
#   'Zur.zur[00]PN',
#   '_',
#   '_',
#   '_',
#   'lu[person]N',
#   '_',
#   'Ur.mes[00]PN',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'Mes.u₄.ba[00]PN',
#   '_',
#   'Šeš.ki.na[00]PN',
#   'tugdu[felter]N',
#   '_',
#   'Ur.en.ki[00]PN',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'Ur.ab.u₂[00]PN',
#   'mušendu[bird-catcher]N',
#   '_',
#   'lal[small]V/i',
#   '_',
#   '_'],
#  ['Šeš.šeš[00]PN',
#   'ensikgal[steward]N',
#   'Ur.igi[00]PN',
#   '_',
#   'Lugal.hi.li[00]PN',
#   'dumu[child]N',
#   'Gu₃.de₂.a[00]PN',
#   '_',
#   'Ur.šara₂[00]PN',
#   'išib[priest]N'],
#  ['_',
#   '_',
#   '_',
#   '_',
#   'dumu[child]N',
#   'ba[allot]V/t',
#   '_',
#   'namarad[slavery]N',
#   '_',
#   'gin[firm]V/i',
#   '_',
#   'maškim[administrator]N'],
#  ['_',
#   'lal[small]V/i',
#   '_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   'us[follow]V/t',
#   '_',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   'guz[tufted]V/i',
#   '_',
#   'gada[flax]N',
#   'du[go]V/i',
#   '_',
#   'gada[flax]N',
#   'saŋ[head]N',
#   'umbin[nail]N',
#   'bala[turn]V/t',
#   'ki[place]N',
#   'Lugal.iri.da[00]PN',
#   'Lugal.inim.du₁₀[00]PN',
#   'šu[hand]N',
#   'teŋ[near]V/i'],
#  ['Ur.ištaran[00]PN',
#   'e[speak]V/t',
#   'Ab.ba.mu[00]PN',
#   'unadug[letter]N',
#   'anše[equid]N',
#   'si[horn]N',
#   '_',
#   'šukur[ration]N',
#   '_'],
#  ['_',
#   'lal[small]V/i',
#   '_',
#   'gada[flax]N',
#   'Al.la[00]PN',
#   '_',
#   'gada[flax]N',
#   'saŋ[head]N',
#   'šaggu[~linen]N',
#   '_',
#   'gada[flax]N',
#   'saŋ[head]N',
#   '_',
#   'Nimgir.ki.ag₂[00]PN',
#   '_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   'us[follow]V/t',
#   '_',
#   'tug[textile]N',
#   'gula[garment]N',
#   'us[follow]V/t',
#   'U₂.da[00]PN',
#   'ki[place]N',
#   'Ur₅.bi.še₃[00]PN',
#   '_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   '_',
#   '_',
#   'tug[textile]N',
#   'gula[garment]N',
#   '_',
#   '_',
#   '_',
#   'u[grass]N',
#   '_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   '_',
#   '_',
#   'tug[textile]N',
#   'gula[garment]N',
#   'us[follow]V/t',
#   '_',
#   'tug[textile]N',
#   'guʾe[textile]N',
#   'us[follow]V/t',
#   '_',
#   'tug[textile]N',
#   '_',
#   '_',
#   'tug[textile]N',
#   '_',
#   'us[follow]V/t',
#   'Ur.ba.ba₆[00]PN',
#   '_',
#   'gada[flax]N',
#   'Lugal.ibila[00]PN',
#   'ki[place]N',
#   'Lugal.ezem[00]PN',
#   'šu[hand]N',
#   'teŋ[near]V/i',
#   'mu[name]N',
#   'mitum[weapon]N',
#   'saŋ[head]N',
#   'ninnu[fifty]NU'],
#  ['Erin.da[00]PN',
#   'šu[hand]N',
#   'teŋ[near]V/i',
#   '_',
#   'gur[unit]N',
#   'Lu₂.nanše[00]PN',
#   'dumu[child]N',
#   'I₃.si[00]SN',
#   '_',
#   'gur[unit]N',
#   'Lugal.gaba[00]PN',
#   '_',
#   'lal[small]V/i',
#   '_',
#   'gur[unit]N',
#   'Ur.mes[00]PN',
#   '_',
#   '_',
#   'gur[unit]N',
#   'Lu₂.nanše[00]PN',
#   'en[priest]N',
#   '_',
#   'gur[unit]N',
#   'Giri₃.ni[00]PN',
#   '_',
#   '_',
#   '_',
#   'gur[unit]N',
#   'sadug[offerings]N',
#   'Geme₂.ba[00]PN',
#   '_',
#   'gur[unit]N',
#   'Al.mu[00]PN',
#   'ugula[overseer]N',
#   'kinkin[miller]N',
#   'šu[hand]N',
#   'teŋ[near]V/i',
#   'itud[moon]N',
#   'Ezemšesagkud[1]MN'],
#  ['_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   '_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   'munus[woman]N',
#   '_',
#   'tug[textile]N',
#   '_',
#   '_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   'ušbar[weaver]N',
#   '_',
#   'tug[textile]N',
#   'šagadu[belt]N',
#   'ušbar[weaver]N',
#   '_',
#   'tug[textile]N',
#   'bar[outside]N',
#   'ušbar[weaver]N',
#   'im[clay]N',
#   'Ur.nig₂[00]PN',
#   'zig[rise]V/i',
#   'Ur.nig₂[00]PN',
#   'šu[hand]N',
#   'teŋ[near]V/i',
#   'itud[moon]N',
#   'ezem[festival]N',
#   'Ezemšeʾilak[1]MN'],
#  ['_',
#   'uzud[goat]N',
#   '_',
#   'maš[goat]N',
#   'šagdug[~animals]N',
#   '_',
#   'maš[goat]N',
#   'luzah[fugitive]N',
#   '_',
#   '_',
#   'uzud[goat]N',
#   '_',
#   'ašgar[kid]N',
#   'šagdug[~animals]N',
#   'Šu.x[00]PN',
#   '_',
#   'maš[goat]N',
#   '_',
#   'ašgar[kid]N',
#   'šagdug[~animals]N',
#   '_',
#   'maš[goat]N',
#   'šagdug[~animals]N',
#   'Ur.pa[00]PN',
#   '_',
#   'uzud[goat]N',
#   '_',
#   'ašgar[kid]N',
#   'šagdug[~animals]N',
#   '_',
#   'maš[goat]N',
#   'šagdug[~animals]N',
#   '_'],
#  ['_',
#   'gal[cup]N',
#   'kugsig[gold]N',
#   '_',
#   'gurgur[vessel]N',
#   'kugsig[gold]N',
#   '_',
#   'šem[drum]N',
#   'kugsig[gold]N',
#   '_',
#   'niŋŋeštug[earring]N',
#   'kugsig[gold]N',
#   'lugal[king]N',
#   'eban[pair]N',
#   '_',
#   '_',
#   'niŋŋeštug[earring]N',
#   'kugsig[gold]N',
#   'eban[pair]N',
#   '_',
#   '_',
#   '_',
#   'niŋŋeštug[earring]N',
#   'kugsig[gold]N',
#   'eban[pair]N',
#   '_',
#   '_',
#   '_',
#   'ŋiri[dagger]N',
#   'banšur[table]N',
#   'zabar[bronze]N',
#   'kugsig[gold]N',
#   'ŋar[place]V/t',
#   '_',
#   'ŋirigub[footstool]N',
#   'galitum[object]N',
#   '_',
#   'guza[chair]N',
#   'esi[diorite]N',
#   'kugsig[gold]N',
#   'ŋar[place]V/t',
#   '_',
#   'guza[chair]N',
#   'zag[side]N',
#   'us[follow]V/t',
#   '_',
#   '_',
#   '_',
#   '_',
#   'banšur[table]N',
#   'kugsig[gold]N',
#   'ŋar[place]V/t',
#   '_',
#   '_',
#   'banšur[table]N',
#   'kugbabbar[silver]N',
#   'ŋar[place]V/t',
#   'lugal[king]N',
#   '_',
#   'gal[cup]N',
#   'kugsig[gold]N',
#   '_',
#   'gurgur[vessel]N',
#   'kugsig[gold]N',
#   '_',
#   'šem[drum]N',
#   'kugsig[gold]N',
#   '_',
#   'guza[chair]N',
#   'munus[woman]N',
#   'esi[diorite]N',
#   'kugsig[gold]N',
#   'ŋar[place]V/t',
#   '_',
#   'guza[chair]N',
#   '_',
#   '_',
#   'guza[chair]N',
#   '_',
#   'zag[side]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   'X.la[00]PN',
#   '_',
#   'tab[double]V/t',
#   'nin[lady]N',
#   '_',
#   'har[ring]N',
#   'kugsig[gold]N',
#   'eban[pair]N',
#   '_',
#   'guza[chair]N',
#   'tur[small]V/i',
#   'ŋešabak[tree]N',
#   'saŋ[head]N',
#   'kugsig[gold]N',
#   'ŋar[place]V/t',
#   '_',
#   'ŋirigub[footstool]N',
#   'tur[small]V/i',
#   'dumu[child]N',
#   'lugal[king]N',
#   '_',
#   'gal[cup]N',
#   'kugsig[gold]N',
#   '_',
#   'gal[cup]N',
#   'kugbabbar[silver]N',
#   '_',
#   'zabar[bronze]N',
#   '_',
#   'gag[nail]N',
#   'kun[shine]V/i',
#   'saŋ[head]N',
#   'zabar[bronze]N',
#   'ŋar[place]V/t',
#   '_',
#   '_',
#   'mes[tree]N',
#   'ilianum[tree]N',
#   '_',
#   '_',
#   'gur[tool]N',
#   'ilianum[tree]N',
#   '_',
#   '_',
#   'ildag[poplar]N',
#   'ilianum[tree]N',
#   '_',
#   'meʾaltum[bed]N',
#   'zabar[bronze]N',
#   'ŋar[place]V/t',
#   'zu[know]V/t',
#   '_',
#   'meʾaltum[bed]N',
#   '_',
#   '_',
#   'meʾaltum[bed]N',
#   '_',
#   '_',
#   'kugsig[gold]N',
#   'ŋar[place]V/t',
#   '_',
#   'guza[chair]N',
#   'šaršabid[tree]N',
#   '_',
#   '_',
#   'guza[chair]N',
#   'šuniŋin[total]N',
#   'halub[tree]N',
#   'saŋ[head]N',
#   'kugsig[gold]N',
#   'ŋar[place]V/t',
#   '_',
#   '_',
#   'guza[chair]N',
#   'gid[long]V/i',
#   '_',
#   'guza[chair]N',
#   'munus[woman]N',
#   '_',
#   'lal[small]V/i',
#   '_',
#   'meʾaltum[bed]N',
#   'halub[tree]N',
#   '_',
#   '_',
#   'tug[textile]N',
#   'du[spread]V/t',
#   'Lu₂.utu[00]PN',
#   '_',
#   'šen[cauldron]N',
#   'gal[big]V/i',
#   '_',
#   'šen[cauldron]N',
#   '_',
#   'sila[unit]N',
#   '_',
#   'šagaru[object]N',
#   'igi[eye]N',
#   'n[n]n',
#   'ŋal[be]V/i',
#   '_',
#   'gu[neck]N',
#   'urud[copper]N',
#   '_',
#   'gag[nail]N',
#   'dar[split]V/t',
#   'lugal[king]N',
#   '_',
#   'leʾum[board]N',
#   'gag[nail]N',
#   '_',
#   'tug[textile]N',
#   '_',
#   '_',
#   '_',
#   'sag[rare]V/i',
#   '_',
#   'šag[heart]N',
#   'tug[textile]N',
#   'tuku[beat]V/t',
#   '_',
#   'sa[bundle]N',
#   '_',
#   '_',
#   'sa[bundle]N',
#   'aktum[garment]N',
#   '_',
#   '_',
#   'dar[split]V/t',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'gur[nugget]N',
#   '_',
#   'la[hang]V/t',
#   'aktum[garment]N',
#   '_',
#   'kuš[skin]N',
#   'ab[window]N',
#   '_',
#   '_',
#   'Du₅.ba[00]PN',
#   'zabar[bronze]N',
#   'ŋar[place]V/t',
#   '_',
#   'sa[bundle]N',
#   'tab[double]V/t',
#   'kugsig[gold]N',
#   'eban[pair]N',
#   '_',
#   '_',
#   'kuš[skin]N',
#   'na[man]N',
#   '_',
#   'kuš[skin]N',
#   '_',
#   '_',
#   'tug[textile]N',
#   'ur[roof]N',
#   'sag[rare]V/i',
#   '_',
#   'tug[textile]N',
#   '_',
#   'sag[rare]V/i',
#   '_',
#   '_',
#   'tug[textile]N',
#   '_',
#   '_',
#   'ŋeš[tree]N',
#   'sisi[horse]N',
#   'gada[flax]N',
#   'gid[long]V/i',
#   '_',
#   '_',
#   'kuš[unit]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   'niŋ[thing]N',
#   '_',
#   '_',
#   'lal[small]V/i',
#   '_',
#   '_',
#   '_',
#   'eš[rope]N',
#   'targul[pole]N',
#   '_',
#   'kuš[skin]N',
#   'ab[window]N',
#   'e[house]N',
#   'diŋir[deity]N',
#   '_',
#   'gu[neck]N',
#   'hašhur[apple]N',
#   '_',
#   'kuš[skin]N',
#   'hašhur[apple]N',
#   '_',
#   'sa[bundle]N',
#   'zabar[bronze]N',
#   '_',
#   'suhub[boots]N',
#   'eban[pair]N',
#   '_',
#   'esir[shoe]N',
#   'eban[pair]N',
#   '_',
#   'mana[unit]N',
#   'šegin[glue]N',
#   '_',
#   'mana[unit]N',
#   'imbabbar[gypsum]N',
#   '_',
#   'dug[pot]N',
#   'kumul[cumin]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'pu[orchard]N',
#   '_',
#   'pešmurgu[date-palm-spine]N',
#   '_',
#   'esir[bitumen]N',
#   'eʾa[~bitumen]N',
#   '_',
#   'šeli[aromatics]N',
#   '_',
#   'li[juniper]N',
#   '_',
#   'gu[neck]N',
#   'siki[hair]N',
#   '_',
#   '_',
#   'mana[unit]N',
#   'šag[heart]N',
#   '_',
#   '_',
#   'gu[neck]N',
#   '_',
#   '_',
#   'bisaŋ[basket]N',
#   'tab[double]V/t',
#   'bur[bowl]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   '_',
#   'kuš[skin]N',
#   '_',
#   '_',
#   'HI×AŠ₂[~tree]N',
#   '_',
#   '_',
#   '_',
#   'mana[unit]N',
#   'šim[aromatics]N',
#   'hib[~aromatic]AJ',
#   '_',
#   'dug[pot]N',
#   'gir[jar]N',
#   'naŋa[potash]N',
#   'gaz[kill]V/t',
#   '_',
#   '_',
#   'šeg[brick]N',
#   'naŋa[potash]N',
#   '_',
#   'naŋa[potash]N',
#   'gur[unit]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   'a[arm]N',
#   'mušen[bird]N',
#   '_',
#   'igitab[blinkers]N',
#   'anše[equid]N',
#   'zabar[bronze]N',
#   '_',
#   'esi[tree]N',
#   '_',
#   '_',
#   'zu[tooth]N',
#   'amsi[elephant]N',
#   'gid[long]V/i',
#   '_',
#   'kuš[unit]N',
#   'daŋal[wide]V/i',
#   '_',
#   'šusi[finger]N',
#   '_',
#   'zu[tooth]N',
#   'amsi[elephant]N',
#   'gid[length]N',
#   '_',
#   'kuš[unit]N',
#   'daŋal[wide]V/i',
#   '_',
#   'šusi[finger]N',
#   '_',
#   'halub[tree]N',
#   'gid[length]N',
#   '_',
#   '_',
#   'kuš[unit]N',
#   'daŋal[wide]V/i',
#   '_',
#   'šuduʾa[unit]N',
#   '_',
#   'halub[tree]N',
#   'gid[length]N',
#   '_',
#   'kuš[unit]N',
#   'daŋal[wide]V/i',
#   '_',
#   'šuduʾa[unit]N',
#   '_',
#   'halub[tree]N',
#   'gid[length]N',
#   '_',
#   '_',
#   'kuš[unit]N',
#   'daŋal[wide]V/i',
#   '_',
#   'zipah[unit]N',
#   '_',
#   'šaršabid[tree]N',
#   'gid[length]N',
#   '_',
#   'kuš[unit]N',
#   'daŋal[wide]V/i',
#   '_',
#   'šusi[finger]N',
#   '_',
#   '_',
#   'gid[length]N',
#   '_',
#   'kuš[unit]N',
#   '_',
#   'gada[flax]N',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   '_',
#   '_',
#   '_',
#   '_',
#   'ki[place]N',
#   'Da.da[00]PN',
#   '_',
#   'tug[textile]N',
#   'bardul[garment]N',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   '_',
#   '_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   'ki[place]N',
#   'Ur.geš.bar.e₃[00]PN',
#   '_',
#   'gada[flax]N',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   '_',
#   'ki[place]N',
#   'Ur.dun[00]PN',
#   '_',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   '_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   'ki[place]N',
#   'Lugal.ur₂.ra.ni[00]PN',
#   '_',
#   'pana[bow]N',
#   'kuš[skin]N',
#   'kiri[orchard]N',
#   '_',
#   'pana[bow]N',
#   'kuš[skin]N',
#   'kiri[orchard]N',
#   'tur[small]V/i',
#   '_',
#   'pana[bow]N',
#   'dar[split]V/t',
#   'tur[small]V/i',
#   '_',
#   'pana[bow]N',
#   'dar[split]V/t',
#   '_',
#   'pana[bow]N',
#   'kuš[skin]N',
#   'giggi[black]V/i',
#   '_',
#   'pana[bow]N',
#   '_',
#   'kuš[skin]N',
#   'giggi[black]V/i',
#   'sig[equal]V/t',
#   'Ur.ba.gara₂[00]PN',
#   'šu[hand]N',
#   'teŋ[near]V/i',
#   '_',
#   'gu[neck]N',
#   'siki[hair]N',
#   '_',
#   'kib[wheat]N',
#   'gur[unit]N',
#   'Lugal.ti[00]PN',
#   'damgar[merchant]N',
#   'šu[hand]N',
#   'teŋ[near]V/i',
#   '_',
#   'la[hang]V/t',
#   '_',
#   '_',
#   'lugal[king]N',
#   '_',
#   '_',
#   '_',
#   'X.ga[00]PN',
#   '_',
#   '_',
#   'dim[post]N',
#   'A.mu.ru.um[00]PN',
#   '_',
#   'dim[post]N',
#   'saŋ[head]N',
#   'sa[equal]V/t',
#   '_',
#   '_',
#   '_',
#   'Da.num₂[00]PN',
#   '_',
#   'lal[small]V/i',
#   '_',
#   'dim[post]N',
#   'kuš[skin]N',
#   'sig[equal]V/t',
#   '_',
#   'ŋeš[tree]N',
#   'A.mu.ru.um[00]PN',
#   '_',
#   'dim[post]N',
#   'manu[wood]N',
#   '_',
#   'eš[rope]N',
#   'A.mu.ru.um[00]PN',
#   '_',
#   'eš[rope]N',
#   'eru[unmng]N',
#   '_',
#   '_',
#   'eš[rope]N',
#   'targul[pole]N',
#   '_',
#   '_',
#   'eš[rope]N',
#   'saŋ[head]N',
#   'urud[copper]N',
#   'Ur.ba.gara₂[00]PN',
#   'mu[name]N',
#   'e[house]N',
#   'nin.gir₂.su[00]DN',
#   'du[build]V/t'],
#  ['Ur.utu[00]PN',
#   'ensik[ruler]N',
#   'unadug[letter]N',
#   'tukum[if]CNJ',
#   'šu[hand]N',
#   'Ma.x[00]PN',
#   'lu[person]N',
#   '_'],
#  ['Ur.lugal.banda₃[00]PN', 'dumu[child]N', 'Ur.dun[00]PN'],
#  ['_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   'Lu₂.nanše[00]PN',
#   'dumu[child]N',
#   'bursala[container]N',
#   '_',
#   'ŋar[place]V/t',
#   'mu[name]N',
#   'išib[priest]N',
#   'nin.gir₂.su[00]DN'],
#  ['_',
#   'lal[small]V/i',
#   '_',
#   'sila[unit]N',
#   'dabin[semolina]N',
#   'En.x[00]PN',
#   '_',
#   'lu[person]N',
#   'An.ta.sur[00]PN',
#   '_',
#   '_',
#   'sila[unit]N',
#   'lu[person]N',
#   '_',
#   '_',
#   'nim[high]V/i',
#   '_',
#   '_',
#   '_',
#   'Giri₃.ni[00]PN'],
#  ['_',
#   'tug[textile]N',
#   'bardul[garment]N',
#   'mu[name]N',
#   'id[river]N',
#   'nin.gir₂.su.ušumgal[00]PN',
#   'bal[dig]V/t',
#   '_',
#   'tug[textile]N',
#   'bardul[garment]N',
#   'mu[name]N',
#   'balaŋ[instrument]N',
#   'ušumgal[dragon]N',
#   'kalam[land]N',
#   'dim[create]V/t',
#   '_',
#   '_',
#   'ŋar[place]V/t'],
#  ['_',
#   'Lu₂.nanše[00]PN',
#   'kaguruk[supervisor]N',
#   '_',
#   'Inim.inanna[00]PN',
#   '_',
#   'nin[lady]N',
#   '_',
#   'gurum[inspection]N',
#   'ak[do]V/t',
#   'ugula[overseer]N',
#   'Ur.zu[00]PN',
#   'šabra[administrator]N',
#   'Ur.ab.ba[00]PN',
#   'ensik[ruler]N',
#   '_'],
#  ['_',
#   'zidgu[flour]N',
#   '_',
#   'zidgu[flour]N',
#   'sag[rare]V/i',
#   '_',
#   '_',
#   '_',
#   'sila[unit]N',
#   'zidsig[flour]N',
#   '_',
#   'lal[small]V/i',
#   '_',
#   'sila[unit]N',
#   '_',
#   '_',
#   'arzana[groats]N',
#   '_',
#   'niŋara[groats]N',
#   'banšur[table]N',
#   '_',
#   'ara[times]N',
#   '_',
#   'Lu₂.nanše[00]PN',
#   'dumu[child]N',
#   'I₃.si[00]SN'],
#  ['_',
#   'idgurum[ladle]N',
#   'i[oil]N',
#   '_',
#   'Ur.geš.bar.e₃[00]PN',
#   '_',
#   'lu[person]N',
#   'ensik[ruler]N',
#   'Adab[00]SN',
#   '_',
#   'ubar[foreigner]N',
#   'šara₂.i₃.sa₆[00]PN'],
#  ['_',
#   'kin[sickle]N',
#   'kila[weight]N',
#   '_',
#   '_',
#   'mana[unit]N',
#   'Lu.lu[00]SN',
#   'šagia[cup-bearer]N',
#   'Lu₂.dingir[00]PN',
#   'maškim[administrator]N',
#   '_',
#   '_',
#   'lal[small]V/i',
#   '_',
#   'har[ring]N',
#   'tur[small]V/i',
#   'ŋešnud[bed]N',
#   '_',
#   'subur[slave]N',
#   'šu[hand]N',
#   'teŋ[near]V/i',
#   '_',
#   '_',
#   'kila[weight]N',
#   '_',
#   'mana[unit]N',
#   'Ur.ba.gara₂[00]PN'],
#  ['Lugal.du₁₀.ga[00]PN', 'dumu[child]N', 'U₂.da[00]PN'],
#  ['_',
#   'dug[pot]N',
#   'gal[big]V/i',
#   'lal[small]V/i',
#   '_',
#   'sila[unit]N',
#   'inun[ghee]N',
#   '_',
#   'dug[pot]N',
#   'lal[syrup]N',
#   'Nibru[00]SN',
#   'Ur.ab.ba[00]PN',
#   'maškim[administrator]N',
#   'šara₂.i₃.sa₆[00]PN'],
#  ['_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   'sag[rare]V/i',
#   'nin.gir₂.su.igi.du[00]PN',
#   'mu.DU[delivery]N',
#   'Lugal.inim.du₁₀[00]PN',
#   'šu[hand]N',
#   'teŋ[near]V/i'],
#  [],
#  ['_',
#   '_',
#   'ab[cow]N',
#   'mah[mature]V/i',
#   '_',
#   'ab[cow]N',
#   '_',
#   '_',
#   'ab[cow]N',
#   '_',
#   '_',
#   'gud[ox]N',
#   '_',
#   '_',
#   'ab[cow]N',
#   '_',
#   '_',
#   'gud[ox]N',
#   '_',
#   '_',
#   'udu[sheep]N',
#   'hi[mix]V/t',
#   'Erin.da[00]PN',
#   'Ki.nu.nir[00]PN',
#   'gud[ox]N',
#   'udu[sheep]N',
#   '_',
#   '_',
#   'mu[year]N',
#   'gi[turn]V/i'],
#  ['_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   'sag[rare]V/i',
#   '_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   'du[go]V/i',
#   'gi[turn]V/i',
#   'kila[weight]N',
#   '_',
#   'mana[unit]N',
#   '_',
#   'tug[textile]N',
#   'kinud[bedroom]N',
#   'kila[weight]N',
#   '_',
#   'mana[unit]N',
#   '_',
#   'tug[textile]N',
#   'mudum[garment]N',
#   'kila[weight]N',
#   '_',
#   'lal[small]V/i',
#   '_',
#   'mana[unit]N',
#   '_',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   'guz[tufted]V/i',
#   'kila[weight]N',
#   '_',
#   'gu[neck]N',
#   '_',
#   '_',
#   'mana[unit]N',
#   'itud[moon]N',
#   'šunumun[seed]N',
#   'mu[name]N',
#   'mitum[weapon]N',
#   'ugula[overseer]N',
#   'šu[hand]N'],
#  ['_',
#   '_',
#   'giŋ[ax]N',
#   'kugbabbar[silver]N',
#   '_',
#   '_',
#   'mana[unit]N',
#   'zabar[bronze]N',
#   '_',
#   'gada[flax]N',
#   'Ur.gigir[00]PN',
#   'nubanda[overseer]N',
#   'Ka.sa₆[00]PN',
#   'maškim[administrator]N',
#   '_',
#   'giŋ[unit]N',
#   'kug[metal]N',
#   '_',
#   'urud[copper]N',
#   '_',
#   'tug[textile]N',
#   'bardul[garment]N',
#   '_',
#   'tug[textile]N',
#   'niŋlam[garment]N',
#   'us[follow]V/t',
#   '_',
#   'gada[flax]N',
#   'Nam.zi[00]PN',
#   'Gu.u₂.gu.a[00]PN',
#   'Lu₂.nin.gir₂.su[00]PN',
#   'maškim[administrator]N',
#   '_',
#   'tug[textile]N',
#   'bardul[garment]N',
#   '_',
#   'tug[textile]N',
#   'aktum[garment]N',
#   'Ka.sa₆[00]PN',
#   'azu[doctor]N',
#   'A.ba.nin.gir₂.su.gin₇[00]PN',
#   'maškim[administrator]N',
#   'amargi[reversion]N',
#   'ŋar[place]V/t',
#   'mu[name]N',
#   'e[house]N',
#   'Ba.gara₂[00]TN',
#   'du[build]V/t']]
