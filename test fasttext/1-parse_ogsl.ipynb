# %% [markdown]
# # Create OGSL table
# Create a DataFrame that associates every sign value that is recognized in [ORACC](http://oracc.org) with a unicode code point (or a sequence of unicode code points). The table may be used to translate a text in transliteration into a sequence of unicode code points for use in `fasttext`. The data are derived from the ORACC Global Sign List ([OGSL](http://build-oracc.museum.upenn.edu)).

# %%
import pandas as pd
import zipfile
import json
import os
import sys
util_dir = os.path.abspath('../utils')
sys.path.append(util_dir)
from utils import *
import pickle

# %% [markdown]
# ## 0 Create Directories, if Necessary
# The two directories needed for this script are `jsonzip` and `output`. The directories are created with the function `make_dirs()` from the `utils` module.

# %%
directories = ['jsonzip', 'output']
make_dirs(directories)

# %% [markdown]
# ## 1 Download the ZIP file

# %%
project = ["ogsl"] # oracc_download() expects a list
oracc_download(project)
# Out:
# Saving http://oracc.museum.upenn.edu/ogsl/json/ogsl.zip as jsonzip/ogsl.zip
# HBox(children=(IntProgress(value=1, bar_style='info', description='ogsl', max=1, style=ProgressStyle(descripti…
# ['ogsl']

# %% [markdown]
# # <a name="head21"></a>2 The `parsejson()` function

# %%
def parsejson(data_json):
    for key, value in data_json["signs"].items():
        if "values" in value:
            for n in value["values"]:
                s["value"] = n
                s["name"] = key
                if "utf8" in value:
                    s["utf8"] = value["utf8"]
                    s["hex"] = value["hex"] 
                else:
                    s["utf8"] = ""
                    s["hex"] = ""
                sign = {key : value for key, value in s.items()}
                s_l.append(sign)
    return

# %% [markdown]
# # 3 Main Process

# %%
s = {}
s_l = []
file = "jsonzip/ogsl.zip"
z = zipfile.ZipFile(file) 
filename = "ogsl/ogsl-sl.json"
signlist = z.read(filename).decode('utf-8')
data_json = json.loads(signlist)                # make it into a json object (essentially a dictionary)
parsejson(data_json)

# %% [markdown]
# # 4 Make Dataframe

# %%
df = pd.DataFrame(s_l)
df
# Out:
#                                                      hex  \
# 0                                                 x12000
# 1                                                 x12000
# 2                                                 x12000
# 3                                                 x12000
# 4                                                 x12000
# 5                                                 x12000
# 6                                                 x12000
# 7                                                 x12000
# 8                                                 x12000
# 9                                                 x12000
# 10                                                x12000
# 11                                                x12000
# 12                                                x12000
# 13                                                x12000
# 14                                                x12000
# 15                                                x12000
# 16                                                x12000
# 17                                                x12000
# 18                                                x12000
# 19                                                x12000
# 20                                                x12000
# 21                                                x12000
# 22                                                x12000
# 23                                                x12000
# 24                                         x12000.x12000
# 25                                         x12000.x12000
# 26                                         x12000.x12000
# 27                                         x12000.x12000
# 28                                         x12000.x12000
# 29                                         x12000.x12000
# ...                                                  ...
# 10068  x1202D.x12097.x12261.x1226D.x12246.x1202D.x122...
# 10069
# 10070
# 10071
# 10072
# 10073
# 10074
# 10075
# 10076
# 10077
# 10078
# 10079
# 10080
# 10081
# 10082
# 10083
# 10084
# 10085
# 10086
# 10087
# 10088
# 10089
# 10090
# 10091
# 10092
# 10093
# 10094
# 10095
# 10096
# 10097
#
#                                  name      utf8     value
# 0                                   A         𒀀       ʾu₄
# 1                                   A         𒀀         a
# 2                                   A         𒀀      aia₂
# 3                                   A         𒀀      aya₂
# 4                                   A         𒀀      barₓ
# 5                                   A         𒀀    buniŋₓ
# 6                                   A         𒀀      burₓ
# 7                                   A         𒀀      dur₅
# 8                                   A         𒀀     duru₅
# 9                                   A         𒀀        e₄
# 10                                  A         𒀀        ea
# 11                                  A         𒀀     ebir₃
# 12                                  A         𒀀       emₓ
# 13                                  A         𒀀     epir₃
# 14                                  A         𒀀      eš₁₀
# 15                                  A         𒀀      ŋa₁₀
# 16                                  A         𒀀      ia₁₀
# 17                                  A         𒀀       id₅
# 18                                  A         𒀀       me₅
# 19                                  A         𒀀      mu₁₄
# 20                                  A         𒀀      sedₓ
# 21                                  A         𒀀      šegₓ
# 22                                  A         𒀀      ṭur₅
# 23                                  A         𒀀      ya₁₀
# 24                              |A.A|        𒀀𒀀        ai
# 25                              |A.A|        𒀀𒀀       aia
# 26                              |A.A|        𒀀𒀀       aya
# 27                              |A.A|        𒀀𒀀       aye
# 28                              |A.A|        𒀀𒀀       ayi
# 29                              |A.A|        𒀀𒀀       ayu
# ...                               ...       ...       ...
# 10068  |AN.EN.NU.NUNUZ.NAM.AN.ŠEŠ.KI|  𒀭𒂗𒉡𒉭𒉆𒀭𒋀𒆠    zirruₓ
# 10069                |KASKAL.LAGAB×X|             šubtumₓ
# 10070                     |SAL.U.DIŠ|               kušuₓ
# 10071                         |SAL.X|                emeₓ
# 10072                       |TAB&TAB|                limₓ
# 10073                       |TAB&TAB|              limmuₓ
# 10074                         |UR×ŠU|               šuziₓ
# 10075                    |SANGA₂.MAH|              dungaₓ
# 10076                         |PA.PA|             šullatₓ
# 10077            |ZA.MUŠ₃.AB×(U.U.U)|            zabalamₓ
# 10078                         |DU.KI|               alikₓ
# 10079                       |DU@s.KI|              lasimₓ
# 10080                       |BAN.GAM|              zugudₓ
# 10081                        |ŠE.DIM|               munuₓ
# 10082                        |GUD×UD|               guduₓ
# 10083                     |NINDA₂×GI|             giguruₓ
# 10084                         |KA×SI|              kurkuₓ
# 10085                |PA.SAL.HUB₂.DU|                rigₓ
# 10086                    |SI.A.GAR.X|              addirₓ
# 10087                        |AN.GUD|              nirahₓ
# 10088                   |SAL.ME.HUB₂|              lagarₓ
# 10089                     |SAL.HU.BA|              lagarₓ
# 10090                |LAGAB×IGI@g.ME|               immaₓ
# 10091                      |EZEN×HAL|                 ugₓ
# 10092                     |E.PAP.PAP|                 paₓ
# 10093                        |AB.KID|              akkilₓ
# 10094                       |TAG.NUN|               uttuₓ
# 10095                 |LU₂×BAD.BAD.A|               addaₓ
# 10096                      |EZEN×U@c|                badₓ
# 10097                     |PA.SI.GAR|               ensiₓ
#
# [10098 rows x 4 columns]

# %%
with open("output/ogsl.p", "wb") as p:
    pickle.dump(df, p)
