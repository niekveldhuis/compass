# %%
import pandas as pd
import pickle

# %%
with open("corpus/sux_df.p", "rb") as f: 
    df = pd.read_pickle(f)

# %%
df
# Out:
#                        transliteration                            words  \
# 0        Startepsd2/admin/ed3a/P011046  [Startepsd2/admin/ed3a/P011046]
# 1                           1(barig@c)                     [1(barig@c)]
# 2                                   še                             [še]
# 3                               ba-lul                        [ba, lul]
# 4                                nagar                          [nagar]
# 5                           1(barig@c)                     [1(barig@c)]
# 6                             nig₂-du₇                      [nig₂, du₇]
# 7                                  ag₂                            [ag₂]
# 8                      hur-sag-še₃-mah             [hur, sag, še₃, mah]
# 9                             sa₁₂-du₅                      [sa₁₂, du₅]
# 10       Startepsd2/admin/ed3a/P010836  [Startepsd2/admin/ed3a/P010836]
# 11                            2(iku@c)                       [2(iku@c)]
# ...

# %%
df2 = df[["transliteration", "utf-8", "lemm"]]
df2.columns

# %%
df2.columns = ['transliteration', 'cuneiform', 'lemmatized']

# %%
df2 = df2[df2["transliteration"].str[:5] != "Start"]

# %%
df2
# Out:
#           transliteration   cuneiform                 lemmatized
# 1              1(barig@c)           𒁹                 1(barig@c)
# 2                      še           𒊺                še[barley]N
# 3                  ba-lul          𒁀𒈜                     ba-lul
# 4                   nagar           𒉄          nagar[carpenter]N
# 5              1(barig@c)           𒁹                 1(barig@c)
# 6                nig₂-du₇          𒃻𒌌  niŋdu[appropriate-thing]N
# 7                     ag₂           𒉘             aŋ[measure]V/t
# 8         hur-sag-še₃-mah        𒄯𒊕𒂠𒈤            hur-sag-še₃-mah
# 9                sa₁₂-du₅          𒊕𒂅        saŋ.DUN₃[recorder]N
# 11               2(iku@c)    2(iku@c)                   2(iku@c)
# 12                   GAN₂           𒃷                 iku[unit]N
# 13         har-tu-{d}sud₃      𒄯𒌅𒀭𒋢𒆳𒊒             har-tu-{d}sud₃
# 14               nu-kiri₆          𒉡𒊬         nukirik[gardener]N
# ...

# %%
from gensim.models.fasttext import FastText as FT_gensim
# Out:
# C:\Users\veldhuis\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
model_tl = FT_gensim.load("model/model_tl.model")

# %%
model_tl.wv.most_similar(positive=["še", "ku₃-sig₁₇"], negative = ["ninda"])
# Out:
# C:\Users\veldhuis\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('huš-a', 0.7877124547958374),
#  ('ku₃-hu-za', 0.7812914848327637),
#  ('ku₃-sig₁₇-bi', 0.7809878587722778),
#  ('si-sa₂', 0.7737034559249878),
#  ('za-ellag₂', 0.7649474143981934),
#  ('tu-dur', 0.7648569941520691),
#  ('tu-di-da', 0.7606604099273682),
#  ('ku₃-babbar', 0.7591084241867065),
#  ('kam-kam-ma-tum', 0.757216215133667),
#  ('nir₃', 0.7563619613647461)]
