# %% [markdown]
# # Create OGSL table

# %%
import pandas as pd
import zipfile
import json
import tqdm
import requests
import errno
import os
import pickle

# %% [markdown]
# ## 0 Create Directories, if Necessary
# The two directories needed for this script are `jsonzip` and `output`. If they do not exist they are created, else: do nothing.
#
# For the code, see [Stack Overflow](http://stackoverflow.com/questions/18973418/os-mkdirpath-returns-oserror-when-directory-does-not-exist).

# %%
directories = ['jsonzip', 'output']
for d in directories:
    try:
        os.mkdir(d)
    except OSError as exc:
        if exc.errno !=errno.EEXIST:
            raise
        pass

# %% [markdown]
# ## 1 Download the ZIP file

# %%
project = "ogsl"
CHUNK = 16 * 1024
url = "http://build-oracc.museum.upenn.edu/json/" + project + ".zip"
file = 'jsonzip/' + project + '.zip'
r = requests.get(url)
if r.status_code == 200:
    print("Downloading " + url + " saving as " + file)
    with open(file, 'wb') as f:
        for c in r.iter_content(chunk_size=CHUNK):
            f.write(c)
else:
    print(url + " does not exist.")
# Out:
# Downloading http://build-oracc.museum.upenn.edu/json/ogsl.zip saving as jsonzip/ogsl.zip

# %% [markdown]
# # <a name="head21"></a>2 The `parsejson()` function

# %%
def parsejson(data_json):
    for key, value in data_json["signs"].items():
        if "values" in value:
            for n in value["values"]:
                s["value"] = n
                s["name"] = key
                if "utf8" in value:
                    s["utf8"] = value["utf8"]
                    s["hex"] = value["hex"] 
                else:
                    s["utf8"] = ""
                    s["hex"] = ""
                sign = {key : value for key, value in s.items()}
                s_l.append(sign)
    return

# %% [markdown]
# # 3 Main Process

# %%
s = {}
s_l = []
file = "jsonzip/ogsl.zip"
z = zipfile.ZipFile(file) 
filename = "ogsl/ogsl-sl.json"
signlist = z.read(filename).decode('utf-8')
data_json = json.loads(signlist)                # make it into a json object (essentially a dictionary)
parsejson(data_json)

# %% [markdown]
# # 4 Make Dataframe

# %%
df = pd.DataFrame(s_l)
df
# Out:
#                         hex            name utf8     value
# 0             x120F0.x122FA      |GAD.TAK₄|   𒃰𒋺    akkil₃
# 1             x120F0.x122FA      |GAD.TAK₄|   𒃰𒋺     ašša₂
# 2             x120F0.x122FA      |GAD.TAK₄|   𒃰𒋺      ašta
# 3             x120F0.x122FA      |GAD.TAK₄|   𒃰𒋺      kil₄
# 4             x122D9.x1202F      |ŠU₂.3×AN|   𒋙𒀯      iši₂
# 5             x122D9.x1202F      |ŠU₂.3×AN|   𒋙𒀯     kunga
# 6             x122D9.x1202F      |ŠU₂.3×AN|   𒋙𒀯     kungi
# 7             x122D9.x1202F      |ŠU₂.3×AN|   𒋙𒀯     suhub
# 8             x122D9.x1202F      |ŠU₂.3×AN|   𒋙𒀯     suhul
# 9             x122D9.x1202F      |ŠU₂.3×AN|   𒋙𒀯    sulgar
# 10            x122D9.x1202F      |ŠU₂.3×AN|   𒋙𒀯     šuhub
# 11            x122D9.x1202F      |ŠU₂.3×AN|   𒋙𒀯    kungaₓ
# 12            x122D9.x1202F      |ŠU₂.3×AN|   𒋙𒀯     suhub
# 13            x122D9.x1202F      |ŠU₂.3×AN|   𒋙𒀯     šuhub
# 14            x122D9.x1202F      |ŠU₂.3×AN|   𒋙𒀯     suhub
# 15            x122D9.x1202F      |ŠU₂.3×AN|   𒋙𒀯     šuhub
# 16            x122D9.x1202F      |ŠU₂.3×AN|   𒋙𒀯    suhub₂
# 17            x122D9.x1202F      |ŠU₂.3×AN|   𒋙𒀯    šuhub₂
# 18                   x122AB          SANGA₂    𒊫     saŋa₂
# 19                   x122AB          SANGA₂    𒊫    sanga₂
# 20                   x122AB          SANGA₂    𒊫     saŋa₇
# 21                   x122AB          SANGA₂    𒊫    saŋŋa₇
# 22                   x122AB          SANGA₂    𒊫    sanga₇
# 23                   x122AB          SANGA₂    𒊫     saŋa₆
# 24                   x122AB          SANGA₂    𒊫    sagga₆
# 25                   x122AB          SANGA₂    𒊫    saŋŋa₆
# 26                   x122AB          SANGA₂    𒊫    sanga₆
# 27                   x122AB          SANGA₂    𒊫    sangu₆
# 28                   x122AB          SANGA₂    𒊫     saŋaₓ
# 29                   x122AB          SANGA₂    𒊫    sangaₓ
# ...                     ...             ...  ...       ...
# 9976          x12239.x12072       |MUŠ₃.DI|   𒈹𒁲    halba₂
# 9977          x12239.x12072       |MUŠ₃.DI|   𒈹𒁲    halbi₂
# 9978          x12239.x12072       |MUŠ₃.DI|   𒈹𒁲    halbu₂
# 9979          x12239.x12072       |MUŠ₃.DI|   𒈹𒁲     mabi₃
# 9980          x12239.x12072       |MUŠ₃.DI|   𒈹𒁲    mammi₃
# 9981          x12239.x12072       |MUŠ₃.DI|   𒈹𒁲      se₁₀
# 9982          x12239.x12072       |MUŠ₃.DI|   𒈹𒁲      sed₈
# 9983          x12239.x12072       |MUŠ₃.DI|   𒈹𒁲     sedi₈
# 9984          x12239.x12072       |MUŠ₃.DI|   𒈹𒁲       še₅
# 9985          x12239.x12072       |MUŠ₃.DI|   𒈹𒁲      šed₈
# 9986          x12239.x12072       |MUŠ₃.DI|   𒈹𒁲     namru
# 9987          x12239.x12072       |MUŠ₃.DI|   𒈹𒁲    amagi₄
# 9988          x12239.x12072       |MUŠ₃.DI|   𒈹𒁲    halba₃
# 9989          x12239.x12072       |MUŠ₃.DI|   𒈹𒁲    halbi₃
# 9990          x12239.x12072       |MUŠ₃.DI|   𒈹𒁲    halbu₃
# 9991          x12239.x12072       |MUŠ₃.DI|   𒈹𒁲      šed₉
# 9992          x12239.x12072       |MUŠ₃.DI|   𒈹𒁲      se₂₉
# 9993                 x1207F       |DUB×EŠ₂|    𒁿      gaz₃
# 9994                                 KA@180        nundumₓ
# 9995                 x120ED       |GA₂&GA₂|    𒃭    lirumₓ
# 9996   x12146.x12244.x1204D  |IGI.NAGAR.BU|  𒅆𒉄𒁍     dulum
# 9997   x12146.x12244.x1204D  |IGI.NAGAR.BU|  𒅆𒉄𒁍     ildu₂
# 9998   x12146.x12244.x1204D  |IGI.NAGAR.BU|  𒅆𒉄𒁍    ildum₂
# 9999   x12146.x12244.x1204D  |IGI.NAGAR.BU|  𒅆𒉄𒁍   ilduma₂
# 10000  x12146.x12244.x1204D  |IGI.NAGAR.BU|  𒅆𒉄𒁍  ildumma₂
# 10001                            |EZEN×GUD|       gublagaₓ
# 10002         x1219C.x121B8  |KASKAL.LAGAB|   𒆜𒆸     šubtu
# 10003         x1219C.x121B8  |KASKAL.LAGAB|   𒆜𒆸    šubtu₃
# 10004         x1219C.x121B8  |KASKAL.LAGAB|   𒆜𒆸   šubtum₃
# 10005         x122E0.x122E6    |SIK₂.SUHUR|   𒋠𒋦   munsubₓ
#
# [10006 rows x 4 columns]

# %%
with open("ogsl.p", "wb") as p:
    pickle.dump(df, p)
