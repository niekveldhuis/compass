# %% [markdown]
# # Create OGSL table
# Create a DataFrame that associates every sign value that is recognized in [ORACC](http://oracc.org) with a unicode code point (or a sequence of unicode code points). The table may be used to translate a text in transliteration into a sequence of unicode code points for use in `fasttext`. The data are derived from the ORACC Global Sign List ([OGSL](http://build-oracc.museum.upenn.edu)).

# %%
import pandas as pd
import zipfile
import json
import tqdm
import requests
import errno
import os
import pickle

# %% [markdown]
# ## 0 Create Directories, if Necessary
# The two directories needed for this script are `jsonzip` and `output`. If they do not exist they are created, else: do nothing.
#
# For the code, see [Stack Overflow](http://stackoverflow.com/questions/18973418/os-mkdirpath-returns-oserror-when-directory-does-not-exist).

# %%
directories = ['jsonzip', 'output']
for d in directories:
    try:
        os.mkdir(d)
    except OSError as exc:
        if exc.errno !=errno.EEXIST:
            raise
        pass

# %% [markdown]
# ## 1 Download the ZIP file

# %%
project = "ogsl"
CHUNK = 16 * 1024
url = "http://build-oracc.museum.upenn.edu/json/" + project + ".zip"
file = 'jsonzip/' + project + '.zip'
r = requests.get(url)
if r.status_code == 200:
    print("Downloading " + url + " saving as " + file)
    with open(file, 'wb') as f:
        for c in r.iter_content(chunk_size=CHUNK):
            f.write(c)
else:
    print(url + " does not exist.")
# Out:
# Downloading http://build-oracc.museum.upenn.edu/json/ogsl.zip saving as jsonzip/ogsl.zip

# %% [markdown]
# # <a name="head21"></a>2 The `parsejson()` function

# %%
def parsejson(data_json):
    for key, value in data_json["signs"].items():
        if "values" in value:
            for n in value["values"]:
                s["value"] = n
                s["name"] = key
                if "utf8" in value:
                    s["utf8"] = value["utf8"]
                    s["hex"] = value["hex"] 
                else:
                    s["utf8"] = ""
                    s["hex"] = ""
                sign = {key : value for key, value in s.items()}
                s_l.append(sign)
    return

# %% [markdown]
# # 3 Main Process

# %%
s = {}
s_l = []
file = "jsonzip/ogsl.zip"
z = zipfile.ZipFile(file) 
filename = "ogsl/ogsl-sl.json"
signlist = z.read(filename).decode('utf-8')
data_json = json.loads(signlist)                # make it into a json object (essentially a dictionary)
parsejson(data_json)

# %% [markdown]
# # 4 Make Dataframe

# %%
df = pd.DataFrame(s_l)
df
# Out:
#                                                      hex  \
# 0                                                 x12000
# 1                                                 x12000
# 2                                                 x12000
# 3                                                 x12000
# 4                                                 x12000
# 5                                                 x12000
# 6                                                 x12000
# 7                                                 x12000
# 8                                                 x12000
# 9                                                 x12000
# 10                                                x12000
# 11                                                x12000
# 12                                                x12000
# 13                                                x12000
# 14                                                x12000
# 15                                                x12000
# 16                                                x12000
# 17                                                x12000
# 18                                                x12000
# 19                                                x12000
# 20                                                x12000
# 21                                                x12000
# 22                                                x12000
# 23                                                x12000
# 24                                         x12000.x12000
# 25                                         x12000.x12000
# 26                                         x12000.x12000
# 27                                         x12000.x12000
# 28                                         x12000.x12000
# 29                                         x12000.x12000
# ...                                                  ...
# 9977                                       x12351.x12032
# 9978
# 9979                                       x120FB.x12306
# 9980
# 9981
# 9982                                       x121FF.x12041
# 9983                                       x12309.x12248
# 9984    x12097.x122A9.x1226D.x12363.x1202D.x122C0.x121A0
# 9985
# 9986                         x12104.x1223E.x1200A.x12308
# 9987                         x12111.x12306.x1227F.x1224C
# 9988
# 9989                                x1221C.x1208D.x12046
# 9990                                x12228.x1201C.x121AC
# 9991                                x1227B.x12110.x122DB
# 9992                                       x122BA.x12334
# 9993
# 9994
# 9995                                       x1214E.x122DB
# 9996                                       x1207A.x121EF
# 9997                                       x1202D.x1230B
# 9998                                       x1214A.x1227D
# 9999
# 10000                               x12306.x1227F.x1227F
# 10001                        x12016.x1202D.x122C0.x121A0
# 10002                                      x1230B.x12263
# 10003
# 10004
# 10005                               x12246.x12097.x1223E
# 10006  x1202D.x12097.x12261.x1226D.x12246.x1202D.x122...
#
#                                  name      utf8    value
# 0                                   A         𒀀      ʾu₄
# 1                                   A         𒀀        a
# 2                                   A         𒀀     aia₂
# 3                                   A         𒀀     aya₂
# 4                                   A         𒀀     barₓ
# 5                                   A         𒀀   buniŋₓ
# 6                                   A         𒀀     burₓ
# 7                                   A         𒀀     dur₅
# 8                                   A         𒀀    duru₅
# 9                                   A         𒀀       e₄
# 10                                  A         𒀀       ea
# 11                                  A         𒀀    ebir₃
# 12                                  A         𒀀      emₓ
# 13                                  A         𒀀    epir₃
# 14                                  A         𒀀     eš₁₀
# 15                                  A         𒀀     ŋa₁₀
# 16                                  A         𒀀     ia₁₀
# 17                                  A         𒀀      id₅
# 18                                  A         𒀀      me₅
# 19                                  A         𒀀     mu₁₄
# 20                                  A         𒀀     sedₓ
# 21                                  A         𒀀     šegₓ
# 22                                  A         𒀀     ṭur₅
# 23                                  A         𒀀     ya₁₀
# 24                              |A.A|        𒀀𒀀       ai
# 25                              |A.A|        𒀀𒀀      aia
# 26                              |A.A|        𒀀𒀀      aya
# 27                              |A.A|        𒀀𒀀      aye
# 28                              |A.A|        𒀀𒀀      ayi
# 29                              |A.A|        𒀀𒀀      ayu
# ...                               ...       ...      ...
# 9977                        |UŠ.ANŠE|        𒍑𒀲     durₓ
# 9978                         |TA×GAR|             lungaₓ
# 9979                       |GAR.TUG₂|        𒃻𒌆   šudulₓ
# 9980                            IL₂@n            dupsikₓ
# 9981                           REC169              uštil
# 9982                    |LU₂×BAD.BAD|        𒇿𒁁    addaₓ
# 9983                         |TUR.NE|        𒌉𒉈   ibilaₓ
# 9984      |EN.SAL.NUNUZ.ZI.AN.ŠEŠ.KI|   𒂗𒊩𒉭𒍣𒀭𒋀𒆠   zirruₓ
# 9985                       |EZEN×ŠID|            asilalₓ
# 9986                  |GI₄.NA.AB.TUM|      𒄄𒈾𒀊𒌈   šutumₓ
# 9987                 |GIŠ.TUG₂.PI.NI|      𒄑𒌆𒉿𒉌  gizzalₓ
# 9988                           LAK526                meₓ
# 9989                   |LUL.E₂.BALAG|       𒈜𒂍𒁆    tigiₓ
# 9990                      |ME.AD.KU₃|       𒈨𒀜𒆬   šennuₓ
# 9991                   |PAD.GISAL.SI|       𒉻𒄐𒋛   addirₓ
# 9992                         |ŠE.UR₄|        𒊺𒌴     gurₓ
# 9993                      |ZUM×LAGAB|             garigₓ
# 9994                  |A.ZI&ZI.LAGAB|              aškiₓ
# 9995                          |IM.SI|        𒅎𒋛   dunguₓ
# 9996                     |DU.LAGAR@g|        𒁺𒇯      edₓ
# 9997                           |AN.U|        𒀭𒌋      enₓ
# 9998                      |IGI@g.PAP|        𒅊𒉽    kumₓ?
# 9999                 |NINDA₂×GI.IDIM|             gidimₓ
# 10000                    |TUG₂.PI.PI|       𒌆𒉿𒉿  ŋeštugₓ
# 10001                 |AB₂.AN.ŠEŠ.KI|      𒀖𒀭𒋀𒆠  munzerₓ
# 10002                     |U.GIŠ%GIŠ|        𒌋𒉣  šennurₓ
# 10003                   |UR₂×KID₂.SU|             umbinₓ
# 10004                          LAK212              asalₓ
# 10005                     |NAM.EN.NA|       𒉆𒂗𒈾    palaₓ
# 10006  |AN.EN.NU.NUNUZ.NAM.AN.ŠEŠ.KI|  𒀭𒂗𒉡𒉭𒉆𒀭𒋀𒆠   zirruₓ
#
# [10007 rows x 4 columns]

# %%
with open("output/ogsl.p", "wb") as p:
    pickle.dump(df, p)
