# %%
import pandas as pd
with open('Normalized/drehem_names2.csv', 'r',encoding='utf8') as n: 
    nnames = pd.read_csv(n)

# %%
nnames
# Out:
#               transliteration        normalization  \
# 0                  A-AN-ba-az       A.AN.ba.az[]PN
# 1                     A-KU-um          A.KU.um[]PN
# 2                  A-KU.KU-ta          A.KU.KU[]PN
# 3                     A-NI-ta             A.NI[]PN
# 4              A-U.E₂-nu-tuku   A.U.E₂.nu.tuku[]PN
# ...                       ...                  ...
# 5801                   {d}utu              Utu[]DN
# 5802            {d}utu-bar-ra          Utubara[]DN
# 5803             Ma₂-gur₈-mah         Magurmah[]ON
# 5804           Ma₂-dara₃-abzu      Madaraʾabzu[]ON
# 5805  Lugal-uri₅{ki}-e-ki-ag₂  LugalUrimekiʾaŋ[]ON
#
#                             sign_names  \
# 0                   A AN BA |PIRIG×ZA|
# 1                              A KU UM
# 2                           A KU KU TA
# 3                              A NI TA
# 4                        A U E₂ NU TUK
# ...                                ...
# 5801                             AN UD
# ...

# %%
pd.set_option('display.max_rows', None)
nnames = nnames.sort_values(by = 'sign_names')
dups = nnames[nnames.duplicated(subset='sign_names', keep=False)]
dups
# Out:
#                            transliteration                 normalization  \
# 66                    A-ba-{d}En-lil₂-gen₇               AbaEnlilgin[]PN
# 68                    A-ba-{d}en-lil₂-gen₇               AbaEnlilgin[]PN
# 124                           A-da-gal-šum                Adaggalšum[]PN
# 301                         A-ta₂-kal₂-šum                Atakkalšum[]PN
# 125                         A-da-gal-šum-e                Adaggalšum[]PN
# 302                       A-ta₂-kal₂-šum-e                Atakkalšum[]PN
# 148                              A-gu-a-ni                   Aguʾali[]PN
# 147                             A-gu-a-li₂                   Aguʾali[]PN
# 157                          A-ha-an-ši-bu                  Ahanšibu[]PN
# 158                          A-ha-an-ši-pu                  Ahanšibu[]PN
# 159                         A-ha-an-ši₂-bu                  Ahanšibu[]PN
# 162                          A-ha-an-si-pu                  Ahanšibu[]PN
# ...
