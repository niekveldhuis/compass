# %% [markdown]
# # Extracting Personal Names from QPN Glossary
# Extract proper nouns with the id_text of where they appear from `gloss-qpn.json`. The appropriate JSON ZIP file must be located in the directory `jsonzip`.

# %%
import pandas as pd
import zipfile
import json
import os
import errno
import tqdm
import requests

# %% [markdown]
# # Create Download Directory
# Create a directory called `jsonzip`. If the directory already exists, do nothing.
#
# For the code, see [Stack Overflow](http://stackoverflow.com/questions/18973418/os-mkdirpath-returns-oserror-when-directory-does-not-exist).

# %%
try:
    os.mkdir('jsonzip')
except OSError as exc:
    if exc.errno !=errno.EEXIST:
        raise
    pass

# %% [markdown]
# # Download the ZIP file

# %%
CHUNK = 16 * 1024
url = "http://oracc.ub.uni-muenchen.de/json/saao-sargonletters.zip"
file = 'jsonzip/saao-sargonletters.zip'
with requests.get(url, stream=True) as r:
    if r.status_code == 200:
        print("Downloading " + url + " saving as " + file)
        with open(file, 'wb') as f:
            for c in tqdm.tqdm(r.iter_content(chunk_size=CHUNK)):
                f.write(c)
    else:
        print(url + " does not exist.")
# Out:
# Downloading http://oracc.ub.uni-muenchen.de/json/saao-sargonletters.zip saving as jsonzip/saao-sargonletters.zip
# 968it [00:04, 212.50it/s]

# %% [markdown]
# Extract the data from the `gloss-qpn.json` file and use the `json` package to store the results in the variable `data_json`.

# %%
filename = ""
z = zipfile.ZipFile(file)
names = z.namelist()
for name in names: 
    if "gloss-qpn.json" in name: 
        filename = name
qpn = z.read(filename).decode('utf-8')         #read and decode the qpn glossary json file
data_json = json.loads(qpn)

# %% [markdown]
# # First DataFrame: Entries
# The DataFrame `df_pn` is created, capturing the columns `headword`, `xis`, and `pos`. The column `pos` is used to select personal names (regnal names and personal names). The value of `xis` is an ID which is used in `instances` (below).

# %%
entries = data_json["entries"]
df = pd.DataFrame(entries)
df = df[["headword", "xis", "pos"]]
df_pn = df.loc[df["pos"].isin(["PN", "RN"])]

# %% [markdown]
# # Second DataFrame: Instances
# Instances links the `xis` ID number with text IDs. It notes the text's ID number, but also line and word.

# %%
instances = data_json["instances"]

# %% [markdown]
# Create a list of lists (called `l`) where every list has two elements: the `xis` number and one text ID. The text ID is made out of the references in `instances` which have the format PROJECT:ID_TEXT.ID_LINE.ID_WORD.

# %%
l = []
for i in df_pn["xis"]:
    for k in instances[i]:
        QPN = k.split(":")[1]
        QPN = QPN.split(".")[0]
        d = [i, QPN]
        l.append(d)

# %% [markdown]
# Create the DataFrame and give names to the columns.

# %%
inst_df = pd.DataFrame(l)
inst_df.columns = ["xis", "id_text"]

# %% [markdown]
# Merge the two DataFrames on the field `xis`, using the keys from the left object (that is `inst_df`).

# %%
df = inst_df.merge(df_pn, on='xis', how='left')
df
# Out:
#               xis  id_text               headword pos
# 0     qpn.r000004  P313422        Abaliuqunu[1]PN  PN
# 1     qpn.r000004  P334090        Abaliuqunu[1]PN  PN
# 2     qpn.r000004  P334090        Abaliuqunu[1]PN  PN
# 3     qpn.r000004  P334257        Abaliuqunu[1]PN  PN
# 4     qpn.r00000b  P313425            Abattu[1]PN  PN
# 5     qpn.r000008  P334282   Abat-šarri-uṣur[1]PN  PN
# 6     qpn.r000008  P334321   Abat-šarri-uṣur[1]PN  PN
# 7     qpn.r000011  P334398             Abile[1]PN  PN
# 8     qpn.r00000f  P334412          Abi-ramu[1]PN  PN
# 9     qpn.r00000e  P313421           Abi-Seʾ[1]PN  PN
# 10    qpn.r000010  P334187          Abi-yaqa[1]PN  PN
# 11    qpn.r000012  P334375         Abu-ilaʾi[1]PN  PN
# 12    qpn.r000012  P334375         Abu-ilaʾi[1]PN  PN
# 13    qpn.r000013  X900008         Abu-lešir[1]PN  PN
# 14    qpn.r000013  X900008         Abu-lešir[1]PN  PN
# 15    qpn.r000014  P334529        Abu-ul-idi[1]PN  PN
# 16    qpn.r000018  P313607               Ada[1]PN  PN
# 17    qpn.r000018  P313609               Ada[1]PN  PN
# 18    qpn.r000018  P314281               Ada[1]PN  PN
# 19    qpn.r000018  P334723               Ada[1]PN  PN
# 20    qpn.r000019  P334830        Adad-abuʾa[1]PN  PN
# 21    qpn.r00001a  P313457  Adad-aplu-iddina[1]PN  PN
# 22    qpn.r00001b  P334209         Adad-ibni[1]PN  PN
# 23    qpn.r00001b  P334210         Adad-ibni[1]PN  PN
# 24    qpn.r00001b  P334357         Adad-ibni[1]PN  PN
# 25    qpn.r00001b  P334555         Adad-ibni[1]PN  PN
# 26    qpn.r00001b  P334568         Adad-ibni[1]PN  PN
# 27    qpn.r00001f  P313505        Adad-iriba[1]PN  PN
# 28    qpn.r000020  P313494       Adad-isseʾa[1]PN  PN
# 29    qpn.r000020  P314294       Adad-isseʾa[1]PN  PN
# ...           ...      ...                    ...  ..
# 1340  qpn.r000647  P313773           Yannuqu[1]PN  PN
# 1341  qpn.r000648  P334612             Yanzu[1]PN  PN
# 1342  qpn.r00064c  P313937            Yasumu[1]PN  PN
# 1343  qpn.r00064c  P334343            Yasumu[1]PN  PN
# 1344  qpn.r00064d  P334187             Yataʾ[1]PN  PN
# 1345  qpn.r00064e  P313829             Yatiʾ[1]PN  PN
# 1346  qpn.r000659  P334223            Zabaya[1]PN  PN
# 1347  qpn.r000657  P334305        Zaba-iqiša[1]PN  PN
# 1348  qpn.r000657  P334305        Zaba-iqiša[1]PN  PN
# 1349  qpn.r00065d  P313660            Zabbua[1]PN  PN
# 1350  qpn.r000662  P334567        Zabina-ili[1]PN  PN
# 1351  qpn.r000666  P313498              Zala[1]PN  PN
# 1352  qpn.r000668  P334163            Zaqiru[1]PN  PN
# 1353  qpn.r00066a  P334102              Zari[1]PN  PN
# 1354  qpn.r00066b  P334155            Zazaya[1]PN  PN
# 1355  qpn.r00066d  P313439         Zeru-ibni[1]PN  PN
# 1356  qpn.r00066d  P313439         Zeru-ibni[1]PN  PN
# 1357  qpn.r00066d  P313439         Zeru-ibni[1]PN  PN
# 1358  qpn.r00066d  P334100         Zeru-ibni[1]PN  PN
# 1359  qpn.r00066d  P334101         Zeru-ibni[1]PN  PN
# 1360  qpn.r00066d  P334102         Zeru-ibni[1]PN  PN
# 1361  qpn.r00066d  P334499         Zeru-ibni[1]PN  PN
# 1362  qpn.r00066d  P334718         Zeru-ibni[1]PN  PN
# 1363  qpn.r00066d  P334728         Zeru-ibni[1]PN  PN
# 1364  qpn.r00066d  P334728         Zeru-ibni[1]PN  PN
# 1365  qpn.r000670  P334708       Zeru-iddina[1]PN  PN
# 1366  qpn.r000670  P334708       Zeru-iddina[1]PN  PN
# 1367  qpn.r000670  P334708       Zeru-iddina[1]PN  PN
# 1368  qpn.r00066c  P313920        Zer-Babili[1]PN  PN
# 1369  qpn.r000679  P334174            Ziziru[1]PN  PN
#
# [1370 rows x 4 columns]
