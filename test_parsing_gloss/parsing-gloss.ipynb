# %% [markdown]
# # Extracting Personal Names from QPN Glossary
# Extract proper nouns with the id_text of where they appear from `gloss-qpn.json`. The appropriate JSON ZIP file must be located in the directory `jsonzip`.

# %%
import pandas as pd
import zipfile
import json

# %% [markdown]
# Extract the data from the `gloss-qpn.json` file and use the `json` package to store the results in the variable `data_json`.

# %%
filename = ""
zfilename = "jsonzip/rinap-szar2gina2019.zip"
z = zipfile.ZipFile(zfilename)
names = z.namelist()
for name in names: 
    if "gloss-qpn.json" in name: 
        filename = name
qpn = z.read(filename).decode('utf-8')         #read and decode the qpn glossary json file
data_json = json.loads(qpn)

# %% [markdown]
# # First DataFrame: Entries
# The DataFrame `df_pn` is created, capturing the columns `headword`, `xis`, and `pos`. The column `pos` is used to select personal names (regnal names and personal names). The value of `xis` is an ID which is used in `instances` (below).

# %%
entries = data_json["entries"]
df = pd.DataFrame(entries)
df = df[["headword", "xis", "pos"]]
df_pn = df.loc[df["pos"].isin(["PN", "RN"])]

# %% [markdown]
# # Second DataFrame: Instances
# Instances links the `xis` ID number with text IDs. It notes the text's ID number, but also line and word.

# %%
instances = data_json["instances"]

# %% [markdown]
# Create a list of lists (called `l`) where every list has two elements: the `xis` number and one text ID. The text ID is made out of the references in `instances` which have the format PROJECT:ID_TEXT.ID_LINE.ID_WORD.

# %%
l = []
for i in df_pn["xis"]:
    for k in instances[i]:
        QPN = k.split(":")[1]
        QPN = QPN.split(".")[0]
        d = [i, QPN]
        l.append(d)

# %% [markdown]
# Create the DataFrame and give names to the columns.

# %%
inst_df = pd.DataFrame(l)
inst_df.columns = ["xis", "id_text"]

# %% [markdown]
# Merge the two DataFrames on the field `xis`, using the keys from the left object (that is `inst_df`).

# %%
df = inst_df.merge(df_pn, on='xis', how='left')
df
# Out:
#              xis  id_text                                         headword pos
# 0    qpn.r000002  Q006482            Abi-hata[chief of the Ruʾuʾa tribe]RN  RN
# 1    qpn.r000002  Q006483            Abi-hata[chief of the Ruʾuʾa tribe]RN  RN
# 2    qpn.r000002  Q006484            Abi-hata[chief of the Ruʾuʾa tribe]RN  RN
# 3    qpn.r00000b  Q006524                            Ada[ruler of Šurda]RN  RN
# 4    qpn.r00000b  Q006557                            Ada[ruler of Šurda]RN  RN
# 5    qpn.r00000b  Q006563                            Ada[ruler of Šurda]RN  RN
# 6    qpn.r00000b  Q006563                            Ada[ruler of Šurda]RN  RN
# 7    qpn.r00000b  Q006592                            Ada[ruler of Šurda]RN  RN
# 8    qpn.r000010  Q006573  Adad-narari[Adad-narari III, king of Assyria]RN  RN
# 9    qpn.r000015  Q006482                  Ahhe-iddina[Gambulean sheikh]RN  RN
# 10   qpn.r000015  Q006483                  Ahhe-iddina[Gambulean sheikh]RN  RN
# 11   qpn.r000015  Q006484                  Ahhe-iddina[Gambulean sheikh]RN  RN
# 12   qpn.r000016  Q006482                       Ahi-Miti[king of Ashdod]RN  RN
# 13   qpn.r000016  Q006483                       Ahi-Miti[king of Ashdod]RN  RN
# 14   qpn.r000016  Q006484                       Ahi-Miti[king of Ashdod]RN  RN
# 15   qpn.r000016  Q006488                       Ahi-Miti[king of Ashdod]RN  RN
# 16   qpn.r000016  Q006563                       Ahi-Miti[king of Ashdod]RN  RN
# 17   qpn.r000026  Q006546                Akkussu[Median ruler of Usigur]RN  RN
# 18   qpn.r00003c  Q006482                         Ambaris[king of Tabal]RN  RN
# 19   qpn.r00003c  Q006482                         Ambaris[king of Tabal]RN  RN
# 20   qpn.r00003c  Q006483                         Ambaris[king of Tabal]RN  RN
# 21   qpn.r00003c  Q006483                         Ambaris[king of Tabal]RN  RN
# 22   qpn.r00003c  Q006488                         Ambaris[king of Tabal]RN  RN
# 23   qpn.r00003c  Q006488                         Ambaris[king of Tabal]RN  RN
# 24   qpn.r00003c  Q006524                         Ambaris[king of Tabal]RN  RN
# 25   qpn.r00003c  Q006555                         Ambaris[king of Tabal]RN  RN
# 26   qpn.r00003c  Q006557                         Ambaris[king of Tabal]RN  RN
# 27   qpn.r00003c  Q006563                         Ambaris[king of Tabal]RN  RN
# 28   qpn.r00003c  Q006586                         Ambaris[king of Tabal]RN  RN
# 29   qpn.r000040  Q006482                     Amitašši[ruler of Karalla]RN  RN
# ..           ...      ...                                              ...  ..
# 758  qpn.r0005e7  Q006584                       Urzana[ruler of Muṣaṣir]RN  RN
# 759  qpn.r0005eb  Q006544            Usilkanu[Osorkon IV, king of Egypt]RN  RN
# 760  qpn.r0005eb  Q006563            Usilkanu[Osorkon IV, king of Egypt]RN  RN
# 761  qpn.r0005f4  Q006546                      Ušra[ruler of Kanzabkani]RN  RN
# 762  qpn.r0005f4  Q006563                      Ušra[ruler of Kanzabkani]RN  RN
# 763  qpn.r0005f4  Q006596                      Ušra[ruler of Kanzabkani]RN  RN
# 764  qpn.r0005f4  Q006596                      Ušra[ruler of Kanzabkani]RN  RN
# 765  qpn.r0005f1  Q006596                                        UŠ-x[1]RN  RN
# 766  qpn.r0005ee  Q006546                      Uzi[Median ruler of Mali]RN  RN
# 767  qpn.r0005ef  Q006546                Uzitar[Median ruler of Qantayu]RN  RN
# 768  qpn.r0005f0  Q006546             Uzumanda[Median ruler of Kisilaha]RN  RN
# 769  qpn.r00063e  Q006482                                 x[(uncertain)]RN  RN
# 770  qpn.r00063e  Q006563                                 x[(uncertain)]RN  RN
# 771  qpn.r00063e  Q006563                                 x[(uncertain)]RN  RN
# 772  qpn.r00063e  Q006563                                 x[(uncertain)]RN  RN
# 773  qpn.r00063e  Q006650                                 x[(uncertain)]RN  RN
# 774  qpn.r000640  Q006563                xparnua[Median ruler of Sikris]RN  RN
# 775  qpn.r000630  Q006483                       x-iada[Gambulean sheikh]RN  RN
# 776  qpn.r000631  Q006482    x-sali[tribal leader in the Tubliaš region]RN  RN
# 777  qpn.r000633  Q006482                          x-x-me[tribal leader]RN  RN
# 778  qpn.r000603  Q006483                       Zabidu[Gambulean sheikh]RN  RN
# 779  qpn.r000603  Q006484                       Zabidu[Gambulean sheikh]RN  RN
# 780  qpn.r000607  Q006482                 Zala[city lord of Gilzilbunda]RN  RN
# 781  qpn.r000607  Q006546                 Zala[city lord of Gilzilbunda]RN  RN
# 782  qpn.r000610  Q006546             Zardukka[Median ruler of Harziani]RN  RN
# 783  qpn.r000610  Q006563             Zardukka[Median ruler of Harziani]RN  RN
# 784  qpn.r000610  Q006596             Zardukka[Median ruler of Harziani]RN  RN
# 785  qpn.r000619  Q006482    Zaruti[tribal leader in the Tubliaš region]RN  RN
# 786  qpn.r00062b  Q006482              Zizi[Median city lord of Appatar]PN  PN
# 787  qpn.r00062b  Q006546              Zizi[Median city lord of Appatar]PN  PN
#
# [788 rows x 4 columns]
