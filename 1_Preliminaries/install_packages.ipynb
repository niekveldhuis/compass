# %% [markdown]
# # Installing Anaconda
#
# In order to install Anaconda go to http://anaconda.com and choose the DOWNLOAD tab. Make sure to download the version for Python 3.x. Installing Anaconda will also install Python 3, Jupyter Notebook, Jupyter Lab, numerous Python packages, and several other tools.
#
# # Installing Python Packages
# With Anaconda, you already have a treasure trove of important Python packages, including `Pandas` (for data manipulation), `bokeh` (interactive visualisations), `requests` (for communicating with web sites), `scikit-learn` (machine learning) etc.
#
# Inevitably, we will be using packages not included in the standard Anaconda distribution. Before they can be imported in a Python script such packages (or libraries) need to be installed. A package needs to be *imported* every time when a script is started. It needs to be *installed* only once (and updated subsequently, if necessary).
#
# Installing packages can be a rather frustrating experience. The issue is that a computer may have more then one instance of Python installed. In order to use Python packages within a Jupyter Notebook, they need to be associated with the so-called Python *kernel* that runs in the background of the notebook (for a more technical description of the issue and a solution see the [article](https://jakevdp.github.io/blog/2017/12/05/installing-python-packages-from-jupyter/) by Jake VanderPlas in his [Pythonic Preambulations](https://jakevdp.github.io/) blog.
#
# The solution adopted here is to use so-called IPython `magic` functions, expanding on the functionality of standard Python. Magic functions are introduced with the % sign; in this notebook we will use `%pip`and `%conda` to call the two most important package managers (pip and conda, respectively). These commands were introduced in IPython version 7.3. To check the IPython version on your machine, open the terminal (Mac OS X) or the Anaconda Prompt (Windows) and type
# ```bash
# ipython --version
# ```
#
# If you need to upgrade IPython, open the terminal (Mac OS X) or the Anaconda Prompt (Windows) and type
# ```bash
# pip install ipython --upgrade
# ```
#
# # TODO
# create a list of packages to be installed.

# %%
#import sys

# %% [markdown]
# # 1.1 Preferred: Install with Conda
#
# # TODO
# conda may not be a great option - simply use pip.
# Include the following:
# If you receive an error message of the following type:
# > Cannot uninstall 'PyYAML'. It is a distutlis installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall
#
# use the `pip` option `--ignore-installed`, as follows:
# ```python
# !{sys.executable} -m pip install [package name] --ignore-installed
#
# Pip will check dependencies and compatability of installed packages and may run into trouble with previously installed libraries. The `--ignore-installed` option will reinstall the required version of those packages.

# %%
# !conda install --yes --prefix {sys.prefix} -c conda-forge cltk
# Out:
# EnvironmentLocationNotFound: Not a conda environment: /Users/veldhuis/github/Compass/1_Preliminaries/{sys.prefix}

# %%
# %conda update --yes -c conda-forge tqdm
# Out:
# Collecting package metadata (current_repodata.json): failed
#
# CondaHTTPError: HTTP 000 CONNECTION FAILED for url <https://conda.anaconda.org/conda-forge/osx-64/current_repodata.json>
# Elapsed: -
#
# An HTTP error occurred when trying to retrieve this URL.
# HTTP errors are often intermittent, and a simple retry will get you on your way.
# ConnectionError(MaxRetryError("HTTPSConnectionPool(host='conda.anaconda.org', port=443): Max retries exceeded with url: /conda-forge/osx-64/current_repodata.json (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11894d320>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))",),)
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2.1 Install with Pip

# %%
# !{sys.executable} -m pip install lexicalrichness

# %%
# !{sys.executable} -m pip install tqdm --upgrade

# %%
# !{sys.executable} -m pip install [package name] --ignore-installed

# %%
# %pip uninstall -y names
# Out:
# Uninstalling names-0.3.0:
#   Successfully uninstalled names-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %conda upgrade -c conda-forge conda-build
# Out:
# WARNING conda.base.context:use_only_tar_bz2(632): Conda is constrained to only using the old .tar.bz2 file format because you have conda-build installed, and it is <3.18.3.  Update or remove conda-build to get smaller downloads and faster extractions.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/veldhuis/anaconda3
#
#   added / updated specs:
#     - conda-build
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-5.1.0    |           py36_2           5 KB
#     absl-py-0.8.0              |           py36_0         157 KB  conda-forge
#     alabaster-0.7.12           |             py_0          15 KB  conda-forge
#     appnope-0.1.0              |        py36_1000           8 KB  conda-forge
#     appscript-1.1.0            |   py36h01d97ff_0         132 KB  conda-forge
#     asn1crypto-0.24.0          |        py36_1003         154 KB  conda-forge
#     astor-0.7.1                |             py_0          22 KB  conda-forge
#     astroid-2.2.5              |           py36_0         272 KB  conda-forge
#     atomicwrites-1.3.0         |             py_0           9 KB  conda-forge
#     attrs-19.1.0               |             py_0          32 KB  conda-forge
#     babel-2.7.0                |             py_0         5.9 MB  conda-forge
#     backcall-0.1.0             |             py_0          13 KB  conda-forge
#     backports-1.0              |             py_2           4 KB  conda-forge
#     backports.os-0.1.1         |        py36_1001          15 KB  conda-forge
#     backports.shutil_get_terminal_size-1.0.0|             py_3           7 KB  conda-forge
#     bitarray-1.0.1             |   py36h01d97ff_0          57 KB  conda-forge
#     bleach-3.1.0               |             py_0         110 KB  conda-forge
#     blosc-1.17.0               |       h6de7cb9_1         648 KB  conda-forge
#     boto-2.49.0                |             py_0         838 KB  conda-forge
#     bzip2-1.0.8                |       h01d97ff_1         148 KB  conda-forge
#     c-ares-1.15.0              |    h01d97ff_1001          81 KB  conda-forge
#     ca-certificates-2019.9.11  |       hecc5488_0         143 KB  conda-forge
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#     cffi-1.12.3                |   py36hccf1714_0         210 KB  conda-forge
#     click-7.0                  |             py_0          61 KB  conda-forge
#     cloudpickle-1.2.2          |             py_0          23 KB  conda-forge
#     clyent-1.2.2               |             py_1           9 KB  conda-forge
#     colorama-0.4.1             |             py_0          15 KB  conda-forge
#     conda-4.7.12               |           py36_0         3.0 MB  conda-forge
#     conda-build-3.18.9         |           py36_3         506 KB  conda-forge
#     conda-package-handling-1.4.1|           py36_0         261 KB  conda-forge
#     contextlib2-0.5.5          |             py_2          10 KB  conda-forge
#     cryptography-2.7           |   py36h212c5bf_0         566 KB  conda-forge
#     curl-7.65.3                |       h22ea746_0         125 KB  conda-forge
#     cycler-0.10.0              |             py_1           8 KB  conda-forge
#     cython-0.29.13             |   py36h6de7cb9_0         2.1 MB  conda-forge
#     cytoolz-0.10.0             |   py36h01d97ff_0         364 KB  conda-forge
#     dask-2.4.0                 |             py_0           4 KB  conda-forge
#     dask-core-2.4.0            |             py_0         575 KB  conda-forge
#     dbus-1.13.6                |       h2f22bb5_0         558 KB  conda-forge
#     decorator-4.4.0            |             py_0          11 KB  conda-forge
#     defusedxml-0.5.0           |             py_1          20 KB  conda-forge
#     distributed-2.4.0          |             py_0         375 KB  conda-forge
#     docutils-0.15.2            |           py36_0         739 KB  conda-forge
#     entrypoints-0.3            |        py36_1000          12 KB  conda-forge
#     et_xmlfile-1.0.1           |          py_1001          11 KB  conda-forge
#     expat-2.2.5                |    h6de7cb9_1003         128 KB  conda-forge
#     fastcache-1.1.0            |   py36h01d97ff_0          27 KB  conda-forge
#     filelock-3.0.10            |             py_0           9 KB  conda-forge
#     flask-1.1.1                |             py_1          69 KB  conda-forge
#     flask-cors-3.0.8           |             py_0          14 KB  conda-forge
#     freetype-2.10.0            |       h24853df_1         894 KB  conda-forge
#     fsspec-0.4.5               |             py_0          42 KB  conda-forge
#     gast-0.3.2                 |             py_0          11 KB  conda-forge
#     gettext-0.19.8.1           |    h46ab8bc_1002         3.3 MB  conda-forge
#     gevent-1.4.0               |   py36h470a237_0         2.5 MB  conda-forge
#     glib-2.58.3                |    h9d45998_1002         3.1 MB  conda-forge
#     glob2-0.7                  |             py_0          11 KB  conda-forge
#     gmp-6.1.2                  |    h0a44026_1000         734 KB  conda-forge
#     gmpy2-2.1.0b1              |   py36h1744cca_0         185 KB  conda-forge
#     greenlet-0.4.15            |   py36h01d97ff_0          20 KB  conda-forge
#     grpcio-1.23.0              |   py36h6ef0057_0         1.0 MB  conda-forge
#     h5py-2.10.0                |nompi_py36h6248fd5_100         1.0 MB  conda-forge
#     hdf5-1.10.5                |nompi_h15a436c_1103         3.0 MB  conda-forge
#     heapdict-1.0.0             |        py36_1000           7 KB  conda-forge
#     html5lib-1.0.1             |             py_0          89 KB  conda-forge
#     icu-58.2                   |    h0a44026_1000        22.3 MB  conda-forge
#     idna-2.8                   |        py36_1000         132 KB  conda-forge
#     imagesize-1.1.0            |             py_0           6 KB  conda-forge
#     importlib_metadata-0.23    |           py36_0          39 KB  conda-forge
#     intel-openmp-2019.4        |              233         1.1 MB
#     ipykernel-5.1.2            |   py36h5ca1d4c_0         159 KB  conda-forge
#     ipython-7.8.0              |   py36h5ca1d4c_0         1.1 MB  conda-forge
#     ipython_genutils-0.2.0     |             py_1          21 KB  conda-forge
#     isort-4.3.21               |           py36_0          64 KB  conda-forge
#     itsdangerous-1.1.0         |             py_0          16 KB  conda-forge
#     jbig-2.1                   |    h1de35cc_2001          41 KB  conda-forge
#     jdcal-1.4.1                |             py_0           9 KB  conda-forge
#     jedi-0.15.1                |           py36_0         706 KB  conda-forge
#     jinja2-2.10.1              |             py_0          91 KB  conda-forge
#     joblib-0.13.2              |             py_0         180 KB  conda-forge
#     jpeg-9c                    |    h1de35cc_1001         237 KB  conda-forge
#     jsonschema-3.0.2           |           py36_0          87 KB  conda-forge
#     jupyter-1.0.0              |             py_2           4 KB  conda-forge
#     jupyter_client-5.3.1       |             py_0          64 KB  conda-forge
#     jupyter_console-6.0.0      |             py_0          19 KB  conda-forge
#     jupyter_core-4.4.0         |             py_0          44 KB  conda-forge
#     jupyterlab_launcher-0.13.1 |             py_2          20 KB  conda-forge
#     jupyterlab_server-1.0.6    |             py_0          23 KB  conda-forge
#     keras-applications-1.0.8   |             py_1          30 KB  conda-forge
#     keras-preprocessing-1.1.0  |             py_0          33 KB  conda-forge
#     keyring-19.2.0             |           py36_0          49 KB  conda-forge
#     kiwisolver-1.1.0           |   py36h770b8ee_0          57 KB  conda-forge
#     krb5-1.16.3                |    hcfa6398_1001         1.1 MB  conda-forge
#     lazy-object-proxy-1.4.2    |   py36h01d97ff_0          26 KB  conda-forge
#     libarchive-3.3.3           |    h5c473cc_1006         1.5 MB  conda-forge
#     libblas-3.8.0              |      12_openblas          10 KB  conda-forge
#     libcblas-3.8.0             |      12_openblas          10 KB  conda-forge
#     libcurl-7.65.3             |       h16faf7d_0         547 KB  conda-forge
#     libcxx-8.0.1               |                0        1000 KB  conda-forge
#     libcxxabi-8.0.1            |                0         136 KB  conda-forge
#     libedit-3.1.20170329       |    hcfe32e1_1001         152 KB  conda-forge
#     libffi-3.2.1               |    h6de7cb9_1006          43 KB  conda-forge
#     libgfortran-4.0.0          |                2         716 KB  conda-forge
#     libiconv-1.15              |    h01d97ff_1005         1.3 MB  conda-forge
#     liblapack-3.8.0            |      12_openblas          10 KB  conda-forge
#     libopenblas-0.3.7          |       h4bb4525_1         8.3 MB  conda-forge
#     libpng-1.6.37              |       h2573ce8_0         298 KB  conda-forge
#     libprotobuf-3.9.1          |       hfbae3c0_0         4.4 MB  conda-forge
#     libsodium-1.0.17           |       h01d97ff_0         308 KB  conda-forge
#     libssh2-1.8.2              |       hcdc9a53_2         221 KB  conda-forge
#     libtiff-4.0.10             |    hd08fb8f_1003         527 KB  conda-forge
#     libxml2-2.9.9              |       hd80cff7_2         1.2 MB  conda-forge
#     libxslt-1.1.32             |    h1e79283_1003         491 KB  conda-forge
#     llvm-openmp-8.0.1          |       h770b8ee_0         253 KB  conda-forge
#     llvmlite-0.29.0            |   py36h3fea490_1        15.5 MB  conda-forge
#     locket-0.2.0               |             py_2           6 KB  conda-forge
#     lxml-4.4.1                 |   py36h08abf6f_0         1.4 MB  conda-forge
#     lz4-c-1.8.3                |    h6de7cb9_1001         139 KB  conda-forge
#     lzo-2.10                   |    h1de35cc_1000         176 KB  conda-forge
#     markdown-3.1.1             |             py_0          60 KB  conda-forge
#     markupsafe-1.1.1           |   py36h1de35cc_0          24 KB  conda-forge
#     matplotlib-base-3.1.1      |   py36h3a684a6_1         6.6 MB  conda-forge
#     mccabe-0.6.1               |             py_1           8 KB  conda-forge
#     mistune-0.8.4              |py36h1de35cc_1000          53 KB  conda-forge
#     mkl-2019.4                 |              233       155.2 MB
#     mkl-service-2.3.0          |   py36h01d97ff_0          45 KB  conda-forge
#     mock-3.0.5                 |           py36_0          44 KB  conda-forge
#     more-itertools-7.2.0       |             py_0          48 KB  conda-forge
#     mpc-1.1.0                  |    h3aece09_1006         140 KB  conda-forge
#     mpfr-4.0.2                 |       h0a95893_0         619 KB  conda-forge
#     mpmath-1.1.0               |             py_0         432 KB  conda-forge
#     msgpack-python-0.6.1       |   py36h04f5b5a_0          82 KB  conda-forge
#     multipledispatch-0.6.0     |             py_0          12 KB  conda-forge
#     nbconvert-5.6.0            |           py36_1         469 KB  conda-forge
#     nbformat-4.4.0             |             py_1          91 KB  conda-forge
#     ncurses-6.1                |    h0a44026_1002         1.3 MB  conda-forge
#     networkx-2.3               |             py_0         1.1 MB  conda-forge
#     nltk-3.4.4                 |             py_0         1.1 MB  conda-forge
#     nose-1.3.7                 |        py36_1002         214 KB  conda-forge
#     notebook-6.0.1             |           py36_0         6.0 MB  conda-forge
#     numba-0.45.1               |   py36h86efe34_0         3.0 MB  conda-forge
#     numexpr-2.7.0              |   py36h86efe34_0         129 KB  conda-forge
#     numpy-1.17.2               |   py36h6b0580a_0         5.0 MB  conda-forge
#     olefile-0.46               |             py_0          31 KB  conda-forge
#     openpyxl-2.6.3             |             py_0         152 KB  conda-forge
#     packaging-19.0             |             py_0          23 KB  conda-forge
#     pandas-0.25.1              |   py36h86efe34_0        10.4 MB  conda-forge
#     pandoc-2.7.3               |                0        15.3 MB  conda-forge
#     pandocfilters-1.4.2        |             py_1           9 KB  conda-forge
#     parso-0.5.1                |             py_0          65 KB  conda-forge
#     partd-1.0.0                |             py_0          16 KB  conda-forge
#     path.py-12.0.1             |             py_0          20 KB  conda-forge
#     pathlib2-2.3.4             |           py36_0          34 KB  conda-forge
#     pcre-8.41                  |    h0a44026_1003         222 KB  conda-forge
#     pep8-1.7.1                 |             py_0          30 KB  conda-forge
#     pexpect-4.7.0              |           py36_0          78 KB  conda-forge
#     pickleshare-0.7.5          |        py36_1000          12 KB  conda-forge
#     pillow-6.1.0               |   py36h75ffe9a_1         582 KB  conda-forge
#     pip-19.2.3                 |           py36_0         1.9 MB  conda-forge
#     pkginfo-1.5.0.1            |             py_0          21 KB  conda-forge
#     pluggy-0.12.0              |             py_0          18 KB  conda-forge
#     ply-3.11                   |             py_1          44 KB  conda-forge
#     prometheus_client-0.7.1    |             py_0          38 KB  conda-forge
#     prompt_toolkit-2.0.9       |             py_0         222 KB  conda-forge
#     protobuf-3.9.1             |   py36h6de7cb9_0         672 KB  conda-forge
#     psutil-5.6.3               |   py36h01d97ff_0         329 KB  conda-forge
#     ptyprocess-0.6.0           |          py_1001          15 KB  conda-forge
#     py-1.8.0                   |             py_0          65 KB  conda-forge
#     pycodestyle-2.5.0          |             py_0          36 KB  conda-forge
#     pycosat-0.6.3              |py36h1de35cc_1001         107 KB  conda-forge
#     pycparser-2.19             |           py36_1         173 KB  conda-forge
#     pycrypto-2.6.1             |py36h01d97ff_1003         473 KB  conda-forge
#     pycurl-7.43.0.2            |   py36ha206b4a_1          70 KB  conda-forge
#     pyflakes-2.1.1             |             py_0          49 KB  conda-forge
#     pygments-2.4.2             |             py_0         661 KB  conda-forge
#     pylint-2.3.1               |           py36_0         826 KB  conda-forge
#     pyodbc-4.0.27              |   py36h6de7cb9_0          63 KB  conda-forge
#     pyopenssl-19.0.0           |           py36_0          81 KB  conda-forge
#     pyparsing-2.4.2            |             py_0          57 KB  conda-forge
#     pyqt-5.9.2                 |   py36h2a560b1_4         4.6 MB  conda-forge
#     pyrsistent-0.15.4          |   py36h01d97ff_0          87 KB  conda-forge
#     pysocks-1.7.0              |           py36_0          26 KB  conda-forge
#     pytables-3.5.2             |   py36hd39446c_1         1.4 MB  conda-forge
#     pytest-5.1.2               |           py36_0         346 KB  conda-forge
#     pytest-astropy-0.5.0       |             py_0           6 KB  conda-forge
#     pytest-doctestplus-0.3.0   |             py_1          16 KB  conda-forge
#     pytest-openfiles-0.4.0     |             py_0           9 KB  conda-forge
#     pytest-remotedata-0.3.1    |             py_0          11 KB  conda-forge
#     python-dateutil-2.8.0      |             py_0         219 KB  conda-forge
#     python-libarchive-c-2.8    |        py36_1004          21 KB  conda-forge
#     python.app-1.2             |py36h1de35cc_1200         1.3 MB  conda-forge
#     pytz-2019.2                |             py_0         228 KB  conda-forge
#     pyyaml-5.1.2               |   py36h01d97ff_0         166 KB  conda-forge
#     pyzmq-18.1.0               |   py36hee98d25_0         458 KB  conda-forge
#     qt-5.9.7                   |       h93ee506_2        76.8 MB  conda-forge
#     qtawesome-0.6.0            |             py_0         668 KB  conda-forge
#     qtconsole-4.5.5            |             py_0          90 KB  conda-forge
#     qtpy-1.9.0                 |             py_0          34 KB  conda-forge
#     readline-7.0               |    hcfe32e1_1001         393 KB  conda-forge
#     requests-2.22.0            |           py36_1          84 KB  conda-forge
#     ripgrep-11.0.2             |                1         1.7 MB  conda-forge
#     rope-0.14.0                |             py_0         111 KB  conda-forge
#     ruamel_yaml-0.15.71        |py36h1de35cc_1000         239 KB  conda-forge
#     scikit-learn-0.21.3        |   py36hd4ffd6c_0         6.0 MB  conda-forge
#     scipy-1.3.1                |   py36h7e0e109_2        18.3 MB  conda-forge
#     send2trash-1.5.0           |             py_0          12 KB  conda-forge
#     setuptools-41.2.0          |           py36_0         621 KB  conda-forge
#     simplegeneric-0.8.1        |             py_1           7 KB  conda-forge
#     singledispatch-3.4.0.3     |        py36_1000          15 KB  conda-forge
#     sip-4.19.8                 |py36h0a44026_1000         251 KB  conda-forge
#     six-1.12.0                 |        py36_1000          22 KB  conda-forge
#     snowballstemmer-1.9.1      |             py_0          56 KB  conda-forge
#     sortedcollections-1.1.2    |             py_0          10 KB  conda-forge
#     sortedcontainers-2.1.0     |             py_0          25 KB  conda-forge
#     soupsieve-1.9.3            |           py36_0          57 KB  conda-forge
#     sphinx-2.2.0               |             py_0         1.5 MB  conda-forge
#     sphinxcontrib-serializinghtml-1.1.3|             py_0          24 KB  conda-forge
#     sphinxcontrib-websupport-1.1.2|             py_0          33 KB  conda-forge
#     spyder-3.3.6               |           py36_0         2.5 MB  conda-forge
#     spyder-kernels-0.5.2       |           py36_0          65 KB  conda-forge
#     sqlalchemy-1.3.8           |   py36h01d97ff_0         1.7 MB  conda-forge
#     sqlite-3.28.0              |       h9721f7c_0         2.4 MB  conda-forge
#     statsmodels-0.10.1         |   py36heacc8b8_0         8.9 MB  conda-forge
#     sympy-1.4                  |           py36_0         9.7 MB  conda-forge
#     tblib-1.4.0                |             py_0          12 KB  conda-forge
#     tensorboard-1.13.1         |           py36_0         3.3 MB  conda-forge
#     tensorflow-1.13.1          |           py36_1        57.2 MB  conda-forge
#     tensorflow-estimator-1.13.0|   py36h24bf2e0_0         472 KB  conda-forge
#     termcolor-1.1.0            |             py_2           6 KB  conda-forge
#     terminado-0.8.2            |           py36_0          23 KB  conda-forge
#     testpath-0.4.2             |          py_1001          85 KB  conda-forge
#     tk-8.6.9                   |    h2573ce8_1003         3.2 MB  conda-forge
#     toolz-0.10.0               |             py_0          46 KB  conda-forge
#     tornado-6.0.3              |   py36h01d97ff_0         636 KB  conda-forge
#     tqdm-4.35.0                |             py_0          42 KB  conda-forge
#     traitlets-4.3.2            |        py36_1000         131 KB  conda-forge
#     typed-ast-1.4.0            |   py36h01d97ff_0         195 KB  conda-forge
#     typing-3.6.4               |           py36_0          46 KB  conda-forge
#     unicodecsv-0.14.1          |             py_1          12 KB  conda-forge
#     unixodbc-2.3.7             |    hea208f4_1000         267 KB  conda-forge
#     urllib3-1.25.3             |           py36_0         187 KB  conda-forge
#     wcwidth-0.1.7              |             py_1          17 KB  conda-forge
#     webencodings-0.5.1         |             py_1          12 KB  conda-forge
#     werkzeug-0.15.6            |             py_0         260 KB  conda-forge
#     wheel-0.33.6               |           py36_0          35 KB  conda-forge
#     widgetsnbextension-3.4.2   |        py36_1000         1.7 MB  conda-forge
#     wrapt-1.11.2               |   py36h01d97ff_0          41 KB  conda-forge
#     wurlitzer-1.0.3            |           py36_0          12 KB  conda-forge
#     xlrd-1.2.0                 |             py_0         108 KB  conda-forge
#     xlsxwriter-1.2.1           |             py_0         102 KB  conda-forge
#     xlwings-0.15.10            |           py36_0         489 KB  conda-forge
#     xlwt-1.3.0                 |             py_1          83 KB  conda-forge
#     xz-5.2.4                   |    h1de35cc_1001         268 KB  conda-forge
#     yaml-0.1.7                 |    h1de35cc_1001          79 KB  conda-forge
#     zeromq-4.3.2               |       h6de7cb9_2         571 KB  conda-forge
#     zict-1.0.0                 |             py_0          10 KB  conda-forge
#     zipp-0.6.0                 |             py_0           7 KB  conda-forge
#     zlib-1.2.11                |    h01d97ff_1006         101 KB  conda-forge
#     zstd-1.4.0                 |       ha9f0a20_0         652 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       526.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   fsspec             conda-forge/noarch::fsspec-0.4.5-py_0
#   joblib             conda-forge/noarch::joblib-0.13.2-py_0
#   libblas            conda-forge/osx-64::libblas-3.8.0-12_openblas
#   libcblas           conda-forge/osx-64::libcblas-3.8.0-12_openblas
#   liblapack          conda-forge/osx-64::liblapack-3.8.0-12_openblas
#   libopenblas        conda-forge/osx-64::libopenblas-0.3.7-h4bb4525_1
#   llvm-openmp        conda-forge/osx-64::llvm-openmp-8.0.1-h770b8ee_0
#   mock               conda-forge/osx-64::mock-3.0.5-py36_0
#   ripgrep            conda-forge/osx-64::ripgrep-11.0.2-1
#   tensorflow-estima~ conda-forge/osx-64::tensorflow-estimator-1.13.0-py36h24bf2e0_0
#   typing             conda-forge/osx-64::typing-3.6.4-py36_0
#
# The following packages will be REMOVED:
#
#   _tflow_select-2.3.0-mkl
#   appdirs-1.4.3-py36h28b3542_0
#   automat-0.7.0-py36_0
#   blas-1.0-mkl
#   conda-env-2.6.0-1
#   constantly-15.1.0-py36h28b3542_0
#   hyperlink-18.0.0-py36_0
#   incremental-17.5.0-py36_0
#   mkl_fft-1.0.6-py36hb8a8100_0
#   mkl_random-1.0.1-py36h5d10147_1
#   numpy-base-1.15.4-py36h8a80b8c_0
#   pyasn1-0.4.4-py36h28b3542_0
#   pyasn1-modules-0.2.2-py36_0
#   service_identity-17.0.0-py36h28b3542_0
#   snappy-1.1.7-he62c110_3
#   tensorflow-base-1.12.0-mkl_py36h70e0e9a_0
#   twisted-17.5.0-py36_0
#   zope-1.0-py36_1
#   zope.interface-4.6.0-py36h1de35cc_0
#
# The following packages will be UPDATED:
#
#   absl-py                   pkgs/main::absl-py-0.6.1-py36_0 --> conda-forge::absl-py-0.8.0-py36_0
#   appnope            pkgs/main::appnope-0.1.0-py36hf537a9a~ --> conda-forge::appnope-0.1.0-py36_1000
#   appscript          pkgs/main::appscript-1.0.1-py36h1de35~ --> conda-forge::appscript-1.1.0-py36h01d97ff_0
#   asn1crypto            pkgs/main::asn1crypto-0.24.0-py36_0 --> conda-forge::asn1crypto-0.24.0-py36_1003
#   astroid                   pkgs/main::astroid-2.0.4-py36_0 --> conda-forge::astroid-2.2.5-py36_0
#   atomicwrites       pkgs/main/osx-64::atomicwrites-1.2.1-~ --> conda-forge/noarch::atomicwrites-1.3.0-py_0
#   attrs              pkgs/main/osx-64::attrs-18.2.0-py36h2~ --> conda-forge/noarch::attrs-19.1.0-py_0
#   babel                pkgs/main/osx-64::babel-2.6.0-py36_0 --> conda-forge/noarch::babel-2.7.0-py_0
#   backports          pkgs/main/osx-64::backports-1.0-py36_1 --> conda-forge/noarch::backports-1.0-py_2
#   backports.os         pkgs/main::backports.os-0.1.1-py36_0 --> conda-forge::backports.os-0.1.1-py36_1001
#   backports.shutil_~ pkgs/main/osx-64::backports.shutil_ge~ --> conda-forge/noarch::backports.shutil_get_terminal_size-1.0.0-py_3
#   bitarray           pkgs/main::bitarray-0.8.3-py36h1de35c~ --> conda-forge::bitarray-1.0.1-py36h01d97ff_0
#   bleach              pkgs/main/osx-64::bleach-3.0.2-py36_0 --> conda-forge/noarch::bleach-3.1.0-py_0
#   blosc                  pkgs/main::blosc-1.14.4-hd9629dc_0 --> conda-forge::blosc-1.17.0-h6de7cb9_1
#   bzip2                   pkgs/main::bzip2-1.0.6-h1de35cc_5 --> conda-forge::bzip2-1.0.8-h01d97ff_1
#   c-ares                pkgs/main::c-ares-1.15.0-h1de35cc_1 --> conda-forge::c-ares-1.15.0-h01d97ff_1001
#   ca-certificates                      2019.6.16-hecc5488_0 --> 2019.9.11-hecc5488_0
#   certifi                                  2019.6.16-py36_0 --> 2019.6.16-py36_1
#   cffi                pkgs/main::cffi-1.11.5-py36h6174b99_1 --> conda-forge::cffi-1.12.3-py36hccf1714_0
#   cloudpickle        pkgs/main/osx-64::cloudpickle-0.6.1-p~ --> conda-forge/noarch::cloudpickle-1.2.2-py_0
#   colorama           pkgs/main/osx-64::colorama-0.4.0-py36~ --> conda-forge/noarch::colorama-0.4.1-py_0
#   conda                                        4.7.5-py36_0 --> 4.7.12-py36_0
#   conda-build                                 3.17.8-py36_1 --> 3.18.9-py36_3
#   conda-package-han~                          1.3.11-py36_0 --> 1.4.1-py36_0
#   contextlib2        pkgs/main/osx-64::contextlib2-0.5.5-p~ --> conda-forge/noarch::contextlib2-0.5.5-py_2
#   cryptography       pkgs/main::cryptography-2.4.2-py36ha1~ --> conda-forge::cryptography-2.7-py36h212c5bf_0
#   curl                 pkgs/main::curl-7.63.0-ha441bb4_1000 --> conda-forge::curl-7.65.3-h22ea746_0
#   cycler             pkgs/main/osx-64::cycler-0.10.0-py36h~ --> conda-forge/noarch::cycler-0.10.0-py_1
#   cython              pkgs/main::cython-0.29-py36h0a44026_0 --> conda-forge::cython-0.29.13-py36h6de7cb9_0
#   cytoolz            pkgs/main::cytoolz-0.9.0.1-py36h1de35~ --> conda-forge::cytoolz-0.10.0-py36h01d97ff_0
#   dask                                           1.0.0-py_1 --> 2.4.0-py_0
#   dask-core          pkgs/main/osx-64::dask-core-1.0.0-py3~ --> conda-forge/noarch::dask-core-2.4.0-py_0
#   dbus                    pkgs/main::dbus-1.13.2-h760590f_1 --> conda-forge::dbus-1.13.6-h2f22bb5_0
#   decorator          pkgs/main/osx-64::decorator-4.3.0-py3~ --> conda-forge/noarch::decorator-4.4.0-py_0
#   distributed        pkgs/main/osx-64::distributed-1.25.0-~ --> conda-forge/noarch::distributed-2.4.0-py_0
#   docutils           pkgs/main::docutils-0.14-py36hbfde631~ --> conda-forge::docutils-0.15.2-py36_0
#   entrypoints           pkgs/main::entrypoints-0.2.3-py36_2 --> conda-forge::entrypoints-0.3-py36_1000
#   et_xmlfile         pkgs/main/osx-64::et_xmlfile-1.0.1-py~ --> conda-forge/noarch::et_xmlfile-1.0.1-py_1001
#   fastcache          pkgs/main::fastcache-1.0.2-py36h1de35~ --> conda-forge::fastcache-1.1.0-py36h01d97ff_0
#   flask                pkgs/main/osx-64::flask-1.0.2-py36_1 --> conda-forge/noarch::flask-1.1.1-py_1
#   flask-cors         pkgs/main/osx-64::flask-cors-3.0.7-py~ --> conda-forge/noarch::flask-cors-3.0.8-py_0
#   freetype             pkgs/main::freetype-2.9.1-hb4e5f40_0 --> conda-forge::freetype-2.10.0-h24853df_1
#   gast                  pkgs/main/osx-64::gast-0.2.0-py36_0 --> conda-forge/noarch::gast-0.3.2-py_0
#   gettext            pkgs/main::gettext-0.19.8.1-h15daf44_3 --> conda-forge::gettext-0.19.8.1-h46ab8bc_1002
#   gevent             pkgs/main::gevent-1.3.7-py36h1de35cc_1 --> conda-forge::gevent-1.4.0-py36h470a237_0
#   glib                    pkgs/main::glib-2.56.2-hd9629dc_0 --> conda-forge::glib-2.58.3-h9d45998_1002
#   glob2                  pkgs/main/osx-64::glob2-0.6-py36_1 --> conda-forge/noarch::glob2-0.7-py_0
#   gmp                       pkgs/main::gmp-6.1.2-hb37e062_1 --> conda-forge::gmp-6.1.2-h0a44026_1000
#   gmpy2               pkgs/main::gmpy2-2.0.8-py36h6ef4df4_2 --> conda-forge::gmpy2-2.1.0b1-py36h1744cca_0
#   grpcio             pkgs/main::grpcio-1.16.1-py36h044775b~ --> conda-forge::grpcio-1.23.0-py36h6ef0057_0
#   h5py                 pkgs/main::h5py-2.8.0-py36h878fce3_3 --> conda-forge::h5py-2.10.0-nompi_py36h6248fd5_100
#   hdf5                    pkgs/main::hdf5-1.10.2-hfa1e0ec_1 --> conda-forge::hdf5-1.10.5-nompi_h15a436c_1103
#   heapdict                 pkgs/main::heapdict-1.0.0-py36_2 --> conda-forge::heapdict-1.0.0-py36_1000
#   icu                        pkgs/main::icu-58.2-h4b95b61_1 --> conda-forge::icu-58.2-h0a44026_1000
#   idna                           pkgs/main::idna-2.7-py36_0 --> conda-forge::idna-2.8-py36_1000
#   importlib_metadata pkgs/main::importlib_metadata-0.6-py3~ --> conda-forge::importlib_metadata-0.23-py36_0
#   intel-openmp                                   2019.1-144 --> 2019.4-233
#   ipykernel          pkgs/main::ipykernel-5.1.0-py36h39e3c~ --> conda-forge::ipykernel-5.1.2-py36h5ca1d4c_0
#   ipython            pkgs/main::ipython-7.1.1-py36h39e3cac~ --> conda-forge::ipython-7.8.0-py36h5ca1d4c_0
#   ipython_genutils   pkgs/main/osx-64::ipython_genutils-0.~ --> conda-forge/noarch::ipython_genutils-0.2.0-py_1
#   isort                       pkgs/main::isort-4.3.4-py36_0 --> conda-forge::isort-4.3.21-py36_0
#   jbig                       pkgs/main::jbig-2.1-h4d881f8_0 --> conda-forge::jbig-2.1-h1de35cc_2001
#   jdcal                  pkgs/main/osx-64::jdcal-1.4-py36_0 --> conda-forge/noarch::jdcal-1.4.1-py_0
#   jedi                        pkgs/main::jedi-0.13.1-py36_0 --> conda-forge::jedi-0.15.1-py36_0
#   jinja2               pkgs/main/osx-64::jinja2-2.10-py36_0 --> conda-forge/noarch::jinja2-2.10.1-py_0
#   jpeg                        pkgs/main::jpeg-9b-he5867d9_2 --> conda-forge::jpeg-9c-h1de35cc_1001
#   jsonschema         pkgs/main::jsonschema-2.6.0-py36hb385~ --> conda-forge::jsonschema-3.0.2-py36_0
#   jupyter_client     pkgs/main/osx-64::jupyter_client-5.2.~ --> conda-forge/noarch::jupyter_client-5.3.1-py_0
#   jupyterlab_launch~ pkgs/main/osx-64::jupyterlab_launcher~ --> conda-forge/noarch::jupyterlab_launcher-0.13.1-py_2
#   jupyterlab_server  pkgs/main::jupyterlab_server-1.0.0-py~ --> conda-forge::jupyterlab_server-1.0.6-py_0
#   keras-applications pkgs/main/osx-64::keras-applications-~ --> conda-forge/noarch::keras-applications-1.0.8-py_1
#   keras-preprocessi~ pkgs/main/osx-64::keras-preprocessing~ --> conda-forge/noarch::keras-preprocessing-1.1.0-py_0
#   keyring                  pkgs/main::keyring-16.1.0-py36_0 --> conda-forge::keyring-19.2.0-py36_0
#   kiwisolver         pkgs/main::kiwisolver-1.0.1-py36h0a44~ --> conda-forge::kiwisolver-1.1.0-py36h770b8ee_0
#   krb5                    pkgs/main::krb5-1.16.1-hddcf347_7 --> conda-forge::krb5-1.16.3-hcfa6398_1001
#   lazy-object-proxy  pkgs/main::lazy-object-proxy-1.3.1-py~ --> conda-forge::lazy-object-proxy-1.4.2-py36h01d97ff_0
#   libarchive         pkgs/main::libarchive-3.3.3-h786848e_5 --> conda-forge::libarchive-3.3.3-h5c473cc_1006
#   libcurl            pkgs/main::libcurl-7.63.0-h051b688_10~ --> conda-forge::libcurl-7.65.3-h16faf7d_0
#   libcxx                 pkgs/main::libcxx-4.0.1-hcfea43d_1 --> conda-forge::libcxx-8.0.1-0
#   libcxxabi           pkgs/main::libcxxabi-4.0.1-hcfea43d_1 --> conda-forge::libcxxabi-8.0.1-0
#   libedit            pkgs/main::libedit-3.1.20170329-hb402~ --> conda-forge::libedit-3.1.20170329-hcfe32e1_1001
#   libffi                 pkgs/main::libffi-3.2.1-h475c297_4 --> conda-forge::libffi-3.2.1-h6de7cb9_1006
#   libgfortran        pkgs/main::libgfortran-3.0.1-h93005f0~ --> conda-forge::libgfortran-4.0.0-2
#   libiconv              pkgs/main::libiconv-1.15-hdd342a3_7 --> conda-forge::libiconv-1.15-h01d97ff_1005
#   libpng                pkgs/main::libpng-1.6.35-ha441bb4_0 --> conda-forge::libpng-1.6.37-h2573ce8_0
#   libprotobuf        pkgs/main::libprotobuf-3.6.1-hd9629dc~ --> conda-forge::libprotobuf-3.9.1-hfbae3c0_0
#   libsodium          pkgs/main::libsodium-1.0.16-h3efe00b_0 --> conda-forge::libsodium-1.0.17-h01d97ff_0
#   libssh2               pkgs/main::libssh2-1.8.0-ha12b0ac_4 --> conda-forge::libssh2-1.8.2-hcdc9a53_2
#   libtiff               pkgs/main::libtiff-4.0.9-hcb84e12_2 --> conda-forge::libtiff-4.0.10-hd08fb8f_1003
#   libxml2               pkgs/main::libxml2-2.9.8-hab757c2_1 --> conda-forge::libxml2-2.9.9-hd80cff7_2
#   libxslt              pkgs/main::libxslt-1.1.32-hb819dd2_0 --> conda-forge::libxslt-1.1.32-h1e79283_1003
#   llvmlite           pkgs/main::llvmlite-0.26.0-py36h8c7ce~ --> conda-forge::llvmlite-0.29.0-py36h3fea490_1
#   locket             pkgs/main/osx-64::locket-0.2.0-py36hc~ --> conda-forge/noarch::locket-0.2.0-py_2
#   lxml                 pkgs/main::lxml-4.2.5-py36hef8c89e_0 --> conda-forge::lxml-4.4.1-py36h08abf6f_0
#   lz4-c                 pkgs/main::lz4-c-1.8.1.2-h1de35cc_0 --> conda-forge::lz4-c-1.8.3-h6de7cb9_1001
#   lzo                        pkgs/main::lzo-2.10-h362108e_2 --> conda-forge::lzo-2.10-h1de35cc_1000
#   markdown           pkgs/main/osx-64::markdown-3.0.1-py36~ --> conda-forge/noarch::markdown-3.1.1-py_0
#   markupsafe         pkgs/main::markupsafe-1.1.0-py36h1de3~ --> conda-forge::markupsafe-1.1.1-py36h1de35cc_0
#   matplotlib-base                      3.1.1-py36h3a684a6_0 --> 3.1.1-py36h3a684a6_1
#   mistune            pkgs/main::mistune-0.8.4-py36h1de35cc~ --> conda-forge::mistune-0.8.4-py36h1de35cc_1000
#   mkl                                            2018.0.3-1 --> 2019.4-233
#   mkl-service        pkgs/main::mkl-service-1.1.2-py36h6b9~ --> conda-forge::mkl-service-2.3.0-py36h01d97ff_0
#   more-itertools     pkgs/main/osx-64::more-itertools-4.3.~ --> conda-forge/noarch::more-itertools-7.2.0-py_0
#   mpc                       pkgs/main::mpc-1.1.0-h6ef4df4_1 --> conda-forge::mpc-1.1.0-h3aece09_1006
#   mpfr                     pkgs/main::mpfr-4.0.1-h3018a27_3 --> conda-forge::mpfr-4.0.2-h0a95893_0
#   mpmath              pkgs/main/osx-64::mpmath-1.0.0-py36_2 --> conda-forge/noarch::mpmath-1.1.0-py_0
#   msgpack-python     pkgs/main::msgpack-python-0.5.6-py36h~ --> conda-forge::msgpack-python-0.6.1-py36h04f5b5a_0
#   nbconvert               pkgs/main::nbconvert-5.3.1-py36_0 --> conda-forge::nbconvert-5.6.0-py36_1
#   nbformat           pkgs/main/osx-64::nbformat-4.4.0-py36~ --> conda-forge/noarch::nbformat-4.4.0-py_1
#   ncurses                 pkgs/main::ncurses-6.1-h0a44026_1 --> conda-forge::ncurses-6.1-h0a44026_1002
#   networkx            pkgs/main/osx-64::networkx-2.2-py36_1 --> conda-forge/noarch::networkx-2.3-py_0
#   nltk                  pkgs/main/osx-64::nltk-3.3.0-py36_0 --> conda-forge/noarch::nltk-3.4.4-py_0
#   nose                         pkgs/main::nose-1.3.7-py36_2 --> conda-forge::nose-1.3.7-py36_1002
#   notebook                 pkgs/main::notebook-5.7.2-py36_0 --> conda-forge::notebook-6.0.1-py36_0
#   numba                            0.41.0-py36h1702cab_1000 --> 0.45.1-py36h86efe34_0
#   numexpr                           2.6.9-py36h1702cab_1000 --> 2.7.0-py36h86efe34_0
#   numpy              pkgs/main::numpy-1.15.4-py36h6a91979_0 --> conda-forge::numpy-1.17.2-py36h6b0580a_0
#   openpyxl           pkgs/main/osx-64::openpyxl-2.5.9-py36~ --> conda-forge/noarch::openpyxl-2.6.3-py_0
#   packaging          pkgs/main/osx-64::packaging-18.0-py36~ --> conda-forge/noarch::packaging-19.0-py_0
#   pandas                              0.24.2-py36h86efe34_0 --> 0.25.1-py36h86efe34_0
#   pandoc                        pkgs/main::pandoc-2.2.3.2-0 --> conda-forge::pandoc-2.7.3-0
#   parso                pkgs/main/osx-64::parso-0.3.1-py36_0 --> conda-forge/noarch::parso-0.5.1-py_0
#   partd                pkgs/main/osx-64::partd-0.3.9-py36_0 --> conda-forge/noarch::partd-1.0.0-py_0
#   path.py            pkgs/main/osx-64::path.py-11.5.0-py36~ --> conda-forge/noarch::path.py-12.0.1-py_0
#   pathlib2                 pkgs/main::pathlib2-2.3.2-py36_0 --> conda-forge::pathlib2-2.3.4-py36_0
#   pexpect                   pkgs/main::pexpect-4.6.0-py36_0 --> conda-forge::pexpect-4.7.0-py36_0
#   pickleshare           pkgs/main::pickleshare-0.7.5-py36_0 --> conda-forge::pickleshare-0.7.5-py36_1000
#   pillow             pkgs/main::pillow-5.3.0-py36hb68e598_0 --> conda-forge::pillow-6.1.0-py36h75ffe9a_1
#   pip                            pkgs/main::pip-18.1-py36_0 --> conda-forge::pip-19.2.3-py36_0
#   pkginfo            pkgs/main/osx-64::pkginfo-1.4.2-py36_1 --> conda-forge/noarch::pkginfo-1.5.0.1-py_0
#   pluggy              pkgs/main/osx-64::pluggy-0.8.0-py36_0 --> conda-forge/noarch::pluggy-0.12.0-py_0
#   ply                     pkgs/main/osx-64::ply-3.11-py36_0 --> conda-forge/noarch::ply-3.11-py_1
#   prometheus_client  pkgs/main/osx-64::prometheus_client-0~ --> conda-forge/noarch::prometheus_client-0.7.1-py_0
#   prompt_toolkit     pkgs/main/osx-64::prompt_toolkit-2.0.~ --> conda-forge/noarch::prompt_toolkit-2.0.9-py_0
#   protobuf           pkgs/main::protobuf-3.6.1-py36h0a4402~ --> conda-forge::protobuf-3.9.1-py36h6de7cb9_0
#   psutil             pkgs/main::psutil-5.4.8-py36h1de35cc_0 --> conda-forge::psutil-5.6.3-py36h01d97ff_0
#   ptyprocess         pkgs/main/osx-64::ptyprocess-0.6.0-py~ --> conda-forge/noarch::ptyprocess-0.6.0-py_1001
#   py                      pkgs/main/osx-64::py-1.7.0-py36_0 --> conda-forge/noarch::py-1.8.0-py_0
#   pycodestyle        pkgs/main/osx-64::pycodestyle-2.4.0-p~ --> conda-forge/noarch::pycodestyle-2.5.0-py_0
#   pycosat            pkgs/main::pycosat-0.6.3-py36h1de35cc~ --> conda-forge::pycosat-0.6.3-py36h1de35cc_1001
#   pycparser                pkgs/main::pycparser-2.19-py36_0 --> conda-forge::pycparser-2.19-py36_1
#   pycrypto           pkgs/main::pycrypto-2.6.1-py36h1de35c~ --> conda-forge::pycrypto-2.6.1-py36h01d97ff_1003
#   pycurl             pkgs/main::pycurl-7.43.0.2-py36ha12b0~ --> conda-forge::pycurl-7.43.0.2-py36ha206b4a_1
#   pyflakes           pkgs/main/osx-64::pyflakes-2.0.0-py36~ --> conda-forge/noarch::pyflakes-2.1.1-py_0
#   pygments           pkgs/main/osx-64::pygments-2.2.0-py36~ --> conda-forge/noarch::pygments-2.4.2-py_0
#   pylint                     pkgs/main::pylint-2.1.1-py36_0 --> conda-forge::pylint-2.3.1-py36_0
#   pyodbc             pkgs/main::pyodbc-4.0.24-py36h0a44026~ --> conda-forge::pyodbc-4.0.27-py36h6de7cb9_0
#   pyopenssl              pkgs/main::pyopenssl-18.0.0-py36_0 --> conda-forge::pyopenssl-19.0.0-py36_0
#   pyparsing          pkgs/main/osx-64::pyparsing-2.3.0-py3~ --> conda-forge/noarch::pyparsing-2.4.2-py_0
#   pyqt                 pkgs/main::pyqt-5.9.2-py36h655552a_2 --> conda-forge::pyqt-5.9.2-py36h2a560b1_4
#   pyrsistent                          0.15.3-py36h01d97ff_0 --> 0.15.4-py36h01d97ff_0
#   pysocks                   pkgs/main::pysocks-1.6.8-py36_0 --> conda-forge::pysocks-1.7.0-py36_0
#   pytables                             3.4.4-py36h247b57e_1 --> 3.5.2-py36hd39446c_1
#   pytest                     pkgs/main::pytest-4.0.0-py36_0 --> conda-forge::pytest-5.1.2-py36_0
#   pytest-astropy                                 0.4.0-py_0 --> 0.5.0-py_0
#   pytest-doctestplus                             0.3.0-py_0 --> 0.3.0-py_1
#   pytest-openfiles   pkgs/main/osx-64::pytest-openfiles-0.~ --> conda-forge/noarch::pytest-openfiles-0.4.0-py_0
#   python-dateutil    pkgs/main/osx-64::python-dateutil-2.7~ --> conda-forge/noarch::python-dateutil-2.8.0-py_0
#   python-libarchive~ pkgs/main::python-libarchive-c-2.8-py~ --> conda-forge::python-libarchive-c-2.8-py36_1004
#   pytz                 pkgs/main/osx-64::pytz-2018.7-py36_0 --> conda-forge/noarch::pytz-2019.2-py_0
#   pyyaml              pkgs/main::pyyaml-3.13-py36h1de35cc_0 --> conda-forge::pyyaml-5.1.2-py36h01d97ff_0
#   pyzmq              pkgs/main::pyzmq-17.1.2-py36h1de35cc_0 --> conda-forge::pyzmq-18.1.0-py36hee98d25_0
#   qt                         pkgs/main::qt-5.9.6-h45cd832_2 --> conda-forge::qt-5.9.7-h93ee506_2
#   qtawesome          pkgs/main/osx-64::qtawesome-0.5.3-py3~ --> conda-forge/noarch::qtawesome-0.6.0-py_0
#   qtconsole          pkgs/main/osx-64::qtconsole-4.4.2-py3~ --> conda-forge/noarch::qtconsole-4.5.5-py_0
#   qtpy                  pkgs/main/osx-64::qtpy-1.5.2-py36_0 --> conda-forge/noarch::qtpy-1.9.0-py_0
#   readline               pkgs/main::readline-7.0-h1de35cc_5 --> conda-forge::readline-7.0-hcfe32e1_1001
#   requests                                    2.22.0-py36_0 --> 2.22.0-py36_1
#   rope                 pkgs/main/osx-64::rope-0.11.0-py36_0 --> conda-forge/noarch::rope-0.14.0-py_0
#   ruamel_yaml        pkgs/main::ruamel_yaml-0.15.46-py36h1~ --> conda-forge::ruamel_yaml-0.15.71-py36h1de35cc_1000
#   scikit-learn       pkgs/main::scikit-learn-0.20.1-py36h4~ --> conda-forge::scikit-learn-0.21.3-py36hd4ffd6c_0
#   scipy               pkgs/main::scipy-1.1.0-py36h28f7352_1 --> conda-forge::scipy-1.3.1-py36h7e0e109_2
#   setuptools            pkgs/main::setuptools-40.6.2-py36_0 --> conda-forge::setuptools-41.2.0-py36_0
#   singledispatch     pkgs/main::singledispatch-3.4.0.3-py3~ --> conda-forge::singledispatch-3.4.0.3-py36_1000
#   sip                  pkgs/main::sip-4.19.8-py36h0a44026_0 --> conda-forge::sip-4.19.8-py36h0a44026_1000
#   six                          pkgs/main::six-1.11.0-py36_1 --> conda-forge::six-1.12.0-py36_1000
#   snowballstemmer    pkgs/main/osx-64::snowballstemmer-1.2~ --> conda-forge/noarch::snowballstemmer-1.9.1-py_0
#   sortedcollections  pkgs/main/osx-64::sortedcollections-1~ --> conda-forge/noarch::sortedcollections-1.1.2-py_0
#   sortedcontainers   pkgs/main/osx-64::sortedcontainers-2.~ --> conda-forge/noarch::sortedcontainers-2.1.0-py_0
#   soupsieve               pkgs/main::soupsieve-1.7.1-py36_0 --> conda-forge::soupsieve-1.9.3-py36_0
#   sphinx                                         2.1.2-py_0 --> 2.2.0-py_0
#   sphinxcontrib-ser~                             1.1.1-py_0 --> 1.1.3-py_0
#   sphinxcontrib-web~ pkgs/main/osx-64::sphinxcontrib-websu~ --> conda-forge/noarch::sphinxcontrib-websupport-1.1.2-py_0
#   spyder                                       3.3.1-py36_2 --> 3.3.6-py36_0
#   spyder-kernels     pkgs/main::spyder-kernels-0.3.0-py36_0 --> conda-forge::spyder-kernels-0.5.2-py36_0
#   sqlalchemy         pkgs/main::sqlalchemy-1.2.14-py36h1de~ --> conda-forge::sqlalchemy-1.3.8-py36h01d97ff_0
#   sqlite                pkgs/main::sqlite-3.25.3-ha441bb4_0 --> conda-forge::sqlite-3.28.0-h9721f7c_0
#   statsmodels                         0.10.0-py36heacc8b8_0 --> 0.10.1-py36heacc8b8_0
#   sympy                         pkgs/main::sympy-1.3-py36_0 --> conda-forge::sympy-1.4-py36_0
#   tblib              pkgs/main/osx-64::tblib-1.3.2-py36hda~ --> conda-forge/noarch::tblib-1.4.0-py_0
#   tensorboard        pkgs/main::tensorboard-1.12.0-py36hdc~ --> conda-forge::tensorboard-1.13.1-py36_0
#   tensorflow         pkgs/main::tensorflow-1.12.0-mkl_py36~ --> conda-forge::tensorflow-1.13.1-py36_1
#   termcolor          pkgs/main/osx-64::termcolor-1.1.0-py3~ --> conda-forge/noarch::termcolor-1.1.0-py_2
#   terminado               pkgs/main::terminado-0.8.1-py36_1 --> conda-forge::terminado-0.8.2-py36_0
#   testpath           pkgs/main/osx-64::testpath-0.4.2-py36~ --> conda-forge/noarch::testpath-0.4.2-py_1001
#   tk                         pkgs/main::tk-8.6.8-ha441bb4_0 --> conda-forge::tk-8.6.9-h2573ce8_1003
#   toolz                pkgs/main/osx-64::toolz-0.9.0-py36_0 --> conda-forge/noarch::toolz-0.10.0-py_0
#   tornado            pkgs/main::tornado-5.1.1-py36h1de35cc~ --> conda-forge::tornado-6.0.3-py36h01d97ff_0
#   tqdm               pkgs/main/osx-64::tqdm-4.28.1-py36h28~ --> conda-forge/noarch::tqdm-4.35.0-py_0
#   traitlets          pkgs/main::traitlets-4.3.2-py36h65bd3~ --> conda-forge::traitlets-4.3.2-py36_1000
#   typed-ast          pkgs/main::typed-ast-1.1.0-py36h1de35~ --> conda-forge::typed-ast-1.4.0-py36h01d97ff_0
#   unicodecsv         pkgs/main/osx-64::unicodecsv-0.14.1-p~ --> conda-forge/noarch::unicodecsv-0.14.1-py_1
#   unixodbc             pkgs/main::unixodbc-2.3.7-h1de35cc_0 --> conda-forge::unixodbc-2.3.7-hea208f4_1000
#   urllib3                    pkgs/main::urllib3-1.23-py36_0 --> conda-forge::urllib3-1.25.3-py36_0
#   wcwidth            pkgs/main/osx-64::wcwidth-0.1.7-py36h~ --> conda-forge/noarch::wcwidth-0.1.7-py_1
#   werkzeug           pkgs/main/osx-64::werkzeug-0.14.1-py3~ --> conda-forge/noarch::werkzeug-0.15.6-py_0
#   wheel                      pkgs/main::wheel-0.32.3-py36_0 --> conda-forge::wheel-0.33.6-py36_0
#   widgetsnbextension pkgs/main::widgetsnbextension-3.4.2-p~ --> conda-forge::widgetsnbextension-3.4.2-py36_1000
#   wrapt              pkgs/main::wrapt-1.10.11-py36h1de35cc~ --> conda-forge::wrapt-1.11.2-py36h01d97ff_0
#   wurlitzer               pkgs/main::wurlitzer-1.0.2-py36_0 --> conda-forge::wurlitzer-1.0.3-py36_0
#   xlrd                  pkgs/main/osx-64::xlrd-1.1.0-py36_1 --> conda-forge/noarch::xlrd-1.2.0-py_0
#   xlsxwriter         pkgs/main/osx-64::xlsxwriter-1.1.2-py~ --> conda-forge/noarch::xlsxwriter-1.2.1-py_0
#   xlwings                  pkgs/main::xlwings-0.14.1-py36_0 --> conda-forge::xlwings-0.15.10-py36_0
#   xlwt               pkgs/main/osx-64::xlwt-1.2.0-py36h5ad~ --> conda-forge/noarch::xlwt-1.3.0-py_1
#   xz                         pkgs/main::xz-5.2.4-h1de35cc_4 --> conda-forge::xz-5.2.4-h1de35cc_1001
#   yaml                     pkgs/main::yaml-0.1.7-hc338f04_2 --> conda-forge::yaml-0.1.7-h1de35cc_1001
#   zeromq                 pkgs/main::zeromq-4.2.5-h0a44026_1 --> conda-forge::zeromq-4.3.2-h6de7cb9_2
#   zict                  pkgs/main/osx-64::zict-0.1.3-py36_0 --> conda-forge/noarch::zict-1.0.0-py_0
#   zipp                                           0.5.1-py_0 --> 0.6.0-py_0
#   zlib                    pkgs/main::zlib-1.2.11-h1de35cc_3 --> conda-forge::zlib-1.2.11-h01d97ff_1006
#   zstd                     pkgs/main::zstd-1.3.7-h5bba6e5_0 --> conda-forge::zstd-1.4.0-ha9f0a20_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   alabaster          pkgs/main/osx-64::alabaster-0.7.12-py~ --> conda-forge/noarch::alabaster-0.7.12-py_0
#   astor                pkgs/main/osx-64::astor-0.7.1-py36_0 --> conda-forge/noarch::astor-0.7.1-py_0
#   backcall           pkgs/main/osx-64::backcall-0.1.0-py36~ --> conda-forge/noarch::backcall-0.1.0-py_0
#   boto                 pkgs/main/osx-64::boto-2.49.0-py36_0 --> conda-forge/noarch::boto-2.49.0-py_0
#   click                  pkgs/main/osx-64::click-7.0-py36_0 --> conda-forge/noarch::click-7.0-py_0
#   clyent              pkgs/main/osx-64::clyent-1.2.2-py36_1 --> conda-forge/noarch::clyent-1.2.2-py_1
#   defusedxml         pkgs/main/osx-64::defusedxml-0.5.0-py~ --> conda-forge/noarch::defusedxml-0.5.0-py_1
#   expat                   pkgs/main::expat-2.2.6-h0a44026_0 --> conda-forge::expat-2.2.5-h6de7cb9_1003
#   filelock           pkgs/main/osx-64::filelock-3.0.10-py3~ --> conda-forge/noarch::filelock-3.0.10-py_0
#   greenlet           pkgs/main::greenlet-0.4.15-py36h1de35~ --> conda-forge::greenlet-0.4.15-py36h01d97ff_0
#   html5lib           pkgs/main/osx-64::html5lib-1.0.1-py36~ --> conda-forge/noarch::html5lib-1.0.1-py_0
#   imagesize          pkgs/main/osx-64::imagesize-1.1.0-py3~ --> conda-forge/noarch::imagesize-1.1.0-py_0
#   itsdangerous       pkgs/main/osx-64::itsdangerous-1.1.0-~ --> conda-forge/noarch::itsdangerous-1.1.0-py_0
#   jupyter            pkgs/main/osx-64::jupyter-1.0.0-py36_7 --> conda-forge/noarch::jupyter-1.0.0-py_2
#   jupyter_console    pkgs/main/osx-64::jupyter_console-6.0~ --> conda-forge/noarch::jupyter_console-6.0.0-py_0
#   jupyter_core       pkgs/main/osx-64::jupyter_core-4.4.0-~ --> conda-forge/noarch::jupyter_core-4.4.0-py_0
#   mccabe              pkgs/main/osx-64::mccabe-0.6.1-py36_1 --> conda-forge/noarch::mccabe-0.6.1-py_1
#   multipledispatch   pkgs/main/osx-64::multipledispatch-0.~ --> conda-forge/noarch::multipledispatch-0.6.0-py_0
#   olefile             pkgs/main/osx-64::olefile-0.46-py36_0 --> conda-forge/noarch::olefile-0.46-py_0
#   pandocfilters      pkgs/main/osx-64::pandocfilters-1.4.2~ --> conda-forge/noarch::pandocfilters-1.4.2-py_1
#   pcre                      pkgs/main::pcre-8.42-h378b8a2_0 --> conda-forge::pcre-8.41-h0a44026_1003
#   pep8                  pkgs/main/osx-64::pep8-1.7.1-py36_0 --> conda-forge/noarch::pep8-1.7.1-py_0
#   pytest-remotedata  pkgs/main/osx-64::pytest-remotedata-0~ --> conda-forge/noarch::pytest-remotedata-0.3.1-py_0
#   python.app                 pkgs/main::python.app-2-py36_9 --> conda-forge::python.app-1.2-py36h1de35cc_1200
#   send2trash         pkgs/main/osx-64::send2trash-1.5.0-py~ --> conda-forge/noarch::send2trash-1.5.0-py_0
#   simplegeneric      pkgs/main/osx-64::simplegeneric-0.8.1~ --> conda-forge/noarch::simplegeneric-0.8.1-py_1
#   webencodings       pkgs/main/osx-64::webencodings-0.5.1-~ --> conda-forge/noarch::webencodings-0.5.1-py_1
#
# The following packages will be DOWNGRADED:
#
#   _anaconda_depends                          2019.03-py36_0 --> 5.1.0-py36_2
#
#
#
# Downloading and Extracting Packages
# ...
# typing-3.6.4         | 46 KB     | ##################################### | 100%
# freetype-2.10.0      | 894 KB    | ##################################### | 100%
# cloudpickle-1.2.2    | 23 KB     | ##################################### | 100%
# idna-2.8             | 132 KB    | ##################################### | 100%
# cython-0.29.13       | 2.1 MB    | ##################################### | 100%
# terminado-0.8.2      | 23 KB     | ##################################### | 100%
# nose-1.3.7           | 214 KB    | ##################################### | 100%
# pycurl-7.43.0.2      | 70 KB     | ##################################### | 100%
# ptyprocess-0.6.0     | 15 KB     | ##################################### | 100%
# requests-2.22.0      | 84 KB     | ##################################### | 100%
# statsmodels-0.10.1   | 8.9 MB    | ##################################### | 100%
# xlwings-0.15.10      | 489 KB    | ##################################### | 100%
# networkx-2.3         | 1.1 MB    | ##################################### | 100%
# astroid-2.2.5        | 272 KB    | ##################################### | 100%
# qtconsole-4.5.5      | 90 KB     | ##################################### | 100%
# mpc-1.1.0            | 140 KB    | ##################################### | 100%
# mpfr-4.0.2           | 619 KB    | ##################################### | 100%
# boto-2.49.0          | 838 KB    | ##################################### | 100%
# defusedxml-0.5.0     | 20 KB     | ##################################### | 100%
# tk-8.6.9             | 3.2 MB    | ##################################### | 100%
# dbus-1.13.6          | 558 KB    | ##################################### | 100%
# html5lib-1.0.1       | 89 KB     | ##################################### | 100%
# jupyterlab_server-1. | 23 KB     | ##################################### | 100%
# more-itertools-7.2.0 | 48 KB     | ##################################### | 100%
# xz-5.2.4             | 268 KB    | ##################################### | 100%
# tqdm-4.35.0          | 42 KB     | ##################################### | 100%
# multipledispatch-0.6 | 12 KB     | ##################################### | 100%
# pycrypto-2.6.1       | 473 KB    | ##################################### | 100%
# pysocks-1.7.0        | 26 KB     | ##################################### | 100%
# scipy-1.3.1          | 18.3 MB   | ##################################### | 100%
# ipykernel-5.1.2      | 159 KB    | ##################################### | 100%
# distributed-2.4.0    | 375 KB    | ##################################### | 100%
# grpcio-1.23.0        | 1.0 MB    | ##################################### | 100%
# libcxx-8.0.1         | 1000 KB   | ##################################### | 100%
# conda-build-3.18.9   | 506 KB    | ##################################### | 100%
# yaml-0.1.7           | 79 KB     | ##################################### | 100%
# gevent-1.4.0         | 2.5 MB    | ##################################### | 100%
# pyflakes-2.1.1       | 49 KB     | ##################################### | 100%
# py-1.8.0             | 65 KB     | ##################################### | 100%
# astor-0.7.1          | 22 KB     | ##################################### | 100%
# colorama-0.4.1       | 15 KB     | ##################################### | 100%
# libsodium-1.0.17     | 308 KB    | ##################################### | 100%
# pip-19.2.3           | 1.9 MB    | ##################################### | 100%
# nbconvert-5.6.0      | 469 KB    | ##################################### | 100%
# pytest-doctestplus-0 | 16 KB     | ##################################### | 100%
# sip-4.19.8           | 251 KB    | ##################################### | 100%
# urllib3-1.25.3       | 187 KB    | ##################################### | 100%
# qtpy-1.9.0           | 34 KB     | ##################################### | 100%
# zipp-0.6.0           | 7 KB      | ##################################### | 100%
# libgfortran-4.0.0    | 716 KB    | ##################################### | 100%
# alabaster-0.7.12     | 15 KB     | ##################################### | 100%
# decorator-4.4.0      | 11 KB     | ##################################### | 100%
# openpyxl-2.6.3       | 152 KB    | ##################################### | 100%
# pytest-openfiles-0.4 | 9 KB      | ##################################### | 100%
# sqlalchemy-1.3.8     | 1.7 MB    | ##################################### | 100%
# pandoc-2.7.3         | 15.3 MB   | ##################################### | 100%
# cffi-1.12.3          | 210 KB    | ##################################### | 100%
# pytables-3.5.2       | 1.4 MB    | ##################################### | 100%
# jupyter_console-6.0. | 19 KB     | ##################################### | 100%
# clyent-1.2.2         | 9 KB      | ##################################### | 100%
# jpeg-9c              | 237 KB    | ##################################### | 100%
# glob2-0.7            | 11 KB     | ##################################### | 100%
# backcall-0.1.0       | 13 KB     | ##################################### | 100%
# jedi-0.15.1          | 706 KB    | ##################################### | 100%
# expat-2.2.5          | 128 KB    | ##################################### | 100%
# imagesize-1.1.0      | 6 KB      | ##################################### | 100%
# qt-5.9.7             | 76.8 MB   | ##################################### | 100%
# singledispatch-3.4.0 | 15 KB     | ##################################### | 100%
# filelock-3.0.10      | 9 KB      | ##################################### | 100%
# jupyterlab_launcher- | 20 KB     | ##################################### | 100%
# protobuf-3.9.1       | 672 KB    | ##################################### | 100%
# markupsafe-1.1.1     | 24 KB     | ##################################### | 100%
# termcolor-1.1.0      | 6 KB      | ##################################### | 100%
# itsdangerous-1.1.0   | 16 KB     | ##################################### | 100%
# bitarray-1.0.1       | 57 KB     | ##################################### | 100%
# backports-1.0        | 4 KB      | ##################################### | 100%
# zeromq-4.3.2         | 571 KB    | ##################################### | 100%
# partd-1.0.0          | 16 KB     | ##################################### | 100%
# cryptography-2.7     | 566 KB    | ##################################### | 100%
# krb5-1.16.3          | 1.1 MB    | ##################################### | 100%
# gmpy2-2.1.0b1        | 185 KB    | ##################################### | 100%
# pathlib2-2.3.4       | 34 KB     | ##################################### | 100%
# xlsxwriter-1.2.1     | 102 KB    | ##################################### | 100%
# llvmlite-0.29.0      | 15.5 MB   | ##################################### | 100%
# tblib-1.4.0          | 12 KB     | ##################################### | 100%
# entrypoints-0.3      | 12 KB     | ##################################### | 100%
# _anaconda_depends-5. | 5 KB      | ##################################### | 100%
# path.py-12.0.1       | 20 KB     | ##################################### | 100%
# pyodbc-4.0.27        | 63 KB     | ##################################### | 100%
# numpy-1.17.2         | 5.0 MB    | ##################################### | 100%
# contextlib2-0.5.5    | 10 KB     | ##################################### | 100%
# sympy-1.4            | 9.7 MB    | ##################################### | 100%
# libxml2-2.9.9        | 1.2 MB    | ##################################### | 100%
# glib-2.58.3          | 3.1 MB    | ##################################### | 100%
# jupyter_core-4.4.0   | 44 KB     | ##################################### | 100%
# prompt_toolkit-2.0.9 | 222 KB    | ##################################### | 100%
# sqlite-3.28.0        | 2.4 MB    | ##################################### | 100%
# pexpect-4.7.0        | 78 KB     | ##################################### | 100%
# sphinx-2.2.0         | 1.5 MB    | ##################################### | 100%
# click-7.0            | 61 KB     | ##################################### | 100%
# certifi-2019.6.16    | 149 KB    | ##################################### | 100%
# ca-certificates-2019 | 143 KB    | ##################################### | 100%
# libprotobuf-3.9.1    | 4.4 MB    | ##################################### | 100%
# absl-py-0.8.0        | 157 KB    | ##################################### | 100%
# pycosat-0.6.3        | 107 KB    | ##################################### | 100%
# mkl-2019.4           | 155.2 MB  | ##################################### | 100%
# zlib-1.2.11          | 101 KB    | ##################################### | 100%
# pillow-6.1.0         | 582 KB    | ##################################### | 100%
# pyyaml-5.1.2         | 166 KB    | ##################################### | 100%
# jinja2-2.10.1        | 91 KB     | ##################################### | 100%
# conda-4.7.12         | 3.0 MB    | ##################################### | 100%
# et_xmlfile-1.0.1     | 11 KB     | ##################################### | 100%
# pytest-remotedata-0. | 11 KB     | ##################################### | 100%
# widgetsnbextension-3 | 1.7 MB    | ##################################### | 100%
# blosc-1.17.0         | 648 KB    | ##################################### | 100%
# libcblas-3.8.0       | 10 KB     | ##################################### | 100%
# kiwisolver-1.1.0     | 57 KB     | ##################################### | 100%
# rope-0.14.0          | 111 KB    | ##################################### | 100%
# ruamel_yaml-0.15.71  | 239 KB    | ##################################### | 100%
# mpmath-1.1.0         | 432 KB    | ##################################### | 100%
# tornado-6.0.3        | 636 KB    | ##################################### | 100%
# libblas-3.8.0        | 10 KB     | ##################################### | 100%
# mccabe-0.6.1         | 8 KB      | ##################################### | 100%
# prometheus_client-0. | 38 KB     | ##################################### | 100%
# pyzmq-18.1.0         | 458 KB    | ##################################### | 100%
# atomicwrites-1.3.0   | 9 KB      | ##################################### | 100%
# toolz-0.10.0         | 46 KB     | ##################################### | 100%
# snowballstemmer-1.9. | 56 KB     | ##################################### | 100%
# backports.shutil_get | 7 KB      | ##################################### | 100%
# pyrsistent-0.15.4    | 87 KB     | ##################################### | 100%
# mistune-0.8.4        | 53 KB     | ##################################### | 100%
# c-ares-1.15.0        | 81 KB     | ##################################### | 100%
# gast-0.3.2           | 11 KB     | ##################################### | 100%
# keyring-19.2.0       | 49 KB     | ##################################### | 100%
# libopenblas-0.3.7    | 8.3 MB    | ##################################### | 100%
# pandas-0.25.1        | 10.4 MB   | ##################################### | 100%
# icu-58.2             | 22.3 MB   | ##################################### | 100%
# libedit-3.1.20170329 | 152 KB    | ##################################### | 100%
# nltk-3.4.4           | 1.1 MB    | ##################################### | 100%
# webencodings-0.5.1   | 12 KB     | ##################################### | 100%
# pcre-8.41            | 222 KB    | ##################################### | 100%
# hdf5-1.10.5          | 3.0 MB    | ##################################### | 100%
# lxml-4.4.1           | 1.4 MB    | ##################################### | 100%
# flask-1.1.1          | 69 KB     | ##################################### | 100%
# wcwidth-0.1.7        | 17 KB     | ##################################### | 100%
# isort-4.3.21         | 64 KB     | ##################################### | 100%
# pycparser-2.19       | 173 KB    | ##################################### | 100%
# babel-2.7.0          | 5.9 MB    | ##################################### | 100%
# conda-package-handli | 261 KB    | ##################################### | 100%
# libarchive-3.3.3     | 1.5 MB    | ##################################### | 100%
# pylint-2.3.1         | 826 KB    | ##################################### | 100%
# sphinxcontrib-serial | 24 KB     | ##################################### | 100%
# keras-applications-1 | 30 KB     | ##################################### | 100%
# liblapack-3.8.0      | 10 KB     | ##################################### | 100%
# ply-3.11             | 44 KB     | ##################################### | 100%
# wurlitzer-1.0.3      | 12 KB     | ##################################### | 100%
# mkl-service-2.3.0    | 45 KB     | ##################################### | 100%
# llvm-openmp-8.0.1    | 253 KB    | ##################################### | 100%
# attrs-19.1.0         | 32 KB     | ##################################### | 100%
# matplotlib-base-3.1. | 6.6 MB    | ##################################### | 100%
# wrapt-1.11.2         | 41 KB     | ##################################### | 100%
# pyparsing-2.4.2      | 57 KB     | ##################################### | 100%
# libxslt-1.1.32       | 491 KB    | ##################################### | 100%
# libcxxabi-8.0.1      | 136 KB    | ##################################### | 100%
# libssh2-1.8.2        | 221 KB    | ##################################### | 100%
# docutils-0.15.2      | 739 KB    | ##################################### | 100%
# pkginfo-1.5.0.1      | 21 KB     | ##################################### | 100%
# pygments-2.4.2       | 661 KB    | ##################################### | 100%
# libtiff-4.0.10       | 527 KB    | ##################################### | 100%
# jbig-2.1             | 41 KB     | ##################################### | 100%
# readline-7.0         | 393 KB    | ##################################### | 100%
# qtawesome-0.6.0      | 668 KB    | ##################################### | 100%
# curl-7.65.3          | 125 KB    | ##################################### | 100%
# send2trash-1.5.0     | 12 KB     | ##################################### | 100%
# sortedcollections-1. | 10 KB     | ##################################### | 100%
# unixodbc-2.3.7       | 267 KB    | ##################################### | 100%
# appnope-0.1.0        | 8 KB      | ##################################### | 100%
# bleach-3.1.0         | 110 KB    | ##################################### | 100%
# simplegeneric-0.8.1  | 7 KB      | ##################################### | 100%
# soupsieve-1.9.3      | 57 KB     | ##################################### | 100%
# typed-ast-1.4.0      | 195 KB    | ##################################### | 100%
# lz4-c-1.8.3          | 139 KB    | ##################################### | 100%
# spyder-3.3.6         | 2.5 MB    | ##################################### | 100%
# markdown-3.1.1       | 60 KB     | ##################################### | 100%
# pep8-1.7.1           | 30 KB     | ##################################### | 100%
# setuptools-41.2.0    | 621 KB    | ##################################### | 100%
# parso-0.5.1          | 65 KB     | ##################################### | 100%
# jupyter_client-5.3.1 | 64 KB     | ##################################### | 100%
# pluggy-0.12.0        | 18 KB     | ##################################### | 100%
# pytest-astropy-0.5.0 | 6 KB      | ##################################### | 100%
# cytoolz-0.10.0       | 364 KB    | ##################################### | 100%
# gmp-6.1.2            | 734 KB    | ##################################### | 100%
# pandocfilters-1.4.2  | 9 KB      | ##################################### | 100%
# appscript-1.1.0      | 132 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: / b'Enabling notebook extension jupyter-js-widgets/extension...\n      - Validating: \x1bOK\x1b\n'
# done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %conda install -c conda-forge pyldavis
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# Examining html5lib:   1%|▎                    | 5/417 [00:00<00:00, 1511.90it/s]
# Comparing specs that have this dependency:   0%|         | 0/20 [00:00<?, ?it/s]
#
# Finding conflict paths:   0%|                             | 0/3 [00:00<?, ?it/s]
#
# Finding shortest conflict path for html5lib==0.9999999:   0%| | 0/3 [00:00<?, ?it/s]\
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  33%|▎| 1/3 [00:00<00:00,  7.79it/s]
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  67%|▋| 2/3 [00:00<00:00, 15.57it/| /
#
# Finding shortest conflict path for html5lib:  67%|▋| 2/3 [00:10<00:00, 15.57it/s]
#
# Finding shortest conflict path for html5lib: 100%|█| 3/3 [00:10<00:00,  3.30s/it]-
#
#
# Comparing specs that have this dependency:   5%| | 1/20 [03:34<1:08:04, 214.96s/it]
#
# Finding conflict paths:   0%|                             | 0/4 [00:00<?, ?it/s]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999']:   0%| | 0/4 [00:00<?, ?it/s]\
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  25%|▎| 1/4 [00:07<00:22,  7.46s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  50%|▌| 2/4 [00:07<00:07,  3.73s/it]/
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  50%|▌| 2/4 [00:14<00:07,  3.73s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  75%|▊| 3/4 [00:14<00:04,  4.69s/it]\
#
# Finding shortest conflict path for html5lib:  75%|▊| 3/4 [00:21<00:04,  4.69s/it]
#
# Finding shortest conflict path for html5lib: 100%|█| 4/4 [00:21<00:00,  5.36s/it]|
#
#
# Comparing specs that have this dependency:  10%| | 2/20 [04:10<37:37, 125.43s/it]
#
# Finding conflict paths:   0%|                             | 0/4 [00:00<?, ?it/s]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999']:   0%| | 0/4 [00:00<?, ?it/s]/
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  25%|▎| 1/4 [00:11<00:34, 11.51s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  50%|▌| 2/4 [00:11<00:11,  5.75s/it]\
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  50%|▌| 2/4 [00:23<00:11,  5.75s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  75%|▊| 3/4 [00:23<00:07,  7.67s/it]-
#
# Finding shortest conflict path for html5lib:  75%|▊| 3/4 [00:35<00:07,  7.67s/it]
#
# Finding shortest conflict path for html5lib: 100%|█| 4/4 [00:35<00:00,  8.91s/it]-
#
#
# Comparing specs that have this dependency:  15%|▏| 3/20 [05:08<29:10, 102.94s/it]
#
# Finding conflict paths:   0%|                             | 0/3 [00:00<?, ?it/s]
#
# Finding shortest conflict path for html5lib==1.0.1=py37_0:   0%| | 0/3 [00:00<?, ?it/s]\
#
# Finding shortest conflict path for html5lib:  33%|▎| 1/3 [00:00<00:00, 10.92it/s]      -
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  67%|▋| 2/3 [00:02<00:01,  1.31s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']: 100%|█| 3/3 [00:02<00:00,  1.14it/s]-
#
#
# Comparing specs that have this dependency:  20%|▏| 4/20 [05:12<20:49, 78.10s/it]
#
# Finding conflict paths:   0%|                             | 0/4 [00:00<?, ?it/s]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999']:   0%| | 0/4 [00:00<?, ?it/s]|
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  25%|▎| 1/4 [00:08<00:24,  8.01s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  50%|▌| 2/4 [00:08<00:08,  4.00s/it]\
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  50%|▌| 2/4 [00:16<00:08,  4.00s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  75%|▊| 3/4 [00:16<00:05,  5.48s/it]\
#
# Finding shortest conflict path for html5lib:  75%|▊| 3/4 [00:25<00:05,  5.48s/it]
#
# Finding shortest conflict path for html5lib: 100%|█| 4/4 [00:25<00:00,  6.43s/it]-
#
#
# Comparing specs that have this dependency:  25%|▎| 5/20 [06:10<18:30, 74.04s/it]
#
# Finding conflict paths:   0%|                             | 0/4 [00:00<?, ?it/s]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999']:   0%| | 0/4 [00:00<?, ?it/s]|
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  25%|▎| 1/4 [00:11<00:35, 11.79s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  50%|▌| 2/4 [00:11<00:11,  5.89s/it]-
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  50%|▌| 2/4 [00:23<00:11,  5.89s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  75%|▊| 3/4 [00:23<00:07,  7.76s/it]|
#
# Finding shortest conflict path for html5lib:  75%|▊| 3/4 [00:35<00:07,  7.76s/it]
#
# Finding shortest conflict path for html5lib: 100%|█| 4/4 [00:35<00:00,  9.04s/it]/
#
#
# Comparing specs that have this dependency:  30%|▎| 6/20 [07:18<17:03, 73.09s/it]
#
# Finding conflict paths:   0%|                             | 0/4 [00:00<?, ?it/s]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999']:   0%| | 0/4 [00:00<?, ?it/s]|
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  25%|▎| 1/4 [00:09<00:27,  9.06s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  50%|▌| 2/4 [00:09<00:09,  4.53s/it]\
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  50%|▌| 2/4 [00:18<00:09,  4.53s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  75%|▊| 3/4 [00:18<00:06,  6.02s/it]/
#
# Finding shortest conflict path for html5lib:  75%|▊| 3/4 [00:27<00:06,  6.02s/it]
#
# Finding shortest conflict path for html5lib: 100%|█| 4/4 [00:27<00:00,  7.00s/it]/
#
#
# Comparing specs that have this dependency:  35%|▎| 7/20 [08:05<15:02, 69.41s/it]
#
# Finding conflict paths:   0%|                             | 0/3 [00:00<?, ?it/s]
#
# Finding shortest conflict path for html5lib==0.9999999:   0%| | 0/3 [00:00<?, ?it/s]|
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  33%|▎| 1/3 [01:17<02:35, 77.72s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  67%|▋| 2/3 [01:17<00:38, 38.86s/it]|
#
# Finding shortest conflict path for html5lib:  67%|▋| 2/3 [02:52<00:38, 38.86s/it]
#
# Finding shortest conflict path for html5lib: 100%|█| 3/3 [02:52<00:00, 55.61s/it]|
#
#
# Comparing specs that have this dependency:  40%|▍| 8/20 [12:59<19:28, 97.40s/it]
#
# Finding conflict paths:   0%|                             | 0/4 [00:00<?, ?it/s]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999']:   0%| | 0/4 [00:00<?, ?it/s]|
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  25%|▎| 1/4 [00:14<00:42, 14.08s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  50%|▌| 2/4 [00:14<00:14,  7.04s/it]/
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  50%|▌| 2/4 [00:27<00:14,  7.04s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  75%|▊| 3/4 [00:27<00:08,  8.81s/it]|
#
# Finding shortest conflict path for html5lib:  75%|▊| 3/4 [00:41<00:08,  8.81s/it]
#
# Finding shortest conflict path for html5lib: 100%|█| 4/4 [00:41<00:00, 10.38s/it]/
#
#
# Comparing specs that have this dependency:  45%|▍| 9/20 [14:04<17:11, 93.80s/it]
#
# Finding conflict paths:   0%|                             | 0/4 [00:00<?, ?it/s]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999']:   0%| | 0/4 [00:00<?, ?it/s]-
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  25%|▎| 1/4 [00:19<00:57, 19.21s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  50%|▌| 2/4 [00:19<00:19,  9.61s/it]\
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  50%|▌| 2/4 [00:39<00:19,  9.61s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  75%|▊| 3/4 [00:39<00:12, 12.84s/it]\
#
# Finding shortest conflict path for html5lib:  75%|▊| 3/4 [00:58<00:12, 12.84s/it]
#
# Finding shortest conflict path for html5lib: 100%|█| 4/4 [00:58<00:00, 14.81s/it]\
#
#
# Comparing specs that have this dependency:  50%|▌| 10/20 [15:33<15:33, 93.39s/it]
#
# Finding conflict paths:   0%|                             | 0/4 [00:00<?, ?it/s]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999']:   0%| | 0/4 [00:00<?, ?it/s]|
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  25%|▎| 1/4 [00:00<00:00,  6.99it/s]
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  50%|▌| 2/4 [00:00<00:00, 13.98it/s]/
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  50%|▌| 2/4 [00:00<00:00, 13.98it/s]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  75%|▊| 3/4 [00:00<00:00, 10.81it/s]\
#
# Finding shortest conflict path for html5lib:  75%|▊| 3/4 [00:00<00:00, 10.81it/s]
#
# Finding shortest conflict path for html5lib: 100%|█| 4/4 [00:00<00:00,  9.30it/s]-
#
#
# Comparing specs that have this dependency:  55%|▌| 11/20 [15:39<12:48, 85.38s/it]
#
# Finding conflict paths:   0%|                             | 0/4 [00:00<?, ?it/s]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999']:   0%| | 0/4 [00:00<?, ?it/s]\
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  25%|▎| 1/4 [00:00<00:00, 17.57it/s]|
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  50%|▌| 2/4 [00:00<00:00, 16.36it/s]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:  75%|▊| 3/4 [00:00<00:00, 24.52it/s]
#
# Finding shortest conflict path for html5lib:  75%|▊| 3/4 [00:00<00:00, 24.52it/s]                                                                                           /
#
#
# Comparing specs that have this dependency:  60%|▌| 12/20 [15:41<10:27, 78.46s/it]
#
# Finding conflict paths:   0%|                             | 0/3 [00:00<?, ?it/s]
#
# Finding shortest conflict path for html5lib==0.9999999:   0%| | 0/3 [00:00<?, ?it/s]|
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  33%|▎| 1/3 [01:30<03:01, 90.98s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  67%|▋| 2/3 [01:30<00:45, 45.49s/it]|
#
# Finding shortest conflict path for html5lib:  67%|▋| 2/3 [03:16<00:45, 45.49s/it]
#
# Finding shortest conflict path for html5lib: 100%|█| 3/3 [03:16<00:00, 63.35s/it]/
#
#
# Comparing specs that have this dependency:  65%|▋| 13/20 [21:04<11:21, 97.29s/it]
#
# Finding conflict paths:   0%|                             | 0/3 [00:00<?, ?it/s]
#
# Finding shortest conflict path for html5lib==0.9999999:   0%| | 0/3 [00:00<?, ?it/s]|
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  33%|▎| 1/3 [00:07<00:14,  7.42s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  67%|▋| 2/3 [00:07<00:03,  3.71s/it]\
#
# Finding shortest conflict path for html5lib:  67%|▋| 2/3 [01:56<00:03,  3.71s/it]
#
# Finding shortest conflict path for html5lib: 100%|█| 3/3 [01:56<00:00, 35.24s/it]\
#
#
# Comparing specs that have this dependency:  70%|▋| 14/20 [25:30<10:55, 109.30s/it]
#
# Finding conflict paths:   0%|                             | 0/3 [00:00<?, ?it/s]
#
# Finding shortest conflict path for html5lib==0.9999999:   0%| | 0/3 [00:00<?, ?it/s]|
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  33%|▎| 1/3 [00:47<01:34, 47.21s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  67%|▋| 2/3 [00:47<00:23, 23.60s/it]\
#
# Finding shortest conflict path for html5lib:  67%|▋| 2/3 [01:54<00:23, 23.60s/it]
#
# Finding shortest conflict path for html5lib: 100%|█| 3/3 [01:54<00:00, 36.63s/it]/
#
#
# Comparing specs that have this dependency:  75%|▊| 15/20 [28:57<09:39, 115.83s/it]
#
# Finding conflict paths:   0%|                             | 0/5 [00:00<?, ?it/s]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']:   0%| | 0/5 [00:00<?, ?it/s]-
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  20%|▏| 1/5 [00:06<00:26,  6.64s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.999,!=0.9999,!=0.99999,<0.99999999']:  40%|▍| 2/5 [00:06<00:09,  3.32s/it]/
#
# Finding shortest conflict path for html5lib:  40%|▍| 2/5 [00:13<00:09,  3.32s/it]
#
# Finding shortest conflict path for html5lib:  60%|▌| 3/5 [00:13<00:08,  4.49s/it]-
#
# Finding shortest conflict path for html5lib[version='>=0.99999999']:  60%|▌| 3/5 [00:14<00:08,  4.49s/it]
#
# Finding shortest conflict path for html5lib[version='>=0.99999999']:  80%|▊| 4/5 [00:14<00:03,  3.19s/it]/
#
# Finding shortest conflict path for html5lib:  80%|▊| 4/5 [00:21<00:03,  3.19s/it]
#
# Finding shortest conflict path for html5lib: 100%|█| 5/5 [00:21<00:00,  4.48s/it]/ ^C
#
#
#                                                                                failed[A
#
# CondaError: KeyboardInterrupt
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pyldavis
# Out:
# Collecting pyldavis
#   Downloading https://files.pythonhosted.org/packages/a5/3a/af82e070a8a96e13217c8f362f9a73e82d61ac8fff3a2561946a97f96266/pyLDAvis-2.1.2.tar.gz (1.6MB)
#      |████████████████████████████████| 1.6MB 2.5MB/s eta 0:00:01
# Requirement already satisfied: wheel>=0.23.0 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pyldavis) (0.33.6)
# Requirement already satisfied: numpy>=1.9.2 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pyldavis) (1.17.2)
# Requirement already satisfied: scipy>=0.18.0 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pyldavis) (1.3.1)
# Requirement already satisfied: pandas>=0.17.0 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pyldavis) (0.25.1)
# Requirement already satisfied: joblib>=0.8.4 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pyldavis) (0.13.2)
# Requirement already satisfied: jinja2>=2.7.2 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pyldavis) (2.10.1)
# Requirement already satisfied: numexpr in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pyldavis) (2.7.0)
# Requirement already satisfied: pytest in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pyldavis) (5.1.2)
# Collecting future (from pyldavis)
#   Downloading https://files.pythonhosted.org/packages/90/52/e20466b85000a181e1e144fd8305caf2cf475e2f9674e797b222f8105f5f/future-0.17.1.tar.gz (829kB)
#      |████████████████████████████████| 829kB 3.8MB/s eta 0:00:01
# Collecting funcy (from pyldavis)
#   Downloading https://files.pythonhosted.org/packages/eb/3a/fc8323f913e8a9c6f33f7203547f8a2171223da5ed965f2541dafb10aa09/funcy-1.13-py2.py3-none-any.whl
# Requirement already satisfied: pytz>=2017.2 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pandas>=0.17.0->pyldavis) (2019.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pandas>=0.17.0->pyldavis) (2.8.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from jinja2>=2.7.2->pyldavis) (1.1.1)
# Requirement already satisfied: py>=1.5.0 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pytest->pyldavis) (1.8.0)
# Requirement already satisfied: packaging in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pytest->pyldavis) (19.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pytest->pyldavis) (19.1.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pytest->pyldavis) (7.2.0)
# Requirement already satisfied: atomicwrites>=1.0 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pytest->pyldavis) (1.3.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pytest->pyldavis) (0.12.0)
# Requirement already satisfied: wcwidth in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pytest->pyldavis) (0.1.7)
# Requirement already satisfied: importlib-metadata>=0.12 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from pytest->pyldavis) (0.23)
# Requirement already satisfied: six>=1.5 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from python-dateutil>=2.6.1->pandas>=0.17.0->pyldavis) (1.12.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from packaging->pytest->pyldavis) (2.4.2)
# Requirement already satisfied: zipp>=0.5 in /Users/veldhuis/anaconda3/lib/python3.6/site-packages (from importlib-metadata>=0.12->pytest->pyldavis) (0.6.0)
# Building wheels for collected packages: pyldavis, future
#   Building wheel for pyldavis (setup.py) ... done
#   Created wheel for pyldavis: filename=pyLDAvis-2.1.2-py2.py3-none-any.whl size=97711 sha256=845dba049d049362d262f15dcffa2e85542611312bbf1b5f861bd328f3b82695
#   Stored in directory: /Users/veldhuis/Library/Caches/pip/wheels/98/71/24/513a99e58bb6b8465bae4d2d5e9dba8f0bef8179e3051ac414
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.17.1-cp36-none-any.whl size=488730 sha256=caabbbc50661037549e995ea8b6db209e42a9d9622685ba0fd8737a021dadac9
#   Stored in directory: /Users/veldhuis/Library/Caches/pip/wheels/0c/61/d2/d6b7317325828fbb39ee6ad559dbe4664d0896da4721bf379e
# Successfully built pyldavis future
# Installing collected packages: future, funcy, pyldavis
# Successfully installed funcy-1.13 future-0.17.1 pyldavis-2.1.2
# Note: you may need to restart the kernel to use updated packages.
