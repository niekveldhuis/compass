# %% [markdown]
# # Test using OGSL to use Name Authority in ORACC
# The Drehem name authority was made by extracting names from [BDTNS](http://bdtns.filol.csic.es/). Using this name authority for the Ur III data set in [ePSD2](http://oracc.org/epsd2/admin/u3adm/pager) runs into the problem of (slightly) different transliteration conventions. For instance, where [BDTNS](http://bdtns.filol.csic.es/) writes "uru", the [ePSD2](http://oracc.org/epsd2/admin/u3adm/pager) transliterations (which derives from [CDLI](http://cdli.ucla.edu)) have "iri".
#
# Similarly, transliterations of names in [CDLI](http://cdli.ucla.edu) (and therefore in [ePSD2](http://oracc.org/epsd2/admin/u3adm/pager)) is often inconsistent. **FIND GOOD EXAMPLE**
#
# The name instances found in the Ur III corpus, therefore, may be reduced to sequences of sign names, which may be compared to sequences of sign names in the name authority.

# %% [markdown]
# First parse the [OGSL](http://oracc.org/ogsl) database with the notebook 1-parse_ogsl.ipynb. This results in a DataFrame that is pickled as "output/ogsl.p".

# %%
import pandas as pd
import pickle
import re

# %%
with open("output/ogsl.p", "rb") as p:
    ogsl_df = pd.read_pickle(p)
ogsl_df
# Out:
#                                                      hex  \
# 0                                                 x12000
# 1                                                 x12000
# 2                                                 x12000
# 3                                                 x12000
# 4                                                 x12000
# 5                                                 x12000
# 6                                                 x12000
# 7                                                 x12000
# 8                                                 x12000
# 9                                                 x12000
# 10                                                x12000
# 11                                                x12000
# 12                                                x12000
# 13                                                x12000
# 14                                                x12000
# 15                                                x12000
# 16                                                x12000
# 17                                                x12000
# 18                                                x12000
# 19                                                x12000
# 20                                                x12000
# 21                                                x12000
# 22                                                x12000
# 23                                                x12000
# 24                                         x12000.x12000
# 25                                         x12000.x12000
# 26                                         x12000.x12000
# 27                                         x12000.x12000
# 28                                         x12000.x12000
# 29                                         x12000.x12000
# ...                                                  ...
# 9987                                       x120FB.x12306
# 9988
# 9989
# 9990                                       x121FF.x12041
# 9991                                       x12309.x12248
# 9992    x12097.x122A9.x1226D.x12363.x1202D.x122C0.x121A0
# 9993
# 9994                         x12104.x1223E.x1200A.x12308
# 9995                         x12111.x12306.x1227F.x1224C
# 9996
# 9997                                x1221C.x1208D.x12046
# 9998
# 9999                                x12228.x1201C.x121AC
# 10000                               x1227B.x12110.x122DB
# 10001                                      x122BA.x12334
# 10002
# 10003                               x12000.x12364.x121B8
# 10004                                      x1214E.x122DB
# 10005                                      x1207A.x121EF
# 10006                                      x1202D.x1230B
# 10007                                      x1214A.x1227D
# 10008
# 10009                               x12306.x1227F.x1227F
# 10010                        x12016.x1202D.x122C0.x121A0
# 10011                                      x1230B.x12263
# 10012
# 10013
# 10014                               x12246.x12097.x1223E
# 10015  x1202D.x12097.x12261.x1226D.x12246.x1202D.x122...
# 10016
#
#                                  name      utf8    value
# 0                                   A         𒀀      ʾu₄
# 1                                   A         𒀀        a
# 2                                   A         𒀀     aia₂
# 3                                   A         𒀀     aya₂
# 4                                   A         𒀀     barₓ
# 5                                   A         𒀀   buniŋₓ
# 6                                   A         𒀀     burₓ
# 7                                   A         𒀀     dur₅
# 8                                   A         𒀀    duru₅
# 9                                   A         𒀀       e₄
# 10                                  A         𒀀       ea
# 11                                  A         𒀀    ebir₃
# 12                                  A         𒀀      emₓ
# 13                                  A         𒀀    epir₃
# 14                                  A         𒀀     eš₁₀
# 15                                  A         𒀀     ŋa₁₀
# 16                                  A         𒀀     ia₁₀
# 17                                  A         𒀀      id₅
# 18                                  A         𒀀      me₅
# 19                                  A         𒀀     mu₁₄
# 20                                  A         𒀀     sedₓ
# 21                                  A         𒀀     šegₓ
# 22                                  A         𒀀     ṭur₅
# 23                                  A         𒀀     ya₁₀
# 24                              |A.A|        𒀀𒀀       ai
# 25                              |A.A|        𒀀𒀀      aia
# 26                              |A.A|        𒀀𒀀      aya
# 27                              |A.A|        𒀀𒀀      aye
# 28                              |A.A|        𒀀𒀀      ayi
# 29                              |A.A|        𒀀𒀀      ayu
# ...                               ...       ...      ...
# 9987                       |GAR.TUG₂|        𒃻𒌆   šudulₓ
# 9988                            IL₂@n            dupsikₓ
# 9989                           REC169              uštil
# 9990                    |LU₂×BAD.BAD|        𒇿𒁁    addaₓ
# 9991                         |TUR.NE|        𒌉𒉈   ibilaₓ
# 9992      |EN.SAL.NUNUZ.ZI.AN.ŠEŠ.KI|   𒂗𒊩𒉭𒍣𒀭𒋀𒆠   zirruₓ
# 9993                       |EZEN×ŠID|            asilalₓ
# 9994                  |GI₄.NA.AB.TUM|      𒄄𒈾𒀊𒌈   šutumₓ
# 9995                 |GIŠ.TUG₂.PI.NI|      𒄑𒌆𒉿𒉌  gizzalₓ
# 9996                           LAK526                meₓ
# 9997                   |LUL.E₂.BALAG|       𒈜𒂍𒁆    tigiₓ
# 9998                    |LUL.DIN.LIŠ|              tigiₓ
# 9999                      |ME.AD.KU₃|       𒈨𒀜𒆬   šennuₓ
# 10000                  |PAD.GISAL.SI|       𒉻𒄐𒋛   addirₓ
# 10001                        |ŠE.UR₄|        𒊺𒌴     gurₓ
# 10002                     |ZUM×LAGAB|             garigₓ
# 10003                 |A.ZI&ZI.LAGAB|       𒀀𒍤𒆸    aškiₓ
# 10004                         |IM.SI|        𒅎𒋛   dunguₓ
# 10005                    |DU.LAGAR@g|        𒁺𒇯      edₓ
# 10006                          |AN.U|        𒀭𒌋      enₓ
# 10007                     |IGI@g.PAP|        𒅊𒉽    kumₓ?
# 10008                |NINDA₂×GI.IDIM|             gidimₓ
# 10009                    |TUG₂.PI.PI|       𒌆𒉿𒉿  ŋeštugₓ
# 10010                 |AB₂.AN.ŠEŠ.KI|      𒀖𒀭𒋀𒆠  munzerₓ
# 10011                     |U.GIŠ%GIŠ|        𒌋𒉣  šennurₓ
# 10012                   |UR₂×KID₂.SU|             umbinₓ
# 10013                          LAK212              asalₓ
# 10014                     |NAM.EN.NA|       𒉆𒂗𒈾    palaₓ
# 10015  |AN.EN.NU.NUNUZ.NAM.AN.ŠEŠ.KI|  𒀭𒂗𒉡𒉭𒉆𒀭𒋀𒆠   zirruₓ
# 10016                |KASKAL.LAGAB×X|            šubtumₓ
#
# [10017 rows x 4 columns]

# %% [markdown]
# Create a dictionary where the keys are sign values and the values sign names.

# %%
val = list(ogsl_df["value"])
names = list(ogsl_df["name"])
d = dict(zip(val,names))

# %%
file = "name_authority/Drehem_name_authority.atf"
with open(file, "r", encoding="utf-8") as f:
    z = f.readlines()
y = [re.sub(r"\t+", "\t", l).strip().split('\t') for l in z]
del y[0]
y
# Out:
# [['0', 'A-AN-ba-az', 'A.AN.ba.az[]PN', 'MVN 13 464 r 10 (copy/photo)'],
#  ['1', 'A-KU-um', 'A.KU.um[]PN', 'Aegyptus 10, 270 27 o 7 (copy)'],
#  ['2', 'A-KU.KU-ta', 'A.KU.KU[]PN', "AnOr 12 277 o i 17' (copy)"],
#  ['3', 'A-NI-ta', 'A.NI[]PN', 'Babyl. 7 pl. 22 18 o 3 (copy)'],
#  ['4',
#   'A-U.E2-nu-tuku',
#   'A.U.E₂.nu.tuku[]PN',
#   'AnOr 07 150 o 2: A-U.KID-nu-tuku IŠ (copy/photo)'],
#  ['5', 'A-a-', 'unkn', '5654 possibilities'],
#  ['6', 'A-a-bad3', 'Ayabad[]PN'],
#  ['7', 'A-a-ce3', 'Aya[]PN'],
#  ['8', 'A-a-dingir', 'Ayadiŋir[]PN'],
#  ['9', 'A-a-dingir-mu', 'Ayadiŋirŋu[]PN'],
#  ['10', 'A-a-dingir-mu-ta', 'Ayadiŋirŋu[]PN'],
#  ['11', 'A-a-dingir-ta', 'Ayadiŋir[]PN'],
#  ['12', 'A-a-i3-li2', 'Abuʾili[]PN'],
#  ['13', 'A-a-i3-li2-cu', 'Abuʾilišu[]PN', 'uncertain (Ayailišu?)'],
#  ['14', 'A-a-kal-la', 'Ayakala[]PN'],
#  ['15', 'A-a-kal-la-mu', 'Ayakalaŋu[]PN'],
#  ['16', 'A-a-kal-la-ta', 'Ayakala[]PN'],
#  ['17', 'A-a-ma', 'Ayama[]PN', 'hypo?'],
#  ['18', 'A-a-mu', 'Ayaŋu[]PN'],
#  ['19', 'A-a-mu-ce3', 'Ayaŋu[]PN'],
#  ['20', 'A-a-mu-dah', 'Ayaŋutah[]PN'],
#  ['21', 'A-a-mu-ta', 'Ayaŋu[]PN'],
#  ['22', 'A-a-ni', 'Ayani[]PN', '= Ayanum?'],
#  ['23', 'A-a-ri2-mu-ce3', 'Ayariŋu[]PN'],
#  ['24', 'A-a-ti', 'Ayati[]PN', '= Ayatum?'],
#  ['25', 'A-a-u4-su3-ce3', 'Ayaʾudsudše[]PN'],
#  ['26', 'A-a-ur-sag', 'Ayaʾursaŋ[]PN'],
#  ['27', 'A-a-{d}Nanna-ar-kal-la', 'AyaNannarkala[]PN'],
#  ['28', 'A-ab-ba', 'Abba[]PN'],
#  ['29', 'A-ab-ba-a', 'Abba[]PN'],
#  ['30', 'A-ab-ba-a-ta', 'Abba[]PN'],
#  ['31', 'A-ab-ba-bi', 'Abbabi[]PN'],
#  ['32', 'A-ab-ba-bi-ta', 'Abbabi[]PN'],
#  ['33', 'A-ab-ba-mmu', 'Abbaŋu[]PN', 'typo'],
#  ['34', 'A-ab-ba-mu', 'Abbaŋu[]PN'],
#  ['35', 'A-ab-ba-ni', 'Abbani[]PN'],
#  ['36', 'A-ab-ba-sig5', 'Abbasag[]PN'],
#  ['37', 'A-ab-ba-ta', 'Abba[]PN'],
#  ['38', 'A-ab-mi-ra-din', 'A.ab.mi.ra.din[]PN', 'WSem with Abu + vb?'],
#  ['39', 'A-ad-da', 'Adda[]PN'],
#  ['40', 'A-ad-da-a', 'Adda[]PN'],
#  ['41', 'A-ad-da-mu', 'Addaŋu[]PN'],
#  ['42',
#   'A-ad-da-ni-ra-am-an-ni',
#   'AbuniramAni[]PN',
#   'uncertain; Akk.: father is beloved of Anu?'],
#  ['43', 'A-al-la', 'Alla[]PN'],
#  ['44', 'A-al-la-mu', 'Allaŋu[]PN'],
#  ['45', 'A-al-la-mu-ta', 'Allaŋu[]PN'],
#  ['46', 'A-al-mu', 'Alŋu[]PN', '= Allaŋu?'],
#  ['47', 'A-al-mu-ta', 'Alŋu[]PN'],
#  ['48', 'A-am-ma', 'Ama[]PN'],
#  ['49',
#   'A-an-na',
#   'Ana[]PN',
#   'or, Aʾanak (hypo for something like A-pada-anak?)'],
#  ['50', 'A-an-na-ti', 'Anati[]PN', 'hypo?'],
#  ['51', 'A-ar-ba-tal', 'Arpatal[]PN', 'Hurrian'],
#  ['52', 'A-ba', 'Abba[]PN'],
#  ['53',
#   'A-ba-al-la-ta',
#   'AbaʾAlla[]PN',
#   'hypo for A-ba-al-la-gin7 (or similar)?'],
#  ['54', 'A-ba-al{ki}', 'Awal[]SN'],
#  ['55', 'A-ba-ar-da', 'Abarda[]PN', '= Abarduk? (1 PD)'],
#  ['56', 'A-ba-ar-du-uk', 'Abarduk[]PN', '= Abarda? (1 PD; Elamite?)'],
#  ['57', 'A-ba-ar-ni-um{ki}', 'Abarniʾum[]SN'],
#  ['58', 'A-ba-ba', 'Ababa[]PN'],
#  ['59', 'A-ba-cec-mu-gen7', 'Abašešŋugin[]PN'],
#  ['60', 'A-ba-dingir-gen7', 'Abadiŋirgin[]PN'],
#  ['61', 'A-ba-dingir-mu-gen7', 'Abadiŋirŋugin[]PN'],
#  ['62', 'A-ba-e-ne-gen7', 'Abaʾenegin[]PN'],
#  ['63', 'A-ba-ni', 'Abani[]PN', "hypo, or 'who is he'?"],
#  ['64', 'A-ba-sa6-ga', 'Abbasaga[]PN'],
#  ['65', 'A-ba-sa6-ga-ta', 'Abbasaga[]PN'],
#  ['66', 'A-ba-{d}Cara2-ta', 'AbaŠara[]PN', 'hypo?'],
#  ['67', 'A-ba-{d}En-lil2-gen7', 'AbaEnlilgin[]PN'],
#  ['68', 'A-ba-{d}En-lil2-gen7-ta', 'AbaEnlilgin[]PN'],
#  ['69', 'A-ba-{d}en-lil2-gen7', 'AbaEnlilgin[]PN'],
#  ['70', 'A-bi-a-bi-ih', 'AbiʾEbih[]PN'],
#  ['71', 'A-bi-a-ti', 'Abiʾati[]PN'],
#  ['72', 'A-bi-nu-um', 'Abinum[]PN'],
#  ['73', 'A-bi-si2-im-ti', 'Abisimti[]PN'],
#  ['74', 'A-bi2-DINGIR', 'Abiʾili[]PN', 'or, Abiʾilum'],
#  ['75', 'A-bi2-DU10', 'Abiṭab[]PN'],
#  ['76', 'A-bi2-DU10-ta', 'Abiṭab[]PN'],
#  ['77', 'A-bi2-E2', 'A.bi₂.E₂[]PN', 'Abibitim?'],
#  ['78',
#   'A-bi2-UD.IC',
#   'AbiŠamšiš[]PN',
#   'uncertain; Aegyptus 10, 270 28 o 6 (copy)'],
#  ['79', 'A-bi2-a', 'Abiʾa[]PN', 'hypo?; or, Abiya?'],
#  ['80', 'A-bi2-a-bi-ih', 'AbiʾEbih[]PN'],
#  ['81', 'A-bi2-a-bi2-ih', 'AbiʾEbih[]PN'],
#  ['82', 'A-bi2-a-mu-ti', 'Abiʾamuti[]PN'],
#  ['83', 'A-bi2-a-ta', 'Abiʾa[]PN'],
#  ['84', 'A-bi2-a-ti', 'Abiʾati[]PN'],
#  ['85', 'A-bi2-ba-na{ki}', 'Abibana[]SN'],
#  ['86', 'A-bi2-cu', 'Abišu[]PN'],
#  ['87', 'A-bi2-ic-ki-in', 'Abiškin[]PN', '< kânu'],
#  ['88', 'A-bi2-ic-qi2-il', 'Abišqil[]PN', '< qâlu'],
#  ['89', 'A-bi2-ki-in', 'Abikin[]PN'],
#  ['90', 'A-bi2-ri-syi', 'Abireṣi[]PN'],
#  ['91', 'A-bi2-si-im-ti', 'Abisimti[]PN'],
#  ['92', 'A-bi2-si2-im-ti', 'Abisimti[]PN'],
#  ['93', 'A-bi2-si2-im-ti-ce3', 'Abisimti[]PN'],
#  ['94', 'A-bi2-si2-im-ti-e', 'Abisimti[]PN'],
#  ['95', 'A-bi2-si2-im-ti-ra', 'Abisimti[]PN'],
#  ['96', 'A-bi2-si2-im-ti-ta', 'Abisimti[]PN'],
#  ['97', 'A-bi2-zu', 'Abizu[]PN'],
#  ['98', 'A-bu-DINGIR', 'Abuʾili[]PN', 'or, Abuʾilum'],
#  ['99', 'A-bu-DU10', 'Abuṭab[]PN'],
#  ['100', 'A-bu-DU10-ta', 'Abuṭab[]PN'],
#  ['101', 'A-bu-ZA', 'A.bu.ZA[]PN'],
#  ['102', 'A-bu-bu', 'Abubu[]PN'],
#  ['103', 'A-bu-da-a', 'Abuda[]PN'],
#  ['104', 'A-bu-na', 'Abuna[]PN', '= Abuni?'],
#  ['105', 'A-bu-ni', 'Abuni[]PN', '= Abuna?'],
#  ['106', 'A-bu-ni-ka', 'Abuni[]PN'],
#  ['107', 'A-bu-ni-ra', 'Abuni[]PN'],
#  ['108', 'A-bu-ni-ta', 'Abuni[]PN'],
#  ['109', 'A-bu-um-DINGIR', 'Abumilum[]PN', 'or, Abumili'],
#  ['110', 'A-bu-um-DINGIR-ma', 'Abumilum[]PN'],
#  ['111', 'A-bu-um-DINGIR-su2', 'Abumilšu[]PN'],
#  ['112', 'A-bu-um-ce3', 'Abum[]PN'],
#  ['113', 'A-bu-um-{d}Dumu-zi', 'AbumDumuzi[]PN'],
#  ['114', 'A-bu3-bu2', 'Abubu[]PN'],
#  ['115', 'A-ci-ba-tal', 'Ašipatal[]PN', 'Hurrian'],
#  ['116', 'A-cir{ki}', 'Aššur[]SN'],
#  ['117', 'A-cum{ki}-ce3', 'Ašum[]SN'],
#  ['118', 'A-cur5', 'Aššur[]PN'],
#  ['119', 'A-cur5-ra-ce3', 'Aššur[]PN'],
#  ['120', 'A-cur5-ra{ki}', 'Aššur[]SN'],
#  ['121', 'A-cur5{ki}', 'Aššur[]SN'],
#  ['122', 'A-da-a', 'Adda[]PN'],
#  ['123', 'A-da-da', 'Adada[]PN'],
#  ['124', 'A-da-gal', 'Adaggal[]PN'],
#  ['125', 'A-da-gal-cum', 'Adaggalšum[]PN'],
#  ['126', 'A-da-gal-cum-e', 'Adaggalšum[]PN'],
#  ['127', 'A-da-la2-a', 'Addalal[]PN'],
#  ['128', 'A-da-lal3', 'Addalal[]PN'],
#  ['129', 'A-da-lal3-bi', 'Addalalbi[]PN'],
#  ['130', 'A-da-lal3-ta', 'Addalal[]PN'],
#  ['131', 'A-da-ni-ta', 'Addani[]PN'],
#  ['132', 'A-da-ti-ta', 'Adati[]PN', '= Adatum?'],
#  ['133', 'A-da-tum', 'Adatum[]PN', '= Adati?'],
#  ['134',
#   'A-dam-DUN',
#   'A.dam.DUN[]SN',
#   '= Elam (generally in context with Susa; = Elamite Haltamti)?'],
#  ['135', 'A-dam-DUN{ki}', 'A.dam.DUN{ki}[]SN'],
#  ['136', 'A-dam-DUN{ki}-ce3', 'A.dam.DUN{ki}[]SN'],
#  ['137', 'A-dam-DUN{ki}-ke4', 'A.dam.DUN{ki}[]SN'],
#  ['138', 'A-dam-DUN{ki}-ta', 'A.dam.DUN{ki}[]SN'],
#  ['139', 'A-ga-a', 'Aga[]PN'],
#  ['140', 'A-ga-de3{ki}', 'Agade[]SN'],
#  ['141', 'A-ga-lum', 'Agalum[]PN'],
#  ['142', 'A-ga-tum', 'Agatum[]PN'],
#  ['143', 'A-gaz{ki}', 'Agaz[]SN'],
#  ['144', 'A-ge', 'Ayagina[]PN', 'or, Ayagin, Agina'],
#  ['145', 'A-gi-pu-um', 'Agipum[]PN'],
#  ['146', 'A-gu', 'Agu[]PN'],
#  ['147', 'A-gu-a', 'Aguʾa[]PN'],
#  ['148', 'A-gu-a-li2', 'Aguʾali[]PN'],
#  ['149', 'A-gu-a-ni', 'Aguʾali[]PN'],
#  ['150', 'A-gu-a-si2-im-ti', 'Aguʾasimti[]PN'],
#  ['151', 'A-gu-a-ta', 'Aguʾa[]PN'],
#  ['152', 'A-gu-da', 'Aguda[]PN'],
#  ['153', 'A-gu-du', 'Agudu[]PN'],
#  ['154', 'A-gu-gu-ta', 'Agugu[]PN'],
#  ['155', 'A-gu-nu-um', 'Agunum[]PN'],
#  ['156', 'A-gu3', 'not PN', 'syntax; in phrase a-gu₃ PN ba(-a)-ŋar/ŋa₂-ar'],
#  ['157', 'A-gub-ba', 'Aguba[]PN', '= Agube?'],
#  ['158', 'A-ha-am-wa-qar', 'Ahamwaqar[]PN'],
#  ['159', 'A-ha-an-ci-bu', 'Ahanšibu[]PN'],
#  ['160', 'A-ha-an-ci-pu', 'Ahanšibu[]PN'],
#  ['161', 'A-ha-an-ci2-bu', 'Ahanšibu[]PN'],
#  ['162', 'A-ha-an-ni-cu', 'Ahanišu[]PN'],
#  ['163', 'A-ha-an-ni-cu-ta', 'Ahanišu[]PN'],
#  ['164', 'A-ha-an-si-pu', 'Ahanšibu[]PN'],
#  ['165', 'A-ha-an-ti-bu', 'Ahantibu[]PN'],
#  ['166', 'A-ha-ci-pu', 'Ahanšibu[]PN'],
#  ['167', 'A-ha-cu', 'Ahašum[]PN'],
#  ['168', 'A-ha-cu-um', 'Ahašum[]PN'],
#  ['169', 'A-ha-ma-ti', 'Ayahamatil[]PN'],
#  ['170', 'A-ha-ni-cu', 'Ahanišu[]PN'],
#  ['171', 'A-ha-ni-cu-ta', 'Ahanišu[]PN'],
#  ['172', 'A-ha-ni-zu', 'Ahanišu[]PN', 'typo; TRU 050 copy & photo show ŠU'],
#  ['173', 'A-ha-tum', 'Ahatum[]PN'],
#  ['174', 'A-hi-DINGIR', 'Ahiʾilum[]PN', 'or, Ahiʾili'],
#  ['175', 'A-hi-DINGIR-ta', 'Ahiʾilum[]PN'],
#  ['176', 'A-hi-ma', 'Ahima[]PN'],
#  ['177', 'A-hi-ma-ra', 'Ahima[]PN'],
#  ['178', 'A-hi-ma-ta', 'Ahima[]PN'],
#  ['179', 'A-hu-DU10', 'Ahuṭab[]PN'],
#  ['180', 'A-hu-DU10-ce3', 'Ahuṭab[]PN'],
#  ['181', 'A-hu-DU10-ta', 'Ahuṭab[]PN'],
#  ['182', 'A-hu-We-er', 'AhuWer[]PN'],
#  ['183', 'A-hu-We-er--ta', 'AhuWer[]PN', 'typo'],
#  ['184', 'A-hu-We-er-ce3', 'AhuWer[]PN'],
#  ['185', 'A-hu-We-er-ta', 'AhuWer[]PN'],
#  ['186', 'A-hu-a', 'Ahuʾa[]PN'],
#  ['187', 'A-hu-a-hi', 'Ahuʾahi[]PN', 'uncertain'],
#  ['188', 'A-hu-a-ni', 'Ahuʾani[]PN'],
#  ['189', 'A-hu-a-ta', 'Ahuʾa[]PN'],
#  ['190', 'A-hu-a-ti', 'Ahuʾati[]PN'],
#  ['191', 'A-hu-ba-qar', 'Ahuwaqar[]PN'],
#  ['192', 'A-hu-cu-ni', 'Ahušuni[]PN'],
#  ['193',
#   'A-hu-cu-ni-ZE2',
#   'A.hu.šu.ni.ZE₂[]PN',
#   'SET 063 r i 20 (rev. photo)'],
#  ['194', 'A-hu-cu-ni-ta', 'Ahušuni[]PN'],
#  ['195', 'A-hu-ki-in', 'Ahukin[]PN'],
#  ['196', 'A-hu-ma', 'Ahuma[]PN'],
#  ['197', 'A-hu-ni', 'Ahuni[]PN', '= Ahunim?'],
#  ['198', 'A-hu-ni-cu', 'Ahunišu[]PN'],
#  ['199',
#   'A-hu-ni-im',
#   'Ahunim[]PN',
#   'gen of Ahunum? (SET 093 o 18: 1 gud kišib A-hu-ni-im)'],
#  ['200', 'A-hu-ni-ta', 'Ahuni[]PN'],
#  ['201', 'A-hu-ti{ki}', 'Ahuti[]SN'],
#  ['202', 'A-hu-um', 'Ahum[]PN'],
#  ['203', 'A-hu-um-BA', 'A.hu.um.BA[]PN', '= Ahumbani?; Nik. 2 461 r 9 (copy)'],
#  ['204', 'A-hu-um-DINGIR', 'Ahumili[]PN', 'or, Ahumilum'],
#  ['205', 'A-hu-um-ba-ni', 'Ahumbani[]PN'],
#  ['206', 'A-hu-um-ma', 'Ahuma[]PN'],
#  ['207', 'A-hu-wa-qar', 'Ahuwaqar[]PN'],
#  ['208', 'A-hu-wa-qar-ta', 'Ahuwaqar[]PN'],
#  ['209', 'A-hu-we-er', 'AhuWer[]PN'],
#  ['210', 'A-hu-we-er-ta', 'AhuWer[]PN'],
#  ['211', 'A-i3-li2-su', 'Abuʾilušu[]PN'],
#  ['212', 'A-kal-la', 'Ayakala[]PN'],
#  ['213', 'A-kal-la-ta', 'Ayakala[]PN'],
#  ['214', 'A-ki-a', 'Akiʾa[]PN'],
#  ['215', 'A-kiri3-zal', 'Akirizal[]PN', 'or, Ayakirizal'],
#  ['216', 'A-ku-a', 'Akuʾa[]PN'],
#  ['217', 'A-la-la-a', 'Alala[]PN'],
#  ['218', 'A-la-la2', 'Alala[]PN'],
#  ['219', 'A-la-mu', 'Alaŋu[]PN', 'Allaŋu?'],
#  ['220', 'A-la-mu-ta', 'Alaŋu[]PN'],
#  ['221', 'A-la-ru-um', 'Alarum[]PN'],
#  ['222', 'A-la-sum', 'Alasum[]PN', '= Alazum?'],
#  ['223', 'A-la-zum', 'Alazum[]PN', '= Alasum?'],
#  ['224', 'A-lal3-la-lum', 'Alalalum[]PN'],
#  ['225', 'A-li', 'Ali[]PN'],
#  ['226', 'A-li-ah', 'Aliʾah[]PN'],
#  ['227', 'A-li2-DU10', 'Aliṭab[]PN'],
#  ['228', 'A-li2-ah', 'Aliʾah[]PN'],
#  ['229', 'A-li2-li2', 'Alili[]PN'],
#  ['230', 'A-li2-ni-cu', 'Alinišu[]PN'],
#  ['231', 'A-lu-tya-bum2', 'Aluṭabum[]PN'],
#  ['232', 'A-lu-um{ki}', 'Alum[]SN'],
#  ['233', 'A-ma-ad', 'Amat[]PN'],
#  ['234', 'A-ma-an-ne-en', 'Amanen[]PN'],
#  ['235', 'A-ma-an-ne-en6', 'Amanen[]PN'],
#  ['236', 'A-ma-la', 'Amala[]PN'],
#  ['237', 'A-ma-ne-en-CA', 'A.ma.ne.en.ŠA[]PN', 'AnOr 07 102 r 2 (copy/photo)'],
#  ['238', 'A-ma-si2-li', 'Amasili[]PN'],
#  ['239',
#   'A-mac-ti-ak',
#   'Amaštiʾak[]WN',
#   'PDT 2 0918 r iii 7: gu2 i7 A-maš-ti-ak'],
#  ['240', 'A-mi-ir-AN', 'Amirili[]PN'],
#  ['241', 'A-mi-ir-{d}Cul-gi', 'AmirŠulgi[]PN'],
#  ['242', 'A-mu-a', 'Amuʾa[]PN'],
#  ['243',
#   'A-mu-er2-LU-numun',
#   'Amuʾa[]PN',
#   'MVN 13 458 o 9: A-mu-a u₃-kul (photo)'],
#  ['244', 'A-mur-An-num2', 'Amurili[]PN', 'uncertain (Amurilum?)'],
#  ['245', 'A-mur-DINGIR', 'Amurili[]PN'],
#  ['246', 'A-mur-DINGIR-ta', 'Amurili[]PN'],
#  ['247', 'A-mur-E2-a', 'AmurEa[]PN'],
#  ['248', 'A-mur-E2-a-ta', 'AmurEa[]PN'],
#  ['249', 'A-mur-da-ku-um', 'Amurdaqqum[]PN', "'I have seen a child'?"],
#  ['250', 'A-mur-{d}Cul-gi', 'AmurŠulgi[]PN'],
#  ['251', 'A-mur-{d}Suen', 'AmurSuʾen[]PN'],
#  ['252', 'A-mur-{d}UTU', 'AmurŠamaš[]PN'],
#  ['253', 'A-na-a', 'Anaa[]PN'],
#  ['254', 'A-na-a-MU', 'Anaŋu[]PN'],
#  ['255', 'A-na-ab-E2-a', 'AnabEa[]PN'],
#  ['256', 'A-na-ah-i3-li2', 'Anahili[]PN'],
#  ['257', 'A-na-at-E2-a', 'AnatEa[]PN'],
#  ['258', 'A-na-ha', 'Anaha[]PN'],
#  ['259', 'A-na-lu2', 'Analu[]PN'],
#  ['260', 'A-na-na', 'Anana[]PN'],
#  ['261', 'A-na-ni-ak', 'Ananiʾak[]PN', '= Ananiʾa?'],
#  ['262', 'A-na-nu-um-DINGIR', 'Ananumilum[]PN'],
#  ['263', 'A-na-ti', 'Anati[]PN', '= Anatum?'],
#  ['264', 'A-na-ti-ta', 'Anati[]PN'],
#  ['265', 'A-na-tum', 'Anatum[]PN', '= Anati?'],
#  ['266', 'A-ni-a', 'Aniʾa[]PN'],
#  ['267', 'A-ni2-ti-dam', 'Anitidam[]PN'],
#  ['268', 'A-nu-il', 'Anuʾil[]PN', "'Anu is god' (stat absol)?"],
#  ['269', 'A-num2-me-il-lum', 'Anumilum[]PN'],
#  ['270', 'A-pi-la-ca', 'Apilaša[]PN', '= Apilašam?'],
#  ['271', 'A-pi-la-ca-am', 'Apilašam[]PN', '= Apilaša?'],
#  ['272', 'A-pi-la-nu-um', 'Apilanum[]PN'],
#  ['273', 'A-pi-te-el2', 'Apitel[]PN', 'Hurrian?'],
#  ['274', 'A-pi2-ak{ki}', 'Apiʾak[]SN'],
#  ['275', 'A-pi2-ak{ki}-ka', 'Apiʾak[]SN'],
#  ['276', 'A-pi2-ak{ki}-ta', 'Apiʾak[]SN'],
#  ['277', 'A-pi5-ak{ki}', 'Apiʾak[]SN'],
#  ['278', 'A-pi5-la-ca', 'Apilaša[]PN'],
#  ['279', 'A-pi5-la-ta', 'Apila[]PN'],
#  ['280', 'A-pi5-la-ti', 'Apilati[]PN', '= Apilatum?'],
#  ['281', 'A-pi5-la-tum', 'Apilatum[]PN', '= Apilati?'],
#  ['282', 'A-pi5-li2', 'Apili[]PN'],
#  ['283', 'A-pi5-li2-a', 'Apiliʾa[]PN'],
#  ['284', 'A-pil2-sa-um', 'Apilsaʾum[]PN'],
#  ['285', 'A-pu-nu-um', 'Apunum[]PN'],
#  ['286', 'A-ra-ap-hu-um{ki}', 'Arraphum[]SN'],
#  ['287', 'A-ra-mi{ki}', 'Arami[]SN'],
#  ['288',
#   'A-ra-zu-{d}I-bi2-{d}Suen-ka-ce3-pa3-da',
#   'ArazuIbbiSuʾenakšepada[]PN',
#   "AUAM 73.2209 o ii 6 (en Eridu) 'found acc. to the supplication of IbbiSuen'?"],
#  ['289',
#   'A-ra-zu-{d}I-bi2-{d}Suen-na-pa3-da',
#   'ArazuIbbiSuʾenakšepada[]PN',
#   "AUAM 73.2209 r i 11 (en Eridu) 'found acc. to the supplication of IbbiSuen'?"],
#  ['290', 'A-ra2-mu', 'Araŋu[]PN'],
#  ['291', 'A-ri-du-bu-uk', 'Aridubuk[]PN', 'Elamite?'],
#  ['292', 'A-ri-ip-a-tal', 'Aripatal[]PN', 'Hurrian'],
#  ['293', 'A-ri-ip-hu-up-pi2', 'Ariphuppi[]PN', 'Hurrian'],
#  ['294', 'A-ri2-bi', 'Aribi[]PN'],
#  ['295', 'A-ri2-bi-um{ki}', 'Aribiʾum[]SN'],
#  ['296', 'A-ri2-ip-a-tal', 'Aripatal[]PN', 'Hurrian'],
#  ['297', 'A-ri2-ip-hu-up-pi2', 'Ariphuppi[]PN', 'Hurrian'],
#  ['298', 'A-sya-ru-um-a-ur2-ra{ki}', 'Aṣarumaʾura[]SN'],
#  ['299', 'A-sya-ru-um-a-ur2-ra{ki}-ka', 'Aṣarumaʾura[]SN'],
#  ['300', 'A-sya-ru-um-da-gi', 'Aṣarumdaqqi[]SN'],
#  ['301', 'A-ta-a', 'Atta[]PN', 'uncertain'],
#  ['302', 'A-ta2-ce-en-ta', 'Attašen[]PN', 'Hurrian'],
#  ['303', 'A-ta2-kal2-cum', 'Atakkalšum[]PN'],
#  ['304', 'A-ta2-kal2-cum-e', 'Atakkalšum[]PN'],
#  ['305', 'A-ta2-na-ah', 'Atanah[]PN'],
#  ['306', 'A-tal-me-me', 'AtalMeme[]PN', 'Hurrian'],
#  ['307', 'A-tal2-{d}Mar-tu-ra', 'AtalMartu[]PN', 'Hurrian'],
#  ['308', 'A-tar-da', 'Atarda[]PN'],
#  ['309', 'A-ti', 'Ati[]PN', 'Ayati?'],
#  ['310', 'A-ti-a-ta', 'Atiʾa[]PN'],
#  ['311', 'A-ti-da', 'Atida[]PN'],
#  ['312', 'A-ti-da-ka', 'Atida[]PN'],
#  ['313', 'A-ti-da-ta', 'Atida[]PN'],
#  ['314', 'A-ti-ma-tum', 'Atimatum[]PN'],
#  ['315', 'A-tu', 'Atu[]PN'],
#  ['316', 'A-tu-Ma-ma', 'AtuMamak[]PN'],
#  ['317',
#   'A-tu-Uri5{ki}-ce3',
#   'not PN',
#   "profession?; 'doorkeeper(s) of Ur'? (AUCT 1 332 o 4)"],
#  ['318', 'A-tu-banda3{da}', 'Atubanda[]PN'],
#  ['319', 'A-tu-du', 'Atudu[]PN', "MVN 01 144 o 11'; name translit only (PD)"],
#  ['320', 'A-tu-kal-la', 'Atukala[]PN', 'or, Atukalag'],
#  ['321', 'A-tu-ki', 'Atuki[]PN'],
#  ['322',
#   'A-tu-su-si-ig',
#   'Atu[]PN',
#   "typo: NBC 00121 o 6: 1# gud# [A-t]u su-si-ig '1 bull for Atu the flayer'"],
#  ['323', 'A-tu-ta', 'Atu[]PN'],
#  ['324', 'A-u3-da-il', 'Aʾudaʾil[]PN'],
#  ['325', 'A-wa-ar-ka', 'Awarka[]PN'],
#  ['326', 'A-wa-at-i3-li2', 'Awatili[]PN'],
#  ['327', 'A-wa-nu-um', 'Awanum[]PN'],
#  ['328', 'A-za', 'Aza[]PN'],
#  ['329', 'A-za-ak-za-kum', 'Azakzakum[]PN'],
#  ['330', 'A-za-ba-an', 'Azaban[]PN', '= Azabani?'],
#  ['331', 'A-za-lum', 'Azalum[]PN'],
#  ['332', 'A-za-ma-an{ki}', 'Azaman[]SN'],
#  ['333', 'A-zi-zi', 'Azizi[]PN'],
#  ['334', 'A.AB.BA-ba-ac-ti', 'Abumbašti[]PN', 'uncertain'],
#  ['335', 'A.AB.BA-ba-ac-ti-ce3', 'Abumbašti[]PN'],
#  ['336', 'A.AB.BA-ba-ac2-ti-e', 'Abumbašti[]PN'],
#  ['337', 'A.AB.BA-ba-ac2-ti-ra', 'Abumbašti[]PN'],
#  ['338', 'A.HA{ki}', 'Kuʾara[]SN'],
#  ['339', 'A.HA{ki}-ce3', 'Kuʾara[]SN'],
#  ['340', 'A.HA{ki}-ta', 'Kuʾara[]SN'],
#  ['341',
#   'A.MA-{d}Ec4-tar2-ra',
#   'A.MA.{d}Eš₁₈.tar₂.ra[]PN',
#   'UmmiʾEštar?; LAOS 1 25 r 2 (copy)'],
#  ['342', 'A2-bi2-DINGIR', 'Abiʾili[]PN'],
#  ['343', 'A2-bi2-DU10', 'Abiṭab[]PN'],
#  ['344', 'A2-bi2-a-bi-ih', 'AbiʾEbih[]PN'],
#  ['345', 'A2-bi2-si2-im-ti', 'Abisimti[]PN'],
#  ['346',
#   'A2-bu-ru-ma',
#   'not PN',
#   "type of shoe (< Akk. burrumu 'multicolored')"],
#  ['347',
#   'A2-bu-ru-um-ma',
#   'not PN',
#   "type of shoe (< Akk. burrumu 'multicolored')"],
#  ['348', 'A2-da-lal3', 'Adalal[]PN', 'Addalal?'],
#  ['349', 'A2-dingir', 'Adiŋirak[]PN'],
#  ['350', 'A2-dingir-ga2-ta', 'Adiŋirŋak[]PN'],
#  ['351', 'A2-ga-ga', 'Agaga[]PN'],
#  ['352', 'A2-kuc3-{d}Mar-tu', 'AkušMartu[]PN'],
#  ['353', 'A2-la-la', 'Alala[]PN'],
#  ['354', 'A2-la-la-ta', 'Alala[]PN'],
#  ['355', 'A2-li2-id', 'Alid[]PN'],
#  ['356',
#   'A2-li2-id-DU',
#   'Alid[]PN',
#   'MCS 1 38 r 2: ŋiri3 a2-li2-id# / D[U-x?] (photo; PD); ra2-gaba?'],
#  ['357', 'A2-na', 'Ana[]PN', 'hypo?'],
#  ['358', 'A2-na-mu', 'Anaŋu[]PN'],
#  ['359', 'A2-na-na', 'Anana[]PN'],
#  ['360', 'A2-na-na-ta', 'Anana[]PN'],
#  ['361', 'A2-ne-ni', 'Apili[]PN'],
#  ['362', 'A2-ni-a2', 'Alid[]PN'],
#  ['363', 'A2-ni-a2-ta', 'Alid[]PN'],
#  ['364', 'A2-ni-ni-ta', 'Alili[]PN'],
#  ['365', 'A2-nin-ga2-ta', 'Aninŋak[]PN'],
#  ['366', 'A2-nu-nu', 'Anunu[]PN'],
#  ['367', 'A2-pi-la-ca', 'Apilaša[]PN'],
#  ['368', 'A2-pi-lum-ma', 'Apiluma[]PN', '= Apilum?'],
#  ['369', 'A2-pi5-la', 'Apila[]PN'],
#  ['370', 'A2-pi5-la-a', 'Apila[]PN', 'or, Apilaʾa/Apilaya?'],
#  ['371', 'A2-pi5-la-ca', 'Apilaša[]PN'],
#  ['372', 'A2-pi5-la-ca-ar', 'Apilaša[]PN'],
#  ['373', 'A2-pi5-la-ca-ce3', 'Apilaša[]PN'],
#  ['374', 'A2-pi5-la-ca-ta', 'Apilaša[]PN'],
#  ['375', 'A2-pi5-la-nu-um', 'Apilanum[]PN'],
#  ['376', 'A2-pi5-la-num2', 'Apilanum[]PN'],
#  ['377', 'A2-pi5-la-ti', 'Apilati[]PN', '= Apilatum?'],
#  ['378', 'A2-pi5-la-tum', 'Apilatum[]PN', '= Apilati?'],
#  ['379', 'A2-pi5-li2', 'Apili[]PN', '= Apilum?'],
#  ['380', 'A2-pi5-li2-a', 'Apiliʾa[]PN'],
#  ['381', 'A2-pi5-li2-a-ta', 'Apiliʾa[]PN'],
#  ['382', 'A2-pi5-li2-ta', 'Apili[]PN'],
#  ['383', 'A2-pi5-lum', 'Apilum[]PN', '= Apili?'],
#  ['384', 'A2-pi5-lum-ma', 'Apiluma[]PN', '= Apilum?'],
#  ['385', 'A2-ti-mu', 'Atiŋu[]PN'],
#  ['386', 'A2-tum-ce3', 'Atum[]PN'],
#  ['387', 'A2-u2-u2', 'AʾUʾu[]PN'],
#  ['388', 'A2-u2-u2-ta', 'AʾUʾu[]PN'],
#  ['389', 'A2-zi-da', 'Azida[]PN'],
#  ['390', 'A2-{d}Nanna', 'unkn', 'PD citation only for A2-{d}Nanna-ta'],
#  ['391', 'A2-{d}Nanna-ta', 'ANannak[]PN', 'uncertain'],
#  ['392',
#   'A2.DU-ni',
#   'A₂.DU.ni[]PN',
#   'Iduni?; BPOA 7 2174 o 2 (no copy/photo)'],
#  ['393', 'AB-il2-la', 'Abbaʾila[]PN'],
#  ['394', 'AB-ma-lik', 'Abummalik[]PN'],
#  ['395', 'AB-na', 'AB.na[]PN', 'MVN 13 529 o 17 (copy/photo)'],
#  ['396',
#   'AB-ti-ga-nu-um',
#   'AB.ti.ga.nu.um[]PN',
#   'may not be PN (PD; title "sheikh of Tiganum"?)'],
#  ['397',
#   'AB.NIN.AB-kam',
#   'AB.NIN.AB.kam[]PN',
#   'PDT 2 0805 o 6 (no copy/photo)'],
#  ['398',
#   'AB.NIN.AB-kam-ta',
#   'AB.NIN.AB.kam[]PN',
#   'PDT 2 0805 r 13 (no copy/photo)'],
#  ['399',
#   'AB.ZU-{d}Inanna',
#   'Abzu[]ON',
#   'Princeton 2 321 o 4: (bull/sheep) ZU.AB {d}Inana (photo)'],
#  ['400', 'AC-SAHAR{mucen}', 'not PN', 'FLP 0145 deliveries of birds (PD)'],
#  ['401', 'AC-a', 'not PN', 'number'],
#  ['402', 'AC-ce3', 'not PN', "adv aš-še₃ '1st time'"],
#  ['403', 'AC-ni-u18-ta', 'Ašliʾu[]PN'],
#  ['404', 'ACc', 'not PN', 'number'],
#  ['405', 'ACcx6', 'not PN', 'number'],
#  ['406', 'AH-bu-ru-um', 'Ahumburum[]PN', "uncertain; 'brother is a calf'?"],
#  ['407', 'AK-ba-ni', 'Akbani[]PN'],
#  ['408', 'AK-ta', 'AK[]PN', '1 PD; elsewhere: (egir) ... AK-ta'],
#  ['409', 'AM-ce3', 'not PN', 'bulls'],
#  ['410', 'AM-i3-li2', 'Rimili[]PN'],
#  ['411', 'AMAR-ma-an{ki}', 'AMAR.ma.an{ki}[]SN', '= Ar-ma-an{ki}?'],
#  ['412', 'AMAR-ma-an{ki}-me', 'AMAR.ma.an{ki}[]SN', '= Ar-ma-an{ki}?'],
#  ['413', 'AMAR-ma-ma', 'AmarMamak[]PN', 'or, BurMama?'],
#  ['414',
#   'AN-AN-zu',
#   'AN.AN.su[]PN',
#   '= Anumilišu?; UDT 119 o 4: ŋiri3 AN-AN-su (copy)'],
#  ['415',
#   'AN-DINGIR-su',
#   'AN.AN.su[]PN',
#   '= Anumilišu?; OrSP 26 66 IB 195 o 17 (copy/photo)'],
#  ['416',
#   'AN-ba-ti-ri-tum-ma',
#   'AN.ba.ti.ri.tum.ma[]PN',
#   'Ontario 1 025 o 3 (copy/photo)'],
#  ['417', 'AN-bu-um', 'not PN', 'metal obj'],
#  ['418', 'AN-dur', 'not PN', "an-usanₓ 'evening'"],
#  ['419', 'AN-ga-a', 'AN.ga.a[]PN', "UDT 091 o vii 12' (copy)"],
#  ['420', 'AN-ga-tum', 'AN.ga.tum[]PN', "UDT 091 o vii 23' (copy)"],
#  ['421', 'AN-kec2', 'AN.keš₂[]PN', 'TCL 2 5498 r i 4 (copy/photo)'],
#  ['422',
#   'AN-ku-zi-ri2',
#   'AN.ku.zi.ri₂[]PN',
#   'Studies Leichty 281 08 r 1 (copy)'],
#  ['423',
#   'AN-la-il',
#   'Ilumlaʾil[]PN',
#   'uncertain (Martu); StOr 09-1 21 (pl.6) r 3 (copy)'],
#  ['424', 'AN-lu2-bi', 'Anlubi[]PN'],
#  ['425', 'AN-lu2-mug-sa6', 'Anlumugsag[]PN'],
#  ['426', 'AN-lu2-sa6', 'Anlusag[]PN'],
#  ['427', 'AN-lugal', 'Anlugal[]PN'],
#  ['428', 'AN-mu-ma-sum', 'Diŋirŋumanšum[]PN'],
#  ['429', 'AN-mu-ma-sum-me-ec2', 'Diŋirŋumanšum[]PN'],
#  ['430', 'AN-na-a', 'Anaʾa[]PN'],
#  ['431', 'AN-ra-bi2-ta', 'Ilumrabi[]PN'],
#  ['432', 'AN-sa6-ga', 'Diŋirsaga[]PN', 'or, Ansaga'],
#  ['433', 'AN-sukkal', 'Ansukkal[]PN'],
#  ['434', 'AN-ta', 'not PN', "an-ta 'above'"],
#  ['435', 'AN-ti-a', 'Antiʾa[]PN'],
#  ['436', 'AN.E2-il', 'AN.E₂.il[]PN', 'Martu; StOr 09-1 21 (pl.6) o 8 (copy)'],
#  ['437',
#   'AN.ERIM-he2-zu',
#   'AN.ERIN₂.he₂.zu[]PN',
#   'uncertain; UDT 179 o 5: AN.ERIN2/UD-he2-zu (copy)'],
#  ['438', 'AN.GA-mu', 'AN.GA.ŋu₁₀[]PN', 'MVN 03 352 o 4 (copy/photo)'],
#  ['439', 'AN.GAR3-ta', 'AN.GAR₃[]PN', 'AUCT 2 008 r 1 (copy/photo)'],
#  ['440', 'AN.KAL.MA2-ke4', 'not PN', 'profession?/ethnicon?'],
#  ['441',
#   'AN.MUNUS.UC-bi',
#   'not PN',
#   'total: n gir2 banšur AN SAL.UŠ-bi {na4}za-gin3 kug-sig17 ŋar-ra (6 citations)'],
#  ['442', 'APIN-ce3', 'not PN', '(items) for the plow'],
#  ['443', 'ARAD2-su2-ni', 'Warassuni[]PN', 'uncertain'],
#  ['444', 'ARAD2-u3', 'ARAD₂.u₃[]PN'],
#  ['445', 'Ab-ab-sa6-ga', 'Abbaʾabbasaga[]PN', "'grandfather is good'?"],
#  ['446', 'Ab-ab-sa6-ga-ta', 'Abbaʾabbasaga[]PN'],
#  ['447', 'Ab-ba', 'Abba[]PN'],
#  ['448', 'Ab-ba-a', 'Abba[]PN', 'or, Abbaya?'],
#  ['449', 'Ab-ba-a-ta', 'Abba[]PN'],
#  ['450', 'Ab-ba-ba-ti', 'Abbabateŋ[]PN'],
#  ['451', 'Ab-ba-da-da', 'AbbaDada[]PN'],
#  ['452', 'Ab-ba-ge-na', 'Abbagina[]PN'],
#  ['453', 'Ab-ba-kal-la', 'Abbakala[]PN'],
#  ['454', 'Ab-ba-kal-la-ta', 'Abbakala[]PN'],
#  ['455', 'Ab-ba-mu', 'Abbaŋu[]PN'],
#  ['456', 'Ab-ba-na-ka', 'Abbani[]PN', 'Abbana?'],
#  ['457', 'Ab-ba-ni-ir', 'Abbani[]PN'],
#  ['458', 'Ab-ba-sa6-a-ta', 'Abbasaga[]PN'],
#  ['459', 'Ab-ba-sa6-ga', 'Abbasaga[]PN'],
#  ['460', 'Ab-ba-sa6-ga-a', 'Abbasaga[]PN'],
#  ['461', 'Ab-ba-sa6-ga-ce3', 'Abbasaga[]PN'],
#  ['462', 'Ab-ba-sa6-ga-ka', 'Abbasaga[]PN'],
#  ['463', 'Ab-ba-sa6-ga-ta', 'Abbasaga[]PN'],
#  ['464',
#   'Ab-ba-sa6-ga-ta-ta',
#   'Abbasaga[]PN',
#   'BM 116656 o 5 (no photo/copy); likely dittography'],
#  ['465', 'Ab-ba-sa6-sa6', 'Abbasagsag[]PN', 'likely Abbasasa(g)'],
#  ['466', 'Ab-ba-sig5', 'Abbasaga[]PN'],
#  ['467', 'Ab-ba-{d}En-lil2-ta', 'AbbaʾEnlil[]PN'],
#  ['468', 'Ab-la', 'Abla[]PN', 'Nebraska 03 seal 3: dumu Ab-la?'],
#  ['469',
#   'Ab-ra-at',
#   'unkn',
#   'TCTI 2 04259 o 5: lu2-kin-gi4-a x#-ab?#/-ra-at (copy; Labrat?)'],
#  ['470', 'Ab2-la-la-a', 'Ablala[]PN'],
#  ['471', 'Abzu', 'Abzu[]ON', 'probly cosmic Abzu or abzu-basin of DN'],
#  ['472',
#   'Abzu-{d}Inanna',
#   'Abzu[]ON',
#   'Princeton 2 319 o 4: (sheep/goats) for the abzu of Inana (photo)'],
#  ['473', 'Ac-cur5{ki}', 'Aššur[]SN'],
#  ['474', 'Ac-cur6{ki}', 'Aššur[]SN'],
#  ['475', 'Ac-da-en-na', 'Ašdaʾena[]PN'],
#  ['476', 'Ac-da-ga', 'Ašdaga[]PN'],
#  ['477', 'Ac-gu-ba-rum', 'Ašgubarum[]PN'],
#  ['478', 'Ac-ku-da-num2', 'Aškudanum[]PN'],
#  ['479', 'Ac-ni-u18', 'Ašliʾu[]PN'],
#  ['480', 'Ac-ni-u18-ta', 'Ašliʾu[]PN'],
#  ['481', 'Ac-ni-u19', 'Ašliʾu[]PN'],
#  ['482', 'Ac-ni-u19-ta', 'Ašliʾu[]PN'],
#  ['483', 'Ac-nun{ki}-ta', 'Ešnuna[]SN'],
#  ['484', 'Ac2-du-bi2-ic-ta', 'Ašdubiš[]PN'],
#  ['485', 'Ac2-nun-na-ta', 'Ešnuna[]PN'],
#  ['486', 'Ac2-nun-na{ki}', 'Ešnuna[]SN'],
#  ['487', 'Ac2-nun-na{ki}-ce3', 'Ešnuna[]SN'],
#  ['488', 'Ac2-nun-na{ki}-ta', 'Ešnuna[]SN'],
#  ['489', 'Ac2-nun{ki}', 'Ešnuna[]SN'],
#  ['490', 'Ac2-nun{ki}-ce3', 'Ešnuna[]SN'],
#  ['491', 'Ac2-nun{ki}-ka', 'Ešnuna[]SN'],
#  ['492', 'Ac2-nun{ki}-ta', 'Ešnuna[]SN'],
#  ['493', 'Ad-da', 'Adda[]PN'],
#  ['494',
#   'Ad-da-a',
#   'Addak[]PN',
#   '5 Nippur citations indicating internal genitive (Adda + -ka/ke4)'],
#  ['495', 'Ad-da-bi', 'Addabi[]PN'],
#  ['496', 'Ad-da-bu-NI-hu-dah', 'Ad.da.bu.NI.hu.dah[]PN'],
#  ['497', 'Ad-da-bu-ni', 'Addabuni[]PN'],
#  ['498', 'Ad-da-da', 'Addada[]PN'],
#  ['499', 'Ad-da-ga-da', 'Addagada[]PN'],
#  ['500', 'Ad-da-ga-da-ta', 'Addagada[]PN'],
#  ['501', 'Ad-da-ge-na', 'Addagina[]PN'],
#  ['502', 'Ad-da-gu-la', 'Addagula[]PN'],
#  ['503', 'Ad-da-ha-li', 'Addahali[]PN'],
#  ['504', 'Ad-da-kal-la', 'Addakala[]PN'],
#  ['505', 'Ad-da-kal-la-ce3', 'Addakala[]PN'],
#  ['506', 'Ad-da-kal-la-ta', 'Addakala[]PN'],
#  ['507', 'Ad-da-mu', 'Addaŋu[]PN'],
#  ['508', 'Ad-da-sa6-ga', 'Addasaga[]PN'],
#  ['509', 'Ad-da-tur', 'Addatur[]PN'],
#  ['510', 'Ad-du', 'Addu[]PN'],
#  ['511', 'Ad-du-na', 'Adduna[]PN'],
#  ['512', 'Ad-ga-nu-um', 'Abuganum[]PN', 'uncertain (2 PD); WSem'],
#  ['513', 'Ad-lal3', 'Addalal[]PN'],
#  ['514', 'Ad6-NI-mu', 'Ad₆.NI.ŋu₁₀[]PN'],
#  ['515', 'Adab{ki}', 'Adab[]SN'],
#  ['516', 'Adab{ki}-ce3', 'Adab[]SN'],
#  ['517', 'Adab{ki}-ka', 'Adab[]SN'],
#  ['518', 'Adab{ki}-me', 'Adab[]SN'],
#  ['519', 'Adab{ki}-ta', 'Adab[]SN'],
#  ['520', 'Ah-ba-bu', 'Ahbabu[]PN'],
#  ['521', 'Ah-da-li-ib', 'Ahdalib[]PN'],
#  ['522', 'Ah-ha-ti-mur', 'Ahatimur[]PN'],
#  ['523', 'Ak-ba-ni', 'Akbani[]PN'],
#  ['524', 'Al-ba-ni-du11', 'Albanidug[]PN'],
#  ['525', 'Al-la', 'Alla[]PN'],
#  ['526', 'Al-la-DI-mu', 'Alladiŋu[]PN'],
#  ['527', 'Al-la-LUL', 'Al.la.LUL[]PN', 'PDT 1 456 o 2 (no copy/photo)'],
#  ['528',
#   'Al-la-LUL-ke4',
#   'duplicate',
#   'same citation as 0527 (PDT 1 456 o 2)'],
#  ['529', 'Al-la-a', 'Alla[]PN'],
#  ['530', 'Al-la-ca-ru-um', 'Allašarrum[]PN', '= Allašar?'],
#  ['531', 'Al-la-ce3', 'Alla[]PN'],
#  ['532', 'Al-la-ge-na', 'Allagina[]PN'],
#  ['533', 'Al-la-ha-ma-ti', 'Allahamatil[]PN'],
#  ['534', 'Al-la-mu', 'Allaŋu[]PN'],
#  ['535', 'Al-la-mu-ta', 'Allaŋu[]PN'],
#  ['536', 'Al-la-ta', 'Alla[]PN'],
#  ['537', 'Al-lu', 'Allu[]PN'],
#  ['538', 'Al-lu-ri-num2', 'Allurinum[]PN'],
#  ['539', 'Al-lu-ta', 'Allu[]PN'],
#  ['540', 'Am-NI.NI', 'Rimili[]PN'],
#  ['541', 'Am-i3-li2', 'Rimili[]PN'],
#  ['542', 'Am-ma-ti', 'Ammati[]PN'],
#  ['543', 'Am-za-ku-um', 'Amzakum[]PN'],
#  ['544', 'Am3-ma', 'Amma[]PN'],
#  ['545', 'Ama-KI.KAL{ki}', 'Ama.KI.KAL{ki}[]SN'],
#  ['546', 'Ama-KI.KAL{ki}-ce3', 'Ama.KI.KAL{ki}[]SN'],
#  ['547', 'Ama-LUL.PI.IR', 'Ama.GIR₃.ši.ir[]PN', 'MVN 13 529 r 5 (copy/photo)'],
#  ['548', 'Ama-ak-nu-um', 'Amaknum[]PN'],
#  ['549', 'Ama-bara2', 'Amabarag[]PN', 'or, Amabaragak?'],
#  ['550', 'Ama-dingir', 'Amadiŋirak[]PN'],
#  ['551', 'Ama-kal-la', 'Amakala[]PN'],
#  ['552', 'Ama-mu', 'Amaŋu[]PN'],
#  ['553', 'Ama-na-a', 'Amanaʾa[]PN'],
#  ['554', 'Ama-zi-mu', 'Amaziŋu[]PN'],
#  ['555', 'Ama-{d}Ec4-tar2', 'AmaʾEštar[]PN', 'or, UmmiʾEštar?'],
#  ['556', 'Amar', 'not PN', 'uncertain (10243 possibilities)'],
#  ['557', 'Amar-Ma-ma', 'AmarMamak[]PN', 'or, BurMama?'],
#  ['558', 'Amar-Ma-ma-ta', 'AmarMamak[]PN'],
#  ['559',
#   'Amar-bu-um-ma',
#   'AMAR.bu.um.ma[]PN',
#   'PDT 2 0918 r iii 7 (no copy/photo)'],
#  ['560', 'Amar-cuba', 'AmarŠubak[]PN'],
#  ['561', 'Amar-cuba-ta', 'AmarŠubak[]PN'],
#  ['562', 'Amar-cuba3', 'AmarŠubak[]PN'],
#  ['563', 'Amar-isin2{si}-na', 'AmarIsinak[]PN'],
#  ['564', 'Amar-ma-an{ki}-ta', 'AMAR.ma.an[]SN', '= Ar-ma-an{ki}?'],
#  ['565', 'Amar-si4', 'Amarsu[]PN'],
#  ['566', 'Amar-{d}Da-mu', 'AmarDamuk[]PN'],
#  ['567', 'Amar-{d}Da-mu-ce3', 'AmarDamuk[]PN'],
#  ['568', 'Amar-{d}Suen', 'AmarSuʾenak[]RN'],
#  ['569', 'Amar-{d}Suen-ra', 'AmarSuʾenak[]RN', 'part of AS 8 year-name'],
#  ['570', 'An', 'unkn', 'no citations'],
#  ['571', 'An-ba-sa6-ga-ta', 'Anbasaga[]PN'],
#  ['572', 'An-ca-an', 'Anšan[]SN'],
#  ['573', 'An-ca-an-na-ke4', 'Anšan[]SN'],
#  ['574', 'An-ca-an-na{ki}', 'Anšan[]SN'],
#  ['575', 'An-ca-an{ki}', 'Anšan[]SN'],
#  ['576', 'An-ca-an{ki}-ke4', 'Anšan[]SN'],
#  ['577', 'An-ca-an{ki}-na', 'Anšan[]SN'],
#  ['578', 'An-ca-na{ki}', 'Anšan[]SN'],
#  ['579', 'An-ca-na{ki}-ke4', 'Anšan[]SN'],
#  ['580', 'An-na', 'unkn', '6034 possibilities'],
#  ['581', 'An-na-bi2-kuc2', 'Anabinkuš[]PN'],
#  ['582', 'An-na-ce3', 'An[]DN'],
#  ['583', 'An-na-da', 'Anada[]PN'],
#  ['584', 'An-na-hi-li', 'Anahili[]PN'],
#  ['585', 'An-na-hi-li-bi', 'Anahilibi[]PN'],
#  ['586', 'An-na-hi-li-bi-ta', 'Anahilibi[]PN'],
#  ['587', 'An-na-hi-li-mu', 'Anahiliŋu[]PN'],
#  ['588', 'An-na-ta', 'An[]DN'],
#  ['589', 'An-na-tal', 'Anatal[]PN', 'Hurrian'],
#  ['590', 'An-ne2', 'Ane[]PN', 'hypo?'],
#  ['591', 'An-ne2-a', 'Aneʾa[]PN', 'hypo?'],
#  ['592', 'An-ne2-ba-ab-du7', 'Anebabdu[]PN'],
#  ['593', 'An-ne2-gar-ra', 'Aneŋara[]PN'],
#  ['594', 'An-ne2-mu', 'Aneŋu[]PN'],
#  ['595', 'An-ne2-zu', 'Anezu[]PN'],
#  ['596', 'An-nu-ni-tum', 'Annunitum[]DN', 'epithet/manifestation of Ishtar'],
#  ['597', 'An-nu-ni-tum-ce3', 'Annunitum[]DN'],
#  ['598', 'An-ta-lu2', 'Antalu[]PN'],
#  ['599', 'An-ti-a', 'Antiʾa[]PN'],
#  ['600', 'An-za-gar3', 'not PN', 'generic tower/fort'],
#  ['601', 'An-za-gar3{ki}', 'Anzagar[]SN'],
#  ['602', 'Aq-ba-ia3', 'Aqbaya[]PN'],
#  ['603', 'Ar-ba-tal', 'Arpatal[]PN', 'Hurrian'],
#  ['604', 'Ar-bi2-gi4', 'Arbigi[]PN'],
#  ['605', 'Ar-bi2-tum', 'Arbitum[]PN'],
#  ['606', 'Ar-ci-ah', 'Aršiʾah[]PN'],
#  ['607', 'Ar-ci-ah-ce3', 'Aršiʾah[]PN'],
#  ['608', 'Ar-ci-ih', 'Aršiʾah[]PN'],
#  ['609', 'Ar-ma-an{ki}', 'Arman[]SN'],
#  ['610', 'Ar-pa2-tal', 'Arpatal[]PN', 'Hurrian'],
#  ['611', 'Ar-ri-du-ga', 'Arriduga[]PN'],
#  ['612',
#   'Ar-wa-lu-uk-bi',
#   'Arwilugga[]PN',
#   'MLC 00036 o 5, r 1 (AS 01-05-28); < Marhaši 1 udu niga each (no photo/copy)'],
#  ['613', 'Ar-wa-tum', 'Arwatum[]PN'],
#  ['614',
#   'Ar-wi-lu-ug-bi',
#   'Arwilugga[]PN',
#   'UMNH 1830 o 1, 2 (AS 01-06-21); < Marhaši 1 udu niga each (no photo/copy)'],
#  ['615',
#   'Ar-wi-lu-ug-ga',
#   'Arwilugga[]PN',
#   'Fonthill Mus. 519 o 6, r 2 (AS 01-06-08); < Marhaši 1 udu niga each (copy)'],
#  ['616', 'Arad-mu', 'Aradŋu[]PN'],
#  ['617', 'Arad2', 'Arad[]PN'],
#  ['618', 'Arad2-da', 'Arad[]PN'],
#  ['619', 'Arad2-da-ni', 'Aradani[]PN'],
#  ['620', 'Arad2-da-ta', 'Arad[]PN'],
#  ['621', 'Arad2-dam', 'Aradam[]PN'],
#  ['622', 'Arad2-dingir-ra', 'Araddiŋirak[]PN'],
#  ['623', 'Arad2-gi4-sal4-la{ki}', 'Aradgisalak[]SN'],
#  ['624', 'Arad2-hu-la', 'Aradhula[]PN'],
#  ['625', 'Arad2-hul2-la', 'Aradhula[]PN'],
#  ['626', 'Arad2-hul3', 'Aradhula[]PN'],
#  ['627', 'Arad2-hul3-la', 'Aradhula[]PN'],
#  ['628', 'Arad2-hul3-la-ta', 'Aradhula[]PN'],
#  ['629', 'Arad2-ku3-ga-ta', 'Aradkuga[]PN'],
#  ['630', 'Arad2-mu', 'Aradŋu[]PN'],
#  ['631', 'Arad2-mu-ra', 'Aradŋu[]PN'],
#  ['632', 'Arad2-mu-ta', 'Aradŋu[]PN'],
#  ['633', 'Arad2-sa6-sa6', 'Aradsagsag[]PN', 'likely Aradsasa(g)'],
#  ['634',
#   'Arad2-sanga--mu-ta',
#   'Aradsaŋŋaŋu[]PN',
#   'uncertain; BM 103411 o i 20: Arad2-<<SANGA>>-mu-ta? (no photo/copy)'],
#  ['635', 'Arad2-ta', 'Arad[]PN'],
#  ['636', 'Arad2-u3', 'ARAD₂.u₃[]PN'],
#  ['637', 'Arad2-{d}Amar-{d}Suen', 'AradAmarSuʾenakak[]PN'],
#  ['638', 'Arad2-{d}Amar-{d}Suen-ta', 'AradAmarSuʾenakak[]PN'],
#  ['639', 'Arad2-{d}Ba-u2', 'AradBaʾuk[]PN'],
#  ['640', 'Arad2-{d}Nanna', 'AradNannak[]PN'],
#  ['641', 'Arad2-{d}Nanna-ce3', 'AradNannak[]PN'],
#  ['642', 'Arad2-{d}Nanna-ta', 'AradNannak[]PN'],
#  ['643', 'Aratta{ki}', 'Aratta[]SN'],
#  ['644', 'Asar-lu2-hi', 'Asarluhi[]DN'],
#  ['645', 'BAD3-AN{ki}', 'BAD₃.AN[]SN'],
#  ['646', 'BAD3-i3-li2', 'Durili[]PN'],
#  ['647',
#   'BAD3.AN.KI.ZI{ki}',
#   'BAD₃.AN.KI.ZI[]SN',
#   'uncertain; SET 010 o 14 (no copy/photo)'],
#  ['648', 'BAD3.AN{ki}', 'BAD₃.AN[]SN'],
#  ['649', 'BAD3.AN{ki}-ce3', 'BAD₃.AN[]SN'],
#  ['650', 'BAD3.AN{ki}-ke4-ne', 'BAD₃.AN[]SN'],
#  ['651', 'BAD3.AN{ki}-me', 'BAD₃.AN[]SN'],
#  ['652', 'BAD3.AN{ki}-ta', 'BAD₃.AN[]SN'],
#  ['653', 'BAD3{ki}', 'BAD₃[]SN', 'all refs likely < bad3 mar-tu'],
#  ['654', 'BAD3{ki}-ce3', 'BAD₃[]SN'],
#  ['655', 'BAD3{ki}-ta', 'BAD₃[]SN'],
#  ['656', 'BI-gu7-ce3', 'BI.gu₇[]PN', "Kašgu 'beer-eater'?"],
#  ['657', 'BI-ku-bi', 'BI.ku.bi[]PN'],
#  ['658', 'BI-{d}Al-la', 'BI.{d}Al.la[]PN'],
#  ['659', 'BI.GIC.MAC-ta', 'BI.GIŠ.MAŠ[]PN'],
#  ['660', 'BU-da-a', 'Buda[]PN', 'note: Nippur refs likely Bu-da + agent'],
#  ['661', 'BU-ra', 'not PN', 'verb'],
#  ['662', 'Ba', 'unkn', '27,837 PD possibilities'],
#  ['663', 'Ba-DU.DU', 'Balah[]PN', 'uncertain'],
#  ['664', 'Ba-NI-a', 'Baniʾa[]PN'],
#  ['665', 'Ba-a-a', 'Baya[]PN'],
#  ['666', 'Ba-a-a-ti', 'Bayati[]PN'],
#  ['667', 'Ba-a-ba-lum', 'Babalum[]PN', 'Wabalum?'],
#  ['668', 'Ba-a-bi2{ki}', 'Babi[]SN', 'Babil?; OIP 115 158 r 7 (copy/photo)'],
#  ['669', 'Ba-a-da-a', 'Bada[]PN', 'or, Badaʾa'],
#  ['670', 'Ba-a-ga', 'Baga[]PN'],
#  ['671', 'Ba-a-ga-ta', 'Baga[]PN'],
#  ['672', 'Ba-a-la-a', 'Bala[]PN', 'or, Balaʾa, Balaya?'],
#  ['673', 'Ba-a-mu', 'Baŋu[]PN'],
#  ['674', 'Ba-a-na-tum', 'Banatum[]PN'],
#  ['675', 'Ba-a-zum', 'Bazum[]PN', 'Baṣum?'],
#  ['676', 'Ba-ab-du-ca', 'Babduša[]PN'],
#  ['677', 'Ba-ah-zu-zu', 'Bahzuzu[]PN'],
#  ['678', 'Ba-ak-NI-NI', 'Bakili[]PN'],
#  ['679', 'Ba-ak-i3-li2-a', 'Bakiliya[]PN', 'or, Bakiliʾa?'],
#  ['680', 'Ba-ak-ti', 'Bakti[]PN'],
#  ['681', 'Ba-al-NI', 'Balli[]PN'],
#  ['682', 'Ba-al-NI-ta', 'Balli[]PN'],
#  ['683', 'Ba-al-du{ki}', 'Baldu[]SN'],
#  ['684', 'Ba-al-li2', 'Balli[]PN'],
#  ['685', 'Ba-al-li2-ta', 'Balli[]PN'],
#  ['686', 'Ba-an-zi-ge', 'Banzige[]PN'],
#  ['687', 'Ba-an-zi-ge-me', 'Banzige[]PN'],
#  ['688', 'Ba-an-zi-ge-ta', 'Banzige[]PN'],
#  ['689', 'Ba-an-zi-zi-ta', 'Banzigzig[]PN', 'likely Banzizi(g)'],
#  ['690', 'Ba-aq-ri', 'Baqri[]PN'],
#  ['691', 'Ba-ar-ba-na-zu', 'Barbanazu[]PN'],
#  ['692', 'Ba-ba', 'Baba[]PN'],
#  ['693', 'Ba-ba-a', 'Baba[]PN', 'or Babaya, Babaʾa?'],
#  ['694', 'Ba-ba-a-a', 'Babaya[]PN'],
#  ['695', 'Ba-ba-a-ti', 'Babati[]PN', '= Babatum?'],
#  ['696', 'Ba-ba-az{ki}', 'Babaz[]SN'],
#  ['697', 'Ba-ba-lum', 'Babalum[]PN', 'Wabalum?'],
#  ['698', 'Ba-ba-lum-ta', 'Babalum[]PN'],
#  ['699', 'Ba-ba-ti', 'Babati[]PN', '= Babatum?'],
#  ['700', 'Ba-ba-ti-ta', 'Babati[]PN'],
#  ['701', 'Ba-ba-tum', 'Babatum[]PN', '= Babati?'],
#  ['702', 'Ba-ca-an-ti-ba-ad', 'Bašantibat[]PN'],
#  ['703', 'Ba-ca-an-ti-ba-at', 'Bašantibat[]PN'],
#  ['704', 'Ba-ce-ri-ic-ta', 'Bašeriš[]PN'],
#  ['705', 'Ba-cim-e{ki}', 'Bašime[]SN'],
#  ['706', 'Ba-cim-e{ki}-ce3', 'Bašime[]SN'],
#  ['707', 'Ba-cim-e{ki}-ka-ce3', 'Bašime[]SN'],
#  ['708',
#   'Ba-cu-u2',
#   'Bašu[]PN',
#   'uncertain (BCT 1 003 o 8: 1 sila4 Ba-šu#/ku#/lu#-u2# dam-gar3)'],
#  ['709', 'Ba-da-ni', 'Badani[]PN'],
#  ['710', 'Ba-da-ti-na', 'Badatina[]PN'],
#  ['711', 'Ba-ga-ri2', 'Bagari[]PN', '= Bagarum?'],
#  ['712', 'Ba-ga-tum', 'Bagatum[]PN', '= Bagati?'],
#  ['713', 'Ba-ga-tum-ta', 'Bagatum[]PN'],
#  ['714', 'Ba-gu-um', 'Bagum[]PN', '= Bagu?'],
#  ['715', 'Ba-ha-ar-ce-en', 'Paharšen[]PN', 'Hurrian'],
#  ['716', 'Ba-hi-zu-zu', 'Bahzuzu[]PN'],
#  ['717', 'Ba-hul', 'not PN', 'verb (part of year-name)'],
#  ['718', 'Ba-ir', 'Baʾir[]PN'],
#  ['719', 'Ba-ki-na-na', 'Pakinana[]PN'],
#  ['720', 'Ba-ku-i3-li2-a', 'Bakuʾiliya[]PN'],
#  ['721', 'Ba-la-a', 'Bala[]PN', 'or, Balaʾa, Balaya?'],
#  ['722', 'Ba-la-i3-li2-a', 'Balaʾiliya[]PN'],
#  ['723', 'Ba-la-la', 'Balala[]PN'],
#  ['724', 'Ba-la-mu', 'Balaŋu[]PN'],
#  ['725', 'Ba-la-ti', 'Balati[]PN', '= Balatum?'],
#  ['726', 'Ba-li-ta', 'Bali[]PN', '= Balli?'],
#  ['727', 'Ba-lu-e{ki}', 'Baluʾe[]SN'],
#  ['728', 'Ba-lu-za', 'Baluza[]PN'],
#  ['729', 'Ba-lu5-lu5', 'Balulu[]PN', '= Palulu?'],
#  ['730', 'Ba-mu', 'Baŋu[]PN'],
#  ['731', 'Ba-mu-ka', 'Baŋu[]PN'],
#  ['732', 'Ba-mu-ta', 'Baŋu[]PN'],
#  ['733', 'Ba-na-na', 'Banana[]PN', '= Bananum/Panana?'],
#  ['734', 'Ba-na-nu-um', 'Bananum[]PN', '= Banana?'],
#  ['735', 'Ba-ni', 'Bani[]PN', '= Banum?'],
#  ['736', 'Ba-ni-tum', 'Banitum[]PN', '= Panitum?'],
#  ['737', 'Ba-num2', 'Banum[]PN', '= Bani?'],
#  ['738', 'Ba-ra-{d}E11-e', 'Baranede[]PN'],
#  ['739', 'Ba-ri-a-cum', 'Bariʾašum[]PN'],
#  ['740', 'Ba-sa6', 'Basaga[]PN'],
#  ['741', 'Ba-sa6-ga', 'Basaga[]PN'],
#  ['742', 'Ba-sa6-ga-ce3', 'Basaga[]PN'],
#  ['743', 'Ba-sa6-ga-ta', 'Basaga[]PN'],
#  ['744', 'Ba-ti', 'not PN', 'verb (šu ba-ti)'],
#  ['745', 'Ba-tu-ug-ra-ad', 'Batugrad[]PN', '< LU2.SU.A{ki}'],
#  ['746', 'Ba-tum', 'Batum[]PN'],
#  ['747', 'Ba-ug7', 'not PN', 'verb'],
#  ['748', 'Ba-za', 'Baza[]PN'],
#  ['749', 'Ba-za-a', 'Baza[]PN'],
#  ['750', 'Ba-za-mu', 'Bazaŋu[]PN'],
#  ['751', 'Ba-za-ti-a', 'Bazatiʾa[]PN', 'or, Bazatiya?'],
#  ['752', 'Ba-za-za', 'Bazaza[]PN'],
#  ['753',
#   'Ba-zi',
#   'not PN',
#   'verb (6004 possibilities; may be PN outside PD); Baziga/e?'],
#  ['754', 'Ba-zi-ge', 'Bazige[]PN', '= Bazigen?'],
#  ['755', 'Ba-zi-ge-en6-ta', 'Bazigen[]PN'],
#  ['756', 'Ba-zi-ge-na-ta', 'Bazigen[]PN'],
#  ['757', 'Ba-zi-ta', 'Bazig[]PN', '= Bazige, Bazigen?'],
#  ['758', 'Babilim-ta', 'Babilim[]SN'],
#  ['759', 'Babilim2-ce3', 'Babilim[]SN'],
#  ['760', 'Babilim{ki}', 'Babilim[]SN'],
#  ['761', 'Babilim{ki}-ce3', 'Babilim[]SN'],
#  ['762', 'Babilim{ki}-ka', 'Babilim[]SN'],
#  ['763', 'Babilim{ki}-ma', 'Babilim[]SN'],
#  ['764', 'Babilim{ki}-ma-ta', 'Babilim[]SN'],
#  ['765', 'Babilim{ki}-ta', 'Babilim[]SN'],
#  ['766', 'Bala', 'not PN', 'office/turn/rotation'],
#  ['767', 'Bar-ba-na-zu{ki}', 'Barbanazu[]SN'],
#  ['768', 'Bar-bar', 'Barbar[]PN'],
#  ['769', 'Bar-bar-NI-a', 'Barbariʾa[]PN'],
#  ['770', 'Bar-bar-NI-a-ta', 'Barbariʾa[]PN'],
#  ['771', 'Bar-bar-i3-a-ta', 'Barbariʾa[]PN'],
#  ['772', 'Bar-bar-ri-a', 'Barbariʾa[]PN'],
#  ['773', 'Bar-ma-an{ki}', 'Barman[]SN'],
#  ['774', 'Bar-ra', 'not PN', 'uncertain (likely verb)'],
#  ['775', 'Be-li2', 'unkn', '3 in broken context'],
#  ['776', 'Be-li2-A.ZU', 'Beliʾasu[]PN'],
#  ['777', 'Be-li2-A.ZU-ta', 'Beliʾasu[]PN'],
#  ['778', 'Be-li2-DU10', 'Beliṭab[]PN', 'or, Beliṭabum'],
#  ['779', 'Be-li2-DU10-ta', 'Beliṭab[]PN'],
#  ['780', 'Be-li2-KAL', 'Belidan[]PN', 'or, Belidannum'],
#  ['781', 'Be-li2-a', 'Beliya[]PN', 'or, Beliʾa'],
#  ['782', 'Be-li2-a-ri-ik', 'Beliʾarik[]PN'],
#  ['783', 'Be-li2-a-ri-ik-ta', 'Beliʾarik[]PN'],
#  ['784', 'Be-li2-a-ri2-ik', 'Beliʾarik[]PN'],
#  ['785', 'Be-li2-a-ri2-ik-ce3', 'Beliʾarik[]PN'],
#  ['786', 'Be-li2-ba-ni', 'Belibani[]PN'],
#  ['787', 'Be-li2-ba-ni-ta', 'Belibani[]PN'],
#  ['788', 'Be-li2-car', 'Beliʾišar[]PN', "or, Belišar 'my lord is king'?"],
#  ['789', 'Be-li2-i-car', 'Beliʾišar[]PN', "'my lord is just'"],
#  ['790', 'Be-li2-i3-li2', 'Beliʾili[]PN'],
#  ['791', 'Be-li2-i3-li2-ta', 'Beliʾili[]PN'],
#  ['792', 'Be-li2-ki-in', 'Belikin[]PN'],
#  ['793', 'Be-li2-na-bi2-ic-ti', 'Belinapišti[]PN'],
#  ['794',
#   'Be-li2-na-ha-ti',
#   'Belinapišti[]PN',
#   'BIN 3 054 o 3: 2 sila4 Be-li2-na-HA/-ti (copy; HA could be HA@g; needs coll.)'],
#  ['795', 'Be-li2-si2-im-ti', 'Belisimti[]PN'],
#  ['796',
#   'Be-li3-li3-ta',
#   'Belili[]PN',
#   'sandhi for Beliʾili? (Studies Leichty 281 08 o 4)'],
#  ['797', 'Be2-bu-ru', 'Beburu[]PN'],
#  ['798', 'Be2-li2-i3-li2', 'Beliʾili[]PN'],
#  ['799', 'Be6-bu-ru', 'Beburu[]PN'],
#  ['800', 'Bi-ga-tum', 'Bigatum[]PN'],
#  ['801', 'Bi-ir-ha-cum', 'Birhašum[]PN'],
#  ['802', 'Bi-ir-hu-um-ce3', 'Birhum[]PN'],
#  ['803', 'Bi-ze2-ze2', 'Bizeze[]PN'],
#  ['804', 'Bi-ze2-ze2-ta', 'Bizeze[]PN'],
#  ['805', 'Bi2-da', 'Bida[]PN'],
#  ['806', 'Bi2-da-dun{ki}', 'Bidadun[]SN'],
#  ['807', 'Bi2-du11-i3-sa6', 'Bidugisag[]PN'],
#  ['808',
#   'Bi2-i3-bi2-a',
#   'Bibiʾa[]PN',
#   'uncertain (AAICAB 1/1, Ashm. 1923-420 r 2)'],
#  ['809', 'Bi2-ib-ra', 'Bibra[]PN', '< LU2.SU'],
#  ['810', 'Bi2-in-zi', 'Binzi[]PN', '< Anšan'],
#  ['811', 'Bi2-la-bi', 'Bilabi[]PN'],
#  ['812', 'Bi2-la-li2-a-ta', 'Bilali[]PN', '-a probly gen'],
#  ['813', 'Bi2-li2-ib-ba', 'Biliba[]PN', '< E2-gu-la/Bitumrabium'],
#  ['814', 'Bi2-li2-la', 'Bilila[]PN'],
#  ['815', 'Bi2-na-tum', 'Binatum[]PN'],
#  ['816', 'Bi2-ra-ti', 'Birati[]PN'],
#  ['817', 'Bi2-tum-ra-bi2-um', 'Bitumrabium[]SN'],
#  ['818', 'Bi2-tum-ra-bi2-um{ki}', 'Bitumrabium[]SN'],
#  ['819', 'Bi2-za-nu-um', 'Bizanum[]PN'],
#  ['820', 'Bi2-za-tum', 'Bizatum[]PN'],
#  ['821', 'Bi2-zu-a', 'Bizuʾa[]PN'],
#  ['822', 'Bil-ga', 'Bilga[]PN'],
#  ['823', 'Blog', 'not PN', 'editorial comment'],
#  ['824', 'Bu-bu', 'Bubu[]PN'],
#  ['825', 'Bu-ca-am', 'Bušam[]PN'],
#  ['826', 'Bu-ca-nu-um', 'Bušanum[]PN'],
#  ['827', 'Bu-ca-num2', 'Bušanum[]PN'],
#  ['828', 'Bu-du-ur2', 'Budur[]PN'],
#  ['829', 'Bu-ga-a', 'Buga[]PN', 'or, Bugaʾa?'],
#  ['830', 'Bu-ga-ti', 'Bugati[]PN', '= Bugatum?'],
#  ['831', 'Bu-ku-bi-ir', 'Bukubir[]PN'],
#  ['832', 'Bu-ku-cum', 'Buqušum[]PN'],
#  ['833', 'Bu-la-li2-ta', 'Bulali[]PN', '= Bulalum?'],
#  ['834', 'Bu-la-lum', 'Bulalum[]PN', '= Bulali?'],
#  ['835', 'Bu-la-mu', 'Bulamu[]PN'],
#  ['836', 'Bu-li{ki}', 'Buli[]SN'],
#  ['837', 'Bu-li{ki}-ta', 'Buli[]SN'],
#  ['838', 'Bu-lu-lu', 'Bululu[]PN'],
#  ['839', 'Bu-nu-ni-lum', 'Bununilum[]PN'],
#  ['840',
#   'Bu-qu-cum',
#   'unkn',
#   'BIN 3 477 seal: Bu-x#-[x?] / dub#-[sar] / arad2 {d}Ni[n-x] (copy)'],
#  ['841', 'Bu-ra-ac-hi', 'Burašhi[]PN'],
#  ['842', 'Bu-ra-am', 'Buram[]PN'],
#  ['843', 'Bu-ru-uk', 'Buruk[]PN'],
#  ['844', 'Bu-u2-du', 'Budu[]PN'],
#  ['845', 'Bu-u2-du-ce3', 'Budu[]PN'],
#  ['846', 'Bu-u2-du-ta', 'Budu[]PN'],
#  ['847', 'Bu-ud-ra', 'Budra[]PN'],
#  ['848', 'Bu-ul-ba-ad', 'Bulbad[]PN'],
#  ['849',
#   'Bu-ul-bu-ul-la',
#   'Bulbula[]PN',
#   "1st UL uncertain (JCS 54 12 82 r ii 30'; no photo/copy)"],
#  ['850', 'Bu-za-nu-um', 'Buzanum[]PN'],
#  ['851', 'Bu-zi', 'Buzi[]PN'],
#  ['852', 'Bu-zi-na-at', 'Buzinat[]PN'],
#  ['853', 'Bu-zu', 'Buzu[]PN'],
#  ['854', 'Bu-zu-a', 'Buzuʾa[]PN'],
#  ['855', 'Bu-zu-a-ta', 'Buzuʾa[]PN'],
#  ['856', 'Bu-zu-zu', 'Puzuzu[]PN'],
#  ['857', 'Bu3-bu3', 'Bubu[]PN'],
#  ['858', 'Bu3-ca-am', 'Bušam[]PN'],
#  ['859', 'Bu3-ca-num2', 'Bušanum[]PN'],
#  ['860',
#   'Bu3-cu-DINGIR',
#   'Pušuʾilum[]PN',
#   "uncertain ('his order/advice/rule/speech is (my) god'?)"],
#  ['861', 'Bu3-cu-du', 'Bušudu[]PN', 'SH 46 (envoy < LU2.SU{ki})'],
#  ['862', 'Bu3-cu-ud', 'Bušudu[]PN', 'AS 08 (envoy < LU2.SU{ki})'],
#  ['863', 'Bu3-du-uk-ce-en', 'Pudukšen[]PN', 'Hurrian'],
#  ['864', 'Bu3-du-uk-ce-en6', 'Pudukšen[]PN'],
#  ['865', 'Bu3-ir{ki}', 'Buʾir[]SN'],
#  ['866', 'Bu3-lu5', 'Bulul[]PN', 'uncertain; = Bululu?'],
#  ['867', 'Bu3-lu5-lu5', 'Bululu[]PN'],
#  ['868', 'Bu3-lu5-lu5-ta', 'Bululu[]PN'],
#  ['869', 'Bu3-u2-a-ta', 'Buʾa[]PN'],
#  ['870',
#   'Bu3-u2-da-a',
#   'Budaya[]PN',
#   'nisbe < Buda{ki}? (SmithCS 38 13 o 3; AS 01-06-00)'],
#  ['871',
#   'Bu3-u2-da{ki}',
#   'Budaya[]PN',
#   'uncertain; animal deliveries < A-dam-dun{ki}, ŋiri3 Bu3-u2-da{ki} (Nik. 2 483 r 4, TRU 277 o 8; both SH 46-08-00)'],
#  ['872', 'Bu3-u2-du', 'Budu[]PN'],
#  ['873', 'Bu3-u2-du-ce3', 'Budu[]PN'],
#  ['874', 'Bu3-u2-du-ta', 'Budu[]PN'],
#  ['875', 'Bu3-u2-za', 'Buza[]PN'],
#  ['876', 'Bu3-uc-ki-in-ce3', 'Puškin[]PN', '= Pušukin?'],
#  ['877', 'Bu3-un-du', 'Bundu[]PN'],
#  ['878', 'Buchanan:', 'not PN', 'formatting'],
#  ['879', 'Bur-Ma-ma', 'BurMama[]PN'],
#  ['880', 'Bur-na-zu', 'Burnazu[]PN'],
#  ['881', 'Bur-{d}Cul-gi', 'BurŠulgi[]PN'],
#  ['882', 'Bur-{d}ICKUR', 'BurAdad[]PN'],
#  ['883', 'Bur-{d}MIR', 'Bur.{d}MIR[]PN', '= BurWer?'],
#  ['884',
#   'CARA2.KAM-a',
#   'Šarakam[]PN',
#   'uncertain; YOS 18 008 o 5: 2 udu 1 sila4 Šara2?-kam-a (copy)'],
#  ['885',
#   'CE.KUR-ra-ce3',
#   'not PN',
#   'TCS 1 125 o 5: (why has PN given še-eštub to PN2) mu še kur-ra-še3'],
#  ['886', 'CE3-za-a-LUM', 'EŠ₂.ZA.a.LUM[]PN', 'AUCT 1 074 r 4 (copy/photo)'],
#  ['887',
#   'CE3.IL-ce3',
#   'unkn',
#   'JCS 54 12 82 i 3 (broken context; partial copy)'],
#  ['888',
#   'CEC.AB{ki}-ma-ke4',
#   'unkn',
#   'no citations (probly part of year-name or seal)'],
#  ['889', 'CI-te-NI', 'Šeteli[]PN'],
#  ['890',
#   'CID-gal2',
#   'not PN',
#   'uncertain (descriptive of {ŋeš}u3-suh5?); PDT 2 0918 o 3 (no copy/photo)'],
#  ['891', 'CUE-la-lum', 'Šulanum', 'OIP 121 028 r 1 (copy/photo)'],
#  ['892', 'Ca-ab-ca-nu', 'Šabšanu[]PN'],
#  ['893', 'Ca-ac-cu2-ru-um{ki}', 'Šašrum[]SN'],
#  ['894', 'Ca-ac-cu2-ru{ki}', 'Šašrum[]SN'],
#  ['895', 'Ca-ac-ru', 'Šašrum[]SN'],
#  ['896', 'Ca-ac-ru-ki', 'Šašrum[]SN'],
#  ['897', 'Ca-ac-ru-um{ki', 'Šašrum[]SN'],
#  ['898', 'Ca-ac-ru-um{ki}', 'Šašrum[]SN'],
#  ['899', 'Ca-ac-ruki}', 'Šašrum[]SN'],
#  ['900', 'Ca-ac-ru{ki}', 'Šašrum[]SN'],
#  ['901', 'Ca-ad-ra-ad', 'Šadrad[]PN'],
#  ['902', 'Ca-al-mah', 'Šalmah[]PN'],
#  ['903',
#   'Ca-as-ru{ki}',
#   'Šašrum[]SN',
#   'so Nisaba 08 013 o 5 (photo); typo in SET 063 r 21 (AS for AŠ; photo)'],
#  ['904', 'Ca-at-E2-a', 'ŠatEa[]PN'],
#  ['905',
#   'Ca-at-bi',
#   'Šatbisal[]PN',
#   'uncertain; MVN 11 217 r 3: 1 maš2 Ša-at-bi-sal nar (copy/photo); cf, Šatbizil at Garšana (28 citations)'],
#  ['906', 'Ca-at-da-ti', 'Šatdati[]PN'],
#  ['907', 'Ca-at-i3-li2-ta', 'Šatili[]PN'],
#  ['908',
#   'Ca-at-il-ti-in-ce3',
#   'Šatiltin[]DN',
#   'uncertain; contextual with animal-deliveries to various gods (MM 0026 o 4 SH 35; MM 0031 S r 1 SH 36)'],
#  ['909', 'Ca-at-ku-ku-ti', 'Šatkukuti[]PN'],
#  ['910', 'Ca-at-ma-mi', 'ŠatMami[]PN'],
#  ['911', 'Ca-at-{d}Cu-{d}Suen', 'ŠatŠuSuʾen[]PN'],
#  ['912', 'Ca-at-{d}Cul-gi', 'ŠatŠulgi[]PN'],
#  ['913', 'Ca-at-{d}Ma-mi', 'ŠatMami[]PN'],
#  ['914', 'Ca-at-{d}Suen', 'ŠatSuʾen[]PN'],
#  ['915', 'Ca-at-{d}Suen-ce3', 'ŠatSuʾen[]PN'],
#  ['916', 'Ca-ba-ar-kum', 'Šabarkum[]PN'],
#  ['917', 'Ca-ci-ku-na', 'Šašikuna[]PN'],
#  ['918', 'Ca-ci-mi', 'Šašimi[]PN'],
#  ['919', 'Ca-ci-nu-NI', 'Šašinuni[]PN', 'uncertain'],
#  ['920', 'Ca-ga-na-kum', 'Šaganakum[]PN', 'uncertain (Mr. Šakkanakkum?)'],
#  ['921',
#   'Ca-gu-ul-tum',
#   'not PN',
#   "šūkultu 'banquet'; SACT 1 132 o 5 (copy/photo)"],
#  ['922', 'Ca-hu-a-an{ki}-ce3', 'Šahuʾan[]SN'],
#  ['923', 'Ca-la-a', 'Šala[]PN', 'or, Šalaʾa/Šalaya?'],
#  ['924', 'Ca-lim-a-hu-um', 'Šalimahum[]PN'],
#  ['925', 'Ca-lim-be-li2', 'Šalimbeli[]PN'],
#  ['926', 'Ca-lim-be-li2-ta', 'Šalimbeli[]PN'],
#  ['927', 'Ca-lim-me2', 'Šalime[]PN'],
#  ['928', 'Ca-lim-ni-ac', 'Šalimniʾaš[]PN'],
#  ['929', 'Ca-lu', 'Šalu[]PN', '< Harši'],
#  ['930', 'Ca-mi-du-um', 'Šamidum[]PN'],
#  ['931', 'Ca-mi{ki}', 'Šami[]SN'],
#  ['932', 'Ca-na-ti-in', 'Šanatin[]PN'],
#  ['933', 'Ca-ri-it-hu-um{ki}', 'Šarithum[]SN'],
#  ['934', 'Ca-ru-mi-um', 'not PN', 'type of sheep'],
#  ['935', 'Ca-ru-um-ba-ni', 'Šarrumbani[]PN'],
#  ['936', 'Ca-ru-um-mi-um', 'not PN', 'type of sheep'],
#  ['937', 'Ca-zi-bi2{ki}-ka-ce3', 'Šazibi[]SN'],
#  ['938', 'Ca-zi-bi{ki}', 'Šazibi[]SN'],
#  ['939', 'Ca3', 'not PN', 'in/from/of, etc.'],
#  ['940',
#   'Ca3-ba-na-sig',
#   'Šagbanasig[]PN',
#   'some ambiguity between GAR & SIG'],
#  ['941', 'Ca3-bi', 'Šagbi[]PN'],
#  ['942', 'Ca3-bi-ta', 'not PN', 'therefrom'],
#  ['943', 'Ca3-da-an', 'Šadan[]PN', 'Libbudan?'],
#  ['944',
#   'Ca3-da-nu-car',
#   'Ša₃.da.nu.SAR[]PN',
#   '10 Umma, 2 PD, 1 unkn citations; = Ša3-da-nu-šar2? (28 citations; Umma/Girsu, 1 Nippur)'],
#  ['945', 'Ca3-da-nu-car-me', 'Ša₃.da.nu.SAR[]PN'],
#  ['946',
#   'Ca3-da-zi',
#   'Šagdazid[]PN',
#   'uncertain; BIN 3 270 seal 1 (copy/photo)'],
#  ['947', 'Ca3-dingir-ra-ka', 'Šagdiŋirak[]PN'],
#  ['948', 'Ca3-ga-na', 'Šagana[]PN', 'Šaganak? (probly female PN)'],
#  ['949',
#   'Ca3-ga-na-kum',
#   'Šaganakum[]PN',
#   'uncertain (Mr. Šakkanakkum?); 21 citations (all PD)'],
#  ['950',
#   'Ca3-ga-na-tum2',
#   'Šaganakum[]PN',
#   'TCL 2 5504 o 3 (DU in copy; GUM in photo)'],
#  ['951', 'Ca3-ge', 'Šage[]PN', 'hypo?'],
#  ['952', 'Ca3-ge-pa3-da', 'Šagepada[]PN'],
#  ['953', 'Ca3-gu2-bi', 'Šaggubi[]PN'],
#  ['954', 'Ca3-hul2-la', 'Šaghula[]PN'],
#  ['955', 'Ca3-kal-la', 'Šagkala[]PN'],
#  ['956', 'Ca3-ku3-ge', 'Šagkuge[]PN', 'hypo?'],
#  ['957', 'Ca3-ta-ku3-zu', 'Šagtakugzu[]PN'],
#  ['958', 'Ca3-ta-sa6-ga', 'Šagtasaga[]PN'],
#  ['959',
#   'Ca3-{d}Ba-u2',
#   'ŠagBaʾuk[]PN',
#   "uncertain (ŠagBaʾu 'Baʾu is the inner'?); Nisaba 24 25 r i 25 (no copy/photo)"],
#  ['960', 'Cakan3-ce-er', 'Šakanšer[]PN'],
#  ['961', 'Cal-le', 'Šale[]PN'],
#  ['962',
#   'Cal-mah',
#   'Šalmahŋu[]PN',
#   'SAT 3 1914 r 10: 1 udu Šal-mah/-ŋu₁₀ (read muhaldim; no photo/copy)'],
#  ['963', 'Cal-mah-mu-ta', 'Šalmahŋu[]PN'],
#  ['964', 'Car-na-AN', 'SAR.na.AN[]PN', 'Martu; BIN 3 546 o 7 (copy)'],
#  ['965',
#   'Car-na-ac',
#   'SAR.na.AŠ[]PN',
#   'Martu; PDT 2 0915 r 5 (no copy/photo)'],
#  ['966', 'Car-ra-a', 'Šarra[]PN', 'or, Šarraʾa/Šarraya?'],
#  ['967', 'Car-ru-KAL', 'Šarrumdan[]PN'],
#  ['968', 'Car-ru-SIPA-i3-li2', 'Šarrumreʾiʾili[]PN'],
#  ['969', 'Car-ru-ba-ni', 'Šarrumbani[]PN'],
#  ['970', 'Car-ru-i3-li2', 'Šarrumili[]PN'],
#  ['971', 'Car-ru-i3-li2-ka', 'Šarrumili[]PN'],
#  ['972', 'Car-ru-mi-um', 'not PN', 'type of sheep'],
#  ['973', 'Car-ru-um-ba-ni', 'Šarrumbani[]PN'],
#  ['974', 'Car-ru-um-ba-ni-ce3', 'Šarrumbani[]PN'],
#  ['975',
#   'Car-ru-um-dam',
#   'Šar.ru.um.X[]PN',
#   'uncertain; Ebay WWW20050526-01 o 1: ŋiri3? x-x-PI / u3 Šar-ru-um-DAM?/SIKIL? (photo)'],
#  ['976', 'Car-ru-um-i3-li2', 'Šarrumili[]PN'],
#  ['977', 'Car-ru-um-i3-li2-ta', 'Šarrumili[]PN'],
#  ['978', 'Car-um-i3-li2', 'Šarrumili[]PN'],
#  ['979',
#   'Ce-da-ak-gu2-gu2',
#   'Šedagugu[]PN',
#   'uncertain; = CTMMA 1 17 (AS 04) r iv 92: Še-da-ku-ku lu2 Ma-ri2{ki}?'],
#  ['980',
#   'Ce-da-ku-ku',
#   'Šedagugu[]PN',
#   'uncertain; = TCL 2 5500 (AS 05) r i 5: Še-da-ag-gu2-gu lu2 Ma-hi-li{ki}?'],
#  ['981', 'Ce-du3', 'Šedu[]PN'],
#  ['982', 'Ce-eb-ba', 'Šebba[]PN', '< Buli'],
#  ['983', 'Ce-eh-la-am', 'Šehlam[]PN'],
#  ['984', 'Ce-el-ha-ha', 'Šelhaha[]PN'],
#  ['985', 'Ce-en-nam', 'Šennam[]PN'],
#  ['986', 'Ce-er-ha-an', 'Šerhan[]PN', '= Šerhanum?'],
#  ['987', 'Ce-er-ha-num2', 'Šerhanum[]PN', '= Šerhan?'],
#  ['988', 'Ce-et-pa2-tal', 'Šetpatal[]PN', 'Hurrian'],
#  ['989', 'Ce-il-ha', 'Šelha[]PN', '= Šelhaha?'],
#  ['990', 'Ce-il-ha-ha', 'Šelhaha[]PN'],
#  ['991', 'Ce-ku-bu{ki}', 'Šekubu[]SN'],
#  ['992', 'Ce-le-bu-tum', 'Šelebutum[]PN'],
#  ['993', 'Ce-le-bu-tum-ce3', 'Šelebutum[]PN'],
#  ['994', 'Ce-le-bu-tum-ma-ce3', 'Šelebutum[]PN'],
#  ['995', 'Ce-le-bu-um', 'Šelebum[]PN'],
#  ['996', 'Ce-le-bu-um-ta', 'Šelebum[]PN'],
#  ['997', 'Ce-le-eb', 'Šeleb[]PN', '= Šelebum?'],
#  ['998', 'Ce-li-bu-ma', 'Šelebum[]PN'],
#  ['999', 'Ce-ra-zu', 'Šerazu[]PN'],
#  ...]

# %%
cols = ["index", "translit_bdtns", "cf_oracc", "notes"]
na_df = pd.DataFrame(y, columns = cols).fillna("")

# %%
na_df = na_df.drop(["index"], axis=1)
na_df
# Out:
#                  translit_bdtns            cf_oracc  \
# 0                    A-AN-ba-az      A.AN.ba.az[]PN
# 1                       A-KU-um         A.KU.um[]PN
# 2                    A-KU.KU-ta         A.KU.KU[]PN
# 3                       A-NI-ta            A.NI[]PN
# 4                A-U.E2-nu-tuku  A.U.E₂.nu.tuku[]PN
# 5                          A-a-                unkn
# 6                      A-a-bad3          Ayabad[]PN
# 7                       A-a-ce3             Aya[]PN
# 8                    A-a-dingir        Ayadiŋir[]PN
# 9                 A-a-dingir-mu      Ayadiŋirŋu[]PN
# 10             A-a-dingir-mu-ta      Ayadiŋirŋu[]PN
# 11                A-a-dingir-ta        Ayadiŋir[]PN
# 12                   A-a-i3-li2         Abuʾili[]PN
# 13                A-a-i3-li2-cu       Abuʾilišu[]PN
# 14                   A-a-kal-la         Ayakala[]PN
# 15                A-a-kal-la-mu       Ayakalaŋu[]PN
# 16                A-a-kal-la-ta         Ayakala[]PN
# 17                       A-a-ma           Ayama[]PN
# 18                       A-a-mu           Ayaŋu[]PN
# 19                   A-a-mu-ce3           Ayaŋu[]PN
# 20                   A-a-mu-dah        Ayaŋutah[]PN
# 21                    A-a-mu-ta           Ayaŋu[]PN
# 22                       A-a-ni           Ayani[]PN
# 23               A-a-ri2-mu-ce3         Ayariŋu[]PN
# 24                       A-a-ti           Ayati[]PN
# 25               A-a-u4-su3-ce3     Ayaʾudsudše[]PN
# 26                   A-a-ur-sag       Ayaʾursaŋ[]PN
# 27       A-a-{d}Nanna-ar-kal-la   AyaNannarkala[]PN
# 28                      A-ab-ba            Abba[]PN
# 29                    A-ab-ba-a            Abba[]PN
# ...                         ...                 ...
# 6046        {d}cul-gi-uru-mu-ta     Šulgiririŋu[]PN
# 6047      {d}cul-gi-{d}Lamma-mu  ŠulgirLammarŋu[]PN
# 6048               {d}cul-pa-e3         Šulpaʾe[]DN
# 6049                  {d}da-gan           Dagan[]DN
# 6050                   {d}en-ki           Enkik[]DN
# 6051                 {d}en-lil2           Enlil[]DN
# 6052             {d}en-lil2-la2           Enlil[]DN
# 6053          {d}en-lil2-la2-ta           Enlil[]DN
# 6054     {d}en-lil2-zi-ca3-gal2    Enlilzišaŋal[]PN
# 6055  {d}en-lil2-zi-ca3-gal2-ta    Enlilzišaŋal[]PN
# 6056                   {d}gu-la            Gula[]DN
# 6057                   {d}gu-za            Guza[]DN
# 6058        {d}gu-za-{d}En-lil2            Guza[]DN
# 6059           {d}i-bi2-{d}Suen       IbbiSuʾen[]RN
# 6060               {d}i7-Idigna          Idigna[]DN
# 6061        {d}i7-lu2-ru-gu2-ta        Idlurugu[]DN
# 6062                   {d}ickur           Iškur[]DN
# 6063                  {d}inanna          Inanak[]DN
# 6064                {d}na-du3-a          Naruʾa[]DN
# 6065                {d}nin-a-zu          Ninazu[]DN
# 6066               {d}nin-cubur      Ninšuburak[]DN
# 6067             {d}nin-hur-sag     Ninhursaŋak[]DN
# 6068                {d}nin-lil2          Ninlil[]DN
# 6069            {d}nin-lil2-la2          Ninlil[]DN
# 6070             {d}nin-lil2-ra          Ninlil[]DN
# 6071                {d}nin-sun2      Ninsumunak[]DN
# 6072          {d}nin-tin-ug5-ga       Nintiluga[]DN
# 6073                {d}nin-urta         Ninurta[]DN
# 6074                     {d}utu             Utu[]DN
# 6075              {d}utu-bar-ra         Utubara[]DN
#
#                                                  notes
# 0                         MVN 13 464 r 10 (copy/photo)
# 1                       Aegyptus 10, 270 27 o 7 (copy)
# 2                           AnOr 12 277 o i 17' (copy)
# 3                        Babyl. 7 pl. 22 18 o 3 (copy)
# 4     AnOr 07 150 o 2: A-U.KID-nu-tuku IŠ (copy/photo)
# 5                                   5654 possibilities
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# 13                               uncertain (Ayailišu?)
# 14
# 15
# 16
# 17                                               hypo?
# 18
# 19
# 20
# 21
# 22                                           = Ayanum?
# 23
# 24                                           = Ayatum?
# 25
# 26
# 27
# 28
# 29
# ...                                                ...
# 6046
# 6047
# 6048
# 6049
# 6050
# 6051
# 6052
# 6053
# 6054
# 6055
# 6056
# 6057
# 6058    part of AS 03, 04 year-name (346 PD citations)
# 6059
# 6060                                           or, WN?
# 6061
# 6062
# 6063
# 6064
# 6065
# 6066
# 6067
# 6068
# 6069
# 6070
# 6071
# 6072
# 6073
# 6074
# 6075
#
# [6076 rows x 3 columns]

# %% [markdown]
# Some data cleaning

# %%
na_df = na_df.loc[~(na_df["cf_oracc"] == "unkn")]
na_df = na_df.loc[~(na_df.cf_oracc.str.contains("not PN"))]

# %%
replace = {"c": "š" , "C" : "Š", "t," : "ṭ", "T," : "Ṭ", "s," : "ṣ", "S," : "Ṣ", "1" : "₁", "2" :  "₂", "3": "₃", "4" : "₄", "5": "₅", 
              "6" : "₆", "7" : "₇", "8" :  "₈", "9" : "₉", "0" : "₀", "x" : "×"}
na_df = na_df.replace({"translit_bdtns" : replace}, regex=True)

# %% [markdown]
# # Create signs and sign_names column.

# %%
separators = ['{', '}', '-', '.', "+"]
def separate(e): 
    for s in separators: # split word into signs   
        e = e.replace(s, ' ').strip()
    return(e.lower().split())

# %%
na_df["signs"] = na_df["translit_bdtns"].apply(lambda x: separate(x))
na_df["sign_names"] = na_df["signs"].apply(lambda x: [d[s] if s in d else s for s in x])

# %%
na_df
# Out:
#                  translit_bdtns            cf_oracc  \
# 0                    A-AN-ba-az      A.AN.ba.az[]PN
# 1                       A-KU-um         A.KU.um[]PN
# 2                    A-KU.KU-ta         A.KU.KU[]PN
# 3                       A-NI-ta            A.NI[]PN
# 4                A-U.E₂-nu-tuku  A.U.E₂.nu.tuku[]PN
# 6                      A-a-bad₃          Ayabad[]PN
# 7                       A-a-še₃             Aya[]PN
# 8                    A-a-dingir        Ayadiŋir[]PN
# 9                 A-a-dingir-mu      Ayadiŋirŋu[]PN
# 10             A-a-dingir-mu-ta      Ayadiŋirŋu[]PN
# 11                A-a-dingir-ta        Ayadiŋir[]PN
# 12                   A-a-i₃-li₂         Abuʾili[]PN
# 13                A-a-i₃-li₂-šu       Abuʾilišu[]PN
# 14                   A-a-kal-la         Ayakala[]PN
# 15                A-a-kal-la-mu       Ayakalaŋu[]PN
# 16                A-a-kal-la-ta         Ayakala[]PN
# 17                       A-a-ma           Ayama[]PN
# 18                       A-a-mu           Ayaŋu[]PN
# 19                   A-a-mu-še₃           Ayaŋu[]PN
# 20                   A-a-mu-dah        Ayaŋutah[]PN
# 21                    A-a-mu-ta           Ayaŋu[]PN
# 22                       A-a-ni           Ayani[]PN
# 23               A-a-ri₂-mu-še₃         Ayariŋu[]PN
# 24                       A-a-ti           Ayati[]PN
# 25               A-a-u₄-su₃-še₃     Ayaʾudsudše[]PN
# 26                   A-a-ur-sag       Ayaʾursaŋ[]PN
# 27       A-a-{d}Nanna-ar-kal-la   AyaNannarkala[]PN
# 28                      A-ab-ba            Abba[]PN
# 29                    A-ab-ba-a            Abba[]PN
# 30                 A-ab-ba-a-ta            Abba[]PN
# ...                         ...                 ...
# 6046        {d}šul-gi-uru-mu-ta     Šulgiririŋu[]PN
# 6047      {d}šul-gi-{d}Lamma-mu  ŠulgirLammarŋu[]PN
# 6048               {d}šul-pa-e₃         Šulpaʾe[]DN
# 6049                  {d}da-gan           Dagan[]DN
# 6050                   {d}en-ki           Enkik[]DN
# 6051                 {d}en-lil₂           Enlil[]DN
# 6052             {d}en-lil₂-la₂           Enlil[]DN
# 6053          {d}en-lil₂-la₂-ta           Enlil[]DN
# 6054     {d}en-lil₂-zi-ša₃-gal₂    Enlilzišaŋal[]PN
# 6055  {d}en-lil₂-zi-ša₃-gal₂-ta    Enlilzišaŋal[]PN
# 6056                   {d}gu-la            Gula[]DN
# 6057                   {d}gu-za            Guza[]DN
# 6058        {d}gu-za-{d}En-lil₂            Guza[]DN
# 6059           {d}i-bi₂-{d}Suen       IbbiSuʾen[]RN
# 6060               {d}i₇-Idigna          Idigna[]DN
# 6061        {d}i₇-lu₂-ru-gu₂-ta        Idlurugu[]DN
# 6062                   {d}iškur           Iškur[]DN
# 6063                  {d}inanna          Inanak[]DN
# 6064                {d}na-du₃-a          Naruʾa[]DN
# 6065                {d}nin-a-zu          Ninazu[]DN
# 6066               {d}nin-šubur      Ninšuburak[]DN
# 6067             {d}nin-hur-sag     Ninhursaŋak[]DN
# 6068                {d}nin-lil₂          Ninlil[]DN
# 6069            {d}nin-lil₂-la₂          Ninlil[]DN
# 6070             {d}nin-lil₂-ra          Ninlil[]DN
# 6071                {d}nin-sun₂      Ninsumunak[]DN
# 6072          {d}nin-tin-ug₅-ga       Nintiluga[]DN
# 6073                {d}nin-urta         Ninurta[]DN
# 6074                     {d}utu             Utu[]DN
# 6075              {d}utu-bar-ra         Utubara[]DN
#
#                                                  notes  \
# 0                         MVN 13 464 r 10 (copy/photo)
# 1                       Aegyptus 10, 270 27 o 7 (copy)
# 2                           AnOr 12 277 o i 17' (copy)
# 3                        Babyl. 7 pl. 22 18 o 3 (copy)
# 4     AnOr 07 150 o 2: A-U.KID-nu-tuku IŠ (copy/photo)
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# 13                               uncertain (Ayailišu?)
# 14
# 15
# 16
# 17                                               hypo?
# 18
# 19
# 20
# 21
# 22                                           = Ayanum?
# 23
# 24                                           = Ayatum?
# 25
# 26
# 27
# 28
# 29
# 30
# ...                                                ...
# 6046
# 6047
# 6048
# 6049
# 6050
# 6051
# 6052
# 6053
# 6054
# 6055
# 6056
# 6057
# 6058    part of AS 03, 04 year-name (346 PD citations)
# 6059
# 6060                                           or, WN?
# 6061
# 6062
# 6063
# 6064
# 6065
# 6066
# 6067
# 6068
# 6069
# 6070
# 6071
# 6072
# 6073
# 6074
# 6075
#
#                                  signs  \
# 0                      [a, an, ba, az]
# 1                          [a, ku, um]
# 2                      [a, ku, ku, ta]
# 3                          [a, ni, ta]
# 4                 [a, u, e₂, nu, tuku]
# 6                         [a, a, bad₃]
# 7                          [a, a, še₃]
# 8                       [a, a, dingir]
# 9                   [a, a, dingir, mu]
# 10              [a, a, dingir, mu, ta]
# 11                  [a, a, dingir, ta]
# 12                     [a, a, i₃, li₂]
# 13                 [a, a, i₃, li₂, šu]
# 14                     [a, a, kal, la]
# 15                 [a, a, kal, la, mu]
# 16                 [a, a, kal, la, ta]
# 17                          [a, a, ma]
# 18                          [a, a, mu]
# 19                     [a, a, mu, še₃]
# 20                     [a, a, mu, dah]
# 21                      [a, a, mu, ta]
# 22                          [a, a, ni]
# 23                [a, a, ri₂, mu, še₃]
# 24                          [a, a, ti]
# 25                [a, a, u₄, su₃, še₃]
# 26                     [a, a, ur, sag]
# 27       [a, a, d, nanna, ar, kal, la]
# 28                         [a, ab, ba]
# 29                      [a, ab, ba, a]
# 30                  [a, ab, ba, a, ta]
# ...                                ...
# 6046         [d, šul, gi, uru, mu, ta]
# 6047        [d, šul, gi, d, lamma, mu]
# 6048                  [d, šul, pa, e₃]
# 6049                      [d, da, gan]
# 6050                       [d, en, ki]
# 6051                     [d, en, lil₂]
# 6052                [d, en, lil₂, la₂]
# 6053            [d, en, lil₂, la₂, ta]
# 6054      [d, en, lil₂, zi, ša₃, gal₂]
# 6055  [d, en, lil₂, zi, ša₃, gal₂, ta]
# 6056                       [d, gu, la]
# 6057                       [d, gu, za]
# 6058          [d, gu, za, d, en, lil₂]
# 6059              [d, i, bi₂, d, suen]
# 6060                   [d, i₇, idigna]
# 6061         [d, i₇, lu₂, ru, gu₂, ta]
# 6062                        [d, iškur]
# 6063                       [d, inanna]
# 6064                   [d, na, du₃, a]
# 6065                   [d, nin, a, zu]
# 6066                   [d, nin, šubur]
# 6067                [d, nin, hur, sag]
# 6068                    [d, nin, lil₂]
# 6069               [d, nin, lil₂, la₂]
# 6070                [d, nin, lil₂, ra]
# 6071                    [d, nin, sun₂]
# 6072            [d, nin, tin, ug₅, ga]
# 6073                    [d, nin, urta]
# 6074                          [d, utu]
# 6075                 [d, utu, bar, ra]
#
#                                    sign_names
# 0                     [A, AN, BA, |PIRIG×ZA|]
# 1                                 [A, KU, UM]
# 2                             [A, KU, KU, TA]
# 3                                 [A, NI, TA]
# 4                         [A, U, E₂, NU, TUK]
# 6                          [A, A, |EZEN×BAD|]
# 7                                 [A, A, EŠ₂]
# 8                                  [A, A, AN]
# 9                              [A, A, AN, MU]
# 10                         [A, A, AN, MU, TA]
# 11                             [A, A, AN, TA]
# 12                             [A, A, NI, NI]
# 13                         [A, A, NI, NI, ŠU]
# 14                            [A, A, KAL, LA]
# 15                        [A, A, KAL, LA, MU]
# 16                        [A, A, KAL, LA, TA]
# 17                                 [A, A, MA]
# 18                                 [A, A, MU]
# 19                            [A, A, MU, EŠ₂]
# 20                        [A, A, MU, |MU&MU|]
# 21                             [A, A, MU, TA]
# 22                                 [A, A, NI]
# 23                       [A, A, URU, MU, EŠ₂]
# 24                                 [A, A, TI]
# 25                       [A, A, UD, SUD, EŠ₂]
# 26                            [A, A, UR, SAG]
# 27    [A, A, AN, |ŠEŠ.KI|, |IGI.RI|, KAL, LA]
# 28                                [A, AB, BA]
# 29                             [A, AB, BA, A]
# 30                         [A, AB, BA, A, TA]
# ...                                       ...
# 6046               [AN, DUN, GI, URU, MU, TA]
# 6047               [AN, DUN, GI, AN, KAL, MU]
# 6048                   [AN, DUN, PA, |UD.DU|]
# 6049                            [AN, DA, GAN]
# 6050                             [AN, EN, KI]
# 6051                            [AN, EN, KID]
# 6052                       [AN, EN, KID, LAL]
# 6053                   [AN, EN, KID, LAL, TA]
# 6054               [AN, EN, KID, ZI, ŠA₃, IG]
# 6055           [AN, EN, KID, ZI, ŠA₃, IG, TA]
# 6056                             [AN, GU, LA]
# 6057                             [AN, GU, ZA]
# 6058                [AN, GU, ZA, AN, EN, KID]
# 6059                 [AN, I, NE, AN, |EN.ZU|]
# 6060          [AN, |A.LAGAB×HAL|, |GU₂.GAR₃|]
# 6061    [AN, |A.LAGAB×HAL|, LU₂, RU, GU₂, TA]
# 6062                                 [AN, IM]
# 6063                               [AN, MUŠ₃]
# 6064                         [AN, NA, KAK, A]
# 6065                  [AN, |SAL.TUG₂|, A, ZU]
# 6066                  [AN, |SAL.TUG₂|, ŠUBUR]
# 6067          [AN, |SAL.TUG₂|, |HI×AŠ₂|, SAG]
# 6068                    [AN, |SAL.TUG₂|, KID]
# 6069               [AN, |SAL.TUG₂|, KID, LAL]
# 6070                [AN, |SAL.TUG₂|, KID, RA]
# 6071                    [AN, |SAL.TUG₂|, GUL]
# 6072    [AN, |SAL.TUG₂|, DIN, |EZEN×BAD|, GA]
# 6073                     [AN, |SAL.TUG₂|, IB]
# 6074                                 [AN, UD]
# 6075                        [AN, UD, BAR, RA]
#
# [5743 rows x 5 columns]

# %%
with open("name_authority/Drehem_na.json", "w", encoding = "utf-8")  as j: 
    na_df.to_json(j, force_ascii=False, orient="table", index=False)

# %%
import json
with open("name_authority/Drehem_na.json", "r", encoding = "utf-8")  as j: 
    n = json.load(j)

# %%
n["authors"] = "Niek Veldhuis and John Carnahan"

# %%
n["license"] = "CC0; https://creativecommons.org/share-your-work/public-domain/cc0/; Open Domain"

# %%
n["website"] = "https://github.com/niekveldhuis/UrIII-names"

# %%
n["notes"] = "Based on the BDTNS (http://bdtns.filol.csic.es/) dataset, December 2016. Proper nouns in BDTNS are marked by initial capital. Proper nouns were extracted and normalized with a script, authored by Niek Veldhuis (https://github.com/niekveldhuis/UrIII-names). Drehem proper nouns were checked and hand-edited by John Carnahan."

# %%
with open("name_authority/Drehem_na2.json", "w", encoding = "utf-8") as j: 
    json.dump(n, j, ensure_ascii=False, sort_keys=True, indent=4, separators=(',', ': '))
