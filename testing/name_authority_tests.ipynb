# %% [markdown]
# # Test using OGSL to use Name Authority in ORACC
# The Drehem name authority was made by extracting names from [BDTNS](http://bdtns.filol.csic.es/). Using this name authority for the Ur III data set in [ePSD2](http://oracc.org/epsd2/admin/u3adm/pager) runs into the problem of (slightly) different transliteration conventions. For instance, where [BDTNS](http://bdtns.filol.csic.es/) writes "uru", the [ePSD2](http://oracc.org/epsd2/admin/u3adm/pager) transliterations (which derives from [CDLI](http://cdli.ucla.edu)) have "iri".
#
# Similarly, transliteration of names in [CDLI](http://cdli.ucla.edu) (and therefore in [ePSD2](http://oracc.org/epsd2/admin/u3adm/pager)) is often inconsistent. **FIND GOOD EXAMPLE**
#
# The name instances found in the Ur III corpus, therefore, are reduced to sequences of sign names, which may be compared to sequences of sign names in the name authority.

# %% [markdown]
# First parse the [OGSL](http://oracc.org/ogsl) database with the notebook 1-parse_ogsl.ipynb. This results in a DataFrame that is pickled as "output/ogsl.p".

# %%
import pandas as pd
import pickle
import re
from collections import OrderedDict
import datetime
import json

# %%
with open("output/ogsl.p", "rb") as p:
    ogsl_df = pd.read_pickle(p)
ogsl_df
# Out:
#                                                      hex  \
# 0                                                 x12000
# 1                                                 x12000
# 2                                                 x12000
# 3                                                 x12000
# 4                                                 x12000
# 5                                                 x12000
# 6                                                 x12000
# 7                                                 x12000
# 8                                                 x12000
# 9                                                 x12000
# 10                                                x12000
# 11                                                x12000
# 12                                                x12000
# 13                                                x12000
# 14                                                x12000
# 15                                                x12000
# 16                                                x12000
# 17                                                x12000
# 18                                                x12000
# 19                                                x12000
# 20                                                x12000
# 21                                                x12000
# 22                                                x12000
# 23                                                x12000
# 24                                         x12000.x12000
# 25                                         x12000.x12000
# 26                                         x12000.x12000
# 27                                         x12000.x12000
# 28                                         x12000.x12000
# 29                                         x12000.x12000
# ...                                                  ...
# 10023
# 10024                               x12000.x12364.x121B8
# 10025                                      x1214E.x122DB
# 10026                                      x1207A.x121EF
# 10027                                      x1202D.x1230B
# 10028                                      x1214A.x1227D
# 10029
# 10030                               x12306.x1227F.x1227F
# 10031                        x12016.x1202D.x122C0.x121A0
# 10032                                      x1230B.x12263
# 10033
# 10034
# 10035                               x12246.x12097.x1223E
# 10036  x1202D.x12097.x12261.x1226D.x12246.x1202D.x122...
# 10037
# 10038
# 10039
# 10040
# 10041
# 10042
# 10043
# 10044
# 10045
# 10046
# 10047
# 10048
# 10049
# 10050
# 10051
# 10052
#
#                                  name      utf8     value
# 0                                   A         𒀀       ʾu₄
# 1                                   A         𒀀         a
# 2                                   A         𒀀      aia₂
# 3                                   A         𒀀      aya₂
# 4                                   A         𒀀      barₓ
# 5                                   A         𒀀    buniŋₓ
# 6                                   A         𒀀      burₓ
# 7                                   A         𒀀      dur₅
# 8                                   A         𒀀     duru₅
# 9                                   A         𒀀        e₄
# 10                                  A         𒀀        ea
# 11                                  A         𒀀     ebir₃
# 12                                  A         𒀀       emₓ
# 13                                  A         𒀀     epir₃
# 14                                  A         𒀀      eš₁₀
# 15                                  A         𒀀      ŋa₁₀
# 16                                  A         𒀀      ia₁₀
# 17                                  A         𒀀       id₅
# 18                                  A         𒀀       me₅
# 19                                  A         𒀀      mu₁₄
# 20                                  A         𒀀      sedₓ
# 21                                  A         𒀀      šegₓ
# 22                                  A         𒀀      ṭur₅
# 23                                  A         𒀀      ya₁₀
# 24                              |A.A|        𒀀𒀀        ai
# 25                              |A.A|        𒀀𒀀       aia
# 26                              |A.A|        𒀀𒀀       aya
# 27                              |A.A|        𒀀𒀀       aye
# 28                              |A.A|        𒀀𒀀       ayi
# 29                              |A.A|        𒀀𒀀       ayu
# ...                               ...       ...       ...
# 10023                     |ZUM×LAGAB|              garigₓ
# 10024                 |A.ZI&ZI.LAGAB|       𒀀𒍤𒆸     aškiₓ
# 10025                         |IM.SI|        𒅎𒋛    dunguₓ
# 10026                    |DU.LAGAR@g|        𒁺𒇯       edₓ
# 10027                          |AN.U|        𒀭𒌋       enₓ
# 10028                     |IGI@g.PAP|        𒅊𒉽     kumₓ?
# 10029                |NINDA₂×GI.IDIM|              gidimₓ
# 10030                    |TUG₂.PI.PI|       𒌆𒉿𒉿   ŋeštugₓ
# 10031                 |AB₂.AN.ŠEŠ.KI|      𒀖𒀭𒋀𒆠   munzerₓ
# 10032                     |U.GIŠ%GIŠ|        𒌋𒉣   šennurₓ
# 10033                   |UR₂×KID₂.SU|              umbinₓ
# 10034                          LAK212               asalₓ
# 10035                     |NAM.EN.NA|       𒉆𒂗𒈾     palaₓ
# 10036  |AN.EN.NU.NUNUZ.NAM.AN.ŠEŠ.KI|  𒀭𒂗𒉡𒉭𒉆𒀭𒋀𒆠    zirruₓ
# 10037                |KASKAL.LAGAB×X|             šubtumₓ
# 10038                     |SAL.U.DIŠ|               kušuₓ
# 10039                         |SAL.X|                emeₓ
# 10040                       |TAB&TAB|                limₓ
# 10041                       |TAB&TAB|              limmuₓ
# 10042                         |UR×ŠU|               šuziₓ
# 10043                    |SANGA₂.MAH|              dungaₓ
# 10044                         |PA.PA|             šullatₓ
# 10045            |ZA.MUŠ₃.AB×(U.U.U)|            zabalamₓ
# 10046                         |DU.KI|               alikₓ
# 10047                       |DU@s.KI|              lasimₓ
# 10048                       |BAN.GAM|              zugudₓ
# 10049                        |ŠE.DIM|               munuₓ
# 10050                        |GUD×UD|               guduₓ
# 10051                     |NINDA₂×GI|             giguruₓ
# 10052                         |KA×SI|              kurkuₓ
#
# [10053 rows x 4 columns]

# %% [markdown]
# Create a dictionary where the keys are sign values and the values sign names. The resulting dictionary can be used to transform a sign reading (such as "buru₁₄") into a sign name ("EN×KAR₂@g"), in the following way
#
# ```python
# d["buru₁₄"]
# ```

# %%
val = list(ogsl_df["value"])
names = list(ogsl_df["name"])
d = dict(zip(val,names))

# %%
#file = "name_authority/Drehem_name_authority.atf"
#with open(file, "r", encoding="utf-8") as f:
#    z = f.readlines()
#y = [re.sub(r"\t+", "\t", l).strip().split('\t') for l in z]  # replace multiple tabs by single tab and split on TAB
#del y[0]  # remove line with column names

# %%
cols = ["index", "translit_bdtns", "cf_oracc", "notes"]
#na_df = pd.DataFrame(y, columns = cols).fillna("")

# %%
file = "../../UrIII-names/output/UrIII-Names.csv"
with open(file, 'r', encoding = 'utf8') as f: 
    na_df = pd.read_csv(f, sep='\t')
na_df.columns = cols[:3]
na_df
# Out:
#        index          translit_bdtns               cf_oracc
# 0          0              A-AMA-a2-a         A.AMA.a₂.a[]PN
# 1          1              A-AN-ba-az         A.AN.ba.az[]PN
# 2          2        A-Ab-ba-ge-na-ta      A.Ab.ba.ge.na[]PN
# 3          3                 A-Ad-da            A.Ad.da[]PN
# 4          4          A-Ad-da-kal-la     A.Ad.da.kal.la[]PN
# 5          5              A-Ad-da-mu       A.Ad.da.ŋu₁₀[]PN
# 6          6        A-An-na-hi-li-bi   A.An.na.hi.li.bi[]PN
# 7          7                  A-DU-a             A.DU.a[]PN
# 8          8                 A-DU-ba            A.DU.ba[]PN
# 9          9              A-DU-ba-bi         A.DU.ba.bi[]PN
# 10        10             A-DU-gam-ma        A.DU.gam.ma[]PN
# 11        11             A-DU-la-URU        A.DU.la.URU[]PN
# 12        12                 A-DU-mu          A.DU.ŋu₁₀[]PN
# 13        13              A-DU-mu-ta          A.DU.ŋu₁₀[]PN
# 14        14              A-DU-ra-mu       A.DU.ra.ŋu₁₀[]PN
# 15        15                 A-DU-ta               A.DU[]PN
# 16        16               A-DU.DU-e          A.DU.DU.e[]PN
# 17        17             A-DU.DU-ke4            A.DU.DU[]PN
# 18        18              A-DU.DU-ta            A.DU.DU[]PN
# 19        19             A-DU.DU-še3            A.DU.DU[]PN
# 20        20              A-Eš4-tar2         A.Eš₄.tar₂[]PN
# 21        21             A-GU4-na-mu      A.GU₄.na.ŋu₁₀[]PN
# 22        22                  A-KA-a             A.KA.a[]PN
# 23        23                 A-KU-um            A.KU.um[]PN
# 24        24             A-KU.KU-lum        A.KU.KU.lum[]PN
# 25        25              A-KU.KU-ta            A.KU.KU[]PN
# 26        26                A-LUM-ma           A.LUM.ma[]PN
# 27        27              A-MUNU4-da         A.MUNU₄.da[]PN
# 28        28              A-NE-i3-zi         A.NE.i₃.zi[]PN
# 29        29              A-NE-ku-bi         A.NE.ku.bi[]PN
# ...      ...                     ...                    ...
# 32288  32288      Ṣi-lu-uš-{d}Da-gan         ṢilušDagan[]PN
# 32289  32289   Ṣi-lu-uš-{d}Da-gan-ka       ṢilušDaganka[]PN
# 32290  32290   Ṣi-lu-uš-{d}Da-gan-ta         ṢilušDagan[]PN
# 32291  32291  Ṣi-lu-uš-{d}Da-gan-še3         ṢilušDagan[]PN
# 32292  32292      Ṣi-lu-uš-{d}da-gan         ṢilušDagan[]PN
# 32293  32293   Ṣi-lu-uš-{d}da-gan-ta         ṢilušDagan[]PN
# 32294  32294      Ṣi-lu-uš-{d}Šul-gi         ṢilušŠulgi[]PN
# 32295  32295        Ṣi-tum3-{d}IŠKUR   Ṣi.tum₃.{d}IŠKUR[]PN
# 32296  32296         Ṣi2-il-{d}IŠKUR    Ṣi₂.il.{d}IŠKUR[]PN
# 32297  32297       Ṣi2-il-{d}IŠKUR-e  Ṣi₂.il.{d}IŠKUR.e[]PN
# 32298  32298                  Ṣi2-la               Ṣila[]PN
# 32299  32299               Ṣi2-la-šu             Ṣilašu[]PN
# 32300  32300            Ṣi2-la-šu-ka           Ṣilašuka[]PN
# 32301  32301                  Ṣi2-li               Ṣili[]PN
# 32302  32302         Ṣi2-li-{d}IŠKUR    Ṣi₂.li.{d}IŠKUR[]PN
# 32303  32303                Ṣi2-lu-a             Ṣiluʾa[]PN
# 32304  32304              Ṣil2-la-la             Ṣilala[]PN
# 32305  32305              Ṣil2-la-šu             Ṣilašu[]PN
# 32306  32306           Ṣil2-la-šu-ta             Ṣilašu[]PN
# 32307  32307         Ṣil2-li2-i3-li2             Ṣilili[]PN
# 32308  32308    Ṣil2-lu-uš-{d}Da-gan         ṢilušDagan[]PN
# 32309  32309         Ṣu-mi-id-DINGIR    Ṣu.mi.id.DINGIR[]PN
# 32310  32310               Ṣu2-hu-ti             Ṣuhuti[]PN
# 32311  32311               Ṣu2-la-la             Ṣulala[]PN
# 32312  32312               Ṣu2-mi-id              Ṣumid[]PN
# 32313  32313        Ṣu2-mi-id-DINGIR   Ṣu₂.mi.id.DINGIR[]PN
# 32314  32314        Ṣum-mi-id-DINGIR   Ṣum.mi.id.DINGIR[]PN
# 32315  32315         Ṭa-ab-{d}Šul-gi           ṬabŠulgi[]PN
# 32316  32316            Ṭa-bi2-Ma-ma       Ṭa.bi₂.Ma.ma[]PN
# 32317  32317                Ṭa-bu-um              Ṭabum[]PN
#
# [32318 rows x 3 columns]

# %%
na_df = na_df.drop(["index"], axis=1)
na_df
# Out:
#                translit_bdtns               cf_oracc
# 0                  A-AMA-a2-a         A.AMA.a₂.a[]PN
# 1                  A-AN-ba-az         A.AN.ba.az[]PN
# 2            A-Ab-ba-ge-na-ta      A.Ab.ba.ge.na[]PN
# 3                     A-Ad-da            A.Ad.da[]PN
# 4              A-Ad-da-kal-la     A.Ad.da.kal.la[]PN
# 5                  A-Ad-da-mu       A.Ad.da.ŋu₁₀[]PN
# 6            A-An-na-hi-li-bi   A.An.na.hi.li.bi[]PN
# 7                      A-DU-a             A.DU.a[]PN
# 8                     A-DU-ba            A.DU.ba[]PN
# 9                  A-DU-ba-bi         A.DU.ba.bi[]PN
# 10                A-DU-gam-ma        A.DU.gam.ma[]PN
# 11                A-DU-la-URU        A.DU.la.URU[]PN
# 12                    A-DU-mu          A.DU.ŋu₁₀[]PN
# 13                 A-DU-mu-ta          A.DU.ŋu₁₀[]PN
# 14                 A-DU-ra-mu       A.DU.ra.ŋu₁₀[]PN
# 15                    A-DU-ta               A.DU[]PN
# 16                  A-DU.DU-e          A.DU.DU.e[]PN
# 17                A-DU.DU-ke4            A.DU.DU[]PN
# 18                 A-DU.DU-ta            A.DU.DU[]PN
# 19                A-DU.DU-še3            A.DU.DU[]PN
# 20                 A-Eš4-tar2         A.Eš₄.tar₂[]PN
# 21                A-GU4-na-mu      A.GU₄.na.ŋu₁₀[]PN
# 22                     A-KA-a             A.KA.a[]PN
# 23                    A-KU-um            A.KU.um[]PN
# 24                A-KU.KU-lum        A.KU.KU.lum[]PN
# 25                 A-KU.KU-ta            A.KU.KU[]PN
# 26                   A-LUM-ma           A.LUM.ma[]PN
# 27                 A-MUNU4-da         A.MUNU₄.da[]PN
# 28                 A-NE-i3-zi         A.NE.i₃.zi[]PN
# 29                 A-NE-ku-bi         A.NE.ku.bi[]PN
# ...                       ...                    ...
# 32288      Ṣi-lu-uš-{d}Da-gan         ṢilušDagan[]PN
# 32289   Ṣi-lu-uš-{d}Da-gan-ka       ṢilušDaganka[]PN
# 32290   Ṣi-lu-uš-{d}Da-gan-ta         ṢilušDagan[]PN
# 32291  Ṣi-lu-uš-{d}Da-gan-še3         ṢilušDagan[]PN
# 32292      Ṣi-lu-uš-{d}da-gan         ṢilušDagan[]PN
# 32293   Ṣi-lu-uš-{d}da-gan-ta         ṢilušDagan[]PN
# 32294      Ṣi-lu-uš-{d}Šul-gi         ṢilušŠulgi[]PN
# 32295        Ṣi-tum3-{d}IŠKUR   Ṣi.tum₃.{d}IŠKUR[]PN
# 32296         Ṣi2-il-{d}IŠKUR    Ṣi₂.il.{d}IŠKUR[]PN
# 32297       Ṣi2-il-{d}IŠKUR-e  Ṣi₂.il.{d}IŠKUR.e[]PN
# 32298                  Ṣi2-la               Ṣila[]PN
# 32299               Ṣi2-la-šu             Ṣilašu[]PN
# 32300            Ṣi2-la-šu-ka           Ṣilašuka[]PN
# 32301                  Ṣi2-li               Ṣili[]PN
# 32302         Ṣi2-li-{d}IŠKUR    Ṣi₂.li.{d}IŠKUR[]PN
# 32303                Ṣi2-lu-a             Ṣiluʾa[]PN
# 32304              Ṣil2-la-la             Ṣilala[]PN
# 32305              Ṣil2-la-šu             Ṣilašu[]PN
# 32306           Ṣil2-la-šu-ta             Ṣilašu[]PN
# 32307         Ṣil2-li2-i3-li2             Ṣilili[]PN
# 32308    Ṣil2-lu-uš-{d}Da-gan         ṢilušDagan[]PN
# 32309         Ṣu-mi-id-DINGIR    Ṣu.mi.id.DINGIR[]PN
# 32310               Ṣu2-hu-ti             Ṣuhuti[]PN
# 32311               Ṣu2-la-la             Ṣulala[]PN
# 32312               Ṣu2-mi-id              Ṣumid[]PN
# 32313        Ṣu2-mi-id-DINGIR   Ṣu₂.mi.id.DINGIR[]PN
# 32314        Ṣum-mi-id-DINGIR   Ṣum.mi.id.DINGIR[]PN
# 32315         Ṭa-ab-{d}Šul-gi           ṬabŠulgi[]PN
# 32316            Ṭa-bi2-Ma-ma       Ṭa.bi₂.Ma.ma[]PN
# 32317                Ṭa-bu-um              Ṭabum[]PN
#
# [32318 rows x 2 columns]

# %% [markdown]
# # Some data cleaning
# Remove lines where the ORACC Citation Form has "unkn" or "not PN" and reset the index afterwards.

# %%
na_df = na_df.loc[~(na_df["cf_oracc"] == "unkn")]
na_df = na_df.loc[~(na_df.cf_oracc.str.contains("not PN"))]
na_df = na_df.reset_index(drop=True)

# %% [markdown]
# Deal with differences in transliteration conventions between BDTNS and CDLI/ORACC.

# %%
replace1 = {"([a-wy-zA-WY-Z])X" : "\\1ₓ"} 
replace2 = {"c": "š" , "C" : "Š", "ty" : "ṭ", "Ty" : "Ṭ", "sy" : "ṣ", "Sy" : "Ṣ", "1" : "₁", "2" :  "₂", "3": "₃", "4" : "₄", "5": "₅", 
              "6" : "₆", "7" : "₇", "8" :  "₈", "9" : "₉", "0" : "₀", "x" : "×", "nigarₓ" : "nigar", 
           "nemurₓ(|PIRIG.TUR|)" : "nemur₂", "nagₓ(GAZ)" : "naŋ₃" }
na_df = na_df.replace({"translit_bdtns" : replace1}, regex=True)
na_df = na_df.replace({"translit_bdtns" : replace2}, regex=True)

# %% [markdown]
# # Create signs and sign_names column.
# Split a word (name) into signs by replacing sign separators by blanks. All signs are lowercased and the string is split into a list.
#
# Use the dictionary `d`, created above, to find the sign name for each sign. Each form is now reduced to a list of sign names. The sign names are re-connected to strings (separated by hyphens), in order to make comparison easier.

# %%
def separate(e): 
    separators = ['{', '}', '-', '.', "+"]
    for s in separators: # split word into signs   
        e = e.replace(s, ' ').strip()
    return(e.lower().split())

# %%
na_df["signs"] = na_df["translit_bdtns"].apply(separate)
na_df["sign_names"] = na_df["signs"].apply(lambda x: "-".join([d[s] if s in d else s for s in x]))

# %%
na_df
# Out:
#                translit_bdtns               cf_oracc  \
# 0                  A-AMA-a₂-a         A.AMA.a₂.a[]PN
# 1                  A-AN-ba-az         A.AN.ba.az[]PN
# 2            A-Ab-ba-ge-na-ta      A.Ab.ba.ge.na[]PN
# 3                     A-Ad-da            A.Ad.da[]PN
# 4              A-Ad-da-kal-la     A.Ad.da.kal.la[]PN
# 5                  A-Ad-da-mu       A.Ad.da.ŋu₁₀[]PN
# 6            A-An-na-hi-li-bi   A.An.na.hi.li.bi[]PN
# 7                      A-DU-a             A.DU.a[]PN
# 8                     A-DU-ba            A.DU.ba[]PN
# 9                  A-DU-ba-bi         A.DU.ba.bi[]PN
# 10                A-DU-gam-ma        A.DU.gam.ma[]PN
# 11                A-DU-la-URU        A.DU.la.URU[]PN
# 12                    A-DU-mu          A.DU.ŋu₁₀[]PN
# 13                 A-DU-mu-ta          A.DU.ŋu₁₀[]PN
# 14                 A-DU-ra-mu       A.DU.ra.ŋu₁₀[]PN
# 15                    A-DU-ta               A.DU[]PN
# 16                  A-DU.DU-e          A.DU.DU.e[]PN
# 17                A-DU.DU-ke₄            A.DU.DU[]PN
# 18                 A-DU.DU-ta            A.DU.DU[]PN
# 19                A-DU.DU-še₃            A.DU.DU[]PN
# 20                 A-Eš₄-tar₂         A.Eš₄.tar₂[]PN
# 21                A-GU₄-na-mu      A.GU₄.na.ŋu₁₀[]PN
# 22                     A-KA-a             A.KA.a[]PN
# 23                    A-KU-um            A.KU.um[]PN
# 24                A-KU.KU-lum        A.KU.KU.lum[]PN
# 25                 A-KU.KU-ta            A.KU.KU[]PN
# 26                   A-LUM-ma           A.LUM.ma[]PN
# 27                 A-MUNU₄-da         A.MUNU₄.da[]PN
# 28                 A-NE-i₃-zi         A.NE.i₃.zi[]PN
# 29                 A-NE-ku-bi         A.NE.ku.bi[]PN
# ...                       ...                    ...
# 32288      Ṣi-lu-uš-{d}Da-gan         ṢilušDagan[]PN
# 32289   Ṣi-lu-uš-{d}Da-gan-ka       ṢilušDaganka[]PN
# 32290   Ṣi-lu-uš-{d}Da-gan-ta         ṢilušDagan[]PN
# 32291  Ṣi-lu-uš-{d}Da-gan-še₃         ṢilušDagan[]PN
# 32292      Ṣi-lu-uš-{d}da-gan         ṢilušDagan[]PN
# 32293   Ṣi-lu-uš-{d}da-gan-ta         ṢilušDagan[]PN
# 32294      Ṣi-lu-uš-{d}Šul-gi         ṢilušŠulgi[]PN
# 32295        Ṣi-tum₃-{d}IŠKUR   Ṣi.tum₃.{d}IŠKUR[]PN
# 32296         Ṣi₂-il-{d}IŠKUR    Ṣi₂.il.{d}IŠKUR[]PN
# 32297       Ṣi₂-il-{d}IŠKUR-e  Ṣi₂.il.{d}IŠKUR.e[]PN
# 32298                  Ṣi₂-la               Ṣila[]PN
# 32299               Ṣi₂-la-šu             Ṣilašu[]PN
# 32300            Ṣi₂-la-šu-ka           Ṣilašuka[]PN
# 32301                  Ṣi₂-li               Ṣili[]PN
# 32302         Ṣi₂-li-{d}IŠKUR    Ṣi₂.li.{d}IŠKUR[]PN
# 32303                Ṣi₂-lu-a             Ṣiluʾa[]PN
# 32304              Ṣil₂-la-la             Ṣilala[]PN
# 32305              Ṣil₂-la-šu             Ṣilašu[]PN
# 32306           Ṣil₂-la-šu-ta             Ṣilašu[]PN
# 32307         Ṣil₂-li₂-i₃-li₂             Ṣilili[]PN
# 32308    Ṣil₂-lu-uš-{d}Da-gan         ṢilušDagan[]PN
# 32309         Ṣu-mi-id-DINGIR    Ṣu.mi.id.DINGIR[]PN
# 32310               Ṣu₂-hu-ti             Ṣuhuti[]PN
# 32311               Ṣu₂-la-la             Ṣulala[]PN
# 32312               Ṣu₂-mi-id              Ṣumid[]PN
# 32313        Ṣu₂-mi-id-DINGIR   Ṣu₂.mi.id.DINGIR[]PN
# 32314        Ṣum-mi-id-DINGIR   Ṣum.mi.id.DINGIR[]PN
# 32315         Ṭa-ab-{d}Šul-gi           ṬabŠulgi[]PN
# 32316            Ṭa-bi₂-Ma-ma       Ṭa.bi₂.Ma.ma[]PN
# 32317                Ṭa-bu-um              Ṭabum[]PN
#
#                                signs               sign_names
# 0                    [a, ama, a₂, a]          A-|GA₂×AN|-A₂-A
# 1                    [a, an, ba, az]       A-AN-BA-|PIRIG×ZA|
# 2            [a, ab, ba, ge, na, ta]         A-AB-BA-GI-NA-TA
# 3                        [a, ad, da]                  A-AD-DA
# 4               [a, ad, da, kal, la]           A-AD-DA-KAL-LA
# 5                    [a, ad, da, mu]               A-AD-DA-MU
# 6            [a, an, na, hi, li, bi]         A-AN-NA-HI-LI-BI
# 7                         [a, du, a]                   A-DU-A
# 8                        [a, du, ba]                  A-DU-BA
# 9                    [a, du, ba, bi]               A-DU-BA-BI
# 10                  [a, du, gam, ma]              A-DU-GAM-MA
# 11                  [a, du, la, uru]              A-DU-LA-URU
# 12                       [a, du, mu]                  A-DU-MU
# 13                   [a, du, mu, ta]               A-DU-MU-TA
# 14                   [a, du, ra, mu]               A-DU-RA-MU
# 15                       [a, du, ta]                  A-DU-TA
# 16                    [a, du, du, e]                A-DU-DU-E
# 17                  [a, du, du, ke₄]              A-DU-DU-KID
# 18                   [a, du, du, ta]               A-DU-DU-TA
# 19                  [a, du, du, še₃]              A-DU-DU-EŠ₂
# 20                    [a, eš₄, tar₂]                A-DIŠ-DAR
# 21                  [a, gu₄, na, mu]              A-GUD-NA-MU
# 22                        [a, ka, a]                   A-KA-A
# 23                       [a, ku, um]                  A-KU-UM
# 24                  [a, ku, ku, lum]              A-KU-KU-LUM
# 25                   [a, ku, ku, ta]               A-KU-KU-TA
# 26                      [a, lum, ma]                 A-LUM-MA
# 27                    [a, munu₄, da]           A-|PAP.PAP|-DA
# 28                   [a, ne, i₃, zi]               A-NE-NI-ZI
# 29                   [a, ne, ku, bi]               A-NE-KU-BI
# ...                              ...                      ...
# 32288       [ṣi, lu, uš, d, da, gan]      ZE₂-LU-UŠ-AN-DA-GAN
# 32289   [ṣi, lu, uš, d, da, gan, ka]   ZE₂-LU-UŠ-AN-DA-GAN-KA
# 32290   [ṣi, lu, uš, d, da, gan, ta]   ZE₂-LU-UŠ-AN-DA-GAN-TA
# 32291  [ṣi, lu, uš, d, da, gan, še₃]  ZE₂-LU-UŠ-AN-DA-GAN-EŠ₂
# 32292       [ṣi, lu, uš, d, da, gan]      ZE₂-LU-UŠ-AN-DA-GAN
# 32293   [ṣi, lu, uš, d, da, gan, ta]   ZE₂-LU-UŠ-AN-DA-GAN-TA
# 32294       [ṣi, lu, uš, d, šul, gi]      ZE₂-LU-UŠ-AN-DUN-GI
# 32295           [ṣi, tum₃, d, iškur]   ZE₂-|NIM×GAN₂@t|-AN-IM
# 32296            [ṣi₂, il, d, iškur]              ZI-IL-AN-IM
# 32297         [ṣi₂, il, d, iškur, e]            ZI-IL-AN-IM-E
# 32298                      [ṣi₂, la]                    ZI-LA
# 32299                  [ṣi₂, la, šu]                 ZI-LA-ŠU
# 32300              [ṣi₂, la, šu, ka]              ZI-LA-ŠU-KA
# 32301                      [ṣi₂, li]                    ZI-LI
# 32302            [ṣi₂, li, d, iškur]              ZI-LI-AN-IM
# 32303                   [ṣi₂, lu, a]                  ZI-LU-A
# 32304                 [ṣil₂, la, la]                 MI-LA-LA
# 32305                 [ṣil₂, la, šu]                 MI-LA-ŠU
# 32306             [ṣil₂, la, šu, ta]              MI-LA-ŠU-TA
# 32307           [ṣil₂, li₂, i₃, li₂]              MI-NI-NI-NI
# 32308     [ṣil₂, lu, uš, d, da, gan]       MI-LU-UŠ-AN-DA-GAN
# 32309           [ṣu, mi, id, dingir]             ZUM-MI-A₂-AN
# 32310                  [ṣu₂, hu, ti]                 ZU-HU-TI
# 32311                  [ṣu₂, la, la]                 ZU-LA-LA
# 32312                  [ṣu₂, mi, id]                 ZU-MI-A₂
# 32313          [ṣu₂, mi, id, dingir]              ZU-MI-A₂-AN
# 32314          [ṣum, mi, id, dingir]             ZUM-MI-A₂-AN
# 32315           [ṭa, ab, d, šul, gi]          DA-AB-AN-DUN-GI
# 32316              [ṭa, bi₂, ma, ma]              DA-NE-MA-MA
# 32317                   [ṭa, bu, um]                 DA-BU-UM
#
# [32318 rows x 4 columns]

# %% [markdown]
# # Find Duplicates
# Duplicate sequences of sign names should result in the same reading in the column `cf_oracc`.

# %%
dups = na_df.loc[na_df.duplicated(["sign_names"], keep=False)]
dups = dups.reset_index()
dups
# Out:
#       index         translit_bdtns              cf_oracc  \
# 0         3                A-Ad-da           A.Ad.da[]PN
# 1         4         A-Ad-da-kal-la    A.Ad.da.kal.la[]PN
# 2         5             A-Ad-da-mu      A.Ad.da.ŋu₁₀[]PN
# 3         7                 A-DU-a            A.DU.a[]PN
# 4         8                A-DU-ba           A.DU.ba[]PN
# 5         9             A-DU-ba-bi        A.DU.ba.bi[]PN
# 6        12                A-DU-mu         A.DU.ŋu₁₀[]PN
# 7        13             A-DU-mu-ta         A.DU.ŋu₁₀[]PN
# 8        15                A-DU-ta              A.DU[]PN
# 9        18             A-DU.DU-ta           A.DU.DU[]PN
# 10       26               A-LUM-ma          A.LUM.ma[]PN
# 11       34                A-NI-ta              A.NI[]PN
# 12       39                    A-a               Aya[]PN
# 13       40                   A-a-               Aya[]PN
# 14       41             A-a-Kal-la        Aya.Kal.la[]PN
# 15       42                 A-a-NI            Aya.NI[]PN
# 16       70              A-a-gir₁₅            Ayagir[]PN
# 17       80             A-a-kal-la           Ayakala[]PN
# 18       81            A-a-kal-la-           Ayakala[]PN
# 19      106                 A-a-ni             Ayani[]PN
# 20      111             A-a-ri₂-in            Ayarin[]PN
# 21      118             A-a-uru-IN        Aya.iri.IN[]PN
# 22      127                A-a-še₃               Aya[]PN
# 23      167                A-ad-da              Aada[]PN
# 24      174         A-ad-da-kal-la          Aadakala[]PN
# 25      175             A-ad-da-mu            Aadaŋu[]PN
# 26      184                A-al-NI           A.al.NI[]PN
# 27      185             A-al-NI-ta           A.al.NI[]PN
# 28      199            A-al-li₂-ta              Aali[]PN
# 29      205                A-al-ni             Aalni[]PN
# ...     ...                    ...                   ...
# 4070  32160           Šu-{d}Tišpak          ŠuTišpak[]PN
# 4071  32161              Šu-{d}UTU         Šu.{d}UTU[]PN
# 4072  32167              Šu-{d}Utu             ŠuUtu[]PN
# 4073  32169         Šu-{d}eš₄-tar₂           ŠuEštar[]PN
# 4074  32176           Šu-{d}Šul-gi           ŠuŠulgi[]PN
# 4075  32178       Šu-Šu-mu-dar-še₃      Šu.Šu.mu.dar[]PN
# 4076  32191       Šu-šu-mu-dar-še₃         Šušumudar[]PN
# 4077  32235            Šu{d}Šul-gi           ŠuŠulgi[]PN
# 4078  32246           Šušin{ki}-ta             Šušin[]SN
# 4079  32252            Šušin{ki}ta           Šušinta[]SN
# 4080  32253               ṢI-lu-um          ṢI.lu.um[]PN
# 4081  32254              Ṣa-al-lum             Ṣalum[]PN
# 4082  32271              Ṣi-la₂-šu            Ṣilašu[]PN
# 4083  32272                  Ṣi-li              Ṣili[]PN
# 4084  32276        Ṣi-li₂-{d}IŠKUR   Ṣi.li₂.{d}IŠKUR[]PN
# 4085  32277        Ṣi-li₂-{d}IšKUR   Ṣi.li₂.{d}IšKUR[]PN
# 4086  32281               Ṣi-lu-um             Ṣilum[]PN
# 4087  32288     Ṣi-lu-uš-{d}Da-gan        ṢilušDagan[]PN
# 4088  32290  Ṣi-lu-uš-{d}Da-gan-ta        ṢilušDagan[]PN
# 4089  32292     Ṣi-lu-uš-{d}da-gan        ṢilušDagan[]PN
# 4090  32293  Ṣi-lu-uš-{d}da-gan-ta        ṢilušDagan[]PN
# 4091  32301                 Ṣi₂-li              Ṣili[]PN
# 4092  32303               Ṣi₂-lu-a            Ṣiluʾa[]PN
# 4093  32309        Ṣu-mi-id-DINGIR   Ṣu.mi.id.DINGIR[]PN
# 4094  32310              Ṣu₂-hu-ti            Ṣuhuti[]PN
# 4095  32311              Ṣu₂-la-la            Ṣulala[]PN
# 4096  32313       Ṣu₂-mi-id-DINGIR  Ṣu₂.mi.id.DINGIR[]PN
# 4097  32314       Ṣum-mi-id-DINGIR  Ṣum.mi.id.DINGIR[]PN
# 4098  32316           Ṭa-bi₂-Ma-ma      Ṭa.bi₂.Ma.ma[]PN
# 4099  32317               Ṭa-bu-um             Ṭabum[]PN
#
#                              signs              sign_names
# 0                      [a, ad, da]                 A-AD-DA
# 1             [a, ad, da, kal, la]          A-AD-DA-KAL-LA
# 2                  [a, ad, da, mu]              A-AD-DA-MU
# 3                       [a, du, a]                  A-DU-A
# 4                      [a, du, ba]                 A-DU-BA
# 5                  [a, du, ba, bi]              A-DU-BA-BI
# 6                      [a, du, mu]                 A-DU-MU
# 7                  [a, du, mu, ta]              A-DU-MU-TA
# 8                      [a, du, ta]                 A-DU-TA
# 9                  [a, du, du, ta]              A-DU-DU-TA
# 10                    [a, lum, ma]                A-LUM-MA
# 11                     [a, ni, ta]                 A-NI-TA
# 12                          [a, a]                     A-A
# 13                          [a, a]                     A-A
# 14                 [a, a, kal, la]              A-A-KAL-LA
# 15                      [a, a, ni]                  A-A-NI
# 16                   [a, a, gir₁₅]                 A-A-EŠ₂
# 17                 [a, a, kal, la]              A-A-KAL-LA
# 18                 [a, a, kal, la]              A-A-KAL-LA
# 19                      [a, a, ni]                  A-A-NI
# 20                 [a, a, ri₂, in]              A-A-URU-IN
# 21                 [a, a, uru, in]              A-A-URU-IN
# 22                     [a, a, še₃]                 A-A-EŠ₂
# 23                     [a, ad, da]                 A-AD-DA
# 24            [a, ad, da, kal, la]          A-AD-DA-KAL-LA
# 25                 [a, ad, da, mu]              A-AD-DA-MU
# 26                     [a, al, ni]                 A-AL-NI
# 27                 [a, al, ni, ta]              A-AL-NI-TA
# 28                [a, al, li₂, ta]              A-AL-NI-TA
# 29                     [a, al, ni]                 A-AL-NI
# ...                            ...                     ...
# 4070               [šu, d, tišpak]            ŠU-AN-MUŠ₃@g
# 4071                  [šu, d, utu]                ŠU-AN-UD
# 4072                  [šu, d, utu]                ŠU-AN-UD
# 4073            [šu, d, eš₄, tar₂]           ŠU-AN-DIŠ-DAR
# 4074              [šu, d, šul, gi]            ŠU-AN-DUN-GI
# 4075        [šu, šu, mu, dar, še₃]        ŠU-ŠU-MU-DAR-EŠ₂
# 4076        [šu, šu, mu, dar, še₃]        ŠU-ŠU-MU-DAR-EŠ₂
# 4077              [šu, d, šul, gi]            ŠU-AN-DUN-GI
# 4078               [šušin, ki, ta]       |MUŠ₃.EREN|-KI-TA
# 4079               [šušin, ki, ta]       |MUŠ₃.EREN|-KI-TA
# 4080                  [ṣi, lu, um]               ZE₂-LU-UM
# 4081                 [ṣa, al, lum]               ZA-AL-LUM
# 4082                 [ṣi, la₂, šu]              ZE₂-LAL-ŠU
# 4083                      [ṣi, li]                  ZE₂-LI
# 4084           [ṣi, li₂, d, iškur]            ZE₂-NI-AN-IM
# 4085           [ṣi, li₂, d, iškur]            ZE₂-NI-AN-IM
# 4086                  [ṣi, lu, um]               ZE₂-LU-UM
# 4087      [ṣi, lu, uš, d, da, gan]     ZE₂-LU-UŠ-AN-DA-GAN
# 4088  [ṣi, lu, uš, d, da, gan, ta]  ZE₂-LU-UŠ-AN-DA-GAN-TA
# 4089      [ṣi, lu, uš, d, da, gan]     ZE₂-LU-UŠ-AN-DA-GAN
# 4090  [ṣi, lu, uš, d, da, gan, ta]  ZE₂-LU-UŠ-AN-DA-GAN-TA
# 4091                     [ṣi₂, li]                   ZI-LI
# 4092                  [ṣi₂, lu, a]                 ZI-LU-A
# 4093          [ṣu, mi, id, dingir]            ZUM-MI-A₂-AN
# 4094                 [ṣu₂, hu, ti]                ZU-HU-TI
# 4095                 [ṣu₂, la, la]                ZU-LA-LA
# 4096         [ṣu₂, mi, id, dingir]             ZU-MI-A₂-AN
# 4097         [ṣum, mi, id, dingir]            ZUM-MI-A₂-AN
# 4098             [ṭa, bi₂, ma, ma]             DA-NE-MA-MA
# 4099                  [ṭa, bu, um]                DA-BU-UM
#
# [4100 rows x 5 columns]

# %% [markdown]
# Create output for Manuel Molina

# %%
dups = dups.sort_values(by="sign_names").reset_index(drop=True)
with open("output/duplicate_names_bdtns.csv", "w", encoding='utf8') as o: 
    dups.to_csv(o, sep = "\t", index=False)
dups
# Out:
#             translit_bdtns            cf_oracc                       signs  \
# 0                     A-a-             Aya[]PN                      [a, a]
# 1                      A-a             Aya[]PN                      [a, a]
# 2                  A-a-še₃             Aya[]PN                 [a, a, še₃]
# 3                A-a-gir₁₅          Ayagir[]PN               [a, a, gir₁₅]
# 4               A-a-Kal-la      Aya.Kal.la[]PN             [a, a, kal, la]
# 5              A-a-kal-la-         Ayakala[]PN             [a, a, kal, la]
# 6               A-a-kal-la         Ayakala[]PN             [a, a, kal, la]
# 7                   A-a-ni           Ayani[]PN                  [a, a, ni]
# 8                   A-a-NI          Aya.NI[]PN                  [a, a, ni]
# 9               A-a-uru-IN      Aya.iri.IN[]PN             [a, a, uru, in]
# 10              A-a-ri₂-in          Ayarin[]PN             [a, a, ri₂, in]
# 11                 A-ad-da            Aada[]PN                 [a, ad, da]
# 12                 A-Ad-da         A.Ad.da[]PN                 [a, ad, da]
# 13          A-ad-da-kal-la        Aadakala[]PN        [a, ad, da, kal, la]
# 14          A-Ad-da-kal-la  A.Ad.da.kal.la[]PN        [a, ad, da, kal, la]
# 15              A-ad-da-mu          Aadaŋu[]PN             [a, ad, da, mu]
# 16              A-Ad-da-mu    A.Ad.da.ŋu₁₀[]PN             [a, ad, da, mu]
# 17                 A-al-ni           Aalni[]PN                 [a, al, ni]
# 18                 A-al-NI         A.al.NI[]PN                 [a, al, ni]
# 19             A-al-li₂-ta            Aali[]PN            [a, al, li₂, ta]
# 20              A-al-NI-ta         A.al.NI[]PN             [a, al, ni, ta]
# 21              A-al-ni-ta           Aalni[]PN             [a, al, ni, ta]
# 22                    A-an             Aan[]PN                     [a, an]
# 23                A-dingir          Adiŋir[]PN                 [a, dingir]
# 24                 A-ba-an            Aban[]PN                 [a, ba, an]
# 25             A-ba-DINGIR     A.ba.DINGIR[]PN             [a, ba, dingir]
# 26    A-ba-{d}En-lil₂-gin₇     AbaEnlilgin[]PN  [a, ba, d, en, lil₂, gin₇]
# 27    A-ba-{d}En-lil₂-gen₇     AbaEnlilgen[]PN  [a, ba, d, en, lil₂, gen₇]
# 28    A-ba-{d}en-lil₂-gen₇     AbaEnlilgen[]PN  [a, ba, d, en, lil₂, gen₇]
# 29                A-ba-gal          Abagal[]PN                [a, ba, gal]
# ...                    ...                 ...                         ...
# 4070              Šu-Ku-ku        Šu.Ku.ku[]PN                [šu, ku, ku]
# 4071              Šu-ku-ku          Šukuku[]PN                [šu, ku, ku]
# 4072              Šu-ma-ma          Šumama[]PN                [šu, ma, ma]
# 4073              Šu-Ma-ma        Šu.Ma.ma[]PN                [šu, ma, ma]
# 4074              Šu-ma-mi          Šumami[]PN                [šu, ma, mi]
# 4075              Šu-Ma-mi        Šu.Ma.mi[]PN                [šu, ma, mi]
# 4076          Šu-Ma-mi-tum    Šu.Ma.mi.tum[]PN           [šu, ma, mi, tum]
# 4077          Šu-ma-mi-tum       Šumamitum[]PN           [šu, ma, mi, tum]
# 4078             Šu-Ma-am₃       Šu.Ma.am₃[]PN               [šu, ma, am₃]
# 4079             Šu-ma-am₃           Šumam[]PN               [šu, ma, am₃]
# 4080          Šu-ni-an-nam       Šuniʾanam[]PN           [šu, ni, an, nam]
# 4081          Šu-NI-an-nam    Šu.NI.an.nam[]PN           [šu, ni, an, nam]
# 4082              Šu-NI.NE        Šu.NI.NE[]PN                [šu, ni, ne]
# 4083             Šu-i₃-li₉          Šuʾili[]PN               [šu, i₃, li₉]
# 4084          Šu-i₃-li₂-Šu    Šu.i₃.li₂.Šu[]PN           [šu, i₃, li₂, šu]
# 4085          Šu-i₃-li₂-šu        Šuʾilišu[]PN           [šu, i₃, li₂, šu]
# 4086              Šu-Nu-nu        Šu.Nu.nu[]PN                [šu, nu, nu]
# 4087              Šu-nu-nu          Šununu[]PN                [šu, nu, nu]
# 4088             Šu-tur-AL       Šu.tur.AL[]PN               [šu, tur, al]
# 4089             Šu-tur-al         Šutural[]PN               [šu, tur, al]
# 4090              Šu-U₂.U₂        Šu.U₂.U₂[]PN                [šu, u₂, u₂]
# 4091              Šu-u₂-u₂             Šuu[]PN                [šu, u₂, u₂]
# 4092                 Šu-zu           Šuzuk[]PN                    [šu, zu]
# 4093                Šu-su₂            Šusu[]PN                   [šu, su₂]
# 4094            Šu-dur-ul₃         Šudurul[]PN              [šu, dur, ul₃]
# 4095            Šu-Dur-ul₃      Šu.Dur.ul₃[]PN              [šu, dur, ul₃]
# 4096                Šu-sa₆           Šusag[]PN                   [šu, sa₆]
# 4097                Šu-SA₆          Šu.SA₆[]PN                   [šu, sa₆]
# 4098      Šu-šu-mu-dar-še₃       Šušumudar[]PN      [šu, šu, mu, dar, še₃]
# 4099      Šu-Šu-mu-dar-še₃    Šu.Šu.mu.dar[]PN      [šu, šu, mu, dar, še₃]
#
#                   sign_names
# 0                        A-A
# 1                        A-A
# 2                    A-A-EŠ₂
# 3                    A-A-EŠ₂
# 4                 A-A-KAL-LA
# 5                 A-A-KAL-LA
# 6                 A-A-KAL-LA
# 7                     A-A-NI
# 8                     A-A-NI
# 9                 A-A-URU-IN
# 10                A-A-URU-IN
# 11                   A-AD-DA
# 12                   A-AD-DA
# 13            A-AD-DA-KAL-LA
# 14            A-AD-DA-KAL-LA
# 15                A-AD-DA-MU
# 16                A-AD-DA-MU
# 17                   A-AL-NI
# 18                   A-AL-NI
# 19                A-AL-NI-TA
# 20                A-AL-NI-TA
# 21                A-AL-NI-TA
# 22                      A-AN
# 23                      A-AN
# 24                   A-BA-AN
# 25                   A-BA-AN
# 26       A-BA-AN-EN-KID-DIM₂
# 27       A-BA-AN-EN-KID-DIM₂
# 28       A-BA-AN-EN-KID-DIM₂
# 29                  A-BA-GAL
# ...                      ...
# 4070                ŠU-KU-KU
# 4071                ŠU-KU-KU
# 4072                ŠU-MA-MA
# 4073                ŠU-MA-MA
# 4074                ŠU-MA-MI
# 4075                ŠU-MA-MI
# 4076            ŠU-MA-MI-TUM
# 4077            ŠU-MA-MI-TUM
# 4078            ŠU-MA-|A.AN|
# 4079            ŠU-MA-|A.AN|
# 4080            ŠU-NI-AN-NAM
# 4081            ŠU-NI-AN-NAM
# 4082                ŠU-NI-NE
# 4083                ŠU-NI-NE
# 4084             ŠU-NI-NI-ŠU
# 4085             ŠU-NI-NI-ŠU
# 4086                ŠU-NU-NU
# 4087                ŠU-NU-NU
# 4088               ŠU-TUR-AL
# 4089               ŠU-TUR-AL
# 4090                ŠU-U₂-U₂
# 4091                ŠU-U₂-U₂
# 4092                   ŠU-ZU
# 4093                   ŠU-ZU
# 4094  ŠU-|GU₂×KAK|-|GIŠ%GIŠ|
# 4095  ŠU-|GU₂×KAK|-|GIŠ%GIŠ|
# 4096                  ŠU-ŠA₆
# 4097                  ŠU-ŠA₆
# 4098        ŠU-ŠU-MU-DAR-EŠ₂
# 4099        ŠU-ŠU-MU-DAR-EŠ₂
#
# [4100 rows x 4 columns]

# %% [markdown]
# # Same Normalization?
# If the duplicates do *not* have the same normalization (in `cf_oracc`) add them to a list for inspection. This is awfully slow - there is probably a better way of doing this.

# %%
dups_l = []
for i, n in enumerate(dups["sign_names"]):
    for o in range(i + 1, len(dups)): 
        if n == dups.iloc[o]["sign_names"]: 
            if dups.iloc[i]["cf_oracc"] == dups.iloc[o]["cf_oracc"]: 
                continue
            else: 
                l = [dups.iloc[i]["index"], dups.iloc[i]["sign_names"], dups.iloc[i]["cf_oracc"], dups.iloc[o]["index"], 
                     dups.iloc[o]["sign_names"], dups.iloc[o]["cf_oracc"]]
                dups_l.append(l)

# %%
if len(dups_l) > 0: 
    dups_df = pd.DataFrame(dups_l)
    dups_df

# %%
len(dups_l)

# %%
r = na_df.to_dict("records")
r = {"data" : r}

p = OrderedDict()
p["authors"] = "Niek Veldhuis and John Carnahan"
p["license"] = "CC0; https://creativecommons.org/share-your-work/public-domain/cc0/; Open Domain"
p["website"] = "https://github.com/niekveldhuis/UrIII-names"
p["notes"] = "Based on the BDTNS (http://bdtns.filol.csic.es/) dataset, December 2016. Proper nouns in BDTNS, marked by initial capital, were extracted and normalized with a script, authored by Niek Veldhuis (https://github.com/niekveldhuis/UrIII-names). Drehem proper nouns were checked and hand-edited by John Carnahan."
fmt='%Y-%m-%d'
p["date"] = datetime.datetime.now().strftime(fmt)
p.update(r)

# %%
with open("name_authority/Drehem_na.json", "w", encoding = "utf-8") as j: 
    json.dump(p, j, ensure_ascii=False, sort_keys=False, indent=4, separators=(',', ': '))

# %%
with open("name_authority/Drehem_na.json", "r", encoding = "utf-8") as k: 
    l = json.load(k)
df = pd.DataFrame(l["data"])
df

# %%
with open("name_authority/people.csv", "r", encoding="utf-8") as f: 
    all_names = pd.read_csv(f)
all_names

# %%
with open("name_authority/Drehem_P_BDTNS.txt", "r", encoding="utf-8") as f:
    P_nos = pd.read_csv(f, sep="\t", header=None, usecols=[1]).fillna("")
P_nos = P_nos[P_nos[1] != ""]
P_nos = list(P_nos[1])
P_nos = [int(n[1:]) for n in P_nos]
P_nos

# %%
drehem_names = all_names.loc[all_names["p index"].isin(P_nos)].copy()

# %%
len(all_names), len(drehem_names)

# %%
drehem_names["signs"] = drehem_names["name"].apply(separate)
drehem_names["sign_names"] = drehem_names["signs"].apply(lambda x: "-".join([d[s] if s in d else s for s in x]))

# %%
drehem_names

# %%
na_d = dict(zip(na_df["sign_names"], na_df["cf_oracc"]))

# %%
drehem_names["norm2"] = drehem_names["sign_names"].apply(lambda x: na_d[x] if x in na_d else "not found")

# %%
perc = len(drehem_names[drehem_names["norm2"] == "not found"]) / len(drehem_names) * 100

# %%
print("percentage of name instances not recognized in normalization " + str(perc) + "%")

# %%
drehem_names.loc[drehem_names["norm2"] == "not found", "norm2"] = drehem_names["name"]
