# %%
import json
import pandas as pd

# %%
file = "jsonzip/blms/corpusjson/P395847.json"
with open(file, encoding="utf-8") as g:
    j = json.load(g)

# %%
textid = "dcclt/" + file[-13:-5]
meta_d = {"label": None, "id_text": None, "dollar_keys" : ["extent", "scope", "state"]}

# %%
def parsejson(text):
    for JSONobject in text["cdl"]:
        if "cdl" in JSONobject: 
            parsejson(JSONobject)
        if "type" in JSONobject and JSONobject["type"] == "line-start":
            meta_d.update(JSONobject)
        if "type" in JSONobject and JSONobject["type"] == "field-start":
            meta_d.update(JSONobject)
        if "type" in JSONobject and JSONobject["type"] == "field-end":
            meta_d.pop("subtype", None) 
        if "f" in JSONobject:
            lemm = JSONobject["f"]
            lemm["label"] = meta_d["label"]
            lemm["lineref"] = meta_d["ref"]
            lemm["id_text"] = meta_d["id_text"]
            if "subtype" in meta_d:
                lemm["field"] = meta_d["subtype"]
            lemm_l.append(lemm)
    return

# %%
lemm_l = []
parsejson(j)

# %%
df = pd.DataFrame(lemm_l)
df
# Out:
#                  base       cf delim epos field              form  \
# 0                   a        a   NaN    N    sv                 a
# 1                 NaN      NaN   NaN  NaN    pr                a₂
# 2                 NaN      NaN   NaN  NaN    sg                 A
# 3                 NaN      NaN   NaN  NaN    sv              ya₁₀
# 4                 NaN      NaN   NaN  NaN    pr                ia
# 5                 NaN      NaN   NaN  NaN    sg                 A
# 6               duru₅     duru   NaN  V/i    sv             duru₅
# 7                 NaN      NaN   NaN  NaN    pr             du-ru
# 8                 NaN      NaN   NaN  NaN    sg                 A
# 9                   a        a   NaN    N    sv                e₄
# 10                NaN      NaN   NaN  NaN    pr                 e
# 11                NaN      NaN   NaN  NaN    sg                 A
# 12                  a        a   NaN    N    sv                 a
# 13                NaN      NaN   NaN  NaN    pr                 a
# 14                NaN      NaN   NaN  NaN    sg                 A
# 15                a-a      aya   NaN    N    sv               aya
# 16                NaN      NaN   NaN  NaN    pr               a-a
# 17                NaN      NaN   NaN  NaN    sg             |A.A|
# 18    ayayaₓ(|A.A.A|)    ayaya   NaN    N    sv   ayayaₓ(|A.A.A|)
# 19                NaN      NaN   NaN  NaN    pr             a-a-a
# 20                NaN      NaN   NaN  NaN    sg           |A.A.A|
# 21               zah₂      zah   NaN  V/i    sv              sah₆
# 22                NaN      NaN   NaN  NaN    pr             sa-ah
# 23                NaN      NaN   NaN  NaN    sg            |HA.A|
# 24                am₃       me   NaN  V/i    sv               am₃
# 25                NaN      NaN   NaN  NaN    pr                am
# 26                NaN      NaN   NaN  NaN    sg            |A.AN|
# 27               šeŋ₃      šeŋ   NaN  V/i    sv              šeŋ₃
# 28                NaN      NaN   NaN  NaN    pr            še-em₃
# 29                NaN      NaN   NaN  NaN    sg            |A.AN|
# ...               ...      ...   ...  ...   ...               ...
# 2603              NaN      NaN   NaN  NaN    pr       ga-ak-ku-ul
# 2604              NaN      NaN   NaN  NaN    sg        |U.DIM×ŠE|
# 2605              NaN      NaN   NaN  NaN    sv                 x
# 2606              NaN      NaN   NaN  NaN    pr            bu-x-x
# 2607              NaN      NaN   NaN  NaN    sg                 x
# 2608             siki     siki   NaN    N    sv              siki
# 2609              NaN      NaN   NaN  NaN    pr             si-ki
# 2610              NaN      NaN   NaN  NaN    sg              SIK₂
# 2611              NaN      NaN   NaN  NaN    sv                 x
# 2612              NaN      NaN   NaN  NaN    pr             ta-si
# 2613              NaN      NaN   NaN  NaN    sg                 X
# 2614            gurun    gurun   NaN    N    sv             gurun
# 2615              NaN      NaN   NaN  NaN    pr         kur-ru-un
# 2616              NaN      NaN   NaN  NaN    sg             GURUN
# 2617              lam      lam   NaN    N    sv               lam
# 2618              NaN      NaN   NaN  NaN    pr             la-am
# 2619              NaN      NaN   NaN  NaN    sg               LAM
# 2620             eš₂₂       eš   NaN    N    sv              eš₂₂
# 2621              NaN      NaN   NaN  NaN    pr               eš₃
# 2622              NaN      NaN   NaN  NaN    sg         |LAM×KUR|
# 2623            kilib    kilib   NaN    N    sv             kilib
# 2624              NaN      NaN   NaN  NaN    pr             ki-li
# 2625              NaN      NaN   NaN  NaN    sg             LAGAB
# 2626        šu-niŋin₂  šuniŋin   NaN    N    sv         šu-niŋin₂
# 2627              NaN      NaN   NaN  NaN    sg          ŠU-LAGAB
# 2628         šu-niŋin  šuniŋin   NaN    N    sv          šu-niŋin
# 2629              NaN      NaN   NaN  NaN    pr       šu-ni-mi-en
# 2630              NaN      NaN   NaN  NaN    sg  ŠU-|LAGAB.LAGAB|
# 2631        {d}nisaba  Nisabak         DN    tx         {d}nisaba
# 2632          za₃-mi₂    zamin   NaN    N    tx           za₃-mi₂
#
#                                                     gdl           gw  \
# 0                   [{'v': 'a', 'id': 'Q000055.1.1.0'}]        water
# 1                  [{'v': 'a₂', 'id': 'Q000055.1.2.0'}]          NaN
# 2                   [{'s': 'A', 'id': 'Q000055.1.3.0'}]          NaN
# 3                [{'v': 'ya₁₀', 'id': 'Q000055.2.1.0'}]          NaN
# 4                  [{'v': 'ia', 'id': 'Q000055.2.2.0'}]          NaN
# 5                   [{'s': 'A', 'id': 'Q000055.2.3.0'}]          NaN
# 6               [{'v': 'duru₅', 'id': 'Q000055.3.1.0'}]          wet
# 7     [{'v': 'du', 'id': 'Q000055.3.2.0', 'delim': '...          NaN
# 8                   [{'s': 'A', 'id': 'Q000055.3.3.0'}]          NaN
# 9                  [{'v': 'e₄', 'id': 'Q000055.4.1.0'}]        water
# 10                  [{'v': 'e', 'id': 'Q000055.4.2.0'}]          NaN
# 11                  [{'s': 'A', 'id': 'Q000055.4.3.0'}]          NaN
# 12                  [{'v': 'a', 'id': 'Q000055.5.1.0'}]        water
# 13                  [{'v': 'a', 'id': 'Q000055.5.2.0'}]          NaN
# 14                  [{'s': 'A', 'id': 'Q000055.5.3.0'}]          NaN
# 15                [{'v': 'aya', 'id': 'Q000055.6.1.0'}]       father
# 16    [{'v': 'a', 'id': 'Q000055.6.2.0', 'delim': '-...          NaN
# 17    [{'c': '|A.A|', 'id': 'Q000055.6.3.0', 'seq': ...          NaN
# 18    [{'q': 'ayayaₓ(|A.A.A|)', 'id': 'Q000055.7.1.0...  grandfather
# 19    [{'v': 'a', 'id': 'Q000055.7.2.0', 'delim': '-...          NaN
# 20    [{'c': '|A.A.A|', 'id': 'Q000055.7.3.0', 'seq'...          NaN
# 21               [{'v': 'sah₆', 'id': 'Q000055.8.1.0'}]    disappear
# 22    [{'v': 'sa', 'id': 'Q000055.8.2.0', 'delim': '...          NaN
# 23    [{'c': '|HA.A|', 'id': 'Q000055.8.3.0', 'seq':...          NaN
# 24                [{'v': 'am₃', 'id': 'Q000055.9.1.0'}]           be
# 25                 [{'v': 'am', 'id': 'Q000055.9.2.0'}]          NaN
# 26    [{'c': '|A.AN|', 'id': 'Q000055.9.3.0', 'seq':...          NaN
# 27              [{'v': 'šeŋ₃', 'id': 'Q000055.10.1.0'}]         rain
# 28    [{'v': 'še', 'id': 'Q000055.10.2.0', 'delim': ...          NaN
# 29    [{'c': '|A.AN|', 'id': 'Q000055.10.3.0', 'seq'...          NaN
# ...                                                 ...          ...
# 2603  [{'v': 'ga', 'id': 'Q000055.893.2.0', 'breakSt...          NaN
# 2604  [{'c': '|U.DIM×ŠE|', 'id': 'Q000055.893.3.0', ...          NaN
# 2605  [{'x': 'ellipsis', 'id': 'Q000055.895.1.0', 'b...          NaN
# 2606  [{'v': 'bu', 'id': 'Q000055.895.2.0', 'break':...          NaN
# 2607  [{'x': 'ellipsis', 'id': 'Q000055.895.3.0', 'b...          NaN
# 2608           [{'v': 'siki', 'id': 'Q000055.896.1.0'}]         hair
# 2609  [{'v': 'si', 'id': 'Q000055.896.2.0', 'delim':...          NaN
# 2610  [{'s': 'SIK₂', 'id': 'Q000055.896.3.0', 'break...          NaN
# 2611              [{'v': 'x', 'id': 'Q000055.897.1.0'}]          NaN
# 2612  [{'v': 'ta', 'id': 'Q000055.897.2.0', 'delim':...          NaN
# 2613  [{'s': 'X', 'id': 'Q000055.897.3.0', 'break': ...          NaN
# 2614          [{'v': 'gurun', 'id': 'Q000055.898.1.0'}]        fruit
# 2615  [{'v': 'kur', 'id': 'Q000055.898.2.0', 'delim'...          NaN
# 2616          [{'s': 'GURUN', 'id': 'Q000055.898.3.0'}]          NaN
# 2617            [{'v': 'lam', 'id': 'Q000055.899.1.0'}]         tree
# 2618  [{'v': 'la', 'id': 'Q000055.899.2.0', 'delim':...          NaN
# 2619            [{'s': 'LAM', 'id': 'Q000055.899.3.0'}]          NaN
# 2620           [{'v': 'eš₂₂', 'id': 'Q000055.900.1.0'}]         tree
# 2621            [{'v': 'eš₃', 'id': 'Q000055.900.2.0'}]          NaN
# 2622  [{'c': '|LAM×KUR|', 'id': 'Q000055.900.3.0', '...          NaN
# 2623          [{'v': 'kilib', 'id': 'Q000055.901.1.0'}]        total
# 2624  [{'v': 'ki', 'id': 'Q000055.901.2.0', 'delim':...          NaN
# 2625          [{'s': 'LAGAB', 'id': 'Q000055.901.3.0'}]          NaN
# 2626  [{'v': 'šu', 'id': 'Q000055.902.1.0', 'delim':...        total
# 2627  [{'s': 'ŠU', 'id': 'Q000055.902.2.0', 'delim':...          NaN
# 2628  [{'v': 'šu', 'id': 'Q000055.903.1.0', 'delim':...        total
# 2629  [{'v': 'šu', 'id': 'Q000055.903.2.0', 'delim':...          NaN
# 2630  [{'s': 'ŠU', 'id': 'Q000055.903.3.0', 'delim':...          NaN
# 2631  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...            1
# 2632  [{'v': 'za₃', 'id': 'Q000055.905.2.0', 'delim'...         lyre
#
#              id_text          label lang      lineref morph norm    norm0  \
# 0     dcclt//Q000055              1  sux    Q000055.1     ~  NaN        a
# 1     dcclt//Q000055              1  sux    Q000055.1   NaN  NaN      NaN
# 2     dcclt//Q000055              1  sux    Q000055.1   NaN  NaN      NaN
# 3     dcclt//Q000055              2  sux    Q000055.2   NaN  NaN      NaN
# 4     dcclt//Q000055              2  sux    Q000055.2   NaN  NaN      NaN
# 5     dcclt//Q000055              2  sux    Q000055.2   NaN  NaN      NaN
# 6     dcclt//Q000055              3  sux    Q000055.3     ~  NaN     duru
# 7     dcclt//Q000055              3  sux    Q000055.3   NaN  NaN      NaN
# 8     dcclt//Q000055              3  sux    Q000055.3   NaN  NaN      NaN
# 9     dcclt//Q000055              4  sux    Q000055.4     ~  NaN        a
# 10    dcclt//Q000055              4  sux    Q000055.4   NaN  NaN      NaN
# 11    dcclt//Q000055              4  sux    Q000055.4   NaN  NaN      NaN
# 12    dcclt//Q000055              5  sux    Q000055.5     ~  NaN        a
# 13    dcclt//Q000055              5  sux    Q000055.5   NaN  NaN      NaN
# 14    dcclt//Q000055              5  sux    Q000055.5   NaN  NaN      NaN
# 15    dcclt//Q000055              6  sux    Q000055.6     ~  NaN      aya
# 16    dcclt//Q000055              6  sux    Q000055.6   NaN  NaN      NaN
# 17    dcclt//Q000055              6  sux    Q000055.6   NaN  NaN      NaN
# 18    dcclt//Q000055             6a  sux    Q000055.7     ~  NaN    ayaya
# 19    dcclt//Q000055             6a  sux    Q000055.7   NaN  NaN      NaN
# 20    dcclt//Q000055             6a  sux    Q000055.7   NaN  NaN      NaN
# 21    dcclt//Q000055              7  sux    Q000055.8     ~  NaN      zah
# 22    dcclt//Q000055              7  sux    Q000055.8   NaN  NaN      NaN
# 23    dcclt//Q000055              7  sux    Q000055.8   NaN  NaN      NaN
# 24    dcclt//Q000055              8  sux    Q000055.9     ~  NaN       me
# 25    dcclt//Q000055              8  sux    Q000055.9   NaN  NaN      NaN
# 26    dcclt//Q000055              8  sux    Q000055.9   NaN  NaN      NaN
# 27    dcclt//Q000055              9  sux   Q000055.10     ~  NaN      šeŋ
# 28    dcclt//Q000055              9  sux   Q000055.10   NaN  NaN      NaN
# 29    dcclt//Q000055              9  sux   Q000055.10   NaN  NaN      NaN
# ...              ...            ...  ...          ...   ...  ...      ...
# 2603  dcclt//Q000055            889  sux  Q000055.893   NaN  NaN      NaN
# 2604  dcclt//Q000055            889  sux  Q000055.893   NaN  NaN      NaN
# 2605  dcclt//Q000055            910  sux  Q000055.895   NaN  NaN      NaN
# 2606  dcclt//Q000055            910  sux  Q000055.895   NaN  NaN      NaN
# 2607  dcclt//Q000055            910  sux  Q000055.895   NaN  NaN      NaN
# 2608  dcclt//Q000055            911  sux  Q000055.896     ~  NaN     siki
# 2609  dcclt//Q000055            911  sux  Q000055.896   NaN  NaN      NaN
# 2610  dcclt//Q000055            911  sux  Q000055.896   NaN  NaN      NaN
# 2611  dcclt//Q000055            912  sux  Q000055.897   NaN  NaN      NaN
# 2612  dcclt//Q000055            912  sux  Q000055.897   NaN  NaN      NaN
# 2613  dcclt//Q000055            912  sux  Q000055.897   NaN  NaN      NaN
# 2614  dcclt//Q000055            913  sux  Q000055.898     ~  NaN    gurun
# 2615  dcclt//Q000055            913  sux  Q000055.898   NaN  NaN      NaN
# 2616  dcclt//Q000055            913  sux  Q000055.898   NaN  NaN      NaN
# 2617  dcclt//Q000055            914  sux  Q000055.899     ~  NaN      lam
# 2618  dcclt//Q000055            914  sux  Q000055.899   NaN  NaN      NaN
# 2619  dcclt//Q000055            914  sux  Q000055.899   NaN  NaN      NaN
# 2620  dcclt//Q000055            915  sux  Q000055.900     ~  NaN       eš
# 2621  dcclt//Q000055            915  sux  Q000055.900   NaN  NaN      NaN
# 2622  dcclt//Q000055            915  sux  Q000055.900   NaN  NaN      NaN
# 2623  dcclt//Q000055            916  sux  Q000055.901     ~  NaN    kilib
# 2624  dcclt//Q000055            916  sux  Q000055.901   NaN  NaN      NaN
# 2625  dcclt//Q000055            916  sux  Q000055.901   NaN  NaN      NaN
# 2626  dcclt//Q000055            917  sux  Q000055.902     ~  NaN  šuniŋin
# 2627  dcclt//Q000055            917  sux  Q000055.902   NaN  NaN      NaN
# 2628  dcclt//Q000055            918  sux  Q000055.903     ~  NaN  šuniŋin
# 2629  dcclt//Q000055            918  sux  Q000055.903   NaN  NaN      NaN
# 2630  dcclt//Q000055            918  sux  Q000055.903   NaN  NaN      NaN
# 2631  dcclt//Q000055  colophon  919  sux  Q000055.905     ~  NaN  Nisabak
# 2632  dcclt//Q000055  colophon  919  sux  Q000055.905     ~  NaN    zamin
#
#       pos                                sense
# 0       N                                water
# 1     NaN                                  NaN
# 2     NaN                                  NaN
# 3       X                                  NaN
# 4     NaN                                  NaN
# 5     NaN                                  NaN
# 6     V/i  (to be) wet, irrigated, damp, fresh
# 7     NaN                                  NaN
# 8     NaN                                  NaN
# 9       N                                water
# 10    NaN                                  NaN
# 11    NaN                                  NaN
# 12      N                                water
# 13    NaN                                  NaN
# 14    NaN                                  NaN
# 15      N                               father
# 16    NaN                                  NaN
# 17    NaN                                  NaN
# 18      N                          grandfather
# 19    NaN                                  NaN
# 20    NaN                                  NaN
# 21    V/i                   to disappear, flee
# 22    NaN                                  NaN
# 23    NaN                                  NaN
# 24    V/i                                to be
# 25    NaN                                  NaN
# 26    NaN                                  NaN
# 27    V/i                              to rain
# 28    NaN                                  NaN
# 29    NaN                                  NaN
# ...   ...                                  ...
# 2603  NaN                                  NaN
# 2604  NaN                                  NaN
# 2605    u                                  NaN
# 2606  NaN                                  NaN
# 2607  NaN                                  NaN
# 2608    N                                 hair
# 2609  NaN                                  NaN
# 2610  NaN                                  NaN
# 2611    u                                  NaN
# 2612  NaN                                  NaN
# 2613  NaN                                  NaN
# 2614    N                                fruit
# 2615  NaN                                  NaN
# 2616  NaN                                  NaN
# 2617    N           a nut-bearing tree, almond
# 2618  NaN                                  NaN
# 2619  NaN                                  NaN
# 2620    N                               a tree
# 2621  NaN                                  NaN
# 2622  NaN                                  NaN
# 2623    N                           total, sum
# 2624  NaN                                  NaN
# 2625  NaN                                  NaN
# 2626    N                           total, sum
# 2627  NaN                                  NaN
# 2628    N                           total, sum
# 2629  NaN                                  NaN
# 2630  NaN                                  NaN
# 2631   DN                                    1
# 2632    N                                 lyre
#
# [2633 rows x 17 columns]

# %%
j
# Out:
# {'type': 'cdl',
#  'project': 'blms',
#  'source': 'http://oracc.org/blms',
#  'license': 'This data is released under the CC0 license',
#  'license-url': 'https://creativecommons.org/publicdomain/zero/1.0/',
#  'more-info': 'http://oracc.org/doc/opendata/',
#  'UTC-timestamp': '2018-11-17T22:43:26',
#  'textid': 'P395847',
#  'cdl': [{'node': 'c',
#    'type': 'text',
#    'id': 'P395847.U0',
#    'cdl': [{'node': 'd', 'type': 'object', 'ref': ''},
#     {'node': 'd',
#      'subtype': 'obverse',
#      'type': 'obverse',
#      'ref': 'P395847.o.1',
#      'label': 'o'},
#     {'node': 'c',
#      'type': 'discourse',
#      'subtype': 'body',
#      'id': 'P395847.U1',
#      'cdl': [{'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'id': 'P395847.U2'},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U4',
#        'cdl': [{'node': 'd', 'type': 'line-start'},
#         {'node': 'l',
#          'frag': '[...]-ra',
#          'id': 'P395847.l0626a',
#          'ref': 'P395847.2.1',
#          'inst': 'u',
#          'f': {'lang': 'sux',
#           'form': 'x-ra',
#           'delim': '',
#           'gdl': [{'x': 'ellipsis',
#             'id': 'P395847.2.1.0',
#             'breakStart': '1',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P395847.2.1.0',
#             'delim': '-'},
#            {'v': 'ra', 'id': 'P395847.2.1.1'}],
#           'pos': 'u'}},
#         {'node': 'l',
#          'frag': 'a-ra-zu',
#          'id': 'P395847.l0626b',
#          'ref': 'P395847.2.2',
#          'inst': 'arazu[supplication]N',
#          'exosig': "@blms%sux:a-ra-zu=arazu[supplication//supplication]N'N$arazu/a-ra-zu#~",
#          'f': {'lang': 'sux',
#           'form': 'a-ra-zu',
#           'delim': '',
#           'gdl': [{'v': 'a', 'id': 'P395847.2.2.0', 'delim': '-'},
#            {'v': 'ra', 'id': 'P395847.2.2.1', 'delim': '-'},
#            {'v': 'zu', 'id': 'P395847.2.2.2'}],
#           'cf': 'arazu',
#           'gw': 'supplication',
#           'sense': 'supplication',
#           'norm0': 'arazu',
#           'pos': 'N',
#           'epos': 'N',
#           'base': 'a-ra-zu',
#           'morph': '~'}},
#         {'node': 'l',
#          'frag': 'ga-an-na-ab-dug₄',
#          'id': 'P395847.l0626c',
#          'ref': 'P395847.2.3',
#          'inst': 'dug[do, perform]',
#          'exosig': "@blms%sux:ga-an-na-ab-dug₄=dug[speak//to do, perform]V/t'V/t$ga.V.na.b:dug/dug₄#ga.V.na.b:~",
#          'f': {'lang': 'sux',
#           'form': 'ga-an-na-ab-dug₄',
#           'gdl': [{'v': 'ga', 'id': 'P395847.2.3.0', 'delim': '-'},
#            {'v': 'an', 'id': 'P395847.2.3.1', 'delim': '-'},
#            {'v': 'na', 'id': 'P395847.2.3.2', 'delim': '-'},
#            {'v': 'ab', 'id': 'P395847.2.3.3', 'delim': '-'},
#            {'v': 'dug₄', 'id': 'P395847.2.3.4'}],
#           'cf': 'dug',
#           'gw': 'speak',
#           'sense': 'to do, perform',
#           'norm0': 'ga.V.na.b:dug',
#           'pos': 'V/t',
#           'epos': 'V/t',
#           'base': 'dug₄',
#           'morph': 'ga.V.na.b:~'}}]},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U6',
#        'cdl': [{'node': 'd', 'type': 'line-start', 'ref': ''},
#         {'node': 'l',
#          'frag': '[...',
#          'id': 'P395847.l0626d',
#          'ref': 'P395847.2.1408000',
#          'inst': 'u',
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'x',
#           'delim': '',
#           'gdl': [{'x': 'ellipsis',
#             'id': 'P395847.2.1408000.0',
#             'breakStart': '1',
#             'break': 'missing',
#             'o': '['}],
#           'pos': 'u'}},
#         {'node': 'l',
#          'frag': 'ana]',
#          'id': 'P395847.l0626e',
#          'ref': 'P395847.2.1408001',
#          'inst': 'ana[to]PRP',
#          'sig': "@blms%akk-x-stdbab:ana=ana[to//to]PRP'PRP$ana",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'ana',
#           'delim': '',
#           'gdl': [{'v': 'ana',
#             'id': 'P395847.2.1408001.0',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P395847.2.1408000.0'}],
#           'cf': 'ana',
#           'gw': 'to',
#           'sense': 'to',
#           'norm': 'ana',
#           'pos': 'PRP',
#           'epos': 'PRP'}},
#         {'node': 'l',
#          'frag': '{⸢d⸣}UTU',
#          'id': 'P395847.l0626f',
#          'ref': 'P395847.2.1408002',
#          'inst': 'Šamaš[1]DN',
#          'sig': "@blms%akk-x-stdbab:{d}UTU=Šamaš[1//1]DN'DN$Šamaš",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': '{d}UTU',
#           'delim': '',
#           'gdl': [{'gg': 'logo',
#             'gdl_type': 'logo',
#             'group': [{'det': 'semantic',
#               'pos': 'pre',
#               'seq': [{'v': 'd',
#                 'id': 'P395847.2.1408002.0',
#                 'break': 'damaged',
#                 'ho': '1',
#                 'hc': '1'}]},
#              {'s': 'UTU',
#               'id': 'P395847.2.1408002.1',
#               'role': 'logo',
#               'logolang': 'sux'}]}],
#           'cf': 'Šamaš',
#           'gw': '1',
#           'sense': '1',
#           'norm': 'Šamaš',
#           'pos': 'DN',
#           'epos': 'DN'}},
#         {'node': 'l',
#          'frag': 'te-es₃-li-tu₄',
#          'id': 'P395847.l06270',
#          'ref': 'P395847.2.1408003',
#          'inst': 'teslītu[appeal]N$',
#          'sig': "@blms%akk-x-stdbab:te-es₃-li-tu₄=teslītu[appeal//appeal]N'N$teslītu",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'te-es₃-li-tu₄',
#           'delim': '',
#           'gdl': [{'v': 'te', 'id': 'P395847.2.1408003.0', 'delim': '-'},
#            {'v': 'es₃', 'id': 'P395847.2.1408003.1', 'delim': '-'},
#            {'v': 'li', 'id': 'P395847.2.1408003.2', 'delim': '-'},
#            {'v': 'tu₄', 'id': 'P395847.2.1408003.3'}],
#           'cf': 'teslītu',
#           'gw': 'appeal',
#           'sense': 'appeal',
#           'norm': 'teslītu',
#           'pos': 'N',
#           'epos': 'N'}},
#         {'node': 'l',
#          'frag': 'lu-uq-bi-šu₂',
#          'id': 'P395847.l06271',
#          'ref': 'P395847.2.1408004',
#          'inst': 'qabû[say]V$luqbišu',
#          'sig': "@blms%akk-x-stdbab:lu-uq-bi-šu₂=qabû[say//say]V'V$luqbišu",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'lu-uq-bi-šu₂',
#           'gdl': [{'v': 'lu', 'id': 'P395847.2.1408004.0', 'delim': '-'},
#            {'v': 'uq', 'id': 'P395847.2.1408004.1', 'delim': '-'},
#            {'v': 'bi', 'id': 'P395847.2.1408004.2', 'delim': '-'},
#            {'v': 'šu₂', 'id': 'P395847.2.1408004.3'}],
#           'cf': 'qabû',
#           'gw': 'say',
#           'sense': 'say',
#           'norm': 'luqbišu',
#           'pos': 'V',
#           'epos': 'V'}}]},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U8'},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U10',
#        'cdl': [{'node': 'd', 'type': 'line-start'},
#         {'node': 'l',
#          'frag': '[...]',
#          'id': 'P395847.l06272',
#          'ref': 'P395847.3.1',
#          'inst': 'u',
#          'f': {'lang': 'sux',
#           'form': 'x',
#           'delim': '',
#           'gdl': [{'x': 'ellipsis',
#             'id': 'P395847.3.1.0',
#             'breakStart': '1',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P395847.3.1.0'}],
#           'pos': 'u'}},
#         {'node': 'l',
#          'frag': 'šul',
#          'id': 'P395847.l06273',
#          'ref': 'P395847.3.2',
#          'inst': 'šul[youth]N',
#          'exosig': "@blms%sux:šul=šul[youth//youth, young man]V/i'N$šul/šul#~",
#          'f': {'lang': 'sux',
#           'form': 'šul',
#           'delim': '',
#           'gdl': [{'v': 'šul', 'id': 'P395847.3.2.0'}],
#           'cf': 'šul',
#           'gw': 'youth',
#           'sense': 'youth, young man',
#           'norm0': 'šul',
#           'pos': 'V/i',
#           'epos': 'N',
#           'base': 'šul',
#           'morph': '~'}},
#         {'node': 'l',
#          'frag': '{d}utu',
#          'id': 'P395847.l06274',
#          'ref': 'P395847.3.3',
#          'inst': 'Utu[1]DN',
#          'exosig': "@blms%sux:{d}utu=Utu[1//1]DN'DN$Utu/{d}utu#~",
#          'f': {'lang': 'sux',
#           'form': '{d}utu',
#           'delim': '',
#           'gdl': [{'det': 'semantic',
#             'pos': 'pre',
#             'seq': [{'v': 'd', 'id': 'P395847.3.3.0'}]},
#            {'v': 'utu', 'id': 'P395847.3.3.1'}],
#           'cf': 'Utu',
#           'gw': '1',
#           'sense': '1',
#           'norm0': 'Utu',
#           'pos': 'DN',
#           'epos': 'DN',
#           'base': '{d}utu',
#           'morph': '~'}},
#         {'node': 'l',
#          'frag': '[...]',
#          'id': 'P395847.l06275',
#          'ref': 'P395847.3.4',
#          'inst': 'u',
#          'f': {'lang': 'sux',
#           'form': 'x',
#           'delim': '',
#           'gdl': [{'x': 'ellipsis',
#             'id': 'P395847.3.4.0',
#             'breakStart': '1',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P395847.3.4.0'}],
#           'pos': 'u'}},
#         {'node': 'l',
#          'frag': '⸢me-e⸣',
#          'id': 'P395847.l06276',
#          'ref': 'P395847.3.5',
#          'inst': 'meʾe[I]IP',
#          'sig': "@blms%sux-x-emesal:me-e=meʾe[I//I]IP'IP$meʾe/me-e#~",
#          'f': {'lang': 'sux-x-emesal',
#           'form': 'me-e',
#           'delim': '',
#           'gdl': [{'v': 'me',
#             'id': 'P395847.3.5.0',
#             'break': 'damaged',
#             'ho': '1',
#             'delim': '-'},
#            {'v': 'e', 'id': 'P395847.3.5.1', 'break': 'damaged', 'hc': '1'}],
#           'cf': 'meʾe',
#           'gw': 'I',
#           'sense': 'I',
#           'norm0': 'meʾe',
#           'pos': 'IP',
#           'epos': 'IP',
#           'base': 'me-e',
#           'morph': '~'}},
#         {'node': 'l',
#          'frag': '[a]-⸢ra-zu⸣',
#          'id': 'P395847.l06277',
#          'ref': 'P395847.3.6',
#          'inst': 'arazu[supplication]N',
#          'exosig': "@blms%sux:a-ra-zu=arazu[supplication//supplication]N'N$arazu/a-ra-zu#~",
#          'f': {'lang': 'sux',
#           'form': 'a-ra-zu',
#           'delim': '',
#           'gdl': [{'v': 'a',
#             'id': 'P395847.3.6.0',
#             'breakStart': '1',
#             'o': ']',
#             'break': 'missing',
#             'breakEnd': 'P395847.3.6.0',
#             'delim': '-'},
#            {'v': 'ra',
#             'id': 'P395847.3.6.1',
#             'break': 'damaged',
#             'ho': '1',
#             'delim': '-'},
#            {'v': 'zu', 'id': 'P395847.3.6.2', 'break': 'damaged', 'hc': '1'}],
#           'cf': 'arazu',
#           'gw': 'supplication',
#           'sense': 'supplication',
#           'norm0': 'arazu',
#           'pos': 'N',
#           'epos': 'N',
#           'base': 'a-ra-zu',
#           'morph': '~'}},
#         {'node': 'l',
#          'frag': '<ga-an-na-ab-dug₄>',
#          'id': 'P395847.l06278',
#          'ref': 'P395847.3.7',
#          'inst': 'dug[do, perform]',
#          'exosig': "@blms%sux:ga-an-na-ab-dug₄=dug[speak//to do, perform]V/t'V/t$ga.V.na.b:dug/dug₄#ga.V.na.b:~",
#          'f': {'lang': 'sux',
#           'form': 'ga-an-na-ab-dug₄',
#           'gdl': [{'v': 'ga',
#             'id': 'P395847.3.7.0',
#             'statusStart': '1',
#             'o': '<',
#             'delim': '-'},
#            {'v': 'an', 'id': 'P395847.3.7.1', 'delim': '-'},
#            {'v': 'na', 'id': 'P395847.3.7.2', 'delim': '-'},
#            {'v': 'ab', 'id': 'P395847.3.7.3', 'delim': '-'},
#            {'v': 'dug₄',
#             'id': 'P395847.3.7.4',
#             'o': '>',
#             'statusStart': 'P395847.3.7.0'}],
#           'cf': 'dug',
#           'gw': 'speak',
#           'sense': 'to do, perform',
#           'norm0': 'ga.V.na.b:dug',
#           'pos': 'V/t',
#           'epos': 'V/t',
#           'base': 'dug₄',
#           'morph': 'ga.V.na.b:~'}}]},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U12',
#        'cdl': [{'node': 'd', 'type': 'line-start', 'ref': ''},
#         {'node': 'l',
#          'frag': '⸢ana',
#          'id': 'P395847.l06279',
#          'ref': 'P395847.3.1409000',
#          'inst': 'ana[to]PRP',
#          'sig': "@blms%akk-x-stdbab:ana=ana[to//to]PRP'PRP$ana",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'ana',
#           'delim': '',
#           'gdl': [{'v': 'ana',
#             'id': 'P395847.3.1409000.0',
#             'break': 'damaged',
#             'ho': '1'}],
#           'cf': 'ana',
#           'gw': 'to',
#           'sense': 'to',
#           'norm': 'ana',
#           'pos': 'PRP',
#           'epos': 'PRP'}},
#         {'node': 'l',
#          'frag': 'qar⸣-ra-di',
#          'id': 'P395847.l0627a',
#          'ref': 'P395847.3.1409001',
#          'inst': 'qarrādi[hero]N',
#          'sig': "@blms%akk-x-stdbab:qar-ra-di=qarrādu[hero//hero]N'N$qarrādi",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'qar-ra-di',
#           'delim': '',
#           'gdl': [{'v': 'qar',
#             'id': 'P395847.3.1409001.0',
#             'break': 'damaged',
#             'delim': '-',
#             'hc': '1'},
#            {'v': 'ra', 'id': 'P395847.3.1409001.1', 'delim': '-'},
#            {'v': 'di', 'id': 'P395847.3.1409001.2'}],
#           'cf': 'qarrādu',
#           'gw': 'hero',
#           'sense': 'hero',
#           'norm': 'qarrādi',
#           'pos': 'N',
#           'epos': 'N'}},
#         {'node': 'l',
#          'frag': 'eṭ-⸢lu₄⸣',
#          'id': 'P395847.l0627b',
#          'ref': 'P395847.3.1409002',
#          'inst': "eṭlu[young man]'N",
#          'sig': "@blms%akk-x-stdbab:eṭ-lu₄=eṭlu[young man//young man]N'N$eṭlu",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'eṭ-lu₄',
#           'delim': '',
#           'gdl': [{'v': 'eṭ', 'id': 'P395847.3.1409002.0', 'delim': '-'},
#            {'v': 'lu₄',
#             'id': 'P395847.3.1409002.1',
#             'break': 'damaged',
#             'ho': '1',
#             'hc': '1'}],
#           'cf': 'eṭlu',
#           'gw': 'young man',
#           'sense': 'young man',
#           'norm': 'eṭlu',
#           'pos': 'N',
#           'epos': 'N'}},
#         {'node': 'l',
#          'frag': '{[d}UTU',
#          'id': 'P395847.l0627c',
#          'ref': 'P395847.3.1409003',
#          'inst': 'Šamaš[1]DN',
#          'sig': "@blms%akk-x-stdbab:{d}UTU=Šamaš[1//1]DN'DN$Šamaš",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': '{d}UTU',
#           'delim': '',
#           'gdl': [{'gg': 'logo',
#             'gdl_type': 'logo',
#             'group': [{'det': 'semantic',
#               'pos': 'pre',
#               'seq': [{'v': 'd',
#                 'id': 'P395847.3.1409003.0',
#                 'breakStart': '1',
#                 'o': '[',
#                 'break': 'missing'}]},
#              {'s': 'UTU',
#               'id': 'P395847.3.1409003.1',
#               'break': 'missing',
#               'role': 'logo',
#               'logolang': 'sux'}]}],
#           'cf': 'Šamaš',
#           'gw': '1',
#           'sense': '1',
#           'norm': 'Šamaš',
#           'pos': 'DN',
#           'epos': 'DN'}},
#         {'node': 'l',
#          'frag': 'te-es₃]-⸢li⸣-tu₄',
#          'id': 'P395847.l0627d',
#          'ref': 'P395847.3.1409004',
#          'inst': 'teslītu[appeal]N$',
#          'sig': "@blms%akk-x-stdbab:te-es₃-li-tu₄=teslītu[appeal//appeal]N'N$teslītu",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'te-es₃-li-tu₄',
#           'delim': '',
#           'gdl': [{'v': 'te',
#             'id': 'P395847.3.1409004.0',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'es₃',
#             'id': 'P395847.3.1409004.1',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P395847.3.1409003.0',
#             'delim': '-'},
#            {'v': 'li',
#             'id': 'P395847.3.1409004.2',
#             'break': 'damaged',
#             'ho': '1',
#             'delim': '-',
#             'hc': '1'},
#            {'v': 'tu₄', 'id': 'P395847.3.1409004.3'}],
#           'cf': 'teslītu',
#           'gw': 'appeal',
#           'sense': 'appeal',
#           'norm': 'teslītu',
#           'pos': 'N',
#           'epos': 'N'}},
#         {'node': 'l',
#          'frag': '<lu-uq-bi-šu₂>',
#          'id': 'P395847.l0627e',
#          'ref': 'P395847.3.1409005',
#          'inst': 'qabû[say]V$luqbišu',
#          'sig': "@blms%akk-x-stdbab:lu-uq-bi-šu₂=qabû[say//say]V'V$luqbišu",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'lu-uq-bi-šu₂',
#           'gdl': [{'v': 'lu',
#             'id': 'P395847.3.1409005.0',
#             'statusStart': '1',
#             'o': '<',
#             'delim': '-'},
#            {'v': 'uq', 'id': 'P395847.3.1409005.1', 'delim': '-'},
#            {'v': 'bi', 'id': 'P395847.3.1409005.2', 'delim': '-'},
#            {'v': 'šu₂',
#             'id': 'P395847.3.1409005.3',
#             'o': '>',
#             'statusStart': 'P395847.3.1409005.0'}],
#           'cf': 'qabû',
#           'gw': 'say',
#           'sense': 'say',
#           'norm': 'luqbišu',
#           'pos': 'V',
#           'epos': 'V'}}]},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U14'},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U16',
#        'cdl': [{'node': 'd', 'type': 'line-start'},
#         {'node': 'l',
#          'frag': '[...]',
#          'id': 'P395847.l0627f',
#          'ref': 'P395847.4.1',
#          'inst': 'u',
#          'f': {'lang': 'sux',
#           'form': 'x',
#           'delim': '',
#           'gdl': [{'x': 'ellipsis',
#             'id': 'P395847.4.1.0',
#             'breakStart': '1',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P395847.4.1.0'}],
#           'pos': 'u'}},
#         {'node': 'l',
#          'frag': '⸢e₂⸣-babbar-ra',
#          'id': 'P395847.l06280',
#          'ref': 'P395847.4.2',
#          'inst': 'Ebabbar[1]TN',
#          'exosig': "@blms%sux:e₂-babbar-ra=Ebabbar[1//1]TN'TN$Ebabbar,ak/e₂-babbar+-ra=r.a#~,ak",
#          'f': {'lang': 'sux',
#           'form': 'e₂-babbar-ra',
#           'delim': '',
#           'gdl': [{'v': 'e₂',
#             'id': 'P395847.4.2.0',
#             'break': 'damaged',
#             'ho': '1',
#             'delim': '-',
#             'hc': '1'},
#            {'v': 'babbar', 'id': 'P395847.4.2.1', 'delim': '-'},
#            {'v': 'ra', 'id': 'P395847.4.2.2'}],
#           'cf': 'Ebabbar',
#           'gw': '1',
#           'sense': '1',
#           'norm0': 'Ebabbar,ak',
#           'pos': 'TN',
#           'epos': 'TN',
#           'base': 'e₂-babbar',
#           'cont': '-ra=r.a',
#           'morph': '~,ak'}},
#         {'node': 'l',
#          'frag': '[...',
#          'id': 'P395847.l06281',
#          'ref': 'P395847.4.3',
#          'inst': 'u',
#          'f': {'lang': 'sux',
#           'form': 'x',
#           'delim': '',
#           'gdl': [{'x': 'ellipsis',
#             'id': 'P395847.4.3.0',
#             'breakStart': '1',
#             'break': 'missing',
#             'o': '['}],
#           'pos': 'u'}},
#         {'node': 'l',
#          'frag': 'me-e',
#          'id': 'P395847.l06282',
#          'ref': 'P395847.4.4',
#          'inst': 'meʾe[I]IP',
#          'sig': "@blms%sux-x-emesal:me-e=meʾe[I//I]IP'IP$meʾe/me-e#~",
#          'f': {'lang': 'sux-x-emesal',
#           'form': 'me-e',
#           'delim': '',
#           'gdl': [{'v': 'me',
#             'id': 'P395847.4.4.0',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'e', 'id': 'P395847.4.4.1', 'break': 'missing'}],
#           'cf': 'meʾe',
#           'gw': 'I',
#           'sense': 'I',
#           'norm0': 'meʾe',
#           'pos': 'IP',
#           'epos': 'IP',
#           'base': 'me-e',
#           'morph': '~'}},
#         {'node': 'l',
#          'frag': 'a-ra-zu',
#          'id': 'P395847.l06283',
#          'ref': 'P395847.4.5',
#          'inst': 'arazu[supplication]N',
#          'exosig': "@blms%sux:a-ra-zu=arazu[supplication//supplication]N'N$arazu/a-ra-zu#~",
#          'f': {'lang': 'sux',
#           'form': 'a-ra-zu',
#           'delim': '',
#           'gdl': [{'v': 'a',
#             'id': 'P395847.4.5.0',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'ra',
#             'id': 'P395847.4.5.1',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'zu',
#             'id': 'P395847.4.5.2',
#             'queried': '1',
#             'break': 'missing'}],
#           'cf': 'arazu',
#           'gw': 'supplication',
#           'sense': 'supplication',
#           'norm0': 'arazu',
#           'pos': 'N',
#           'epos': 'N',
#           'base': 'a-ra-zu',
#           'morph': '~'}},
#         {'node': 'l',
#          'frag': '<ga-an-na-ab-dug₄>]',
#          'id': 'P395847.l06284',
#          'ref': 'P395847.4.6',
#          'inst': 'dug[do, perform]',
#          'exosig': "@blms%sux:ga-an-na-ab-dug₄=dug[speak//to do, perform]V/t'V/t$ga.V.na.b:dug/dug₄#ga.V.na.b:~",
#          'f': {'lang': 'sux',
#           'form': 'ga-an-na-ab-dug₄',
#           'gdl': [{'v': 'ga',
#             'id': 'P395847.4.6.0',
#             'statusStart': '1',
#             'o': '<',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'an',
#             'id': 'P395847.4.6.1',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'na',
#             'id': 'P395847.4.6.2',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'ab',
#             'id': 'P395847.4.6.3',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'dug₄',
#             'id': 'P395847.4.6.4',
#             'break': 'missing',
#             'o': '>]',
#             'statusStart': 'P395847.4.6.0',
#             'breakEnd': 'P395847.4.3.0'}],
#           'cf': 'dug',
#           'gw': 'speak',
#           'sense': 'to do, perform',
#           'norm0': 'ga.V.na.b:dug',
#           'pos': 'V/t',
#           'epos': 'V/t',
#           'base': 'dug₄',
#           'morph': 'ga.V.na.b:~'}}]},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U18',
#        'cdl': [{'node': 'd', 'type': 'line-start', 'ref': ''},
#         {'node': 'l',
#          'frag': '⸢ana⸣',
#          'id': 'P395847.l06285',
#          'ref': 'P395847.4.1410000',
#          'inst': 'ana[to]PRP',
#          'sig': "@blms%akk-x-stdbab:ana=ana[to//to]PRP'PRP$ana",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'ana',
#           'delim': '',
#           'gdl': [{'v': 'ana',
#             'id': 'P395847.4.1410000.0',
#             'break': 'damaged',
#             'ho': '1',
#             'hc': '1'}],
#           'cf': 'ana',
#           'gw': 'to',
#           'sense': 'to',
#           'norm': 'ana',
#           'pos': 'PRP',
#           'epos': 'PRP'}},
#         {'node': 'l',
#          'frag': 'be-lu₄',
#          'id': 'P395847.l06286',
#          'ref': 'P395847.4.1410001',
#          'inst': 'bēlu[lord]N',
#          'sig': "@blms%akk-x-stdbab:be-lu₄=bēlu[lord//lord]N'N$bēlu",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'be-lu₄',
#           'delim': '',
#           'gdl': [{'v': 'be', 'id': 'P395847.4.1410001.0', 'delim': '-'},
#            {'v': 'lu₄', 'id': 'P395847.4.1410001.1'}],
#           'cf': 'bēlu',
#           'gw': 'lord',
#           'sense': 'lord',
#           'norm': 'bēlu',
#           'pos': 'N',
#           'epos': 'N'}},
#         {'node': 'l',
#          'frag': 'E₂.⸢BABBAR⸣',
#          'id': 'P395847.l06287',
#          'ref': 'P395847.4.1410002',
#          'inst': 'Ebabbar[]TN$',
#          'sig': "@blms%akk-x-stdbab:E₂.BABBAR=Ebabbar[1//1]TN'TN$Ebabbar",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'E₂.BABBAR',
#           'delim': '',
#           'gdl': [{'gg': 'logo',
#             'gdl_type': 'logo',
#             'group': [{'s': 'E₂',
#               'id': 'P395847.4.1410002.0',
#               'role': 'logo',
#               'logolang': 'sux',
#               'delim': '.'},
#              {'s': 'BABBAR',
#               'id': 'P395847.4.1410002.1',
#               'break': 'damaged',
#               'gdl_remarked': '1',
#               'ho': '1',
#               'role': 'logo',
#               'logolang': 'sux',
#               'hc': '1'}]}],
#           'cf': 'Ebabbar',
#           'gw': '1',
#           'sense': '1',
#           'norm': 'Ebabbar',
#           'pos': 'TN',
#           'epos': 'TN'}},
#         {'node': 'l',
#          'frag': '[te-es₃-li]-⸢tu₄⸣',
#          'id': 'P395847.l06288',
#          'ref': 'P395847.4.1410003',
#          'inst': 'teslītu[appeal]N$',
#          'sig': "@blms%akk-x-stdbab:te-es₃-li-tu₄=teslītu[appeal//appeal]N'N$teslītu",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'te-es₃-li-tu₄',
#           'delim': '',
#           'gdl': [{'v': 'te',
#             'id': 'P395847.4.1410003.0',
#             'breakStart': '1',
#             'o': '[',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'es₃',
#             'id': 'P395847.4.1410003.1',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'li',
#             'id': 'P395847.4.1410003.2',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P395847.4.1410003.0',
#             'delim': '-'},
#            {'v': 'tu₄',
#             'id': 'P395847.4.1410003.3',
#             'break': 'damaged',
#             'ho': '1',
#             'hc': '1'}],
#           'cf': 'teslītu',
#           'gw': 'appeal',
#           'sense': 'appeal',
#           'norm': 'teslītu',
#           'pos': 'N',
#           'epos': 'N'}},
#         {'node': 'l',
#          'frag': '<lu-uq-bi-šu₂>',
#          'id': 'P395847.l06289',
#          'ref': 'P395847.4.1410004',
#          'inst': 'qabû[say]V$luqbišu',
#          'sig': "@blms%akk-x-stdbab:lu-uq-bi-šu₂=qabû[say//say]V'V$luqbišu",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'lu-uq-bi-šu₂',
#           'gdl': [{'v': 'lu',
#             'id': 'P395847.4.1410004.0',
#             'statusStart': '1',
#             'o': '<',
#             'delim': '-'},
#            {'v': 'uq', 'id': 'P395847.4.1410004.1', 'delim': '-'},
#            {'v': 'bi', 'id': 'P395847.4.1410004.2', 'delim': '-'},
#            {'v': 'šu₂',
#             'id': 'P395847.4.1410004.3',
#             'o': '>',
#             'statusStart': 'P395847.4.1410004.0'}],
#           'cf': 'qabû',
#           'gw': 'say',
#           'sense': 'say',
#           'norm': 'luqbišu',
#           'pos': 'V',
#           'epos': 'V'}}]},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U20'},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U22',
#        'cdl': [{'node': 'd', 'type': 'line-start'},
#         {'node': 'l',
#          'frag': '⸢sum₄⸣',
#          'id': 'P395847.l0628a',
#          'ref': 'P395847.5.1',
#          'inst': 'sum[beard]',
#          'exosig': "@blms%sux:sum₄=sum[beard//beard]N'N$sum/sum₄#~",
#          'f': {'lang': 'sux',
#           'form': 'sum₄',
#           'delim': '',
#           'gdl': [{'v': 'sum₄',
#             'id': 'P395847.5.1.0',
#             'break': 'damaged',
#             'ho': '1',
#             'hc': '1'}],
#           'cf': 'sum',
#           'gw': 'beard',
#           'sense': 'beard',
#           'norm0': 'sum',
#           'pos': 'N',
#           'epos': 'N',
#           'base': 'sum₄',
#           'morph': '~'}},
#         {'node': 'l',
#          'frag': 'mu₂',
#          'id': 'P395847.l0628b',
#          'ref': 'P395847.5.2',
#          'inst': 'mu[to grow]',
#          'exosig': "@blms%sux:mu₂=mu[grow//to grow]V/i'V/i$mu/mu₂#~",
#          'f': {'lang': 'sux',
#           'form': 'mu₂',
#           'delim': '',
#           'gdl': [{'v': 'mu₂', 'id': 'P395847.5.2.0'}],
#           'cf': 'mu',
#           'gw': 'grow',
#           'sense': 'to grow',
#           'norm0': 'mu',
#           'pos': 'V/i',
#           'epos': 'V/i',
#           'base': 'mu₂',
#           'morph': '~'}},
#         {'node': 'l',
#          'frag': 'dumu',
#          'id': 'P395847.l0628c',
#          'ref': 'P395847.5.3',
#          'inst': 'dumu[child, son, daughter]N',
#          'exosig': "@blms%sux:dumu=dumu[child//child, son, daughter]N'N$dumu/dumu#~",
#          'f': {'lang': 'sux',
#           'form': 'dumu',
#           'delim': '',
#           'gdl': [{'v': 'dumu', 'id': 'P395847.5.3.0'}],
#           'cf': 'dumu',
#           'gw': 'child',
#           'sense': 'child, son, daughter',
#           'norm0': 'dumu',
#           'pos': 'N',
#           'epos': 'N',
#           'base': 'dumu',
#           'morph': '~'}},
#         {'node': 'l',
#          'frag': '{d}[nin-gal',
#          'id': 'P395847.l0628d',
#          'ref': 'P395847.5.4',
#          'inst': 'Ningal[1]DN',
#          'exosig': "@blms%sux:{d}nin-gal=Ningal[1//1]DN'DN$Ningal/{d}nin-gal#~",
#          'f': {'lang': 'sux',
#           'form': '{d}nin-gal',
#           'delim': '',
#           'gdl': [{'det': 'semantic',
#             'pos': 'pre',
#             'seq': [{'v': 'd', 'id': 'P395847.5.4.0'}]},
#            {'v': 'nin',
#             'id': 'P395847.5.4.1',
#             'breakStart': '1',
#             'o': '[',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'gal', 'id': 'P395847.5.4.2', 'break': 'missing'}],
#           'cf': 'Ningal',
#           'gw': '1',
#           'sense': '1',
#           'norm0': 'Ningal',
#           'pos': 'DN',
#           'epos': 'DN',
#           'base': '{d}nin-gal',
#           'morph': '~'}},
#         {'node': 'l',
#          'frag': 'me-e',
#          'id': 'P395847.l0628e',
#          'ref': 'P395847.5.5',
#          'inst': 'meʾe[I]IP',
#          'sig': "@blms%sux-x-emesal:me-e=meʾe[I//I]IP'IP$meʾe/me-e#~",
#          'f': {'lang': 'sux-x-emesal',
#           'form': 'me-e',
#           'delim': '',
#           'gdl': [{'v': 'me',
#             'id': 'P395847.5.5.0',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'e', 'id': 'P395847.5.5.1', 'break': 'missing'}],
#           'cf': 'meʾe',
#           'gw': 'I',
#           'sense': 'I',
#           'norm0': 'meʾe',
#           'pos': 'IP',
#           'epos': 'IP',
#           'base': 'me-e',
#           'morph': '~'}},
#         {'node': 'l',
#          'frag': 'a-ra-zu',
#          'id': 'P395847.l0628f',
#          'ref': 'P395847.5.6',
#          'inst': 'arazu[supplication]N',
#          'exosig': "@blms%sux:a-ra-zu=arazu[supplication//supplication]N'N$arazu/a-ra-zu#~",
#          'f': {'lang': 'sux',
#           'form': 'a-ra-zu',
#           'delim': '',
#           'gdl': [{'v': 'a',
#             'id': 'P395847.5.6.0',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'ra',
#             'id': 'P395847.5.6.1',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'zu',
#             'id': 'P395847.5.6.2',
#             'queried': '1',
#             'break': 'missing'}],
#           'cf': 'arazu',
#           'gw': 'supplication',
#           'sense': 'supplication',
#           'norm0': 'arazu',
#           'pos': 'N',
#           'epos': 'N',
#           'base': 'a-ra-zu',
#           'morph': '~'}},
#         {'node': 'l',
#          'frag': '<ga-an-na-ab-dug₄>]',
#          'id': 'P395847.l06290',
#          'ref': 'P395847.5.7',
#          'inst': 'dug[do, perform]',
#          'exosig': "@blms%sux:ga-an-na-ab-dug₄=dug[speak//to do, perform]V/t'V/t$ga.V.na.b:dug/dug₄#ga.V.na.b:~",
#          'f': {'lang': 'sux',
#           'form': 'ga-an-na-ab-dug₄',
#           'gdl': [{'v': 'ga',
#             'id': 'P395847.5.7.0',
#             'statusStart': '1',
#             'o': '<',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'an',
#             'id': 'P395847.5.7.1',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'na',
#             'id': 'P395847.5.7.2',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'ab',
#             'id': 'P395847.5.7.3',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'dug₄',
#             'id': 'P395847.5.7.4',
#             'break': 'missing',
#             'o': '>]',
#             'statusStart': 'P395847.5.7.0',
#             'breakEnd': 'P395847.5.4.1'}],
#           'cf': 'dug',
#           'gw': 'speak',
#           'sense': 'to do, perform',
#           'norm0': 'ga.V.na.b:dug',
#           'pos': 'V/t',
#           'epos': 'V/t',
#           'base': 'dug₄',
#           'morph': 'ga.V.na.b:~'}}]},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U24',
#        'cdl': [{'node': 'd', 'type': 'line-start', 'ref': ''},
#         {'node': 'l',
#          'frag': 'ana',
#          'id': 'P395847.l06291',
#          'ref': 'P395847.5.1411000',
#          'inst': 'ana[to]PRP',
#          'sig': "@blms%akk-x-stdbab:ana=ana[to//to]PRP'PRP$ana",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'ana',
#           'delim': '',
#           'gdl': [{'v': 'ana', 'id': 'P395847.5.1411000.0'}],
#           'cf': 'ana',
#           'gw': 'to',
#           'sense': 'to',
#           'norm': 'ana',
#           'pos': 'PRP',
#           'epos': 'PRP'}},
#         {'node': 'l',
#          'frag': 'ṭa-ar',
#          'id': 'P395847.l06292',
#          'ref': 'P395847.5.1411001',
#          'inst': "ṭarru[bearded//bearded one]AJ'N$ṭar",
#          'sig': "@blms%akk-x-stdbab:ṭa-ar=ṭarru[bearded one//bearded one]AJ'N$ṭar",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'ṭa-ar',
#           'delim': '',
#           'gdl': [{'v': 'ṭa', 'id': 'P395847.5.1411001.0', 'delim': '-'},
#            {'v': 'ar', 'id': 'P395847.5.1411001.1'}],
#           'cf': 'ṭarru',
#           'gw': 'bearded one',
#           'sense': 'bearded one',
#           'norm': 'ṭar',
#           'pos': 'AJ',
#           'epos': 'N'}},
#         {'node': 'l',
#          'frag': '⸢ma⸣-[ar',
#          'id': 'P395847.l06293',
#          'ref': 'P395847.5.1411002',
#          'inst': 'māru[son]N$mār',
#          'sig': "@blms%akk-x-stdbab:ma-ar=māru[son//son]N'N$mār",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'ma-ar',
#           'delim': '',
#           'gdl': [{'v': 'ma',
#             'id': 'P395847.5.1411002.0',
#             'break': 'damaged',
#             'ho': '1',
#             'delim': '-',
#             'hc': '1'},
#            {'v': 'ar',
#             'id': 'P395847.5.1411002.1',
#             'breakStart': '1',
#             'o': '[',
#             'break': 'missing'}],
#           'cf': 'māru',
#           'gw': 'son',
#           'sense': 'son',
#           'norm': 'mār',
#           'pos': 'N',
#           'epos': 'N'}},
#         {'node': 'l',
#          'frag': '{d}NIN.GAL',
#          'id': 'P395847.l06294',
#          'ref': 'P395847.5.1411003',
#          'inst': 'Ningal[]DN$',
#          'sig': "@blms%akk-x-stdbab:{d}NIN.GAL=Ningal[1//1]DN'DN$Ningal",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': '{d}NIN.GAL',
#           'delim': '',
#           'gdl': [{'gg': 'logo',
#             'gdl_type': 'logo',
#             'group': [{'det': 'semantic',
#               'pos': 'pre',
#               'seq': [{'v': 'd',
#                 'id': 'P395847.5.1411003.0',
#                 'break': 'missing'}]},
#              {'s': 'NIN',
#               'id': 'P395847.5.1411003.1',
#               'break': 'missing',
#               'role': 'logo',
#               'logolang': 'sux',
#               'delim': '.'},
#              {'s': 'GAL',
#               'id': 'P395847.5.1411003.2',
#               'break': 'missing',
#               'role': 'logo',
#               'logolang': 'sux'}]}],
#           'cf': 'Ningal',
#           'gw': '1',
#           'sense': '1',
#           'norm': 'Ningal',
#           'pos': 'DN',
#           'epos': 'DN'}},
#         {'node': 'l',
#          'frag': 'te-es₃-li]-⸢tu₄⸣',
#          'id': 'P395847.l06295',
#          'ref': 'P395847.5.1411004',
#          'inst': 'teslītu[appeal]N$',
#          'sig': "@blms%akk-x-stdbab:te-es₃-li-tu₄=teslītu[appeal//appeal]N'N$teslītu",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'te-es₃-li-tu₄',
#           'delim': '',
#           'gdl': [{'v': 'te',
#             'id': 'P395847.5.1411004.0',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'es₃',
#             'id': 'P395847.5.1411004.1',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'li',
#             'id': 'P395847.5.1411004.2',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P395847.5.1411002.1',
#             'delim': '-'},
#            {'v': 'tu₄',
#             'id': 'P395847.5.1411004.3',
#             'break': 'damaged',
#             'ho': '1',
#             'hc': '1'}],
#           'cf': 'teslītu',
#           'gw': 'appeal',
#           'sense': 'appeal',
#           'norm': 'teslītu',
#           'pos': 'N',
#           'epos': 'N'}},
#         {'node': 'l',
#          'frag': '<lu-uq-bi-šu₂>',
#          'id': 'P395847.l06296',
#          'ref': 'P395847.5.1411005',
#          'inst': 'qabû[say]V$luqbišu',
#          'sig': "@blms%akk-x-stdbab:lu-uq-bi-šu₂=qabû[say//say]V'V$luqbišu",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'lu-uq-bi-šu₂',
#           'gdl': [{'v': 'lu',
#             'id': 'P395847.5.1411005.0',
#             'statusStart': '1',
#             'o': '<',
#             'delim': '-'},
#            {'v': 'uq', 'id': 'P395847.5.1411005.1', 'delim': '-'},
#            {'v': 'bi', 'id': 'P395847.5.1411005.2', 'delim': '-'},
#            {'v': 'šu₂',
#             'id': 'P395847.5.1411005.3',
#             'o': '>',
#             'statusStart': 'P395847.5.1411005.0'}],
#           'cf': 'qabû',
#           'gw': 'say',
#           'sense': 'say',
#           'norm': 'luqbišu',
#           'pos': 'V',
#           'epos': 'V'}}]},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U26'},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U28',
#        'cdl': [{'node': 'd', 'type': 'line-start'},
#         {'node': 'l',
#          'frag': 'barag',
#          'id': 'P395847.l06297',
#          'ref': 'P395847.6.1',
#          'inst': 'barag[dais]N',
#          'exosig': "@blms%sux:barag=barag[sanctum//dais, seat]N'N$barag/barag#~",
#          'f': {'lang': 'sux',
#           'form': 'barag',
#           'delim': '',
#           'gdl': [{'v': 'barag', 'id': 'P395847.6.1.0'}],
#           'cf': 'barag',
#           'gw': 'sanctum',
#           'sense': 'dais, seat',
#           'norm0': 'barag',
#           'pos': 'N',
#           'epos': 'N',
#           'base': 'barag',
#           'morph': '~'}},
#         {'node': 'l',
#          'frag': 'za-gin₃-⸢na⸣',
#          'id': 'P395847.l06298',
#          'ref': 'P395847.6.2',
#          'inst': 'zagin[lapis]N',
#          'exosig': "@blms%sux:za-gin₃-na=zagin[lapis//lapis lazuli]N'N$zagin,ak/za-gin₃+-na=n.a#~,ak",
#          'f': {'lang': 'sux',
#           'form': 'za-gin₃-na',
#           'delim': '',
#           'gdl': [{'v': 'za', 'id': 'P395847.6.2.0', 'delim': '-'},
#            {'v': 'gin₃', 'id': 'P395847.6.2.1', 'delim': '-'},
#            {'v': 'na',
#             'id': 'P395847.6.2.2',
#             'break': 'damaged',
#             'ho': '1',
#             'hc': '1'}],
#           'cf': 'zagin',
#           'gw': 'lapis',
#           'sense': 'lapis lazuli',
#           'norm0': 'zagin,ak',
#           'pos': 'N',
#           'epos': 'N',
#           'base': 'za-gin₃',
#           'cont': '-na=n.a',
#           'morph': '~,ak'}},
#         {'node': 'l',
#          'frag': '[...',
#          'id': 'P395847.l06299',
#          'ref': 'P395847.6.3',
#          'inst': 'u',
#          'f': {'lang': 'sux',
#           'form': 'x',
#           'delim': '',
#           'gdl': [{'x': 'ellipsis',
#             'id': 'P395847.6.3.0',
#             'breakStart': '1',
#             'break': 'missing',
#             'o': '['}],
#           'pos': 'u'}},
#         {'node': 'l',
#          'frag': 'me-e',
#          'id': 'P395847.l0629a',
#          'ref': 'P395847.6.4',
#          'inst': 'meʾe[I]IP',
#          'sig': "@blms%sux-x-emesal:me-e=meʾe[I//I]IP'IP$meʾe/me-e#~",
#          'f': {'lang': 'sux-x-emesal',
#           'form': 'me-e',
#           'delim': '',
#           'gdl': [{'v': 'me',
#             'id': 'P395847.6.4.0',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'e', 'id': 'P395847.6.4.1', 'break': 'missing'}],
#           'cf': 'meʾe',
#           'gw': 'I',
#           'sense': 'I',
#           'norm0': 'meʾe',
#           'pos': 'IP',
#           'epos': 'IP',
#           'base': 'me-e',
#           'morph': '~'}},
#         {'node': 'l',
#          'frag': 'a-ra-zu',
#          'id': 'P395847.l0629b',
#          'ref': 'P395847.6.5',
#          'inst': 'arazu[supplication]N',
#          'exosig': "@blms%sux:a-ra-zu=arazu[supplication//supplication]N'N$arazu/a-ra-zu#~",
#          'f': {'lang': 'sux',
#           'form': 'a-ra-zu',
#           'delim': '',
#           'gdl': [{'v': 'a',
#             'id': 'P395847.6.5.0',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'ra',
#             'id': 'P395847.6.5.1',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'zu',
#             'id': 'P395847.6.5.2',
#             'queried': '1',
#             'break': 'missing'}],
#           'cf': 'arazu',
#           'gw': 'supplication',
#           'sense': 'supplication',
#           'norm0': 'arazu',
#           'pos': 'N',
#           'epos': 'N',
#           'base': 'a-ra-zu',
#           'morph': '~'}},
#         {'node': 'l',
#          'frag': '<ga-an-na-ab-dug₄>]',
#          'id': 'P395847.l0629c',
#          'ref': 'P395847.6.6',
#          'inst': 'dug[do, perform]',
#          'exosig': "@blms%sux:ga-an-na-ab-dug₄=dug[speak//to do, perform]V/t'V/t$ga.V.na.b:dug/dug₄#ga.V.na.b:~",
#          'f': {'lang': 'sux',
#           'form': 'ga-an-na-ab-dug₄',
#           'gdl': [{'v': 'ga',
#             'id': 'P395847.6.6.0',
#             'statusStart': '1',
#             'o': '<',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'an',
#             'id': 'P395847.6.6.1',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'na',
#             'id': 'P395847.6.6.2',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'ab',
#             'id': 'P395847.6.6.3',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'dug₄',
#             'id': 'P395847.6.6.4',
#             'break': 'missing',
#             'o': '>]',
#             'statusStart': 'P395847.6.6.0',
#             'breakEnd': 'P395847.6.3.0'}],
#           'cf': 'dug',
#           'gw': 'speak',
#           'sense': 'to do, perform',
#           'norm0': 'ga.V.na.b:dug',
#           'pos': 'V/t',
#           'epos': 'V/t',
#           'base': 'dug₄',
#           'morph': 'ga.V.na.b:~'}}]},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U30',
#        'cdl': [{'node': 'd', 'type': 'line-start', 'ref': ''},
#         {'node': 'l',
#          'frag': 'ana',
#          'id': 'P395847.l0629d',
#          'ref': 'P395847.6.1412000',
#          'inst': 'ana[to]PRP',
#          'sig': "@blms%akk-x-stdbab:ana=ana[to//to]PRP'PRP$ana",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'ana',
#           'delim': '',
#           'gdl': [{'v': 'ana', 'id': 'P395847.6.1412000.0'}],
#           'cf': 'ana',
#           'gw': 'to',
#           'sense': 'to',
#           'norm': 'ana',
#           'pos': 'PRP',
#           'epos': 'PRP'}},
#         {'node': 'l',
#          'frag': 'ša₂',
#          'id': 'P395847.l0629e',
#          'ref': 'P395847.6.1412001',
#          'inst': 'ša[of]DET',
#          'sig': "@blms%akk-x-stdbab:ša₂=ša[of//of]DET'DET$ša",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'ša₂',
#           'delim': '',
#           'gdl': [{'v': 'ša₂', 'id': 'P395847.6.1412001.0'}],
#           'cf': 'ša',
#           'gw': 'of',
#           'sense': 'of',
#           'norm': 'ša',
#           'pos': 'DET',
#           'epos': 'DET'}},
#         {'node': 'l',
#          'frag': 'pa-⸢rak⸣-[ki',
#          'id': 'P395847.l0629f',
#          'ref': 'P395847.6.1412002',
#          'inst': 'parakki[cult dais]N',
#          'sig': "@blms%akk-x-stdbab:pa-rak-ki=parakku[cult dais//cult dais]N'N$parakki",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'pa-rak-ki',
#           'delim': '',
#           'gdl': [{'v': 'pa', 'id': 'P395847.6.1412002.0', 'delim': '-'},
#            {'v': 'rak',
#             'id': 'P395847.6.1412002.1',
#             'break': 'damaged',
#             'ho': '1',
#             'delim': '-',
#             'hc': '1'},
#            {'v': 'ki',
#             'id': 'P395847.6.1412002.2',
#             'breakStart': '1',
#             'o': '[',
#             'break': 'missing'}],
#           'cf': 'parakku',
#           'gw': 'cult dais',
#           'sense': 'cult dais',
#           'norm': 'parakki',
#           'pos': 'N',
#           'epos': 'N'}},
#         {'node': 'l',
#          'frag': 'el-li',
#          'id': 'P395847.l062a0',
#          'ref': 'P395847.6.1412003',
#          'inst': 'elli[pure]AJ',
#          'sig': "@blms%akk-x-stdbab:el-li=ellu[pure//pure]AJ'AJ$elli",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'el-li',
#           'delim': '',
#           'gdl': [{'v': 'el',
#             'id': 'P395847.6.1412003.0',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'li', 'id': 'P395847.6.1412003.1', 'break': 'missing'}],
#           'cf': 'ellu',
#           'gw': 'pure',
#           'sense': 'pure',
#           'norm': 'elli',
#           'pos': 'AJ',
#           'epos': 'AJ'}},
#         {'node': 'l',
#          'frag': 'te-es₃-li]-⸢tu₄⸣',
#          'id': 'P395847.l062a1',
#          'ref': 'P395847.6.1412004',
#          'inst': 'teslītu[appeal]N$',
#          'sig': "@blms%akk-x-stdbab:te-es₃-li-tu₄=teslītu[appeal//appeal]N'N$teslītu",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'te-es₃-li-tu₄',
#           'delim': '',
#           'gdl': [{'v': 'te',
#             'id': 'P395847.6.1412004.0',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'es₃',
#             'id': 'P395847.6.1412004.1',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'li',
#             'id': 'P395847.6.1412004.2',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P395847.6.1412002.2',
#             'delim': '-'},
#            {'v': 'tu₄',
#             'id': 'P395847.6.1412004.3',
#             'break': 'damaged',
#             'ho': '1',
#             'hc': '1'}],
#           'cf': 'teslītu',
#           'gw': 'appeal',
#           'sense': 'appeal',
#           'norm': 'teslītu',
#           'pos': 'N',
#           'epos': 'N'}},
#         {'node': 'l',
#          'frag': '<lu-uq-bi-šu₂>',
#          'id': 'P395847.l062a2',
#          'ref': 'P395847.6.1412005',
#          'inst': 'qabû[say]V$luqbišu',
#          'sig': "@blms%akk-x-stdbab:lu-uq-bi-šu₂=qabû[say//say]V'V$luqbišu",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'lu-uq-bi-šu₂',
#           'gdl': [{'v': 'lu',
#             'id': 'P395847.6.1412005.0',
#             'statusStart': '1',
#             'o': '<',
#             'delim': '-'},
#            {'v': 'uq', 'id': 'P395847.6.1412005.1', 'delim': '-'},
#            {'v': 'bi', 'id': 'P395847.6.1412005.2', 'delim': '-'},
#            {'v': 'šu₂',
#             'id': 'P395847.6.1412005.3',
#             'o': '>',
#             'statusStart': 'P395847.6.1412005.0'}],
#           'cf': 'qabû',
#           'gw': 'say',
#           'sense': 'say',
#           'norm': 'luqbišu',
#           'pos': 'V',
#           'epos': 'V'}}]},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U32'},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U34',
#        'cdl': [{'node': 'd', 'type': 'line-start'},
#         {'node': 'l',
#          'frag': 'di-kud',
#          'id': 'P395847.l062a3',
#          'ref': 'P395847.7.1',
#          'inst': 'dikud[judge]N',
#          'exosig': "@blms%sux:di-kud=dikud[judge//judge]N'N$dikud/di-kud#~",
#          'f': {'lang': 'sux',
#           'form': 'di-kud',
#           'delim': '',
#           'gdl': [{'v': 'di', 'id': 'P395847.7.1.0', 'delim': '-'},
#            {'v': 'kud', 'id': 'P395847.7.1.1'}],
#           'cf': 'dikud',
#           'gw': 'judge',
#           'sense': 'judge',
#           'norm0': 'dikud',
#           'pos': 'N',
#           'epos': 'N',
#           'base': 'di-kud',
#           'morph': '~'}},
#         {'node': 'l',
# ...
#              {'v': 'aš', 'id': 'P395847.8.1.1'}],
#             'cf': 'kaš',
#             'gw': 'decision',
#             'sense': 'decision',
#             'norm0': 'kaš',
#             'pos': 'N',
#             'epos': 'N',
#             'base': 'ka-aš',
#             'morph': '~'}},
#           {'node': 'l',
#            'frag': 'bar',
#            'id': 'P395847.l062ae',
#            'ref': 'P395847.8.2',
#            'inst': 'bar[cvve]',
#            'exosig': "@blms%sux:bar=bar[cvve//(compound verb verbal element)]V/t'V/t$bar/bar#~",
#            'f': {'lang': 'sux',
#             'form': 'bar',
#             'delim': '',
#             'gdl': [{'v': 'bar', 'id': 'P395847.8.2.0'}],
#             'cf': 'bar',
#             'gw': 'cvve',
#             'sense': '(compound verb verbal element)',
#             'norm0': 'bar',
#             'pos': 'V/t',
#             'epos': 'V/t',
#             'base': 'bar',
#             'morph': '~'}}]},
#         {'node': 'l',
#          'frag': '{d}[...]',
#          'id': 'P395847.l062af',
#          'ref': 'P395847.8.3',
#          'inst': 'u',
#          'f': {'lang': 'sux',
#           'form': '{d}x',
#           'gdl': [{'det': 'semantic',
#             'pos': 'pre',
#             'seq': [{'v': 'd', 'id': 'P395847.8.3.0'}]},
#            {'x': 'ellipsis',
#             'id': 'P395847.8.3.1',
#             'breakStart': '1',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P395847.8.3.1'}],
#           'pos': 'u'}}]},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U42',
#        'cdl': [{'node': 'd', 'type': 'line-start', 'ref': ''},
#         {'node': 'l',
#          'frag': 'ana',
#          'id': 'P395847.l062b0',
#          'ref': 'P395847.8.1414000',
#          'inst': 'ana[to]PRP',
#          'sig': "@blms%akk-x-stdbab:ana=ana[to//to]PRP'PRP$ana",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'ana',
#           'delim': '',
#           'gdl': [{'v': 'ana', 'id': 'P395847.8.1414000.0'}],
#           'cf': 'ana',
#           'gw': 'to',
#           'sense': 'to',
#           'norm': 'ana',
#           'pos': 'PRP',
#           'epos': 'PRP'}},
#         {'node': 'l',
#          'frag': 'pa-⸢ri⸣-[is',
#          'id': 'P395847.l062b1',
#          'ref': 'P395847.8.1414001',
#          'inst': 'pāris[one who decides]N',
#          'sig': "@blms%akk-x-stdbab:pa-ri-is=pārisu[one who divides//one who decides]N'N$pāris",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'pa-ri-is',
#           'delim': '',
#           'gdl': [{'v': 'pa',
#             'id': 'P395847.8.1414001.0',
#             'gdl_remarked': '1',
#             'delim': '-'},
#            {'v': 'ri',
#             'id': 'P395847.8.1414001.1',
#             'break': 'damaged',
#             'ho': '1',
#             'delim': '-',
#             'hc': '1'},
#            {'v': 'is',
#             'id': 'P395847.8.1414001.2',
#             'breakStart': '1',
#             'o': '[',
#             'break': 'missing'}],
#           'cf': 'pārisu',
#           'gw': 'one who divides',
#           'sense': 'one who decides',
#           'norm': 'pāris',
#           'pos': 'N',
#           'epos': 'N'}},
#         {'node': 'l',
#          'frag': '...',
#          'id': 'P395847.l062b2',
#          'ref': 'P395847.8.1414002',
#          'inst': 'u',
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'x',
#           'delim': '',
#           'gdl': [{'x': 'ellipsis',
#             'id': 'P395847.8.1414002.0',
#             'break': 'missing'}],
#           'pos': 'u'}},
#         {'node': 'l',
#          'frag': 'te-es₃-li]-⸢tu₄⸣',
#          'id': 'P395847.l062b3',
#          'ref': 'P395847.8.1414003',
#          'inst': 'teslītu[appeal]N$',
#          'sig': "@blms%akk-x-stdbab:te-es₃-li-tu₄=teslītu[appeal//appeal]N'N$teslītu",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'te-es₃-li-tu₄',
#           'delim': '',
#           'gdl': [{'v': 'te',
#             'id': 'P395847.8.1414003.0',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'es₃',
#             'id': 'P395847.8.1414003.1',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'li',
#             'id': 'P395847.8.1414003.2',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P395847.8.1414001.2',
#             'delim': '-'},
#            {'v': 'tu₄',
#             'id': 'P395847.8.1414003.3',
#             'break': 'damaged',
#             'ho': '1',
#             'hc': '1'}],
#           'cf': 'teslītu',
#           'gw': 'appeal',
#           'sense': 'appeal',
#           'norm': 'teslītu',
#           'pos': 'N',
#           'epos': 'N'}},
#         {'node': 'l',
#          'frag': '<lu-uq-bi-šu₂>',
#          'id': 'P395847.l062b4',
#          'ref': 'P395847.8.1414004',
#          'inst': 'qabû[say]V$luqbišu',
#          'sig': "@blms%akk-x-stdbab:lu-uq-bi-šu₂=qabû[say//say]V'V$luqbišu",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'lu-uq-bi-šu₂',
#           'gdl': [{'v': 'lu',
#             'id': 'P395847.8.1414004.0',
#             'statusStart': '1',
#             'o': '<',
#             'delim': '-'},
#            {'v': 'uq', 'id': 'P395847.8.1414004.1', 'delim': '-'},
#            {'v': 'bi', 'id': 'P395847.8.1414004.2', 'delim': '-'},
#            {'v': 'šu₂',
#             'id': 'P395847.8.1414004.3',
#             'o': '>',
#             'statusStart': 'P395847.8.1414004.0'}],
#           'cf': 'qabû',
#           'gw': 'say',
#           'sense': 'say',
#           'norm': 'luqbišu',
#           'pos': 'V',
#           'epos': 'V'}}]},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U44'},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U46',
#        'cdl': [{'node': 'd', 'type': 'line-start'},
#         {'node': 'l',
#          'frag': '⸢ib₂-si⸣',
#          'id': 'P395847.l062b5',
#          'ref': 'P395847.9.1',
#          'inst': "ibsi[enough! (lit. `it is enough')]J",
#          'exosig': "@blms%sux:ib₂-si=ibsi[enough!//enough! (lit. `it is enough')]J'J$ibsi/ib₂-si#~",
#          'f': {'lang': 'sux',
#           'form': 'ib₂-si',
#           'delim': '',
#           'gdl': [{'v': 'ib₂',
#             'id': 'P395847.9.1.0',
#             'break': 'damaged',
#             'ho': '1',
#             'delim': '-'},
#            {'v': 'si', 'id': 'P395847.9.1.1', 'break': 'damaged', 'hc': '1'}],
#           'cf': 'ibsi',
#           'gw': 'enough!',
#           'sense': "enough! (lit. `it is enough')",
#           'norm0': 'ibsi',
#           'pos': 'J',
#           'epos': 'J',
#           'base': 'ib₂-si',
#           'morph': '~'}},
#         {'node': 'l',
#          'frag': '[...]',
#          'id': 'P395847.l062b6',
#          'ref': 'P395847.9.2',
#          'inst': 'u',
#          'f': {'lang': 'sux',
#           'form': 'x',
#           'gdl': [{'x': 'ellipsis',
#             'id': 'P395847.9.2.0',
#             'breakStart': '1',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P395847.9.2.0'}],
#           'pos': 'u'}}]},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U48',
#        'cdl': [{'node': 'd', 'type': 'line-start', 'ref': ''},
#         {'node': 'l',
#          'frag': '⸢ma⸣-[ṣi',
#          'id': 'P395847.l062b7',
#          'ref': 'P395847.9.1415000',
#          'inst': 'maṣi[sufficient]AJ',
#          'sig': "@blms%akk-x-stdbab:ma-ṣi=maṣû[sufficient//sufficient]AJ'AJ$maṣi",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'ma-ṣi',
#           'delim': '',
#           'gdl': [{'v': 'ma',
#             'id': 'P395847.9.1415000.0',
#             'break': 'damaged',
#             'ho': '1',
#             'delim': '-',
#             'hc': '1'},
#            {'v': 'ṣi',
#             'id': 'P395847.9.1415000.1',
#             'breakStart': '1',
#             'o': '[',
#             'break': 'missing'}],
#           'cf': 'maṣû',
#           'gw': 'sufficient',
#           'sense': 'sufficient',
#           'norm': 'maṣi',
#           'pos': 'AJ',
#           'epos': 'AJ'}},
#         {'node': 'l',
#          'frag': 'a-di',
#          'id': 'P395847.l062b8',
#          'ref': 'P395847.9.1415001',
#          'inst': 'adi[until]PRP',
#          'sig': "@blms%akk-x-stdbab:a-di=adi[until//until]PRP'PRP$adi",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'a-di',
#           'delim': '',
#           'gdl': [{'v': 'a',
#             'id': 'P395847.9.1415001.0',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'di', 'id': 'P395847.9.1415001.1', 'break': 'missing'}],
#           'cf': 'adi',
#           'gw': 'until',
#           'sense': 'until',
#           'norm': 'adi',
#           'pos': 'PRP',
#           'epos': 'PRP'}},
#         {'node': 'l',
#          'frag': 'ma-ti',
#          'id': 'P395847.l062b9',
#          'ref': 'P395847.9.1415002',
#          'inst': 'mati[when?]QP$',
#          'sig': "@blms%akk-x-stdbab:ma-ti=mati[when?//when?]QP'QP$mati",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'ma-ti',
#           'delim': '',
#           'gdl': [{'v': 'ma',
#             'id': 'P395847.9.1415002.0',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'ti', 'id': 'P395847.9.1415002.1', 'break': 'missing'}],
#           'cf': 'mati',
#           'gw': 'when?',
#           'sense': 'when?',
#           'norm': 'mati',
#           'pos': 'QP',
#           'epos': 'QP'}},
#         {'node': 'l',
#          'frag': 'lu-uq-bi-šu₂]',
#          'id': 'P395847.l062ba',
#          'ref': 'P395847.9.1415003',
#          'inst': 'qabû[say]V$luqbišu',
#          'sig': "@blms%akk-x-stdbab:lu-uq-bi-šu₂=qabû[say//say]V'V$luqbišu",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'lu-uq-bi-šu₂',
#           'gdl': [{'v': 'lu',
#             'id': 'P395847.9.1415003.0',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'uq',
#             'id': 'P395847.9.1415003.1',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'bi',
#             'id': 'P395847.9.1415003.2',
#             'break': 'missing',
#             'delim': '-'},
#            {'v': 'šu₂',
#             'id': 'P395847.9.1415003.3',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P395847.9.1415000.1'}],
#           'cf': 'qabû',
#           'gw': 'say',
#           'sense': 'say',
#           'norm': 'luqbišu',
#           'pos': 'V',
#           'epos': 'V'}}]},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U50'},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U52',
#        'cdl': [{'node': 'd', 'type': 'line-start'},
#         {'node': 'l',
#          'frag': '⸢mah⸣-[am₃',
#          'id': 'P395847.l062bb',
#          'ref': 'P395847.10.1',
#          'inst': 'mah[(to be) great]',
#          'exosig': "@blms%sux:mah-am₃=mah[great//(to be) great]V/i'V/i$mah;am/mah#~;am",
#          'f': {'lang': 'sux',
#           'form': 'mah-am₃',
#           'delim': '',
#           'gdl': [{'v': 'mah',
#             'id': 'P395847.10.1.0',
#             'break': 'damaged',
#             'ho': '1',
#             'delim': '-',
#             'hc': '1'},
#            {'v': 'am₃',
#             'id': 'P395847.10.1.1',
#             'breakStart': '1',
#             'o': '[',
#             'break': 'missing'}],
#           'cf': 'mah',
#           'gw': 'great',
#           'sense': '(to be) great',
#           'norm0': 'mah;am',
#           'pos': 'V/i',
#           'epos': 'V/i',
#           'base': 'mah',
#           'morph': '~;am'}},
#         {'node': 'l',
#          'frag': '...]',
#          'id': 'P395847.l062bc',
#          'ref': 'P395847.10.2',
#          'inst': 'u',
#          'f': {'lang': 'sux',
#           'form': 'x',
#           'gdl': [{'x': 'ellipsis',
#             'id': 'P395847.10.2.0',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P395847.10.1.1'}],
#           'pos': 'u'}}]},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U54',
#        'cdl': [{'node': 'd', 'type': 'line-start', 'ref': ''},
#         {'node': 'l',
#          'frag': '⸢ra⸣-[bi',
#          'id': 'P395847.l062bd',
#          'ref': 'P395847.10.1416000',
#          'inst': 'rabû[great]AJ$rabi',
#          'sig': "@blms%akk-x-stdbab:ra-bi=rabû[big//great]AJ'AJ$rabi",
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'ra-bi',
#           'delim': '',
#           'gdl': [{'v': 'ra',
#             'id': 'P395847.10.1416000.0',
#             'break': 'damaged',
#             'ho': '1',
#             'delim': '-',
#             'hc': '1'},
#            {'v': 'bi',
#             'id': 'P395847.10.1416000.1',
#             'breakStart': '1',
#             'o': '[',
#             'queried': '1',
#             'break': 'missing'}],
#           'cf': 'rabû',
#           'gw': 'big',
#           'sense': 'great',
#           'norm': 'rabi',
#           'pos': 'AJ',
#           'epos': 'AJ'}},
#         {'node': 'l',
#          'frag': '...]',
#          'id': 'P395847.l062be',
#          'ref': 'P395847.10.1416001',
#          'inst': 'u',
#          'f': {'lang': 'akk-x-stdbab',
#           'form': 'x',
#           'gdl': [{'x': 'ellipsis',
#             'id': 'P395847.10.1416001.0',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P395847.10.1416000.1'}],
#           'pos': 'u'}}]},
#       {'node': 'c',
#        'type': 'sentence',
#        'implicit': 'yes',
#        'tag': '#auto',
#        'id': 'P395847.U56',
#        'label': 'o 10',
#        'cdl': [{'node': 'd',
#          'type': 'line-start',
#          'ref': 'P395847.11',
#          'n': '10',
#          'label': 'o 10'},
#         {'node': 'l',
#          'frag': '⸢šag₄⸣-[zu',
#          'id': 'P395847.l062bf',
#          'ref': 'P395847.11.1',
#          'inst': 'šag[heart]N',
#          'exosig': "@blms%sux:šag₄-zu=šag[heart//heart]N'N$šag,zu/šag₄#~,zu",
#          'f': {'lang': 'sux',
#           'form': 'šag₄-zu',
#           'delim': '',
#           'gdl': [{'v': 'šag₄',
#             'id': 'P395847.11.1.0',
#             'break': 'damaged',
#             'ho': '1',
#             'delim': '-',
#             'hc': '1'},
#            {'v': 'zu',
#             'id': 'P395847.11.1.1',
#             'breakStart': '1',
#             'o': '[',
#             'break': 'missing'}],
#           'cf': 'šag',
#           'gw': 'heart',
#           'sense': 'heart',
#           'norm0': 'šag,zu',
#           'pos': 'N',
#           'epos': 'N',
#           'base': 'šag₄',
#           'morph': '~,zu'}},
#         {'node': 'l',
#          'frag': '...]',
#          'id': 'P395847.l062c0',
#          'ref': 'P395847.11.2',
#          'inst': 'u',
#          'f': {'lang': 'sux',
#           'form': 'x',
#           'gdl': [{'x': 'ellipsis',
#             'id': 'P395847.11.2.0',
#             'break': 'missing',
#             'o': ']',
#             'breakEnd': 'P395847.11.1.1'}],
#           'pos': 'u'}},
#         {'node': 'd',
#          'type': 'nonx',
#          'ref': 'P395847.12',
#          'strict': '0',
#          'state': 'missing'},
#         {'node': 'd',
#          'subtype': 'reverse',
#          'type': 'reverse',
#          'ref': 'P395847.r.13',
#          'label': 'r'},
#         {'node': 'd',
#          'type': 'nonx',
#          'ref': 'P395847.14',
#          'strict': '0',
#          'state': 'missing'}]}]}]},
#   {'linkbase': [{'type': 'linkset',
#      'xlink_title': "kaš bad[make a decision//to make a decision]V/t'V/t",
#      'id': 'P395847.ls00000',
#      'xlink_type': 'extended',
#      'xlink_role': 'psu',
#      'sig': "{ga-eš₈ ba = kaš[decision]N bar[outside]N += kaš bad[make a decision//to make a decision]V/t'V/t}::@epsd2%sux:ga-eš₈=kaš[decision//decision]N'N$kaš/ga-eš₈#~++@epsd2%sux:ba=bar[outside//outside, (other) side]N'N$bar/ba#~",
#      'links': [{'type': 'link',
#        'xlink_title': 'kaš',
#        'xlink_type': 'locator',
#        'xlink_href': '#P395847.l062ad',
#        'xlink_role': 'elt'},
#       {'type': 'link',
#        'xlink_title': 'bar',
#        'xlink_type': 'locator',
#        'xlink_href': '#P395847.l062ae',
#        'xlink_role': 'elt'}]}]}]}

# %%
def parsejson(text):
    for JSONobject in text["cdl"]:
        if "cdl" in JSONobject: 
            parsejson(JSONobject)
        if "type" in JSONobject and JSONobject["type"] == "line-start":
            meta_d.update(JSONobject)
        if "type" in JSONobject and JSONobject["type"] == "field-start": # this is for sign lists, identifying fields such as
                                                                # sign, pronunciation, translation.
            meta_d.update(JSONobject)
        if "type" in JSONobject and JSONobject["type"] == "field-end":
            meta_d.pop("subtype", None)                           # remove the key "subtype" to prevent it from being copied 
                                                              # to all subsequent lemmas (which may not have fields)
        if "f" in JSONobject:
            lemma = JSONobject["f"]
            lemma["id_line"] = meta_d["ref"]
            lemma['label'] = meta_d["label"]
            lemma["id_text"] = meta_d["id_text"]
            if "subtype" in meta_d:
                lemma["field"] = meta_d["subtype"]
            lemm_l.append(lemma)
        if "strict" in JSONobject and JSONobject["strict"] == "1":
            lemma = {key: JSONobject[key] for key in meta_d["dollar_keys"]}
            lemma["id_line"] = JSONobject["ref"]
            lemma["id_text"] = meta_d["id_text"]
            lemm_l.append(lemma)
    return

# %%
lemm_l = []
parsejson(j)

# %%
words = pd.DataFrame(lemm_l)
words = words.fillna('')   # replace NaN (Not a Number) with empty string
words
# Out:
#                  base       cf delim epos extent field              form  \
# 0                   a        a          N           sv                 a
# 1                                                   pr                a₂
# 2                                                   sg                 A
# 3                                                   sv              ya₁₀
# 4                                                   pr                ia
# 5                                                   sg                 A
# 6               duru₅     duru        V/i           sv             duru₅
# 7                                                   pr             du-ru
# 8                                                   sg                 A
# 9                   a        a          N           sv                e₄
# 10                                                  pr                 e
# 11                                                  sg                 A
# 12                  a        a          N           sv                 a
# 13                                                  pr                 a
# 14                                                  sg                 A
# 15                a-a      aya          N           sv               aya
# 16                                                  pr               a-a
# 17                                                  sg             |A.A|
# 18    ayayaₓ(|A.A.A|)    ayaya          N           sv   ayayaₓ(|A.A.A|)
# 19                                                  pr             a-a-a
# 20                                                  sg           |A.A.A|
# 21               zah₂      zah        V/i           sv              sah₆
# 22                                                  pr             sa-ah
# 23                                                  sg            |HA.A|
# 24                am₃       me        V/i           sv               am₃
# 25                                                  pr                am
# 26                                                  sg            |A.AN|
# 27               šeŋ₃      šeŋ        V/i           sv              šeŋ₃
# 28                                                  pr            še-em₃
# 29                                                  sg            |A.AN|
# ...               ...      ...   ...  ...    ...   ...               ...
# 2604                                                sg        |U.DIM×ŠE|
# 2605                                                sv                 x
# 2606                                                pr            bu-x-x
# 2607                                                sg                 x
# 2608             siki     siki          N           sv              siki
# 2609                                                pr             si-ki
# 2610                                                sg              SIK₂
# 2611                                                sv                 x
# 2612                                                pr             ta-si
# 2613                                                sg                 X
# 2614            gurun    gurun          N           sv             gurun
# 2615                                                pr         kur-ru-un
# 2616                                                sg             GURUN
# 2617              lam      lam          N           sv               lam
# 2618                                                pr             la-am
# 2619                                                sg               LAM
# 2620             eš₂₂       eš          N           sv              eš₂₂
# 2621                                                pr               eš₃
# 2622                                                sg         |LAM×KUR|
# 2623            kilib    kilib          N           sv             kilib
# 2624                                                pr             ki-li
# 2625                                                sg             LAGAB
# 2626        šu-niŋin₂  šuniŋin          N           sv         šu-niŋin₂
# 2627                                                sg          ŠU-LAGAB
# 2628         šu-niŋin  šuniŋin          N           sv          šu-niŋin
# 2629                                                pr       šu-ni-mi-en
# 2630                                                sg  ŠU-|LAGAB.LAGAB|
# 2631                                           1
# 2632        {d}nisaba  Nisabak         DN           tx         {d}nisaba
# 2633          za₃-mi₂    zamin          N           tx           za₃-mi₂
#
#                                                     gdl           gw  \
# 0                   [{'v': 'a', 'id': 'Q000055.1.1.0'}]        water
# 1                  [{'v': 'a₂', 'id': 'Q000055.1.2.0'}]
# 2                   [{'s': 'A', 'id': 'Q000055.1.3.0'}]
# 3                [{'v': 'ya₁₀', 'id': 'Q000055.2.1.0'}]
# 4                  [{'v': 'ia', 'id': 'Q000055.2.2.0'}]
# 5                   [{'s': 'A', 'id': 'Q000055.2.3.0'}]
# 6               [{'v': 'duru₅', 'id': 'Q000055.3.1.0'}]          wet
# 7     [{'v': 'du', 'id': 'Q000055.3.2.0', 'delim': '...
# 8                   [{'s': 'A', 'id': 'Q000055.3.3.0'}]
# 9                  [{'v': 'e₄', 'id': 'Q000055.4.1.0'}]        water
# 10                  [{'v': 'e', 'id': 'Q000055.4.2.0'}]
# 11                  [{'s': 'A', 'id': 'Q000055.4.3.0'}]
# 12                  [{'v': 'a', 'id': 'Q000055.5.1.0'}]        water
# 13                  [{'v': 'a', 'id': 'Q000055.5.2.0'}]
# 14                  [{'s': 'A', 'id': 'Q000055.5.3.0'}]
# 15                [{'v': 'aya', 'id': 'Q000055.6.1.0'}]       father
# 16    [{'v': 'a', 'id': 'Q000055.6.2.0', 'delim': '-...
# 17    [{'c': '|A.A|', 'id': 'Q000055.6.3.0', 'seq': ...
# 18    [{'q': 'ayayaₓ(|A.A.A|)', 'id': 'Q000055.7.1.0...  grandfather
# 19    [{'v': 'a', 'id': 'Q000055.7.2.0', 'delim': '-...
# 20    [{'c': '|A.A.A|', 'id': 'Q000055.7.3.0', 'seq'...
# 21               [{'v': 'sah₆', 'id': 'Q000055.8.1.0'}]    disappear
# 22    [{'v': 'sa', 'id': 'Q000055.8.2.0', 'delim': '...
# 23    [{'c': '|HA.A|', 'id': 'Q000055.8.3.0', 'seq':...
# 24                [{'v': 'am₃', 'id': 'Q000055.9.1.0'}]           be
# 25                 [{'v': 'am', 'id': 'Q000055.9.2.0'}]
# 26    [{'c': '|A.AN|', 'id': 'Q000055.9.3.0', 'seq':...
# 27              [{'v': 'šeŋ₃', 'id': 'Q000055.10.1.0'}]         rain
# 28    [{'v': 'še', 'id': 'Q000055.10.2.0', 'delim': ...
# 29    [{'c': '|A.AN|', 'id': 'Q000055.10.3.0', 'seq'...
# ...                                                 ...          ...
# 2604  [{'c': '|U.DIM×ŠE|', 'id': 'Q000055.893.3.0', ...
# 2605  [{'x': 'ellipsis', 'id': 'Q000055.895.1.0', 'b...
# 2606  [{'v': 'bu', 'id': 'Q000055.895.2.0', 'break':...
# 2607  [{'x': 'ellipsis', 'id': 'Q000055.895.3.0', 'b...
# 2608           [{'v': 'siki', 'id': 'Q000055.896.1.0'}]         hair
# 2609  [{'v': 'si', 'id': 'Q000055.896.2.0', 'delim':...
# 2610  [{'s': 'SIK₂', 'id': 'Q000055.896.3.0', 'break...
# 2611              [{'v': 'x', 'id': 'Q000055.897.1.0'}]
# 2612  [{'v': 'ta', 'id': 'Q000055.897.2.0', 'delim':...
# 2613  [{'s': 'X', 'id': 'Q000055.897.3.0', 'break': ...
# 2614          [{'v': 'gurun', 'id': 'Q000055.898.1.0'}]        fruit
# 2615  [{'v': 'kur', 'id': 'Q000055.898.2.0', 'delim'...
# 2616          [{'s': 'GURUN', 'id': 'Q000055.898.3.0'}]
# 2617            [{'v': 'lam', 'id': 'Q000055.899.1.0'}]         tree
# 2618  [{'v': 'la', 'id': 'Q000055.899.2.0', 'delim':...
# 2619            [{'s': 'LAM', 'id': 'Q000055.899.3.0'}]
# 2620           [{'v': 'eš₂₂', 'id': 'Q000055.900.1.0'}]         tree
# 2621            [{'v': 'eš₃', 'id': 'Q000055.900.2.0'}]
# 2622  [{'c': '|LAM×KUR|', 'id': 'Q000055.900.3.0', '...
# 2623          [{'v': 'kilib', 'id': 'Q000055.901.1.0'}]        total
# 2624  [{'v': 'ki', 'id': 'Q000055.901.2.0', 'delim':...
# 2625          [{'s': 'LAGAB', 'id': 'Q000055.901.3.0'}]
# 2626  [{'v': 'šu', 'id': 'Q000055.902.1.0', 'delim':...        total
# 2627  [{'s': 'ŠU', 'id': 'Q000055.902.2.0', 'delim':...
# 2628  [{'v': 'šu', 'id': 'Q000055.903.1.0', 'delim':...        total
# 2629  [{'v': 'šu', 'id': 'Q000055.903.2.0', 'delim':...
# 2630  [{'s': 'ŠU', 'id': 'Q000055.903.3.0', 'delim':...
# 2631
# 2632  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...            1
# 2633  [{'v': 'za₃', 'id': 'Q000055.905.2.0', 'delim'...         lyre
#
#           id_line   ...            label lang      lineref morph norm  \
# 0       Q000055.1   ...                1  sux    Q000055.1     ~
# 1       Q000055.1   ...                1  sux    Q000055.1
# 2       Q000055.1   ...                1  sux    Q000055.1
# 3       Q000055.2   ...                2  sux    Q000055.2
# 4       Q000055.2   ...                2  sux    Q000055.2
# 5       Q000055.2   ...                2  sux    Q000055.2
# 6       Q000055.3   ...                3  sux    Q000055.3     ~
# 7       Q000055.3   ...                3  sux    Q000055.3
# 8       Q000055.3   ...                3  sux    Q000055.3
# 9       Q000055.4   ...                4  sux    Q000055.4     ~
# 10      Q000055.4   ...                4  sux    Q000055.4
# 11      Q000055.4   ...                4  sux    Q000055.4
# 12      Q000055.5   ...                5  sux    Q000055.5     ~
# 13      Q000055.5   ...                5  sux    Q000055.5
# 14      Q000055.5   ...                5  sux    Q000055.5
# 15      Q000055.6   ...                6  sux    Q000055.6     ~
# 16      Q000055.6   ...                6  sux    Q000055.6
# 17      Q000055.6   ...                6  sux    Q000055.6
# 18      Q000055.7   ...               6a  sux    Q000055.7     ~
# 19      Q000055.7   ...               6a  sux    Q000055.7
# 20      Q000055.7   ...               6a  sux    Q000055.7
# 21      Q000055.8   ...                7  sux    Q000055.8     ~
# 22      Q000055.8   ...                7  sux    Q000055.8
# 23      Q000055.8   ...                7  sux    Q000055.8
# 24      Q000055.9   ...                8  sux    Q000055.9     ~
# 25      Q000055.9   ...                8  sux    Q000055.9
# 26      Q000055.9   ...                8  sux    Q000055.9
# 27     Q000055.10   ...                9  sux   Q000055.10     ~
# 28     Q000055.10   ...                9  sux   Q000055.10
# 29     Q000055.10   ...                9  sux   Q000055.10
# ...           ...   ...              ...  ...          ...   ...  ...
# 2604  Q000055.893   ...              889  sux  Q000055.893
# 2605  Q000055.895   ...              910  sux  Q000055.895
# 2606  Q000055.895   ...              910  sux  Q000055.895
# 2607  Q000055.895   ...              910  sux  Q000055.895
# 2608  Q000055.896   ...              911  sux  Q000055.896     ~
# 2609  Q000055.896   ...              911  sux  Q000055.896
# 2610  Q000055.896   ...              911  sux  Q000055.896
# 2611  Q000055.897   ...              912  sux  Q000055.897
# 2612  Q000055.897   ...              912  sux  Q000055.897
# 2613  Q000055.897   ...              912  sux  Q000055.897
# 2614  Q000055.898   ...              913  sux  Q000055.898     ~
# 2615  Q000055.898   ...              913  sux  Q000055.898
# 2616  Q000055.898   ...              913  sux  Q000055.898
# 2617  Q000055.899   ...              914  sux  Q000055.899     ~
# 2618  Q000055.899   ...              914  sux  Q000055.899
# 2619  Q000055.899   ...              914  sux  Q000055.899
# 2620  Q000055.900   ...              915  sux  Q000055.900     ~
# 2621  Q000055.900   ...              915  sux  Q000055.900
# 2622  Q000055.900   ...              915  sux  Q000055.900
# 2623  Q000055.901   ...              916  sux  Q000055.901     ~
# 2624  Q000055.901   ...              916  sux  Q000055.901
# 2625  Q000055.901   ...              916  sux  Q000055.901
# 2626  Q000055.902   ...              917  sux  Q000055.902     ~
# 2627  Q000055.902   ...              917  sux  Q000055.902
# 2628  Q000055.903   ...              918  sux  Q000055.903     ~
# 2629  Q000055.903   ...              918  sux  Q000055.903
# 2630  Q000055.903   ...              918  sux  Q000055.903
# 2631  Q000055.904   ...
# 2632  Q000055.905   ...    colophon  919  sux  Q000055.905     ~
# 2633  Q000055.905   ...    colophon  919  sux  Q000055.905     ~
#
#         norm0  pos scope                                sense   state
# 0           a    N                                      water
# 1
# 2
# 3                X
# 4
# 5
# 6        duru  V/i        (to be) wet, irrigated, damp, fresh
# 7
# 8
# 9           a    N                                      water
# 10
# 11
# 12          a    N                                      water
# 13
# 14
# 15        aya    N                                     father
# 16
# 17
# 18      ayaya    N                                grandfather
# 19
# 20
# 21        zah  V/i                         to disappear, flee
# 22
# 23
# 24         me  V/i                                      to be
# 25
# 26
# 27        šeŋ  V/i                                    to rain
# 28
# 29
# ...       ...  ...   ...                                  ...     ...
# 2604
# 2605             u
# 2606
# 2607
# 2608     siki    N                                       hair
# 2609
# 2610
# 2611             u
# 2612
# 2613
# 2614    gurun    N                                      fruit
# 2615
# 2616
# 2617      lam    N                 a nut-bearing tree, almond
# 2618
# 2619
# 2620       eš    N                                     a tree
# 2621
# 2622
# 2623    kilib    N                                 total, sum
# 2624
# 2625
# 2626  šuniŋin    N                                 total, sum
# 2627
# 2628  šuniŋin    N                                 total, sum
# 2629
# 2630
# 2631                line                                       ruling
# 2632  Nisabak   DN                                          1
# 2633    zamin    N                                       lyre
#
# [2634 rows x 21 columns]
