# %% [markdown]
# # Retrieve Catalog Data from `catalogue.json`
#
# The file `catalogue.json` contains all the catalog data for an [ORACC](http://oracc.org) project (for general information, see the [Oracc Open Data](http://oracc.org/doc/opendata) page). The `zip` that contains all JSON files of a particular project can be found at `http://build-oracc.museum.upenn.edu/json/[PROJECT].zip`. In the URL replace [PROJECT] with your project or sub-project name (e.g. `dcclt` or `cams/gkab`).
#
# The main node in a `catalogue.json` file is called `members`. This node contains the information of all the fields and all the entries in the project catalog.

# %%
import pandas as pd
import zipfile
import json
import requests
import errno
import os
import tqdm

# %% [markdown]
# ## 0 Create Directories, if Necessary
# The two directories needed for this script are `jsonzip` and `output`. If they do not exist they are created, else: do nothing.
#
# For the code, see [Stack Overflow](http://stackoverflow.com/questions/18973418/os-mkdirpath-returns-oserror-when-directory-does-not-exist).

# %%
directories = ['jsonzip', 'output']
for d in directories:
    try:
        os.mkdir(d)
    except OSError as exc:
        if exc.errno !=errno.EEXIST:
            raise
        pass

# %% [markdown]
# ## 1.1 Input Project Name
# We will download and manipulate one catalog file at a time. Different [ORACC](http://oracc.org) projects use different fields in their catalogs, the catalogs are not mutually compatible.
#
# Provide a project name. Note that subprojects must be processed separately, they are not included in the main project. A subproject is named `[PROJECT]/[SUBPROJECT]`, for instance `saao/saa01`.

# %%
projects = input('Project(s): ').lower().strip() # lowercase user input and strip accidental spaces
# Out:
# Project(s): dcclt

# %% [markdown]
# ## 1.2 Split the List of Projects
# Split the list of projects and create a list of project names.

# %%
p = projects.split(',')               # split at each comma and make a list called `p`
p = [x.strip() for x in p]        # strip spaces left and right of each entry in `p`

# %% [markdown]
# ## 1.2 Download the ZIP files
# Download all the `json` files from `http://build-oracc.museum.upenn.edu/json/`. The file is called `[PROJECT].zip` (for instance: `dcclt.zip`). For subprojects the file is called `[PROJECT-SUBPROJECT].zip` (for instance `cams-gkab.zip`).
#
# For larger projects (such as [DCCLT](http://oracc.org/dcclt)) the `zip` file may be 25Mb or more. Downloading may take some time and it may be necessary to chunk the downloading process. The `iter_content()` function in the `requests` library takes care of that. For the chunking code see [this page](https://www.smallsurething.com/how-to-read-a-file-properly-in-python/).
#
# If you have downloaded the files by hand (and put them in the `jsonzip` directory) you may skip this cell and jump directly to section ...

# %%
non_existent = []
CHUNK = 16 * 1024
for project in tqdm.tqdm(p):
    project = project.replace('/', '-')
    url = "http://build-oracc.museum.upenn.edu/json/" + project + ".zip"
    file = 'jsonzip/' + project + '.zip'
    r = requests.get(url)
    if r.status_code == 200:
        print("Downloading " + url + " saving as " + file)
        with open(file, 'wb') as f:
            for c in r.iter_content(chunk_size=CHUNK):
                f.write(c)
    else:
        print(url + " does not exist.")
        non_existent.append(project)
p = [i for i in p if i not in non_existent] # remove non-existing project names from list
# Out:
#   0%|                                                    | 0/1 [00:00<?, ?it/s]
# Downloading http://build-oracc.museum.upenn.edu/json/dcclt.zip saving as jsonzip/dcclt.zip
# 100%|████████████████████████████████████████████| 1/1 [00:07<00:00,  7.02s/it]

# %% [markdown]
# ## 2 Extract Catalogue Data from `JSON` files
# The code in this cell will iterate through the list of projects entered above (1.1). For each project the `JSON` zip file, named `[PROJECT].zip` is located in the directory `jsonzip`. Each of these `zip` files includes a file called `catalogue.json`. This file is extracted and read with the command `json.loads()`, which reads the json data and transforms it into a JSON object - a sequence of names and values.
#
# The JSON object is transformed into a Pandas Dataframe. The dataframe needs to be transposed (`.T`), so that the P, Q, and X numbers become indexes or row names (rather than column names), and each column represents a field in the catalog.  The individual dataframes (one for each project requested) are concatenated. Since individual [ORACC](http://oracc.org) project catalogs may have different fields, the dataframes may have different column names. By default Pandas concatenation uses an `outer join` so that all column names of all the catalogs are preserved.

# %%
df = pd.DataFrame() # create an empty dataframe
for project in p:
    file = "jsonzip/" + project.replace("/", "-") + ".zip"
    try:
        z = zipfile.ZipFile(file)       # create a Zipfile object
    except:
        print(file + " does not exist or is not a proper ZIP file")
        continue
    try:
        st = z.read(project + '/catalogue.json').decode('utf-8')  #read and decode the catalogue.json file of one project
                                                                # the result is a string object
    except:
        print(project + '/catalogue.json' + ' is not available or not complete')
        continue
    cat = json.loads(st)
    cat = cat['members']  # select the 'members' node 
    for item in cat.values():
        item["project"] = project # add project name as separate field
    cat_df = pd.DataFrame(cat).T
    df = pd.concat([df, cat_df])

# %% [markdown]
# ## Create Dataframe
#  Creating a Dataframe is not necessary, one may also manipulate the dictionary directly, but for demonstration purposes the Dataframe is a handy format. In manipulating the dictionary directly it is important to keep in mind that not all catalog fields have data for all entries, which means that not all dictionary keys are available for each P, Q, or X number.
#
# The function `fillna('')` will put a blank (instead of `NaN`) in all fields that have no entry.
#
# Example code for slicing the dictionary to select all entries that have `provenience = 'Ur'`:
# > `urcat = {key:value for key, value in d.items() if 'provenience' in d[key] and d[key]['provenience'] == 'Ur'}

# %%
df = df.fillna('')
df
# Out:
#         accession_no acquisition_history archive               ark  \
# P000001                                           21198/zz001q0dtm
# P000002                                           21198/zz001q0dv4
# P000003                                           21198/zz001q0dwn
# P000004                                           21198/zz001q0dx5
# P000005                                           21198/zz001q0dzp
# P000006                                           21198/zz001q0f0p
# P000007                                           21198/zz001q0f16
# P000008                                           21198/zz001q0f2q
# P000009                                           21198/zz001q0f37
# P000010                                           21198/zz001q0f4r
# P000011                                           21198/zz001q0f58
# P000012                                           21198/zz001q0f6s
# P000013                                           21198/zz001q0f79
# P000014                                           21198/zz001q0f8t
# P000015                                           21198/zz001q0f9b
# P000019                                           21198/zz001q0ffd
# P000020                                           21198/zz001q0fgx
# P000021                                           21198/zz001q0fhf
# P000022                                           21198/zz001pzm1r
# P000023                                           21198/zz001pzm28
# P000024                                           21198/zz001pzm3s
# P000025                                           21198/zz001pzm49
# P000030                                           21198/zz001pzm9w
# P000031                                           21198/zz001pzmbd
# P000033                                           21198/zz001pzmdf
# P000034                                           21198/zz001pzmfz
# P000035                                           21198/zz001pzmgg
# P000036                                           21198/zz001pzmh0
# P000037                                           21198/zz001pzmjh
# P000038                                           21198/zz001pzmk1
# ...              ...                 ...     ...               ...
# X400009
# X400010
# X400011
# X400012
# X400013
# X400014
# X400015
# X400016
# X400017
# X400018
# X400019
# X400020
# X400021
# X400022
# X400023
# X400024
# X400025
# X400026
# X400027
# X400028
# X800010
# X800054
# X800072
# X800083
# X800085
# X999901
# X999902
# X999903
# X999905
# X999906
#
#                  atf_source        atf_up  \
# P000001  Englund, Robert K.  20130125.atf
# P000002  Englund, Robert K.  20130125.atf
# P000003  Englund, Robert K.  20130125.atf
# P000004  Englund, Robert K.  20130125.atf
# P000005  Englund, Robert K.  20130125.atf
# P000006  Englund, Robert K.  20130125.atf
# P000007  Englund, Robert K.  20130125.atf
# P000008  Englund, Robert K.  20130125.atf
# P000009  Englund, Robert K.  20130125.atf
# P000010  Englund, Robert K.  20130125.atf
# P000011  Englund, Robert K.  20130125.atf
# P000012  Englund, Robert K.  20130125.atf
# P000013  Englund, Robert K.  20130125.atf
# P000014  Englund, Robert K.  20130125.atf
# P000015  Englund, Robert K.  20130125.atf
# P000019  Englund, Robert K.  20130125.atf
# P000020  Englund, Robert K.  20130125.atf
# P000021  Englund, Robert K.  20130125.atf
# P000022  Englund, Robert K.  20130125.atf
# P000023  Englund, Robert K.  20130125.atf
# P000024  Englund, Robert K.  20130125.atf
# P000025  Englund, Robert K.  20130125.atf
# P000030  Englund, Robert K.  20130125.atf
# P000031  Englund, Robert K.  20130125.atf
# P000033  Englund, Robert K.  20130125.atf
# P000034  Englund, Robert K.  20130125.atf
# P000035  Englund, Robert K.  20130125.atf
# P000036  Englund, Robert K.  20130125.atf
# P000037  Englund, Robert K.  20130125.atf
# P000038  Englund, Robert K.  20130125.atf
# ...                     ...           ...
# X400009
# X400010
# X400011
# X400012
# X400013
# X400014
# X400015
# X400016
# X400017
# X400018
# X400019
# X400020
# X400021
# X400022
# X400023
# X400024
# X400025
# X400026
# X400027
# X400028
# X800010
# X800054
# X800072
# X800083
# X800085
# X999901
# X999902
# X999903
# X999905
# X999906
#
#                                                     author  \
# P000001           Englund, Robert K. &amp; Nissen, Hans J.
# P000002           Englund, Robert K. &amp; Nissen, Hans J.
# P000003           Englund, Robert K. &amp; Nissen, Hans J.
# P000004           Englund, Robert K. &amp; Nissen, Hans J.
# P000005           Englund, Robert K. &amp; Nissen, Hans J.
# P000006           Englund, Robert K. &amp; Nissen, Hans J.
# P000007           Englund, Robert K. &amp; Nissen, Hans J.
# P000008           Englund, Robert K. &amp; Nissen, Hans J.
# P000009           Englund, Robert K. &amp; Nissen, Hans J.
# P000010           Englund, Robert K. &amp; Nissen, Hans J.
# P000011           Englund, Robert K. &amp; Nissen, Hans J.
# P000012           Englund, Robert K. &amp; Nissen, Hans J.
# P000013           Englund, Robert K. &amp; Nissen, Hans J.
# P000014           Englund, Robert K. &amp; Nissen, Hans J.
# P000015           Englund, Robert K. &amp; Nissen, Hans J.
# P000019           Englund, Robert K. &amp; Nissen, Hans J.
# P000020           Englund, Robert K. &amp; Nissen, Hans J.
# P000021           Englund, Robert K. &amp; Nissen, Hans J.
# P000022           Englund, Robert K. &amp; Nissen, Hans J.
# P000023           Englund, Robert K. &amp; Nissen, Hans J.
# P000024           Englund, Robert K. &amp; Nissen, Hans J.
# P000025           Englund, Robert K. &amp; Nissen, Hans J.
# P000030           Englund, Robert K. &amp; Nissen, Hans J.
# P000031           Englund, Robert K. &amp; Nissen, Hans J.
# P000033           Englund, Robert K. &amp; Nissen, Hans J.
# P000034           Englund, Robert K. &amp; Nissen, Hans J.
# P000035           Englund, Robert K. &amp; Nissen, Hans J.
# P000036           Englund, Robert K. &amp; Nissen, Hans J.
# P000037           Englund, Robert K. &amp; Nissen, Hans J.
# P000038           Englund, Robert K. &amp; Nissen, Hans J.
# ...                                                    ...
# X400009  Cig, Muazzez &amp; Kizilyay, Hatice &amp; Land...
# X400010  Cig, Muazzez &amp; Kizilyay, Hatice &amp; Land...
# X400011  Cig, Muazzez &amp; Kizilyay, Hatice &amp; Land...
# X400012  Cig, Muazzez &amp; Kizilyay, Hatice &amp; Land...
# X400013  Cig, Muazzez &amp; Kizilyay, Hatice &amp; Land...
# X400014                Cig, Muazzez &amp; Kizilyay, Hatice
# X400015                Cig, Muazzez &amp; Kizilyay, Hatice
# X400016                Cig, Muazzez &amp; Kizilyay, Hatice
# X400017                Cig, Muazzez &amp; Kizilyay, Hatice
# X400018                Cig, Muazzez &amp; Kizilyay, Hatice
# X400019                Cig, Muazzez &amp; Kizilyay, Hatice
# X400020                Cig, Muazzez &amp; Kizilyay, Hatice
# X400021                Cig, Muazzez &amp; Kizilyay, Hatice
# X400022                Cig, Muazzez &amp; Kizilyay, Hatice
# X400023                Cig, Muazzez &amp; Kizilyay, Hatice
# X400024                Cig, Muazzez &amp; Kizilyay, Hatice
# X400025                Cig, Muazzez &amp; Kizilyay, Hatice
# X400026                Cig, Muazzez &amp; Kizilyay, Hatice
# X400027                Cig, Muazzez &amp; Kizilyay, Hatice
# X400028                Cig, Muazzez &amp; Kizilyay, Hatice
# X800010
# X800054
# X800072
# X800083                                 Wiseman, Donald J.
# X800085                                     Finkel, Irving
# X999901
# X999902
# X999903
# X999905
# X999906
#
#                                             author_remarks cdli_collation  \
# P000001  31x61x18; Lú A 14-16.30-32.48-50; M XVIII, auf...
# P000002  30x48x13; Lú A 13-15.23-25.?; Fundstelle wie W...
# P000003  42x53x19; Vocabulary 9; Qa XVI,2, unter der Ab...
# P000004  26x23x23; Lú A 9-10.?.?; Fundstelle wie W 9123...
# P000005  29x36x20; Lú A Vorläufer; Qa XVI,2, unter der ...
# P000006  82x62x19; Lú A Vorläufer; Fundstelle wie W 912...
# P000007  56x36x29; Lú A Vorläufer; Fundstelle wie W 912...
# P000008  39x26x9; Unidentified 1; Pb XVII,1, +19.50 m, ...
# P000009  54x46x?; Lú A 95-98.111-113; Fundstelle wie W ...
# P000010  23x25x19; Officials 16-18.66-68.?-?; Fundstell...
# P000011  66x56x24; Lú A + Metal 3-8.15-21.?-? + 44-50.5...
# P000012  41x31x14; Lú A 65-66.71-72.93.86-88 mit Koloph...
# P000013  30x38x16; Unidentified 2; Fundstelle wie W 119...
# P000014  76x51x15; Swine 1-58 mit Kolophon; Oe XVI,4, +...
# P000015  101x99x30; Vessels Vorläufer; Oe XVI,5, 1 m üb...
# P000019      25x25x17; Lú A 7-8.?-?; Od/e XVI,5, +20.07 m.
# P000020  39x24x20; Unidentified 3; Fundstelle wie W 136...
# P000021  42x43x20; Vocabulary 1; Pc XVII,4, +ca. 17.20 ...
# P000022  45x52x21; Practice 2; Od XVI,5, dicht über den...
# P000023  62x57x17; Vocabulary 2; Pb XVII,3, +18.00 m, S...
# P000024  33x28x16; Unidentified 4; Od XVI,5, ca. +20.20...
# P000025  99x92x33; Vocabulary 3; Fundstelle wie W 14335...
# P000030  47x32x?; Lú A 3-6; in plankonvexem Ziegel des ...
# P000031  39x50x?; Lú A ?-?.24-30.44-48; Pb XVII,2, +19....
# P000033  23x26x?; Lú A 89-91; Od XVI,4/5, +20 m; Tafel ...
# P000034  35x24x?; Unidentified 5; Od XVI,5, +20 m, unte...
# P000035  61x62x?; Fish 19-23.30-38.41-49.91-97 mit Kolo...
# P000036  64x54x33; Grain Vorläufer; Pa XVI,2, +19.20 m,...
# P000037  46x28x18; Unidentified 5x; Nb/c XVI,4, Seleuki...
# P000038  33x22x16; Unidentified 6; Fundstelle wie W 157...
# ...                                                    ...            ...
# X400009
# X400010
# X400011
# X400012
# X400013
# X400014
# X400015
# X400016
# X400017
# X400018
# X400019
# X400020
# X400021
# X400022
# X400023
# X400024
# X400025
# X400026
# X400027
# X400028
# X800010
# X800054
# X800072
# X800083
# X800085
# X999901
# X999902
# X999903
# X999905
# X999906
#
#         cdli_comments   ...                         subgenre  \
# P000001                 ...                     Archaic Lu A
# P000002                 ...                     Archaic Lu A
# P000003                 ...               Archaic Vocabulary
# P000004                 ...                     Archaic Lu A
# P000005                 ...                     Archaic Lu A
# P000006                 ...                     Archaic Lu A
# P000007                 ...                     Archaic Lu A
# P000008                 ...             Archaic Unidentified
# P000009                 ...                     Archaic Lu A
# P000010                 ...                Archaic Officials
# P000011                 ...                     Archaic Lu A
# P000012                 ...                     Archaic Lu A
# P000013                 ...             Archaic Unidentified
# P000014                 ...                     Archaic Pigs
# P000015                 ...     Archaic Vessels and Garments
# P000019                 ...                     Archaic Lu A
# P000020                 ...             Archaic Unidentified
# P000021                 ...               Archaic Vocabulary
# P000022                 ...                 Archaic Practice
# P000023                 ...               Archaic Vocabulary
# P000024                 ...             Archaic Unidentified
# P000025                 ...               Archaic Vocabulary
# P000030                 ...                     Archaic Lu A
# P000031                 ...                     Archaic Lu A
# P000033                 ...                     Archaic Lu A
# P000034                 ...             Archaic Unidentified
# P000035                 ...                     Archaic Fish
# P000036                 ...                     Archaic Food
# P000037                 ...             Archaic Unidentified
# P000038                 ...             Archaic Unidentified
# ...               ...   ...                              ...
# X400009                 ...           List of Personal Names
# X400010                 ...           List of Personal Names
# X400011                 ...           List of Personal Names
# X400012                 ...           List of Personal Names
# X400013                 ...           List of Personal Names
# X400014                 ...           List of Personal Names
# X400015                 ...           List of Personal Names
# X400016                 ...           List of Personal Names
# X400017                 ...           List of Personal Names
# X400018                 ...           List of Personal Names
# X400019                 ...           List of Personal Names
# X400020                 ...           List of Personal Names
# X400021                 ...           List of Personal Names
# X400022                 ...           List of Personal Names
# X400023                 ...           List of Personal Names
# X400024                 ...           List of Personal Names
# X400025                 ...           List of Personal Names
# X400026                 ...           List of Personal Names
# X400027                 ...           List of Personal Names
# X400028                 ...           List of Personal Names
# X800010                 ...                              Ura
# X800054                 ...                              Ura
# X800072                 ...                              Ura
# X800083                 ...                              Ura
# X800085                 ...                              Ura
# X999901                 ...                           Murgud
# X999902                 ...                           Murgud
# X999903                 ...                           Murgud
# X999905                 ...                           Murgud
# X999906                 ...                           Murgud
#
#                   subgenre_remarks supergenre surface_preservation  \
# P000001                                   LEX
# P000002                                   LEX
# P000003                                   LEX
# P000004                                   LEX
# P000005                                   LEX
# P000006                                   LEX
# P000007                                   LEX
# P000008                          1        LEX
# P000009                                   LEX
# P000010                                   LEX
# P000011                                   LEX
# P000012                                   LEX
# P000013                          2        LEX
# P000014                                   LEX
# P000015                                   LEX
# P000019                                   LEX
# P000020                          3        LEX
# P000021                                   LEX
# P000022                                   LEX
# P000023                                   LEX
# P000024                          4        LEX
# P000025                                   LEX
# P000030                                   LEX
# P000031                                   LEX
# P000033                                   LEX
# P000034                          5        LEX
# P000035                                   LEX
# P000036                                   LEX
# P000037                         5x        LEX
# P000038                          6        LEX
# ...                            ...        ...                  ...
# X400009                    Nin-nin        LEX
# X400010                    Nin-nin        LEX
# X400011                    Nin-nin        LEX
# X400012                    Nin-nin        LEX
# X400013                   Ba-[...]        LEX
# X400014  Theophoric Personal Names        LEX
# X400015  Theophoric Personal Names        LEX
# X400016  Theophoric Personal Names        LEX
# X400017  Theophoric Personal Names        LEX
# X400018  Theophoric Personal Names        LEX
# X400019  Theophoric Personal Names        LEX
# X400020  Theophoric Personal Names        LEX
# X400021  Theophoric Personal Names        LEX
# X400022  Theophoric Personal Names        LEX
# X400023  Theophoric Personal Names        LEX
# X400024  Theophoric Personal Names        LEX
# X400025  Theophoric Personal Names        LEX
# X400026  Theophoric Personal Names        LEX
# X400027  Theophoric Personal Names        LEX
# X400028  Theophoric Personal Names        LEX
# X800010                         02        LEX
# X800054                         02        LEX
# X800072                         02        LEX
# X800083                         01        LEX
# X800085                         02        LEX
# X999901                        L 2        LEX
# X999902                        L 3        LEX
# X999903                        L 4        LEX
# X999905                        L 1        LEX
# X999906                        L 6        LEX
#
#                      text_remarks thickness trans  \
# P000001                                  18
# P000002                                  13
# P000003                                  19
# P000004                                  23
# P000005                                  20
# P000006                                  19
# P000007                                  29
# P000008                                   9
# P000009
# P000010                                  19
# P000011                                  24
# P000012                                  14
# P000013                                  16
# P000014                                  15
# P000015                                  30
# P000019                                  17
# P000020                                  20
# P000021                                  20
# P000022                                  21
# P000023                                  17
# P000024                                  16
# P000025                                  33
# P000030
# P000031
# P000033
# P000034
# P000035
# P000036                                  33
# P000037                                  18
# P000038                                  16
# ...                           ...       ...   ...
# X400009
# X400010
# X400011
# X400012
# X400013  Rev: Syllable Alphabet B
# X400014
# X400015
# X400016
# X400017
# X400018
# X400019
# X400020
# X400021
# X400022
# X400023
# X400024
# X400025
# X400026
# X400027
# X400028
# X800010
# X800054
# X800072
# X800083
# X800085
# X999901                To Ura 7-8
# X999902               To Ura 8-10
# X999903                 To Ura 11
# X999905               To Ura 7A-B
# X999906                To Ura 8-9
#
#                                   uri width xproject
# P000001  http://cdli.ucla.edu/P000001    61     CDLI
# P000002  http://cdli.ucla.edu/P000002    48     CDLI
# P000003  http://cdli.ucla.edu/P000003    53     CDLI
# P000004  http://cdli.ucla.edu/P000004    23     CDLI
# P000005  http://cdli.ucla.edu/P000005    36     CDLI
# P000006  http://cdli.ucla.edu/P000006    62     CDLI
# P000007  http://cdli.ucla.edu/P000007    36     CDLI
# P000008  http://cdli.ucla.edu/P000008    26     CDLI
# P000009  http://cdli.ucla.edu/P000009    46     CDLI
# P000010  http://cdli.ucla.edu/P000010    25     CDLI
# P000011  http://cdli.ucla.edu/P000011    56     CDLI
# P000012  http://cdli.ucla.edu/P000012    31     CDLI
# P000013  http://cdli.ucla.edu/P000013    38     CDLI
# P000014  http://cdli.ucla.edu/P000014    51     CDLI
# P000015  http://cdli.ucla.edu/P000015    99     CDLI
# P000019  http://cdli.ucla.edu/P000019    25     CDLI
# P000020  http://cdli.ucla.edu/P000020    24     CDLI
# P000021  http://cdli.ucla.edu/P000021    43     CDLI
# P000022  http://cdli.ucla.edu/P000022    52     CDLI
# P000023  http://cdli.ucla.edu/P000023    57     CDLI
# P000024  http://cdli.ucla.edu/P000024    28     CDLI
# P000025  http://cdli.ucla.edu/P000025    92     CDLI
# P000030  http://cdli.ucla.edu/P000030    32     CDLI
# P000031  http://cdli.ucla.edu/P000031    50     CDLI
# P000033  http://cdli.ucla.edu/P000033    26     CDLI
# P000034  http://cdli.ucla.edu/P000034    24     CDLI
# P000035  http://cdli.ucla.edu/P000035    62     CDLI
# P000036  http://cdli.ucla.edu/P000036    54     CDLI
# P000037  http://cdli.ucla.edu/P000037    28     CDLI
# P000038  http://cdli.ucla.edu/P000038    22     CDLI
# ...                               ...   ...      ...
# X400009
# X400010
# X400011
# X400012
# X400013
# X400014
# X400015
# X400016
# X400017
# X400018
# X400019
# X400020
# X400021
# X400022
# X400023
# X400024
# X400025
# X400026
# X400027
# X400028
# X800010
# X800054
# X800072
# X800083
# X800085
# X999901
# X999902
# X999903
# X999905
# X999906
#
# [9261 rows x 79 columns]

# %% [markdown]
# ## Select Relevant Fields
# [ORACC](http://oracc.org) catalogs may have custom fields, the only fields that are obligatory are `id_text` (the P, Q, or X number that identifies the text, for instance "P243546") and `designation` (the human-readable reference, for instance "VS 17, 012"). In order to find out which fields are available one may list the column names of the DataFrame.
#
# First display all available fields, then select the ones that are relevant for the task at hand.

# %%
df.columns
# Out:
# Index(['accession_no', 'acquisition_history', 'archive', 'ark', 'atf_source',
#        'atf_up', 'author', 'author_remarks', 'cdli_collation', 'cdli_comments',
#        'citation', 'collection', 'collection_copyright',
#        'condition_description', 'created_by', 'created_on', 'credits',
#        'date_entered', 'date_of_origin', 'date_remarks', 'date_updated',
#        'dates_referenced', 'db_source', 'designation',
#        'electronic_publication', 'elevation', 'excavation_no', 'external_id',
#        'findspot_remarks', 'findspot_square', 'genre',
#        'google_earth_collection', 'google_earth_provenience', 'height',
#        'id_composite', 'id_text', 'images', 'join_information', 'keywords',
#        'langs', 'language', 'last_modified_by', 'last_modified_on',
#        'lineart_up', 'material', 'museum_no', 'notes', 'object_preservation',
#        'object_remarks', 'object_type', 'other_names', 'period',
#        'period_remarks', 'photo_up', 'place', 'primary_edition',
#        'primary_publication', 'project', 'provenience', 'provenience_remarks',
#        'public', 'publication_date', 'publication_history',
#        'published_collation', 'seal_id', 'seal_information', 'series',
#        'series_section', 'status', 'subgenre', 'subgenre_remarks',
#        'supergenre', 'surface_preservation', 'text_remarks', 'thickness',
#        'trans', 'uri', 'width', 'xproject'],
#       dtype='object')

# %%
df1 = df[['designation', 'period', 'provenience',
        'museum_no', 'project', 'id_text']]
df1
# Out:
#                        designation          period provenience  \
# P000001                  W 06435,a        Uruk III        Uruk
# P000002                  W 06435,b        Uruk III        Uruk
# P000003                  W 09123,d         Uruk IV        Uruk
# P000004                  W 09169,d         Uruk IV        Uruk
# P000005                  W 09206,k         Uruk IV        Uruk
# P000006                 W 09656,h1         Uruk IV        Uruk
# P000007                  W 09656,x         Uruk IV        Uruk
# P000008                  W 11985,e        Uruk III        Uruk
# P000009                  W 11985,f        Uruk III        Uruk
# P000010                  W 11985,g        Uruk III        Uruk
# P000011                  W 11986,a        Uruk III        Uruk
# P000012                  W 11986,c        Uruk III        Uruk
# P000013                  W 11988,d        Uruk III        Uruk
# P000014                    W 12139        Uruk III        Uruk
# P000015      W 12256,i + k + l + o        Uruk III        Uruk
# P000019                 W 13662,c1        Uruk III        Uruk
# P000020                 W 13662,v1        Uruk III        Uruk
# P000021                    W 13948        Uruk III        Uruk
# P000022                    W 13982        Uruk III        Uruk
# P000023                    W 14264        Uruk III        Uruk
# P000024                  W 14335,c        Uruk III        Uruk
# P000025  W 14337,a + b + c + d + e        Uruk III        Uruk
# P000030                    W 14497        Uruk III        Uruk
# P000031            W 14551,a + b ?        Uruk III        Uruk
# P000033                    W 14638        Uruk III        Uruk
# P000034                  W 14731,x        Uruk III        Uruk
# P000035                  W 14777,b        Uruk III        Uruk
# P000036                    W 15085        Uruk III        Uruk
# P000037                  W 15772,l        Uruk III        Uruk
# P000038                  W 15773,c        Uruk III        Uruk
# ...                            ...             ...         ...
# X400009               Ist Ni 02658  Old Babylonian      Nippur
# X400010               Ist Ni 04606  Old Babylonian      Nippur
# X400011               Ist Ni 05247  Old Babylonian      Nippur
# X400012               Ist Ni 05318  Old Babylonian      Nippur
# X400013               Ist Ni 05318  Old Babylonian      Nippur
# X400014               Ist Ni 03882  Old Babylonian      Nippur
# X400015               Ist Ni 03910  Old Babylonian      Nippur
# X400016               Ist Ni 03918  Old Babylonian      Nippur
# X400017               Ist Ni 03964  Old Babylonian      Nippur
# X400018               Ist Ni 04791  Old Babylonian      Nippur
# X400019               Ist Ni 04889  Old Babylonian      Nippur
# X400020               Ist Ni 04972  Old Babylonian      Nippur
# X400021               Ist Ni 05070  Old Babylonian      Nippur
# X400022               Ist Ni 05079  Old Babylonian      Nippur
# X400023               Ist Ni 05129  Old Babylonian      Nippur
# X400024               Ist Ni 05180  Old Babylonian      Nippur
# X400025               Ist Ni 10125  Old Babylonian      Nippur
# X400026               Ist Ni 10185  Old Babylonian      Nippur
# X400027               Ist Ni 10493  Old Babylonian      Nippur
# X400028               Ist Ni 10939  Old Babylonian      Nippur
# X800010                  BM 036576  Neo-Babylonian   uncertain
# X800054                  BM 037956  Neo-Babylonian   uncertain
# X800072                  BM 038591  Neo-Babylonian   uncertain
# X800083                  BM 046740  Neo-Babylonian   uncertain
# X800085                  BM 047733  Neo-Babylonian   uncertain
# X999901                  BM 034129  Neo-Babylonian     unclear
# X999902                  BM 034082  Neo-Babylonian     unclear
# X999903                  BM 034917  Neo-Babylonian     unclear
# X999905                  BM 045859  Neo-Babylonian     unclear
# X999906                  BM 076024  Neo-Babylonian     unclear
#
#                      museum_no project  id_text
# P000001              VAT 01533   dcclt  P000001
# P000002              VAT 15263   dcclt  P000002
# P000003              VAT 15253   dcclt  P000003
# P000004              VAT 15168   dcclt  P000004
# P000005              VAT 15153   dcclt  P000005
# P000006              VAT 15003   dcclt  P000006
# P000007              VAT 15111   dcclt  P000007
# P000008              VAT 17684   dcclt  P000008
# P000009              VAT 17702   dcclt  P000009
# P000010              VAT 17709   dcclt  P000010
# P000011              VAT 17685   dcclt  P000011
# P000012              VAT 17619   dcclt  P000012
# P000013              VAT 17729   dcclt  P000013
# P000014              VAT 16773   dcclt  P000014
# P000015  VAT 17858 + VAT 17886   dcclt  P000015
# P000019              VAT 17630   dcclt  P000019
# P000020              VAT 17699   dcclt  P000020
# P000021              VAT 16972   dcclt  P000021
# P000022              VAT 16741   dcclt  P000022
# P000023              VAT 16759   dcclt  P000023
# P000024              VAT 17588   dcclt  P000024
# P000025              VAT 16912   dcclt  P000025
# P000030                 VA — ?   dcclt  P000030
# P000031                 VA — ?   dcclt  P000031
# P000033                 VA — ?   dcclt  P000033
# P000034                 VA — ?   dcclt  P000034
# P000035              VAT 16828   dcclt  P000035
# P000036              VAT 16945   dcclt  P000036
# P000037              VAT 16902   dcclt  P000037
# P000038           IM 023436,14   dcclt  P000038
# ...                        ...     ...      ...
# X400009           Ist Ni 02658   dcclt  X400009
# X400010           Ist Ni 04606   dcclt  X400010
# X400011           Ist Ni 05247   dcclt  X400011
# X400012           Ist Ni 05318   dcclt  X400012
# X400013           Ist Ni 03854   dcclt  X400013
# X400014           Ist Ni 03882   dcclt  X400014
# X400015           Ist Ni 03910   dcclt  X400015
# X400016           Ist Ni 03918   dcclt  X400016
# X400017           Ist Ni 03964   dcclt  X400017
# X400018           Ist Ni 04791   dcclt  X400018
# X400019           Ist Ni 04889   dcclt  X400019
# X400020           Ist Ni 04972   dcclt  X400020
# X400021           Ist Ni 05070   dcclt  X400021
# X400022           Ist Ni 05079   dcclt  X400022
# X400023           Ist Ni 05129   dcclt  X400023
# X400024           Ist Ni 05180   dcclt  X400024
# X400025           Ist Ni 10125   dcclt  X400025
# X400026           Ist Ni 10185   dcclt  X400026
# X400027           Ist Ni 10493   dcclt  X400027
# X400028           Ist Ni 10939   dcclt  X400028
# X800010              BM 036576   dcclt  X800010
# X800054              BM 037956   dcclt  X800054
# X800072              BM 038591   dcclt  X800072
# X800083              BM 047733   dcclt  X800083
# X800085              BM 047733   dcclt  X800085
# X999901              BM 034129   dcclt  X999901
# X999902              BM 034082   dcclt  X999902
# X999903              BM 034917   dcclt  X999903
# X999905              BM 045859   dcclt  X999905
# X999906              BM 076024   dcclt  X999906
#
# [9261 rows x 6 columns]

# %% [markdown]
# ## Manipulate
# The Dataframe may now be manipulated with standard Pandas methods. The example code selects the texts from Ur.
# > `ur = df1[df1.provenience == "Ur"]`

# %% [markdown]
# ## Save
# Save the resulting data set as a `csv` file. `UTF-8` encoding is the encoding with the widest support in text analysis (and also the encoding used by [ORACC](http://oracc.org)). If you intend to use the catalog file in Excel, however, it is better to use `utf-16` encoding.

# %%
filename = 'catalog.csv'
with open('output/' + filename, 'w', encoding='utf-8') as w:
    df1.to_csv(w, index=False)
