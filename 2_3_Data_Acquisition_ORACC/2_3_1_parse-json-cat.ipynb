# %% [markdown]
# # Retrieve Catalog Data from `catalogue.json`
#
# The file `catalogue.json` contains all the catalog data for an [ORACC](http://oracc.org) project (for general information, see the [Oracc Open Data](http://oracc.org/doc/opendata) page). The `zip` that contains all JSON files of a particular project can be found at `http://build-oracc.museum.upenn.edu/json/[PROJECT].zip`. In the URL replace [PROJECT] with your project or sub-project name (e.g. `dcclt` or `cams/gkab`).
#
# The main node in a `catalogue.json` file is called `members`. This node contains the information of all the fields and all the entries in the project catalog.

# %%
import pandas as pd
import zipfile
import json
import requests
import errno
import os
import tqdm

# %% [markdown]
# ## 0 Create Directories, if Necessary
# The two directories needed for this script are `jsonzip` and `output`. If they do not exist they are created, else: do nothing.
#
# For the code, see [Stack Overflow](http://stackoverflow.com/questions/18973418/os-mkdirpath-returns-oserror-when-directory-does-not-exist).

# %%
directories = ['jsonzip', 'output']
for d in directories:
    try:
        os.mkdir(d)
    except OSError as exc:
        if exc.errno !=errno.EEXIST:
            raise
        pass

# %% [markdown]
# ## 1.1 Input Project Name
# We will download and manipulate one catalog file at a time. Different [ORACC](http://oracc.org) projects use different fields in their catalogs, the catalogs are not mutually compatible.
#
# Provide a project name. Note that subprojects must be processed separately, they are not included in the main project. A subproject is named `[PROJECT]/[SUBPROJECT]`, for instance `saao/saa01`.

# %%
projects = input('Project(s): ').lower().strip() # lowercase user input and strip accidental spaces
# Out:
# Project(s): saao/saa11

# %% [markdown]
# ## 1.2 Split the List of Projects
# Split the list of projects and create a list of project names.

# %%
p = projects.split(',')               # split at each comma and make a list called `p`
p = [x.strip() for x in p]        # strip spaces left and right of each entry in `p`

# %% [markdown]
# ## 1.2 Download the ZIP files
# Download all the `json` files from `http://build-oracc.museum.upenn.edu/json/`. The file is called `[PROJECT].zip` (for instance: `dcclt.zip`). For subprojects the file is called `[PROJECT-SUBPROJECT].zip` (for instance `cams-gkab.zip`).
#
# For larger projects (such as [DCCLT](http://oracc.org/dcclt)) the `zip` file may be 25Mb or more. Downloading may take some time and it may be necessary to chunk the downloading process. The `iter_content()` function in the `requests` library takes care of that. For the chunking code see [this page](https://www.smallsurething.com/how-to-read-a-file-properly-in-python/).
#
# If you have downloaded the files by hand (and put them in the `jsonzip` directory) you may skip this cell and jump directly to section ...

# %%
non_existent = []
CHUNK = 16 * 1024
for project in tqdm.tqdm(p):
    project = project.replace('/', '-')
    url = "http://build-oracc.museum.upenn.edu/json/" + project + ".zip"
    file = 'jsonzip/' + project + '.zip'
    r = requests.get(url)
    if r.status_code == 200:
        print("Downloading " + url + " saving as " + file)
        with open(file, 'wb') as f:
            for c in r.iter_content(chunk_size=CHUNK):
                f.write(c)
    else:
        print(url + " does not exist.")
        non_existent.append(project)
p = [i for i in p if i not in non_existent] # remove non-existing project names from list
# Out:
#   0%|                                                    | 0/1 [00:00<?, ?it/s]
# Downloading http://build-oracc.museum.upenn.edu/json/saao-saa11.zip saving as jsonzip/saao-saa11.zip
# 100%|████████████████████████████████████████████| 1/1 [00:02<00:00,  2.06s/it]

# %% [markdown]
# ## 2 Extract Catalogue Data from `JSON` files
# The code in this cell will iterate through the list of projects entered above (1.1). For each project the `JSON` zip file, named `[PROJECT].zip` is located in the directory `jsonzip`. Each of these `zip` files includes a file called `catalogue.json`. This file is extracted and read with the command `json.loads()`, which reads the json data and transforms it into a JSON object - a sequence of names and values.
#
# The JSON object is transformed into a Pandas Dataframe. The dataframe needs to be transposed (`.T`), so that the P, Q, and X numbers become indexes or row names (rather than column names), and each column represents a field in the catalog.  The individual dataframes (one for each project requested) are concatenated. Since individual [ORACC](http://oracc.org) project catalogs may have different fields, the dataframes may have different column names. By default Pandas concatenation uses an `outer join` so that all column names of all the catalogs are preserved.

# %%
df = pd.DataFrame() # create an empty dataframe
for project in p:
    file = "jsonzip/" + project.replace("/", "-") + ".zip"
    try:
        z = zipfile.ZipFile(file)       # create a Zipfile object
    except:
        print(file + " does not exist or is not a proper ZIP file")
        continue
    try:
        st = z.read(project + '/catalogue.json').decode('utf-8')  #read and decode the catalogue.json file of one project
                                                                # the result is a string object
    except:
        print(project + '/catalogue.json' + ' is not available or not complete')
        continue
    cat = json.loads(st)
    cat = cat['members']  # select the 'members' node 
    for item in cat.values():
        item["project"] = project # add project name as separate field
    cat_df = pd.DataFrame(cat).T
    df = pd.concat([df, cat_df])

# %% [markdown]
# ## Create Dataframe
#  Creating a Dataframe is not necessary, one may also manipulate the dictionary directly, but for demonstration purposes the Dataframe is a handy format. In manipulating the dictionary directly it is important to keep in mind that not all catalog fields have data for all entries, which means that not all dictionary keys are available for each P, Q, or X number.
#
# The function `fillna('')` will put a blank (instead of `NaN`) in all fields that have no entry.
#
# Example code for slicing the dictionary to select all entries that have `provenience = 'Ur'`:
# > `urcat = {key:value for key, value in d.items() if 'provenience' in d[key] and d[key]['provenience'] == 'Ur'}

# %%
df = df.fillna('')
df
# Out:
#                                  ch_name   ch_no  \
# P237876     Schedules of Land and People  Ch. 10
# P313588  Deportees and Displaced Persons   Ch. 8
# P313651               Geographical Lists   Ch. 1
# P313736                    Harran Census   Ch. 9
# P313842                   Building Texts   Ch. 2
# P313928                 Domestic Animals   Ch. 5
# P314083        Miscellaneous Commodities   Ch. 3
# P314131  Deportees and Displaced Persons   Ch. 8
# P314132        Miscellaneous Commodities   Ch. 3
# P314197  Deportees and Displaced Persons   Ch. 8
# P314226        Miscellaneous Commodities   Ch. 3
# P333950               Geographical Lists   Ch. 1
# P334311  Deportees and Displaced Persons   Ch. 8
# P334436  Deportees and Displaced Persons   Ch. 8
# P334437        Miscellaneous Commodities   Ch. 3
# P334934                    Harran Census   Ch. 9
# P334935                    Harran Census   Ch. 9
# P334936                    Harran Census   Ch. 9
# P334937                    Harran Census   Ch. 9
# P334938                    Harran Census   Ch. 9
# P334939                    Harran Census   Ch. 9
# P334940     Schedules of Land and People  Ch. 10
# P334941                    Harran Census   Ch. 9
# P334942                    Harran Census   Ch. 9
# P334943                    Harran Census   Ch. 9
# P334944                    Harran Census   Ch. 9
# P334945                    Harran Census   Ch. 9
# P334946                    Harran Census   Ch. 9
# P334947                    Harran Census   Ch. 9
# P334948                    Harran Census   Ch. 9
# ...                                  ...     ...
# P336704                         Sealings   Ch. 4
# P336705                         Sealings   Ch. 4
# P336706                         Sealings   Ch. 4
# P336707                         Sealings   Ch. 4
# P336708                 Domestic Animals   Ch. 5
# P336709                 Domestic Animals   Ch. 5
# P336710                 Domestic Animals   Ch. 5
# P336711                 Domestic Animals   Ch. 5
# P336712                           Horses   Ch. 6
# P336713               Military Personnel   Ch. 7
# P336714               Military Personnel   Ch. 7
# P336715               Military Personnel   Ch. 7
# P336716               Military Personnel   Ch. 7
# P336717  Deportees and Displaced Persons   Ch. 8
# P336718  Deportees and Displaced Persons   Ch. 8
# P336719  Deportees and Displaced Persons   Ch. 8
# P336720  Deportees and Displaced Persons   Ch. 8
# P336721  Deportees and Displaced Persons   Ch. 8
# P336722  Deportees and Displaced Persons   Ch. 8
# P336723  Deportees and Displaced Persons   Ch. 8
# P336724     Schedules of Land and People  Ch. 10
# P336799        Miscellaneous Commodities   Ch. 3
# P336801               Geographical Lists   Ch. 1
# P336803        Miscellaneous Commodities   Ch. 3
# P336804                 Domestic Animals   Ch. 5
# P336805                           Horses   Ch. 6
# P336806                 Domestic Animals   Ch. 5
# P336807                 Domestic Animals   Ch. 5
# P336808                 Domestic Animals   Ch. 5
# P337167        Miscellaneous Commodities   Ch. 3
#
#                                      ch_num_name  \
# P237876    Ch. 10 (Schedules of Land and People)
# P313588  Ch. 8 (Deportees and Displaced Persons)
# P313651               Ch. 1 (Geographical Lists)
# P313736                    Ch. 9 (Harran Census)
# P313842                   Ch. 2 (Building Texts)
# P313928                 Ch. 5 (Domestic Animals)
# P314083        Ch. 3 (Miscellaneous Commodities)
# P314131  Ch. 8 (Deportees and Displaced Persons)
# P314132        Ch. 3 (Miscellaneous Commodities)
# P314197  Ch. 8 (Deportees and Displaced Persons)
# P314226        Ch. 3 (Miscellaneous Commodities)
# P333950               Ch. 1 (Geographical Lists)
# P334311  Ch. 8 (Deportees and Displaced Persons)
# P334436  Ch. 8 (Deportees and Displaced Persons)
# P334437        Ch. 3 (Miscellaneous Commodities)
# P334934                    Ch. 9 (Harran Census)
# P334935                    Ch. 9 (Harran Census)
# P334936                    Ch. 9 (Harran Census)
# P334937                    Ch. 9 (Harran Census)
# P334938                    Ch. 9 (Harran Census)
# P334939                    Ch. 9 (Harran Census)
# P334940    Ch. 10 (Schedules of Land and People)
# P334941                    Ch. 9 (Harran Census)
# P334942                    Ch. 9 (Harran Census)
# P334943                    Ch. 9 (Harran Census)
# P334944                    Ch. 9 (Harran Census)
# P334945                    Ch. 9 (Harran Census)
# P334946                    Ch. 9 (Harran Census)
# P334947                    Ch. 9 (Harran Census)
# P334948                    Ch. 9 (Harran Census)
# ...                                          ...
# P336704                         Ch. 4 (Sealings)
# P336705                         Ch. 4 (Sealings)
# P336706                         Ch. 4 (Sealings)
# P336707                         Ch. 4 (Sealings)
# P336708                 Ch. 5 (Domestic Animals)
# P336709                 Ch. 5 (Domestic Animals)
# P336710                 Ch. 5 (Domestic Animals)
# P336711                 Ch. 5 (Domestic Animals)
# P336712                           Ch. 6 (Horses)
# P336713               Ch. 7 (Military Personnel)
# P336714               Ch. 7 (Military Personnel)
# P336715               Ch. 7 (Military Personnel)
# P336716               Ch. 7 (Military Personnel)
# P336717  Ch. 8 (Deportees and Displaced Persons)
# P336718  Ch. 8 (Deportees and Displaced Persons)
# P336719  Ch. 8 (Deportees and Displaced Persons)
# P336720  Ch. 8 (Deportees and Displaced Persons)
# P336721  Ch. 8 (Deportees and Displaced Persons)
# P336722  Ch. 8 (Deportees and Displaced Persons)
# P336723  Ch. 8 (Deportees and Displaced Persons)
# P336724    Ch. 10 (Schedules of Land and People)
# P336799        Ch. 3 (Miscellaneous Commodities)
# P336801               Ch. 1 (Geographical Lists)
# P336803        Ch. 3 (Miscellaneous Commodities)
# P336804                 Ch. 5 (Domestic Animals)
# P336805                           Ch. 6 (Horses)
# P336806                 Ch. 5 (Domestic Animals)
# P336807                 Ch. 5 (Domestic Animals)
# P336808                 Ch. 5 (Domestic Animals)
# P337167        Ch. 3 (Miscellaneous Commodities)
#
#                                                    credits         date  \
# P237876  Copyright F. Mario Fales and J. Nicholas Postg...
# P313588  Copyright F. Mario Fales and J. Nicholas Postg...
# P313651  Copyright F. Mario Fales and J. Nicholas Postg...
# P313736  Copyright F. Mario Fales and J. Nicholas Postg...
# P313842  Copyright F. Mario Fales and J. Nicholas Postg...
# P313928  Copyright F. Mario Fales and J. Nicholas Postg...
# P314083  Copyright F. Mario Fales and J. Nicholas Postg...
# P314131  Copyright F. Mario Fales and J. Nicholas Postg...
# P314132  Copyright F. Mario Fales and J. Nicholas Postg...
# P314197  Copyright F. Mario Fales and J. Nicholas Postg...
# P314226  Copyright F. Mario Fales and J. Nicholas Postg...
# P333950  Copyright F. Mario Fales and J. Nicholas Postg...
# P334311  Copyright F. Mario Fales and J. Nicholas Postg...
# P334436  Copyright F. Mario Fales and J. Nicholas Postg...
# P334437  Copyright F. Mario Fales and J. Nicholas Postg...
# P334934  Copyright F. Mario Fales and J. Nicholas Postg...
# P334935  Copyright F. Mario Fales and J. Nicholas Postg...
# P334936  Copyright F. Mario Fales and J. Nicholas Postg...
# P334937  Copyright F. Mario Fales and J. Nicholas Postg...
# P334938  Copyright F. Mario Fales and J. Nicholas Postg...
# P334939  Copyright F. Mario Fales and J. Nicholas Postg...
# P334940  Copyright F. Mario Fales and J. Nicholas Postg...
# P334941  Copyright F. Mario Fales and J. Nicholas Postg...
# P334942  Copyright F. Mario Fales and J. Nicholas Postg...
# P334943  Copyright F. Mario Fales and J. Nicholas Postg...
# P334944  Copyright F. Mario Fales and J. Nicholas Postg...
# P334945  Copyright F. Mario Fales and J. Nicholas Postg...
# P334946  Copyright F. Mario Fales and J. Nicholas Postg...
# P334947  Copyright F. Mario Fales and J. Nicholas Postg...
# P334948  Copyright F. Mario Fales and J. Nicholas Postg...
# ...                                                    ...          ...
# P336704  Copyright F. Mario Fales and J. Nicholas Postg...
# P336705  Copyright F. Mario Fales and J. Nicholas Postg...
# P336706  Copyright F. Mario Fales and J. Nicholas Postg...    000-12-18
# P336707  Copyright F. Mario Fales and J. Nicholas Postg...
# P336708  Copyright F. Mario Fales and J. Nicholas Postg...
# P336709  Copyright F. Mario Fales and J. Nicholas Postg...
# P336710  Copyright F. Mario Fales and J. Nicholas Postg...
# P336711  Copyright F. Mario Fales and J. Nicholas Postg...
# P336712  Copyright F. Mario Fales and J. Nicholas Postg...
# P336713  Copyright F. Mario Fales and J. Nicholas Postg...
# P336714  Copyright F. Mario Fales and J. Nicholas Postg...
# P336715  Copyright F. Mario Fales and J. Nicholas Postg...
# P336716  Copyright F. Mario Fales and J. Nicholas Postg...
# P336717  Copyright F. Mario Fales and J. Nicholas Postg...
# P336718  Copyright F. Mario Fales and J. Nicholas Postg...
# P336719  Copyright F. Mario Fales and J. Nicholas Postg...
# P336720  Copyright F. Mario Fales and J. Nicholas Postg...
# P336721  Copyright F. Mario Fales and J. Nicholas Postg...
# P336722  Copyright F. Mario Fales and J. Nicholas Postg...
# P336723  Copyright F. Mario Fales and J. Nicholas Postg...
# P336724  Copyright F. Mario Fales and J. Nicholas Postg...
# P336799  Copyright F. Mario Fales and J. Nicholas Postg...
# P336801  Copyright F. Mario Fales and J. Nicholas Postg...
# P336803  Copyright F. Mario Fales and J. Nicholas Postg...
# P336804  Copyright F. Mario Fales and J. Nicholas Postg...  *636-11--00
# P336805  Copyright F. Mario Fales and J. Nicholas Postg...   *636-11-00
# P336806  Copyright F. Mario Fales and J. Nicholas Postg...
# P336807  Copyright F. Mario Fales and J. Nicholas Postg...
# P336808  Copyright F. Mario Fales and J. Nicholas Postg...
# P337167  Copyright F. Mario Fales and J. Nicholas Postg...
#
#         designation display_name                  genre  id_text images  \
# P237876  SAA 11 227   SAA 11 227  administrative record  P237876     []
# P313588  SAA 11 145   SAA 11 145  administrative record  P313588     []
# P313651  SAA 11 012   SAA 11 012  administrative record  P313651     []
# P313736  SAA 11 200   SAA 11 200  administrative record  P313736     []
# P313842  SAA 11 019   SAA 11 019  administrative record  P313842     []
# P313928  SAA 11 099   SAA 11 099  administrative record  P313928     []
# P314083  SAA 11 047   SAA 11 047  administrative record  P314083     []
# P314131  SAA 11 152   SAA 11 152  administrative record  P314131     []
# P314132  SAA 11 034   SAA 11 034  administrative record  P314132     []
# P314197  SAA 11 168   SAA 11 168  administrative record  P314197     []
# P314226  SAA 11 035   SAA 11 035  administrative record  P314226     []
# P333950  SAA 11 001   SAA 11 001  administrative record  P333950
# P334311  SAA 11 156   SAA 11 156  administrative record  P334311     []
# P334436  SAA 11 162   SAA 11 162  administrative record  P334436     []
# P334437  SAA 11 033   SAA 11 033  administrative record  P334437     []
# P334934  SAA 11 201   SAA 11 201  administrative record  P334934
# P334935  SAA 11 202   SAA 11 202  administrative record  P334935     []
# P334936  SAA 11 203   SAA 11 203  administrative record  P334936     []
# P334937  SAA 11 213   SAA 11 213  administrative record  P334937     []
# P334938  SAA 11 219   SAA 11 219  administrative record  P334938     []
# P334939  SAA 11 207   SAA 11 207  administrative record  P334939     []
# P334940  SAA 11 220   SAA 11 220  administrative record  P334940
# P334941  SAA 11 206   SAA 11 206  administrative record  P334941     []
# P334942  SAA 11 209   SAA 11 209  administrative record  P334942     []
# P334943  SAA 11 210   SAA 11 210  administrative record  P334943
# P334944  SAA 11 205   SAA 11 205  administrative record  P334944     []
# P334945  SAA 11 208   SAA 11 208  administrative record  P334945     []
# P334946  SAA 11 215   SAA 11 215  administrative record  P334946     []
# P334947  SAA 11 217   SAA 11 217  administrative record  P334947     []
# P334948  SAA 11 212   SAA 11 212  administrative record  P334948     []
# ...             ...          ...                    ...      ...    ...
# P336704  SAA 11 072   SAA 11 072  administrative record  P336704
# P336705  SAA 11 073   SAA 11 073  administrative record  P336705
# P336706  SAA 11 074   SAA 11 074  administrative record  P336706
# P336707  SAA 11 075   SAA 11 075  administrative record  P336707
# P336708  SAA 11 082   SAA 11 082  administrative record  P336708     []
# P336709  SAA 11 083   SAA 11 083  administrative record  P336709     []
# P336710  SAA 11 097   SAA 11 097  administrative record  P336710     []
# P336711  SAA 11 104   SAA 11 104  administrative record  P336711     []
# P336712  SAA 11 118   SAA 11 118  administrative record  P336712     []
# P336713  SAA 11 129   SAA 11 129  administrative record  P336713     []
# P336714  SAA 11 130   SAA 11 130  administrative record  P336714
# P336715  SAA 11 131   SAA 11 131  administrative record  P336715     []
# P336716  SAA 11 142   SAA 11 142  administrative record  P336716     []
# P336717  SAA 11 161   SAA 11 161  administrative record  P336717     []
# P336718  SAA 11 164   SAA 11 164  administrative record  P336718
# P336719  SAA 11 186   SAA 11 186  administrative record  P336719     []
# P336720  SAA 11 195   SAA 11 195  administrative record  P336720     []
# P336721  SAA 11 196   SAA 11 196  administrative record  P336721     []
# P336722  SAA 11 197   SAA 11 197  administrative record  P336722
# P336723  SAA 11 199   SAA 11 199  administrative record  P336723     []
# P336724  SAA 11 234   SAA 11 234  administrative record  P336724     []
# P336799  SAA 11 030   SAA 11 030  administrative record  P336799
# P336801  SAA 11 014   SAA 11 014  administrative record  P336801     []
# P336803  SAA 11 024   SAA 11 024  administrative record  P336803
# P336804  SAA 11 100   SAA 11 100  administrative record  P336804
# P336805  SAA 11 121   SAA 11 121  administrative record  P336805
# P336806  SAA 11 102   SAA 11 102  administrative record  P336806
# P336807  SAA 11 101   SAA 11 101  administrative record  P336807
# P336808  SAA 11 103   SAA 11 103  administrative record  P336808
# P337167  SAA 11 027   SAA 11 027  administrative record  P337167     []
#
#           ...   public publication_history          script script_remarks  \
# P237876   ...       no         SAA 11, 227  Neo-Babylonian      inscribed
# P313588   ...       no         SAA 11, 145    Neo-Assyrian      inscribed
# P313651   ...       no         SAA 11, 012    Neo-Assyrian      inscribed
# P313736   ...       no         SAA 11, 200    Neo-Assyrian      inscribed
# P313842   ...       no         SAA 11, 019    Neo-Assyrian      inscribed
# P313928   ...       no         SAA 11, 099    Neo-Assyrian      inscribed
# P314083   ...       no         SAA 11, 047    Neo-Assyrian      inscribed
# P314131   ...       no         SAA 11, 152    Neo-Assyrian      inscribed
# P314132   ...       no         SAA 11, 034    Neo-Assyrian      inscribed
# P314197   ...       no         SAA 11, 168    Neo-Assyrian      inscribed
# P314226   ...       no         SAA 11, 035    Neo-Assyrian      inscribed
# P333950   ...                  SAA 11, 001    Neo-Assyrian      inscribed
# P334311   ...       no         SAA 11, 156    Neo-Assyrian      inscribed
# P334436   ...       no         SAA 11, 162    Neo-Assyrian      inscribed
# P334437   ...       no         SAA 11, 033    Neo-Assyrian      inscribed
# P334934   ...                  SAA 11, 201    Neo-Assyrian      inscribed
# P334935   ...       no         SAA 11, 202    Neo-Assyrian      inscribed
# P334936   ...       no         SAA 11, 203    Neo-Assyrian      inscribed
# P334937   ...       no         SAA 11, 213    Neo-Assyrian      inscribed
# P334938   ...       no         SAA 11, 219    Neo-Assyrian      inscribed
# P334939   ...       no         SAA 11, 207    Neo-Assyrian      inscribed
# P334940   ...                  SAA 11, 220    Neo-Assyrian      inscribed
# P334941   ...       no         SAA 11, 206    Neo-Assyrian      inscribed
# P334942   ...       no         SAA 11, 209    Neo-Assyrian      inscribed
# P334943   ...                  SAA 11, 210    Neo-Assyrian      inscribed
# P334944   ...       no         SAA 11, 205    Neo-Assyrian      inscribed
# P334945   ...       no         SAA 11, 208    Neo-Assyrian      inscribed
# P334946   ...       no         SAA 11, 215    Neo-Assyrian      inscribed
# P334947   ...       no         SAA 11, 217    Neo-Assyrian      inscribed
# P334948   ...       no         SAA 11, 212    Neo-Assyrian      inscribed
# ...       ...      ...                 ...             ...            ...
# P336704   ...                  SAA 11, 072    Neo-Assyrian      inscribed
# P336705   ...                  SAA 11, 073    Neo-Assyrian      inscribed
# P336706   ...                  SAA 11, 074    Neo-Assyrian      inscribed
# P336707   ...                  SAA 11, 075    Neo-Assyrian      inscribed
# P336708   ...       no         SAA 11, 082    Neo-Assyrian      inscribed
# P336709   ...       no         SAA 11, 083    Neo-Assyrian      inscribed
# P336710   ...       no         SAA 11, 097    Neo-Assyrian      inscribed
# P336711   ...       no         SAA 11, 104  Neo-Babylonian      inscribed
# P336712   ...       no         SAA 11, 118    Neo-Assyrian      inscribed
# P336713   ...       no         SAA 11, 129    Neo-Assyrian      inscribed
# P336714   ...                  SAA 11, 130    Neo-Assyrian      inscribed
# P336715   ...       no         SAA 11, 131    Neo-Assyrian      inscribed
# P336716   ...       no         SAA 11, 142    Neo-Assyrian      inscribed
# P336717   ...       no         SAA 11, 161    Neo-Assyrian      inscribed
# P336718   ...                  SAA 11, 164    Neo-Assyrian      inscribed
# P336719   ...       no         SAA 11, 186    Neo-Assyrian      inscribed
# P336720   ...       no         SAA 11, 195    Neo-Assyrian      inscribed
# P336721   ...       no         SAA 11, 196    Neo-Assyrian      inscribed
# P336722   ...                  SAA 11, 197    Neo-Assyrian      inscribed
# P336723   ...       no         SAA 11, 199    Neo-Assyrian      inscribed
# P336724   ...       no         SAA 11, 234    Neo-Assyrian      inscribed
# P336799   ...                  SAA 11, 030    Neo-Assyrian      inscribed
# P336801   ...       no         SAA 11, 014    Neo-Assyrian      inscribed
# P336803   ...                  SAA 11, 024    Neo-Assyrian      inscribed
# P336804   ...                  SAA 11, 100    Neo-Assyrian      inscribed
# P336805   ...                  SAA 11, 121    Neo-Assyrian      inscribed
# P336806   ...                  SAA 11, 102    Neo-Assyrian      inscribed
# P336807   ...                  SAA 11, 101    Neo-Assyrian      inscribed
# P336808   ...                  SAA 11, 103    Neo-Assyrian      inscribed
# P337167   ...       no         SAA 11, 027    Neo-Assyrian      inscribed
#
#         script_type               short_title  \
# P237876   Cuneiform  Administrative Records 2
# P313588   Cuneiform  Administrative Records 2
# P313651   Cuneiform  Administrative Records 2
# P313736   Cuneiform  Administrative Records 2
# P313842   Cuneiform  Administrative Records 2
# P313928   Cuneiform  Administrative Records 2
# P314083   Cuneiform  Administrative Records 2
# P314131   Cuneiform  Administrative Records 2
# P314132   Cuneiform  Administrative Records 2
# P314197   Cuneiform  Administrative Records 2
# P314226   Cuneiform  Administrative Records 2
# P333950   Cuneiform  Administrative Records 2
# P334311   Cuneiform  Administrative Records 2
# P334436   Cuneiform  Administrative Records 2
# P334437   Cuneiform  Administrative Records 2
# P334934   Cuneiform  Administrative Records 2
# P334935   Cuneiform  Administrative Records 2
# P334936   Cuneiform  Administrative Records 2
# P334937   Cuneiform  Administrative Records 2
# P334938   Cuneiform  Administrative Records 2
# P334939   Cuneiform  Administrative Records 2
# P334940   Cuneiform  Administrative Records 2
# P334941   Cuneiform  Administrative Records 2
# P334942   Cuneiform  Administrative Records 2
# P334943   Cuneiform  Administrative Records 2
# P334944   Cuneiform  Administrative Records 2
# P334945   Cuneiform  Administrative Records 2
# P334946   Cuneiform  Administrative Records 2
# P334947   Cuneiform  Administrative Records 2
# P334948   Cuneiform  Administrative Records 2
# ...             ...                       ...
# P336704   Cuneiform  Administrative Records 2
# P336705   Cuneiform  Administrative Records 2
# P336706   Cuneiform  Administrative Records 2
# P336707   Cuneiform  Administrative Records 2
# P336708   Cuneiform  Administrative Records 2
# P336709   Cuneiform  Administrative Records 2
# P336710   Cuneiform  Administrative Records 2
# P336711   Cuneiform  Administrative Records 2
# P336712   Cuneiform  Administrative Records 2
# P336713   Cuneiform  Administrative Records 2
# P336714   Cuneiform  Administrative Records 2
# P336715   Cuneiform  Administrative Records 2
# P336716   Cuneiform  Administrative Records 2
# P336717   Cuneiform  Administrative Records 2
# P336718   Cuneiform  Administrative Records 2
# P336719   Cuneiform  Administrative Records 2
# P336720   Cuneiform  Administrative Records 2
# P336721   Cuneiform  Administrative Records 2
# P336722   Cuneiform  Administrative Records 2
# P336723   Cuneiform  Administrative Records 2
# P336724   Cuneiform  Administrative Records 2
# P336799   Cuneiform  Administrative Records 2
# P336801   Cuneiform  Administrative Records 2
# P336803   Cuneiform  Administrative Records 2
# P336804   Cuneiform  Administrative Records 2
# P336805   Cuneiform  Administrative Records 2
# P336806   Cuneiform  Administrative Records 2
# P336807   Cuneiform  Administrative Records 2
# P336808   Cuneiform  Administrative Records 2
# P337167   Cuneiform  Administrative Records 2
#
#                                                   title trans  \
# P237876                             Report on Sown Land  [en]
# P313588   Difficulty of Obtaining Justice? A Memorandum  [en]
# P313651            Note of Towns with Persons in Charge  [en]
# P313736                   From an Inventory of Families  [en]
# P313842                        Building Progress Report  [en]
# P313928           List of Commodities Including Animals  [en]
# P314083                       Fragment of Offering List  [en]
# P314131     Fragment of a List with Female Temple Staff  [en]
# P314132                  Tribute(?) Bowls from the West  [en]
# P314197            Deportees(?) from the North and East  [en]
# P314226          Fragment from Note of Contributions(?)  [en]
# P333950     Lexical List of Neo-Assyrian Provinces etc.  [en]
# P334311              Babylonians Working in the Library  [en]
# P334436     Dealings with the Arabs over Men and Camels  [en]
# P334437                      Gifts from Western Clients  [en]
# P334934                                   Census Tablet  [en]
# P334935                                   Census Tablet  [en]
# P334936                                   Census Tablet  [en]
# P334937                                   Census Tablet  [en]
# P334938                                   Census Tablet  [en]
# P334939                                   Census Tablet  [en]
# P334940                                   Census Tablet  [en]
# P334941                                   Census Tablet  [en]
# P334942                                   Census Tablet  [en]
# P334943                       Fragment of Census Tablet  [en]
# P334944                                   Census Tablet  [en]
# P334945                       Fragment of Census Tablet  [en]
# P334946                       Fragment of Census Tablet  [en]
# P334947                       Fragment of Census Tablet  [en]
# P334948                       Fragment of Census Tablet  [en]
# ...                                                 ...   ...
# P336704                         Fragmentary Jar Sealing  [en]
# P336705                             Fragmentary Sealing  [en]
# P336706                             Fragmentary Sealing  [en]
# P336707                                     Box Sealing  [en]
# P336708                       Fragment of Sheep List(?)  [en]
# P336709                          Fragment of Sheep List  [en]
# P336710  Various Contributions Including Oxen and Sheep  [en]
# P336711                        List of Tribute or Booty  [en]
# P336712           Fragment from List of Incoming Horses  [en]
# P336713                          Note of Chariot Troops  [en]
# P336714               Fragment of List of Army Officers  [en]
# P336715             Fragment of Military Personnel List  [en]
# P336716                                Note of Official  [en]
# P336717             Note of Men, Some from Dur-Šarruken  [en]
# P336718              Note of Men from Plunder of a Town  [en]
# P336719                             Five Recipients ...  [en]
# P336720          From a List of Men with their Families  [en]
# P336721                Eunuchs with their Households(?)  [en]
# P336722                              Note of Some Women  [en]
# P336723                   From an Inventory of Families  [en]
# P336724             Fragmentary List of Land and People  [en]
# P336799                              Tribute from Tabal  [en]
# P336801                            Itinerary to Mazamua  [en]
# P336803                                  Harvest Record  [en]
# P336804                       Note of Silver from Sheep  [en]
# P336805                     Note from the Review Palace  [en]
# P336806                                     Flock Tally  [en]
# P336807                                     Flock Tally  [en]
# P336808                                     Flock Tally  [en]
# P337167                     Note of Royal Accoutrements  [en]
#
#                                                  vol_title  volume
# P237876  Imperial Administrative Records, Part II: Prov...  SAA 11
# P313588  Imperial Administrative Records, Part II: Prov...  SAA 11
# P313651  Imperial Administrative Records, Part II: Prov...  SAA 11
# P313736  Imperial Administrative Records, Part II: Prov...  SAA 11
# P313842  Imperial Administrative Records, Part II: Prov...  SAA 11
# P313928  Imperial Administrative Records, Part II: Prov...  SAA 11
# P314083  Imperial Administrative Records, Part II: Prov...  SAA 11
# P314131  Imperial Administrative Records, Part II: Prov...  SAA 11
# P314132  Imperial Administrative Records, Part II: Prov...  SAA 11
# P314197  Imperial Administrative Records, Part II: Prov...  SAA 11
# P314226  Imperial Administrative Records, Part II: Prov...  SAA 11
# P333950  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334311  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334436  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334437  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334934  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334935  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334936  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334937  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334938  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334939  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334940  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334941  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334942  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334943  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334944  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334945  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334946  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334947  Imperial Administrative Records, Part II: Prov...  SAA 11
# P334948  Imperial Administrative Records, Part II: Prov...  SAA 11
# ...                                                    ...     ...
# P336704  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336705  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336706  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336707  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336708  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336709  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336710  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336711  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336712  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336713  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336714  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336715  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336716  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336717  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336718  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336719  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336720  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336721  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336722  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336723  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336724  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336799  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336801  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336803  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336804  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336805  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336806  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336807  Imperial Administrative Records, Part II: Prov...  SAA 11
# P336808  Imperial Administrative Records, Part II: Prov...  SAA 11
# P337167  Imperial Administrative Records, Part II: Prov...  SAA 11
#
# [234 rows x 32 columns]

# %% [markdown]
# ## Select Relevant Fields
# [ORACC](http://oracc.org) catalogs may have custom fields, the only fields that are obligatory are `id_text` (the P, Q, or X number that identifies the text, for instance "P243546") and `designation` (the human-readable reference, for instance "VS 17, 012"). In order to find out which fields are available one may list the column names of the DataFrame.
#
# First display all available fields, then select the ones that are relevant for the task at hand.

# %%
df.columns
# Out:
# Index(['ch_name', 'ch_no', 'ch_num_name', 'credits', 'date', 'designation',
#        'display_name', 'genre', 'id_text', 'images', 'last_mod_by',
#        'last_modified', 'material', 'museum_no', 'object_type', 'period',
#        'pleaides_id', 'pleiades_coord', 'pleiades_id', 'primary_publication',
#        'project', 'provenience', 'public', 'publication_history', 'script',
#        'script_remarks', 'script_type', 'short_title', 'title', 'trans',
#        'vol_title', 'volume'],
#       dtype='object')

# %%
df1 = df[['designation', 'period', 'provenience',
        'museum_no', 'project']]
df1
# Out:
#         designation        period           provenience         museum_no  \
# P237876  SAA 11 227  Neo-Assyrian               Nineveh           K 00764
# P313588  SAA 11 145  Neo-Assyrian               Nineveh           K 01441
# P313651  SAA 11 012  Neo-Assyrian               Nineveh           K 05131
# P313736  SAA 11 200  Neo-Assyrian               Nineveh           K 07294
# P313842  SAA 11 019  Neo-Assyrian               Nineveh          K 11933+
# P313928  SAA 11 099  Neo-Assyrian               Nineveh           K 14244
# P314083  SAA 11 047  Neo-Assyrian               Nineveh           K 15601
# P314131  SAA 11 152  Neo-Assyrian               Nineveh           K 16036
# P314132  SAA 11 034  Neo-Assyrian               Nineveh           K 16037
# P314197  SAA 11 168  Neo-Assyrian               Nineveh           K 16517
# P314226  SAA 11 035  Neo-Assyrian               Nineveh           Sm 0437
# P333950  SAA 11 001  Neo-Assyrian               Nineveh           K 04384
# P334311  SAA 11 156  Neo-Assyrian               Nineveh           K 00821
# P334436  SAA 11 162  Neo-Assyrian               Nineveh           K 01265
# P334437  SAA 11 033  Neo-Assyrian               Nineveh           K 01295
# P334934  SAA 11 201  Neo-Assyrian               Nineveh           K 02017
# P334935  SAA 11 202  Neo-Assyrian               Nineveh          Sm 0484+
# P334936  SAA 11 203  Neo-Assyrian               Nineveh           K 08134
# P334937  SAA 11 213  Neo-Assyrian               Nineveh          K 13548+
# P334938  SAA 11 219  Neo-Assyrian               Nineveh           K 04729
# P334939  SAA 11 207  Neo-Assyrian               Nineveh          Sm 1178+
# P334940  SAA 11 220  Neo-Assyrian               Nineveh        Rm 2,0130+
# P334941  SAA 11 206  Neo-Assyrian               Nineveh           K 08179
# P334942  SAA 11 209  Neo-Assyrian               Nineveh          K 18541+
# P334943  SAA 11 210  Neo-Assyrian               Nineveh          K 13132+
# P334944  SAA 11 205  Neo-Assyrian               Nineveh           K 08957
# P334945  SAA 11 208  Neo-Assyrian               Nineveh           K 13394
# P334946  SAA 11 215  Neo-Assyrian               Nineveh           K 13224
# P334947  SAA 11 217  Neo-Assyrian               Nineveh           K 13204
# P334948  SAA 11 212  Neo-Assyrian               Nineveh           K 12956
# ...             ...           ...                   ...               ...
# P336704  SAA 11 072  Neo-Assyrian               Nineveh         BM 089972
# P336705  SAA 11 073  Neo-Assyrian               Nineveh         BM 084875
# P336706  SAA 11 074  Neo-Assyrian               Nineveh         BM 084893
# P336707  SAA 11 075  Neo-Assyrian               Nineveh         BM 084834
# P336708  SAA 11 082  Neo-Assyrian               Nineveh           K 09529
# P336709  SAA 11 083  Neo-Assyrian               Nineveh           K 05993
# P336710  SAA 11 097  Neo-Assyrian               Nineveh           K 06509
# P336711  SAA 11 104  Neo-Assyrian               Nineveh          K 20329+
# P336712  SAA 11 118  Neo-Assyrian               Nineveh           K 15276
# P336713  SAA 11 129  Neo-Assyrian               Nineveh           K 10349
# P336714  SAA 11 130  Neo-Assyrian               Nineveh  Ki 1904-10-9,281
# P336715  SAA 11 131  Neo-Assyrian               Nineveh           K 16475
# P336716  SAA 11 142  Neo-Assyrian               Nineveh           K 00771
# P336717  SAA 11 161  Neo-Assyrian               Nineveh           K 15270
# P336718  SAA 11 164  Neo-Assyrian               Nineveh         Rm 2,0591
# P336719  SAA 11 186  Neo-Assyrian               Nineveh           K 12852
# P336720  SAA 11 195  Neo-Assyrian               Nineveh           K 20348
# P336721  SAA 11 196  Neo-Assyrian               Nineveh           K 18317
# P336722  SAA 11 197  Neo-Assyrian               Nineveh           K 01991
# P336723  SAA 11 199  Neo-Assyrian               Nineveh           K 14233
# P336724  SAA 11 234  Neo-Assyrian               Nineveh           K 17307
# P336799  SAA 11 030  Neo-Assyrian               Nineveh           DT 256+
# P336801  SAA 11 014  Neo-Assyrian               Nineveh          K 13156+
# P336803  SAA 11 024  Neo-Assyrian  Nineveh (Nebi Yunus)          IM 59049
# P336804  SAA 11 100  Neo-Assyrian  Nineveh (Nebi Yunus)          IM 59048
# P336805  SAA 11 121  Neo-Assyrian  Nineveh (Nebi Yunus)          IM 60011
# P336806  SAA 11 102  Neo-Assyrian  Nineveh (Nebi Yunus)          IM 60012
# P336807  SAA 11 101  Neo-Assyrian  Nineveh (Nebi Yunus)          IM 60014
# P336808  SAA 11 103  Neo-Assyrian  Nineveh (Nebi Yunus)          IM 60016
# P337167  SAA 11 027  Neo-Assyrian               Nineveh           K 01275
#
#             project
# P237876  saao/saa11
# P313588  saao/saa11
# P313651  saao/saa11
# P313736  saao/saa11
# P313842  saao/saa11
# P313928  saao/saa11
# P314083  saao/saa11
# P314131  saao/saa11
# P314132  saao/saa11
# P314197  saao/saa11
# P314226  saao/saa11
# P333950  saao/saa11
# P334311  saao/saa11
# P334436  saao/saa11
# P334437  saao/saa11
# P334934  saao/saa11
# P334935  saao/saa11
# P334936  saao/saa11
# P334937  saao/saa11
# P334938  saao/saa11
# P334939  saao/saa11
# P334940  saao/saa11
# P334941  saao/saa11
# P334942  saao/saa11
# P334943  saao/saa11
# P334944  saao/saa11
# P334945  saao/saa11
# P334946  saao/saa11
# P334947  saao/saa11
# P334948  saao/saa11
# ...             ...
# P336704  saao/saa11
# P336705  saao/saa11
# P336706  saao/saa11
# P336707  saao/saa11
# P336708  saao/saa11
# P336709  saao/saa11
# P336710  saao/saa11
# P336711  saao/saa11
# P336712  saao/saa11
# P336713  saao/saa11
# P336714  saao/saa11
# P336715  saao/saa11
# P336716  saao/saa11
# P336717  saao/saa11
# P336718  saao/saa11
# P336719  saao/saa11
# P336720  saao/saa11
# P336721  saao/saa11
# P336722  saao/saa11
# P336723  saao/saa11
# P336724  saao/saa11
# P336799  saao/saa11
# P336801  saao/saa11
# P336803  saao/saa11
# P336804  saao/saa11
# P336805  saao/saa11
# P336806  saao/saa11
# P336807  saao/saa11
# P336808  saao/saa11
# P337167  saao/saa11
#
# [234 rows x 5 columns]

# %% [markdown]
# ## Manipulate
# The Dataframe may now be manipulated with standard Pandas methods. The example code selects the texts from Ur.
# > `ur = df1[df1.provenience == "Ur"]`

# %% [markdown]
# ## Save
# Save the resulting data set as a `csv` file. `UTF-8` encoding is the encoding with the widest support in text analysis (and also the encoding used by [ORACC](http://oracc.org)). If you intend to use the catalog file in Excel, however, it is better to use `utf-16` encoding.

# %%
filename = 'catalog.csv'
with open('output/' + filename, 'w', encoding='utf-8') as w:
    df1.to_csv(w)
